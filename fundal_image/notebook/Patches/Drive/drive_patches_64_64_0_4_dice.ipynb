# %% [markdown]
# ### Import the required libraries and modules:

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
import numpy as np

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# %cd /content/gdrive/MyDrive/medical_image_processing/
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/medical_image_processing

# %%
from fundal_image.utils import create_dir, get_filenames_sorted
from patches import generate_patches_images_only, reconstruct_patches
from metrics import iou, dice_coef, dice_loss, DiceBCELoss, bce
from metrics import compute_metrics, save_results
from utils import read_image_train, read_mask_train

# %%
image_sizes = {"HRF": (2336, 3504), "drive": (584, 565), "chase_db": (960, 999)}
patch_size = {"HRF": (768, 768),
              "drive":(64, 64)
              }

dataset_name = "drive"
patch_size = patch_size[dataset_name]
patch_height = patch_size[0]
patch_width = patch_size[1]

# %%
loss_str = "dice_loss"
with_augmentation = False
stride=64
seed = 42
run_id = 1
test_percentage = 0.4
class_weight = 0.4
class_weight_str = str(class_weight).replace(".", "_")
aug_string = ""
if with_augmentation:
    aug_string = "_hvr"
test_percentage_str = str(test_percentage).replace(".", "_")
root_path = f"/content/datasets/{dataset_name}_{patch_height}_{stride}_{loss_str}_{class_weight_str}_{aug_string}_{test_percentage_str}_{run_id}/"

images_path_train = f"{root_path}/training/images/"
gt_path_train = f"{root_path}/training/1st_manual/"
images_path_test = f"{root_path}/test/images/"
gt_path_test = f"{root_path}/test/1st_manual/"

create_dir(images_path_train)
create_dir(gt_path_train)
create_dir(images_path_test)
create_dir(gt_path_test)

# %%
def wbce(actual, predicted):
    y_pred = K.clip(predicted, K.epsilon(), 1 - K.epsilon())
    term_0 = (1 - actual) * K.log(1 - y_pred)
    term_1 = class_weight * actual * K.log(y_pred + K.epsilon())
    return -K.mean(term_0 + term_1, axis=0)

# %%
root_path
# Out:
# '/content/datasets/drive_64_64_dice_bce_0_4__0_4_1/'

# %%
images_path_train
# Out:
# '/content/datasets/drive_64_64_dice_bce_0_4__0_4_1//training/images/'

# %%
# !cp /content/gdrive/MyDrive/medical_image_processing/fundal_image/datasets/drive/training/images/*.* {images_path_train}
# !cp /content/gdrive/MyDrive/medical_image_processing/fundal_image/datasets/drive/training/1st_manual/*.* {gt_path_train}

# %%
# !cp /content/gdrive/MyDrive/medical_image_processing/fundal_image/datasets/drive/test/images/*.* {images_path_test}
# !cp /content/gdrive/MyDrive/medical_image_processing/fundal_image/datasets/drive/test/1st_manual/*.* {gt_path_test}

# %%
# !ls /content/gdrive/MyDrive/medical_image_processing/fundal_image/datasets/drive/training/images
# Out:
# 21_training.tif  26_training.tif  31_training.tif  36_training.tif
# 22_training.tif  27_training.tif  32_training.tif  37_training.tif
# 23_training.tif  28_training.tif  33_training.tif  38_training.tif
# 24_training.tif  29_training.tif  34_training.tif  39_training.tif
# 25_training.tif  30_training.tif  35_training.tif  40_training.tif

# %%
# images_files, gt_files = get_filenames_sorted(images_path, gt_path)
# print(len(images_files), len(gt_files))
# # train_test_split
# from sklearn.model_selection import train_test_split
# label = [_xtrain.rsplit("/", 1)[1].rsplit(".", 1)[0].rsplit("_", 1)[1] for _xtrain in images_files] 
# xtrain, xtest, ytrain, ytest = train_test_split(images_files, gt_files, stratify=label,  test_size=test_percentage, random_state=seed)

# %%
xtrain, ytrain = get_filenames_sorted(images_path_train, gt_path_train)
xtest, ytest = get_filenames_sorted(images_path_test, gt_path_test)

# %%
print(len(xtrain), len(xtest))
# print(label)
# Out:
# 20 20

# %%
xtrain[:5]
# Out:
# ['/content/datasets/drive_64_64_dice_bce_0_4__0_4_1//training/images/21_training.tif',
#  '/content/datasets/drive_64_64_dice_bce_0_4__0_4_1//training/images/22_training.tif',
#  '/content/datasets/drive_64_64_dice_bce_0_4__0_4_1//training/images/23_training.tif',
#  '/content/datasets/drive_64_64_dice_bce_0_4__0_4_1//training/images/24_training.tif',
#  '/content/datasets/drive_64_64_dice_bce_0_4__0_4_1//training/images/25_training.tif']

# %%
print(len(ytrain), len(ytest))
ytrain[:5]
# Out:
# 20 20
# ['/content/datasets/drive_64_64_dice_bce_0_4__0_4_1//training/1st_manual/21_manual1.gif',
#  '/content/datasets/drive_64_64_dice_bce_0_4__0_4_1//training/1st_manual/22_manual1.gif',
#  '/content/datasets/drive_64_64_dice_bce_0_4__0_4_1//training/1st_manual/23_manual1.gif',
#  '/content/datasets/drive_64_64_dice_bce_0_4__0_4_1//training/1st_manual/24_manual1.gif',
#  '/content/datasets/drive_64_64_dice_bce_0_4__0_4_1//training/1st_manual/25_manual1.gif']

# %%
from tqdm import tqdm
import pandas as pd

# %%
num_pixels_to_add = [0, 0]
if (image_sizes[dataset_name][0] % patch_size[0]) > 0:
    num_pixels_to_add[0] = ((image_sizes["drive"][0] // patch_size[0]) + 1) * patch_size[0]
    num_pixels_to_add[1] = ((image_sizes["drive"][1] // patch_size[1]) + 1) * patch_size[1]

split_name = "split_2"
data_path = root_path
splits =["train","test"]


split = "train"
#for split in splits:
image_patches_path = f"{data_path}/{split_name}/{split}/image/"
create_dir(image_patches_path)
gt_patches_path = f"{data_path}/{split_name}/{split}/mask/"
create_dir(gt_patches_path)
im_patches_dict_train, metadata_train_df, gt_patches_dict_train = generate_patches_images_only(xtrain,
                                                                image_patches_path,
                                                                patch_size=patch_size,
                                                                stride=stride,
                                                                zero_padding_size=num_pixels_to_add,
                                                                gt_files=ytrain,
                                                                save_path_gt=gt_patches_path)
metadata_train_df.to_csv(f"{data_path}/{split_name}/image_patches_{stride}_{stride}_{split}.csv", index=False)
# Out:
# Generating patches for 20 images
# 100%|██████████| 20/20 [00:00<00:00, 23.62it/s]

# %%
split = "test"
#for split in splits:
image_patches_path = f"{data_path}/{split_name}/{split}/image/"
create_dir(image_patches_path)
gt_patches_path = f"{data_path}/{split_name}/{split}/mask/"
create_dir(gt_patches_path)
im_patches_dict_test, metadata_test_df, gt_patches_dict_test = generate_patches_images_only(xtest,
                                                                image_patches_path,
                                                                patch_size=patch_size,
                                                                stride=stride,
                                                                zero_padding_size=num_pixels_to_add,
                                                                gt_files=ytest,
                                                                save_path_gt=gt_patches_path)
metadata_test_df.to_csv(f"{data_path}/{split_name}/image_patches_{patch_height}_{stride}_{split}.csv", index=False)
# Out:
# Generating patches for 20 images
# 100%|██████████| 20/20 [00:00<00:00, 25.53it/s]

# %%
metadata_test_df.shape
# Out:
# (1800, 7)

# %%
metadata_train_df.shape
# Out:
# (1800, 7)

# %%
metadata_train_df.head()
# Out:
#                                       image_filename  ...  num_fg_pixels
# 0  /content/datasets/drive_64_64_dice_bce_0_4__0_...  ...           1667
# 1  /content/datasets/drive_64_64_dice_bce_0_4__0_...  ...           1774
# 2  /content/datasets/drive_64_64_dice_bce_0_4__0_...  ...           1788
# 3  /content/datasets/drive_64_64_dice_bce_0_4__0_...  ...           1746
# 4  /content/datasets/drive_64_64_dice_bce_0_4__0_...  ...           1750
#
# [5 rows x 7 columns]

# %%
import glob
split = "test"
image_patches_path = f"{data_path}/{split_name}/{split}/image/"

reconstructed_original_path = f"{data_path}/{split_name}/reconstructed/{split}/image"
create_dir(reconstructed_original_path)
reconstruct_patches(im_patches_dict_test,
                    metadata_test_df,
                    reconstructed_original_path
                    )

# %%
print(list(gt_patches_dict_test.keys()))
# Out:
# ['01_test', '02_test', '03_test', '04_test', '05_test', '06_test', '07_test', '08_test', '09_test', '10_test', '11_test', '12_test', '13_test', '14_test', '15_test', '16_test', '17_test', '18_test', '19_test', '20_test']

# %%
type(gt_patches_dict_test["01_test"])
# Out:
# numpy.ndarray

# %%
reconstructed_gt_path = f"{data_path}/{split_name}/reconstructed/{split}/mask"

create_dir(reconstructed_gt_path)
reconstruct_patches(gt_patches_dict_test,
                    metadata_test_df,
                    reconstructed_gt_path,
                    )

# %%
print([k for k in im_patches_dict_test.keys()])
# Out:
# ['01_test', '02_test', '03_test', '04_test', '05_test', '06_test', '07_test', '08_test', '09_test', '10_test', '11_test', '12_test', '13_test', '14_test', '15_test', '16_test', '17_test', '18_test', '19_test', '20_test']

# %% [markdown]
# ### Construct the Model:

# %%
def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    b1 = conv_block(p4, 1024)

    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="UNET")
    return model

input_shape = (512, 512, 3)
model = build_unet(input_shape)
model.summary()
# Out:
# Model: "UNET"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 512, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 512, 512, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 512, 512, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 512, 512, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 12  0          ['activation_3[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 25  295168      ['max_pooling2d_1[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_4[0][0]']
#  rmalization)                   6)
#
#  activation_4 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_4[0][0]']
#                                 6)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 25  590080      ['activation_4[0][0]']
#                                 6)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_5[0][0]']
#  rmalization)                   6)
#
#  activation_5 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_5[0][0]']
#                                 6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 512)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 512)  2097664    ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 64, 64, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 25  524544     ['activation_11[0][0]']
#  spose)                         6)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 51  0           ['conv2d_transpose_1[0][0]',
#                                 2)                                'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_12 (BatchN  (None, 128, 128, 25  1024       ['conv2d_12[0][0]']
#  ormalization)                  6)
#
#  activation_12 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_12[0][0]']
#                                 6)
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 25  590080      ['activation_12[0][0]']
#                                 6)
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 25  1024       ['conv2d_13[0][0]']
#  ormalization)                  6)
#
#  activation_13 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_13[0][0]']
#                                 6)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 12  131200     ['activation_13[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 256, 256, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  activation_14 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_15 (BatchN  (None, 256, 256, 12  512        ['conv2d_15[0][0]']
#  ormalization)                  8)
#
#  activation_15 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_15[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 64  32832      ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 512, 512, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 512, 512, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 512, 512, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 512, 512, 1)  65          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %% [markdown]
# ### Adding the Metrics:

# %%
def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def DiceBCELoss(y_true, y_pred):
    
    inputs = tf.keras.layers.Flatten()(y_true)
    targets = tf.keras.layers.Flatten()(y_pred)

    intersection = tf.reduce_sum(inputs * targets)
    dice_loss = 1 - (2.*intersection + smooth)/(tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)
    BCE = tf.keras.losses.BinaryCrossentropy()
    Dice_BCE = BCE(inputs, targets) + dice_loss

    return Dice_BCE

def bce(y_true, y_pred):
    
    inputs = tf.keras.layers.Flatten()(y_true)
    targets = tf.keras.layers.Flatten()(y_pred)
    BCE = tf.keras.losses.BinaryCrossentropy()
    Dice_BCE = BCE(inputs, targets)

    return Dice_BCE

# %% [markdown]
# ### Training the Model:

# %%
if loss_str == "bce":
    loss = bce
elif loss_str == "dice_bce":
    loss = DiceBCELoss
elif loss_str == "dice_loss":
    loss = dice_loss
elif loss_str == "wbce":
    loss = wbce
else:
    raise Exception("Invalid value for loss_str")
    
print(loss)
# Out:
# <function DiceBCELoss at 0x7f40502fae60>

# %%
H = patch_height
W = patch_width
loss = dice_loss

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.png")))
    y = sorted(glob(os.path.join(path, "mask", "*.png")))
    return x, y

def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)
    return x, y

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)              ## (512, 512, 1)
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y, batch_size=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(4)
    return dataset

# %%
from keras.metrics import AUC

# %%
model_dir = f"{root_path}/trained_models/"

# %%
create_dir(model_dir)

# %%
# !ls {model_dir}

# %%
# %cd /content/datasets
# Out:
# /content/datasets

# %%
from glob import glob

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir(model_dir)

""" Hyperparameters """
batch_size = 8
lr = 1e-4
num_epochs = 50
model_path = os.path.join(f"{model_dir}", "model.h5")
csv_path = os.path.join(f"{model_dir}", "data.csv")

""" Dataset """
dataset_path = f"{data_path}/{split_name}"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
# train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model = build_unet((H, W, 3))
model.compile(loss=loss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision(), AUC()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 1800 - 1800
# Valid: 1800 - 1800
# Epoch 1/50
# 225/225 [==============================] - ETA: 0s - loss: 0.6150 - dice_coef: 0.3850 - iou: 0.2566 - recall: 0.7794 - precision: 0.3069 - auc: 0.8914
# Epoch 1: val_loss improved from inf to 0.91772, saving model to /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//trained_models/model.h5
# 225/225 [==============================] - 22s 39ms/step - loss: 0.6150 - dice_coef: 0.3850 - iou: 0.2566 - recall: 0.7794 - precision: 0.3069 - auc: 0.8914 - val_loss: 0.9177 - val_dice_coef: 0.0823 - val_iou: 0.0432 - val_recall: 3.8066e-05 - val_precision: 0.0071 - val_auc: 0.5363 - lr: 1.0000e-04
# Epoch 2/50
# 225/225 [==============================] - ETA: 0s - loss: 0.4682 - dice_coef: 0.5318 - iou: 0.3859 - recall: 0.7607 - precision: 0.6179 - auc: 0.9257
# Epoch 2: val_loss improved from 0.91772 to 0.81451, saving model to /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//trained_models/model.h5
# 225/225 [==============================] - 8s 37ms/step - loss: 0.4682 - dice_coef: 0.5318 - iou: 0.3859 - recall: 0.7607 - precision: 0.6179 - auc: 0.9257 - val_loss: 0.8145 - val_dice_coef: 0.1855 - val_iou: 0.1081 - val_recall: 0.1452 - val_precision: 0.5262 - val_auc: 0.6972 - lr: 1.0000e-04
# Epoch 3/50
# 224/225 [============================>.] - ETA: 0s - loss: 0.4089 - dice_coef: 0.5911 - iou: 0.4462 - recall: 0.7603 - precision: 0.6858 - auc: 0.9306
# Epoch 3: val_loss improved from 0.81451 to 0.53782, saving model to /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//trained_models/model.h5
# 225/225 [==============================] - 8s 37ms/step - loss: 0.4109 - dice_coef: 0.5891 - iou: 0.4445 - recall: 0.7603 - precision: 0.6845 - auc: 0.9306 - val_loss: 0.5378 - val_dice_coef: 0.4622 - val_iou: 0.3218 - val_recall: 0.4772 - val_precision: 0.7778 - val_auc: 0.8677 - lr: 1.0000e-04
# Epoch 4/50
# 223/225 [============================>.] - ETA: 0s - loss: 0.3697 - dice_coef: 0.6303 - iou: 0.4872 - recall: 0.7645 - precision: 0.7244 - auc: 0.9339
# Epoch 4: val_loss did not improve from 0.53782
# 225/225 [==============================] - 7s 33ms/step - loss: 0.3706 - dice_coef: 0.6294 - iou: 0.4865 - recall: 0.7649 - precision: 0.7247 - auc: 0.9340 - val_loss: 0.5445 - val_dice_coef: 0.4555 - val_iou: 0.3138 - val_recall: 0.4315 - val_precision: 0.7906 - val_auc: 0.8396 - lr: 1.0000e-04
# Epoch 5/50
# 224/225 [============================>.] - ETA: 0s - loss: 0.3409 - dice_coef: 0.6591 - iou: 0.5173 - recall: 0.7621 - precision: 0.7537 - auc: 0.9335
# Epoch 5: val_loss improved from 0.53782 to 0.51295, saving model to /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//trained_models/model.h5
# 225/225 [==============================] - 8s 37ms/step - loss: 0.3421 - dice_coef: 0.6579 - iou: 0.5161 - recall: 0.7621 - precision: 0.7536 - auc: 0.9335 - val_loss: 0.5130 - val_dice_coef: 0.4870 - val_iou: 0.3435 - val_recall: 0.4274 - val_precision: 0.9447 - val_auc: 0.8456 - lr: 1.0000e-04
# Epoch 6/50
# 223/225 [============================>.] - ETA: 0s - loss: 0.3125 - dice_coef: 0.6875 - iou: 0.5461 - recall: 0.7680 - precision: 0.7774 - auc: 0.9352
# Epoch 6: val_loss improved from 0.51295 to 0.47357, saving model to /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//trained_models/model.h5
# 225/225 [==============================] - 8s 37ms/step - loss: 0.3125 - dice_coef: 0.6875 - iou: 0.5462 - recall: 0.7684 - precision: 0.7778 - auc: 0.9353 - val_loss: 0.4736 - val_dice_coef: 0.5264 - val_iou: 0.3808 - val_recall: 0.4574 - val_precision: 0.9246 - val_auc: 0.8718 - lr: 1.0000e-04
# Epoch 7/50
# 223/225 [============================>.] - ETA: 0s - loss: 0.2889 - dice_coef: 0.7111 - iou: 0.5715 - recall: 0.7766 - precision: 0.7904 - auc: 0.9372
# Epoch 7: val_loss improved from 0.47357 to 0.42941, saving model to /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//trained_models/model.h5
# 225/225 [==============================] - 8s 37ms/step - loss: 0.2889 - dice_coef: 0.7111 - iou: 0.5716 - recall: 0.7770 - precision: 0.7908 - auc: 0.9374 - val_loss: 0.4294 - val_dice_coef: 0.5706 - val_iou: 0.4222 - val_recall: 0.4989 - val_precision: 0.9175 - val_auc: 0.8790 - lr: 1.0000e-04
# Epoch 8/50
# 225/225 [==============================] - ETA: 0s - loss: 0.2700 - dice_coef: 0.7300 - iou: 0.5916 - recall: 0.7828 - precision: 0.8013 - auc: 0.9363
# Epoch 8: val_loss did not improve from 0.42941
# 225/225 [==============================] - 7s 33ms/step - loss: 0.2700 - dice_coef: 0.7300 - iou: 0.5916 - recall: 0.7828 - precision: 0.8013 - auc: 0.9363 - val_loss: 0.4422 - val_dice_coef: 0.5578 - val_iou: 0.4073 - val_recall: 0.4850 - val_precision: 0.8763 - val_auc: 0.8457 - lr: 1.0000e-04
# Epoch 9/50
# 224/225 [============================>.] - ETA: 0s - loss: 0.2570 - dice_coef: 0.7430 - iou: 0.6064 - recall: 0.7845 - precision: 0.8108 - auc: 0.9329
# Epoch 9: val_loss improved from 0.42941 to 0.37823, saving model to /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//trained_models/model.h5
# 225/225 [==============================] - 8s 37ms/step - loss: 0.2572 - dice_coef: 0.7428 - iou: 0.6061 - recall: 0.7846 - precision: 0.8108 - auc: 0.9329 - val_loss: 0.3782 - val_dice_coef: 0.6218 - val_iou: 0.4723 - val_recall: 0.5502 - val_precision: 0.9111 - val_auc: 0.8674 - lr: 1.0000e-04
# Epoch 10/50
# 223/225 [============================>.] - ETA: 0s - loss: 0.2455 - dice_coef: 0.7545 - iou: 0.6197 - recall: 0.7911 - precision: 0.8147 - auc: 0.9320
# Epoch 10: val_loss did not improve from 0.37823
# 225/225 [==============================] - 7s 33ms/step - loss: 0.2449 - dice_coef: 0.7551 - iou: 0.6205 - recall: 0.7914 - precision: 0.8151 - auc: 0.9322 - val_loss: 0.4511 - val_dice_coef: 0.5489 - val_iou: 0.3993 - val_recall: 0.4686 - val_precision: 0.8726 - val_auc: 0.8153 - lr: 1.0000e-04
# Epoch 11/50
# 223/225 [============================>.] - ETA: 0s - loss: 0.2386 - dice_coef: 0.7614 - iou: 0.6288 - recall: 0.7944 - precision: 0.8199 - auc: 0.9311
# Epoch 11: val_loss did not improve from 0.37823
# 225/225 [==============================] - 7s 33ms/step - loss: 0.2379 - dice_coef: 0.7621 - iou: 0.6296 - recall: 0.7948 - precision: 0.8203 - auc: 0.9313 - val_loss: 0.4969 - val_dice_coef: 0.5031 - val_iou: 0.3564 - val_recall: 0.3927 - val_precision: 0.9496 - val_auc: 0.8000 - lr: 1.0000e-04
# Epoch 12/50
# 225/225 [==============================] - ETA: 0s - loss: 0.2311 - dice_coef: 0.7689 - iou: 0.6373 - recall: 0.7995 - precision: 0.8228 - auc: 0.9312
# Epoch 12: val_loss did not improve from 0.37823
# 225/225 [==============================] - 7s 33ms/step - loss: 0.2311 - dice_coef: 0.7689 - iou: 0.6373 - recall: 0.7995 - precision: 0.8228 - auc: 0.9312 - val_loss: 0.4809 - val_dice_coef: 0.5191 - val_iou: 0.3693 - val_recall: 0.3997 - val_precision: 0.9453 - val_auc: 0.7914 - lr: 1.0000e-04
# Epoch 13/50
# 225/225 [==============================] - ETA: 0s - loss: 0.2316 - dice_coef: 0.7684 - iou: 0.6375 - recall: 0.7982 - precision: 0.8244 - auc: 0.9292
# Epoch 13: val_loss did not improve from 0.37823
# 225/225 [==============================] - 7s 33ms/step - loss: 0.2316 - dice_coef: 0.7684 - iou: 0.6375 - recall: 0.7982 - precision: 0.8244 - auc: 0.9292 - val_loss: 0.5204 - val_dice_coef: 0.4796 - val_iou: 0.3336 - val_recall: 0.3747 - val_precision: 0.9292 - val_auc: 0.7598 - lr: 1.0000e-04
# Epoch 14/50
# 225/225 [==============================] - ETA: 0s - loss: 0.2196 - dice_coef: 0.7804 - iou: 0.6504 - recall: 0.8025 - precision: 0.8279 - auc: 0.9294
# Epoch 14: val_loss did not improve from 0.37823
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 225/225 [==============================] - 7s 33ms/step - loss: 0.2196 - dice_coef: 0.7804 - iou: 0.6504 - recall: 0.8025 - precision: 0.8279 - auc: 0.9294 - val_loss: 0.3868 - val_dice_coef: 0.6132 - val_iou: 0.4619 - val_recall: 0.5198 - val_precision: 0.9221 - val_auc: 0.8371 - lr: 1.0000e-04
# Epoch 15/50
# 224/225 [============================>.] - ETA: 0s - loss: 0.2111 - dice_coef: 0.7889 - iou: 0.6599 - recall: 0.7974 - precision: 0.8384 - auc: 0.9267
# Epoch 15: val_loss improved from 0.37823 to 0.31488, saving model to /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//trained_models/model.h5
# 225/225 [==============================] - 8s 37ms/step - loss: 0.2109 - dice_coef: 0.7891 - iou: 0.6602 - recall: 0.7974 - precision: 0.8385 - auc: 0.9267 - val_loss: 0.3149 - val_dice_coef: 0.6851 - val_iou: 0.5431 - val_recall: 0.6389 - val_precision: 0.8718 - val_auc: 0.8723 - lr: 1.0000e-05
# Epoch 16/50
# 225/225 [==============================] - ETA: 0s - loss: 0.2001 - dice_coef: 0.7999 - iou: 0.6748 - recall: 0.8149 - precision: 0.8383 - auc: 0.9327
# Epoch 16: val_loss did not improve from 0.31488
# 225/225 [==============================] - 7s 33ms/step - loss: 0.2001 - dice_coef: 0.7999 - iou: 0.6748 - recall: 0.8149 - precision: 0.8383 - auc: 0.9327 - val_loss: 0.3194 - val_dice_coef: 0.6806 - val_iou: 0.5368 - val_recall: 0.6285 - val_precision: 0.8794 - val_auc: 0.8728 - lr: 1.0000e-05
# Epoch 17/50
# 225/225 [==============================] - ETA: 0s - loss: 0.1954 - dice_coef: 0.8046 - iou: 0.6809 - recall: 0.8185 - precision: 0.8422 - auc: 0.9336
# Epoch 17: val_loss did not improve from 0.31488
# 225/225 [==============================] - 7s 33ms/step - loss: 0.1954 - dice_coef: 0.8046 - iou: 0.6809 - recall: 0.8185 - precision: 0.8422 - auc: 0.9336 - val_loss: 0.3200 - val_dice_coef: 0.6800 - val_iou: 0.5360 - val_recall: 0.6292 - val_precision: 0.8772 - val_auc: 0.8740 - lr: 1.0000e-05
# Epoch 18/50
# 225/225 [==============================] - ETA: 0s - loss: 0.1913 - dice_coef: 0.8087 - iou: 0.6866 - recall: 0.8218 - precision: 0.8462 - auc: 0.9343
# Epoch 18: val_loss did not improve from 0.31488
# 225/225 [==============================] - 7s 33ms/step - loss: 0.1913 - dice_coef: 0.8087 - iou: 0.6866 - recall: 0.8218 - precision: 0.8462 - auc: 0.9343 - val_loss: 0.3181 - val_dice_coef: 0.6819 - val_iou: 0.5388 - val_recall: 0.6318 - val_precision: 0.8770 - val_auc: 0.8709 - lr: 1.0000e-05
# Epoch 19/50
# 225/225 [==============================] - ETA: 0s - loss: 0.1876 - dice_coef: 0.8124 - iou: 0.6918 - recall: 0.8249 - precision: 0.8497 - auc: 0.9348
# Epoch 19: val_loss did not improve from 0.31488
# 225/225 [==============================] - 7s 33ms/step - loss: 0.1876 - dice_coef: 0.8124 - iou: 0.6918 - recall: 0.8249 - precision: 0.8497 - auc: 0.9348 - val_loss: 0.3187 - val_dice_coef: 0.6813 - val_iou: 0.5377 - val_recall: 0.6297 - val_precision: 0.8774 - val_auc: 0.8704 - lr: 1.0000e-05
# Epoch 20/50
# 225/225 [==============================] - ETA: 0s - loss: 0.1840 - dice_coef: 0.8160 - iou: 0.6966 - recall: 0.8272 - precision: 0.8537 - auc: 0.9351
# Epoch 20: val_loss did not improve from 0.31488
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1e-06.
# 225/225 [==============================] - 7s 33ms/step - loss: 0.1840 - dice_coef: 0.8160 - iou: 0.6966 - recall: 0.8272 - precision: 0.8537 - auc: 0.9351 - val_loss: 0.3331 - val_dice_coef: 0.6669 - val_iou: 0.5223 - val_recall: 0.6042 - val_precision: 0.8912 - val_auc: 0.8613 - lr: 1.0000e-05
# Epoch 21/50
# 225/225 [==============================] - ETA: 0s - loss: 0.1875 - dice_coef: 0.8125 - iou: 0.6915 - recall: 0.8134 - precision: 0.8597 - auc: 0.9315
# Epoch 21: val_loss improved from 0.31488 to 0.31256, saving model to /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//trained_models/model.h5
# 225/225 [==============================] - 8s 37ms/step - loss: 0.1875 - dice_coef: 0.8125 - iou: 0.6915 - recall: 0.8134 - precision: 0.8597 - auc: 0.9315 - val_loss: 0.3126 - val_dice_coef: 0.6874 - val_iou: 0.5459 - val_recall: 0.6427 - val_precision: 0.8715 - val_auc: 0.8720 - lr: 1.0000e-06
# Epoch 22/50
# 224/225 [============================>.] - ETA: 0s - loss: 0.1835 - dice_coef: 0.8165 - iou: 0.6973 - recall: 0.8243 - precision: 0.8566 - auc: 0.9347
# Epoch 22: val_loss improved from 0.31256 to 0.31148, saving model to /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//trained_models/model.h5
# 225/225 [==============================] - 8s 37ms/step - loss: 0.1834 - dice_coef: 0.8166 - iou: 0.6975 - recall: 0.8244 - precision: 0.8566 - auc: 0.9348 - val_loss: 0.3115 - val_dice_coef: 0.6885 - val_iou: 0.5473 - val_recall: 0.6470 - val_precision: 0.8680 - val_auc: 0.8735 - lr: 1.0000e-06
# Epoch 23/50
# 223/225 [============================>.] - ETA: 0s - loss: 0.1827 - dice_coef: 0.8173 - iou: 0.6984 - recall: 0.8270 - precision: 0.8559 - auc: 0.9353
# Epoch 23: val_loss did not improve from 0.31148
# 225/225 [==============================] - 7s 33ms/step - loss: 0.1821 - dice_coef: 0.8179 - iou: 0.6993 - recall: 0.8275 - precision: 0.8560 - auc: 0.9355 - val_loss: 0.3121 - val_dice_coef: 0.6879 - val_iou: 0.5467 - val_recall: 0.6465 - val_precision: 0.8678 - val_auc: 0.8732 - lr: 1.0000e-06
# Epoch 24/50
# 223/225 [============================>.] - ETA: 0s - loss: 0.1819 - dice_coef: 0.8181 - iou: 0.6995 - recall: 0.8284 - precision: 0.8560 - auc: 0.9355
# Epoch 24: val_loss did not improve from 0.31148
# 225/225 [==============================] - 7s 33ms/step - loss: 0.1813 - dice_coef: 0.8187 - iou: 0.7004 - recall: 0.8288 - precision: 0.8560 - auc: 0.9358 - val_loss: 0.3127 - val_dice_coef: 0.6873 - val_iou: 0.5461 - val_recall: 0.6460 - val_precision: 0.8677 - val_auc: 0.8730 - lr: 1.0000e-06
# Epoch 25/50
# 224/225 [============================>.] - ETA: 0s - loss: 0.1808 - dice_coef: 0.8192 - iou: 0.7011 - recall: 0.8295 - precision: 0.8564 - auc: 0.9359
# Epoch 25: val_loss did not improve from 0.31148
# 225/225 [==============================] - 7s 33ms/step - loss: 0.1807 - dice_coef: 0.8193 - iou: 0.7013 - recall: 0.8295 - precision: 0.8564 - auc: 0.9359 - val_loss: 0.3133 - val_dice_coef: 0.6867 - val_iou: 0.5454 - val_recall: 0.6451 - val_precision: 0.8679 - val_auc: 0.8727 - lr: 1.0000e-06
# Epoch 26/50
# 224/225 [============================>.] - ETA: 0s - loss: 0.1802 - dice_coef: 0.8198 - iou: 0.7019 - recall: 0.8301 - precision: 0.8568 - auc: 0.9360
# Epoch 26: val_loss did not improve from 0.31148
# 225/225 [==============================] - 7s 33ms/step - loss: 0.1800 - dice_coef: 0.8200 - iou: 0.7022 - recall: 0.8301 - precision: 0.8568 - auc: 0.9361 - val_loss: 0.3137 - val_dice_coef: 0.6863 - val_iou: 0.5450 - val_recall: 0.6443 - val_precision: 0.8683 - val_auc: 0.8724 - lr: 1.0000e-06
# Epoch 27/50
# 223/225 [============================>.] - ETA: 0s - loss: 0.1801 - dice_coef: 0.8199 - iou: 0.7021 - recall: 0.8302 - precision: 0.8572 - auc: 0.9359
# Epoch 27: val_loss did not improve from 0.31148
# 225/225 [==============================] - 7s 32ms/step - loss: 0.1795 - dice_coef: 0.8205 - iou: 0.7030 - recall: 0.8306 - precision: 0.8572 - auc: 0.9361 - val_loss: 0.3140 - val_dice_coef: 0.6860 - val_iou: 0.5446 - val_recall: 0.6437 - val_precision: 0.8685 - val_auc: 0.8721 - lr: 1.0000e-06
# Epoch 28/50
# 224/225 [============================>.] - ETA: 0s - loss: 0.1791 - dice_coef: 0.8209 - iou: 0.7035 - recall: 0.8311 - precision: 0.8577 - auc: 0.9362
# Epoch 28: val_loss did not improve from 0.31148
# 225/225 [==============================] - 7s 33ms/step - loss: 0.1789 - dice_coef: 0.8211 - iou: 0.7037 - recall: 0.8311 - precision: 0.8577 - auc: 0.9362 - val_loss: 0.3144 - val_dice_coef: 0.6856 - val_iou: 0.5441 - val_recall: 0.6429 - val_precision: 0.8688 - val_auc: 0.8717 - lr: 1.0000e-06
# Epoch 29/50
# 223/225 [============================>.] - ETA: 0s - loss: 0.1789 - dice_coef: 0.8211 - iou: 0.7037 - recall: 0.8312 - precision: 0.8581 - auc: 0.9361
# Epoch 29: val_loss did not improve from 0.31148
# 225/225 [==============================] - 7s 32ms/step - loss: 0.1783 - dice_coef: 0.8217 - iou: 0.7045 - recall: 0.8316 - precision: 0.8582 - auc: 0.9363 - val_loss: 0.3148 - val_dice_coef: 0.6852 - val_iou: 0.5437 - val_recall: 0.6422 - val_precision: 0.8692 - val_auc: 0.8713 - lr: 1.0000e-06
# Epoch 30/50
# 223/225 [============================>.] - ETA: 0s - loss: 0.1784 - dice_coef: 0.8216 - iou: 0.7044 - recall: 0.8317 - precision: 0.8586 - auc: 0.9362
# Epoch 30: val_loss did not improve from 0.31148
# 225/225 [==============================] - 7s 32ms/step - loss: 0.1778 - dice_coef: 0.8222 - iou: 0.7053 - recall: 0.8322 - precision: 0.8587 - auc: 0.9364 - val_loss: 0.3149 - val_dice_coef: 0.6851 - val_iou: 0.5437 - val_recall: 0.6421 - val_precision: 0.8692 - val_auc: 0.8712 - lr: 1.0000e-06
# Epoch 31/50
# 224/225 [============================>.] - ETA: 0s - loss: 0.1775 - dice_coef: 0.8225 - iou: 0.7058 - recall: 0.8325 - precision: 0.8592 - auc: 0.9364
# Epoch 31: val_loss did not improve from 0.31148
# 225/225 [==============================] - 7s 32ms/step - loss: 0.1773 - dice_coef: 0.8227 - iou: 0.7060 - recall: 0.8325 - precision: 0.8592 - auc: 0.9364 - val_loss: 0.3153 - val_dice_coef: 0.6847 - val_iou: 0.5432 - val_recall: 0.6413 - val_precision: 0.8693 - val_auc: 0.8709 - lr: 1.0000e-06
# Epoch 32/50
# 225/225 [==============================] - ETA: 0s - loss: 0.1768 - dice_coef: 0.8232 - iou: 0.7067 - recall: 0.8330 - precision: 0.8596 - auc: 0.9365
# Epoch 32: val_loss did not improve from 0.31148
# 225/225 [==============================] - 7s 33ms/step - loss: 0.1768 - dice_coef: 0.8232 - iou: 0.7067 - recall: 0.8330 - precision: 0.8596 - auc: 0.9365 - val_loss: 0.3153 - val_dice_coef: 0.6847 - val_iou: 0.5431 - val_recall: 0.6412 - val_precision: 0.8694 - val_auc: 0.8707 - lr: 1.0000e-06

# %% [markdown]
# ### Evaluating the Model:

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import pandas as pd
import cv2
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import accuracy_score, f1_score, jaccard_score, precision_score, recall_score
from tensorflow.keras.models import load_model

# %%
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.float32)
    return ori_x, x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.int32)
    return ori_x, x

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.png")))
    y = sorted(glob(os.path.join(path, "mask", "*.png")))
    return x, y

def save_results(ori_x, ori_y, y_pred, save_image_path):
    line = np.ones((H, 10, 3)) * 255

    ori_y = np.expand_dims(ori_y, axis=-1)
    ori_y = np.concatenate([ori_y, ori_y, ori_y], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1) * 255

    cat_images = np.concatenate([ori_x, line, ori_y, line, y_pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)

# %%
import glob
supported_extensions = ["png", "jpg", "tif", "jpeg", "gif", "bmp"]

def image_files(path, file_prefix=None):
    all_image_files = []
    # print("path", path)
    # print("file_prefix", file_prefix)
    if file_prefix is None:
        file_names = list(glob.glob(path + "/*.*" ))
    else:
        prefix___ = path + "/" + file_prefix + ".*"
        #print("prefix", prefix___)
        file_names = list(glob.glob(prefix___))

    # print("filenames", file_names)

    for filename in file_names:
        ext = filename.rsplit(".", 1)[1]
        if ext.lower() in supported_extensions:
            all_image_files.append(filename)
    # print("All Image files", all_image_files)
    return sorted(all_image_files)

# %%
results_path = f"{root_path}/results/"
prediction_path = f"{root_path}/predictions/"
prediction_np_path = f"{root_path}/predictions_np/"
create_dir(prediction_path)
create_dir(prediction_np_path)
create_dir(results_path)

# %%
results_path
# Out:
# '/content/datasets/drive_64_64_dice_bce_0_4__0_4_1//results/'

# %%
from glob import glob

# %%
from copy import deepcopy
from sklearn.metrics import roc_auc_score
# prediction_path = "predictions"

""" Save the results in this folder """
# create_dir("results_sunil_test")
# create_dir(prediction_path)

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model_path = os.path.join(f"{model_dir}", "model.h5")

model = load_model(model_path, compile=False)

""" Load the dataset """
dataset_path = os.path.join(f"{data_path}/{split_name}", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)
    y = y.astype(np.int)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    np.save(f"{prediction_np_path}/{name}.npy", y_pred)
    y_prob = deepcopy(y_pred).flatten()
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"{results_path}/{name}.png"
#    print(ori_x.shape, ori_y.shape, y_pred.shape)
    save_results(ori_x, ori_y, y_pred, save_image_path)
    cv2.imwrite(f"{prediction_path}/{name}.png", y_pred * 255)
    

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    if np.sum(y) == 0 or np.sum(y) == H * W:
        auc_value = 1
    else:
        auc_value = roc_auc_score(y, y_prob)
    dice_value = dice_coef(y.astype(np.float64), y_prob)

    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value, auc_value, dice_value])

score = [s[1:] for s in SCORE]
score = np.mean(score, axis=0)
print(f"Accuracy: {score[0]:0.5f}")
print(f"F1: {score[1]:0.5f}")
print(f"Jaccard: {score[2]:0.5f}")
print(f"Recall: {score[3]:0.5f}")
print(f"Precision: {score[4]:0.5f}")
print(f"AUC: {score[5]:0.5f}")
print(f"Dice Coeff: {score[6]:0.5f}")
""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision", "AUC", "Dice Coeff"])
df.to_csv(f"{results_path}/score.csv")
# Out:
# Streaming output truncated to the last 5000 lines.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  32%|███▏      | 581/1800 [00:36<01:16, 15.92it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  32%|███▏      | 583/1800 [00:36<01:17, 15.61it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  32%|███▎      | 585/1800 [00:36<01:18, 15.58it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  33%|███▎      | 587/1800 [00:36<01:16, 15.78it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  33%|███▎      | 589/1800 [00:36<01:16, 15.90it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  33%|███▎      | 591/1800 [00:37<01:14, 16.19it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  33%|███▎      | 593/1800 [00:37<01:16, 15.87it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  33%|███▎      | 595/1800 [00:37<01:14, 16.15it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  33%|███▎      | 597/1800 [00:37<01:13, 16.29it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  33%|███▎      | 599/1800 [00:37<01:14, 16.20it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  33%|███▎      | 601/1800 [00:37<01:14, 16.10it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  34%|███▎      | 603/1800 [00:37<01:15, 15.88it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  34%|███▎      | 605/1800 [00:37<01:14, 15.94it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  34%|███▎      | 607/1800 [00:38<01:14, 16.07it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  34%|███▍      | 609/1800 [00:38<01:13, 16.13it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  34%|███▍      | 611/1800 [00:38<01:12, 16.35it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  34%|███▍      | 613/1800 [00:38<01:13, 16.17it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  34%|███▍      | 615/1800 [00:38<01:12, 16.26it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  34%|███▍      | 617/1800 [00:38<01:13, 16.04it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  34%|███▍      | 619/1800 [00:38<01:12, 16.25it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  34%|███▍      | 621/1800 [00:38<01:12, 16.27it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  35%|███▍      | 623/1800 [00:39<01:11, 16.55it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  35%|███▍      | 625/1800 [00:39<01:10, 16.61it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  35%|███▍      | 627/1800 [00:39<01:10, 16.57it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  35%|███▍      | 629/1800 [00:39<01:10, 16.71it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# ...
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 100%|█████████▉| 1791/1800 [01:52<00:00, 16.11it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 100%|█████████▉| 1793/1800 [01:52<00:00, 16.10it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 100%|█████████▉| 1795/1800 [01:53<00:00, 15.95it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 100%|█████████▉| 1797/1800 [01:53<00:00, 16.11it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 100%|█████████▉| 1799/1800 [01:53<00:00, 16.13it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 100%|██████████| 1800/1800 [01:53<00:00, 15.87it/s]
# Accuracy: 0.96461
# F1: 0.43662
# Jaccard: 0.34786
# Recall: 0.39275
# Precision: 0.56160
# AUC: 0.89693
# Dice Coeff: 0.43504

# %% [markdown]
# # Reconstruct original image

# %%
prediction_np_path
# Out:
# '/content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/'

# %%
from glob import glob

# %%
# Create patches dictionary
predicted_patches_dict = dict()
for file in glob(f"{prediction_np_path}/*.npy"):
    print("file", file)
    patch = np.load(file)
    fname_without_ext = file.rsplit("/", 1)[1].rsplit(".", 1)[0]
    fname_without_ext = fname_without_ext[1:]
    patch_number = int(fname_without_ext.rsplit("_", 1)[1])
    image_file = fname_without_ext.rsplit("_", 1)[0]
    print(image_file, patch_number )

    if image_file in predicted_patches_dict.keys():
        predicted_patches_dict[image_file][patch_number] = np.load(file)
    else:
        patches = [None] * 140
        patches[patch_number] = np.load(file)
        predicted_patches_dict[image_file] = patches
# Out:
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_17_test_45.npy
# 17_test 45
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_16_test_11.npy
# 16_test 11
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_20_test_7.npy
# 20_test 7
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_06_test_15.npy
# 06_test 15
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_03_test_82.npy
# 03_test 82
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_05_test_66.npy
# 05_test 66
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_12_test_22.npy
# 12_test 22
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_19_test_60.npy
# 19_test 60
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_12_test_33.npy
# 12_test 33
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_12_test_71.npy
# 12_test 71
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_15_test_13.npy
# 15_test 13
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_14_test_67.npy
# 14_test 67
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_20_test_27.npy
# 20_test 27
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_17_test_8.npy
# 17_test 8
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_12_test_73.npy
# 12_test 73
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_14_test_27.npy
# 14_test 27
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_12_test_52.npy
# 12_test 52
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_12_test_63.npy
# 12_test 63
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_20_test_82.npy
# 20_test 82
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_03_test_87.npy
# 03_test 87
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_15_test_50.npy
# 15_test 50
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_02_test_52.npy
# 02_test 52
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_17_test_22.npy
# 17_test 22
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_20_test_68.npy
# 20_test 68
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_05_test_21.npy
# 05_test 21
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_04_test_14.npy
# 04_test 14
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_03_test_5.npy
# 03_test 5
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_20_test_47.npy
# 20_test 47
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_20_test_18.npy
# 20_test 18
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_20_test_48.npy
# 20_test 48
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_12_test_17.npy
# 12_test 17
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_06_test_89.npy
# 06_test 89
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_02_test_79.npy
# 02_test 79
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_20_test_25.npy
# 20_test 25
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_15_test_79.npy
# 15_test 79
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_04_test_59.npy
# 04_test 59
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_03_test_48.npy
# 03_test 48
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_03_test_0.npy
# 03_test 0
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_10_test_51.npy
# 10_test 51
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_01_test_24.npy
# 01_test 24
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_17_test_68.npy
# 17_test 68
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_15_test_37.npy
# 15_test 37
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_06_test_60.npy
# 06_test 60
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_01_test_46.npy
# 01_test 46
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_20_test_81.npy
# 20_test 81
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_10_test_32.npy
# 10_test 32
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_09_test_22.npy
# 09_test 22
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_17_test_87.npy
# 17_test 87
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_01_test_41.npy
# 01_test 41
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_19_test_33.npy
# 19_test 33
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_08_test_74.npy
# 08_test 74
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_08_test_54.npy
# 08_test 54
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_15_test_8.npy
# 15_test 8
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_06_test_46.npy
# 06_test 46
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_09_test_47.npy
# 09_test 47
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_13_test_7.npy
# 13_test 7
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_10_test_76.npy
# 10_test 76
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_04_test_29.npy
# 04_test 29
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_19_test_27.npy
# 19_test 27
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_03_test_72.npy
# 03_test 72
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_19_test_28.npy
# 19_test 28
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_20_test_6.npy
# 20_test 6
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_11_test_4.npy
# 11_test 4
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_01_test_84.npy
# 01_test 84
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_14_test_10.npy
# 14_test 10
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_09_test_7.npy
# 09_test 7
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_13_test_53.npy
# 13_test 53
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_20_test_66.npy
# 20_test 66
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_04_test_81.npy
# 04_test 81
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_17_test_40.npy
# 17_test 40
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_19_test_0.npy
# 19_test 0
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_05_test_47.npy
# 05_test 47
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_14_test_26.npy
# 14_test 26
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_17_test_30.npy
# 17_test 30
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_08_test_47.npy
# 08_test 47
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_02_test_85.npy
# 02_test 85
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_10_test_33.npy
# 10_test 33
# file /content/datasets/drive_64_64_dice_bce_0_4__0_4_1//predictions_np/_18_test_40.npy
# 18_test 40

# %%
reconstructed_predictions_path = f"{data_path}/{split_name}/reconstructed/{split}/predictions_reconstructed"
create_dir(reconstructed_predictions_path)
reconstruct_patches(predicted_patches_dict,
                    metadata_test_df,
                    reconstructed_predictions_path,
                    mfactor=255
                    )

# %%
# !pwd
# Out:
# /content/datasets

# %%
def read_mask(path):
    print(path)
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
#    x = x.astype(np.int32)
    return ori_x, x

# %%
def save_results(ori_x, ori_y, y_pred, save_image_path):
    line = np.ones((ori_x.shape[0], 10, 3)) * 255

    ori_y = np.expand_dims(ori_y, axis=-1)
    ori_y = np.concatenate([ori_y, ori_y, ori_y], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1) * 255

    cat_images = np.concatenate([ori_x, line, ori_y, line, y_pred], axis=1)
    print(f"Saving image of size {cat_images.shape} to {save_image_path}")
    cv2.imwrite(save_image_path, cat_images)

# %%
results_path_reconstructed = f"{root_path}/results_reconstructed/"
create_dir(results_path_reconstructed)

# %%
from glob import glob

# %%
dataset_path = f"{root_path}/{split_name}/{split}/"
df_0_4, score_0_4 = compute_metrics(dataset_path,
                    results_path=results_path,
                    threshold=0.4,
                    model=model,
                    predictions_path=prediction_path,
                    prediction_np_path=prediction_np_path)

# %%
dataset_path = f"{root_path}/{split_name}/{split}/"
df_0_5, score_0_5 = compute_metrics(dataset_path,
                    results_path=results_path,
                    threshold=0.5,
                    model=model,
                    predictions_path=prediction_path,
                    prediction_np_path=prediction_np_path)

# %%
dataset_path = f"{root_path}/{split_name}/{split}/"
df_0_6, score_0_6 = compute_metrics(dataset_path,
                    results_path=results_path,
                    threshold=0.6,
                    model=model,
                    predictions_path=prediction_path,
                    prediction_np_path=prediction_np_path)

# %%
results_path_reconstructed

# %%
# !ls

# %%
folder_name = root_path.split("/")[3]
print(folder_name)

# %%
# !zip -r {folder_name}.zip  {folder_name}/

# %%
# !ls -ltrh

# %%
# !ls /content/gdrive/MyDrive/Blood_Vessel_Results/hrf_patches/

# %%
# !cp {folder_name}.zip /content/gdrive/MyDrive/Blood_Vessel_Results/hrf_patches/

# %%
# %cd /content/gdrive/MyDrive/Blood_Vessel_Results/hrf_patches/

# %%
# !pwd

# %%
# !ls

# %%
# !unzip {folder_name}.zip

# %%
drive.flush_and_unmount()
