# %% [markdown]
# ### Import the required libraries and modules:

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
import numpy as np

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# %cd /content/gdrive/MyDrive/medical_image_processing/
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/medical_image_processing

# %%
from fundal_image.utils import create_dir, get_filenames_sorted
from patches import generate_patches_images_only, reconstruct_patches
from metrics import iou, dice_coef, dice_loss, DiceBCELoss, bce
from metrics import compute_metrics, save_results
from utils import read_image_train, read_mask_train

# %%
image_sizes = {"HRF": (2336, 3504), "drive": (584, 565), "chase_db": (960, 999)}
patch_size = {"HRF": (768, 768),
              "drive":(128, 128),
              "chase_db":(384, 384)
              }

dataset_name = "chase_db"
patch_size = patch_size[dataset_name]
patch_height = patch_size[0]
patch_width = patch_size[1]

# %%
loss_str = "dice_loss"
with_augmentation = False
stride=384
seed = 42
run_id = 1
test_percentage = 0.4
class_weight = 0.4
class_weight_str = str(class_weight).replace(".", "_")

aug_string = "_hvr"
test_percentage_str = str(test_percentage).replace(".", "_")

root_path = f"/content/datasets/{dataset_name}_{patch_height}_{stride}_{loss_str}_{class_weight_str}_{aug_string}_{test_percentage_str}_{run_id}/"

images_path_train = f"{root_path}/training/images/"
gt_path_train = f"{root_path}/training/1st_manual/"
images_path_test = f"{root_path}/test/images/"
gt_path_test = f"{root_path}/test/1st_manual/"

create_dir(images_path_train)
create_dir(gt_path_train)
create_dir(images_path_test)
create_dir(gt_path_test)

# %%
def wbce(actual, predicted):
    y_pred = K.clip(predicted, K.epsilon(), 1 - K.epsilon())
    term_0 = (1 - actual) * K.log(1 - y_pred)
    term_1 = class_weight * actual * K.log(y_pred + K.epsilon())
    return -K.mean(term_0 + term_1, axis=0)

# %%
root_path
# Out:
# '/content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1/'

# %%
images_path_train
# Out:
# '/content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//training/images/'

# %%
# !cp /content/gdrive/MyDrive/medical_image_processing/fundal_image/datasets/chase_db/split_1/training/images/*.* {images_path_train}
# !cp /content/gdrive/MyDrive/medical_image_processing/fundal_image/datasets/chase_db/split_1//training/groundtruth1/*.* {gt_path_train}

# %%
# !cp /content/gdrive/MyDrive/medical_image_processing/fundal_image/datasets/chase_db/split_1/test/images/*.* {images_path_test}
# !cp /content/gdrive/MyDrive/medical_image_processing/fundal_image/datasets/chase_db/split_1/test/groundtruth1/*.* {gt_path_test}

# %%
# !ls /content/gdrive/MyDrive/medical_image_processing/fundal_image/datasets//chase_db/split_1/training/images
# Out:
# Image_01L.jpg  Image_03R.jpg  Image_06L.jpg  Image_08R.jpg  Image_13R.jpg
# Image_01R.jpg  Image_04L.jpg  Image_06R.jpg  Image_09L.jpg  Image_14L.jpg
# Image_02L.jpg  Image_04R.jpg  Image_07L.jpg  Image_09R.jpg  Image_14R.jpg
# Image_02R.jpg  Image_05L.jpg  Image_07R.jpg  Image_10L.jpg
# Image_03L.jpg  Image_05R.jpg  Image_08L.jpg  Image_10R.jpg

# %%
# images_files, gt_files = get_filenames_sorted(images_path, gt_path)
# print(len(images_files), len(gt_files))
# # train_test_split
# from sklearn.model_selection import train_test_split
# label = [_xtrain.rsplit("/", 1)[1].rsplit(".", 1)[0].rsplit("_", 1)[1] for _xtrain in images_files] 
# xtrain, xtest, ytrain, ytest = train_test_split(images_files, gt_files, stratify=label,  test_size=test_percentage, random_state=seed)

# %%
xtrain, ytrain = get_filenames_sorted(images_path_train, gt_path_train)
xtest, ytest = get_filenames_sorted(images_path_test, gt_path_test)

# %%
print(len(xtrain), len(xtest))
# print(label)
# Out:
# 23 5

# %%
xtrain[:5]
# Out:
# ['/content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//training/images/Image_01L.jpg',
#  '/content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//training/images/Image_01R.jpg',
#  '/content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//training/images/Image_02L.jpg',
#  '/content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//training/images/Image_02R.jpg',
#  '/content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//training/images/Image_03L.jpg']

# %%
print(len(ytrain), len(ytest))
ytrain[:5]
# Out:
# 23 5
# ['/content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//training/1st_manual/Image_01L_1stHO.png',
#  '/content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//training/1st_manual/Image_01R_1stHO.png',
#  '/content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//training/1st_manual/Image_02L_1stHO.png',
#  '/content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//training/1st_manual/Image_02R_1stHO.png',
#  '/content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//training/1st_manual/Image_03L_1stHO.png']

# %%
from tqdm import tqdm
import pandas as pd

# %%
from albumentations import HorizontalFlip, VerticalFlip, Rotate
import imageio

def augment_data(images, masks, save_path, augment=True):
    H = 960
    W = 999

    for idx, (x, y) in tqdm(enumerate(zip(images, masks)), total=len(images)):
        """ Extracting names """
        name = x.rsplit("/", 1)[1].rsplit(".", 1)[0]
        print(name)
        """ Reading image and mask """
        x = cv2.imread(x, cv2.IMREAD_COLOR)
        y = cv2.imread(y, cv2.IMREAD_GRAYSCALE)
        # y = imageio.mimread(y)[0]

        if augment == True:
            aug = HorizontalFlip(p=1.0)
            augmented = aug(image=x, mask=y)
            x1 = augmented["image"]
            y1 = augmented["mask"]

            aug = VerticalFlip(p=1.0)
            augmented = aug(image=x, mask=y)
            x2 = augmented["image"]
            y2 = augmented["mask"]

            aug = Rotate(limit=45, p=1.0)
            augmented = aug(image=x, mask=y)
            x3 = augmented["image"]
            y3 = augmented["mask"]

            X = [x, x1, x2, x3]
            Y = [y, y1, y2, y3]

            X = [x, x1, x2, x3]
            Y = [y, y1, y2, y3]

        else:
            X = [x]
            Y = [y]

        index = 0
        for i, m in zip(X, Y):
            i = cv2.resize(i, (W, H))
            m = cv2.resize(m, (W, H))

            if len(X) == 1:
                tmp_image_name = f"{name}.png"
                tmp_mask_name = f"{name}.png"
            else:
                tmp_image_name = f"{name}_{index}.png"
                tmp_mask_name = f"{name}_{index}.png"

            image_path = os.path.join(save_path, "image", tmp_image_name)
            mask_path = os.path.join(save_path, "mask", tmp_mask_name)

            cv2.imwrite(image_path, i)
            cv2.imwrite(mask_path, m)

            index += 1

# %%
create_dir(f"{root_path}/augmented/train/image/")
create_dir(f"{root_path}/augmented/train/mask/")

# %%
augment_data(xtrain, ytrain, f"{root_path}/augmented/train/", True )
# Out:
#   0%|          | 0/23 [00:00<?, ?it/s]
# Image_01L
#   9%|▊         | 2/23 [00:00<00:04,  4.94it/s]
# Image_01R
# Image_02L
#  13%|█▎        | 3/23 [00:00<00:03,  5.16it/s]

# %%
xtrain, ytrain = get_filenames_sorted(f"{root_path}/augmented/train/image", f"{root_path}/augmented/train/mask")

# %%
print(len(xtrain), len(ytrain))

# %%
from sklearn.feature_extraction import image
import numpy as np
from PIL import Image
from tqdm import tqdm
import pandas as pd
import cv2

from fundal_image.utils import  create_dir
from utils import get_filenames_sorted

def generate_patches_images_only(image_files,
                                 save_path_image,
                                 max_patch=30,
                                 dataset_name="",
                                 patch_size=(512, 512),
                                 stride=None,
                                 padding="zeros",
                                 exclude_boundary=True,
                                 zero_padding_size=(0, 0),
                                 gt_files=None,
                                 save_path_gt=None
                                 ):
    
    def patches_with_stride(image_filename, im, _patch_size, _stride, gt_name=None, gt=None):
        patches = []
        gt_patches = []
        # print("Image size", im.shape)
        metadata_list = []
        columns = ["image_filename", "row", "col", "patch_height", "patch_width", "stride", "num_fg_pixels"]
        if padding == "zeros":
            num_zero_padding_height = im.shape[0] % patch_size[0]
            num_zero_padding_width = im.shape[1] % patch_size[1]

            if num_zero_padding_height > 0:
                num_zero_padding_height = _patch_size[0] - num_zero_padding_height

            if num_zero_padding_width > 0:
                num_zero_padding_width = _patch_size[1] - num_zero_padding_width

            height_odd = 0 if (num_zero_padding_height % 2) == 0 else 1
            width_odd = 0 if (num_zero_padding_width % 2) == 0 else 1
        else:
            raise Exception(f"Value for argument padding is not mentioned")

        # print(f"Image shape {im.shape}. Patch size {_patch_size}.  Num Zero padding rows {num_zero_padding_height}. Num zero padding cols {num_zero_padding_width}")
        im = np.pad(im, ((num_zero_padding_height // 2, num_zero_padding_height // 2 + height_odd),
                                (num_zero_padding_width // 2, num_zero_padding_width // 2 + width_odd),
                                (0, 0)
                                )
                           )
        if gt is not None:
            if len(gt.shape) == 3:
                gt = np.pad(gt, ((num_zero_padding_height // 2, num_zero_padding_height // 2 + height_odd),
                                 (num_zero_padding_width // 2, num_zero_padding_width // 2 + width_odd),
                                 (0, 0)
                                 )
                            )
            else:
                gt = np.pad(gt, ((num_zero_padding_height // 2, num_zero_padding_height // 2 + height_odd),
                                 (num_zero_padding_width // 2, num_zero_padding_width // 2 + width_odd)
                                 )
                            )

        im_gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
        # print(f"image shape after padding {im.shape}")
        for row in range(0, im.shape[0], _stride):
            for col in range(0, im.shape[1], _stride):
                if row + _patch_size[0] >= im.shape[0]:
                    row = im.shape[0] - _patch_size[0]
                if col + _patch_size[1] >= im.shape[1]:
                    col = im.shape[1] - _patch_size[1]
                image_patch = im[row:row + _patch_size[0], col:col + _patch_size[1]]
                num_fg_pixels = np.sum(im_gray[row:row + _patch_size[0], col:col + _patch_size[1]] > 0)
                if gt is not None:
                    gt_patch = gt[row:row + _patch_size[0], col:col + _patch_size[1]]
                if num_fg_pixels > 0:
                    patches.append(image_patch)
                    metadata_list.append([image_filename, row, col, _patch_size[0], _patch_size[1], _stride, num_fg_pixels])
                    if gt is not None:
                        gt_patches.append(gt_patch)


        metadata_df = pd.DataFrame(metadata_list, columns=columns )
        patches_np = np.asarray(patches)
        if gt is not None:
            gt_patches_np = np.asarray(gt_patches)
        else:
            gt_patches_np = None

        return patches_np, metadata_df, gt_patches_np

    num_images = len(image_files)
    print(f"Generating patches for {num_images} images")
    metadata_df = None
    create_dir(save_path_image)
    im_patches_dict = dict()
    gt_patches_dict = dict()
    for idx, image_filename in tqdm(enumerate(image_files), total=len(image_files)):
        image_filename = image_filename.replace("\\", "/")
        # print("Image file", image_filename)
        name = image_filename.rsplit("/", 1)[1].rsplit(".", 1)[0]
        # image1 = Image.open(x)
        # image_array = np.asarray(image1)
        image_array = cv2.imread(image_filename)

        if gt_files is not None and len(gt_files) > 0:
            gt_filename = gt_files[idx]
            gt_filename = gt_filename.replace("\\", "/")
            # print("Image file", image_filename)
            gt_name = gt_filename.rsplit("/", 1)[1].rsplit(".", 1)[0]


            gt = cv2.imread(gt_filename)
            # gt = np.asarray(Image.open(gt_filename))
            # print(gt.dtype)
            if len(gt.shape) == 3:
                gt = cv2.cvtColor(gt, cv2.COLOR_BGR2GRAY)

        if not exclude_boundary:
            # add zero padding
            image_array = np.pad(image_array, zero_padding_size)
            gt = np.pad(gt, zero_padding_size)

        if stride is None:
            image_patches = image.extract_patches_2d(image_array, patch_size, max_patches=max_patch, random_state=42)
        else:
            ret_value = patches_with_stride(image_filename, image_array, patch_size, stride, gt_name, gt)
            if ret_value is None :
                raise Exception(f"Could not create patches for {image_filename}")
            else:
                image_patches, _metadata_df, gt_patches = ret_value[0], ret_value[1], ret_value[2]
            if metadata_df is not None:
                metadata_df = metadata_df.append(_metadata_df)
            else:
                metadata_df = _metadata_df
        im_patches_dict[name] = image_patches
        gt_patches_dict[name] = gt_patches

        # print(gt_patches.dtype)


        if save_path_image is not None and len(save_path_image) > 0:
            count = 0
            for i in range(len(image_patches)):
                # data = Image.fromarray(image_patches[i])
                # print(save_path_image, dataset_name, name)
                image_path_file = f"{save_path_image}/{dataset_name}_{name}_{count}.png"
                # print(f"Saving patches to {image_path_file}")
                cv2.imwrite(image_path_file, image_patches[i])

                if gt_patches is not None and save_path_gt is not None:
                    gt_path_file = f"{save_path_gt}/{dataset_name}_{name}_{count}.png"
                    # print(gt_path_file)
                    # print(type(gt_patches))
                    # print(gt_patches[i].shape)
                    # print(gt_patches[i].dtype)
                    # print(np.min(gt_patches[i]), np.max(gt_patches[i]))
                    cv2.imwrite(gt_path_file, gt_patches[i])
                count += 1

    return im_patches_dict, metadata_df, gt_patches_dict

# %%
num_pixels_to_add = [0, 0]
if (image_sizes[dataset_name][0] % patch_size[0]) > 0:
    num_pixels_to_add[0] = ((image_sizes["drive"][0] // patch_size[0]) + 1) * patch_size[0]
    num_pixels_to_add[1] = ((image_sizes["drive"][1] // patch_size[1]) + 1) * patch_size[1]

split_name = "split_2"
data_path = root_path
splits =["train","test"]


split = "train"
#for split in splits:
image_patches_path = f"{data_path}/{split_name}/{split}/image/"
create_dir(image_patches_path)
gt_patches_path = f"{data_path}/{split_name}/{split}/mask/"
create_dir(gt_patches_path)
im_patches_dict_train, metadata_train_df, gt_patches_dict_train = generate_patches_images_only(xtrain,
                                                                image_patches_path,
                                                                patch_size=patch_size,
                                                                stride=stride,
                                                                zero_padding_size=num_pixels_to_add,
                                                                gt_files=ytrain,
                                                                save_path_gt=gt_patches_path)
metadata_train_df.to_csv(f"{data_path}/{split_name}/image_patches_{stride}_{stride}_{split}.csv", index=False)

# %%
split = "test"
#for split in splits:
image_patches_path = f"{data_path}/{split_name}/{split}/image/"
create_dir(image_patches_path)
gt_patches_path = f"{data_path}/{split_name}/{split}/mask/"
create_dir(gt_patches_path)
im_patches_dict_test, metadata_test_df, gt_patches_dict_test = generate_patches_images_only(xtest,
                                                                image_patches_path,
                                                                patch_size=patch_size,
                                                                stride=stride,
                                                                zero_padding_size=num_pixels_to_add,
                                                                gt_files=ytest,
                                                                save_path_gt=gt_patches_path)
metadata_test_df.to_csv(f"{data_path}/{split_name}/image_patches_{patch_height}_{stride}_{split}.csv", index=False)

# %%
metadata_test_df.shape

# %%
metadata_train_df.shape

# %%
metadata_train_df.head()

# %%
import glob
split = "test"
image_patches_path = f"{data_path}/{split_name}/{split}/image/"

reconstructed_original_path = f"{data_path}/{split_name}/reconstructed/{split}/image"
create_dir(reconstructed_original_path)
reconstruct_patches(im_patches_dict_test,
                    metadata_test_df,
                    reconstructed_original_path
                    )

# %%
print(list(gt_patches_dict_test.keys()))

# %%
type(gt_patches_dict_test["Image_11L"])

# %%
reconstructed_gt_path = f"{data_path}/{split_name}/reconstructed/{split}/mask"

create_dir(reconstructed_gt_path)
reconstruct_patches(gt_patches_dict_test,
                    metadata_test_df,
                    reconstructed_gt_path,
                    )

# %%
print([k for k in im_patches_dict_test.keys()])

# %% [markdown]
# ### Construct the Model:

# %%
def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    b1 = conv_block(p4, 1024)

    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="UNET")
    return model

input_shape = (512, 512, 3)
model = build_unet(input_shape)
model.summary()

# %% [markdown]
# ### Adding the Metrics:

# %%
def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def DiceBCELoss(y_true, y_pred):
    
    inputs = tf.keras.layers.Flatten()(y_true)
    targets = tf.keras.layers.Flatten()(y_pred)

    intersection = tf.reduce_sum(inputs * targets)
    dice_loss = 1 - (2.*intersection + smooth)/(tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)
    BCE = tf.keras.losses.BinaryCrossentropy()
    Dice_BCE = BCE(inputs, targets) + dice_loss

    return Dice_BCE

def bce(y_true, y_pred):
    
    inputs = tf.keras.layers.Flatten()(y_true)
    targets = tf.keras.layers.Flatten()(y_pred)
    BCE = tf.keras.losses.BinaryCrossentropy()
    Dice_BCE = BCE(inputs, targets)

    return Dice_BCE

# %% [markdown]
# ### Training the Model:

# %%
if loss_str == "bce":
    loss = bce
elif loss_str == "dice_bce":
    loss = DiceBCELoss
elif loss_str == "dice_loss":
    loss = dice_loss
elif loss_str == "wbce":
    loss = wbce
else:
    raise Exception("Invalid value for loss_str")
    
print(loss)

# %%
H = patch_height
W = patch_width

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.png")))
    y = sorted(glob(os.path.join(path, "mask", "*.png")))
    return x, y

def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)
    return x, y

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)              ## (512, 512, 1)
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y, batch_size=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(4)
    return dataset

# %%
from keras.metrics import AUC

# %%
model_dir = f"{root_path}/trained_models/"

# %%
create_dir(model_dir)

# %%
# !ls {model_dir}

# %%
# %cd /content/datasets

# %%
from glob import glob

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir(model_dir)

""" Hyperparameters """
batch_size = 8
lr = 1e-4
num_epochs = 50
model_path = os.path.join(f"{model_dir}", "model.h5")
csv_path = os.path.join(f"{model_dir}", "data.csv")

""" Dataset """
dataset_path = f"{data_path}/{split_name}"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
# train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model = build_unet((H, W, 3))
model.compile(loss=loss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision(), AUC()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 828 - 828
# Valid: 45 - 45
# Epoch 1/50
# 104/104 [==============================] - ETA: 0s - loss: 0.6352 - dice_coef: 0.3650 - iou: 0.2275 - recall: 0.8521 - precision: 0.2793 - auc: 0.9438
# Epoch 1: val_loss improved from inf to 0.92735, saving model to /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//trained_models/model.h5
# 104/104 [==============================] - 74s 564ms/step - loss: 0.6352 - dice_coef: 0.3650 - iou: 0.2275 - recall: 0.8521 - precision: 0.2793 - auc: 0.9438 - val_loss: 0.9273 - val_dice_coef: 0.0734 - val_iou: 0.0381 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_auc: 0.2485 - lr: 1.0000e-04
# Epoch 2/50
# 104/104 [==============================] - ETA: 0s - loss: 0.4732 - dice_coef: 0.5265 - iou: 0.3586 - recall: 0.8397 - precision: 0.6509 - auc: 0.9723
# Epoch 2: val_loss did not improve from 0.92735
# 104/104 [==============================] - 54s 520ms/step - loss: 0.4732 - dice_coef: 0.5265 - iou: 0.3586 - recall: 0.8397 - precision: 0.6509 - auc: 0.9723 - val_loss: 0.9534 - val_dice_coef: 0.0470 - val_iou: 0.0241 - val_recall: 2.0947e-04 - val_precision: 0.0115 - val_auc: 0.2509 - lr: 1.0000e-04
# Epoch 3/50
# 104/104 [==============================] - ETA: 0s - loss: 0.4076 - dice_coef: 0.5921 - iou: 0.4218 - recall: 0.8539 - precision: 0.7109 - auc: 0.9770
# Epoch 3: val_loss did not improve from 0.92735
# 104/104 [==============================] - 54s 521ms/step - loss: 0.4076 - dice_coef: 0.5921 - iou: 0.4218 - recall: 0.8539 - precision: 0.7109 - auc: 0.9770 - val_loss: 0.9296 - val_dice_coef: 0.0701 - val_iou: 0.0363 - val_recall: 0.0294 - val_precision: 0.1163 - val_auc: 0.6073 - lr: 1.0000e-04
# Epoch 4/50
# 104/104 [==============================] - ETA: 0s - loss: 0.3597 - dice_coef: 0.6400 - iou: 0.4719 - recall: 0.8535 - precision: 0.7460 - auc: 0.9776
# Epoch 4: val_loss improved from 0.92735 to 0.60352, saving model to /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//trained_models/model.h5
# 104/104 [==============================] - 55s 531ms/step - loss: 0.3597 - dice_coef: 0.6400 - iou: 0.4719 - recall: 0.8535 - precision: 0.7460 - auc: 0.9776 - val_loss: 0.6035 - val_dice_coef: 0.3898 - val_iou: 0.2443 - val_recall: 0.3674 - val_precision: 0.8911 - val_auc: 0.8954 - lr: 1.0000e-04
# Epoch 5/50
# 104/104 [==============================] - ETA: 0s - loss: 0.3199 - dice_coef: 0.6798 - iou: 0.5162 - recall: 0.8569 - precision: 0.7694 - auc: 0.9792
# Epoch 5: val_loss improved from 0.60352 to 0.42128, saving model to /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//trained_models/model.h5
# 104/104 [==============================] - 55s 531ms/step - loss: 0.3199 - dice_coef: 0.6798 - iou: 0.5162 - recall: 0.8569 - precision: 0.7694 - auc: 0.9792 - val_loss: 0.4213 - val_dice_coef: 0.5750 - val_iou: 0.4051 - val_recall: 0.6366 - val_precision: 0.8173 - val_auc: 0.9358 - lr: 1.0000e-04
# Epoch 6/50
# 104/104 [==============================] - ETA: 0s - loss: 0.2901 - dice_coef: 0.7096 - iou: 0.5511 - recall: 0.8556 - precision: 0.7850 - auc: 0.9785
# Epoch 6: val_loss improved from 0.42128 to 0.33608, saving model to /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//trained_models/model.h5
# 104/104 [==============================] - 55s 531ms/step - loss: 0.2901 - dice_coef: 0.7096 - iou: 0.5511 - recall: 0.8556 - precision: 0.7850 - auc: 0.9785 - val_loss: 0.3361 - val_dice_coef: 0.6619 - val_iou: 0.4954 - val_recall: 0.7411 - val_precision: 0.7893 - val_auc: 0.9564 - lr: 1.0000e-04
# Epoch 7/50
# 104/104 [==============================] - ETA: 0s - loss: 0.2643 - dice_coef: 0.7354 - iou: 0.5827 - recall: 0.8564 - precision: 0.7978 - auc: 0.9784
# Epoch 7: val_loss improved from 0.33608 to 0.33486, saving model to /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//trained_models/model.h5
# 104/104 [==============================] - 55s 531ms/step - loss: 0.2643 - dice_coef: 0.7354 - iou: 0.5827 - recall: 0.8564 - precision: 0.7978 - auc: 0.9784 - val_loss: 0.3349 - val_dice_coef: 0.6643 - val_iou: 0.4981 - val_recall: 0.7657 - val_precision: 0.7496 - val_auc: 0.9529 - lr: 1.0000e-04
# Epoch 8/50
# 104/104 [==============================] - ETA: 0s - loss: 0.2449 - dice_coef: 0.7550 - iou: 0.6074 - recall: 0.8548 - precision: 0.8080 - auc: 0.9778
# Epoch 8: val_loss did not improve from 0.33486
# 104/104 [==============================] - 54s 522ms/step - loss: 0.2449 - dice_coef: 0.7550 - iou: 0.6074 - recall: 0.8548 - precision: 0.8080 - auc: 0.9778 - val_loss: 0.3526 - val_dice_coef: 0.6472 - val_iou: 0.4787 - val_recall: 0.8095 - val_precision: 0.6373 - val_auc: 0.9464 - lr: 1.0000e-04
# Epoch 9/50
# 104/104 [==============================] - ETA: 0s - loss: 0.2281 - dice_coef: 0.7718 - iou: 0.6293 - recall: 0.8563 - precision: 0.8160 - auc: 0.9756
# Epoch 9: val_loss improved from 0.33486 to 0.32068, saving model to /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//trained_models/model.h5
# 104/104 [==============================] - 55s 531ms/step - loss: 0.2281 - dice_coef: 0.7718 - iou: 0.6293 - recall: 0.8563 - precision: 0.8160 - auc: 0.9756 - val_loss: 0.3207 - val_dice_coef: 0.6785 - val_iou: 0.5141 - val_recall: 0.7747 - val_precision: 0.6817 - val_auc: 0.9522 - lr: 1.0000e-04
# Epoch 10/50
# 104/104 [==============================] - ETA: 0s - loss: 0.2151 - dice_coef: 0.7848 - iou: 0.6467 - recall: 0.8570 - precision: 0.8220 - auc: 0.9730
# Epoch 10: val_loss did not improve from 0.32068
# 104/104 [==============================] - 54s 522ms/step - loss: 0.2151 - dice_coef: 0.7848 - iou: 0.6467 - recall: 0.8570 - precision: 0.8220 - auc: 0.9730 - val_loss: 0.3323 - val_dice_coef: 0.6676 - val_iou: 0.5027 - val_recall: 0.7538 - val_precision: 0.6780 - val_auc: 0.9149 - lr: 1.0000e-04
# Epoch 11/50
# 104/104 [==============================] - ETA: 0s - loss: 0.2044 - dice_coef: 0.7955 - iou: 0.6613 - recall: 0.8581 - precision: 0.8267 - auc: 0.9753
# Epoch 11: val_loss improved from 0.32068 to 0.28697, saving model to /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//trained_models/model.h5
# 104/104 [==============================] - 55s 531ms/step - loss: 0.2044 - dice_coef: 0.7955 - iou: 0.6613 - recall: 0.8581 - precision: 0.8267 - auc: 0.9753 - val_loss: 0.2870 - val_dice_coef: 0.7117 - val_iou: 0.5531 - val_recall: 0.8114 - val_precision: 0.7033 - val_auc: 0.9400 - lr: 1.0000e-04
# Epoch 12/50
# 104/104 [==============================] - ETA: 0s - loss: 0.1940 - dice_coef: 0.8060 - iou: 0.6757 - recall: 0.8605 - precision: 0.8324 - auc: 0.9758
# Epoch 12: val_loss improved from 0.28697 to 0.27154, saving model to /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//trained_models/model.h5
# 104/104 [==============================] - 55s 531ms/step - loss: 0.1940 - dice_coef: 0.8060 - iou: 0.6757 - recall: 0.8605 - precision: 0.8324 - auc: 0.9758 - val_loss: 0.2715 - val_dice_coef: 0.7258 - val_iou: 0.5701 - val_recall: 0.7349 - val_precision: 0.7983 - val_auc: 0.9319 - lr: 1.0000e-04
# Epoch 13/50
# 104/104 [==============================] - ETA: 0s - loss: 0.1858 - dice_coef: 0.8142 - iou: 0.6873 - recall: 0.8612 - precision: 0.8375 - auc: 0.9749
# Epoch 13: val_loss did not improve from 0.27154
# 104/104 [==============================] - 54s 523ms/step - loss: 0.1858 - dice_coef: 0.8142 - iou: 0.6873 - recall: 0.8612 - precision: 0.8375 - auc: 0.9749 - val_loss: 0.2792 - val_dice_coef: 0.7173 - val_iou: 0.5601 - val_recall: 0.7100 - val_precision: 0.8177 - val_auc: 0.9262 - lr: 1.0000e-04
# Epoch 14/50
# 104/104 [==============================] - ETA: 0s - loss: 0.1785 - dice_coef: 0.8215 - iou: 0.6976 - recall: 0.8628 - precision: 0.8420 - auc: 0.9732
# Epoch 14: val_loss improved from 0.27154 to 0.25547, saving model to /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//trained_models/model.h5
# 104/104 [==============================] - 55s 532ms/step - loss: 0.1785 - dice_coef: 0.8215 - iou: 0.6976 - recall: 0.8628 - precision: 0.8420 - auc: 0.9732 - val_loss: 0.2555 - val_dice_coef: 0.7442 - val_iou: 0.5930 - val_recall: 0.8067 - val_precision: 0.7402 - val_auc: 0.9412 - lr: 1.0000e-04
# 104/104 [==============================] - ETA: 0s - loss: 0.1478 - dice_coef: 0.8522 - iou: 0.7429 - recall: 0.8735 - precision: 0.8624 - auc: 0.9650
# Epoch 20: val_loss did not improve from 0.25038
# 104/104 [==============================] - 54s 523ms/step - loss: 0.1478 - dice_coef: 0.8522 - iou: 0.7429 - recall: 0.8735 - precision: 0.8624 - auc: 0.9650 - val_loss: 0.2558 - val_dice_coef: 0.7426 - val_iou: 0.5911 - val_recall: 0.7370 - val_precision: 0.7887 - val_auc: 0.9159 - lr: 1.0000e-04
# Epoch 21/50
# 104/104 [==============================] - ETA: 0s - loss: 0.1449 - dice_coef: 0.8551 - iou: 0.7473 - recall: 0.8744 - precision: 0.8643 - auc: 0.9642
# Epoch 21: val_loss improved from 0.25038 to 0.22863, saving model to /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//trained_models/model.h5
# 104/104 [==============================] - 55s 532ms/step - loss: 0.1449 - dice_coef: 0.8551 - iou: 0.7473 - recall: 0.8744 - precision: 0.8643 - auc: 0.9642 - val_loss: 0.2286 - val_dice_coef: 0.7696 - val_iou: 0.6258 - val_recall: 0.7878 - val_precision: 0.7831 - val_auc: 0.9314 - lr: 1.0000e-04
# Epoch 22/50
# 104/104 [==============================] - ETA: 0s - loss: 0.1379 - dice_coef: 0.8621 - iou: 0.7581 - recall: 0.8785 - precision: 0.8717 - auc: 0.9642
# Epoch 22: val_loss improved from 0.22863 to 0.22171, saving model to /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//trained_models/model.h5
# 104/104 [==============================] - 55s 532ms/step - loss: 0.1379 - dice_coef: 0.8621 - iou: 0.7581 - recall: 0.8785 - precision: 0.8717 - auc: 0.9642 - val_loss: 0.2217 - val_dice_coef: 0.7763 - val_iou: 0.6347 - val_recall: 0.8000 - val_precision: 0.7808 - val_auc: 0.9312 - lr: 1.0000e-04
# Epoch 23/50
# 104/104 [==============================] - ETA: 0s - loss: 0.1352 - dice_coef: 0.8648 - iou: 0.7623 - recall: 0.8807 - precision: 0.8734 - auc: 0.9640
# Epoch 23: val_loss did not improve from 0.22171
# 104/104 [==============================] - 54s 523ms/step - loss: 0.1352 - dice_coef: 0.8648 - iou: 0.7623 - recall: 0.8807 - precision: 0.8734 - auc: 0.9640 - val_loss: 0.2334 - val_dice_coef: 0.7634 - val_iou: 0.6180 - val_recall: 0.7728 - val_precision: 0.7822 - val_auc: 0.9214 - lr: 1.0000e-04
# Epoch 24/50
# 104/104 [==============================] - ETA: 0s - loss: 0.1355 - dice_coef: 0.8646 - iou: 0.7621 - recall: 0.8800 - precision: 0.8726 - auc: 0.9627
# Epoch 24: val_loss did not improve from 0.22171
# 104/104 [==============================] - 54s 523ms/step - loss: 0.1355 - dice_coef: 0.8646 - iou: 0.7621 - recall: 0.8800 - precision: 0.8726 - auc: 0.9627 - val_loss: 0.2307 - val_dice_coef: 0.7677 - val_iou: 0.6232 - val_recall: 0.7945 - val_precision: 0.7627 - val_auc: 0.9273 - lr: 1.0000e-04
# Epoch 25/50
# 104/104 [==============================] - ETA: 0s - loss: 0.1307 - dice_coef: 0.8694 - iou: 0.7694 - recall: 0.8823 - precision: 0.8779 - auc: 0.9628
# Epoch 25: val_loss did not improve from 0.22171
# 104/104 [==============================] - 54s 523ms/step - loss: 0.1307 - dice_coef: 0.8694 - iou: 0.7694 - recall: 0.8823 - precision: 0.8779 - auc: 0.9628 - val_loss: 0.2233 - val_dice_coef: 0.7732 - val_iou: 0.6310 - val_recall: 0.7922 - val_precision: 0.7806 - val_auc: 0.9266 - lr: 1.0000e-04
# Epoch 26/50
# 104/104 [==============================] - ETA: 0s - loss: 0.1243 - dice_coef: 0.8758 - iou: 0.7794 - recall: 0.8870 - precision: 0.8837 - auc: 0.9638
# Epoch 26: val_loss did not improve from 0.22171
# 104/104 [==============================] - 54s 523ms/step - loss: 0.1243 - dice_coef: 0.8758 - iou: 0.7794 - recall: 0.8870 - precision: 0.8837 - auc: 0.9638 - val_loss: 0.2436 - val_dice_coef: 0.7529 - val_iou: 0.6045 - val_recall: 0.7260 - val_precision: 0.8114 - val_auc: 0.8996 - lr: 1.0000e-04
# Epoch 27/50
# 104/104 [==============================] - ETA: 0s - loss: 0.1200 - dice_coef: 0.8801 - iou: 0.7863 - recall: 0.8890 - precision: 0.8889 - auc: 0.9641
# Epoch 27: val_loss did not improve from 0.22171
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 104/104 [==============================] - 54s 523ms/step - loss: 0.1200 - dice_coef: 0.8801 - iou: 0.7863 - recall: 0.8890 - precision: 0.8889 - auc: 0.9641 - val_loss: 0.2380 - val_dice_coef: 0.7583 - val_iou: 0.6115 - val_recall: 0.7409 - val_precision: 0.8027 - val_auc: 0.9013 - lr: 1.0000e-04
# Epoch 28/50
# 104/104 [==============================] - ETA: 0s - loss: 0.1225 - dice_coef: 0.8775 - iou: 0.7821 - recall: 0.8888 - precision: 0.8828 - auc: 0.9627
# Epoch 28: val_loss did not improve from 0.22171
# 104/104 [==============================] - 54s 523ms/step - loss: 0.1225 - dice_coef: 0.8775 - iou: 0.7821 - recall: 0.8888 - precision: 0.8828 - auc: 0.9627 - val_loss: 0.2266 - val_dice_coef: 0.7695 - val_iou: 0.6262 - val_recall: 0.7265 - val_precision: 0.8436 - val_auc: 0.8964 - lr: 1.0000e-05
# Epoch 29/50
# 104/104 [==============================] - ETA: 0s - loss: 0.1149 - dice_coef: 0.8851 - iou: 0.7942 - recall: 0.8913 - precision: 0.8954 - auc: 0.9641
# Epoch 29: val_loss did not improve from 0.22171
# 104/104 [==============================] - 54s 523ms/step - loss: 0.1149 - dice_coef: 0.8851 - iou: 0.7942 - recall: 0.8913 - precision: 0.8954 - auc: 0.9641 - val_loss: 0.2305 - val_dice_coef: 0.7657 - val_iou: 0.6212 - val_recall: 0.7191 - val_precision: 0.8446 - val_auc: 0.8939 - lr: 1.0000e-05
# Epoch 30/50
# 104/104 [==============================] - ETA: 0s - loss: 0.1102 - dice_coef: 0.8898 - iou: 0.8018 - recall: 0.8947 - precision: 0.9011 - auc: 0.9654
# Epoch 30: val_loss did not improve from 0.22171
# 104/104 [==============================] - 54s 523ms/step - loss: 0.1102 - dice_coef: 0.8898 - iou: 0.8018 - recall: 0.8947 - precision: 0.9011 - auc: 0.9654 - val_loss: 0.2303 - val_dice_coef: 0.7661 - val_iou: 0.6217 - val_recall: 0.7230 - val_precision: 0.8396 - val_auc: 0.8956 - lr: 1.0000e-05
# Epoch 31/50
# 104/104 [==============================] - ETA: 0s - loss: 0.1059 - dice_coef: 0.8942 - iou: 0.8089 - recall: 0.8990 - precision: 0.9055 - auc: 0.9668
# Epoch 31: val_loss did not improve from 0.22171
# 104/104 [==============================] - 54s 523ms/step - loss: 0.1059 - dice_coef: 0.8942 - iou: 0.8089 - recall: 0.8990 - precision: 0.9055 - auc: 0.9668 - val_loss: 0.2292 - val_dice_coef: 0.7673 - val_iou: 0.6233 - val_recall: 0.7262 - val_precision: 0.8373 - val_auc: 0.8964 - lr: 1.0000e-05
# Epoch 32/50
# 104/104 [==============================] - ETA: 0s - loss: 0.1023 - dice_coef: 0.8978 - iou: 0.8148 - recall: 0.9026 - precision: 0.9091 - auc: 0.9680
# Epoch 32: val_loss did not improve from 0.22171
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1e-06.
# 104/104 [==============================] - 54s 523ms/step - loss: 0.1023 - dice_coef: 0.8978 - iou: 0.8148 - recall: 0.9026 - precision: 0.9091 - auc: 0.9680 - val_loss: 0.2291 - val_dice_coef: 0.7673 - val_iou: 0.6233 - val_recall: 0.7248 - val_precision: 0.8398 - val_auc: 0.8955 - lr: 1.0000e-05

# %% [markdown]
# ### Evaluating the Model:

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import pandas as pd
import cv2
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import accuracy_score, f1_score, jaccard_score, precision_score, recall_score
from tensorflow.keras.models import load_model

# %%
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.float32)
    return ori_x, x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.int32)
    return ori_x, x

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.png")))
    y = sorted(glob(os.path.join(path, "mask", "*.png")))
    return x, y

def save_results(ori_x, ori_y, y_pred, save_image_path):
    line = np.ones((H, 10, 3)) * 255

    ori_y = np.expand_dims(ori_y, axis=-1)
    ori_y = np.concatenate([ori_y, ori_y, ori_y], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1) * 255

    cat_images = np.concatenate([ori_x, line, ori_y, line, y_pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)

# %%
import glob
supported_extensions = ["png", "jpg", "tif", "jpeg", "gif", "bmp"]

def image_files(path, file_prefix=None):
    all_image_files = []
    # print("path", path)
    # print("file_prefix", file_prefix)
    if file_prefix is None:
        file_names = list(glob.glob(path + "/*.*" ))
    else:
        prefix___ = path + "/" + file_prefix + ".*"
        #print("prefix", prefix___)
        file_names = list(glob.glob(prefix___))

    # print("filenames", file_names)

    for filename in file_names:
        ext = filename.rsplit(".", 1)[1]
        if ext.lower() in supported_extensions:
            all_image_files.append(filename)
    # print("All Image files", all_image_files)
    return sorted(all_image_files)

# %%
results_path = f"{root_path}/results/"
prediction_path = f"{root_path}/predictions/"
prediction_np_path = f"{root_path}/predictions_np/"
create_dir(prediction_path)
create_dir(prediction_np_path)
create_dir(results_path)

# %%
results_path
# Out:
# '/content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//results/'

# %%
from glob import glob

# %%
from copy import deepcopy
from sklearn.metrics import roc_auc_score
# prediction_path = "predictions"

""" Save the results in this folder """
# create_dir("results_sunil_test")
# create_dir(prediction_path)

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model_path = os.path.join(f"{model_dir}", "model.h5")

model = load_model(model_path, compile=False)

""" Load the dataset """
dataset_path = os.path.join(f"{data_path}/{split_name}", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)
    y = y.astype(np.int)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    np.save(f"{prediction_np_path}/{name}.npy", y_pred)
    y_prob = deepcopy(y_pred).flatten()
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"{results_path}/{name}.png"
#    print(ori_x.shape, ori_y.shape, y_pred.shape)
    save_results(ori_x, ori_y, y_pred, save_image_path)
    cv2.imwrite(f"{prediction_path}/{name}.png", y_pred * 255)
    

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    if np.sum(y) == 0 or np.sum(y) == H * W:
        auc_value = 1
    else:
        auc_value = roc_auc_score(y, y_prob)
    dice_value = dice_coef(y.astype(np.float64), y_prob)

    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value, auc_value, dice_value])

score = [s[1:] for s in SCORE]
score = np.mean(score, axis=0)
print(f"Accuracy: {score[0]:0.5f}")
print(f"F1: {score[1]:0.5f}")
print(f"Jaccard: {score[2]:0.5f}")
print(f"Recall: {score[3]:0.5f}")
print(f"Precision: {score[4]:0.5f}")
print(f"AUC: {score[5]:0.5f}")
print(f"Dice Coeff: {score[6]:0.5f}")
""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision", "AUC", "Dice Coeff"])
df.to_csv(f"{results_path}/score.csv")
# Out:
#   0%|          | 0/45 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   2%|▏         | 1/45 [00:01<00:53,  1.22s/it]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   4%|▍         | 2/45 [00:01<00:29,  1.46it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   7%|▋         | 3/45 [00:01<00:21,  1.96it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   9%|▉         | 4/45 [00:02<00:17,  2.31it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  11%|█         | 5/45 [00:02<00:15,  2.56it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  13%|█▎        | 6/45 [00:02<00:14,  2.74it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  16%|█▌        | 7/45 [00:03<00:13,  2.87it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  18%|█▊        | 8/45 [00:03<00:12,  2.97it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  20%|██        | 9/45 [00:03<00:11,  3.04it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  22%|██▏       | 10/45 [00:04<00:11,  3.06it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  24%|██▍       | 11/45 [00:04<00:11,  3.09it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  27%|██▋       | 12/45 [00:04<00:10,  3.14it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  29%|██▉       | 13/45 [00:04<00:10,  3.13it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  31%|███       | 14/45 [00:05<00:09,  3.13it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  33%|███▎      | 15/45 [00:05<00:09,  3.13it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  36%|███▌      | 16/45 [00:05<00:09,  3.15it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  38%|███▊      | 17/45 [00:06<00:08,  3.16it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  40%|████      | 18/45 [00:06<00:08,  3.17it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  42%|████▏     | 19/45 [00:06<00:08,  3.20it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  44%|████▍     | 20/45 [00:07<00:07,  3.22it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  47%|████▋     | 21/45 [00:07<00:07,  3.23it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  49%|████▉     | 22/45 [00:07<00:07,  3.21it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  51%|█████     | 23/45 [00:08<00:06,  3.17it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  53%|█████▎    | 24/45 [00:08<00:06,  3.18it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  56%|█████▌    | 25/45 [00:08<00:06,  3.16it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  58%|█████▊    | 26/45 [00:09<00:06,  3.14it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  60%|██████    | 27/45 [00:09<00:05,  3.17it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  62%|██████▏   | 28/45 [00:09<00:05,  3.16it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  64%|██████▍   | 29/45 [00:10<00:05,  3.13it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  67%|██████▋   | 30/45 [00:10<00:04,  3.16it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  69%|██████▉   | 31/45 [00:10<00:04,  3.16it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  71%|███████   | 32/45 [00:10<00:04,  3.16it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  73%|███████▎  | 33/45 [00:11<00:03,  3.16it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  76%|███████▌  | 34/45 [00:11<00:03,  3.18it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  78%|███████▊  | 35/45 [00:11<00:03,  3.19it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  80%|████████  | 36/45 [00:12<00:02,  3.20it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  82%|████████▏ | 37/45 [00:12<00:02,  3.21it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  84%|████████▍ | 38/45 [00:12<00:02,  3.20it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  87%|████████▋ | 39/45 [00:13<00:01,  3.21it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  89%|████████▉ | 40/45 [00:13<00:01,  3.21it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  91%|█████████ | 41/45 [00:13<00:01,  3.20it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  93%|█████████▎| 42/45 [00:14<00:00,  3.19it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  96%|█████████▌| 43/45 [00:14<00:00,  3.19it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  98%|█████████▊| 44/45 [00:14<00:00,  3.19it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 100%|██████████| 45/45 [00:15<00:00,  2.99it/s]
# Accuracy: 0.98076
# F1: 0.74511
# Jaccard: 0.60211
# Recall: 0.73533
# Precision: 0.77498
# AUC: 0.95373
# Dice Coeff: 0.72459

# %% [markdown]
# # Reconstruct original image

# %%
prediction_np_path
# Out:
# '/content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//predictions_np/'

# %%
from glob import glob

# %%
# Create patches dictionary
predicted_patches_dict = dict()
for file in glob(f"{prediction_np_path}/*.npy"):
    print("file", file)
    patch = np.load(file)
    fname_without_ext = file.rsplit("/", 1)[1].rsplit(".", 1)[0]
    fname_without_ext = fname_without_ext[1:]
    patch_number = int(fname_without_ext.rsplit("_", 1)[1])
    image_file = fname_without_ext.rsplit("_", 1)[0]
    print(image_file, patch_number )

    if image_file in predicted_patches_dict.keys():
        predicted_patches_dict[image_file][patch_number] = np.load(file)
    else:
        patches = [None] * 140
        patches[patch_number] = np.load(file)
        predicted_patches_dict[image_file] = patches
# Out:
# file /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//predictions_np/_Image_12R_7.npy
# Image_12R 7
# file /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//predictions_np/_Image_11R_1.npy
# Image_11R 1
# file /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//predictions_np/_Image_13L_1.npy
# Image_13L 1
# file /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//predictions_np/_Image_11L_3.npy
# Image_11L 3
# file /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//predictions_np/_Image_11L_7.npy
# Image_11L 7
# file /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//predictions_np/_Image_11R_5.npy
# Image_11R 5
# file /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//predictions_np/_Image_11L_0.npy
# Image_11L 0
# file /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//predictions_np/_Image_13L_6.npy
# Image_13L 6
# file /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//predictions_np/_Image_11L_2.npy
# Image_11L 2
# file /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//predictions_np/_Image_12L_1.npy
# Image_12L 1
# file /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//predictions_np/_Image_11R_4.npy
# Image_11R 4
# file /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//predictions_np/_Image_13L_5.npy
# Image_13L 5
# file /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//predictions_np/_Image_13L_7.npy
# Image_13L 7
# file /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//predictions_np/_Image_13L_0.npy
# file /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//predictions_np/_Image_12R_6.npy
# Image_12R 6
# file /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//predictions_np/_Image_13L_8.npy
# Image_13L 8
# file /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//predictions_np/_Image_12R_2.npy
# Image_12R 2
# file /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//predictions_np/_Image_12L_5.npy
# Image_12L 5
# file /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//predictions_np/_Image_11R_2.npy
# Image_11R 2
# file /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//predictions_np/_Image_12R_0.npy
# Image_12R 0
# file /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//predictions_np/_Image_11R_7.npy
# Image_11R 7
# file /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//predictions_np/_Image_12L_0.npy
# Image_12L 0

# %%
reconstructed_predictions_path = f"{data_path}/{split_name}/reconstructed/{split}/predictions_reconstructed"
create_dir(reconstructed_predictions_path)
reconstruct_patches(predicted_patches_dict,
                    metadata_test_df,
                    reconstructed_predictions_path,
                    mfactor=255
                    )

# %%
# !pwd
# Out:
# /content/datasets

# %%
def read_mask(path):
    print(path)
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
#    x = x.astype(np.int32)
    return ori_x, x

# %%
def save_results(ori_x, ori_y, y_pred, save_image_path):
    line = np.ones((ori_x.shape[0], 10, 3)) * 255

    ori_y = np.expand_dims(ori_y, axis=-1)
    ori_y = np.concatenate([ori_y, ori_y, ori_y], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1) * 255

    cat_images = np.concatenate([ori_x, line, ori_y, line, y_pred], axis=1)
    print(f"Saving image of size {cat_images.shape} to {save_image_path}")
    cv2.imwrite(save_image_path, cat_images)

# %% [markdown]
# ### Remove the Zero Padding:

# %%
results_path_reconstructed_orig_size = f"{root_path}/results_reconstructed_orig_size/"
gt_path_reconstructed_orig_size = f"{root_path}/reconstructed_orig_size/mask/"
im_path_reconstructed_orig_size = f"{root_path}/reconstructed_orig_size/image/"

create_dir(results_path_reconstructed_orig_size)
create_dir(gt_path_reconstructed_orig_size)
create_dir(im_path_reconstructed_orig_size)

# %%
from patches import get_zero_padding_size
num_zero_padding_height, num_zero_padding_width = get_zero_padding_size(patch_size,
                                                                        image_sizes[dataset_name])
height_odd = 0 if (num_zero_padding_height % 2) == 0 else 1
width_odd = 0 if (num_zero_padding_width % 2) == 0 else 1

# %%
reconstructed_pred_files, _ = get_filenames_sorted(reconstructed_predictions_path)
print(len(reconstructed_pred_files))
print(reconstructed_pred_files[:5])
for reconstructed_pred_file in reconstructed_pred_files:
    im = cv2.imread(reconstructed_pred_file)
    name = reconstructed_pred_file.rsplit("/", 1)[1]
    im_cropped = im[num_zero_padding_height // 2 : - num_zero_padding_height // 2, num_zero_padding_width // 2 : -num_zero_padding_width //2 ]
    print(im.shape, im_cropped.shape)
    cv2.imwrite(f"{results_path_reconstructed_orig_size}/{name}", im_cropped)
# Out:
# 5
# ['/content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//split_2/reconstructed/test/predictions_reconstructed/Image_11L.png', '/content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//split_2/reconstructed/test/predictions_reconstructed/Image_11R.png', '/content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//split_2/reconstructed/test/predictions_reconstructed/Image_12L.png', '/content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//split_2/reconstructed/test/predictions_reconstructed/Image_12R.png', '/content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//split_2/reconstructed/test/predictions_reconstructed/Image_13L.png']
# (1152, 1152, 3) (960, 999, 3)
# (1152, 1152, 3) (960, 999, 3)
# (1152, 1152, 3) (960, 999, 3)
# (1152, 1152, 3) (960, 999, 3)
# (1152, 1152, 3) (960, 999, 3)

# %%
gt_path_reconstructed = f"{root_path}/{split_name}/reconstructed/{split}/"

reconstructed_im_files, reconstructed_gt_files = get_filenames_sorted(f"{gt_path_reconstructed}/image/", f"{gt_path_reconstructed}/mask/" )
print(len(reconstructed_gt_files))
print(reconstructed_gt_files[:5])

for reconstructed_im_file, reconstructed_gt_file in zip(reconstructed_im_files, reconstructed_gt_files):
    gt = cv2.imread(reconstructed_gt_file)
    im = cv2.imread(reconstructed_im_file)
    name = reconstructed_gt_file.rsplit("/", 1)[1]
    gt_cropped = gt[num_zero_padding_height // 2 : - num_zero_padding_height // 2, num_zero_padding_width // 2 : -num_zero_padding_width //2 ]
    im_cropped = im[num_zero_padding_height // 2 : - num_zero_padding_height // 2, num_zero_padding_width // 2 : -num_zero_padding_width //2 ]
    print(im.shape, im_cropped.shape)
    print(gt.shape, gt_cropped.shape)

    cv2.imwrite(f"{gt_path_reconstructed_orig_size}/{name}", gt_cropped)
    cv2.imwrite(f"{im_path_reconstructed_orig_size}/{name}", im_cropped)
# Out:
# 5
# ['/content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//split_2/reconstructed/test//mask/Image_11L.png', '/content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//split_2/reconstructed/test//mask/Image_11R.png', '/content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//split_2/reconstructed/test//mask/Image_12L.png', '/content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//split_2/reconstructed/test//mask/Image_12R.png', '/content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//split_2/reconstructed/test//mask/Image_13L.png']
# (1152, 1152, 3) (960, 999, 3)
# (1152, 1152, 3) (960, 999, 3)
# (1152, 1152, 3) (960, 999, 3)
# (1152, 1152, 3) (960, 999, 3)
# (1152, 1152, 3) (960, 999, 3)
# (1152, 1152, 3) (960, 999, 3)
# (1152, 1152, 3) (960, 999, 3)
# (1152, 1152, 3) (960, 999, 3)
# (1152, 1152, 3) (960, 999, 3)
# (1152, 1152, 3) (960, 999, 3)

# %%
results_path_reconstructed = f"{root_path}/results_reconstructed/"
create_dir(results_path_reconstructed)

# %%
from glob import glob

# %%
import tensorflow as tf
import cv2
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score, jaccard_score, recall_score, precision_score, roc_auc_score

from utils import read_image, read_mask
from utils import get_filenames_sorted
from tqdm import tqdm
from copy import deepcopy
from sklearn.metrics import confusion_matrix
def compute_metrics(data_path: str,
                    results_path: str,
                    threshold: float,
                    model=None,
                    predictions_path: str = None,
                    prediction_np_path=None):
    """ Make the prediction ( if model is not None) and calculate the metrics values. If model is None compute the
    metrics using predicted images present in location predictions_path
    data_path: Path location where images and ground truths are saved. Images should be saved in a folder data_path/image
     and ground truths should be saved at data_path/mask
    result_path: Path to directory where results should be saved

    """

    """ Load the dataset """
    test_x, test_y = get_filenames_sorted(f"{data_path}/image", f"{data_path}/mask")
    SCORE = []
    print("Threshold", threshold)
    print(len(test_x), len(test_y))
    for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):

        if model is None and predictions_path is None:
            raise Exception("Invalid input parameters. Both model and prediction_path can not be None")
        """ Extracting name """
        name = x.split("/")[-1].split(".")[0]

        """ Read the image and mask """
        ori_x, x = read_image(x)
        ori_y, y = read_mask(y)
        y = y.astype(np.int)
#        print(name)

        #     """ Prediction """
        if model != None:
            y_pred = model.predict(np.expand_dims(x, axis=0))[0]
        else:
 #           print("Reading predicted image from ", f"{predictions_path}/{name}.png")
            orig_y_pred, y_pred = read_mask(f"{predictions_path}/{name}.png")
#            print(y_pred.shape, np.max(orig_y_pred), np.min(orig_y_pred))
#        print(y_pred.shape, np.max(y_pred), np.min(y_pred))
        if prediction_np_path is not None:
            np.save(f"{prediction_np_path}/{name}.npy", y_pred)

        y_prob = deepcopy(y_pred).flatten()
        y_pred = y_pred > threshold
        y_pred = y_pred.astype(np.int32)
        y_pred = np.squeeze(y_pred)

        """ Saving the images """
        save_image_path = f"{results_path}/{name}.png"
 #       print(ori_x.shape, ori_y.shape, y_pred.shape)
        save_results(ori_x, ori_y, y_pred, save_image_path)

        if model is not None:
            cv2.imwrite(f"{predictions_path}/{name}.png", y_pred * 255)

        """ Flatten the array """
        y = y.flatten()
        y_pred = y_pred.flatten()

        """ Calculate the metrics """
        acc_value = accuracy_score(y, y_pred)
        f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
        jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
        recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
        precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
        confusion_metrics = confusion_matrix(y, y_pred, labels=[0, 1])
        if np.sum(y) == 0 or np.sum(y) == y.shape[0] :
            auc_value = 1
        else:
            auc_value = roc_auc_score(y, y_prob)
        dice_value = dice_coef(y.astype(np.float64), y_prob.astype(np.float64))
        SCORE.append([name, threshold, acc_value, f1_value, jac_value, recall_value, precision_value, auc_value, dice_value, confusion_metrics[0,0], confusion_metrics[0,1],confusion_metrics[1,0],confusion_metrics[1,1]])

    score = [s[1:] for s in SCORE]
    score = np.mean(score, axis=0)

    print(f"Threshold: {threshold:0.5f}")
    print(f"Accuracy: {score[1]:0.5f}")
    print(f"F1: {score[2]:0.5f}")
    print(f"Jaccard: {score[3]:0.5f}")
    print(f"Recall: {score[4]:0.5f}")
    print(f"Precision: {score[5]:0.5f}")
    print(f"AUC: {score[6]:0.5f}")
    print(f"Dice Coeff: {score[7]:0.5f}")


    """ Saving """
    df = pd.DataFrame(SCORE, columns=["Image","Threshold", "Acc", "F1", "Jaccard", "Recall", "Precision", "AUC", "Dice Coef", "TN", "FP","FN","TP"])
    threshold_str = str(threshold).replace(".", "_")
    df.to_csv(f"{results_path}/score_full_{threshold_str}.csv")
    return df, score

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 

dataset_path = f"{root_path}/reconstructed_orig_size/"
df = dict()
score = dict()
for threshold in range(4,7):
    df[threshold], score[threshold] = compute_metrics(dataset_path,
                        results_path=results_path_reconstructed,
                        threshold = threshold / 10,
                        model=None,
                        predictions_path=results_path_reconstructed_orig_size,
                        prediction_np_path=None)
# Out:
# Threshold 0.4
# 5 5
#   0%|          | 0/5 [00:00<?, ?it/s]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//results_reconstructed//Image_11L.png
#  20%|██        | 1/5 [00:01<00:06,  1.70s/it]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//results_reconstructed//Image_11R.png
#  40%|████      | 2/5 [00:03<00:05,  1.71s/it]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//results_reconstructed//Image_12L.png
#  60%|██████    | 3/5 [00:05<00:03,  1.71s/it]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//results_reconstructed//Image_12R.png
#  80%|████████  | 4/5 [00:06<00:01,  1.72s/it]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//results_reconstructed//Image_13L.png
# 100%|██████████| 5/5 [00:08<00:00,  1.72s/it]
# Threshold: 0.40000
# Accuracy: 0.97388
# F1: 0.77801
# Jaccard: 0.63715
# Recall: 0.73330
# Precision: 0.83048
# AUC: 0.86163
# Dice Coeff: 0.77801
# Threshold 0.5
# 5 5
#   0%|          | 0/5 [00:00<?, ?it/s]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//results_reconstructed//Image_11L.png
#  20%|██        | 1/5 [00:01<00:06,  1.73s/it]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//results_reconstructed//Image_11R.png
#  40%|████      | 2/5 [00:03<00:05,  1.74s/it]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//results_reconstructed//Image_12L.png
#  60%|██████    | 3/5 [00:05<00:03,  1.73s/it]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//results_reconstructed//Image_12R.png
#  80%|████████  | 4/5 [00:06<00:01,  1.73s/it]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//results_reconstructed//Image_13L.png
# 100%|██████████| 5/5 [00:08<00:00,  1.73s/it]
# Threshold: 0.50000
# Accuracy: 0.97388
# F1: 0.77801
# Jaccard: 0.63715
# Recall: 0.73330
# Precision: 0.83048
# AUC: 0.86163
# Dice Coeff: 0.77801
# Threshold 0.6
# 5 5
#   0%|          | 0/5 [00:00<?, ?it/s]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//results_reconstructed//Image_11L.png
#  20%|██        | 1/5 [00:01<00:06,  1.72s/it]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//results_reconstructed//Image_11R.png
#  40%|████      | 2/5 [00:03<00:05,  1.73s/it]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//results_reconstructed//Image_12L.png
#  60%|██████    | 3/5 [00:05<00:03,  1.74s/it]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//results_reconstructed//Image_12R.png
#  80%|████████  | 4/5 [00:06<00:01,  1.74s/it]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//results_reconstructed//Image_13L.png
# 100%|██████████| 5/5 [00:08<00:00,  1.73s/it]
# Threshold: 0.60000
# Accuracy: 0.97388
# F1: 0.77801
# Jaccard: 0.63715
# Recall: 0.73330
# Precision: 0.83048
# AUC: 0.86163
# Dice Coeff: 0.77801

# %%
results_path_reconstructed
# Out:
# '/content/datasets/chase_db_384_384_dice_loss_0_4__hvr_0_4_1//results_reconstructed/'

# %%
# !ls
# Out:
# chase_db_384_384_dice_loss_0_4__hvr_0_4_1  logs

# %%
folder_name = root_path.split("/")[3]
print(folder_name)
# Out:
# chase_db_384_384_dice_loss_0_4__hvr_0_4_1

# %%
# !zip -r {folder_name}.zip  {folder_name}/
# Out:
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/ (stored 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/ (stored 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_11L_2.png (deflated 53%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_11L_7.png (deflated 16%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_13L_1.png (deflated 20%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_12R_8.png (deflated 26%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_11R_5.png (deflated 18%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_11L_1.png (deflated 17%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1
)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_06L_1stHO.png (deflated 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_07L_1stHO.png (deflated 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_08R_1stHO.png (deflated 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_13R_1stHO.png (deflated 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_09L_1stHO.png (deflated 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_10R_1stHO.png (deflated 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_04L_1stHO.png (deflated 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_03L_1stHO.png (deflated 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_14R_1stHO.png (deflated 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_04R_1stHO.png (deflated 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_09R_1stHO.png (deflated 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_10L_1stHO.png (deflated 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_01L_1stHO.png (deflated 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_08L_1stHO.png (deflated 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_05R_1stHO.png (deflated 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/reconstructed_orig_size/ (stored 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/reconstructed_orig_size/mask/ (stored 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/reconstructed_orig_size/mask/Image_11L.png (deflated 30%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/reconstructed_orig_size/mask/Image_11R.png (deflated 34%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/reconstructed_orig_size/mask/Image_12R.png (deflated 31%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/reconstructed_orig_size/mask/Image_12L.png (deflated 32%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/reconstructed_orig_size/mask/Image_13L.png (deflated 32%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/reconstructed_orig_size/image/ (stored 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/reconstructed_orig_size/image/Image_11L.png (deflated 2%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/reconstructed_orig_size/image/Image_11R.png (deflated 2%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/reconstructed_orig_size/image/Image_12R.png (deflated 2%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/reconstructed_orig_size/image/Image_12L.png (deflated 2%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/reconstructed_orig_size/image/Image_13L.png (deflated 6%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/test/ (stored 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/test/images/ (stored 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/test/images/Image_13L.jpg (deflated 8%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/test/images/Image_11R.jpg (deflated 7%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/test/images/Image_12R.jpg (deflated 6%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/test/images/Image_11L.jpg (deflated 6%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/test/images/Image_12L.jpg (deflated 7%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/test/1st_manual/ (stored 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/test/1st_manual/Image_12R_1stHO.png (deflated 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/test/1st_manual/Image_12L_1stHO.png (deflated 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/test/1st_manual/Image_11R_1stHO.png (deflated 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/test/1st_manual/Image_11L_1stHO.png (deflated 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/test/1st_manual/Image_13L_1stHO.png (deflated 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/results_reconstructed/ (stored 0%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/results_reconstructed/Image_11L.png (deflated 4%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/results_reconstructed/Image_11R.png (deflated 4%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/results_reconstructed/Image_12R.png (deflated 4%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/results_reconstructed/score_full_0_5.csv (deflated 50%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/results_reconstructed/Image_12L.png (deflated 4%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/results_reconstructed/score_full_0_6.csv (deflated 50%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/results_reconstructed/score_full_0_4.csv (deflated 50%)
#   adding: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/results_reconstructed/Image_13L.png (deflated 8%)

# %%
# !ls -ltrh
# Out:
# total 516M
# drwxr-xr-x  4 root root 4.0K Mar 29 06:28 logs
# drwxr-xr-x 13 root root 4.0K Mar 29 06:57 chase_db_384_384_dice_loss_0_4__hvr_0_4_1
# -rw-r--r--  1 root root 516M Mar 29 06:58 chase_db_384_384_dice_loss_0_4__hvr_0_4_1.zip

# %%
# !ls /content/gdrive/MyDrive/Blood_Vessel_Results/chase_patches/
# Out:
# chase_db_128_128_dice_loss_0_4__0_4_1
# chase_db_128_128_dice_loss_0_4__0_4_1.zip
# chase_db_128_128_dice_loss_0_4__hvr_0_4_1
# chase_db_128_128_dice_loss_0_4__hvr_0_4_1.zip
# chase_db_256_256_dice_loss_0_4__0_4_1
# chase_db_256_256_dice_loss_0_4__0_4_1.zip
# chase_db_256_256_dice_loss_0_4__hvr_0_4_1
# chase_db_256_256_dice_loss_0_4__hvr_0_4_1.zip
# chase_db_384_384_dice_loss_0_4__0_4_1
# chase_db_384_384_dice_loss_0_4__0_4_1.zip
# chase_db_512_512_dice_loss_0_4__0_4_1
# chase_db_512_512_dice_loss_0_4__0_4_1.zip

# %%
# !cp {folder_name}.zip /content/gdrive/MyDrive/Blood_Vessel_Results/chase_patches/

# %%
# %cd /content/gdrive/MyDrive/Blood_Vessel_Results/chase_patches/
# Out:
# /content/gdrive/MyDrive/Blood_Vessel_Results/chase_patches

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/Blood_Vessel_Results/chase_patches

# %%
# !ls
# Out:
# chase_db_128_128_dice_loss_0_4__0_4_1
# chase_db_128_128_dice_loss_0_4__0_4_1.zip
# chase_db_128_128_dice_loss_0_4__hvr_0_4_1
# chase_db_128_128_dice_loss_0_4__hvr_0_4_1.zip
# chase_db_256_256_dice_loss_0_4__0_4_1
# chase_db_256_256_dice_loss_0_4__0_4_1.zip
# chase_db_256_256_dice_loss_0_4__hvr_0_4_1
# chase_db_256_256_dice_loss_0_4__hvr_0_4_1.zip
# chase_db_384_384_dice_loss_0_4__0_4_1
# chase_db_384_384_dice_loss_0_4__0_4_1.zip
# chase_db_384_384_dice_loss_0_4__hvr_0_4_1.zip
# chase_db_512_512_dice_loss_0_4__0_4_1
# chase_db_512_512_dice_loss_0_4__0_4_1.zip

# %%
# !unzip {folder_name}.zip
# Out:
# Archive:  chase_db_384_384_dice_loss_0_4__hvr_0_4_1.zip
#    creating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/
#    creating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_11L_2.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_11L_7.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_13L_1.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_12R_8.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_11R_5.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_11L_1.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_12R_3.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_12R_1.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_12L_0.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_11L_0.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_11L_8.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_11R_0.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_12R_4.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_12R_7.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_13L_5.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_12L_1.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_13L_6.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_12L_8.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_11R_1.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_12L_2.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_11L_3.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_13L_4.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_13L_8.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_13L_2.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_12L_7.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_12R_6.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_13L_0.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_12L_6.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_12L_5.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_11R_6.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_12R_2.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_13L_3.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/predictions/_Image_11R_8.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/images/Image_01R.jpg
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/images/Image_10R.jpg
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/images/Image_06L.jpg
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/images/Image_03R.jpg
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/images/Image_10L.jpg
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/images/Image_07L.jpg
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/images/Image_09R.jpg
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/images/Image_03L.jpg
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/images/Image_02L.jpg
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/images/Image_05L.jpg
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/images/Image_02R.jpg
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/images/Image_01L.jpg
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/images/Image_08L.jpg
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/images/Image_14R.jpg
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/images/Image_08R.jpg
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/images/Image_13R.jpg
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/images/Image_14L.jpg
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/images/Image_06R.jpg
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/images/Image_09L.jpg
#    creating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_07R_1stHO.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_02L_1stHO.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_05L_1stHO.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_06R_1stHO.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_03R_1stHO.png
#  extracting: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_14L_1stHO.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_02R_1stHO.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_01R_1stHO.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_06L_1stHO.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_07L_1stHO.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_08R_1stHO.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_13R_1stHO.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_09L_1stHO.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_10R_1stHO.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_04L_1stHO.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_03L_1stHO.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_14R_1stHO.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_04R_1stHO.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_09R_1stHO.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_10L_1stHO.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_01L_1stHO.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_08L_1stHO.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/training/1st_manual/Image_05R_1stHO.png
#    creating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/reconstructed_orig_size/
#    creating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/reconstructed_orig_size/mask/
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/reconstructed_orig_size/mask/Image_11L.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/reconstructed_orig_size/mask/Image_11R.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/reconstructed_orig_size/mask/Image_12R.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/reconstructed_orig_size/mask/Image_12L.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/reconstructed_orig_size/mask/Image_13L.png
#    creating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/reconstructed_orig_size/image/
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/reconstructed_orig_size/image/Image_11L.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/reconstructed_orig_size/image/Image_11R.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/reconstructed_orig_size/image/Image_12R.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/reconstructed_orig_size/image/Image_12L.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/reconstructed_orig_size/image/Image_13L.png
#    creating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/test/
#    creating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/test/images/
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/test/images/Image_13L.jpg
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/test/images/Image_11R.jpg
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/test/images/Image_12R.jpg
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/test/images/Image_11L.jpg
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/test/images/Image_12L.jpg
#    creating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/test/1st_manual/
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/test/1st_manual/Image_12R_1stHO.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/test/1st_manual/Image_12L_1stHO.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/test/1st_manual/Image_11R_1stHO.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/test/1st_manual/Image_11L_1stHO.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/test/1st_manual/Image_13L_1stHO.png
#    creating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/results_reconstructed/
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/results_reconstructed/Image_11L.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/results_reconstructed/Image_11R.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/results_reconstructed/Image_12R.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/results_reconstructed/score_full_0_5.csv
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/results_reconstructed/Image_12L.png
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/results_reconstructed/score_full_0_6.csv
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/results_reconstructed/score_full_0_4.csv
#   inflating: chase_db_384_384_dice_loss_0_4__hvr_0_4_1/results_reconstructed/Image_13L.png

# %%
drive.flush_and_unmount()
