# %% [markdown]
# ### Import the required libraries and modules:

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
import numpy as np

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# %cd /content/gdrive/MyDrive/medical_image_processing/
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/medical_image_processing

# %%
from fundal_image.utils import create_dir, get_filenames_sorted
from patches import generate_patches_images_only, reconstruct_patches
from metrics import iou, dice_coef, dice_loss, DiceBCELoss, bce
from metrics import compute_metrics, save_results
from utils import read_image_train, read_mask_train

# %%
image_sizes = {"HRF": (2336, 3504), "drive": (584, 565), "chase_db": (960, 999)}
patch_size = {"HRF": (768, 768),
              "drive":(128, 128),
              "chase_db":(128, 128)
              }

dataset_name = "chase_db"
patch_size = patch_size[dataset_name]
patch_height = patch_size[0]
patch_width = patch_size[1]

# %%
loss_str = "dice_loss"
with_augmentation = False
stride=128
seed = 42
run_id = 1
test_percentage = 0.4
class_weight = 0.4
class_weight_str = str(class_weight).replace(".", "_")
aug_string = ""
if with_augmentation:
    aug_string = "_hvr"
test_percentage_str = str(test_percentage).replace(".", "_")
root_path = f"/content/datasets/{dataset_name}_{patch_height}_{stride}_{loss_str}_{class_weight_str}_{aug_string}_{test_percentage_str}_{run_id}/"

images_path_train = f"{root_path}/training/images/"
gt_path_train = f"{root_path}/training/1st_manual/"
images_path_test = f"{root_path}/test/images/"
gt_path_test = f"{root_path}/test/1st_manual/"

create_dir(images_path_train)
create_dir(gt_path_train)
create_dir(images_path_test)
create_dir(gt_path_test)

# %%
def wbce(actual, predicted):
    y_pred = K.clip(predicted, K.epsilon(), 1 - K.epsilon())
    term_0 = (1 - actual) * K.log(1 - y_pred)
    term_1 = class_weight * actual * K.log(y_pred + K.epsilon())
    return -K.mean(term_0 + term_1, axis=0)

# %%
root_path
# Out:
# '/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1/'

# %%
images_path_train
# Out:
# '/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//training/images/'

# %%
# !cp /content/gdrive/MyDrive/medical_image_processing/fundal_image/datasets/chase_db/split_1/training/images/*.* {images_path_train}
# !cp /content/gdrive/MyDrive/medical_image_processing/fundal_image/datasets/chase_db/split_1//training/groundtruth1/*.* {gt_path_train}

# %%
# !cp /content/gdrive/MyDrive/medical_image_processing/fundal_image/datasets/chase_db/split_1/test/images/*.* {images_path_test}
# !cp /content/gdrive/MyDrive/medical_image_processing/fundal_image/datasets/chase_db/split_1/test/groundtruth1/*.* {gt_path_test}

# %%
# !ls /content/gdrive/MyDrive/medical_image_processing/fundal_image/datasets//chase_db/split_1/training/images
# Out:
# Image_01L.jpg  Image_03R.jpg  Image_06L.jpg  Image_08R.jpg  Image_13R.jpg
# Image_01R.jpg  Image_04L.jpg  Image_06R.jpg  Image_09L.jpg  Image_14L.jpg
# Image_02L.jpg  Image_04R.jpg  Image_07L.jpg  Image_09R.jpg  Image_14R.jpg
# Image_02R.jpg  Image_05L.jpg  Image_07R.jpg  Image_10L.jpg
# Image_03L.jpg  Image_05R.jpg  Image_08L.jpg  Image_10R.jpg

# %%
# images_files, gt_files = get_filenames_sorted(images_path, gt_path)
# print(len(images_files), len(gt_files))
# # train_test_split
# from sklearn.model_selection import train_test_split
# label = [_xtrain.rsplit("/", 1)[1].rsplit(".", 1)[0].rsplit("_", 1)[1] for _xtrain in images_files] 
# xtrain, xtest, ytrain, ytest = train_test_split(images_files, gt_files, stratify=label,  test_size=test_percentage, random_state=seed)

# %%
xtrain, ytrain = get_filenames_sorted(images_path_train, gt_path_train)
xtest, ytest = get_filenames_sorted(images_path_test, gt_path_test)

# %%
print(len(xtrain), len(xtest))
# print(label)
# Out:
# 23 5

# %%
xtrain[:5]
# Out:
# ['/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//training/images/Image_01L.jpg',
#  '/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//training/images/Image_01R.jpg',
#  '/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//training/images/Image_02L.jpg',
#  '/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//training/images/Image_02R.jpg',
#  '/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//training/images/Image_03L.jpg']

# %%
print(len(ytrain), len(ytest))
ytrain[:5]
# Out:
# 23 5
# ['/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//training/1st_manual/Image_01L_1stHO.png',
#  '/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//training/1st_manual/Image_01R_1stHO.png',
#  '/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//training/1st_manual/Image_02L_1stHO.png',
#  '/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//training/1st_manual/Image_02R_1stHO.png',
#  '/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//training/1st_manual/Image_03L_1stHO.png']

# %%
ytest[:5]
# Out:
# ['/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//test/1st_manual/Image_11L_1stHO.png',
#  '/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//test/1st_manual/Image_11R_1stHO.png',
#  '/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//test/1st_manual/Image_12L_1stHO.png',
#  '/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//test/1st_manual/Image_12R_1stHO.png',
#  '/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//test/1st_manual/Image_13L_1stHO.png']

# %%
from tqdm import tqdm
import pandas as pd

# %%
from sklearn.feature_extraction import image
import numpy as np
from PIL import Image
from tqdm import tqdm
import pandas as pd
import cv2

from fundal_image.utils import  create_dir
from utils import get_filenames_sorted

def generate_patches_images_only(image_files,
                                 save_path_image,
                                 max_patch=30,
                                 dataset_name="",
                                 patch_size=(512, 512),
                                 stride=None,
                                 padding="zeros",
                                 exclude_boundary=True,
                                 zero_padding_size=(0, 0),
                                 gt_files=None,
                                 save_path_gt=None
                                 ):
    
    def patches_with_stride(image_filename, im, _patch_size, _stride, gt_name=None, gt=None):
        patches = []
        gt_patches = []
        # print("Image size", im.shape)
        metadata_list = []
        columns = ["image_filename", "row", "col", "patch_height", "patch_width", "stride", "num_fg_pixels"]
        if padding == "zeros":
            num_zero_padding_height = im.shape[0] % patch_size[0]
            num_zero_padding_width = im.shape[1] % patch_size[1]

            if num_zero_padding_height > 0:
                num_zero_padding_height = _patch_size[0] - num_zero_padding_height

            if num_zero_padding_width > 0:
                num_zero_padding_width = _patch_size[1] - num_zero_padding_width

            height_odd = 0 if (num_zero_padding_height % 2) == 0 else 1
            width_odd = 0 if (num_zero_padding_width % 2) == 0 else 1
        else:
            raise Exception(f"Value for argument padding is not mentioned")

        # print(f"Image shape {im.shape}. Patch size {_patch_size}.  Num Zero padding rows {num_zero_padding_height}. Num zero padding cols {num_zero_padding_width}")
        im = np.pad(im, ((num_zero_padding_height // 2, num_zero_padding_height // 2 + height_odd),
                                (num_zero_padding_width // 2, num_zero_padding_width // 2 + width_odd),
                                (0, 0)
                                )
                           )
        if gt is not None:
            if len(gt.shape) == 3:
                gt = np.pad(gt, ((num_zero_padding_height // 2, num_zero_padding_height // 2 + height_odd),
                                 (num_zero_padding_width // 2, num_zero_padding_width // 2 + width_odd),
                                 (0, 0)
                                 )
                            )
            else:
                gt = np.pad(gt, ((num_zero_padding_height // 2, num_zero_padding_height // 2 + height_odd),
                                 (num_zero_padding_width // 2, num_zero_padding_width // 2 + width_odd)
                                 )
                            )

        im_gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
        # print(f"image shape after padding {im.shape}")
        for row in range(0, im.shape[0], _stride):
            for col in range(0, im.shape[1], _stride):
                if row + _patch_size[0] >= im.shape[0]:
                    row = im.shape[0] - _patch_size[0]
                if col + _patch_size[1] >= im.shape[1]:
                    col = im.shape[1] - _patch_size[1]
                image_patch = im[row:row + _patch_size[0], col:col + _patch_size[1]]
                num_fg_pixels = np.sum(im_gray[row:row + _patch_size[0], col:col + _patch_size[1]] > 0)
                if gt is not None:
                    gt_patch = gt[row:row + _patch_size[0], col:col + _patch_size[1]]
                if num_fg_pixels > 0:
                    patches.append(image_patch)
                    metadata_list.append([image_filename, row, col, _patch_size[0], _patch_size[1], _stride, num_fg_pixels])
                    if gt is not None:
                        gt_patches.append(gt_patch)


        metadata_df = pd.DataFrame(metadata_list, columns=columns )
        patches_np = np.asarray(patches)
        if gt is not None:
            gt_patches_np = np.asarray(gt_patches)
        else:
            gt_patches_np = None

        return patches_np, metadata_df, gt_patches_np

    num_images = len(image_files)
    print(f"Generating patches for {num_images} images")
    metadata_df = None
    create_dir(save_path_image)
    im_patches_dict = dict()
    gt_patches_dict = dict()
    for idx, image_filename in tqdm(enumerate(image_files), total=len(image_files)):
        image_filename = image_filename.replace("\\", "/")
        # print("Image file", image_filename)
        name = image_filename.rsplit("/", 1)[1].rsplit(".", 1)[0]
        # image1 = Image.open(x)
        # image_array = np.asarray(image1)
        image_array = cv2.imread(image_filename)

        if gt_files is not None and len(gt_files) > 0:
            gt_filename = gt_files[idx]
            gt_filename = gt_filename.replace("\\", "/")
            # print("Image file", image_filename)
            gt_name = gt_filename.rsplit("/", 1)[1].rsplit(".", 1)[0]


            gt = cv2.imread(gt_filename)
            # gt = np.asarray(Image.open(gt_filename))
            # print(gt.dtype)
            if len(gt.shape) == 3:
                gt = cv2.cvtColor(gt, cv2.COLOR_BGR2GRAY)

        if not exclude_boundary:
            # add zero padding
            image_array = np.pad(image_array, zero_padding_size)
            gt = np.pad(gt, zero_padding_size)

        if stride is None:
            image_patches = image.extract_patches_2d(image_array, patch_size, max_patches=max_patch, random_state=42)
        else:
            ret_value = patches_with_stride(image_filename, image_array, patch_size, stride, gt_name, gt)
            if ret_value is None :
                raise Exception(f"Could not create patches for {image_filename}")
            else:
                image_patches, _metadata_df, gt_patches = ret_value[0], ret_value[1], ret_value[2]
            if metadata_df is not None:
                metadata_df = metadata_df.append(_metadata_df)
            else:
                metadata_df = _metadata_df
        im_patches_dict[name] = image_patches
        gt_patches_dict[name] = gt_patches

        # print(gt_patches.dtype)


        if save_path_image is not None and len(save_path_image) > 0:
            count = 0
            for i in range(len(image_patches)):
                # data = Image.fromarray(image_patches[i])
                # print(save_path_image, dataset_name, name)
                image_path_file = f"{save_path_image}/{dataset_name}_{name}_{count}.png"
                # print(f"Saving patches to {image_path_file}")
                cv2.imwrite(image_path_file, image_patches[i])

                if gt_patches is not None and save_path_gt is not None:
                    gt_path_file = f"{save_path_gt}/{dataset_name}_{name}_{count}.png"
                    # print(gt_path_file)
                    # print(type(gt_patches))
                    # print(gt_patches[i].shape)
                    # print(gt_patches[i].dtype)
                    # print(np.min(gt_patches[i]), np.max(gt_patches[i]))
                    cv2.imwrite(gt_path_file, gt_patches[i])
                count += 1

    return im_patches_dict, metadata_df, gt_patches_dict

# %%
num_pixels_to_add = [0, 0]
if (image_sizes[dataset_name][0] % patch_size[0]) > 0:
    num_pixels_to_add[0] = ((image_sizes["chase_db"][0] // patch_size[0]) + 1) * patch_size[0]
    num_pixels_to_add[1] = ((image_sizes["chase_db"][1] // patch_size[1]) + 1) * patch_size[1]

split_name = "split_2"
data_path = root_path
splits =["train","test"]


split = "train"
#for split in splits:
image_patches_path = f"{data_path}/{split_name}/{split}/image/"
create_dir(image_patches_path)
gt_patches_path = f"{data_path}/{split_name}/{split}/mask/"
create_dir(gt_patches_path)
im_patches_dict_train, metadata_train_df, gt_patches_dict_train = generate_patches_images_only(xtrain,
                                                                image_patches_path,
                                                                patch_size=patch_size,
                                                                stride=stride,
                                                                zero_padding_size=num_pixels_to_add,
                                                                gt_files=ytrain,
                                                                save_path_gt=gt_patches_path)
metadata_train_df.to_csv(f"{data_path}/{split_name}/image_patches_{stride}_{stride}_{split}.csv", index=False)
# Out:
# Generating patches for 23 images
# 100%|██████████| 23/23 [00:01<00:00, 14.80it/s]

# %%
gt_patches_path
# Out:
# '/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//split_2/train/mask/'

# %%
split = "test"
#for split in splits:
image_patches_path = f"{data_path}/{split_name}/{split}/image/"
create_dir(image_patches_path)
gt_patches_path = f"{data_path}/{split_name}/{split}/mask/"
create_dir(gt_patches_path)
im_patches_dict_test, metadata_test_df, gt_patches_dict_test = generate_patches_images_only(xtest,
                                                                image_patches_path,
                                                                patch_size=patch_size,
                                                                stride=stride,
                                                                zero_padding_size=num_pixels_to_add,
                                                                gt_files=ytest,
                                                                save_path_gt=gt_patches_path)
metadata_test_df.to_csv(f"{data_path}/{split_name}/image_patches_{patch_height}_{stride}_{split}.csv", index=False)
# Out:
# Generating patches for 5 images
# 100%|██████████| 5/5 [00:00<00:00, 16.45it/s]

# %%
metadata_test_df.shape
# Out:
# (296, 7)

# %%
metadata_train_df.shape
# Out:
# (1337, 7)

# %%
metadata_train_df.head()
# Out:
#                                       image_filename  row  col  patch_height  \
# 0  /content/datasets/chase_db_128_128_dice_loss_0...    0  128           128
# 1  /content/datasets/chase_db_128_128_dice_loss_0...    0  256           128
# 2  /content/datasets/chase_db_128_128_dice_loss_0...    0  384           128
# 3  /content/datasets/chase_db_128_128_dice_loss_0...    0  512           128
# 4  /content/datasets/chase_db_128_128_dice_loss_0...    0  640           128
#
#    patch_width  stride  num_fg_pixels
# 0          128     128             72
# 1          128     128           5537
# 2          128     128           9894
# 3          128     128           9705
# 4          128     128           4833

# %%
import glob
split = "test"
image_patches_path = f"{data_path}/{split_name}/{split}/image/"

reconstructed_original_path = f"{data_path}/{split_name}/reconstructed/{split}/image"
create_dir(reconstructed_original_path)
reconstruct_patches(im_patches_dict_test,
                    metadata_test_df,
                    reconstructed_original_path
                    )
# Out:
# /content/gdrive/MyDrive/medical_image_processing/patches.py:294: RuntimeWarning: invalid value encountered in true_divide
#   im[:, :, channel] = np.true_divide(im[:, :, channel], count_im)

# %%
print(list(gt_patches_dict_test.keys()))
# Out:
# ['Image_11L', 'Image_11R', 'Image_12L', 'Image_12R', 'Image_13L']

# %%
type(gt_patches_dict_test["Image_11L"])
# Out:
# numpy.ndarray

# %%
reconstructed_gt_path = f"{data_path}/{split_name}/reconstructed/{split}/mask"

create_dir(reconstructed_gt_path)
reconstruct_patches(gt_patches_dict_test,
                    metadata_test_df,
                    reconstructed_gt_path,
                    )
# Out:
# /content/gdrive/MyDrive/medical_image_processing/patches.py:296: RuntimeWarning: invalid value encountered in true_divide
#   im[:, :] = np.true_divide(im[:, :], count_im)

# %%
print([k for k in im_patches_dict_test.keys()])
# Out:
# ['Image_11L', 'Image_11R', 'Image_12L', 'Image_12R', 'Image_13L']

# %% [markdown]
# ### Construct the Model:

# %%
def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    b1 = conv_block(p4, 1024)

    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="UNET")
    return model

input_shape = (512, 512, 3)
model = build_unet(input_shape)
model.summary()
# Out:
# Model: "UNET"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 512, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 512, 512, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 512, 512, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 512, 512, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 12  0          ['activation_3[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 25  295168      ['max_pooling2d_1[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_4[0][0]']
#  rmalization)                   6)
#
#  activation_4 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_4[0][0]']
#                                 6)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 25  590080      ['activation_4[0][0]']
#                                 6)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_5[0][0]']
#  rmalization)                   6)
#
#  activation_5 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_5[0][0]']
#                                 6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 512)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 512)  2097664    ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 64, 64, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 25  524544     ['activation_11[0][0]']
#  spose)                         6)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 51  0           ['conv2d_transpose_1[0][0]',
#                                 2)                                'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_12 (BatchN  (None, 128, 128, 25  1024       ['conv2d_12[0][0]']
#  ormalization)                  6)
#
#  activation_12 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_12[0][0]']
#                                 6)
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 25  590080      ['activation_12[0][0]']
#                                 6)
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 25  1024       ['conv2d_13[0][0]']
#  ormalization)                  6)
#
#  activation_13 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_13[0][0]']
#                                 6)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 12  131200     ['activation_13[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 256, 256, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  activation_14 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_15 (BatchN  (None, 256, 256, 12  512        ['conv2d_15[0][0]']
#  ormalization)                  8)
#
#  activation_15 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_15[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 64  32832      ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 512, 512, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 512, 512, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 512, 512, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 512, 512, 1)  65          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %% [markdown]
# ### Adding the Metrics:

# %%
def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def DiceBCELoss(y_true, y_pred):
    
    inputs = tf.keras.layers.Flatten()(y_true)
    targets = tf.keras.layers.Flatten()(y_pred)

    intersection = tf.reduce_sum(inputs * targets)
    dice_loss = 1 - (2.*intersection + smooth)/(tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)
    BCE = tf.keras.losses.BinaryCrossentropy()
    Dice_BCE = BCE(inputs, targets) + dice_loss

    return Dice_BCE

def bce(y_true, y_pred):
    
    inputs = tf.keras.layers.Flatten()(y_true)
    targets = tf.keras.layers.Flatten()(y_pred)
    BCE = tf.keras.losses.BinaryCrossentropy()
    Dice_BCE = BCE(inputs, targets)

    return Dice_BCE

# %% [markdown]
# ### Training the Model:

# %%
if loss_str == "bce":
    loss = bce
elif loss_str == "dice_bce":
    loss = DiceBCELoss
elif loss_str == "dice_loss":
    loss = dice_loss
elif loss_str == "wbce":
    loss = wbce
else:
    raise Exception("Invalid value for loss_str")
    
print(loss)
# Out:
# <function dice_loss at 0x7f0cd02447a0>

# %%
H = patch_height
W = patch_width

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.png")))
    y = sorted(glob(os.path.join(path, "mask", "*.png")))
    return x, y

def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)
    return x, y

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)              ## (512, 512, 1)
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y, batch_size=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(4)
    return dataset

# %%
from keras.metrics import AUC

# %%
model_dir = f"{root_path}/trained_models/"

# %%
create_dir(model_dir)

# %%
# !ls {model_dir}

# %%
# %cd /content/datasets
# Out:
# /content/datasets

# %%
from glob import glob

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir(model_dir)

""" Hyperparameters """
batch_size = 8
lr = 1e-4
num_epochs = 50
model_path = os.path.join(f"{model_dir}", "model.h5")
csv_path = os.path.join(f"{model_dir}", "data.csv")

""" Dataset """
dataset_path = f"{data_path}/{split_name}"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
# train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model = build_unet((H, W, 3))
model.compile(loss=loss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision(), AUC()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 1337 - 1337
# Valid: 296 - 296
# Epoch 1/50
# 168/168 [==============================] - ETA: 0s - loss: 0.6020 - dice_coef: 0.3969 - iou: 0.2553 - recall: 0.7805 - precision: 0.3219 - auc: 0.9039
# Epoch 1: val_loss improved from inf to 0.91679, saving model to /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//trained_models/model.h5
# 168/168 [==============================] - 25s 64ms/step - loss: 0.6020 - dice_coef: 0.3969 - iou: 0.2553 - recall: 0.7805 - precision: 0.3219 - auc: 0.9039 - val_loss: 0.9168 - val_dice_coef: 0.0832 - val_iou: 0.0436 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_auc: 0.3844 - lr: 1.0000e-04
# Epoch 2/50
# 167/168 [============================>.] - ETA: 0s - loss: 0.4372 - dice_coef: 0.5628 - iou: 0.3974 - recall: 0.7790 - precision: 0.6464 - auc: 0.9398
# Epoch 2: val_loss improved from 0.91679 to 0.88129, saving model to /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//trained_models/model.h5
# 168/168 [==============================] - 10s 57ms/step - loss: 0.4374 - dice_coef: 0.5610 - iou: 0.3959 - recall: 0.7791 - precision: 0.6460 - auc: 0.9398 - val_loss: 0.8813 - val_dice_coef: 0.1187 - val_iou: 0.0652 - val_recall: 0.0817 - val_precision: 0.5077 - val_auc: 0.4572 - lr: 1.0000e-04
# Epoch 3/50
# 167/168 [============================>.] - ETA: 0s - loss: 0.3675 - dice_coef: 0.6325 - iou: 0.4686 - recall: 0.7905 - precision: 0.7048 - auc: 0.9451
# Epoch 3: val_loss improved from 0.88129 to 0.68437, saving model to /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//trained_models/model.h5
# 168/168 [==============================] - 10s 57ms/step - loss: 0.3677 - dice_coef: 0.6305 - iou: 0.4668 - recall: 0.7905 - precision: 0.7044 - auc: 0.9451 - val_loss: 0.6844 - val_dice_coef: 0.3156 - val_iou: 0.1957 - val_recall: 0.2820 - val_precision: 0.7734 - val_auc: 0.7210 - lr: 1.0000e-04
# Epoch 4/50
# 167/168 [============================>.] - ETA: 0s - loss: 0.3179 - dice_coef: 0.6821 - iou: 0.5233 - recall: 0.7980 - precision: 0.7424 - auc: 0.9476
# Epoch 4: val_loss improved from 0.68437 to 0.60728, saving model to /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//trained_models/model.h5
# 168/168 [==============================] - 10s 57ms/step - loss: 0.3182 - dice_coef: 0.6801 - iou: 0.5214 - recall: 0.7981 - precision: 0.7421 - auc: 0.9476 - val_loss: 0.6073 - val_dice_coef: 0.3927 - val_iou: 0.2548 - val_recall: 0.3421 - val_precision: 0.8343 - val_auc: 0.8263 - lr: 1.0000e-04
# Epoch 5/50
# 168/168 [==============================] - ETA: 0s - loss: 0.2858 - dice_coef: 0.7127 - iou: 0.5592 - recall: 0.7999 - precision: 0.7646 - auc: 0.9481
# Epoch 5: val_loss improved from 0.60728 to 0.45723, saving model to /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//trained_models/model.h5
# 168/168 [==============================] - 10s 57ms/step - loss: 0.2858 - dice_coef: 0.7127 - iou: 0.5592 - recall: 0.7999 - precision: 0.7646 - auc: 0.9481 - val_loss: 0.4572 - val_dice_coef: 0.5428 - val_iou: 0.3855 - val_recall: 0.5193 - val_precision: 0.7997 - val_auc: 0.8867 - lr: 1.0000e-04
# Epoch 6/50
# 167/168 [============================>.] - ETA: 0s - loss: 0.2583 - dice_coef: 0.7417 - iou: 0.5935 - recall: 0.8077 - precision: 0.7818 - auc: 0.9492
# Epoch 6: val_loss improved from 0.45723 to 0.41297, saving model to /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//trained_models/model.h5
# 168/168 [==============================] - 10s 57ms/step - loss: 0.2586 - dice_coef: 0.7393 - iou: 0.5912 - recall: 0.8078 - precision: 0.7813 - auc: 0.9492 - val_loss: 0.4130 - val_dice_coef: 0.5870 - val_iou: 0.4270 - val_recall: 0.5830 - val_precision: 0.7558 - val_auc: 0.9077 - lr: 1.0000e-04
# Epoch 7/50
# 167/168 [============================>.] - ETA: 0s - loss: 0.2390 - dice_coef: 0.7610 - iou: 0.6175 - recall: 0.8085 - precision: 0.7977 - auc: 0.9471
# Epoch 7: val_loss did not improve from 0.41297
# 168/168 [==============================] - 9s 52ms/step - loss: 0.2392 - dice_coef: 0.7593 - iou: 0.6157 - recall: 0.8085 - precision: 0.7974 - auc: 0.9471 - val_loss: 0.4328 - val_dice_coef: 0.5672 - val_iou: 0.4099 - val_recall: 0.5242 - val_precision: 0.8037 - val_auc: 0.8522 - lr: 1.0000e-04
# Epoch 8/50
# 167/168 [============================>.] - ETA: 0s - loss: 0.2247 - dice_coef: 0.7753 - iou: 0.6359 - recall: 0.8135 - precision: 0.8041 - auc: 0.9518
# Epoch 8: val_loss did not improve from 0.41297
# 168/168 [==============================] - 9s 52ms/step - loss: 0.2249 - dice_coef: 0.7740 - iou: 0.6344 - recall: 0.8135 - precision: 0.8040 - auc: 0.9518 - val_loss: 0.4541 - val_dice_coef: 0.5459 - val_iou: 0.3942 - val_recall: 0.4796 - val_precision: 0.8485 - val_auc: 0.8515 - lr: 1.0000e-04
# Epoch 9/50
# 168/168 [==============================] - ETA: 0s - loss: 0.2129 - dice_coef: 0.7858 - iou: 0.6500 - recall: 0.8169 - precision: 0.8121 - auc: 0.9507
# Epoch 9: val_loss improved from 0.41297 to 0.31897, saving model to /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//trained_models/model.h5
# 168/168 [==============================] - 10s 57ms/step - loss: 0.2129 - dice_coef: 0.7858 - iou: 0.6500 - recall: 0.8169 - precision: 0.8121 - auc: 0.9507 - val_loss: 0.3190 - val_dice_coef: 0.6810 - val_iou: 0.5259 - val_recall: 0.6949 - val_precision: 0.7667 - val_auc: 0.9033 - lr: 1.0000e-04
# Epoch 10/50
# 168/168 [==============================] - ETA: 0s - loss: 0.2027 - dice_coef: 0.7958 - iou: 0.6635 - recall: 0.8207 - precision: 0.8193 - auc: 0.9481
# Epoch 10: val_loss did not improve from 0.31897
# 168/168 [==============================] - 9s 52ms/step - loss: 0.2027 - dice_coef: 0.7958 - iou: 0.6635 - recall: 0.8207 - precision: 0.8193 - auc: 0.9481 - val_loss: 0.3259 - val_dice_coef: 0.6741 - val_iou: 0.5233 - val_recall: 0.6624 - val_precision: 0.7955 - val_auc: 0.8825 - lr: 1.0000e-04
# Epoch 11/50
# 168/168 [==============================] - ETA: 0s - loss: 0.1930 - dice_coef: 0.8061 - iou: 0.6773 - recall: 0.8260 - precision: 0.8268 - auc: 0.9464
# Epoch 11: val_loss did not improve from 0.31897
# 168/168 [==============================] - 9s 51ms/step - loss: 0.1930 - dice_coef: 0.8061 - iou: 0.6773 - recall: 0.8260 - precision: 0.8268 - auc: 0.9464 - val_loss: 0.3246 - val_dice_coef: 0.6754 - val_iou: 0.5209 - val_recall: 0.6674 - val_precision: 0.7837 - val_auc: 0.8805 - lr: 1.0000e-04
# Epoch 12/50
# 168/168 [==============================] - ETA: 0s - loss: 0.1860 - dice_coef: 0.8129 - iou: 0.6868 - recall: 0.8265 - precision: 0.8339 - auc: 0.9444
# Epoch 12: val_loss did not improve from 0.31897
# 168/168 [==============================] - 9s 51ms/step - loss: 0.1860 - dice_coef: 0.8129 - iou: 0.6868 - recall: 0.8265 - precision: 0.8339 - auc: 0.9444 - val_loss: 0.3251 - val_dice_coef: 0.6749 - val_iou: 0.5195 - val_recall: 0.6222 - val_precision: 0.8261 - val_auc: 0.8597 - lr: 1.0000e-04
# Epoch 13/50
# 167/168 [============================>.] - ETA: 0s - loss: 0.1793 - dice_coef: 0.8207 - iou: 0.6976 - recall: 0.8324 - precision: 0.8384 - auc: 0.9442
# Epoch 13: val_loss improved from 0.31897 to 0.30678, saving model to /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//trained_models/model.h5
# 168/168 [==============================] - 10s 57ms/step - loss: 0.1795 - dice_coef: 0.8194 - iou: 0.6961 - recall: 0.8324 - precision: 0.8382 - auc: 0.9442 - val_loss: 0.3068 - val_dice_coef: 0.6932 - val_iou: 0.5396 - val_recall: 0.6785 - val_precision: 0.7832 - val_auc: 0.8773 - lr: 1.0000e-04
# Epoch 14/50
# 168/168 [==============================] - ETA: 0s - loss: 0.1747 - dice_coef: 0.8246 - iou: 0.7032 - recall: 0.8338 - precision: 0.8413 - auc: 0.9427
# Epoch 14: val_loss did not improve from 0.30678
# 168/168 [==============================] - 9s 52ms/step - loss: 0.1747 - dice_coef: 0.8246 - iou: 0.7032 - recall: 0.8338 - precision: 0.8413 - auc: 0.9427 - val_loss: 0.3278 - val_dice_coef: 0.6722 - val_iou: 0.5160 - val_recall: 0.6245 - val_precision: 0.8077 - val_auc: 0.8569 - lr: 1.0000e-04
# Epoch 15/50
# 167/168 [============================>.] - ETA: 0s - loss: 0.1676 - dice_coef: 0.8324 - iou: 0.7142 - recall: 0.8381 - precision: 0.8470 - auc: 0.9429
# Epoch 15: val_loss did not improve from 0.30678
# 168/168 [==============================] - 9s 51ms/step - loss: 0.1677 - dice_coef: 0.8317 - iou: 0.7133 - recall: 0.8382 - precision: 0.8469 - auc: 0.9429 - val_loss: 0.3281 - val_dice_coef: 0.6719 - val_iou: 0.5155 - val_recall: 0.6196 - val_precision: 0.8102 - val_auc: 0.8537 - lr: 1.0000e-04
# Epoch 16/50
# 168/168 [==============================] - ETA: 0s - loss: 0.1605 - dice_coef: 0.8389 - iou: 0.7239 - recall: 0.8438 - precision: 0.8540 - auc: 0.9437
# Epoch 16: val_loss did not improve from 0.30678
# 168/168 [==============================] - 9s 51ms/step - loss: 0.1605 - dice_coef: 0.8389 - iou: 0.7239 - recall: 0.8438 - precision: 0.8540 - auc: 0.9437 - val_loss: 0.3653 - val_dice_coef: 0.6347 - val_iou: 0.4801 - val_recall: 0.5754 - val_precision: 0.8178 - val_auc: 0.8285 - lr: 1.0000e-04
# Epoch 17/50
# 168/168 [==============================] - ETA: 0s - loss: 0.1549 - dice_coef: 0.8446 - iou: 0.7323 - recall: 0.8484 - precision: 0.8591 - auc: 0.9445
# Epoch 17: val_loss did not improve from 0.30678
# 168/168 [==============================] - 9s 51ms/step - loss: 0.1549 - dice_coef: 0.8446 - iou: 0.7323 - recall: 0.8484 - precision: 0.8591 - auc: 0.9445 - val_loss: 0.3637 - val_dice_coef: 0.6363 - val_iou: 0.4806 - val_recall: 0.5739 - val_precision: 0.8219 - val_auc: 0.8243 - lr: 1.0000e-04
# Epoch 18/50
# 168/168 [==============================] - ETA: 0s - loss: 0.1504 - dice_coef: 0.8492 - iou: 0.7391 - recall: 0.8498 - precision: 0.8642 - auc: 0.9442
# Epoch 18: val_loss did not improve from 0.30678
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 168/168 [==============================] - 9s 51ms/step - loss: 0.1504 - dice_coef: 0.8492 - iou: 0.7391 - recall: 0.8498 - precision: 0.8642 - auc: 0.9442 - val_loss: 0.3428 - val_dice_coef: 0.6572 - val_iou: 0.5030 - val_recall: 0.5977 - val_precision: 0.8222 - val_auc: 0.8321 - lr: 1.0000e-04
# Epoch 19/50
# 167/168 [============================>.] - ETA: 0s - loss: 0.1472 - dice_coef: 0.8528 - iou: 0.7444 - recall: 0.8526 - precision: 0.8661 - auc: 0.9447
# Epoch 19: val_loss did not improve from 0.30678
# 168/168 [==============================] - 9s 52ms/step - loss: 0.1473 - dice_coef: 0.8524 - iou: 0.7439 - recall: 0.8526 - precision: 0.8661 - auc: 0.9447 - val_loss: 0.3157 - val_dice_coef: 0.6843 - val_iou: 0.5313 - val_recall: 0.6112 - val_precision: 0.8417 - val_auc: 0.8446 - lr: 1.0000e-05
# Epoch 20/50
# 167/168 [============================>.] - ETA: 0s - loss: 0.1384 - dice_coef: 0.8616 - iou: 0.7578 - recall: 0.8600 - precision: 0.8756 - auc: 0.9477
# Epoch 20: val_loss did not improve from 0.30678
# 168/168 [==============================] - 9s 51ms/step - loss: 0.1384 - dice_coef: 0.8612 - iou: 0.7573 - recall: 0.8600 - precision: 0.8755 - auc: 0.9477 - val_loss: 0.3175 - val_dice_coef: 0.6825 - val_iou: 0.5290 - val_recall: 0.6063 - val_precision: 0.8454 - val_auc: 0.8421 - lr: 1.0000e-05
# Epoch 21/50
# 167/168 [============================>.] - ETA: 0s - loss: 0.1333 - dice_coef: 0.8667 - iou: 0.7657 - recall: 0.8639 - precision: 0.8813 - auc: 0.9490
# Epoch 21: val_loss did not improve from 0.30678
# 168/168 [==============================] - 9s 51ms/step - loss: 0.1334 - dice_coef: 0.8663 - iou: 0.7652 - recall: 0.8639 - precision: 0.8812 - auc: 0.9490 - val_loss: 0.3220 - val_dice_coef: 0.6780 - val_iou: 0.5238 - val_recall: 0.5987 - val_precision: 0.8475 - val_auc: 0.8388 - lr: 1.0000e-05
# Epoch 22/50
# 167/168 [============================>.] - ETA: 0s - loss: 0.1292 - dice_coef: 0.8708 - iou: 0.7721 - recall: 0.8672 - precision: 0.8858 - auc: 0.9500
# Epoch 22: val_loss did not improve from 0.30678
# 168/168 [==============================] - 9s 51ms/step - loss: 0.1293 - dice_coef: 0.8705 - iou: 0.7716 - recall: 0.8672 - precision: 0.8857 - auc: 0.9500 - val_loss: 0.3234 - val_dice_coef: 0.6766 - val_iou: 0.5220 - val_recall: 0.5968 - val_precision: 0.8480 - val_auc: 0.8376 - lr: 1.0000e-05
# Epoch 23/50
# 167/168 [============================>.] - ETA: 0s - loss: 0.1256 - dice_coef: 0.8744 - iou: 0.7777 - recall: 0.8699 - precision: 0.8900 - auc: 0.9508
# Epoch 23: val_loss did not improve from 0.30678
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1e-06.
# 168/168 [==============================] - 9s 51ms/step - loss: 0.1256 - dice_coef: 0.8741 - iou: 0.7773 - recall: 0.8700 - precision: 0.8900 - auc: 0.9508 - val_loss: 0.3264 - val_dice_coef: 0.6736 - val_iou: 0.5187 - val_recall: 0.5923 - val_precision: 0.8481 - val_auc: 0.8353 - lr: 1.0000e-05

# %% [markdown]
# ### Evaluating the Model:

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import pandas as pd
import cv2
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import accuracy_score, f1_score, jaccard_score, precision_score, recall_score
from tensorflow.keras.models import load_model

# %%
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.float32)
    return ori_x, x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.int32)
    return ori_x, x

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.png")))
    y = sorted(glob(os.path.join(path, "mask", "*.png")))
    return x, y

def save_results(ori_x, ori_y, y_pred, save_image_path):
    line = np.ones((H, 10, 3)) * 255

    ori_y = np.expand_dims(ori_y, axis=-1)
    ori_y = np.concatenate([ori_y, ori_y, ori_y], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1) * 255

    cat_images = np.concatenate([ori_x, line, ori_y, line, y_pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)

# %%
import glob
supported_extensions = ["png", "jpg", "tif", "jpeg", "gif", "bmp"]

def image_files(path, file_prefix=None):
    all_image_files = []
    # print("path", path)
    # print("file_prefix", file_prefix)
    if file_prefix is None:
        file_names = list(glob.glob(path + "/*.*" ))
    else:
        prefix___ = path + "/" + file_prefix + ".*"
        #print("prefix", prefix___)
        file_names = list(glob.glob(prefix___))

    # print("filenames", file_names)

    for filename in file_names:
        ext = filename.rsplit(".", 1)[1]
        if ext.lower() in supported_extensions:
            all_image_files.append(filename)
    # print("All Image files", all_image_files)
    return sorted(all_image_files)

# %%
results_path = f"{root_path}/results/"
prediction_path = f"{root_path}/predictions/"
prediction_np_path = f"{root_path}/predictions_np/"
create_dir(prediction_path)
create_dir(prediction_np_path)
create_dir(results_path)

# %%
results_path
# Out:
# '/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//results/'

# %%
from glob import glob

# %%
from copy import deepcopy
from sklearn.metrics import roc_auc_score
# prediction_path = "predictions"

""" Save the results in this folder """
# create_dir("results_sunil_test")
# create_dir(prediction_path)

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model_path = os.path.join(f"{model_dir}", "model.h5")

model = load_model(model_path, compile=False)

""" Load the dataset """
dataset_path = os.path.join(f"{data_path}/{split_name}", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)
    y = y.astype(np.int)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    np.save(f"{prediction_np_path}/{name}.npy", y_pred)
    y_prob = deepcopy(y_pred).flatten()
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"{results_path}/{name}.png"
#    print(ori_x.shape, ori_y.shape, y_pred.shape)
    save_results(ori_x, ori_y, y_pred, save_image_path)
    cv2.imwrite(f"{prediction_path}/{name}.png", y_pred * 255)
    

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    if np.sum(y) == 0 or np.sum(y) == H * W:
        auc_value = 1
    else:
        auc_value = roc_auc_score(y, y_prob)
    dice_value = dice_coef(y.astype(np.float64), y_prob)

    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value, auc_value, dice_value])

score = [s[1:] for s in SCORE]
score = np.mean(score, axis=0)
print(f"Accuracy: {score[0]:0.5f}")
print(f"F1: {score[1]:0.5f}")
print(f"Jaccard: {score[2]:0.5f}")
print(f"Recall: {score[3]:0.5f}")
print(f"Precision: {score[4]:0.5f}")
print(f"AUC: {score[5]:0.5f}")
print(f"Dice Coeff: {score[6]:0.5f}")
""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision", "AUC", "Dice Coeff"])
df.to_csv(f"{results_path}/score.csv")
# Out:
#   0%|          | 0/296 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#   0%|          | 1/296 [00:00<02:22,  2.07it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   1%|          | 3/296 [00:00<00:52,  5.55it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#   2%|▏         | 5/296 [00:00<00:35,  8.09it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#   2%|▏         | 7/296 [00:00<00:30,  9.52it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   3%|▎         | 9/296 [00:01<00:27, 10.31it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   4%|▎         | 11/296 [00:01<00:25, 10.98it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   4%|▍         | 13/296 [00:01<00:23, 11.80it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#   5%|▌         | 15/296 [00:01<00:22, 12.34it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   6%|▌         | 17/296 [00:01<00:22, 12.66it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   6%|▋         | 19/296 [00:01<00:22, 12.48it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   7%|▋         | 21/296 [00:02<00:22, 12.42it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#   8%|▊         | 23/296 [00:02<00:21, 12.70it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#   8%|▊         | 25/296 [00:02<00:21, 12.81it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   9%|▉         | 27/296 [00:02<00:20, 12.95it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  10%|▉         | 29/296 [00:02<00:21, 12.64it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  10%|█         | 31/296 [00:02<00:21, 12.50it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  11%|█         | 33/296 [00:02<00:20, 12.79it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  12%|█▏        | 35/296 [00:03<00:20, 12.91it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  12%|█▎        | 37/296 [00:03<00:19, 12.96it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  13%|█▎        | 39/296 [00:03<00:20, 12.62it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  14%|█▍        | 41/296 [00:03<00:20, 12.60it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  15%|█▍        | 43/296 [00:03<00:19, 12.69it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  15%|█▌        | 45/296 [00:03<00:19, 12.71it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  16%|█▌        | 47/296 [00:04<00:19, 12.78it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  17%|█▋        | 49/296 [00:04<00:19, 12.65it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  17%|█▋        | 51/296 [00:04<00:19, 12.89it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  18%|█▊        | 53/296 [00:04<00:18, 13.03it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  19%|█▊        | 55/296 [00:04<00:18, 12.89it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  95%|█████████▍| 281/296 [00:22<00:01, 12.61it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#  96%|█████████▌| 283/296 [00:22<00:01, 12.52it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  96%|█████████▋| 285/296 [00:22<00:00, 12.74it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  97%|█████████▋| 287/296 [00:23<00:00, 12.50it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  98%|█████████▊| 289/296 [00:23<00:00, 12.59it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  98%|█████████▊| 291/296 [00:23<00:00, 12.63it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1580: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, "true nor predicted", "F-score is", len(true_sum))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Jaccard is ill-defined and being set to 0.0 due to no true or predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  99%|█████████▉| 293/296 [00:23<00:00, 12.85it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 100%|█████████▉| 295/296 [00:23<00:00, 12.97it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# 100%|██████████| 296/296 [00:23<00:00, 12.43it/s]
# Accuracy: 0.96841
# F1: 0.42732
# Jaccard: 0.33613
# Recall: 0.41827
# Precision: 0.51050
# AUC: 0.84659
# Dice Coeff: 0.42109

# %% [markdown]
# # Reconstruct original image

# %%
prediction_np_path
# Out:
# '/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/'

# %%
from glob import glob

# %%
# Create patches dictionary
predicted_patches_dict = dict()
for file in glob(f"{prediction_np_path}/*.npy"):
    print("file", file)
    patch = np.load(file)
    fname_without_ext = file.rsplit("/", 1)[1].rsplit(".", 1)[0]
    fname_without_ext = fname_without_ext[1:]
    patch_number = int(fname_without_ext.rsplit("_", 1)[1])
    image_file = fname_without_ext.rsplit("_", 1)[0]
    print(image_file, patch_number )

    if image_file in predicted_patches_dict.keys():
        predicted_patches_dict[image_file][patch_number] = np.load(file)
    else:
        patches = [None] * 140
        patches[patch_number] = np.load(file)
        predicted_patches_dict[image_file] = patches
# Out:
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_5.npy
# Image_11L 5
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_53.npy
# Image_13L 53
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_34.npy
# Image_11R 34
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_58.npy
# Image_11L 58
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_9.npy
# Image_12L 9
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_33.npy
# Image_11R 33
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_54.npy
# Image_11L 54
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_59.npy
# Image_11R 59
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_34.npy
# Image_12R 34
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_53.npy
# Image_11L 53
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_13.npy
# Image_11L 13
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_51.npy
# Image_12L 51
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_52.npy
# Image_12L 52
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_44.npy
# Image_12R 44
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_36.npy
# Image_12R 36
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_2.npy
# Image_11L 2
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_9.npy
# Image_12R 9
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_42.npy
# Image_12L 42
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_48.npy
# Image_11L 48
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_24.npy
# Image_11R 24
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_6.npy
# Image_11R 6
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_56.npy
# Image_12L 56
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_50.npy
# Image_13L 50
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_18.npy
# Image_12L 18
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_15.npy
# Image_13L 15
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_1.npy
# Image_11L 1
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_7.npy
# Image_11L 7
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_44.npy
# Image_12L 44
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_55.npy
# Image_13L 55
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_17.npy
# Image_11L 17
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_27.npy
# Image_12L 27
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_39.npy
# Image_11L 39
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_28.npy
# Image_12R 28
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_17.npy
# Image_11R 17
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_6.npy
# Image_11L 6
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_29.npy
# Image_12L 29
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_24.npy
# Image_12R 24
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_31.npy
# Image_11R 31
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_21.npy
# Image_11L 21
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_18.npy
# Image_11R 18
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_37.npy
# Image_11R 37
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_49.npy
# Image_11R 49
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_33.npy
# Image_11L 33
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_49.npy
# Image_13L 49
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_21.npy
# Image_11R 21
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_27.npy
# Image_11R 27
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_2.npy
# Image_13L 2
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_20.npy
# Image_11L 20
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_25.npy
# Image_11L 25
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_14.npy
# Image_11R 14
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_41.npy
# Image_12R 41
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_2.npy
# Image_12L 2
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_5.npy
# Image_11R 5
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_23.npy
# Image_11L 23
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_58.npy
# Image_12L 58
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_36.npy
# Image_13L 36
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_20.npy
# Image_12R 20
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_43.npy
# Image_11R 43
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_31.npy
# Image_11L 31
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_22.npy
# Image_13L 22
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_49.npy
# Image_12R 49
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_45.npy
# Image_11L 45
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_52.npy
# Image_12R 52
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_50.npy
# Image_11L 50
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_29.npy
# Image_11L 29
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_37.npy
# Image_12L 37
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_12.npy
# Image_11L 12
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_38.npy
# Image_11L 38
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_14.npy
# Image_13L 14
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_32.npy
# Image_12L 32
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_37.npy
# Image_12R 37
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_11.npy
# Image_11L 11
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_2.npy
# Image_11R 2
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_18.npy
# Image_11L 18
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_33.npy
# Image_12L 33
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_4.npy
# Image_11R 4
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_51.npy
# Image_12R 51
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_56.npy
# Image_11L 56
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_40.npy
# Image_11R 40
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_56.npy
# Image_13L 56
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_8.npy
# Image_12R 8
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_38.npy
# Image_13L 38
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_22.npy
# Image_11L 22
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_5.npy
# Image_13L 5
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_26.npy
# Image_13L 26
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_17.npy
# Image_12R 17
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_9.npy
# Image_13L 9
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_48.npy
# Image_12R 48
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_46.npy
# Image_12R 46
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_33.npy
# Image_12R 33
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_30.npy
# Image_11L 30
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_16.npy
# Image_11L 16
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_32.npy
# Image_11L 32
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_30.npy
# Image_11R 30
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_7.npy
# Image_13L 7
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_5.npy
# Image_12R 5
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_16.npy
# Image_12R 16
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_59.npy
# Image_12L 59
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_42.npy
# Image_12R 42
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_50.npy
# Image_12R 50
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_35.npy
# Image_12L 35
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_11.npy
# Image_11R 11
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_40.npy
# Image_12L 40
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_8.npy
# Image_12L 8
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_25.npy
# Image_12R 25
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_48.npy
# Image_11R 48
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_12.npy
# Image_12R 12
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_26.npy
# Image_11L 26
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_9.npy
# Image_11L 9
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_45.npy
# Image_12L 45
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_49.npy
# Image_11L 49
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_4.npy
# Image_11L 4
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_14.npy
# Image_11L 14
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_24.npy
# Image_11L 24
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_24.npy
# Image_12L 24
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_42.npy
# Image_13L 42
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_22.npy
# Image_12R 22
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_52.npy
# Image_13L 52
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_36.npy
# Image_12L 36
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_54.npy
# Image_11R 54
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_43.npy
# Image_12R 43
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_27.npy
# Image_11L 27
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_23.npy
# Image_11R 23
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_54.npy
# Image_13L 54
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_11.npy
# Image_12L 11
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_31.npy
# Image_12L 31
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_54.npy
# Image_12L 54
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_20.npy
# Image_13L 20
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_13.npy
# Image_11R 13
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_1.npy
# Image_13L 1
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_13.npy
# Image_12L 13
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_39.npy
# Image_13L 39
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_14.npy
# Image_12R 14
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_50.npy
# Image_11R 50
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_46.npy
# Image_13L 46
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_15.npy
# Image_12R 15
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_26.npy
# Image_12L 26
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_39.npy
# Image_12R 39
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_29.npy
# Image_13L 29
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_35.npy
# Image_11L 35
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_10.npy
# Image_11R 10
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_36.npy
# Image_11R 36
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_10.npy
# Image_12R 10
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_3.npy
# Image_11R 3
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_59.npy
# Image_11L 59
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_27.npy
# Image_12R 27
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_10.npy
# Image_12L 10
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_41.npy
# Image_11R 41
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_46.npy
# Image_11R 46
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_47.npy
# Image_12R 47
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_37.npy
# Image_11L 37
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_14.npy
# Image_12L 14
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_28.npy
# Image_12L 28
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_43.npy
# Image_12L 43
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_55.npy
# Image_12R 55
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_52.npy
# Image_11L 52
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_38.npy
# Image_11R 38
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_31.npy
# Image_13L 31
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_28.npy
# Image_13L 28
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_35.npy
# Image_11R 35
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_35.npy
# Image_12R 35
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_34.npy
# Image_13L 34
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_24.npy
# Image_13L 24
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_52.npy
# Image_11R 52
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_11.npy
# Image_12R 11
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_10.npy
# Image_13L 10
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_7.npy
# Image_12R 7
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_0.npy
# Image_13L 0
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_19.npy
# Image_12R 19
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_41.npy
# Image_12L 41
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_3.npy
# Image_11L 3
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_12.npy
# Image_11R 12
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_49.npy
# Image_12L 49
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_3.npy
# Image_12R 3
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_4.npy
# Image_12L 4
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_34.npy
# Image_11L 34
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_40.npy
# Image_11L 40
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_7.npy
# Image_11R 7
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_2.npy
# Image_12R 2
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_13.npy
# Image_13L 13
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_19.npy
# Image_12L 19
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_29.npy
# Image_11R 29
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_0.npy
# Image_12R 0
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_58.npy
# Image_11R 58
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_36.npy
# Image_11L 36
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_47.npy
# Image_12L 47
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_44.npy
# Image_13L 44
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_12.npy
# Image_12L 12
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_7.npy
# Image_12L 7
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_46.npy
# Image_12L 46
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_26.npy
# Image_12R 26
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_45.npy
# Image_13L 45
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_19.npy
# Image_11R 19
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_25.npy
# Image_13L 25
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_15.npy
# Image_11R 15
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_13.npy
# Image_12R 13
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_18.npy
# Image_12R 18
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_35.npy
# Image_13L 35
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_55.npy
# Image_12L 55
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_0.npy
# Image_11L 0
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_51.npy
# Image_13L 51
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_6.npy
# Image_12L 6
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_3.npy
# Image_13L 3
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_31.npy
# Image_12R 31
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_44.npy
# Image_11L 44
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_6.npy
# Image_12R 6
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_42.npy
# Image_11R 42
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_39.npy
# Image_11R 39
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_37.npy
# Image_13L 37
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_55.npy
# Image_11R 55
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_17.npy
# Image_13L 17
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_25.npy
# Image_12L 25
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_53.npy
# Image_12R 53
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_53.npy
# Image_12L 53
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_21.npy
# Image_12R 21
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_6.npy
# Image_13L 6
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_29.npy
# Image_12R 29
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_16.npy
# Image_12L 16
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_4.npy
# Image_12R 4
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_10.npy
# Image_11L 10
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_41.npy
# Image_11L 41
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_41.npy
# Image_13L 41
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_4.npy
# Image_13L 4
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_16.npy
# Image_11R 16
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_15.npy
# Image_11L 15
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_48.npy
# Image_13L 48
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_28.npy
# Image_11R 28
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_23.npy
# Image_12R 23
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_11.npy
# Image_13L 11
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_8.npy
# Image_11R 8
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_39.npy
# Image_12L 39
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_40.npy
# Image_13L 40
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_19.npy
# Image_11L 19
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_34.npy
# Image_12L 34
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_30.npy
# Image_12L 30
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_56.npy
# Image_11R 56
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_0.npy
# Image_11R 0
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_42.npy
# Image_11L 42
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_56.npy
# Image_12R 56
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_16.npy
# Image_13L 16
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_58.npy
# Image_12R 58
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_55.npy
# Image_11L 55
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_18.npy
# Image_13L 18
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_45.npy
# Image_12R 45
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_43.npy
# Image_11L 43
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_5.npy
# Image_12L 5
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_30.npy
# Image_12R 30
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_20.npy
# Image_12L 20
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_17.npy
# Image_12L 17
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_21.npy
# Image_12L 21
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_53.npy
# Image_11R 53
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_23.npy
# Image_13L 23
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_22.npy
# Image_12L 22
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_1.npy
# Image_12L 1
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_43.npy
# Image_13L 43
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_51.npy
# Image_11L 51
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_19.npy
# Image_13L 19
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_21.npy
# Image_13L 21
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_38.npy
# Image_12L 38
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_1.npy
# Image_12R 1
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_48.npy
# Image_12L 48
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_12.npy
# Image_13L 12
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_15.npy
# Image_12L 15
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_30.npy
# Image_13L 30
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_28.npy
# Image_11L 28
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_50.npy
# Image_12L 50
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_51.npy
# Image_11R 51
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_25.npy
# Image_11R 25
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_1.npy
# Image_11R 1
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_27.npy
# Image_13L 27
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_3.npy
# Image_12L 3
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_47.npy
# Image_11L 47
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_54.npy
# Image_12R 54
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_32.npy
# Image_13L 32
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_57.npy
# Image_12R 57
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_9.npy
# Image_11R 9
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_26.npy
# Image_11R 26
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_23.npy
# Image_12L 23
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_57.npy
# Image_11L 57
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_46.npy
# Image_11L 46
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_45.npy
# Image_11R 45
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_20.npy
# Image_11R 20
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_57.npy
# Image_12L 57
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_47.npy
# Image_11R 47
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11L_8.npy
# Image_11L 8
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_33.npy
# Image_13L 33
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_47.npy
# Image_13L 47
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_38.npy
# Image_12R 38
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_40.npy
# Image_12R 40
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12R_32.npy
# Image_12R 32
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_13L_8.npy
# Image_13L 8
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_57.npy
# Image_11R 57
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_32.npy
# Image_11R 32
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_44.npy
# Image_11R 44
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_12L_0.npy
# Image_12L 0
# file /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//predictions_np/_Image_11R_22.npy
# Image_11R 22

# %%
reconstructed_predictions_path = f"{data_path}/{split_name}/reconstructed/{split}/predictions_reconstructed"
create_dir(reconstructed_predictions_path)
reconstruct_patches(predicted_patches_dict,
                    metadata_test_df,
                    reconstructed_predictions_path,
                    mfactor=255
                    )
# Out:
# /content/gdrive/MyDrive/medical_image_processing/patches.py:294: RuntimeWarning: invalid value encountered in true_divide
#   im[:, :, channel] = np.true_divide(im[:, :, channel], count_im)

# %%
# !pwd
# Out:
# /content/datasets

# %%
def read_mask(path):
    print(path)
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
#    x = x.astype(np.int32)
    return ori_x, x

# %%
def save_results(ori_x, ori_y, y_pred, save_image_path):
    line = np.ones((ori_x.shape[0], 10, 3)) * 255

    ori_y = np.expand_dims(ori_y, axis=-1)
    ori_y = np.concatenate([ori_y, ori_y, ori_y], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1) * 255

    cat_images = np.concatenate([ori_x, line, ori_y, line, y_pred], axis=1)
    print(f"Saving image of size {cat_images.shape} to {save_image_path}")
    cv2.imwrite(save_image_path, cat_images)

# %% [markdown]
# # Reconstruct original image

# %%
results_path_reconstructed_orig_size = f"{root_path}/results_reconstructed_orig_size/"
gt_path_reconstructed_orig_size = f"{root_path}/reconstructed_orig_size/mask/"
im_path_reconstructed_orig_size = f"{root_path}/reconstructed_orig_size/image/"

create_dir(results_path_reconstructed_orig_size)
create_dir(gt_path_reconstructed_orig_size)
create_dir(im_path_reconstructed_orig_size)

# %%
from patches import get_zero_padding_size
num_zero_padding_height, num_zero_padding_width = get_zero_padding_size(patch_size,
                                                                        image_sizes[dataset_name])
height_odd = 0 if (num_zero_padding_height % 2) == 0 else 1
width_odd = 0 if (num_zero_padding_width % 2) == 0 else 1

# %%
reconstructed_pred_files, _ = get_filenames_sorted(reconstructed_predictions_path)
print(len(reconstructed_pred_files))
print(reconstructed_pred_files[:5])
for reconstructed_pred_file in reconstructed_pred_files:
    im = cv2.imread(reconstructed_pred_file)
    name = reconstructed_pred_file.rsplit("/", 1)[1]
    im_cropped = im[num_zero_padding_height // 2 : - num_zero_padding_height // 2, num_zero_padding_width // 2 : -num_zero_padding_width //2 ]
    print(im.shape, im_cropped.shape)
    cv2.imwrite(f"{results_path_reconstructed_orig_size}/{name}", im_cropped)
# Out:
# 5
# ['/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//split_2/reconstructed/test/predictions_reconstructed/Image_11L.png', '/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//split_2/reconstructed/test/predictions_reconstructed/Image_11R.png', '/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//split_2/reconstructed/test/predictions_reconstructed/Image_12L.png', '/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//split_2/reconstructed/test/predictions_reconstructed/Image_12R.png', '/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//split_2/reconstructed/test/predictions_reconstructed/Image_13L.png']
# (1024, 1024, 3) (960, 999, 3)
# (1024, 1024, 3) (960, 999, 3)
# (1024, 1024, 3) (960, 999, 3)
# (1024, 1024, 3) (960, 999, 3)
# (1024, 1024, 3) (960, 999, 3)

# %%
gt_path_reconstructed = f"{root_path}/{split_name}/reconstructed/{split}/"

reconstructed_im_files, reconstructed_gt_files = get_filenames_sorted(f"{gt_path_reconstructed}/image/", f"{gt_path_reconstructed}/mask/" )
print(len(reconstructed_gt_files))
print(reconstructed_gt_files[:5])

for reconstructed_im_file, reconstructed_gt_file in zip(reconstructed_im_files, reconstructed_gt_files):
    gt = cv2.imread(reconstructed_gt_file)
    im = cv2.imread(reconstructed_im_file)
    name = reconstructed_gt_file.rsplit("/", 1)[1]
    gt_cropped = gt[num_zero_padding_height // 2 : - num_zero_padding_height // 2, num_zero_padding_width // 2 : -num_zero_padding_width //2 ]
    im_cropped = im[num_zero_padding_height // 2 : - num_zero_padding_height // 2, num_zero_padding_width // 2 : -num_zero_padding_width //2 ]
    print(im.shape, im_cropped.shape)
    print(gt.shape, gt_cropped.shape)

    cv2.imwrite(f"{gt_path_reconstructed_orig_size}/{name}", gt_cropped)
    cv2.imwrite(f"{im_path_reconstructed_orig_size}/{name}", im_cropped)
# Out:
# 5
# ['/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//split_2/reconstructed/test//mask/Image_11L.png', '/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//split_2/reconstructed/test//mask/Image_11R.png', '/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//split_2/reconstructed/test//mask/Image_12L.png', '/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//split_2/reconstructed/test//mask/Image_12R.png', '/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//split_2/reconstructed/test//mask/Image_13L.png']
# (1024, 1024, 3) (960, 999, 3)
# (1024, 1024, 3) (960, 999, 3)
# (1024, 1024, 3) (960, 999, 3)
# (1024, 1024, 3) (960, 999, 3)
# (1024, 1024, 3) (960, 999, 3)
# (1024, 1024, 3) (960, 999, 3)
# (1024, 1024, 3) (960, 999, 3)
# (1024, 1024, 3) (960, 999, 3)
# (1024, 1024, 3) (960, 999, 3)
# (1024, 1024, 3) (960, 999, 3)

# %%
results_path_reconstructed = f"{root_path}/results_reconstructed/"
create_dir(results_path_reconstructed)

# %%
from glob import glob

# %%
import tensorflow as tf
import cv2
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score, jaccard_score, recall_score, precision_score, roc_auc_score

from utils import read_image, read_mask
from utils import get_filenames_sorted
from tqdm import tqdm
from copy import deepcopy
from sklearn.metrics import confusion_matrix
def compute_metrics(data_path: str,
                    results_path: str,
                    threshold: float,
                    model=None,
                    predictions_path: str = None,
                    prediction_np_path=None):
    """ Make the prediction ( if model is not None) and calculate the metrics values. If model is None compute the
    metrics using predicted images present in location predictions_path
    data_path: Path location where images and ground truths are saved. Images should be saved in a folder data_path/image
     and ground truths should be saved at data_path/mask
    result_path: Path to directory where results should be saved

    """

    """ Load the dataset """
    test_x, test_y = get_filenames_sorted(f"{data_path}/image", f"{data_path}/mask")
    SCORE = []
    print("Threshold", threshold)
    print(len(test_x), len(test_y))
    for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):

        if model is None and predictions_path is None:
            raise Exception("Invalid input parameters. Both model and prediction_path can not be None")
        """ Extracting name """
        name = x.split("/")[-1].split(".")[0]

        """ Read the image and mask """
        ori_x, x = read_image(x)
        ori_y, y = read_mask(y)
        y = y.astype(np.int)
#        print(name)

        #     """ Prediction """
        if model != None:
            y_pred = model.predict(np.expand_dims(x, axis=0))[0]
        else:
 #           print("Reading predicted image from ", f"{predictions_path}/{name}.png")
            orig_y_pred, y_pred = read_mask(f"{predictions_path}/{name}.png")
#            print(y_pred.shape, np.max(orig_y_pred), np.min(orig_y_pred))
#        print(y_pred.shape, np.max(y_pred), np.min(y_pred))
        if prediction_np_path is not None:
            np.save(f"{prediction_np_path}/{name}.npy", y_pred)

        y_prob = deepcopy(y_pred).flatten()
        y_pred = y_pred > threshold
        y_pred = y_pred.astype(np.int32)
        y_pred = np.squeeze(y_pred)

        """ Saving the images """
        save_image_path = f"{results_path}/{name}.png"
 #       print(ori_x.shape, ori_y.shape, y_pred.shape)
        save_results(ori_x, ori_y, y_pred, save_image_path)

        if model is not None:
            cv2.imwrite(f"{predictions_path}/{name}.png", y_pred * 255)

        """ Flatten the array """
        y = y.flatten()
        y_pred = y_pred.flatten()

        """ Calculate the metrics """
        acc_value = accuracy_score(y, y_pred)
        f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
        jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
        recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
        precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
        confusion_metrics = confusion_matrix(y, y_pred, labels=[0, 1])
        if np.sum(y) == 0 or np.sum(y) == y.shape[0] :
            auc_value = 1
        else:
            auc_value = roc_auc_score(y, y_prob)
        dice_value = dice_coef(y.astype(np.float64), y_prob.astype(np.float64))
        SCORE.append([name, threshold, acc_value, f1_value, jac_value, recall_value, precision_value, auc_value, dice_value, confusion_metrics[0,0], confusion_metrics[0,1],confusion_metrics[1,0],confusion_metrics[1,1]])

    score = [s[1:] for s in SCORE]
    score = np.mean(score, axis=0)

    print(f"Threshold: {threshold:0.5f}")
    print(f"Accuracy: {score[1]:0.5f}")
    print(f"F1: {score[2]:0.5f}")
    print(f"Jaccard: {score[3]:0.5f}")
    print(f"Recall: {score[4]:0.5f}")
    print(f"Precision: {score[5]:0.5f}")
    print(f"AUC: {score[6]:0.5f}")
    print(f"Dice Coeff: {score[7]:0.5f}")


    """ Saving """
    df = pd.DataFrame(SCORE, columns=["Image","Threshold", "Acc", "F1", "Jaccard", "Recall", "Precision", "AUC", "Dice Coef", "TN", "FP","FN","TP"])
    threshold_str = str(threshold).replace(".", "_")
    df.to_csv(f"{results_path}/score_full_{threshold_str}.csv")
    return df, score

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 

dataset_path = f"{root_path}/reconstructed_orig_size/"
df = dict()
score = dict()
for threshold in range(4,7):
    df[threshold], score[threshold] = compute_metrics(dataset_path,
                        results_path=results_path_reconstructed,
                        threshold = threshold / 10,
                        model=None,
                        predictions_path=results_path_reconstructed_orig_size,
                        prediction_np_path=None)
# Out:
# Threshold 0.4
# 5 5
#   0%|          | 0/5 [00:00<?, ?it/s]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//results_reconstructed//Image_11L.png
#  20%|██        | 1/5 [00:01<00:06,  1.72s/it]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//results_reconstructed//Image_11R.png
#  40%|████      | 2/5 [00:03<00:05,  1.73s/it]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//results_reconstructed//Image_12L.png
#  60%|██████    | 3/5 [00:05<00:03,  1.71s/it]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//results_reconstructed//Image_12R.png
#  80%|████████  | 4/5 [00:06<00:01,  1.72s/it]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//results_reconstructed//Image_13L.png
# 100%|██████████| 5/5 [00:08<00:00,  1.72s/it]
# Threshold: 0.40000
# Accuracy: 0.96751
# F1: 0.68888
# Jaccard: 0.53070
# Recall: 0.59381
# Precision: 0.84052
# AUC: 0.79301
# Dice Coeff: 0.68888
# Threshold 0.5
# 5 5
#   0%|          | 0/5 [00:00<?, ?it/s]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//results_reconstructed//Image_11L.png
#  20%|██        | 1/5 [00:01<00:06,  1.69s/it]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//results_reconstructed//Image_11R.png
#  40%|████      | 2/5 [00:03<00:05,  1.71s/it]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//results_reconstructed//Image_12L.png
#  60%|██████    | 3/5 [00:05<00:03,  1.70s/it]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//results_reconstructed//Image_12R.png
#  80%|████████  | 4/5 [00:06<00:01,  1.72s/it]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//results_reconstructed//Image_13L.png
# 100%|██████████| 5/5 [00:08<00:00,  1.70s/it]
# Threshold: 0.50000
# Accuracy: 0.96751
# F1: 0.68888
# Jaccard: 0.53070
# Recall: 0.59381
# Precision: 0.84052
# AUC: 0.79301
# Dice Coeff: 0.68888
# Threshold 0.6
# 5 5
#   0%|          | 0/5 [00:00<?, ?it/s]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//results_reconstructed//Image_11L.png
#  20%|██        | 1/5 [00:01<00:06,  1.70s/it]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//results_reconstructed//Image_11R.png
#  40%|████      | 2/5 [00:03<00:05,  1.73s/it]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//results_reconstructed//Image_12L.png
#  60%|██████    | 3/5 [00:05<00:03,  1.72s/it]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//results_reconstructed//Image_12R.png
#  80%|████████  | 4/5 [00:06<00:01,  1.72s/it]
# Saving image of size (960, 3017, 3) to /content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//results_reconstructed//Image_13L.png
# 100%|██████████| 5/5 [00:08<00:00,  1.71s/it]
# Threshold: 0.60000
# Accuracy: 0.96751
# F1: 0.68888
# Jaccard: 0.53070
# Recall: 0.59381
# Precision: 0.84052
# AUC: 0.79301
# Dice Coeff: 0.68888

# %%
results_path_reconstructed
# Out:
# '/content/datasets/chase_db_128_128_dice_loss_0_4__0_4_1//results_reconstructed/'

# %%
# !ls
# Out:
# chase_db_128_128_dice_loss_0_4__0_4_1  logs

# %%
folder_name = root_path.split("/")[3]
print(folder_name)
# Out:
# chase_db_128_128_dice_loss_0_4__0_4_1

# %%
# !zip -r {folder_name}.zip  {folder_name}/
# Out:
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/ (stored 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/test/ (stored 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/test/1st_manual/ (stored 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/test/1st_manual/Image_12R_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/test/1st_manual/Image_12L_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/test/1st_manual/Image_11R_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/test/1st_manual/Image_13L_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/test/1st_manual/Image_11L_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/test/images/ (stored 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/test/images/Image_12R.jpg (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/test/images/Image_11L.jpg (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/test/images/Image_11R.jpg (deflated 7%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/test/images/Image_13L.jpg (deflated 8%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/test/images/Image_12L.jpg (deflated 7%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/ (stored 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/ (stored 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/ (stored 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_1.png (deflated 5%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_55.png (deflated 8%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_39.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_15.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_6.png (deflated 38%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_40.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_23.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_21.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_53.png (deflated 67%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_24.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_32.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_58.png (deflated 65%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_38.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_59.png (deflated 67%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_3.png (deflated 5%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_56.png (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_30.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_8.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_31.png (deflated 5%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_19.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_31.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_34.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_57.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_56.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_16.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_37.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_58.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_37.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_0.png (deflated 42%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_45.png (deflated 34%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_53.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_16.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_3.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_19.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_24.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_57.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_20.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_20.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_58.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_24.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_22.png (deflated 7%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_46.png (deflated 30%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_47.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_51.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_56.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_34.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_43.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_35.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_22.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_18.png (deflated 5%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_52.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_16.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_53.png (deflated 40%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_32.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_36.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_44.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_21.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_10.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_7.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_38.png (deflated 8%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_41.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_50.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_42.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_45.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_18.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_49.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_30.png (deflated 9%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_12.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_41.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_50.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_0.png (deflated 42%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_11.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_45.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_44.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_32.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_29.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_0.png (deflated 47%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_3.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_58.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_54.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_42.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_39.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_33.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_41.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_19.png (deflated 8%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_40.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_13.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_51.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_12.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_46.png (deflated 24%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_5.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_4.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_25.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_21.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_11.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_18.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_5.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_17.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_7.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_23.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_7.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_33.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_7.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_6.png (deflated 26%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_36.png (deflated 9%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_56.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_28.png (deflated 10%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_6.png (deflated 37%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_4.png (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_4.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_1.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_30.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_20.png (deflated 5%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_46.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_2.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_17.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_36.png (deflated 5%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_25.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_47.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_25.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_13.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_43.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_32.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_28.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_11.png (deflated 5%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_33.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_15.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_19.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_4.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_26.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_42.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_2.png (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_49.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_36.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_24.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_39.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_57.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_51.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_38.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_34.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_3.png (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_8.png (deflated 7%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_2.png (deflated 8%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_48.png (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_30.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_35.png (deflated 8%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_49.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_12.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_22.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_14.png (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_49.png (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_42.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_55.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_32.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_26.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_37.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_1.png (deflated 5%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_29.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_40.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_54.png (deflated 42%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_34.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_55.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_50.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_5.png (deflated 65%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_41.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_51.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_23.png (deflated 7%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_14.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_28.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_48.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_21.png (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_52.png (deflated 46%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_9.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_2.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_39.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_23.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_25.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_25.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_5.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_1.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_9.png (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_14.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_59.png (deflated 65%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_13.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_0.png (deflated 42%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_15.png (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_0.png (deflated 40%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_48.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_23.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_13.png (deflated 67%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_21.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_2.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_8.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_34.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_31.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_35.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_39.png (deflated 7%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_56.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_9.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_15.png (deflated 5%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_28.png (deflated 5%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_40.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_46.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_8.png (deflated 5%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_38.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_14.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_29.png (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_10.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_16.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_35.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_17.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_12.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_17.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_52.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_1.png (deflated 7%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_33.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_10.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_6.png (deflated 26%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_27.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_24.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_27.png (deflated 9%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_14.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_11.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_12.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_42.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_57.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_10.png (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_5.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_30.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_18.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_4.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_46.png (deflated 32%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_44.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_44.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_20.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_9.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_47.png (deflated 8%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_40.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_59.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_55.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_51.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_36.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_27.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_33.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_18.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_7.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_45.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_52.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_47.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_22.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_22.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_54.png (deflated 42%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_26.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_54.png (deflated 8%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_27.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_41.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_37.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_27.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_20.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_35.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_6.png (deflated 30%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_31.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_17.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_48.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_19.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_43.png (deflated 8%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_37.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_9.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_10.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_43.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_29.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_15.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_45.png (deflated 35%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_38.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_50.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_48.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_50.png (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_16.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_55.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_44.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_49.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_3.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_8.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_53.png (deflated 7%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_28.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_43.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_53.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_26.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_47.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_54.png (deflated 40%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_26.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_52.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_11.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_29.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_13.png (deflated 67%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_31.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/ (stored 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_1.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_55.png (deflated 38%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_39.png (deflated 25%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_15.png (deflated 13%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_6.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_40.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_23.png (deflated 7%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_21.png (deflated 56%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_53.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_24.png (deflated 11%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_32.png (deflated 5%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_58.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_38.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_59.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_3.png (deflated 55%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_56.png (deflated 42%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_30.png (deflated 40%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_8.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_31.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_19.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_31.png (deflated 26%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_34.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_57.png (deflated 13%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_56.png (deflated 17%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_16.png (deflated 17%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_37.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_58.png (deflated 56%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_37.png (deflated 43%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_0.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_45.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_53.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_16.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_3.png (deflated 26%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_19.png (deflated 9%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_24.png (deflated 10%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_57.png (deflated 47%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_20.png (deflated 55%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_20.png (deflated 11%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_58.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_24.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_22.png (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_46.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_47.png (deflated 32%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_51.png (deflated 15%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_56.png (deflated 39%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_34.png (deflated 5%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_43.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_35.png (deflated 11%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_22.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_18.png (stored 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_52.png (deflated 10%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_16.png (stored 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_53.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_32.png (stored 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_36.png (deflated 11%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_44.png (deflated 54%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_21.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_10.png (deflated 10%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_7.png (deflated 18%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_38.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_41.png (deflated 7%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_50.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_42.png (stored 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_45.png (deflated 45%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_18.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_49.png (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_30.png (deflated 30%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_12.png (deflated 45%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_41.png (deflated 17%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_50.png (deflated 26%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_0.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_11.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_45.png (deflated 43%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_44.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_32.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_29.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_0.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_3.png (deflated 14%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_58.png (deflated 28%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_54.png (deflated 27%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_42.png (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_39.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_33.png (deflated 7%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_41.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_19.png (deflated 20%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_40.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_13.png (deflated 32%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_51.png (deflated 16%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_12.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_46.png (deflated 64%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_5.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_4.png (deflated 44%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_25.png (deflated 5%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_21.png (deflated 15%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_11.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_18.png (deflated 14%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_5.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_17.png (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_7.png (deflated 23%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_23.png (deflated 8%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_7.png (deflated 11%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_33.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_7.png (deflated 26%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_6.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_36.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_56.png (deflated 17%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_28.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_6.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_4.png (deflated 60%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_4.png (deflated 32%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_1.png (deflated 20%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_30.png (deflated 16%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_20.png (deflated 35%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_46.png (deflated 24%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_2.png (deflated 15%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_17.png (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_36.png (deflated 16%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_25.png (deflated 17%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_47.png (deflated 12%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_25.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_13.png (deflated 26%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_43.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_32.png (deflated 15%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_28.png (deflated 19%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_11.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_33.png (deflated 12%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_15.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_19.png (deflated 5%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_4.png (deflated 39%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_26.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_42.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_2.png (deflated 43%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_49.png (deflated 9%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_36.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_24.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_39.png (deflated 36%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_57.png (deflated 30%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_51.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_38.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_34.png (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_3.png (deflated 16%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_8.png (deflated 12%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_2.png (deflated 26%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_48.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_30.png (deflated 40%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_35.png (deflated 26%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_49.png (deflated 19%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_12.png (deflated 10%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_22.png (deflated 5%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_14.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_49.png (deflated 5%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_42.png (stored 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_55.png (deflated 46%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_32.png (deflated 5%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_26.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_37.png (deflated 24%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_1.png (deflated 33%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_29.png (deflated 51%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_40.png (deflated 17%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_54.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_34.png (deflated 5%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_55.png (deflated 62%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_50.png (deflated 8%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_5.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_41.png (deflated 9%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_51.png (stored 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_23.png (deflated 27%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_14.png (deflated 60%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_28.png (deflated 7%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_48.png (stored 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_21.png (deflated 22%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_52.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_9.png (deflated 8%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_2.png (deflated 48%)
# ...
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_13.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_21.png (deflated 40%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_2.png (deflated 16%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_8.png (deflated 7%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_34.png (deflated 8%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_31.png (deflated 10%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_35.png (deflated 22%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_39.png (deflated 4%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_56.png (deflated 28%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_9.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_15.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_28.png (deflated 40%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_40.png (deflated 32%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_46.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_8.png (deflated 7%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_38.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_14.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_29.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_10.png (deflated 13%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_16.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_35.png (deflated 28%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_17.png (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_12.png (deflated 15%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_17.png (deflated 12%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_52.png (deflated 14%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_1.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_33.png (deflated 7%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_10.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_6.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_27.png (deflated 44%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_24.png (deflated 12%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_27.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_14.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_11.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_12.png (deflated 16%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_42.png (stored 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_57.png (deflated 25%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_10.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_5.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_30.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_18.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_4.png (deflated 52%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_46.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_44.png (deflated 52%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_44.png (deflated 10%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_20.png (deflated 49%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_9.png (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_47.png (deflated 51%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_40.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_59.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_55.png (deflated 8%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_51.png (deflated 54%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_36.png (deflated 37%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_27.png (deflated 30%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_33.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_18.png (deflated 8%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_7.png (deflated 62%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_45.png (deflated 60%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_52.png (deflated 15%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_47.png (deflated 10%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_22.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_22.png (deflated 49%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_54.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_26.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_54.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_27.png (deflated 20%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_41.png (deflated 10%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_37.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_27.png (deflated 24%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_20.png (deflated 49%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_35.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_6.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_31.png (deflated 21%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_17.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_48.png (deflated 13%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_19.png (deflated 7%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_43.png (deflated 34%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_37.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_9.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_10.png (deflated 9%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_43.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_29.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_15.png (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_45.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_38.png (deflated 29%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_50.png (stored 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_48.png (deflated 17%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_50.png (deflated 49%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_16.png (deflated 20%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_55.png (deflated 28%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_44.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_49.png (deflated 1%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_3.png (deflated 17%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_8.png (deflated 18%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_53.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_28.png (deflated 55%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_43.png (deflated 5%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_53.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_26.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_47.png (deflated 49%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_54.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_26.png (deflated 8%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_52.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_11.png (deflated 3%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_29.png (deflated 45%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_13.png (deflated 66%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_31.png (deflated 57%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/reconstructed_orig_size/ (stored 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/reconstructed_orig_size/image/ (stored 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/reconstructed_orig_size/image/Image_11L.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/reconstructed_orig_size/image/Image_12L.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/reconstructed_orig_size/image/Image_12R.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/reconstructed_orig_size/image/Image_13L.png (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/reconstructed_orig_size/image/Image_11R.png (deflated 2%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/reconstructed_orig_size/mask/ (stored 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/reconstructed_orig_size/mask/Image_11L.png (deflated 30%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/reconstructed_orig_size/mask/Image_12L.png (deflated 32%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/reconstructed_orig_size/mask/Image_12R.png (deflated 31%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/reconstructed_orig_size/mask/Image_13L.png (deflated 32%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/reconstructed_orig_size/mask/Image_11R.png (deflated 34%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/ (stored 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/ (stored 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_02L_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_06R_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_09R_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_07L_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_13R_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_01L_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_10R_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_09L_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_14R_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_14L_1stHO.png (stored 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_05L_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_10L_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_01R_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_05R_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_04L_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_08L_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_06L_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_08R_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_04R_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_03L_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_07R_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_03R_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_02R_1stHO.png (deflated 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/ (stored 0%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_05L.jpg (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_07R.jpg (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_08R.jpg (deflated 9%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_04L.jpg (deflated 7%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_10R.jpg (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_07L.jpg (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_02R.jpg (deflated 7%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_09R.jpg (deflated 7%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_14L.jpg (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_04R.jpg (deflated 7%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_09L.jpg (deflated 8%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_03R.jpg (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_06L.jpg (deflated 7%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_13R.jpg (deflated 8%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_14R.jpg (deflated 8%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_06R.jpg (deflated 7%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_01L.jpg (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_08L.jpg (deflated 8%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_05R.jpg (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_10L.jpg (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_01R.jpg (deflated 7%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_02L.jpg (deflated 6%)
#   adding: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_03L.jpg (deflated 6%)

# %%
# !ls -ltrh
# Out:
# total 384M
# drwxr-xr-x  4 root root 4.0K Mar 28 04:50 logs
# drwxr-xr-x 12 root root 4.0K Mar 28 04:54 chase_db_128_128_dice_loss_0_4__0_4_1
# -rw-r--r--  1 root root 384M Mar 28 04:55 chase_db_128_128_dice_loss_0_4__0_4_1.zip

# %%
# !ls /content/gdrive/MyDrive/Blood_Vessel_Results/chase_patches/

# %%
# !cp {folder_name}.zip /content/gdrive/MyDrive/Blood_Vessel_Results/chase_patches/

# %%
# %cd /content/gdrive/MyDrive/Blood_Vessel_Results/chase_patches/
# Out:
# /content/gdrive/MyDrive/Blood_Vessel_Results/chase_patches

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/Blood_Vessel_Results/chase_patches

# %%
# !ls
# Out:
# chase_db_128_128_dice_loss_0_4__0_4_1.zip

# %%
# !unzip {folder_name}.zip
# Out:
# Archive:  chase_db_128_128_dice_loss_0_4__0_4_1.zip
#    creating: chase_db_128_128_dice_loss_0_4__0_4_1/
#    creating: chase_db_128_128_dice_loss_0_4__0_4_1/test/
#    creating: chase_db_128_128_dice_loss_0_4__0_4_1/test/1st_manual/
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/test/1st_manual/Image_12R_1stHO.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/test/1st_manual/Image_12L_1stHO.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/test/1st_manual/Image_11R_1stHO.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/test/1st_manual/Image_13L_1stHO.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/test/1st_manual/Image_11L_1stHO.png
#    creating: chase_db_128_128_dice_loss_0_4__0_4_1/test/images/
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/test/images/Image_12R.jpg
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/test/images/Image_11L.jpg
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/test/images/Image_11R.jpg
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/test/images/Image_13L.jpg
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/test/images/Image_12L.jpg
#    creating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/
#    creating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/
#    creating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_1.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_55.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_39.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_15.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_6.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_40.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_23.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_21.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_53.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_24.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_32.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_58.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_38.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_59.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_3.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_56.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_30.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_8.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_31.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_19.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_31.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_34.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_57.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_56.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_16.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_37.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_58.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_37.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_0.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_45.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_53.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_16.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_3.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_19.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_24.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_57.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_20.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_20.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_58.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_24.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_22.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_46.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_47.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_51.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_56.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_34.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_43.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_35.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_22.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_18.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_52.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_16.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_53.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_32.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_36.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_44.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_21.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_10.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_7.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_38.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_41.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_50.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_42.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_45.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_18.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_49.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_30.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_12.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_41.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_50.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_0.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_11.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_45.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_44.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_32.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_29.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_0.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_3.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_58.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_54.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_42.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_39.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_33.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_41.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_19.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_40.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_13.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_51.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_12.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_46.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_5.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_4.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_25.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_21.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_11.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_18.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_5.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_17.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_7.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_23.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_7.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_33.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_7.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_6.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_36.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_56.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_28.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_6.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_4.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_4.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_1.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_30.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_20.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_46.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_2.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_17.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_36.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_25.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_47.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_25.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_13.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_43.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_32.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_28.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_11.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_33.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_15.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_19.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_4.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_26.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_42.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_2.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_49.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_36.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_24.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_39.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_57.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_51.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_38.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_34.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_3.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_8.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_2.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_48.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_30.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_35.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_49.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_12.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_22.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_14.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_49.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_42.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_55.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_32.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_26.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_37.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_1.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_29.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_40.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_54.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_34.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_55.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_50.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_5.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_41.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_51.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_23.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_14.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_28.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_48.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_21.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_52.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_9.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_2.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_39.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_23.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_25.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_25.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_5.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_1.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_9.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_14.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_59.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_13.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_0.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_15.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_0.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_48.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_23.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_13.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_21.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_2.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_8.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_34.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_31.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_35.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_39.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_56.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_9.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_15.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_28.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_40.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_46.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_8.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_38.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_14.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_29.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_10.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_16.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_35.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_17.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_12.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_17.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_52.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_1.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_33.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_10.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_6.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_27.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_24.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_27.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_14.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_11.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_12.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_42.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_57.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_10.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_5.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_30.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_18.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_4.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_46.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_44.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_44.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_20.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_9.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_47.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_40.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_59.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_55.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_51.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_36.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_27.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_33.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_18.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_7.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_45.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_52.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_47.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_22.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_22.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_54.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_26.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_54.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_27.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_41.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_37.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_27.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_20.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_35.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_6.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_31.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_17.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_48.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_19.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_43.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_37.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_9.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_10.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_43.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12L_29.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_15.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_45.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_38.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_50.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_48.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_50.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_16.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_55.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_44.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_49.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_3.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_8.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_13L_53.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_28.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_43.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_53.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_26.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_47.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_54.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_26.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_52.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_11.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_12R_29.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11R_13.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/image/_Image_11L_31.png
#    creating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_1.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_55.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_39.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_15.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_6.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_40.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_23.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_21.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_53.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_24.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_32.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_58.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_38.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_59.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_3.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_56.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_30.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_8.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_31.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_19.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_31.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_34.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_57.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_56.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_16.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_37.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_58.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_37.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_0.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_45.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_53.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_16.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_3.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_19.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_24.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_57.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_20.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_20.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_58.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_24.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_22.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_46.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_47.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_51.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_56.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_34.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_43.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_35.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_22.png
#  extracting: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_18.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_52.png
#  extracting: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_16.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_53.png
#  extracting: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_32.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_36.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_44.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_21.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_10.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_7.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_38.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_41.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_50.png
#  extracting: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_42.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_45.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_18.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_49.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_30.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_12.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_41.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_50.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_0.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_11.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_45.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_44.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_32.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_29.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_0.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_3.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_58.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_54.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_42.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_39.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_33.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_41.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_19.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_40.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_13.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_51.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_12.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_46.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_5.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_4.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_25.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_21.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_11.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_18.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_5.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_17.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_7.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_23.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_7.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_33.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_7.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_6.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_36.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_56.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_28.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_6.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_4.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_4.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_1.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_30.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_20.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_46.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_2.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_17.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_36.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_25.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_47.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_25.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_13.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_43.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_32.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_28.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_11.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_33.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_15.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_19.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_4.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_26.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_42.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_2.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_49.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_36.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_24.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_39.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_57.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_51.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_38.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_34.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_3.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_8.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_2.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_48.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_30.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_35.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_49.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_12.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_22.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_14.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_49.png
#  extracting: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_42.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_55.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_32.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_26.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_37.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_1.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_29.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_40.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_54.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_34.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_55.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_50.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_5.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_41.png
#  extracting: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_51.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_23.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_14.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_28.png
#  extracting: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_48.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_21.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_52.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_9.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_2.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_39.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_23.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_25.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_25.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_5.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_1.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_9.png
#  extracting: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_14.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_59.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_13.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_0.png
#  extracting: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_15.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_0.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_48.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_23.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_13.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_21.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_2.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_8.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_34.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_31.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_35.png
#  extracting: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_39.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_56.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_9.png
#  extracting: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_15.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_28.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_40.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_46.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_8.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_38.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_14.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_29.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_10.png
#  extracting: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_16.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_35.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_17.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_12.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_17.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_52.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_1.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12L_33.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_10.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_6.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_12R_27.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_24.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_27.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11L_14.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_11.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_11R_12.png
#  extracting: chase_db_128_128_dice_loss_0_4__0_4_1/split_2/test/mask/_Image_13L_42.png
# ...
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_48.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_21.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_52.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_9.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_2.png
#  extracting: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_39.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_23.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_25.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_25.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_5.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_1.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_9.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_14.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_59.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_13.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_0.png
#  extracting: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_15.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_0.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_48.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_23.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_13.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_21.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_2.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_8.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_34.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_31.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_35.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_39.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_56.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_9.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_15.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_28.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_40.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_46.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_8.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_38.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_14.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_29.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_10.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_16.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_35.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_17.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_12.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_17.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_52.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_1.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_33.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_10.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_6.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_27.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_24.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_27.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_14.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_11.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_12.png
#  extracting: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_42.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_57.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_10.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_5.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_30.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_18.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_4.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_46.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_44.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_44.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_20.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_9.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_47.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_40.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_59.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_55.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_51.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_36.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_27.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_33.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_18.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_7.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_45.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_52.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_47.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_22.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_22.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_54.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_26.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_54.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_27.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_41.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_37.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_27.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_20.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_35.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_6.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_31.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_17.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_48.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_19.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_43.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_37.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_9.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_10.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_43.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12L_29.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_15.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_45.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_38.png
#  extracting: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_50.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_48.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_50.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_16.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_55.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_44.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_49.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_3.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_8.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_13L_53.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_28.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_43.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_53.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_26.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_47.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_54.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_26.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_52.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_11.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_12R_29.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11R_13.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/predictions/_Image_11L_31.png
#    creating: chase_db_128_128_dice_loss_0_4__0_4_1/reconstructed_orig_size/
#    creating: chase_db_128_128_dice_loss_0_4__0_4_1/reconstructed_orig_size/image/
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/reconstructed_orig_size/image/Image_11L.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/reconstructed_orig_size/image/Image_12L.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/reconstructed_orig_size/image/Image_12R.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/reconstructed_orig_size/image/Image_13L.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/reconstructed_orig_size/image/Image_11R.png
#    creating: chase_db_128_128_dice_loss_0_4__0_4_1/reconstructed_orig_size/mask/
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/reconstructed_orig_size/mask/Image_11L.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/reconstructed_orig_size/mask/Image_12L.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/reconstructed_orig_size/mask/Image_12R.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/reconstructed_orig_size/mask/Image_13L.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/reconstructed_orig_size/mask/Image_11R.png
#    creating: chase_db_128_128_dice_loss_0_4__0_4_1/training/
#    creating: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_02L_1stHO.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_06R_1stHO.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_09R_1stHO.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_07L_1stHO.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_13R_1stHO.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_01L_1stHO.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_10R_1stHO.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_09L_1stHO.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_14R_1stHO.png
#  extracting: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_14L_1stHO.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_05L_1stHO.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_10L_1stHO.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_01R_1stHO.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_05R_1stHO.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_04L_1stHO.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_08L_1stHO.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_06L_1stHO.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_08R_1stHO.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_04R_1stHO.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_03L_1stHO.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_07R_1stHO.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_03R_1stHO.png
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/1st_manual/Image_02R_1stHO.png
#    creating: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_05L.jpg
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_07R.jpg
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_08R.jpg
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_04L.jpg
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_10R.jpg
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_07L.jpg
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_02R.jpg
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_09R.jpg
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_14L.jpg
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_04R.jpg
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_09L.jpg
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_03R.jpg
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_06L.jpg
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_13R.jpg
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_14R.jpg
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_06R.jpg
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_01L.jpg
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_08L.jpg
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_05R.jpg
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_10L.jpg
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_01R.jpg
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_02L.jpg
#   inflating: chase_db_128_128_dice_loss_0_4__0_4_1/training/images/Image_03L.jpg

# %%
drive.flush_and_unmount()
