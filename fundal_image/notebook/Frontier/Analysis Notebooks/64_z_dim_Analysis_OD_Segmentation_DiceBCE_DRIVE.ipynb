# %% [markdown]
# ### Import the required libraries and modules:

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
import numpy as np

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# %cd /content/gdrive/MyDrive/Blood_Vessel_Results/ALL_BEST_RESULTS/DRIVE_OD_2
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/Blood_Vessel_Results/ALL_BEST_RESULTS/DRIVE_OD_2

# %% [markdown]
# ### Unzip the data:

# %%
# !unzip new_data.zip

# %% [markdown]
# ### Construct the Model:

# %%
def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(inputs, num_filters, strides=2):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D(strides)(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters, strides=2):
    x = Conv2DTranspose(num_filters, (2, 2), strides=strides, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape, num_filters=[64, 128, 256, 512, 1024], strides=[2, 2, 2, 2]):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, num_filters[0], strides=strides[0])
    s2, p2 = encoder_block(p1, num_filters[1], strides=strides[1])
    s3, p3 = encoder_block(p2, num_filters[2], strides=strides[2])
    s4, p4 = encoder_block(p3, num_filters[3], strides=strides[3])

    b1 = conv_block(p4, num_filters[4])

    d1 = decoder_block(b1, s4, num_filters[3], strides=strides[3])
    d2 = decoder_block(d1, s3, num_filters[2], strides=strides[2])
    d3 = decoder_block(d2, s2, num_filters[1], strides=strides[1])
    d4 = decoder_block(d3, s1, num_filters[0], strides=strides[0])

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="UNET")
    return model

input_shape = (512, 512, 3)
model = build_unet(input_shape)
model.summary()
# Out:
# Model: "UNET"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 512, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 512, 512, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 512, 512, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 512, 512, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 12  0          ['activation_3[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 25  295168      ['max_pooling2d_1[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_4[0][0]']
#  rmalization)                   6)
#
#  activation_4 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_4[0][0]']
#                                 6)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 25  590080      ['activation_4[0][0]']
#                                 6)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_5[0][0]']
#  rmalization)                   6)
#
#  activation_5 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_5[0][0]']
#                                 6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 512)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 512)  2097664    ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 64, 64, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 25  524544     ['activation_11[0][0]']
#  spose)                         6)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 51  0           ['conv2d_transpose_1[0][0]',
#                                 2)                                'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_12 (BatchN  (None, 128, 128, 25  1024       ['conv2d_12[0][0]']
#  ormalization)                  6)
#
#  activation_12 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_12[0][0]']
#                                 6)
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 25  590080      ['activation_12[0][0]']
#                                 6)
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 25  1024       ['conv2d_13[0][0]']
#  ormalization)                  6)
#
#  activation_13 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_13[0][0]']
#                                 6)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 12  131200     ['activation_13[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 256, 256, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  activation_14 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_15 (BatchN  (None, 256, 256, 12  512        ['conv2d_15[0][0]']
#  ormalization)                  8)
#
#  activation_15 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_15[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 64  32832      ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 512, 512, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 512, 512, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 512, 512, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 512, 512, 1)  65          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %% [markdown]
# ### Adding the Metrics:

# %%
def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def DiceBCELoss(y_true, y_pred):

    inputs = tf.keras.layers.Flatten()(y_true)
    targets = tf.keras.layers.Flatten()(y_pred)

    intersection = tf.reduce_sum(inputs * targets)
    dice_loss = 1 - (2.*intersection + smooth)/(tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)
    BCE = tf.keras.losses.BinaryCrossentropy()
    Dice_BCE = BCE(inputs, targets) + dice_loss

    return Dice_BCE

# %% [markdown]
# ### Training the Model:

# %%
H = 512
W = 512

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.png")))
    y = sorted(glob(os.path.join(path, "mask", "*.png")))
    return x, y

def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)
    return x, y

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)              ## (512, 512, 1)
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y, batch_size=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(4)
    return dataset

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 4
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model1.h5")
csv_path = os.path.join("files", "data1.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model1 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 384], strides=[1, 2, 2, 2])

model1.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model1.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 140 - 140
# Valid: 20 - 20
# Epoch 1/50
# 35/35 [==============================] - ETA: 0s - loss: 1.2333 - dice_coef: 0.0975 - iou: 0.0517 - recall: 0.5391 - precision: 0.1855
# Epoch 1: val_loss improved from inf to 1.58759, saving model to files/model1.h5
# 35/35 [==============================] - 104s 2s/step - loss: 1.2333 - dice_coef: 0.0975 - iou: 0.0517 - recall: 0.5391 - precision: 0.1855 - val_loss: 1.5876 - val_dice_coef: 0.0292 - val_iou: 0.0148 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 2/50
# 35/35 [==============================] - ETA: 0s - loss: 0.9772 - dice_coef: 0.1880 - iou: 0.1044 - recall: 0.7122 - precision: 0.5486
# Epoch 2: val_loss did not improve from 1.58759
# 35/35 [==============================] - 28s 804ms/step - loss: 0.9772 - dice_coef: 0.1880 - iou: 0.1044 - recall: 0.7122 - precision: 0.5486 - val_loss: 1.6509 - val_dice_coef: 0.0296 - val_iou: 0.0150 - val_recall: 0.4821 - val_precision: 0.0174 - lr: 1.0000e-04
# Epoch 3/50
# 35/35 [==============================] - ETA: 0s - loss: 0.8827 - dice_coef: 0.2485 - iou: 0.1425 - recall: 0.7737 - precision: 0.6387
# Epoch 3: val_loss improved from 1.58759 to 1.27510, saving model to files/model1.h5
# 35/35 [==============================] - 30s 866ms/step - loss: 0.8827 - dice_coef: 0.2485 - iou: 0.1425 - recall: 0.7737 - precision: 0.6387 - val_loss: 1.2751 - val_dice_coef: 0.0280 - val_iou: 0.0142 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 4/50
# 35/35 [==============================] - ETA: 0s - loss: 0.8114 - dice_coef: 0.2914 - iou: 0.1714 - recall: 0.8049 - precision: 0.7094
# Epoch 4: val_loss improved from 1.27510 to 1.19471, saving model to files/model1.h5
# 35/35 [==============================] - 30s 864ms/step - loss: 0.8114 - dice_coef: 0.2914 - iou: 0.1714 - recall: 0.8049 - precision: 0.7094 - val_loss: 1.1947 - val_dice_coef: 0.0309 - val_iou: 0.0157 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 5/50
# 35/35 [==============================] - ETA: 0s - loss: 0.7569 - dice_coef: 0.3309 - iou: 0.1991 - recall: 0.8339 - precision: 0.7409
# Epoch 5: val_loss improved from 1.19471 to 1.13194, saving model to files/model1.h5
# 35/35 [==============================] - 30s 860ms/step - loss: 0.7569 - dice_coef: 0.3309 - iou: 0.1991 - recall: 0.8339 - precision: 0.7409 - val_loss: 1.1319 - val_dice_coef: 0.0302 - val_iou: 0.0153 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 6/50
# 35/35 [==============================] - ETA: 0s - loss: 0.7099 - dice_coef: 0.3683 - iou: 0.2265 - recall: 0.8661 - precision: 0.7738
# Epoch 6: val_loss improved from 1.13194 to 1.10817, saving model to files/model1.h5
# 35/35 [==============================] - 32s 908ms/step - loss: 0.7099 - dice_coef: 0.3683 - iou: 0.2265 - recall: 0.8661 - precision: 0.7738 - val_loss: 1.1082 - val_dice_coef: 0.0303 - val_iou: 0.0154 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 7/50
# 35/35 [==============================] - ETA: 0s - loss: 0.6765 - dice_coef: 0.3967 - iou: 0.2481 - recall: 0.8843 - precision: 0.7758
# Epoch 7: val_loss improved from 1.10817 to 1.08915, saving model to files/model1.h5
# 35/35 [==============================] - 32s 899ms/step - loss: 0.6765 - dice_coef: 0.3967 - iou: 0.2481 - recall: 0.8843 - precision: 0.7758 - val_loss: 1.0891 - val_dice_coef: 0.0266 - val_iou: 0.0135 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 8/50
# 35/35 [==============================] - ETA: 0s - loss: 0.6446 - dice_coef: 0.4205 - iou: 0.2671 - recall: 0.8892 - precision: 0.8048
# Epoch 8: val_loss improved from 1.08915 to 1.08489, saving model to files/model1.h5
# 35/35 [==============================] - 31s 877ms/step - loss: 0.6446 - dice_coef: 0.4205 - iou: 0.2671 - recall: 0.8892 - precision: 0.8048 - val_loss: 1.0849 - val_dice_coef: 0.0254 - val_iou: 0.0129 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 
# 35/35 [==============================] - ETA: 0s - loss: 0.1612 - dice_coef: 0.8478 - iou: 0.7366 - recall: 0.9641 - precision: 0.9840
# Epoch 49: val_loss improved from 0.47426 to 0.47379, saving model to files/model1.h5
# 35/35 [==============================] - 30s 849ms/step - loss: 0.1612 - dice_coef: 0.8478 - iou: 0.7366 - recall: 0.9641 - precision: 0.9840 - val_loss: 0.4738 - val_dice_coef: 0.5899 - val_iou: 0.4235 - val_recall: 0.6918 - val_precision: 0.7303 - lr: 1.0000e-05
# Epoch 50/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1596 - dice_coef: 0.8492 - iou: 0.7386 - recall: 0.9645 - precision: 0.9846
# Epoch 50: val_loss improved from 0.47379 to 0.47321, saving model to files/model1.h5
# 35/35 [==============================] - 30s 849ms/step - loss: 0.1596 - dice_coef: 0.8492 - iou: 0.7386 - recall: 0.9645 - precision: 0.9846 - val_loss: 0.4732 - val_dice_coef: 0.5908 - val_iou: 0.4244 - val_recall: 0.6920 - val_precision: 0.7300 - lr: 1.0000e-05

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 4
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model2.h5")
csv_path = os.path.join("files", "data2.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model2 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 512], strides=[1, 2, 2, 2])

model2.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model2.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 140 - 140
# Valid: 20 - 20
# Epoch 1/50
# 35/35 [==============================] - ETA: 0s - loss: 1.2332 - dice_coef: 0.0981 - iou: 0.0520 - recall_1: 0.5434 - precision_1: 0.1856
# Epoch 1: val_loss improved from inf to 1.58445, saving model to files/model2.h5
# Epoch 18/50
# 35/35 [==============================] - ETA: 0s - loss: 0.3796 - dice_coef: 0.6485 - iou: 0.4809 - recall_1: 0.9387 - precision_1: 0.8978
# Epoch 18: val_loss improved from 0.73380 to 0.65630, saving model to files/model2.h5
# 35/35 [==============================] - 33s 950ms/step - loss: 0.3796 - dice_coef: 0.6485 - iou: 0.4809 - recall_1: 0.9387 - precision_1: 0.8978 - val_loss: 0.6563 - val_dice_coef: 0.4040 - val_iou: 0.2565 - val_recall_1: 0.5812 - val_precision_1: 0.7308 - lr: 1.0000e-04
# Epoch 19/50
# 35/35 [==============================] - ETA: 0s - loss: 0.3627 - dice_coef: 0.6636 - iou: 0.4978 - recall_1: 0.9306 - precision_1: 0.9061
# Epoch 19: val_loss improved from 0.65630 to 0.56874, saving model to files/model2.h5
# 35/35 [==============================] - 33s 948ms/step - loss: 0.3627 - dice_coef: 0.6636 - iou: 0.4978 - recall_1: 0.9306 - precision_1: 0.9061 - val_loss: 0.5687 - val_dice_coef: 0.4999 - val_iou: 0.3378 - val_recall_1: 0.8024 - val_precision_1: 0.6726 - lr: 1.0000e-04
# Epoch 20/50
# 35/35 [==============================] - ETA: 0s - loss: 0.3470 - dice_coef: 0.6789 - iou: 0.5151 - recall_1: 0.9283 - precision_1: 0.9081
# Epoch 20: val_loss did not improve from 0.56874
# 35/35 [==============================] - 31s 892ms/step - loss: 0.3470 - dice_coef: 0.6789 - iou: 0.5151 - recall_1: 0.9283 - precision_1: 0.9081 - val_loss: 0.6403 - val_dice_coef: 0.4147 - val_iou: 0.2659 - val_recall_1: 0.5779 - val_precision_1: 0.6919 - lr: 1.0000e-04
# Epoch 21/50
# 35/35 [==============================] - ETA: 0s - loss: 0.3397 - dice_coef: 0.6863 - iou: 0.5240 - recall_1: 0.9219 - precision_1: 0.8940
# Epoch 21: val_loss did not improve from 0.56874
# 35/35 [==============================] - 31s 892ms/step - loss: 0.3397 - dice_coef: 0.6863 - iou: 0.5240 - recall_1: 0.9219 - precision_1: 0.8940 - val_loss: 0.6278 - val_dice_coef: 0.4780 - val_iou: 0.3204 - val_recall_1: 0.8825 - val_precision_1: 0.4788 - lr: 1.0000e-04
# Epoch 22/50
# 35/35 [==============================] - ETA: 0s - loss: 0.3507 - dice_coef: 0.6820 - iou: 0.5200 - recall_1: 0.9017 - precision_1: 0.8433
# Epoch 22: val_loss did not improve from 0.56874
# 35/35 [==============================] - 31s 893ms/step - loss: 0.3507 - dice_coef: 0.6820 - iou: 0.5200 - recall_1: 0.9017 - precision_1: 0.8433 - val_loss: 0.8341 - val_dice_coef: 0.3473 - val_iou: 0.2121 - val_recall_1: 0.9331 - val_precision_1: 0.3549 - lr: 1.0000e-04
# Epoch 23/50
# 35/35 [==============================] - ETA: 0s - loss: 0.3184 - dice_coef: 0.7074 - iou: 0.5491 - recall_1: 0.9065 - precision_1: 0.8902
# Epoch 23: val_loss improved from 0.56874 to 0.55092, saving model to files/model2.h5
# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 4
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model3.h5")
csv_path = os.path.join("files", "data3.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model3 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 768], strides=[1, 2, 2, 2])

model3.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model3.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 140 - 140
# Valid: 20 - 20
# Epoch 1/50
# 35/35 [==============================] - ETA: 0s - loss: 1.2317 - dice_coef: 0.0976 - iou: 0.0517 - recall_2: 0.5349 - precision_2: 0.1854
# Epoch 1: val_loss improved from inf to 1.58535, saving model to files/model3.h5
# 35/35 [==============================] - 39s 1s/step - loss: 1.2317 - dice_coef: 0.0976 - iou: 0.0517 - recall_2: 0.5349 - precision_2: 0.1854 - val_loss: 1.5854 - val_dice_coef: 0.0292 - val_iou: 0.0148 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 2/50
# 35/35 [==============================] - ETA: 0s - loss: 0.9862 - dice_coef: 0.1813 - iou: 0.1003 - recall_2: 0.6684 - precision_2: 0.5461
# Epoch 2: val_loss did not improve from 1.58535
# 35/35 [==============================] - 32s 910ms/step - loss: 0.9862 - dice_coef: 0.1813 - iou: 0.1003 - recall_2: 0.6684 - precision_2: 0.5461 - val_loss: 2.9526 - val_dice_coef: 0.0306 - val_iou: 0.0156 - val_recall_2: 1.0000 - val_precision_2: 0.0160 - lr: 1.0000e-04
# Epoch 3/50
# 35/35 [==============================] - ETA: 0s - loss: 0.8899 - dice_coef: 0.2406 - iou: 0.1375 - recall_2: 0.7460 - precision_2: 0.6406
# Epoch 3: val_loss improved from 1.58535 to 1.26455, saving model to files/model3.h5
# 35/35 [==============================] - 35s 989ms/step - loss: 0.8899 - dice_coef: 0.2406 - iou: 0.1375 - recall_2: 0.7460 - precision_2: 0.6406 - val_loss: 1.2646 - val_dice_coef: 0.0271 - val_iou: 0.0137 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 4/50
# 35/35 [==============================] - ETA: 0s - loss: 0.8136 - dice_coef: 0.2906 - iou: 0.1709 - recall_2: 0.8005 - precision_2: 0.7302
# Epoch 4: val_loss improved from 1.26455 to 1.19424, saving model to files/model3.h5
# 35/35 [==============================] - 34s 984ms/step - loss: 0.8136 - dice_coef: 0.2906 - iou: 0.1709 - recall_2: 0.8005 - precision_2: 0.7302 - val_loss: 1.1942 - val_dice_coef: 0.0315 - val_iou: 0.0160 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 5/50
# 35/35 [==============================] - ETA: 0s - loss: 0.7570 - dice_coef: 0.3316 - iou: 0.1996 - recall_2: 0.8325 - precision_2: 0.7601
# Epoch 5: val_loss improved from 1.19424 to 1.12812, saving model to files/model3.h5
# 35/35 [==============================] - 35s 989ms/step - loss: 0.7570 - dice_coef: 0.3316 - iou: 0.1996 - recall_2: 0.8325 - precision_2: 0.7601 - val_loss: 1.1281 - val_dice_coef: 0.0302 - val_iou: 0.0154 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 6/50
# 35/35 [==============================] - ETA: 0s - loss: 0.7331 - dice_coef: 0.3514 - iou: 0.2141 - recall_2: 0.8288 - precision_2: 0.7340
# Epoch 6: val_loss improved from 1.12812 to 1.10830, saving model to files/model3.h5
# 35/35 [==============================] - 35s 994ms/step - loss: 0.7331 - dice_coef: 0.3514 - iou: 0.2141 - recall_2: 0.8288 - precision_2: 0.7340 - val_loss: 1.1083 - val_dice_coef: 0.0285 - val_iou: 0.0145 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 7/50
# 35/35 [==============================] - ETA: 0s - loss: 0.6845 - dice_coef: 0.3880 - iou: 0.2416 - recall_2: 0.8656 - precision_2: 0.7837
# Epoch 7: val_loss improved from 1.10830 to 1.08912, saving model to files/model3.h5
# 35/35 [==============================] - 35s 988ms/step - loss: 0.6845 - dice_coef: 0.3880 - iou: 0.2416 - recall_2: 0.8656 - precision_2: 0.7837 - val_loss: 1.0891 - val_dice_coef: 0.0265 - val_iou: 0.0134 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 8/50
# 35/35 [==============================] - ETA: 0s - loss: 0.6466 - dice_coef: 0.4199 - iou: 0.2666 - recall_2: 0.8887 - precision_2: 0.7972
# Epoch 8: val_loss improved from 1.08912 to 1.07307, saving model to files/model3.h5
# 35/35 [==============================] - 35s 996ms/step - loss: 0.6466 - dice_coef: 0.4199 - iou: 0.2666 - recall_2: 0.8887 - precision_2: 0.7972 - val_loss: 1.0731 - val_dice_coef: 0.0267 - val_iou: 0.0135 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 9/50
# 35/35 [==============================] - ETA: 0s - loss: 0.6192 - dice_coef: 0.4422 - iou: 0.2846 - recall_2: 0.8887 - precision_2: 0.8179
# Epoch 9: val_loss improved from 1.07307 to 1.07008, saving model to files/model3.h5
# 35/35 [==============================] - 35s 994ms/step - loss: 0.6192 - dice_coef: 0.4422 - iou: 0.2846 - recall_2: 0.8887 - precision_2: 0.8179 - val_loss: 1.0701 - val_dice_coef: 0.0246 - val_iou: 0.0125 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 10/50
# 35/35 [==============================] - ETA: 0s - loss: 0.6046 - dice_coef: 0.4553 - iou: 0.2957 - recall_2: 0.8869 - precision_2: 0.7828
# Epoch 10: val_loss improved from 1.07008 to 1.05462, saving model to files/model3.h5
# 35/35 [==============================] - 35s 995ms/step - loss: 0.6046 - dice_coef: 0.4553 - iou: 0.2957 - recall_2: 0.8869 - precision_2: 0.7828 - val_loss: 1.0546 - val_dice_coef: 0.0344 - val_iou: 0.0175 - val_recall_2: 0.0138 - val_precision_2: 0.5825 - lr: 1.0000e-04
# Epoch 11/50
# 35/35 [==============================] - ETA: 0s - loss: 0.5690 - dice_coef: 0.4823 - iou: 0.3187 - recall_2: 0.8761 - precision_2: 0.8422
# Epoch 11: val_loss improved from 1.05462 to 0.97911, saving model to files/model3.h5
# 35/35 [==============================] - 35s 992ms/step - loss: 0.5690 - dice_coef: 0.4823 - iou: 0.3187 - recall_2: 0.8761 - precision_2: 0.8422 - val_loss: 0.9791 - val_dice_coef: 0.0985 - val_iou: 0.0522 - val_recall_2: 0.1471 - val_precision_2: 0.9604 - lr: 1.0000e-04
# Epoch 12/50
# 35/35 [==============================] - ETA: 0s - loss: 0.5370 - dice_coef: 0.5100 - iou: 0.3431 - recall_2: 0.8920 - precision_2: 0.8482
# Epoch 12: val_loss did not improve from 0.97911
# 35/35 [==============================] - 32s 907ms/step - loss: 0.5370 - dice_coef: 0.5100 - iou: 0.3431 - recall_2: 0.8920 - precision_2: 0.8482 - val_loss: 1.0081 - val_dice_coef: 0.0725 - val_iou: 0.0379 - val_recall_2: 0.0953 - val_precision_2: 0.9896 - lr: 1.0000e-04
# Epoch 13/50
# 35/35 [==============================] - ETA: 0s - loss: 0.5213 - dice_coef: 0.5260 - iou: 0.3579 - recall_2: 0.8987 - precision_2: 0.8227
# Epoch 13: val_loss improved from 0.97911 to 0.80517, saving model to files/model3.h5
# 35/35 [==============================] - 35s 994ms/step - loss: 0.5213 - dice_coef: 0.5260 - iou: 0.3579 - recall_2: 0.8987 - precision_2: 0.8227 - val_loss: 0.8052 - val_dice_coef: 0.3082 - val_iou: 0.1847 - val_recall_2: 0.7982 - val_precision_2: 0.5046 - lr: 1.0000e-04
# Epoch 14/50
# 35/35 [==============================] - ETA: 0s - loss: 0.5043 - dice_coef: 0.5396 - iou: 0.3708 - recall_2: 0.8795 - precision_2: 0.8318
# Epoch 14: val_loss did not improve from 0.80517
# 35/35 [==============================] - 32s 910ms/step - loss: 0.5043 - dice_coef: 0.5396 - iou: 0.3708 - recall_2: 0.8795 - precision_2: 0.8318 - val_loss: 0.9109 - val_dice_coef: 0.1619 - val_iou: 0.0890 - val_recall_2: 0.2718 - val_precision_2: 0.7405 - lr: 1.0000e-04
# Epoch 15/50
# 35/35 [==============================] - ETA: 0s - loss: 0.4648 - dice_coef: 0.5747 - iou: 0.4044 - recall_2: 0.9073 - precision_2: 0.8571
# Epoch 15: val_loss improved from 0.80517 to 0.72171, saving model to files/model3.h5
# 35/35 [==============================] - 35s 989ms/step - loss: 0.4648 - dice_coef: 0.5747 - iou: 0.4044 - recall_2: 0.9073 - precision_2: 0.8571 - val_loss: 0.7217 - val_dice_coef: 0.3437 - val_iou: 0.2081 - val_recall_2: 0.5750 - val_precision_2: 0.7243 - lr: 1.0000e-04
# Epoch 16/50
# 35/35 [==============================] - ETA: 0s - loss: 0.4444 - dice_coef: 0.5933 - iou: 0.4231 - recall_2: 0.9049 - precision_2: 0.8600
# Epoch 16: val_loss improved from 0.72171 to 0.62804, saving model to files/model3.h5
# 35/35 [==============================] - 35s 994ms/step - loss: 0.4444 - dice_coef: 0.5933 - iou: 0.4231 - recall_2: 0.9049 - precision_2: 0.8600 - val_loss: 0.6280 - val_dice_coef: 0.4405 - val_iou: 0.2854 - val_recall_2: 0.7779 - val_precision_2: 0.7011 - lr: 1.0000e-04
# Epoch 17/50
# 35/35 [==============================] - ETA: 0s - loss: 0.4016 - dice_coef: 0.6287 - iou: 0.4595 - recall_2: 0.9292 - precision_2: 0.8932
# Epoch 17: val_loss did not improve from 0.62804
# 35/35 [==============================] - 32s 905ms/step - loss: 0.4016 - dice_coef: 0.6287 - iou: 0.4595 - recall_2: 0.9292 - precision_2: 0.8932 - val_loss: 0.7145 - val_dice_coef: 0.3408 - val_iou: 0.2067 - val_recall_2: 0.4808 - val_precision_2: 0.7757 - lr: 1.0000e-04
# Epoch 18/50
# 35/35 [==============================] - ETA: 0s - loss: 0.3750 - dice_coef: 0.6521 - iou: 0.4847 - recall_2: 0.9302 - precision_2: 0.9141
# Epoch 18: val_loss did not improve from 0.62804
# 35/35 [==============================] - 32s 910ms/step - loss: 0.3750 - dice_coef: 0.6521 - iou: 0.4847 - recall_2: 0.9302 - precision_2: 0.9141 - val_loss: 0.6326 - val_dice_coef: 0.4236 - val_iou: 0.2709 - val_recall_2: 0.6178 - val_precision_2: 0.7312 - lr: 1.0000e-04
# Epoch 19/50
# 35/35 [==============================] - ETA: 0s - loss: 0.3543 - dice_coef: 0.6712 - iou: 0.5061 - recall_2: 0.9298 - precision_2: 0.9213
# Epoch 19: val_loss did not improve from 0.62804
# 35/35 [==============================] - 32s 908ms/step - loss: 0.3543 - dice_coef: 0.6712 - iou: 0.5061 - recall_2: 0.9298 - precision_2: 0.9213 - val_loss: 0.6338 - val_dice_coef: 0.4211 - val_iou: 0.2687 - val_recall_2: 0.5771 - val_precision_2: 0.7450 - lr: 1.0000e-04
# Epoch 20/50
# 35/35 [==============================] - ETA: 0s - loss: 0.3464 - dice_coef: 0.6797 - iou: 0.5167 - recall_2: 0.9248 - precision_2: 0.9069
# Epoch 20: val_loss did not improve from 0.62804
# 35/35 [==============================] - 32s 908ms/step - loss: 0.3464 - dice_coef: 0.6797 - iou: 0.5167 - recall_2: 0.9248 - precision_2: 0.9069 - val_loss: 0.6716 - val_dice_coef: 0.3860 - val_iou: 0.2421 - val_recall_2: 0.5095 - val_precision_2: 0.7254 - lr: 1.0000e-04
# Epoch 21/50
# 35/35 [==============================] - ETA: 0s - loss: 0.3364 - dice_coef: 0.6890 - iou: 0.5268 - recall_2: 0.9143 - precision_2: 0.9037
# Epoch 21: val_loss improved from 0.62804 to 0.58526, saving model to files/model3.h5
# 35/35 [==============================] - 34s 987ms/step - loss: 0.3364 - dice_coef: 0.6890 - iou: 0.5268 - recall_2: 0.9143 - precision_2: 0.9037 - val_loss: 0.5853 - val_dice_coef: 0.4911 - val_iou: 0.3256 - val_recall_2: 0.8084 - val_precision_2: 0.5628 - lr: 1.0000e-04
# Epoch 22/50
# 35/35 [==============================] - ETA: 0s - loss: 0.3104 - dice_coef: 0.7121 - iou: 0.5541 - recall_2: 0.9304 - precision_2: 0.9106
# Epoch 22: val_loss improved from 0.58526 to 0.49767, saving model to files/model3.h5
# 35/35 [==============================] - 34s 981ms/step - loss: 0.3104 - dice_coef: 0.7121 - iou: 0.5541 - recall_2: 0.9304 - precision_2: 0.9106 - val_loss: 0.4977 - val_dice_coef: 0.5638 - val_iou: 0.3947 - val_recall_2: 0.8393 - val_precision_2: 0.7143 - lr: 1.0000e-04
# Epoch 23/50
# 35/35 [==============================] - ETA: 0s - loss: 0.2977 - dice_coef: 0.7247 - iou: 0.5695 - recall_2: 0.9222 - precision_2: 0.9161
# Epoch 23: val_loss did not improve from 0.49767
# 35/35 [==============================] - 32s 910ms/step - loss: 0.2977 - dice_coef: 0.7247 - iou: 0.5695 - recall_2: 0.9222 - precision_2: 0.9161 - val_loss: 0.5856 - val_dice_coef: 0.4728 - val_iou: 0.3126 - val_recall_2: 0.6356 - val_precision_2: 0.7159 - lr: 1.0000e-04
# Epoch 24/50
# 35/35 [==============================] - ETA: 0s - loss: 0.2771 - dice_coef: 0.7430 - iou: 0.5920 - recall_2: 0.9291 - precision_2: 0.9286
# Epoch 24: val_loss improved from 0.49767 to 0.48577, saving model to files/model3.h5
# 35/35 [==============================] - 34s 981ms/step - loss: 0.2771 - dice_coef: 0.7430 - iou: 0.5920 - recall_2: 0.9291 - precision_2: 0.9286 - val_loss: 0.4858 - val_dice_coef: 0.5690 - val_iou: 0.4001 - val_recall_2: 0.7872 - val_precision_2: 0.7254 - lr: 1.0000e-04
# Epoch 25/50
# 35/35 [==============================] - ETA: 0s - loss: 0.2674 - dice_coef: 0.7523 - iou: 0.6040 - recall_2: 0.9264 - precision_2: 0.9244
# Epoch 25: val_loss did not improve from 0.48577
# 35/35 [==============================] - 32s 897ms/step - loss: 0.2674 - dice_coef: 0.7523 - iou: 0.6040 - recall_2: 0.9264 - precision_2: 0.9244 - val_loss: 0.5977 - val_dice_coef: 0.4947 - val_iou: 0.3294 - val_recall_2: 0.7585 - val_precision_2: 0.5360 - lr: 1.0000e-04
# Epoch 26/50
# 35/35 [==============================] - ETA: 0s - loss: 0.2537 - dice_coef: 0.7652 - iou: 0.6207 - recall_2: 0.9264 - precision_2: 0.9267
# Epoch 26: val_loss did not improve from 0.48577
# 35/35 [==============================] - 31s 896ms/step - loss: 0.2537 - dice_coef: 0.7652 - iou: 0.6207 - recall_2: 0.9264 - precision_2: 0.9267 - val_loss: 0.7355 - val_dice_coef: 0.5087 - val_iou: 0.3545 - val_recall_2: 0.9425 - val_precision_2: 0.3596 - lr: 1.0000e-04
# Epoch 27/50
# 35/35 [==============================] - ETA: 0s - loss: 0.2450 - dice_coef: 0.7735 - iou: 0.6319 - recall_2: 0.9205 - precision_2: 0.9283
# Epoch 27: val_loss did not improve from 0.48577
# 35/35 [==============================] - 31s 897ms/step - loss: 0.2450 - dice_coef: 0.7735 - iou: 0.6319 - recall_2: 0.9205 - precision_2: 0.9283 - val_loss: 0.6926 - val_dice_coef: 0.5009 - val_iou: 0.3468 - val_recall_2: 0.9281 - val_precision_2: 0.3487 - lr: 1.0000e-04
# Epoch 28/50
# 35/35 [==============================] - ETA: 0s - loss: 0.2595 - dice_coef: 0.7635 - iou: 0.6189 - recall_2: 0.9067 - precision_2: 0.8951
# Epoch 28: val_loss did not improve from 0.48577
# 35/35 [==============================] - 31s 897ms/step - loss: 0.2595 - dice_coef: 0.7635 - iou: 0.6189 - recall_2: 0.9067 - precision_2: 0.8951 - val_loss: 0.5178 - val_dice_coef: 0.5713 - val_iou: 0.4034 - val_recall_2: 0.8007 - val_precision_2: 0.6182 - lr: 1.0000e-04
# Epoch 29/50
# 35/35 [==============================] - ETA: 0s - loss: 0.2274 - dice_coef: 0.7900 - iou: 0.6542 - recall_2: 0.9166 - precision_2: 0.9306
# Epoch 29: val_loss did not improve from 0.48577
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 35/35 [==============================] - 31s 897ms/step - loss: 0.2274 - dice_coef: 0.7900 - iou: 0.6542 - recall_2: 0.9166 - precision_2: 0.9306 - val_loss: 0.5135 - val_dice_coef: 0.5392 - val_iou: 0.3772 - val_recall_2: 0.6380 - val_precision_2: 0.7473 - lr: 1.0000e-04
# Epoch 30/50
# 35/35 [==============================] - ETA: 0s - loss: 0.2175 - dice_coef: 0.8008 - iou: 0.6699 - recall_2: 0.9281 - precision_2: 0.9164
# Epoch 30: val_loss improved from 0.48577 to 0.44831, saving model to files/model3.h5
# 35/35 [==============================] - 34s 980ms/step - loss: 0.2175 - dice_coef: 0.8008 - iou: 0.6699 - recall_2: 0.9281 - precision_2: 0.9164 - val_loss: 0.4483 - val_dice_coef: 0.6149 - val_iou: 0.4466 - val_recall_2: 0.8215 - val_precision_2: 0.7011 - lr: 1.0000e-05
# Epoch 31/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1979 - dice_coef: 0.8156 - iou: 0.6893 - recall_2: 0.9393 - precision_2: 0.9553
# Epoch 31: val_loss improved from 0.44831 to 0.44698, saving model to files/model3.h5
# 35/35 [==============================] - 34s 973ms/step - loss: 0.1979 - dice_coef: 0.8156 - iou: 0.6893 - recall_2: 0.9393 - precision_2: 0.9553 - val_loss: 0.4470 - val_dice_coef: 0.6110 - val_iou: 0.4433 - val_recall_2: 0.7915 - val_precision_2: 0.7165 - lr: 1.0000e-05
# Epoch 32/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1937 - dice_coef: 0.8191 - iou: 0.6942 - recall_2: 0.9428 - precision_2: 0.9592
# Epoch 32: val_loss improved from 0.44698 to 0.44617, saving model to files/model3.h5
# 35/35 [==============================] - 34s 971ms/step - loss: 0.1937 - dice_coef: 0.8191 - iou: 0.6942 - recall_2: 0.9428 - precision_2: 0.9592 - val_loss: 0.4462 - val_dice_coef: 0.6110 - val_iou: 0.4435 - val_recall_2: 0.7827 - val_precision_2: 0.7171 - lr: 1.0000e-05
# Epoch 33/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1907 - dice_coef: 0.8217 - iou: 0.6980 - recall_2: 0.9444 - precision_2: 0.9623
# Epoch 33: val_loss improved from 0.44617 to 0.44433, saving model to files/model3.h5
# 35/35 [==============================] - 34s 978ms/step - loss: 0.1907 - dice_coef: 0.8217 - iou: 0.6980 - recall_2: 0.9444 - precision_2: 0.9623 - val_loss: 0.4443 - val_dice_coef: 0.6122 - val_iou: 0.4449 - val_recall_2: 0.7776 - val_precision_2: 0.7174 - lr: 1.0000e-05
# Epoch 34/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1877 - dice_coef: 0.8243 - iou: 0.7018 - recall_2: 0.9474 - precision_2: 0.9646
# Epoch 34: val_loss improved from 0.44433 to 0.44229, saving model to files/model3.h5
# 35/35 [==============================] - 34s 978ms/step - loss: 0.1877 - dice_coef: 0.8243 - iou: 0.7018 - recall_2: 0.9474 - precision_2: 0.9646 - val_loss: 0.4423 - val_dice_coef: 0.6140 - val_iou: 0.4468 - val_recall_2: 0.7749 - val_precision_2: 0.7179 - lr: 1.0000e-05
# Epoch 35/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1851 - dice_coef: 0.8267 - iou: 0.7052 - recall_2: 0.9494 - precision_2: 0.9662
# Epoch 35: val_loss improved from 0.44229 to 0.44076, saving model to files/model3.h5
# 35/35 [==============================] - 34s 974ms/step - loss: 0.1851 - dice_coef: 0.8267 - iou: 0.7052 - recall_2: 0.9494 - precision_2: 0.9662 - val_loss: 0.4408 - val_dice_coef: 0.6156 - val_iou: 0.4485 - val_recall_2: 0.7733 - val_precision_2: 0.7175 - lr: 1.0000e-05
# Epoch 36/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1827 - dice_coef: 0.8288 - iou: 0.7083 - recall_2: 0.9510 - precision_2: 0.9675
# Epoch 36: val_loss improved from 0.44076 to 0.44052, saving model to files/model3.h5
# 35/35 [==============================] - 34s 982ms/step - loss: 0.1827 - dice_coef: 0.8288 - iou: 0.7083 - recall_2: 0.9510 - precision_2: 0.9675 - val_loss: 0.4405 - val_dice_coef: 0.6160 - val_iou: 0.4488 - val_recall_2: 0.7706 - val_precision_2: 0.7166 - lr: 1.0000e-05
# Epoch 37/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1805 - dice_coef: 0.8308 - iou: 0.7112 - recall_2: 0.9520 - precision_2: 0.9689
# Epoch 37: val_loss improved from 0.44052 to 0.43968, saving model to files/model3.h5
# 35/35 [==============================] - 34s 981ms/step - loss: 0.1805 - dice_coef: 0.8308 - iou: 0.7112 - recall_2: 0.9520 - precision_2: 0.9689 - val_loss: 0.4397 - val_dice_coef: 0.6174 - val_iou: 0.4501 - val_recall_2: 0.7722 - val_precision_2: 0.7148 - lr: 1.0000e-05
# Epoch 38/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1785 - dice_coef: 0.8326 - iou: 0.7139 - recall_2: 0.9530 - precision_2: 0.9698
# Epoch 38: val_loss did not improve from 0.43968
# 35/35 [==============================] - 31s 895ms/step - loss: 0.1785 - dice_coef: 0.8326 - iou: 0.7139 - recall_2: 0.9530 - precision_2: 0.9698 - val_loss: 0.4400 - val_dice_coef: 0.6174 - val_iou: 0.4500 - val_recall_2: 0.7694 - val_precision_2: 0.7139 - lr: 1.0000e-05
# Epoch 39/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1766 - dice_coef: 0.8343 - iou: 0.7164 - recall_2: 0.9536 - precision_2: 0.9709
# Epoch 39: val_loss improved from 0.43968 to 0.43947, saving model to files/model3.h5
# 35/35 [==============================] - 34s 979ms/step - loss: 0.1766 - dice_coef: 0.8343 - iou: 0.7164 - recall_2: 0.9536 - precision_2: 0.9709 - val_loss: 0.4395 - val_dice_coef: 0.6187 - val_iou: 0.4512 - val_recall_2: 0.7718 - val_precision_2: 0.7126 - lr: 1.0000e-05
# Epoch 40/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1748 - dice_coef: 0.8359 - iou: 0.7189 - recall_2: 0.9544 - precision_2: 0.9717
# Epoch 40: val_loss did not improve from 0.43947
# 35/35 [==============================] - 32s 896ms/step - loss: 0.1748 - dice_coef: 0.8359 - iou: 0.7189 - recall_2: 0.9544 - precision_2: 0.9717 - val_loss: 0.4397 - val_dice_coef: 0.6190 - val_iou: 0.4515 - val_recall_2: 0.7710 - val_precision_2: 0.7114 - lr: 1.0000e-05
# Epoch 41/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1730 - dice_coef: 0.8376 - iou: 0.7212 - recall_2: 0.9550 - precision_2: 0.9726
# Epoch 41: val_loss did not improve from 0.43947
# 35/35 [==============================] - 31s 896ms/step - loss: 0.1730 - dice_coef: 0.8376 - iou: 0.7212 - recall_2: 0.9550 - precision_2: 0.9726 - val_loss: 0.4398 - val_dice_coef: 0.6196 - val_iou: 0.4520 - val_recall_2: 0.7714 - val_precision_2: 0.7098 - lr: 1.0000e-05
# Epoch 42/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1713 - dice_coef: 0.8391 - iou: 0.7236 - recall_2: 0.9557 - precision_2: 0.9734
# Epoch 42: val_loss did not improve from 0.43947
# 35/35 [==============================] - 31s 897ms/step - loss: 0.1713 - dice_coef: 0.8391 - iou: 0.7236 - recall_2: 0.9557 - precision_2: 0.9734 - val_loss: 0.4406 - val_dice_coef: 0.6193 - val_iou: 0.4517 - val_recall_2: 0.7702 - val_precision_2: 0.7082 - lr: 1.0000e-05
# Epoch 43/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1696 - dice_coef: 0.8407 - iou: 0.7258 - recall_2: 0.9562 - precision_2: 0.9741
# Epoch 43: val_loss did not improve from 0.43947
# 35/35 [==============================] - 31s 897ms/step - loss: 0.1696 - dice_coef: 0.8407 - iou: 0.7258 - recall_2: 0.9562 - precision_2: 0.9741 - val_loss: 0.4414 - val_dice_coef: 0.6191 - val_iou: 0.4513 - val_recall_2: 0.7692 - val_precision_2: 0.7068 - lr: 1.0000e-05
# Epoch 44/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1680 - dice_coef: 0.8421 - iou: 0.7281 - recall_2: 0.9568 - precision_2: 0.9748
# Epoch 44: val_loss did not improve from 0.43947
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1e-06.
# 35/35 [==============================] - 31s 898ms/step - loss: 0.1680 - dice_coef: 0.8421 - iou: 0.7281 - recall_2: 0.9568 - precision_2: 0.9748 - val_loss: 0.4426 - val_dice_coef: 0.6186 - val_iou: 0.4507 - val_recall_2: 0.7673 - val_precision_2: 0.7052 - lr: 1.0000e-05
# Epoch 45/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1661 - dice_coef: 0.8437 - iou: 0.7304 - recall_2: 0.9547 - precision_2: 0.9780
# Epoch 45: val_loss did not improve from 0.43947
# 35/35 [==============================] - 31s 898ms/step - loss: 0.1661 - dice_coef: 0.8437 - iou: 0.7304 - recall_2: 0.9547 - precision_2: 0.9780 - val_loss: 0.4405 - val_dice_coef: 0.6210 - val_iou: 0.4531 - val_recall_2: 0.7720 - val_precision_2: 0.7058 - lr: 1.0000e-06
# Epoch 46/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1658 - dice_coef: 0.8441 - iou: 0.7309 - recall_2: 0.9570 - precision_2: 0.9771
# Epoch 46: val_loss improved from 0.43947 to 0.43890, saving model to files/model3.h5
# 35/35 [==============================] - 34s 975ms/step - loss: 0.1658 - dice_coef: 0.8441 - iou: 0.7309 - recall_2: 0.9570 - precision_2: 0.9771 - val_loss: 0.4389 - val_dice_coef: 0.6232 - val_iou: 0.4553 - val_recall_2: 0.7770 - val_precision_2: 0.7049 - lr: 1.0000e-06
# Epoch 47/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1655 - dice_coef: 0.8443 - iou: 0.7312 - recall_2: 0.9580 - precision_2: 0.9767
# Epoch 47: val_loss improved from 0.43890 to 0.43804, saving model to files/model3.h5
# 35/35 [==============================] - 34s 973ms/step - loss: 0.1655 - dice_coef: 0.8443 - iou: 0.7312 - recall_2: 0.9580 - precision_2: 0.9767 - val_loss: 0.4380 - val_dice_coef: 0.6245 - val_iou: 0.4565 - val_recall_2: 0.7796 - val_precision_2: 0.7041 - lr: 1.0000e-06
# Epoch 48/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1654 - dice_coef: 0.8445 - iou: 0.7315 - recall_2: 0.9583 - precision_2: 0.9766
# Epoch 48: val_loss improved from 0.43804 to 0.43754, saving model to files/model3.h5
# 35/35 [==============================] - 34s 981ms/step - loss: 0.1654 - dice_coef: 0.8445 - iou: 0.7315 - recall_2: 0.9583 - precision_2: 0.9766 - val_loss: 0.4375 - val_dice_coef: 0.6253 - val_iou: 0.4573 - val_recall_2: 0.7817 - val_precision_2: 0.7037 - lr: 1.0000e-06
# Epoch 49/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1652 - dice_coef: 0.8446 - iou: 0.7317 - recall_2: 0.9585 - precision_2: 0.9766
# Epoch 49: val_loss improved from 0.43754 to 0.43725, saving model to files/model3.h5
# 35/35 [==============================] - 34s 975ms/step - loss: 0.1652 - dice_coef: 0.8446 - iou: 0.7317 - recall_2: 0.9585 - precision_2: 0.9766 - val_loss: 0.4373 - val_dice_coef: 0.6259 - val_iou: 0.4579 - val_recall_2: 0.7830 - val_precision_2: 0.7034 - lr: 1.0000e-06
# Epoch 50/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1650 - dice_coef: 0.8448 - iou: 0.7320 - recall_2: 0.9585 - precision_2: 0.9766
# Epoch 50: val_loss improved from 0.43725 to 0.43711, saving model to files/model3.h5
# 35/35 [==============================] - 34s 973ms/step - loss: 0.1650 - dice_coef: 0.8448 - iou: 0.7320 - recall_2: 0.9585 - precision_2: 0.9766 - val_loss: 0.4371 - val_dice_coef: 0.6262 - val_iou: 0.4582 - val_recall_2: 0.7842 - val_precision_2: 0.7031 - lr: 1.0000e-06

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 2
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model4.h5")
csv_path = os.path.join("files", "data4.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model4 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 1024], strides=[1, 2, 2, 2])

model4.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model4.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 140 - 140
# Valid: 20 - 20
# Epoch 1/50
# 70/70 [==============================] - ETA: 0s - loss: 1.1217 - dice_coef: 0.1385 - iou: 0.0757 - recall_3: 0.5957 - precision_3: 0.2823
# Epoch 1: val_loss improved from inf to 1.57340, saving model to files/model4.h5
# 70/70 [==============================] - 44s 474ms/step - loss: 1.1217 - dice_coef: 0.1385 - iou: 0.0757 - recall_3: 0.5957 - precision_3: 0.2823 - val_loss: 1.5734 - val_dice_coef: 0.0260 - val_iou: 0.0132 - val_recall_3: 0.0140 - val_precision_3: 0.0022 - lr: 1.0000e-04
# Epoch 2/50
# 70/70 [==============================] - ETA: 0s - loss: 0.9052 - dice_coef: 0.2380 - iou: 0.1364 - recall_3: 0.7361 - precision_3: 0.5825
# Epoch 2: val_loss improved from 1.57340 to 1.18147, saving model to files/model4.h5
# 70/70 [==============================] - 34s 492ms/step - loss: 0.9052 - dice_coef: 0.2380 - iou: 0.1364 - recall_3: 0.7361 - precision_3: 0.5825 - val_loss: 1.1815 - val_dice_coef: 0.0319 - val_iou: 0.0162 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00 - lr: 1.0000e-04
# Epoch 3/50
# 70/70 [==============================] - ETA: 0s - loss: 0.8091 - dice_coef: 0.3029 - iou: 0.1804 - recall_3: 0.7917 - precision_3: 0.6338
# Epoch 3: val_loss improved from 1.18147 to 1.10083, saving model to files/model4.h5
# 70/70 [==============================] - 35s 491ms/step - loss: 0.8091 - dice_coef: 0.3029 - iou: 0.1804 - recall_3: 0.7917 - precision_3: 0.6338 - val_loss: 1.1008 - val_dice_coef: 0.0298 - val_iou: 0.0151 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00 - lr: 1.0000e-04
# Epoch 4/50
# 70/70 [==============================] - ETA: 0s - loss: 0.7096 - dice_coef: 0.3707 - iou: 0.2296 - recall_3: 0.8389 - precision_3: 0.7314
# Epoch 4: val_loss improved from 1.10083 to 1.06702, saving model to files/model4.h5
# 70/70 [==============================] - 35s 493ms/step - loss: 0.7096 - dice_coef: 0.3707 - iou: 0.2296 - recall_3: 0.8389 - precision_3: 0.7314 - val_loss: 1.0670 - val_dice_coef: 0.0300 - val_iou: 0.0152 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00 - lr: 1.0000e-04
# Epoch 5/50
# 70/70 [==============================] - ETA: 0s - loss: 0.6626 - dice_coef: 0.4113 - iou: 0.2612 - recall_3: 0.8488 - precision_3: 0.7228
# Epoch 5: val_loss improved from 1.06702 to 1.03896, saving model to files/model4.h5
# 70/70 [==============================] - 35s 491ms/step - loss: 0.6626 - dice_coef: 0.4113 - iou: 0.2612 - recall_3: 0.8488 - precision_3: 0.7228 - val_loss: 1.0390 - val_dice_coef: 0.0423 - val_iou: 0.0216 - val_recall_3: 0.0177 - val_precision_3: 0.9004 - lr: 1.0000e-04
# Epoch 6/50
# 70/70 [==============================] - ETA: 0s - loss: 0.5981 - dice_coef: 0.4613 - iou: 0.3021 - recall_3: 0.8667 - precision_3: 0.7716
# Epoch 6: val_loss improved from 1.03896 to 0.98356, saving model to files/model4.h5
# 70/70 [==============================] - 35s 492ms/step - loss: 0.5981 - dice_coef: 0.4613 - iou: 0.3021 - recall_3: 0.8667 - precision_3: 0.7716 - val_loss: 0.9836 - val_dice_coef: 0.0902 - val_iou: 0.0477 - val_recall_3: 0.1049 - val_precision_3: 0.8221 - lr: 1.0000e-04
# Epoch 7/50
# 70/70 [==============================] - ETA: 0s - loss: 0.5344 - dice_coef: 0.5154 - iou: 0.3497 - recall_3: 0.8862 - precision_3: 0.8091
# Epoch 7: val_loss improved from 0.98356 to 0.89416, saving model to files/model4.h5
# 70/70 [==============================] - 35s 496ms/step - loss: 0.5344 - dice_coef: 0.5154 - iou: 0.3497 - recall_3: 0.8862 - precision_3: 0.8091 - val_loss: 0.8942 - val_dice_coef: 0.1790 - val_iou: 0.0993 - val_recall_3: 0.2775 - val_precision_3: 0.5541 - lr: 1.0000e-04
# Epoch 8/50
# 70/70 [==============================] - ETA: 0s - loss: 0.4937 - dice_coef: 0.5513 - iou: 0.3836 - recall_3: 0.8825 - precision_3: 0.8166
# Epoch 8: val_loss did not improve from 0.89416
# 70/70 [==============================] - 32s 449ms/step - loss: 0.4937 - dice_coef: 0.5513 - iou: 0.3836 - recall_3: 0.8825 - precision_3: 0.8166 - val_loss: 0.9660 - val_dice_coef: 0.1015 - val_iou: 0.0556 - val_recall_3: 0.1179 - val_precision_3: 0.8225 - lr: 1.0000e-04
# Epoch 9/50
# 70/70 [==============================] - ETA: 0s - loss: 0.4456 - dice_coef: 0.5956 - iou: 0.4269 - recall_3: 0.8924 - precision_3: 0.8317
# Epoch 9: val_loss improved from 0.89416 to 0.63378, saving model to files/model4.h5
# 70/70 [==============================] - 34s 491ms/step - loss: 0.4456 - dice_coef: 0.5956 - iou: 0.4269 - recall_3: 0.8924 - precision_3: 0.8317 - val_loss: 0.6338 - val_dice_coef: 0.4379 - val_iou: 0.2929 - val_recall_3: 0.7709 - val_precision_3: 0.6803 - lr: 1.0000e-04
# Epoch 10/50
# 70/70 [==============================] - ETA: 0s - loss: 0.4082 - dice_coef: 0.6277 - iou: 0.4608 - recall_3: 0.8887 - precision_3: 0.8400
# Epoch 10: val_loss did not improve from 0.63378
# 70/70 [==============================] - 32s 449ms/step - loss: 0.4082 - dice_coef: 0.6277 - iou: 0.4608 - recall_3: 0.8887 - precision_3: 0.8400 - val_loss: 0.8813 - val_dice_coef: 0.3562 - val_iou: 0.2316 - val_recall_3: 0.9114 - val_precision_3: 0.2759 - lr: 1.0000e-04
# Epoch 11/50
# 70/70 [==============================] - ETA: 0s - loss: 0.3664 - dice_coef: 0.6656 - iou: 0.5022 - recall_3: 0.8942 - precision_3: 0.8560
# Epoch 11: val_loss improved from 0.63378 to 0.57063, saving model to files/model4.h5
# 70/70 [==============================] - 34s 493ms/step - loss: 0.3664 - dice_coef: 0.6656 - iou: 0.5022 - recall_3: 0.8942 - precision_3: 0.8560 - val_loss: 0.5706 - val_dice_coef: 0.4950 - val_iou: 0.3462 - val_recall_3: 0.7672 - val_precision_3: 0.6640 - lr: 1.0000e-04
# Epoch 12/50
# 70/70 [==============================] - ETA: 0s - loss: 0.3216 - dice_coef: 0.7057 - iou: 0.5484 - recall_3: 0.9187 - precision_3: 0.8742
# Epoch 12: val_loss improved from 0.57063 to 0.55040, saving model to files/model4.h5
# 70/70 [==============================] - 34s 489ms/step - loss: 0.3216 - dice_coef: 0.7057 - iou: 0.5484 - recall_3: 0.9187 - precision_3: 0.8742 - val_loss: 0.5504 - val_dice_coef: 0.5067 - val_iou: 0.3565 - val_recall_3: 0.7277 - val_precision_3: 0.7053 - lr: 1.0000e-04
# Epoch 13/50
# 70/70 [==============================] - ETA: 0s - loss: 0.2947 - dice_coef: 0.7299 - iou: 0.5775 - recall_3: 0.9134 - precision_3: 0.8899
# Epoch 13: val_loss did not improve from 0.55040
# 70/70 [==============================] - 32s 449ms/step - loss: 0.2947 - dice_coef: 0.7299 - iou: 0.5775 - recall_3: 0.9134 - precision_3: 0.8899 - val_loss: 1.4574 - val_dice_coef: 0.2619 - val_iou: 0.1591 - val_recall_3: 0.8309 - val_precision_3: 0.1306 - lr: 1.0000e-04
# Epoch 14/50
# 70/70 [==============================] - ETA: 0s - loss: 0.2749 - dice_coef: 0.7499 - iou: 0.6038 - recall_3: 0.9026 - precision_3: 0.8904
# Epoch 14: val_loss improved from 0.55040 to 0.53848, saving model to files/model4.h5
# 70/70 [==============================] - 34s 492ms/step - loss: 0.2749 - dice_coef: 0.7499 - iou: 0.6038 - recall_3: 0.9026 - precision_3: 0.8904 - val_loss: 0.5385 - val_dice_coef: 0.5335 - val_iou: 0.3874 - val_recall_3: 0.7518 - val_precision_3: 0.6250 - lr: 1.0000e-04
# Epoch 15/50
# 70/70 [==============================] - ETA: 0s - loss: 0.2405 - dice_coef: 0.7799 - iou: 0.6419 - recall_3: 0.9151 - precision_3: 0.9080
# Epoch 15: val_loss did not improve from 0.53848
# 70/70 [==============================] - 32s 449ms/step - loss: 0.2405 - dice_coef: 0.7799 - iou: 0.6419 - recall_3: 0.9151 - precision_3: 0.9080 - val_loss: 0.6619 - val_dice_coef: 0.4729 - val_iou: 0.3368 - val_recall_3: 0.7056 - val_precision_3: 0.3946 - lr: 1.0000e-04
# Epoch 16/50
# 70/70 [==============================] - ETA: 0s - loss: 0.2382 - dice_coef: 0.7836 - iou: 0.6475 - recall_3: 0.8968 - precision_3: 0.9001
# Epoch 16: val_loss improved from 0.53848 to 0.49297, saving model to files/model4.h5
# 70/70 [==============================] - 34s 490ms/step - loss: 0.2382 - dice_coef: 0.7836 - iou: 0.6475 - recall_3: 0.8968 - precision_3: 0.9001 - val_loss: 0.4930 - val_dice_coef: 0.5896 - val_iou: 0.4517 - val_recall_3: 0.8279 - val_precision_3: 0.6179 - lr: 1.0000e-04
# Epoch 17/50
# 70/70 [==============================] - ETA: 0s - loss: 0.2226 - dice_coef: 0.7991 - iou: 0.6688 - recall_3: 0.9049 - precision_3: 0.8998
# Epoch 17: val_loss did not improve from 0.49297
# 70/70 [==============================] - 32s 449ms/step - loss: 0.2226 - dice_coef: 0.7991 - iou: 0.6688 - recall_3: 0.9049 - precision_3: 0.8998 - val_loss: 0.6209 - val_dice_coef: 0.5251 - val_iou: 0.3917 - val_recall_3: 0.8781 - val_precision_3: 0.4212 - lr: 1.0000e-04
# Epoch 18/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1910 - dice_coef: 0.8259 - iou: 0.7056 - recall_3: 0.9205 - precision_3: 0.9202
# Epoch 18: val_loss did not improve from 0.49297
# 70/70 [==============================] - 31s 450ms/step - loss: 0.1910 - dice_coef: 0.8259 - iou: 0.7056 - recall_3: 0.9205 - precision_3: 0.9202 - val_loss: 0.5130 - val_dice_coef: 0.5689 - val_iou: 0.4360 - val_recall_3: 0.7698 - val_precision_3: 0.5168 - lr: 1.0000e-04
# Epoch 19/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1802 - dice_coef: 0.8360 - iou: 0.7205 - recall_3: 0.9167 - precision_3: 0.9285
# Epoch 19: val_loss did not improve from 0.49297
# 70/70 [==============================] - 31s 450ms/step - loss: 0.1802 - dice_coef: 0.8360 - iou: 0.7205 - recall_3: 0.9167 - precision_3: 0.9285 - val_loss: 0.6310 - val_dice_coef: 0.5370 - val_iou: 0.4005 - val_recall_3: 0.9226 - val_precision_3: 0.3998 - lr: 1.0000e-04
# Epoch 20/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1954 - dice_coef: 0.8248 - iou: 0.7060 - recall_3: 0.9012 - precision_3: 0.9028
# Epoch 20: val_loss did not improve from 0.49297
# 70/70 [==============================] - 31s 450ms/step - loss: 0.1954 - dice_coef: 0.8248 - iou: 0.7060 - recall_3: 0.9012 - precision_3: 0.9028 - val_loss: 0.7471 - val_dice_coef: 0.4855 - val_iou: 0.3521 - val_recall_3: 0.9181 - val_precision_3: 0.3382 - lr: 1.0000e-04
# Epoch 21/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1670 - dice_coef: 0.8490 - iou: 0.7400 - recall_3: 0.9144 - precision_3: 0.9260
# Epoch 21: val_loss did not improve from 0.49297
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 70/70 [==============================] - 32s 450ms/step - loss: 0.1670 - dice_coef: 0.8490 - iou: 0.7400 - recall_3: 0.9144 - precision_3: 0.9260 - val_loss: 0.5913 - val_dice_coef: 0.4775 - val_iou: 0.3315 - val_recall_3: 0.4836 - val_precision_3: 0.6618 - lr: 1.0000e-04
# Epoch 22/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1470 - dice_coef: 0.8663 - iou: 0.7664 - recall_3: 0.9148 - precision_3: 0.9492
# Epoch 22: val_loss did not improve from 0.49297
# 70/70 [==============================] - 32s 450ms/step - loss: 0.1470 - dice_coef: 0.8663 - iou: 0.7664 - recall_3: 0.9148 - precision_3: 0.9492 - val_loss: 0.5040 - val_dice_coef: 0.5582 - val_iou: 0.4128 - val_recall_3: 0.5956 - val_precision_3: 0.6948 - lr: 1.0000e-05
# Epoch 23/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1374 - dice_coef: 0.8743 - iou: 0.7783 - recall_3: 0.9269 - precision_3: 0.9543
# Epoch 23: val_loss did not improve from 0.49297
# 70/70 [==============================] - 32s 450ms/step - loss: 0.1374 - dice_coef: 0.8743 - iou: 0.7783 - recall_3: 0.9269 - precision_3: 0.9543 - val_loss: 0.5072 - val_dice_coef: 0.5523 - val_iou: 0.4044 - val_recall_3: 0.5769 - val_precision_3: 0.7035 - lr: 1.0000e-05
# Epoch 24/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1314 - dice_coef: 0.8793 - iou: 0.7859 - recall_3: 0.9353 - precision_3: 0.9584
# Epoch 24: val_loss improved from 0.49297 to 0.49179, saving model to files/model4.h5
# 70/70 [==============================] - 35s 499ms/step - loss: 0.1314 - dice_coef: 0.8793 - iou: 0.7859 - recall_3: 0.9353 - precision_3: 0.9584 - val_loss: 0.4918 - val_dice_coef: 0.5672 - val_iou: 0.4195 - val_recall_3: 0.5961 - val_precision_3: 0.7063 - lr: 1.0000e-05
# Epoch 25/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1282 - dice_coef: 0.8821 - iou: 0.7904 - recall_3: 0.9373 - precision_3: 0.9611
# Epoch 25: val_loss did not improve from 0.49179
# 70/70 [==============================] - 32s 450ms/step - loss: 0.1282 - dice_coef: 0.8821 - iou: 0.7904 - recall_3: 0.9373 - precision_3: 0.9611 - val_loss: 0.4955 - val_dice_coef: 0.5632 - val_iou: 0.4150 - val_recall_3: 0.5867 - val_precision_3: 0.7065 - lr: 1.0000e-05
# Epoch 26/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1256 - dice_coef: 0.8845 - iou: 0.7941 - recall_3: 0.9388 - precision_3: 0.9628
# Epoch 26: val_loss improved from 0.49179 to 0.49055, saving model to files/model4.h5
# 70/70 [==============================] - 35s 493ms/step - loss: 0.1256 - dice_coef: 0.8845 - iou: 0.7941 - recall_3: 0.9388 - precision_3: 0.9628 - val_loss: 0.4906 - val_dice_coef: 0.5683 - val_iou: 0.4204 - val_recall_3: 0.5946 - val_precision_3: 0.7071 - lr: 1.0000e-05
# Epoch 27/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1231 - dice_coef: 0.8867 - iou: 0.7976 - recall_3: 0.9403 - precision_3: 0.9645
# Epoch 27: val_loss did not improve from 0.49055
# 70/70 [==============================] - 32s 449ms/step - loss: 0.1231 - dice_coef: 0.8867 - iou: 0.7976 - recall_3: 0.9403 - precision_3: 0.9645 - val_loss: 0.5027 - val_dice_coef: 0.5562 - val_iou: 0.4079 - val_recall_3: 0.5728 - val_precision_3: 0.7082 - lr: 1.0000e-05
# Epoch 28/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1207 - dice_coef: 0.8888 - iou: 0.8010 - recall_3: 0.9417 - precision_3: 0.9658
# Epoch 28: val_loss did not improve from 0.49055
# 70/70 [==============================] - 31s 450ms/step - loss: 0.1207 - dice_coef: 0.8888 - iou: 0.8010 - recall_3: 0.9417 - precision_3: 0.9658 - val_loss: 0.5101 - val_dice_coef: 0.5489 - val_iou: 0.4013 - val_recall_3: 0.5608 - val_precision_3: 0.7091 - lr: 1.0000e-05
# Epoch 29/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1182 - dice_coef: 0.8910 - iou: 0.8045 - recall_3: 0.9433 - precision_3: 0.9672
# Epoch 29: val_loss did not improve from 0.49055
# 70/70 [==============================] - 32s 450ms/step - loss: 0.1182 - dice_coef: 0.8910 - iou: 0.8045 - recall_3: 0.9433 - precision_3: 0.9672 - val_loss: 0.5128 - val_dice_coef: 0.5464 - val_iou: 0.3994 - val_recall_3: 0.5566 - val_precision_3: 0.7089 - lr: 1.0000e-05
# Epoch 30/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1161 - dice_coef: 0.8929 - iou: 0.8076 - recall_3: 0.9443 - precision_3: 0.9683
# Epoch 30: val_loss did not improve from 0.49055
# 70/70 [==============================] - 32s 450ms/step - loss: 0.1161 - dice_coef: 0.8929 - iou: 0.8076 - recall_3: 0.9443 - precision_3: 0.9683 - val_loss: 0.5089 - val_dice_coef: 0.5507 - val_iou: 0.4041 - val_recall_3: 0.5645 - val_precision_3: 0.7089 - lr: 1.0000e-05
# Epoch 31/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1140 - dice_coef: 0.8948 - iou: 0.8105 - recall_3: 0.9452 - precision_3: 0.9697
# Epoch 31: val_loss did not improve from 0.49055
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1e-06.
# 70/70 [==============================] - 32s 450ms/step - loss: 0.1140 - dice_coef: 0.8948 - iou: 0.8105 - recall_3: 0.9452 - precision_3: 0.9697 - val_loss: 0.5096 - val_dice_coef: 0.5504 - val_iou: 0.4045 - val_recall_3: 0.5634 - val_precision_3: 0.7077 - lr: 1.0000e-05
# Epoch 32/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1121 - dice_coef: 0.8964 - iou: 0.8131 - recall_3: 0.9398 - precision_3: 0.9753
# Epoch 32: val_loss did not improve from 0.49055
# Epoch 44/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1085 - dice_coef: 0.8996 - iou: 0.8184 - recall_3: 0.9484 - precision_3: 0.9732
# Epoch 44: val_loss did not improve from 0.48593
# 70/70 [==============================] - 32s 450ms/step - loss: 0.1085 - dice_coef: 0.8996 - iou: 0.8184 - recall_3: 0.9484 - precision_3: 0.9732 - val_loss: 0.4876 - val_dice_coef: 0.5742 - val_iou: 0.4318 - val_recall_3: 0.6049 - val_precision_3: 0.7043 - lr: 1.0000e-06
# Epoch 45/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1083 - dice_coef: 0.8998 - iou: 0.8188 - recall_3: 0.9485 - precision_3: 0.9733
# Epoch 45: val_loss did not improve from 0.48593
# 70/70 [==============================] - 32s 450ms/step - loss: 0.1083 - dice_coef: 0.8998 - iou: 0.8188 - recall_3: 0.9485 - precision_3: 0.9733 - val_loss: 0.4878 - val_dice_coef: 0.5740 - val_iou: 0.4316 - val_recall_3: 0.6047 - val_precision_3: 0.7042 - lr: 1.0000e-06
# Epoch 46/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1080 - dice_coef: 0.9001 - iou: 0.8191 - recall_3: 0.9486 - precision_3: 0.9734
# Epoch 46: val_loss did not improve from 0.48593
# 70/70 [==============================] - 32s 450ms/step - loss: 0.1080 - dice_coef: 0.9001 - iou: 0.8191 - recall_3: 0.9486 - precision_3: 0.9734 - val_loss: 0.4881 - val_dice_coef: 0.5737 - val_iou: 0.4315 - val_recall_3: 0.6044 - val_precision_3: 0.7041 - lr: 1.0000e-06

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 1
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model5.h5")
csv_path = os.path.join("files", "data5.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model5 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 1280], strides=[1, 2, 2, 2])

model5.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model5.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 140 - 140
# Valid: 20 - 20
# Epoch 1/50
# 140/140 [==============================] - ETA: 0s - loss: 0.9897 - dice_coef: 0.2126 - iou: 0.1222 - recall_4: 0.7436 - precision_4: 0.4142
# Epoch 1: val_loss improved from inf to 1.17464, saving model to files/model5.h5
# 140/140 [==============================] - 45s 266ms/step - loss: 0.9897 - dice_coef: 0.2126 - iou: 0.1222 - recall_4: 0.7436 - precision_4: 0.4142 - val_loss: 1.1746 - val_dice_coef: 0.0242 - val_iou: 0.0123 - val_recall_4: 0.0000e+00 - val_precision_4: 0.0000e+00 - lr: 1.0000e-04
# Epoch 2/50
# 140/140 [==============================] - ETA: 0s - loss: 0.7557 - dice_coef: 0.3447 - iou: 0.2117 - recall_4: 0.8369 - precision_4: 0.6933
# Epoch 2: val_loss improved from 1.17464 to 1.08110, saving model to files/model5.h5
# 140/140 [==============================] - 39s 277ms/step - loss: 0.7557 - dice_coef: 0.3447 - iou: 0.2117 - recall_4: 0.8369 - precision_4: 0.6933 - val_loss: 1.0811 - val_dice_coef: 0.0225 - val_iou: 0.0114 - val_recall_4: 0.0000e+00 - val_precision_4: 0.0000e+00 - lr: 1.0000e-04
# Epoch 3/50
# 140/140 [==============================] - ETA: 0s - loss: 0.6546 - dice_coef: 0.4255 - iou: 0.2758 - recall_4: 0.8382 - precision_4: 0.7234
# Epoch 3: val_loss improved from 1.08110 to 1.05760, saving model to files/model5.h5
# 140/140 [==============================] - 39s 278ms/step - loss: 0.6546 - dice_coef: 0.4255 - iou: 0.2758 - recall_4: 0.8382 - precision_4: 0.7234 - val_loss: 1.0576 - val_dice_coef: 0.0240 - val_iou: 0.0122 - val_recall_4: 0.0000e+00 - val_precision_4: 0.0000e+00 - lr: 1.0000e-04
# Epoch 4/50
# 140/140 [==============================] - ETA: 0s - loss: 0.5327 - dice_coef: 0.5210 - iou: 0.3591 - recall_4: 0.8628 - precision_4: 0.8023
# Epoch 4: val_loss improved from 1.05760 to 0.93744, saving model to files/model5.h5
# 140/140 [==============================] - 39s 281ms/step - loss: 0.5327 - dice_coef: 0.5210 - iou: 0.3591 - recall_4: 0.8628 - precision_4: 0.8023 - val_loss: 0.9374 - val_dice_coef: 0.1378 - val_iou: 0.0811 - val_recall_4: 0.2141 - val_precision_4: 0.5369 - lr: 1.0000e-04
# Epoch 5/50
# 140/140 [==============================] - ETA: 0s - loss: 0.4302 - dice_coef: 0.6092 - iou: 0.4466 - recall_4: 0.8832 - precision_4: 0.8476
# Epoch 5: val_loss improved from 0.93744 to 0.78375, saving model to files/model5.h5
# 140/140 [==============================] - 44s 313ms/step - loss: 0.4302 - dice_coef: 0.6092 - iou: 0.4466 - recall_4: 0.8832 - precision_4: 0.8476 - val_loss: 0.7837 - val_dice_coef: 0.3175 - val_iou: 0.2062 - val_recall_4: 0.5374 - val_precision_4: 0.3776 - lr: 1.0000e-04
# Epoch 6/50
# 140/140 [==============================] - ETA: 0s - loss: 0.3677 - dice_coef: 0.6665 - iou: 0.5101 - recall_4: 0.8826 - precision_4: 0.8536
# Epoch 6: val_loss did not improve from 0.78375
# 140/140 [==============================] - 35s 252ms/step - loss: 0.3677 - dice_coef: 0.6665 - iou: 0.5101 - recall_4: 0.8826 - precision_4: 0.8536 - val_loss: 1.6162 - val_dice_coef: 0.2393 - val_iou: 0.1593 - val_recall_4: 0.6340 - val_precision_4: 0.0891 - lr: 1.0000e-04
# Epoch 7/50
# 140/140 [==============================] - ETA: 0s - loss: 0.3410 - dice_coef: 0.6961 - iou: 0.5494 - recall_4: 0.8638 - precision_4: 0.8370
# Epoch 7: val_loss did not improve from 0.78375
# 140/140 [==============================] - 35s 252ms/step - loss: 0.3410 - dice_coef: 0.6961 - iou: 0.5494 - recall_4: 0.8638 - precision_4: 0.8370 - val_loss: 1.5711 - val_dice_coef: 0.3473 - val_iou: 0.2378 - val_recall_4: 0.8686 - val_precision_4: 0.1422 - lr: 1.0000e-04
# Epoch 8/50
# 140/140 [==============================] - ETA: 0s - loss: 0.3046 - dice_coef: 0.7313 - iou: 0.5929 - recall_4: 0.8594 - precision_4: 0.8412
# Epoch 8: val_loss did not improve from 0.78375
# 140/140 [==============================] - 35s 252ms/step - loss: 0.3046 - dice_coef: 0.7313 - iou: 0.5929 - recall_4: 0.8594 - precision_4: 0.8412 - val_loss: 0.8362 - val_dice_coef: 0.3888 - val_iou: 0.2783 - val_recall_4: 0.6013 - val_precision_4: 0.2171 - lr: 1.0000e-04
# Epoch 9/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2419 - dice_coef: 0.7825 - iou: 0.6563 - recall_4: 0.8849 - precision_4: 0.8875
# Epoch 9: val_loss did not improve from 0.78375
# 140/140 [==============================] - 35s 252ms/step - loss: 0.2419 - dice_coef: 0.7825 - iou: 0.6563 - recall_4: 0.8849 - precision_4: 0.8875 - val_loss: 1.4425 - val_dice_coef: 0.2088 - val_iou: 0.1397 - val_recall_4: 0.4472 - val_precision_4: 0.0773 - lr: 1.0000e-04
# Epoch 10/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2101 - dice_coef: 0.8113 - iou: 0.6960 - recall_4: 0.8882 - precision_4: 0.9087
# Epoch 10: val_loss did not improve from 0.78375
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 140/140 [==============================] - 35s 253ms/step - loss: 0.2101 - dice_coef: 0.8113 - iou: 0.6960 - recall_4: 0.8882 - precision_4: 0.9087 - val_loss: 1.1825 - val_dice_coef: 0.3345 - val_iou: 0.2358 - val_recall_4: 0.5446 - val_precision_4: 0.1293 - lr: 1.0000e-04
# Epoch 11/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1806 - dice_coef: 0.8365 - iou: 0.7316 - recall_4: 0.9003 - precision_4: 0.9328
# Epoch 11: val_loss did not improve from 0.78375
# 140/140 [==============================] - 35s 252ms/step - loss: 0.1806 - dice_coef: 0.8365 - iou: 0.7316 - recall_4: 0.9003 - precision_4: 0.9328 - val_loss: 1.0755 - val_dice_coef: 0.2266 - val_iou: 0.1486 - val_recall_4: 0.2944 - val_precision_4: 0.1171 - lr: 1.0000e-05
# Epoch 12/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1724 - dice_coef: 0.8436 - iou: 0.7412 - recall_4: 0.9014 - precision_4: 0.9439
# Epoch 12: val_loss did not improve from 0.78375
# 140/140 [==============================] - 35s 252ms/step - loss: 0.1724 - dice_coef: 0.8436 - iou: 0.7412 - recall_4: 0.9014 - precision_4: 0.9439 - val_loss: 1.0876 - val_dice_coef: 0.2509 - val_iou: 0.1676 - val_recall_4: 0.3285 - val_precision_4: 0.1246 - lr: 1.0000e-05
# Epoch 13/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1674 - dice_coef: 0.8479 - iou: 0.7471 - recall_4: 0.9044 - precision_4: 0.9471
# Epoch 13: val_loss did not improve from 0.78375
# 140/140 [==============================] - 35s 252ms/step - loss: 0.1674 - dice_coef: 0.8479 - iou: 0.7471 - recall_4: 0.9044 - precision_4: 0.9471 - val_loss: 1.0831 - val_dice_coef: 0.2533 - val_iou: 0.1690 - val_recall_4: 0.3282 - val_precision_4: 0.1281 - lr: 1.0000e-05
# Epoch 14/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1625 - dice_coef: 0.8525 - iou: 0.7536 - recall_4: 0.9066 - precision_4: 0.9506
# Epoch 14: val_loss did not improve from 0.78375
# 140/140 [==============================] - 35s 252ms/step - loss: 0.1625 - dice_coef: 0.8525 - iou: 0.7536 - recall_4: 0.9066 - precision_4: 0.9506 - val_loss: 1.0510 - val_dice_coef: 0.2534 - val_iou: 0.1684 - val_recall_4: 0.3210 - val_precision_4: 0.1339 - lr: 1.0000e-05
# Epoch 15/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1576 - dice_coef: 0.8567 - iou: 0.7592 - recall_4: 0.9104 - precision_4: 0.9532
# Epoch 15: val_loss did not improve from 0.78375
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1e-06.
# 140/140 [==============================] - 35s 252ms/step - loss: 0.1576 - dice_coef: 0.8567 - iou: 0.7592 - recall_4: 0.9104 - precision_4: 0.9532 - val_loss: 1.0193 - val_dice_coef: 0.2591 - val_iou: 0.1731 - val_recall_4: 0.3249 - val_precision_4: 0.1442 - lr: 1.0000e-05

# %% [markdown]
# ### Evaluating the Model:

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import pandas as pd
import cv2
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import accuracy_score, f1_score, jaccard_score, precision_score, recall_score
from tensorflow.keras.models import load_model

# %%
H = 512
W = 512

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.float32)
    return ori_x, x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.int32)
    return ori_x, x

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.png")))
    y = sorted(glob(os.path.join(path, "mask", "*.png")))
    return x, y

def save_results(ori_x, ori_y, y_pred, save_image_path):
    line = np.ones((H, 10, 3)) * 255

    ori_y = np.expand_dims(ori_y, axis=-1)
    ori_y = np.concatenate([ori_y, ori_y, ori_y], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1) * 255

    cat_images = np.concatenate([ori_x, line, ori_y, line, y_pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model1.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score1 = [s[1:] for s in SCORE]
score1 = np.mean(score1, axis=0)
print(f"Accuracy: {score1[0]:0.5f}")
print(f"F1: {score1[1]:0.5f}")
print(f"Jaccard: {score1[2]:0.5f}")
print(f"Recall: {score1[3]:0.5f}")
print(f"Precision: {score1[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score1.csv")
# Out:
#  10%|█         | 2/20 [00:01<00:10,  1.70it/s]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 100%|██████████| 20/20 [00:08<00:00,  2.48it/s]
# Accuracy: 0.99147
# F1: 0.66734
# Jaccard: 0.55956
# Recall: 0.76016
# Precision: 0.73194

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model2.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score2 = [s[1:] for s in SCORE]
score2 = np.mean(score2, axis=0)
print(f"Accuracy: {score2[0]:0.5f}")
print(f"F1: {score2[1]:0.5f}")
print(f"Jaccard: {score2[2]:0.5f}")
print(f"Recall: {score2[3]:0.5f}")
print(f"Precision: {score2[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score2.csv")
# Out:
# 100%|██████████| 20/20 [00:08<00:00,  2.49it/s]
# Accuracy: 0.99206
# F1: 0.72285
# Jaccard: 0.62970
# Recall: 0.86944
# Precision: 0.75392

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model3.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score3 = [s[1:] for s in SCORE]
score3 = np.mean(score3, axis=0)
print(f"Accuracy: {score3[0]:0.5f}")
print(f"F1: {score3[1]:0.5f}")
print(f"Jaccard: {score3[2]:0.5f}")
print(f"Recall: {score3[3]:0.5f}")
print(f"Precision: {score3[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score3.csv")
# Out:
# 100%|██████████| 20/20 [00:08<00:00,  2.42it/s]
# Accuracy: 0.99162
# F1: 0.71480
# Jaccard: 0.61174
# Recall: 0.84091
# Precision: 0.75855

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model4.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score4 = [s[1:] for s in SCORE]
score4 = np.mean(score4, axis=0)
print(f"Accuracy: {score4[0]:0.5f}")
print(f"F1: {score4[1]:0.5f}")
print(f"Jaccard: {score4[2]:0.5f}")
print(f"Recall: {score4[3]:0.5f}")
print(f"Precision: {score4[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score4.csv")
# Out:
#  10%|█         | 2/20 [00:01<00:14,  1.22it/s]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 100%|██████████| 20/20 [00:08<00:00,  2.28it/s]
# Accuracy: 0.99038
# F1: 0.61050
# Jaccard: 0.50124
# Recall: 0.68850
# Precision: 0.74042

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model5.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score5 = [s[1:] for s in SCORE]
score5 = np.mean(score5, axis=0)
print(f"Accuracy: {score5[0]:0.5f}")
print(f"F1: {score5[1]:0.5f}")
print(f"Jaccard: {score5[2]:0.5f}")
print(f"Recall: {score5[3]:0.5f}")
print(f"Precision: {score5[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score5.csv")
# Out:
#  10%|█         | 2/20 [00:01<00:09,  1.89it/s]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  25%|██▌       | 5/20 [00:02<00:06,  2.40it/s]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 100%|██████████| 20/20 [00:08<00:00,  2.47it/s]
# Accuracy: 0.97953
# F1: 0.47118
# Jaccard: 0.36871
# Recall: 0.63324
# Precision: 0.62956

# %%
import matplotlib.pyplot as plt

z_dim = 64
channels = [384, 512, 768, 1024, 1280]
final_score = [score1[1], score2[1], score3[1], score4[1], score5[1]]

plt.plot(channels, final_score)  
plt.show()

# %%
import pandas as pd

df = pd.read_csv("files/data5.csv")

df.head()
# Out:
#    epoch  dice_coef       iou      loss      lr  precision_4  recall_4  \
# 0      0   0.212582  0.122158  0.989744  0.0001     0.414227  0.743618
# 1      1   0.344730  0.211732  0.755653  0.0001     0.693324  0.836877
# 2      2   0.425477  0.275791  0.654627  0.0001     0.723402  0.838192
# 3      3   0.520983  0.359130  0.532744  0.0001     0.802276  0.862834
# 4      4   0.609221  0.446585  0.430222  0.0001     0.847556  0.883182
#
#    val_dice_coef   val_iou  val_loss  val_precision_4  val_recall_4
# 0       0.024214  0.012275  1.174639         0.000000      0.000000
# 1       0.022526  0.011407  1.081101         0.000000      0.000000
# 2       0.024043  0.012181  1.057599         0.000000      0.000000
# 3       0.137795  0.081133  0.937436         0.536894      0.214077
# 4       0.317474  0.206194  0.783749         0.377608      0.537443

# %%
import matplotlib.pyplot as plt

plt.plot(df["epoch"], df["dice_coef"].values)
plt.plot(df["epoch"], df["val_dice_coef"].values)
plt.legend(["train", "val"])
plt.show()
