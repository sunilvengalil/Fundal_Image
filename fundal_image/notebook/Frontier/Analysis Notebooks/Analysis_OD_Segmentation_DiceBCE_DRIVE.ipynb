# %% [markdown]
# ### Import the required libraries and modules:

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
import numpy as np

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# %cd /content/gdrive/MyDrive/Blood_Vessel_Results/ALL_BEST_RESULTS/DRIVE_OD_3
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/Blood_Vessel_Results/ALL_BEST_RESULTS/DRIVE_OD_3

# %% [markdown]
# ### Unzip the data:

# %%
# !unzip new_data.zip

# %% [markdown]
# ### Construct the Model:

# %%
def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(inputs, num_filters, strides=2):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D(strides)(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters, strides=2):
    x = Conv2DTranspose(num_filters, (2, 2), strides=strides, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape, num_filters=[64, 128, 256, 512, 1024], strides=[2, 2, 2, 2]):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, num_filters[0], strides=strides[0])
    s2, p2 = encoder_block(p1, num_filters[1], strides=strides[1])
    s3, p3 = encoder_block(p2, num_filters[2], strides=strides[2])
    s4, p4 = encoder_block(p3, num_filters[3], strides=strides[3])

    b1 = conv_block(p4, num_filters[4])

    d1 = decoder_block(b1, s4, num_filters[3], strides=strides[3])
    d2 = decoder_block(d1, s3, num_filters[2], strides=strides[2])
    d3 = decoder_block(d2, s2, num_filters[1], strides=strides[1])
    d4 = decoder_block(d3, s1, num_filters[0], strides=strides[0])

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="UNET")
    return model

input_shape = (512, 512, 3)
model = build_unet(input_shape)
model.summary()
# Out:
# Model: "UNET"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 512, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 512, 512, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 512, 512, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 512, 512, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 12  0          ['activation_3[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 25  295168      ['max_pooling2d_1[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_4[0][0]']
#  rmalization)                   6)
#
#  activation_4 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_4[0][0]']
#                                 6)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 25  590080      ['activation_4[0][0]']
#                                 6)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_5[0][0]']
#  rmalization)                   6)
#
#  activation_5 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_5[0][0]']
#                                 6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 512)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 512)  2097664    ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 64, 64, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 25  524544     ['activation_11[0][0]']
#  spose)                         6)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 51  0           ['conv2d_transpose_1[0][0]',
#                                 2)                                'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_12 (BatchN  (None, 128, 128, 25  1024       ['conv2d_12[0][0]']
#  ormalization)                  6)
#
#  activation_12 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_12[0][0]']
#                                 6)
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 25  590080      ['activation_12[0][0]']
#                                 6)
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 25  1024       ['conv2d_13[0][0]']
#  ormalization)                  6)
#
#  activation_13 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_13[0][0]']
#                                 6)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 12  131200     ['activation_13[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 256, 256, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  activation_14 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_15 (BatchN  (None, 256, 256, 12  512        ['conv2d_15[0][0]']
#  ormalization)                  8)
#
#  activation_15 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_15[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 64  32832      ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 512, 512, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 512, 512, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 512, 512, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 512, 512, 1)  65          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %% [markdown]
# ### Adding the Metrics:

# %%
def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def DiceBCELoss(y_true, y_pred):

    inputs = tf.keras.layers.Flatten()(y_true)
    targets = tf.keras.layers.Flatten()(y_pred)

    intersection = tf.reduce_sum(inputs * targets)
    dice_loss = 1 - (2.*intersection + smooth)/(tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)
    BCE = tf.keras.losses.BinaryCrossentropy()
    Dice_BCE = BCE(inputs, targets) + dice_loss

    return Dice_BCE

# %% [markdown]
# ### Training the Model:

# %%
H = 512
W = 512

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.png")))
    y = sorted(glob(os.path.join(path, "mask", "*.png")))
    return x, y

def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)
    return x, y

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)              ## (512, 512, 1)
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y, batch_size=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(4)
    return dataset

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 8
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model1.h5")
csv_path = os.path.join("files", "data1.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model1 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 1024], strides=[2, 2, 2, 4])

model1.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model1.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 140 - 140
# Valid: 20 - 20
# Epoch 1/50
# 18/18 [==============================] - ETA: 0s - loss: 1.3908 - dice_coef: 0.0705 - iou: 0.0366 - recall: 0.5912 - precision: 0.0977
# Epoch 1: val_loss improved from inf to 1.66781, saving model to files/model1.h5
# 18/18 [==============================] - 114s 5s/step - loss: 1.3908 - dice_coef: 0.0705 - iou: 0.0366 - recall: 0.5912 - precision: 0.0977 - val_loss: 1.6678 - val_dice_coef: 0.0275 - val_iou: 0.0139 - val_recall: 0.0975 - val_precision: 0.0040 - lr: 1.0000e-04
# Epoch 2/50
# 18/18 [==============================] - ETA: 0s - loss: 1.1026 - dice_coef: 0.1334 - iou: 0.0717 - recall: 0.6527 - precision: 0.5422
# Epoch 2: val_loss improved from 1.66781 to 1.64567, saving model to files/model1.h5
# 18/18 [==============================] - 17s 944ms/step - loss: 1.1026 - dice_coef: 0.1334 - iou: 0.0717 - recall: 0.6527 - precision: 0.5422 - val_loss: 1.6457 - val_dice_coef: 0.0271 - val_iou: 0.0137 - val_recall: 9.9880e-04 - val_precision: 6.4209e-05 - lr: 1.0000e-04
# Epoch 3/50
# 18/18 [==============================] - ETA: 0s - loss: 0.9594 - dice_coef: 0.1994 - iou: 0.1110 - recall: 0.7691 - precision: 0.6911
# Epoch 3: val_loss improved from 1.64567 to 1.59213, saving model to files/model1.h5
# 18/18 [==============================] - 19s 1s/step - loss: 0.9594 - dice_coef: 0.1994 - iou: 0.1110 - recall: 0.7691 - precision: 0.6911 - val_loss: 1.5921 - val_dice_coef: 0.0274 - val_iou: 0.0139 - val_recall: 1.2331e-05 - val_precision: 4.6891e-05 - lr: 1.0000e-04
# Epoch 4/50
# 18/18 [==============================] - ETA: 0s - loss: 0.8755 - dice_coef: 0.2492 - iou: 0.1426 - recall: 0.8496 - precision: 0.7639
# Epoch 4: val_loss improved from 1.59213 to 1.49784, saving model to files/model1.h5
# 18/18 [==============================] - 19s 1s/step - loss: 0.8755 - dice_coef: 0.2492 - iou: 0.1426 - recall: 0.8496 - precision: 0.7639 - val_loss: 1.4978 - val_dice_coef: 0.0269 - val_iou: 0.0136 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 5/50
# 18/18 [==============================] - ETA: 0s - loss: 0.8285 - dice_coef: 0.2798 - iou: 0.1629 - recall: 0.8802 - precision: 0.8046
# Epoch 5: val_loss improved from 1.49784 to 1.41482, saving model to files/model1.h5
# 18/18 [==============================] - 19s 1s/step - loss: 0.8285 - dice_coef: 0.2798 - iou: 0.1629 - recall: 0.8802 - precision: 0.8046 - val_loss: 1.4148 - val_dice_coef: 0.0265 - val_iou: 0.0134 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 6/50
# 18/18 [==============================] - ETA: 0s - loss: 0.8026 - dice_coef: 0.2984 - iou: 0.1756 - recall: 0.8870 - precision: 0.7867
# Epoch 6: val_loss improved from 1.41482 to 1.34033, saving model to files/model1.h5
# 18/18 [==============================] - 19s 1s/step - loss: 0.8026 - dice_coef: 0.2984 - iou: 0.1756 - recall: 0.8870 - precision: 0.7867 - val_loss: 1.3403 - val_dice_coef: 0.0267 - val_iou: 0.0135 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 7/50
# 18/18 [==============================] - ETA: 0s - loss: 0.7679 - dice_coef: 0.3229 - iou: 0.1928 - recall: 0.9108 - precision: 0.8145
# Epoch 7: val_loss improved from 1.34033 to 1.26818, saving model to files/model1.h5
# 18/18 [==============================] - 19s 1s/step - loss: 0.7679 - dice_coef: 0.3229 - iou: 0.1928 - recall: 0.9108 - precision: 0.8145 - val_loss: 1.2682 - val_dice_coef: 0.0276 - val_iou: 0.0140 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 8/50
# 18/18 [==============================] - ETA: 0s - loss: 0.7344 - dice_coef: 0.3471 - iou: 0.2103 - recall: 0.9331 - precision: 0.8522
# Epoch 8: val_loss improved from 1.26818 to 1.21300, saving model to files/model1.h5
# 18/18 [==============================] - 19s 1s/step - loss: 0.7344 - dice_coef: 0.3471 - iou: 0.2103 - recall: 0.9331 - precision: 0.8522 - val_loss: 1.2130 - val_dice_coef: 0.0286 - val_iou: 0.0145 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 9/50
# 18/18 [==============================] - ETA: 0s - loss: 0.7105 - dice_coef: 0.3640 - iou: 0.2229 - recall: 0.9351 - precision: 0.8734
# Epoch 9: val_loss improved from 1.21300 to 1.16953, saving model to files/model1.h5
# 18/18 [==============================] - 17s 952ms/step - loss: 0.7105 - dice_coef: 0.3640 - iou: 0.2229 - recall: 0.9351 - precision: 0.8734 - val_loss: 1.1695 - val_dice_coef: 0.0296 - val_iou: 0.0150 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 10/50
# 18/18 [==============================] - ETA: 0s - loss: 0.6905 - dice_coef: 0.3799 - iou: 0.2349 - recall: 0.9381 - precision: 0.8815
# Epoch 10: val_loss improved from 1.16953 to 1.14488, saving model to files/model1.h5
# 18/18 [==============================] - 19s 1s/step - loss: 0.6905 - dice_coef: 0.3799 - iou: 0.2349 - recall: 0.9381 - precision: 0.8815 - val_loss: 1.1449 - val_dice_coef: 0.0290 - val_iou: 0.0147 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 11/50
# 18/18 [==============================] - ETA: 0s - loss: 0.6749 - dice_coef: 0.3928 - iou: 0.2449 - recall: 0.9393 - precision: 0.8755
# Epoch 11: val_loss improved from 1.14488 to 1.11763, saving model to files/model1.h5
# 18/18 [==============================] - 17s 954ms/step - loss: 0.6749 - dice_coef: 0.3928 - iou: 0.2449 - recall: 0.9393 - precision: 0.8755 - val_loss: 1.1176 - val_dice_coef: 0.0283 - val_iou: 0.0144 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 12/50
# 18/18 [==============================] - ETA: 0s - loss: 0.6517 - dice_coef: 0.4105 - iou: 0.2587 - recall: 0.9504 - precision: 0.8907
# Epoch 12: val_loss improved from 1.11763 to 1.10683, saving model to files/model1.h5
# 18/18 [==============================] - 19s 1s/step - loss: 0.6517 - dice_coef: 0.4105 - iou: 0.2587 - recall: 0.9504 - precision: 0.8907 - val_loss: 1.1068 - val_dice_coef: 0.0265 - val_iou: 0.0135 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 13/50
# 18/18 [==============================] - ETA: 0s - loss: 0.6326 - dice_coef: 0.4262 - iou: 0.2714 - recall: 0.9568 - precision: 0.8968
# Epoch 13: val_loss improved from 1.10683 to 1.09593, saving model to files/model1.h5
# 18/18 [==============================] - 18s 954ms/step - loss: 0.6326 - dice_coef: 0.4262 - iou: 0.2714 - recall: 0.9568 - precision: 0.8968 - val_loss: 1.0959 - val_dice_coef: 0.0272 - val_iou: 0.0138 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 14/50
# 18/18 [==============================] - ETA: 0s - loss: 0.6172 - dice_coef: 0.4381 - iou: 0.2811 - recall: 0.9500 - precision: 0.9082
# Epoch 14: val_loss improved from 1.09593 to 1.08965, saving model to files/model1.h5
# 18/18 [==============================] - 19s 1s/step - loss: 0.6172 - dice_coef: 0.4381 - iou: 0.2811 - recall: 0.9500 - precision: 0.9082 - val_loss: 1.0896 - val_dice_coef: 0.0258 - val_iou: 0.0131 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 15/50
# 18/18 [==============================] - ETA: 0s - loss: 0.6063 - dice_coef: 0.4477 - iou: 0.2890 - recall: 0.9409 - precision: 0.9022
# Epoch 15: val_loss improved from 1.08965 to 1.07064, saving model to files/model1.h5
# 18/18 [==============================] - 17s 957ms/step - loss: 0.6063 - dice_coef: 0.4477 - iou: 0.2890 - recall: 0.9409 - precision: 0.9022 - val_loss: 1.0706 - val_dice_coef: 0.0334 - val_iou: 0.0170 - val_recall: 0.0026 - val_precision: 1.0000 - lr: 1.0000e-04
# Epoch 16/50
# 18/18 [==============================] - ETA: 0s - loss: 0.5906 - dice_coef: 0.4607 - iou: 0.2999 - recall: 0.9489 - precision: 0.8993
# Epoch 16: val_loss did not improve from 1.07064
# 18/18 [==============================] - 16s 877ms/step - loss: 0.5906 - dice_coef: 0.4607 - iou: 0.2999 - recall: 0.9489 - precision: 0.8993 - val_loss: 1.0725 - val_dice_coef: 0.0255 - val_iou: 0.0129 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 17/50
# 18/18 [==============================] - ETA: 0s - loss: 0.5780 - dice_coef: 0.4720 - iou: 0.3095 - recall: 0.9464 - precision: 0.8962
# Epoch 17: val_loss improved from 1.07064 to 1.07010, saving model to files/model1.h5
# 18/18 [==============================] - 19s 1s/step - loss: 0.5780 - dice_coef: 0.4720 - iou: 0.3095 - recall: 0.9464 - precision: 0.8962 - val_loss: 1.0701 - val_dice_coef: 0.0249 - val_iou: 0.0126 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 18/50
# 18/18 [==============================] - ETA: 0s - loss: 0.5696 - dice_coef: 0.4796 - iou: 0.3162 - recall: 0.9408 - precision: 0.8885
# Epoch 18: val_loss improved from 1.07010 to 1.06954, saving model to files/model1.h5
# 18/18 [==============================] - 19s 1s/step - loss: 0.5696 - dice_coef: 0.4796 - iou: 0.3162 - recall: 0.9408 - precision: 0.8885 - val_loss: 1.0695 - val_dice_coef: 0.0230 - val_iou: 0.0117 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 19/50
# 18/18 [==============================] - ETA: 0s - loss: 0.5464 - dice_coef: 0.4977 - iou: 0.3321 - recall: 0.9523 - precision: 0.9131
# Epoch 19: val_loss improved from 1.06954 to 1.05810, saving model to files/model1.h5
# 18/18 [==============================] - 19s 1s/step - loss: 0.5464 - dice_coef: 0.4977 - iou: 0.3321 - recall: 0.9523 - precision: 0.9131 - val_loss: 1.0581 - val_dice_coef: 0.0330 - val_iou: 0.0168 - val_recall: 0.0102 - val_precision: 1.0000 - lr: 1.0000e-04
# Epoch 20/50
# 18/18 [==============================] - ETA: 0s - loss: 0.5289 - dice_coef: 0.5132 - iou: 0.3460 - recall: 0.9597 - precision: 0.9159
# Epoch 20: val_loss did not improve from 1.05810
# 18/18 [==============================] - 16s 879ms/step - loss: 0.5289 - dice_coef: 0.5132 - iou: 0.3460 - recall: 0.9597 - precision: 0.9159 - val_loss: 1.0591 - val_dice_coef: 0.0305 - val_iou: 0.0155 - val_recall: 0.0185 - val_precision: 0.9053 - lr: 1.0000e-04
# Epoch 21/50
# 18/18 [==============================] - ETA: 0s - loss: 0.5074 - dice_coef: 0.5310 - iou: 0.3623 - recall: 0.9690 - precision: 0.9339
# Epoch 21: val_loss did not improve from 1.05810
# 18/18 [==============================] - 16s 878ms/step - loss: 0.5074 - dice_coef: 0.5310 - iou: 0.3623 - recall: 0.9690 - precision: 0.9339 - val_loss: 1.0642 - val_dice_coef: 0.0279 - val_iou: 0.0141 - val_recall: 0.0093 - val_precision: 1.0000 - lr: 1.0000e-04
# Epoch 22/50
# 18/18 [==============================] - ETA: 0s - loss: 0.4925 - dice_coef: 0.5435 - iou: 0.3740 - recall: 0.9659 - precision: 0.9425
# Epoch 22: val_loss did not improve from 1.05810
# 18/18 [==============================] - 16s 878ms/step - loss: 0.4925 - dice_coef: 0.5435 - iou: 0.3740 - recall: 0.9659 - precision: 0.9425 - val_loss: 1.0652 - val_dice_coef: 0.0298 - val_iou: 0.0152 - val_recall: 0.0123 - val_precision: 1.0000 - lr: 1.0000e-04
# Epoch 23/50
# 18/18 [==============================] - ETA: 0s - loss: 0.4822 - dice_coef: 0.5536 - iou: 0.3838 - recall: 0.9655 - precision: 0.9345
# Epoch 23: val_loss improved from 1.05810 to 1.03094, saving model to files/model1.h5
# 18/18 [==============================] - 19s 1s/step - loss: 0.4822 - dice_coef: 0.5536 - iou: 0.3838 - recall: 0.9655 - precision: 0.9345 - val_loss: 1.0309 - val_dice_coef: 0.0647 - val_iou: 0.0337 - val_recall: 0.0691 - val_precision: 0.9889 - lr: 1.0000e-04
# Epoch 24/50
# 18/18 [==============================] - ETA: 0s - loss: 0.4725 - dice_coef: 0.5617 - iou: 0.3916 - recall: 0.9580 - precision: 0.9330
# Epoch 24: val_loss improved from 1.03094 to 0.95234, saving model to files/model1.h5
# 18/18 [==============================] - 17s 952ms/step - loss: 0.4725 - dice_coef: 0.5617 - iou: 0.3916 - recall: 0.9580 - precision: 0.9330 - val_loss: 0.9523 - val_dice_coef: 0.1427 - val_iou: 0.0780 - val_recall: 0.2052 - val_precision: 0.9024 - lr: 1.0000e-04
# Epoch 25/50
# 18/18 [==============================] - ETA: 0s - loss: 0.4704 - dice_coef: 0.5650 - iou: 0.3945 - recall: 0.9471 - precision: 0.9146
# Epoch 25: val_loss improved from 0.95234 to 0.82330, saving model to files/model1.h5
# 18/18 [==============================] - 19s 1s/step - loss: 0.4704 - dice_coef: 0.5650 - iou: 0.3945 - recall: 0.9471 - precision: 0.9146 - val_loss: 0.8233 - val_dice_coef: 0.2622 - val_iou: 0.1510 - val_recall: 0.5135 - val_precision: 0.6888 - lr: 1.0000e-04
# Epoch 26/50
# 18/18 [==============================] - ETA: 0s - loss: 0.4481 - dice_coef: 0.5832 - iou: 0.4125 - recall: 0.9566 - precision: 0.9384
# Epoch 26: val_loss improved from 0.82330 to 0.82100, saving model to files/model1.h5
# 18/18 [==============================] - 19s 1s/step - loss: 0.4481 - dice_coef: 0.5832 - iou: 0.4125 - recall: 0.9566 - precision: 0.9384 - val_loss: 0.8210 - val_dice_coef: 0.2655 - val_iou: 0.1535 - val_recall: 0.4895 - val_precision: 0.6932 - lr: 1.0000e-04
# Epoch 27/50
# 18/18 [==============================] - ETA: 0s - loss: 0.4361 - dice_coef: 0.5948 - iou: 0.4242 - recall: 0.9579 - precision: 0.9365
# Epoch 27: val_loss did not improve from 0.82100
# 18/18 [==============================] - 16s 879ms/step - loss: 0.4361 - dice_coef: 0.5948 - iou: 0.4242 - recall: 0.9579 - precision: 0.9365 - val_loss: 0.8464 - val_dice_coef: 0.2424 - val_iou: 0.1394 - val_recall: 0.3820 - val_precision: 0.7262 - lr: 1.0000e-04
# Epoch 28/50
# 18/18 [==============================] - ETA: 0s - loss: 0.4213 - dice_coef: 0.6077 - iou: 0.4375 - recall: 0.9643 - precision: 0.9371
# Epoch 28: val_loss improved from 0.82100 to 0.72005, saving model to files/model1.h5
# 18/18 [==============================] - 19s 1s/step - loss: 0.4213 - dice_coef: 0.6077 - iou: 0.4375 - recall: 0.9643 - precision: 0.9371 - val_loss: 0.7201 - val_dice_coef: 0.3584 - val_iou: 0.2201 - val_recall: 0.6888 - val_precision: 0.7257 - lr: 1.0000e-04
# Epoch 29/50
# 18/18 [==============================] - ETA: 0s - loss: 0.4036 - dice_coef: 0.6224 - iou: 0.4528 - recall: 0.9648 - precision: 0.9542
# Epoch 29: val_loss improved from 0.72005 to 0.69356, saving model to files/model1.h5
# 18/18 [==============================] - 17s 952ms/step - loss: 0.4036 - dice_coef: 0.6224 - iou: 0.4528 - recall: 0.9648 - precision: 0.9542 - val_loss: 0.6936 - val_dice_coef: 0.3778 - val_iou: 0.2344 - val_recall: 0.7071 - val_precision: 0.7345 - lr: 1.0000e-04
# Epoch 30/50
# 18/18 [==============================] - ETA: 0s - loss: 0.3887 - dice_coef: 0.6359 - iou: 0.4672 - recall: 0.9689 - precision: 0.9580
# Epoch 30: val_loss improved from 0.69356 to 0.66995, saving model to files/model1.h5
# 18/18 [==============================] - 18s 960ms/step - loss: 0.3887 - dice_coef: 0.6359 - iou: 0.4672 - recall: 0.9689 - precision: 0.9580 - val_loss: 0.6699 - val_dice_coef: 0.3999 - val_iou: 0.2520 - val_recall: 0.7309 - val_precision: 0.7282 - lr: 1.0000e-04
# Epoch 31/50
# 18/18 [==============================] - ETA: 0s - loss: 0.3757 - dice_coef: 0.6476 - iou: 0.4799 - recall: 0.9669 - precision: 0.9647
# Epoch 31: val_loss improved from 0.66995 to 0.63049, saving model to files/model1.h5
# 18/18 [==============================] - 19s 1s/step - loss: 0.3757 - dice_coef: 0.6476 - iou: 0.4799 - recall: 0.9669 - precision: 0.9647 - val_loss: 0.6305 - val_dice_coef: 0.4369 - val_iou: 0.2817 - val_recall: 0.7843 - val_precision: 0.7288 - lr: 1.0000e-04
# Epoch 32/50
# 18/18 [==============================] - ETA: 0s - loss: 0.3749 - dice_coef: 0.6508 - iou: 0.4835 - recall: 0.9622 - precision: 0.9391
# Epoch 32: val_loss improved from 0.63049 to 0.60194, saving model to files/model1.h5
# 18/18 [==============================] - 19s 1s/step - loss: 0.3749 - dice_coef: 0.6508 - iou: 0.4835 - recall: 0.9622 - precision: 0.9391 - val_loss: 0.6019 - val_dice_coef: 0.4708 - val_iou: 0.3111 - val_recall: 0.8865 - val_precision: 0.6833 - lr: 1.0000e-04
# Epoch 33/50
# 18/18 [==============================] - ETA: 0s - loss: 0.3617 - dice_coef: 0.6613 - iou: 0.4951 - recall: 0.9582 - precision: 0.9533
# Epoch 33: val_loss improved from 0.60194 to 0.59165, saving model to files/model1.h5
# 18/18 [==============================] - 19s 1s/step - loss: 0.3617 - dice_coef: 0.6613 - iou: 0.4951 - recall: 0.9582 - precision: 0.9533 - val_loss: 0.5917 - val_dice_coef: 0.4733 - val_iou: 0.3119 - val_recall: 0.8616 - val_precision: 0.7234 - lr: 1.0000e-04
# Epoch 34/50
# 18/18 [==============================] - ETA: 0s - loss: 0.3465 - dice_coef: 0.6749 - iou: 0.5103 - recall: 0.9621 - precision: 0.9600
# Epoch 34: val_loss improved from 0.59165 to 0.58021, saving model to files/model1.h5
# 18/18 [==============================] - 17s 950ms/step - loss: 0.3465 - dice_coef: 0.6749 - iou: 0.5103 - recall: 0.9621 - precision: 0.9600 - val_loss: 0.5802 - val_dice_coef: 0.4823 - val_iou: 0.3196 - val_recall: 0.8444 - val_precision: 0.7256 - lr: 1.0000e-04
# Epoch 35/50
# 18/18 [==============================] - ETA: 0s - loss: 0.3370 - dice_coef: 0.6838 - iou: 0.5206 - recall: 0.9629 - precision: 0.9582
# Epoch 35: val_loss did not improve from 0.58021
# 18/18 [==============================] - 16s 879ms/step - loss: 0.3370 - dice_coef: 0.6838 - iou: 0.5206 - recall: 0.9629 - precision: 0.9582 - val_loss: 0.5952 - val_dice_coef: 0.4934 - val_iou: 0.3327 - val_recall: 0.9325 - val_precision: 0.6410 - lr: 1.0000e-04
# Epoch 36/50
# 18/18 [==============================] - ETA: 0s - loss: 0.3268 - dice_coef: 0.6931 - iou: 0.5314 - recall: 0.9628 - precision: 0.9619
# Epoch 36: val_loss improved from 0.58021 to 0.56518, saving model to files/model1.h5
# 18/18 [==============================] - 19s 1s/step - loss: 0.3268 - dice_coef: 0.6931 - iou: 0.5314 - recall: 0.9628 - precision: 0.9619 - val_loss: 0.5652 - val_dice_coef: 0.5114 - val_iou: 0.3476 - val_recall: 0.9361 - val_precision: 0.6730 - lr: 1.0000e-04
# Epoch 37/50
# 18/18 [==============================] - ETA: 0s - loss: 0.3182 - dice_coef: 0.7013 - iou: 0.5410 - recall: 0.9619 - precision: 0.9596
# Epoch 37: val_loss improved from 0.56518 to 0.54209, saving model to files/model1.h5
# 18/18 [==============================] - 19s 1s/step - loss: 0.3182 - dice_coef: 0.7013 - iou: 0.5410 - recall: 0.9619 - precision: 0.9596 - val_loss: 0.5421 - val_dice_coef: 0.5229 - val_iou: 0.3572 - val_recall: 0.8803 - val_precision: 0.6987 - lr: 1.0000e-04
# Epoch 38/50
# 18/18 [==============================] - ETA: 0s - loss: 0.3085 - dice_coef: 0.7102 - iou: 0.5516 - recall: 0.9614 - precision: 0.9623
# Epoch 38: val_loss improved from 0.54209 to 0.52538, saving model to files/model1.h5
# 18/18 [==============================] - 17s 953ms/step - loss: 0.3085 - dice_coef: 0.7102 - iou: 0.5516 - recall: 0.9614 - precision: 0.9623 - val_loss: 0.5254 - val_dice_coef: 0.5350 - val_iou: 0.3682 - val_recall: 0.8820 - val_precision: 0.7030 - lr: 1.0000e-04
# Epoch 39/50
# 18/18 [==============================] - ETA: 0s - loss: 0.3008 - dice_coef: 0.7177 - iou: 0.5606 - recall: 0.9638 - precision: 0.9565
# Epoch 39: val_loss did not improve from 0.52538
# 18/18 [==============================] - 16s 879ms/step - loss: 0.3008 - dice_coef: 0.7177 - iou: 0.5606 - recall: 0.9638 - precision: 0.9565 - val_loss: 0.5393 - val_dice_coef: 0.5347 - val_iou: 0.3677 - val_recall: 0.8989 - val_precision: 0.6793 - lr: 1.0000e-04
# Epoch 40/50
# 18/18 [==============================] - ETA: 0s - loss: 0.2912 - dice_coef: 0.7263 - iou: 0.5711 - recall: 0.9663 - precision: 0.9585
# Epoch 40: val_loss improved from 0.52538 to 0.52263, saving model to files/model1.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.2912 - dice_coef: 0.7263 - iou: 0.5711 - recall: 0.9663 - precision: 0.9585 - val_loss: 0.5226 - val_dice_coef: 0.5358 - val_iou: 0.3693 - val_recall: 0.8388 - val_precision: 0.7352 - lr: 1.0000e-04
# Epoch 41/50
# 18/18 [==============================] - ETA: 0s - loss: 0.2840 - dice_coef: 0.7334 - iou: 0.5799 - recall: 0.9632 - precision: 0.9598
# Epoch 41: val_loss did not improve from 0.52263
# 18/18 [==============================] - 16s 879ms/step - loss: 0.2840 - dice_coef: 0.7334 - iou: 0.5799 - recall: 0.9632 - precision: 0.9598 - val_loss: 0.5304 - val_dice_coef: 0.5292 - val_iou: 0.3634 - val_recall: 0.8049 - val_precision: 0.7335 - lr: 1.0000e-04
# Epoch 42/50
# 18/18 [==============================] - ETA: 0s - loss: 0.2702 - dice_coef: 0.7452 - iou: 0.5948 - recall: 0.9640 - precision: 0.9707
# Epoch 42: val_loss improved from 0.52263 to 0.50174, saving model to files/model1.h5
# 18/18 [==============================] - 19s 1s/step - loss: 0.2702 - dice_coef: 0.7452 - iou: 0.5948 - recall: 0.9640 - precision: 0.9707 - val_loss: 0.5017 - val_dice_coef: 0.5595 - val_iou: 0.3928 - val_recall: 0.8706 - val_precision: 0.7200 - lr: 1.0000e-04
# Epoch 43/50
# 18/18 [==============================] - ETA: 0s - loss: 0.2592 - dice_coef: 0.7550 - iou: 0.6073 - recall: 0.9629 - precision: 0.9791
# Epoch 43: val_loss did not improve from 0.50174
# 18/18 [==============================] - 16s 878ms/step - loss: 0.2592 - dice_coef: 0.7550 - iou: 0.6073 - recall: 0.9629 - precision: 0.9791 - val_loss: 0.5103 - val_dice_coef: 0.5613 - val_iou: 0.3956 - val_recall: 0.8908 - val_precision: 0.6823 - lr: 1.0000e-04
# Epoch 44/50
# 18/18 [==============================] - ETA: 0s - loss: 0.2541 - dice_coef: 0.7605 - iou: 0.6144 - recall: 0.9625 - precision: 0.9741
# Epoch 44: val_loss improved from 0.50174 to 0.48328, saving model to files/model1.h5
# 18/18 [==============================] - 19s 1s/step - loss: 0.2541 - dice_coef: 0.7605 - iou: 0.6144 - recall: 0.9625 - precision: 0.9741 - val_loss: 0.4833 - val_dice_coef: 0.5741 - val_iou: 0.4064 - val_recall: 0.8576 - val_precision: 0.7098 - lr: 1.0000e-04
# Epoch 45/50
# 18/18 [==============================] - ETA: 0s - loss: 0.2474 - dice_coef: 0.7669 - iou: 0.6227 - recall: 0.9647 - precision: 0.9716
# Epoch 45: val_loss improved from 0.48328 to 0.46938, saving model to files/model1.h5
# 18/18 [==============================] - 17s 952ms/step - loss: 0.2474 - dice_coef: 0.7669 - iou: 0.6227 - recall: 0.9647 - precision: 0.9716 - val_loss: 0.4694 - val_dice_coef: 0.5847 - val_iou: 0.4159 - val_recall: 0.8540 - val_precision: 0.7159 - lr: 1.0000e-04
# Epoch 46/50
# 18/18 [==============================] - ETA: 0s - loss: 0.2416 - dice_coef: 0.7727 - iou: 0.6304 - recall: 0.9651 - precision: 0.9698
# Epoch 46: val_loss did not improve from 0.46938
# 18/18 [==============================] - 16s 878ms/step - loss: 0.2416 - dice_coef: 0.7727 - iou: 0.6304 - recall: 0.9651 - precision: 0.9698 - val_loss: 0.4700 - val_dice_coef: 0.5840 - val_iou: 0.4167 - val_recall: 0.8307 - val_precision: 0.7310 - lr: 1.0000e-04
# Epoch 47/50
# 18/18 [==============================] - ETA: 0s - loss: 0.2356 - dice_coef: 0.7785 - iou: 0.6381 - recall: 0.9666 - precision: 0.9672
# Epoch 47: val_loss did not improve from 0.46938
# 18/18 [==============================] - 16s 877ms/step - loss: 0.2356 - dice_coef: 0.7785 - iou: 0.6381 - recall: 0.9666 - precision: 0.9672 - val_loss: 0.4740 - val_dice_coef: 0.5771 - val_iou: 0.4097 - val_recall: 0.8034 - val_precision: 0.7532 - lr: 1.0000e-04
# Epoch 48/50
# 18/18 [==============================] - ETA: 0s - loss: 0.2354 - dice_coef: 0.7795 - iou: 0.6395 - recall: 0.9552 - precision: 0.9644
# Epoch 48: val_loss improved from 0.46938 to 0.44818, saving model to files/model1.h5
# 18/18 [==============================] - 19s 1s/step - loss: 0.2354 - dice_coef: 0.7795 - iou: 0.6395 - recall: 0.9552 - precision: 0.9644 - val_loss: 0.4482 - val_dice_coef: 0.6029 - val_iou: 0.4352 - val_recall: 0.8507 - val_precision: 0.7385 - lr: 1.0000e-04
# Epoch 49/50
# 18/18 [==============================] - ETA: 0s - loss: 0.2271 - dice_coef: 0.7865 - iou: 0.6488 - recall: 0.9550 - precision: 0.9691
# Epoch 49: val_loss did not improve from 0.44818
# 18/18 [==============================] - 16s 878ms/step - loss: 0.2271 - dice_coef: 0.7865 - iou: 0.6488 - recall: 0.9550 - precision: 0.9691 - val_loss: 0.4542 - val_dice_coef: 0.6013 - val_iou: 0.4348 - val_recall: 0.8462 - val_precision: 0.7181 - lr: 1.0000e-04
# Epoch 50/50
# 18/18 [==============================] - ETA: 0s - loss: 0.2221 - dice_coef: 0.7915 - iou: 0.6558 - recall: 0.9561 - precision: 0.9686
# Epoch 50: val_loss improved from 0.44818 to 0.43692, saving model to files/model1.h5
# 18/18 [==============================] - 19s 1s/step - loss: 0.2221 - dice_coef: 0.7915 - iou: 0.6558 - recall: 0.9561 - precision: 0.9686 - val_loss: 0.4369 - val_dice_coef: 0.6173 - val_iou: 0.4503 - val_recall: 0.8775 - val_precision: 0.7219 - lr: 1.0000e-04

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 8
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model2.h5")
csv_path = os.path.join("files", "data2.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model2 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 1024], strides=[2, 2, 2, 2])

model2.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model2.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 140 - 140
# Valid: 20 - 20
# Epoch 1/50
# 18/18 [==============================] - ETA: 0s - loss: 1.3911 - dice_coef: 0.0707 - iou: 0.0367 - recall_1: 0.5937 - precision_1: 0.0978
# Epoch 1: val_loss improved from inf to 1.66776, saving model to files/model2.h5
# 18/18 [==============================] - 34s 2s/step - loss: 1.3911 - dice_coef: 0.0707 - iou: 0.0367 - recall_1: 0.5937 - precision_1: 0.0978 - val_loss: 1.6678 - val_dice_coef: 0.0275 - val_iou: 0.0139 - val_recall_1: 0.0984 - val_precision_1: 0.0041 - lr: 1.0000e-04
# Epoch 2/50
# 18/18 [==============================] - ETA: 0s - loss: 1.1019 - dice_coef: 0.1335 - iou: 0.0717 - recall_1: 0.6559 - precision_1: 0.5402
# Epoch 2: val_loss improved from 1.66776 to 1.64545, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 1.1019 - dice_coef: 0.1335 - iou: 0.0717 - recall_1: 0.6559 - precision_1: 0.5402 - val_loss: 1.6455 - val_dice_coef: 0.0271 - val_iou: 0.0137 - val_recall_1: 9.1249e-04 - val_precision_1: 5.8636e-05 - lr: 1.0000e-04
# Epoch 3/50
# 18/18 [==============================] - ETA: 0s - loss: 0.9666 - dice_coef: 0.1937 - iou: 0.1074 - recall_1: 0.7509 - precision_1: 0.6537
# Epoch 3: val_loss did not improve from 1.64545
# 18/18 [==============================] - 17s 919ms/step - loss: 0.9666 - dice_coef: 0.1937 - iou: 0.1074 - recall_1: 0.7509 - precision_1: 0.6537 - val_loss: 2.4313 - val_dice_coef: 0.0300 - val_iou: 0.0153 - val_recall_1: 1.0000 - val_precision_1: 0.0164 - lr: 1.0000e-04
# Epoch 4/50
# 18/18 [==============================] - ETA: 0s - loss: 0.8928 - dice_coef: 0.2362 - iou: 0.1341 - recall_1: 0.8033 - precision_1: 0.7367
# Epoch 4: val_loss improved from 1.64545 to 1.49165, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.8928 - dice_coef: 0.2362 - iou: 0.1341 - recall_1: 0.8033 - precision_1: 0.7367 - val_loss: 1.4916 - val_dice_coef: 0.0265 - val_iou: 0.0134 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 5/50
# 18/18 [==============================] - ETA: 0s - loss: 0.8393 - dice_coef: 0.2727 - iou: 0.1581 - recall_1: 0.8685 - precision_1: 0.7707
# Epoch 5: val_loss improved from 1.49165 to 1.41853, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.8393 - dice_coef: 0.2727 - iou: 0.1581 - recall_1: 0.8685 - precision_1: 0.7707 - val_loss: 1.4185 - val_dice_coef: 0.0264 - val_iou: 0.0134 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 6/50
# 18/18 [==============================] - ETA: 0s - loss: 0.8065 - dice_coef: 0.2956 - iou: 0.1737 - recall_1: 0.8799 - precision_1: 0.7732
# Epoch 6: val_loss improved from 1.41853 to 1.34217, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.8065 - dice_coef: 0.2956 - iou: 0.1737 - recall_1: 0.8799 - precision_1: 0.7732 - val_loss: 1.3422 - val_dice_coef: 0.0269 - val_iou: 0.0136 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 7/50
# 18/18 [==============================] - ETA: 0s - loss: 0.7711 - dice_coef: 0.3197 - iou: 0.1906 - recall_1: 0.8995 - precision_1: 0.8268
# Epoch 7: val_loss improved from 1.34217 to 1.26809, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.7711 - dice_coef: 0.3197 - iou: 0.1906 - recall_1: 0.8995 - precision_1: 0.8268 - val_loss: 1.2681 - val_dice_coef: 0.0275 - val_iou: 0.0140 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 8/50
# 18/18 [==============================] - ETA: 0s - loss: 0.7396 - dice_coef: 0.3431 - iou: 0.2073 - recall_1: 0.9279 - precision_1: 0.8412
# Epoch 8: val_loss improved from 1.26809 to 1.20958, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.7396 - dice_coef: 0.3431 - iou: 0.2073 - recall_1: 0.9279 - precision_1: 0.8412 - val_loss: 1.2096 - val_dice_coef: 0.0279 - val_iou: 0.0141 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 9/50
# 18/18 [==============================] - ETA: 0s - loss: 0.7139 - dice_coef: 0.3628 - iou: 0.2219 - recall_1: 0.9383 - precision_1: 0.8557
# Epoch 9: val_loss improved from 1.20958 to 1.16761, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.7139 - dice_coef: 0.3628 - iou: 0.2219 - recall_1: 0.9383 - precision_1: 0.8557 - val_loss: 1.1676 - val_dice_coef: 0.0298 - val_iou: 0.0151 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 10/50
# 18/18 [==============================] - ETA: 0s - loss: 0.6983 - dice_coef: 0.3744 - iou: 0.2307 - recall_1: 0.9290 - precision_1: 0.8629
# Epoch 10: val_loss improved from 1.16761 to 1.13345, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.6983 - dice_coef: 0.3744 - iou: 0.2307 - recall_1: 0.9290 - precision_1: 0.8629 - val_loss: 1.1334 - val_dice_coef: 0.0296 - val_iou: 0.0150 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 11/50
# 18/18 [==============================] - ETA: 0s - loss: 0.6754 - dice_coef: 0.3920 - iou: 0.2442 - recall_1: 0.9430 - precision_1: 0.8763
# Epoch 11: val_loss improved from 1.13345 to 1.11916, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.6754 - dice_coef: 0.3920 - iou: 0.2442 - recall_1: 0.9430 - precision_1: 0.8763 - val_loss: 1.1192 - val_dice_coef: 0.0294 - val_iou: 0.0149 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 12/50
# 18/18 [==============================] - ETA: 0s - loss: 0.6573 - dice_coef: 0.4067 - iou: 0.2557 - recall_1: 0.9457 - precision_1: 0.8824
# Epoch 12: val_loss improved from 1.11916 to 1.10806, saving model to files/model2.h5
# 18/18 [==============================] - 18s 990ms/step - loss: 0.6573 - dice_coef: 0.4067 - iou: 0.2557 - recall_1: 0.9457 - precision_1: 0.8824 - val_loss: 1.1081 - val_dice_coef: 0.0281 - val_iou: 0.0143 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 13/50
# 18/18 [==============================] - ETA: 0s - loss: 0.6387 - dice_coef: 0.4219 - iou: 0.2679 - recall_1: 0.9527 - precision_1: 0.8812
# Epoch 13: val_loss improved from 1.10806 to 1.09316, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.6387 - dice_coef: 0.4219 - iou: 0.2679 - recall_1: 0.9527 - precision_1: 0.8812 - val_loss: 1.0932 - val_dice_coef: 0.0278 - val_iou: 0.0141 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 14/50
# 18/18 [==============================] - ETA: 0s - loss: 0.6319 - dice_coef: 0.4276 - iou: 0.2726 - recall_1: 0.9402 - precision_1: 0.8555
# Epoch 14: val_loss improved from 1.09316 to 1.08608, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.6319 - dice_coef: 0.4276 - iou: 0.2726 - recall_1: 0.9402 - precision_1: 0.8555 - val_loss: 1.0861 - val_dice_coef: 0.0275 - val_iou: 0.0139 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 15/50
# 18/18 [==============================] - ETA: 0s - loss: 0.6227 - dice_coef: 0.4353 - iou: 0.2787 - recall_1: 0.9243 - precision_1: 0.8662
# Epoch 15: val_loss improved from 1.08608 to 1.07600, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.6227 - dice_coef: 0.4353 - iou: 0.2787 - recall_1: 0.9243 - precision_1: 0.8662 - val_loss: 1.0760 - val_dice_coef: 0.0270 - val_iou: 0.0137 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 16/50
# 18/18 [==============================] - ETA: 0s - loss: 0.5997 - dice_coef: 0.4539 - iou: 0.2941 - recall_1: 0.9385 - precision_1: 0.8830
# Epoch 16: val_loss improved from 1.07600 to 1.07177, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.5997 - dice_coef: 0.4539 - iou: 0.2941 - recall_1: 0.9385 - precision_1: 0.8830 - val_loss: 1.0718 - val_dice_coef: 0.0268 - val_iou: 0.0136 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 17/50
# 18/18 [==============================] - ETA: 0s - loss: 0.5768 - dice_coef: 0.4726 - iou: 0.3100 - recall_1: 0.9510 - precision_1: 0.9023
# Epoch 17: val_loss improved from 1.07177 to 1.06930, saving model to files/model2.h5
# 18/18 [==============================] - 18s 1s/step - loss: 0.5768 - dice_coef: 0.4726 - iou: 0.3100 - recall_1: 0.9510 - precision_1: 0.9023 - val_loss: 1.0693 - val_dice_coef: 0.0265 - val_iou: 0.0134 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 18/50
# 18/18 [==============================] - ETA: 0s - loss: 0.5617 - dice_coef: 0.4850 - iou: 0.3208 - recall_1: 0.9496 - precision_1: 0.9057
# Epoch 18: val_loss improved from 1.06930 to 1.06358, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.5617 - dice_coef: 0.4850 - iou: 0.3208 - recall_1: 0.9496 - precision_1: 0.9057 - val_loss: 1.0636 - val_dice_coef: 0.0263 - val_iou: 0.0133 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 19/50
# 18/18 [==============================] - ETA: 0s - loss: 0.5454 - dice_coef: 0.4994 - iou: 0.3336 - recall_1: 0.9571 - precision_1: 0.9108
# Epoch 19: val_loss did not improve from 1.06358
# 18/18 [==============================] - 17s 917ms/step - loss: 0.5454 - dice_coef: 0.4994 - iou: 0.3336 - recall_1: 0.9571 - precision_1: 0.9108 - val_loss: 1.0643 - val_dice_coef: 0.0244 - val_iou: 0.0124 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 20/50
# 18/18 [==============================] - ETA: 0s - loss: 0.5341 - dice_coef: 0.5089 - iou: 0.3420 - recall_1: 0.9518 - precision_1: 0.9051
# Epoch 20: val_loss improved from 1.06358 to 1.04340, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.5341 - dice_coef: 0.5089 - iou: 0.3420 - recall_1: 0.9518 - precision_1: 0.9051 - val_loss: 1.0434 - val_dice_coef: 0.0444 - val_iou: 0.0227 - val_recall_1: 0.0430 - val_precision_1: 0.8678 - lr: 1.0000e-04
# Epoch 21/50
# 18/18 [==============================] - ETA: 0s - loss: 0.5280 - dice_coef: 0.5133 - iou: 0.3463 - recall_1: 0.9404 - precision_1: 0.9006
# Epoch 21: val_loss did not improve from 1.04340
# 18/18 [==============================] - 17s 917ms/step - loss: 0.5280 - dice_coef: 0.5133 - iou: 0.3463 - recall_1: 0.9404 - precision_1: 0.9006 - val_loss: 1.0465 - val_dice_coef: 0.0429 - val_iou: 0.0219 - val_recall_1: 0.0412 - val_precision_1: 0.9425 - lr: 1.0000e-04
# Epoch 22/50
# 18/18 [==============================] - ETA: 0s - loss: 0.5198 - dice_coef: 0.5226 - iou: 0.3544 - recall_1: 0.9407 - precision_1: 0.8852
# Epoch 22: val_loss improved from 1.04340 to 1.02399, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.5198 - dice_coef: 0.5226 - iou: 0.3544 - recall_1: 0.9407 - precision_1: 0.8852 - val_loss: 1.0240 - val_dice_coef: 0.0938 - val_iou: 0.0493 - val_recall_1: 0.1908 - val_precision_1: 0.1671 - lr: 1.0000e-04
# Epoch 23/50
# 18/18 [==============================] - ETA: 0s - loss: 0.5116 - dice_coef: 0.5304 - iou: 0.3615 - recall_1: 0.9306 - precision_1: 0.8891
# Epoch 23: val_loss improved from 1.02399 to 0.92806, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.5116 - dice_coef: 0.5304 - iou: 0.3615 - recall_1: 0.9306 - precision_1: 0.8891 - val_loss: 0.9281 - val_dice_coef: 0.1561 - val_iou: 0.0847 - val_recall_1: 0.3029 - val_precision_1: 0.7524 - lr: 1.0000e-04
# Epoch 24/50
# 18/18 [==============================] - ETA: 0s - loss: 0.4905 - dice_coef: 0.5479 - iou: 0.3780 - recall_1: 0.9354 - precision_1: 0.9135
# Epoch 24: val_loss did not improve from 0.92806
# 18/18 [==============================] - 17s 919ms/step - loss: 0.4905 - dice_coef: 0.5479 - iou: 0.3780 - recall_1: 0.9354 - precision_1: 0.9135 - val_loss: 0.9577 - val_dice_coef: 0.1284 - val_iou: 0.0687 - val_recall_1: 0.2383 - val_precision_1: 0.7716 - lr: 1.0000e-04
# Epoch 25/50
# 18/18 [==============================] - ETA: 0s - loss: 0.4844 - dice_coef: 0.5546 - iou: 0.3845 - recall_1: 0.9462 - precision_1: 0.8760
# Epoch 25: val_loss improved from 0.92806 to 0.85045, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.4844 - dice_coef: 0.5546 - iou: 0.3845 - recall_1: 0.9462 - precision_1: 0.8760 - val_loss: 0.8505 - val_dice_coef: 0.2697 - val_iou: 0.1572 - val_recall_1: 0.7617 - val_precision_1: 0.4255 - lr: 1.0000e-04
# Epoch 26/50
# 18/18 [==============================] - ETA: 0s - loss: 0.4552 - dice_coef: 0.5779 - iou: 0.4073 - recall_1: 0.9569 - precision_1: 0.9243
# Epoch 26: val_loss improved from 0.85045 to 0.79315, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.4552 - dice_coef: 0.5779 - iou: 0.4073 - recall_1: 0.9569 - precision_1: 0.9243 - val_loss: 0.7932 - val_dice_coef: 0.2728 - val_iou: 0.1584 - val_recall_1: 0.5667 - val_precision_1: 0.7192 - lr: 1.0000e-04
# Epoch 27/50
# 18/18 [==============================] - ETA: 0s - loss: 0.4407 - dice_coef: 0.5909 - iou: 0.4204 - recall_1: 0.9575 - precision_1: 0.9293
# Epoch 27: val_loss improved from 0.79315 to 0.77832, saving model to files/model2.h5
# 18/18 [==============================] - 18s 991ms/step - loss: 0.4407 - dice_coef: 0.5909 - iou: 0.4204 - recall_1: 0.9575 - precision_1: 0.9293 - val_loss: 0.7783 - val_dice_coef: 0.2958 - val_iou: 0.1738 - val_recall_1: 0.5901 - val_precision_1: 0.7131 - lr: 1.0000e-04
# Epoch 28/50
# 18/18 [==============================] - ETA: 0s - loss: 0.4249 - dice_coef: 0.6046 - iou: 0.4344 - recall_1: 0.9616 - precision_1: 0.9355
# Epoch 28: val_loss improved from 0.77832 to 0.73891, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.4249 - dice_coef: 0.6046 - iou: 0.4344 - recall_1: 0.9616 - precision_1: 0.9355 - val_loss: 0.7389 - val_dice_coef: 0.3366 - val_iou: 0.2031 - val_recall_1: 0.6738 - val_precision_1: 0.7306 - lr: 1.0000e-04
# Epoch 29/50
# 18/18 [==============================] - ETA: 0s - loss: 0.4104 - dice_coef: 0.6173 - iou: 0.4475 - recall_1: 0.9633 - precision_1: 0.9405
# Epoch 29: val_loss improved from 0.73891 to 0.69978, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.4104 - dice_coef: 0.6173 - iou: 0.4475 - recall_1: 0.9633 - precision_1: 0.9405 - val_loss: 0.6998 - val_dice_coef: 0.3704 - val_iou: 0.2286 - val_recall_1: 0.7214 - val_precision_1: 0.7385 - lr: 1.0000e-04
# Epoch 30/50
# 18/18 [==============================] - ETA: 0s - loss: 0.3982 - dice_coef: 0.6284 - iou: 0.4592 - recall_1: 0.9585 - precision_1: 0.9456
# Epoch 30: val_loss did not improve from 0.69978
# 18/18 [==============================] - 17s 917ms/step - loss: 0.3982 - dice_coef: 0.6284 - iou: 0.4592 - recall_1: 0.9585 - precision_1: 0.9456 - val_loss: 0.7393 - val_dice_coef: 0.3264 - val_iou: 0.1960 - val_recall_1: 0.5816 - val_precision_1: 0.7203 - lr: 1.0000e-04
# Epoch 31/50
# 18/18 [==============================] - ETA: 0s - loss: 0.3929 - dice_coef: 0.6342 - iou: 0.4654 - recall_1: 0.9530 - precision_1: 0.9340
# Epoch 31: val_loss improved from 0.69978 to 0.63631, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.3929 - dice_coef: 0.6342 - iou: 0.4654 - recall_1: 0.9530 - precision_1: 0.9340 - val_loss: 0.6363 - val_dice_coef: 0.4443 - val_iou: 0.2892 - val_recall_1: 0.8848 - val_precision_1: 0.6798 - lr: 1.0000e-04
# Epoch 32/50
# 18/18 [==============================] - ETA: 0s - loss: 0.3788 - dice_coef: 0.6460 - iou: 0.4780 - recall_1: 0.9545 - precision_1: 0.9431
# Epoch 32: val_loss improved from 0.63631 to 0.61622, saving model to files/model2.h5
# 18/18 [==============================] - 18s 992ms/step - loss: 0.3788 - dice_coef: 0.6460 - iou: 0.4780 - recall_1: 0.9545 - precision_1: 0.9431 - val_loss: 0.6162 - val_dice_coef: 0.4389 - val_iou: 0.2849 - val_recall_1: 0.8125 - val_precision_1: 0.7084 - lr: 1.0000e-04
# Epoch 33/50
# 18/18 [==============================] - ETA: 0s - loss: 0.3704 - dice_coef: 0.6549 - iou: 0.4879 - recall_1: 0.9603 - precision_1: 0.9283
# Epoch 33: val_loss did not improve from 0.61622
# 18/18 [==============================] - 17s 917ms/step - loss: 0.3704 - dice_coef: 0.6549 - iou: 0.4879 - recall_1: 0.9603 - precision_1: 0.9283 - val_loss: 0.6216 - val_dice_coef: 0.4523 - val_iou: 0.2957 - val_recall_1: 0.8685 - val_precision_1: 0.7042 - lr: 1.0000e-04
# Epoch 34/50
# 18/18 [==============================] - ETA: 0s - loss: 0.3526 - dice_coef: 0.6698 - iou: 0.5045 - recall_1: 0.9568 - precision_1: 0.9565
# Epoch 34: val_loss improved from 0.61622 to 0.60021, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.3526 - dice_coef: 0.6698 - iou: 0.5045 - recall_1: 0.9568 - precision_1: 0.9565 - val_loss: 0.6002 - val_dice_coef: 0.4662 - val_iou: 0.3070 - val_recall_1: 0.8434 - val_precision_1: 0.7294 - lr: 1.0000e-04
# Epoch 35/50
# 18/18 [==============================] - ETA: 0s - loss: 0.3425 - dice_coef: 0.6794 - iou: 0.5154 - recall_1: 0.9597 - precision_1: 0.9517
# Epoch 35: val_loss improved from 0.60021 to 0.57506, saving model to files/model2.h5
# 18/18 [==============================] - 18s 1s/step - loss: 0.3425 - dice_coef: 0.6794 - iou: 0.5154 - recall_1: 0.9597 - precision_1: 0.9517 - val_loss: 0.5751 - val_dice_coef: 0.4869 - val_iou: 0.3246 - val_recall_1: 0.8705 - val_precision_1: 0.7238 - lr: 1.0000e-04
# Epoch 36/50
# 18/18 [==============================] - ETA: 0s - loss: 0.3309 - dice_coef: 0.6896 - iou: 0.5273 - recall_1: 0.9619 - precision_1: 0.9544
# Epoch 36: val_loss improved from 0.57506 to 0.54365, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.3309 - dice_coef: 0.6896 - iou: 0.5273 - recall_1: 0.9619 - precision_1: 0.9544 - val_loss: 0.5437 - val_dice_coef: 0.5058 - val_iou: 0.3402 - val_recall_1: 0.8640 - val_precision_1: 0.7523 - lr: 1.0000e-04
# Epoch 37/50
# 18/18 [==============================] - ETA: 0s - loss: 0.3214 - dice_coef: 0.6988 - iou: 0.5380 - recall_1: 0.9620 - precision_1: 0.9544
# Epoch 37: val_loss did not improve from 0.54365
# 18/18 [==============================] - 17s 917ms/step - loss: 0.3214 - dice_coef: 0.6988 - iou: 0.5380 - recall_1: 0.9620 - precision_1: 0.9544 - val_loss: 0.5536 - val_dice_coef: 0.5157 - val_iou: 0.3507 - val_recall_1: 0.9209 - val_precision_1: 0.6937 - lr: 1.0000e-04
# Epoch 38/50
# 18/18 [==============================] - ETA: 0s - loss: 0.3127 - dice_coef: 0.7064 - iou: 0.5470 - recall_1: 0.9603 - precision_1: 0.9557
# Epoch 38: val_loss did not improve from 0.54365
# 18/18 [==============================] - 17s 917ms/step - loss: 0.3127 - dice_coef: 0.7064 - iou: 0.5470 - recall_1: 0.9603 - precision_1: 0.9557 - val_loss: 0.5636 - val_dice_coef: 0.5071 - val_iou: 0.3435 - val_recall_1: 0.8557 - val_precision_1: 0.6963 - lr: 1.0000e-04
# Epoch 39/50
# 18/18 [==============================] - ETA: 0s - loss: 0.3000 - dice_coef: 0.7176 - iou: 0.5604 - recall_1: 0.9618 - precision_1: 0.9639
# Epoch 39: val_loss improved from 0.54365 to 0.53924, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.3000 - dice_coef: 0.7176 - iou: 0.5604 - recall_1: 0.9618 - precision_1: 0.9639 - val_loss: 0.5392 - val_dice_coef: 0.5162 - val_iou: 0.3502 - val_recall_1: 0.8184 - val_precision_1: 0.7443 - lr: 1.0000e-04
# Epoch 40/50
# 18/18 [==============================] - ETA: 0s - loss: 0.2874 - dice_coef: 0.7294 - iou: 0.5750 - recall_1: 0.9666 - precision_1: 0.9690
# Epoch 40: val_loss improved from 0.53924 to 0.52675, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.2874 - dice_coef: 0.7294 - iou: 0.5750 - recall_1: 0.9666 - precision_1: 0.9690 - val_loss: 0.5267 - val_dice_coef: 0.5330 - val_iou: 0.3671 - val_recall_1: 0.8642 - val_precision_1: 0.7230 - lr: 1.0000e-04
# Epoch 41/50
# 18/18 [==============================] - ETA: 0s - loss: 0.2786 - dice_coef: 0.7374 - iou: 0.5850 - recall_1: 0.9650 - precision_1: 0.9710
# Epoch 41: val_loss did not improve from 0.52675
# 18/18 [==============================] - 17s 917ms/step - loss: 0.2786 - dice_coef: 0.7374 - iou: 0.5850 - recall_1: 0.9650 - precision_1: 0.9710 - val_loss: 0.5336 - val_dice_coef: 0.5331 - val_iou: 0.3676 - val_recall_1: 0.8541 - val_precision_1: 0.7039 - lr: 1.0000e-04
# Epoch 42/50
# 18/18 [==============================] - ETA: 0s - loss: 0.2723 - dice_coef: 0.7435 - iou: 0.5926 - recall_1: 0.9624 - precision_1: 0.9689
# Epoch 42: val_loss did not improve from 0.52675
# 18/18 [==============================] - 17s 918ms/step - loss: 0.2723 - dice_coef: 0.7435 - iou: 0.5926 - recall_1: 0.9624 - precision_1: 0.9689 - val_loss: 0.5298 - val_dice_coef: 0.5378 - val_iou: 0.3716 - val_recall_1: 0.8436 - val_precision_1: 0.7014 - lr: 1.0000e-04
# Epoch 43/50
# 18/18 [==============================] - ETA: 0s - loss: 0.2644 - dice_coef: 0.7510 - iou: 0.6022 - recall_1: 0.9649 - precision_1: 0.9679
# Epoch 43: val_loss improved from 0.52675 to 0.51739, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.2644 - dice_coef: 0.7510 - iou: 0.6022 - recall_1: 0.9649 - precision_1: 0.9679 - val_loss: 0.5174 - val_dice_coef: 0.5443 - val_iou: 0.3767 - val_recall_1: 0.8150 - val_precision_1: 0.7178 - lr: 1.0000e-04
# Epoch 44/50
# 18/18 [==============================] - ETA: 0s - loss: 0.2571 - dice_coef: 0.7579 - iou: 0.6111 - recall_1: 0.9641 - precision_1: 0.9684
# Epoch 44: val_loss improved from 0.51739 to 0.51468, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.2571 - dice_coef: 0.7579 - iou: 0.6111 - recall_1: 0.9641 - precision_1: 0.9684 - val_loss: 0.5147 - val_dice_coef: 0.5506 - val_iou: 0.3834 - val_recall_1: 0.8270 - val_precision_1: 0.7008 - lr: 1.0000e-04
# Epoch 45/50
# 18/18 [==============================] - ETA: 0s - loss: 0.2516 - dice_coef: 0.7632 - iou: 0.6179 - recall_1: 0.9612 - precision_1: 0.9675
# Epoch 45: val_loss improved from 0.51468 to 0.49335, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.2516 - dice_coef: 0.7632 - iou: 0.6179 - recall_1: 0.9612 - precision_1: 0.9675 - val_loss: 0.4934 - val_dice_coef: 0.5602 - val_iou: 0.3920 - val_recall_1: 0.7853 - val_precision_1: 0.7348 - lr: 1.0000e-04
# Epoch 46/50
# 18/18 [==============================] - ETA: 0s - loss: 0.2488 - dice_coef: 0.7666 - iou: 0.6225 - recall_1: 0.9601 - precision_1: 0.9609
# Epoch 46: val_loss did not improve from 0.49335
# 18/18 [==============================] - 17s 917ms/step - loss: 0.2488 - dice_coef: 0.7666 - iou: 0.6225 - recall_1: 0.9601 - precision_1: 0.9609 - val_loss: 0.4983 - val_dice_coef: 0.5657 - val_iou: 0.3985 - val_recall_1: 0.8198 - val_precision_1: 0.7182 - lr: 1.0000e-04
# Epoch 47/50
# 18/18 [==============================] - ETA: 0s - loss: 0.2429 - dice_coef: 0.7721 - iou: 0.6297 - recall_1: 0.9591 - precision_1: 0.9601
# Epoch 47: val_loss improved from 0.49335 to 0.48646, saving model to files/model2.h5
# 18/18 [==============================] - 20s 1s/step - loss: 0.2429 - dice_coef: 0.7721 - iou: 0.6297 - recall_1: 0.9591 - precision_1: 0.9601 - val_loss: 0.4865 - val_dice_coef: 0.5713 - val_iou: 0.4045 - val_recall_1: 0.8184 - val_precision_1: 0.7354 - lr: 1.0000e-04
# Epoch 48/50
# 18/18 [==============================] - ETA: 0s - loss: 0.2609 - dice_coef: 0.7558 - iou: 0.6086 - recall_1: 0.9302 - precision_1: 0.9400
# Epoch 48: val_loss did not improve from 0.48646
# 18/18 [==============================] - 17s 916ms/step - loss: 0.2609 - dice_coef: 0.7558 - iou: 0.6086 - recall_1: 0.9302 - precision_1: 0.9400 - val_loss: 0.5717 - val_dice_coef: 0.4935 - val_iou: 0.3341 - val_recall_1: 0.8501 - val_precision_1: 0.5693 - lr: 1.0000e-04
# Epoch 49/50
# 18/18 [==============================] - ETA: 0s - loss: 0.2805 - dice_coef: 0.7443 - iou: 0.5936 - recall_1: 0.9129 - precision_1: 0.9093
# Epoch 49: val_loss did not improve from 0.48646
# 18/18 [==============================] - 17s 917ms/step - loss: 0.2805 - dice_coef: 0.7443 - iou: 0.5936 - recall_1: 0.9129 - precision_1: 0.9093 - val_loss: 0.7971 - val_dice_coef: 0.4227 - val_iou: 0.2793 - val_recall_1: 0.9960 - val_precision_1: 0.3345 - lr: 1.0000e-04
# Epoch 50/50
# 18/18 [==============================] - ETA: 0s - loss: 0.2478 - dice_coef: 0.7702 - iou: 0.6269 - recall_1: 0.9349 - precision_1: 0.9372
# Epoch 50: val_loss did not improve from 0.48646
# 18/18 [==============================] - 17s 916ms/step - loss: 0.2478 - dice_coef: 0.7702 - iou: 0.6269 - recall_1: 0.9349 - precision_1: 0.9372 - val_loss: 0.5400 - val_dice_coef: 0.5460 - val_iou: 0.3780 - val_recall_1: 0.9322 - val_precision_1: 0.6158 - lr: 1.0000e-04

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 2
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model3.h5")
csv_path = os.path.join("files", "data3.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model3 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 1024], strides=[1, 2, 2, 2])

model3.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model3.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 140 - 140
# Valid: 20 - 20
# Epoch 1/50
# 70/70 [==============================] - ETA: 0s - loss: 1.1220 - dice_coef: 0.1384 - iou: 0.0756 - recall_2: 0.5957 - precision_2: 0.2818
# Epoch 1: val_loss improved from inf to 1.65117, saving model to files/model3.h5
# 70/70 [==============================] - 63s 758ms/step - loss: 1.1220 - dice_coef: 0.1384 - iou: 0.0756 - recall_2: 0.5957 - precision_2: 0.2818 - val_loss: 1.6512 - val_dice_coef: 0.0258 - val_iou: 0.0131 - val_recall_2: 0.1193 - val_precision_2: 0.0040 - lr: 1.0000e-04
# Epoch 2/50
# 70/70 [==============================] - ETA: 0s - loss: 0.9064 - dice_coef: 0.2363 - iou: 0.1354 - recall_2: 0.7310 - precision_2: 0.5878
# Epoch 2: val_loss improved from 1.65117 to 1.21401, saving model to files/model3.h5
# 70/70 [==============================] - 54s 778ms/step - loss: 0.9064 - dice_coef: 0.2363 - iou: 0.1354 - recall_2: 0.7310 - precision_2: 0.5878 - val_loss: 1.2140 - val_dice_coef: 0.0290 - val_iou: 0.0147 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 3/50
# 70/70 [==============================] - ETA: 0s - loss: 0.7995 - dice_coef: 0.3068 - iou: 0.1829 - recall_2: 0.7953 - precision_2: 0.6641
# Epoch 3: val_loss improved from 1.21401 to 1.10195, saving model to files/model3.h5
# 70/70 [==============================] - 54s 776ms/step - loss: 0.7995 - dice_coef: 0.3068 - iou: 0.1829 - recall_2: 0.7953 - precision_2: 0.6641 - val_loss: 1.1020 - val_dice_coef: 0.0289 - val_iou: 0.0147 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 4/50
# 70/70 [==============================] - ETA: 0s - loss: 0.7063 - dice_coef: 0.3738 - iou: 0.2319 - recall_2: 0.8464 - precision_2: 0.7396
# Epoch 4: val_loss improved from 1.10195 to 1.06910, saving model to files/model3.h5
# 70/70 [==============================] - 54s 776ms/step - loss: 0.7063 - dice_coef: 0.3738 - iou: 0.2319 - recall_2: 0.8464 - precision_2: 0.7396 - val_loss: 1.0691 - val_dice_coef: 0.0276 - val_iou: 0.0140 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 5/50
# 70/70 [==============================] - ETA: 0s - loss: 0.6366 - dice_coef: 0.4295 - iou: 0.2758 - recall_2: 0.8723 - precision_2: 0.7730
# Epoch 5: val_loss improved from 1.06910 to 1.06378, saving model to files/model3.h5
# 70/70 [==============================] - 54s 774ms/step - loss: 0.6366 - dice_coef: 0.4295 - iou: 0.2758 - recall_2: 0.8723 - precision_2: 0.7730 - val_loss: 1.0638 - val_dice_coef: 0.0246 - val_iou: 0.0125 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 6/50
# 70/70 [==============================] - ETA: 0s - loss: 0.5842 - dice_coef: 0.4728 - iou: 0.3121 - recall_2: 0.8719 - precision_2: 0.7983
# Epoch 6: val_loss improved from 1.06378 to 1.05322, saving model to files/model3.h5
# 70/70 [==============================] - 54s 774ms/step - loss: 0.5842 - dice_coef: 0.4728 - iou: 0.3121 - recall_2: 0.8719 - precision_2: 0.7983 - val_loss: 1.0532 - val_dice_coef: 0.0273 - val_iou: 0.0138 - val_recall_2: 0.0011 - val_precision_2: 1.0000 - lr: 1.0000e-04
# Epoch 7/50
# 70/70 [==============================] - ETA: 0s - loss: 0.5345 - dice_coef: 0.5170 - iou: 0.3511 - recall_2: 0.8848 - precision_2: 0.8091
# Epoch 7: val_loss improved from 1.05322 to 0.76374, saving model to files/model3.h5
# 70/70 [==============================] - 54s 774ms/step - loss: 0.5345 - dice_coef: 0.5170 - iou: 0.3511 - recall_2: 0.8848 - precision_2: 0.8091 - val_loss: 0.7637 - val_dice_coef: 0.3068 - val_iou: 0.1846 - val_recall_2: 0.5448 - val_precision_2: 0.7269 - lr: 1.0000e-04
# Epoch 8/50
# 70/70 [==============================] - ETA: 0s - loss: 0.4849 - dice_coef: 0.5587 - iou: 0.3902 - recall_2: 0.8933 - precision_2: 0.8233
# Epoch 8: val_loss did not improve from 0.76374
# 70/70 [==============================] - 51s 730ms/step - loss: 0.4849 - dice_coef: 0.5587 - iou: 0.3902 - recall_2: 0.8933 - precision_2: 0.8233 - val_loss: 0.8212 - val_dice_coef: 0.2420 - val_iou: 0.1413 - val_recall_2: 0.3805 - val_precision_2: 0.7071 - lr: 1.0000e-04
# Epoch 9/50
# 70/70 [==============================] - ETA: 0s - loss: 0.4447 - dice_coef: 0.5943 - iou: 0.4258 - recall_2: 0.8878 - precision_2: 0.8367
# Epoch 9: val_loss improved from 0.76374 to 0.63470, saving model to files/model3.h5
# 70/70 [==============================] - 54s 774ms/step - loss: 0.4447 - dice_coef: 0.5943 - iou: 0.4258 - recall_2: 0.8878 - precision_2: 0.8367 - val_loss: 0.6347 - val_dice_coef: 0.4332 - val_iou: 0.2888 - val_recall_2: 0.7343 - val_precision_2: 0.6702 - lr: 1.0000e-04
# Epoch 10/50
# 70/70 [==============================] - ETA: 0s - loss: 0.3941 - dice_coef: 0.6404 - iou: 0.4738 - recall_2: 0.9023 - precision_2: 0.8563
# Epoch 10: val_loss improved from 0.63470 to 0.57492, saving model to files/model3.h5
# 70/70 [==============================] - 54s 774ms/step - loss: 0.3941 - dice_coef: 0.6404 - iou: 0.4738 - recall_2: 0.9023 - precision_2: 0.8563 - val_loss: 0.5749 - val_dice_coef: 0.5001 - val_iou: 0.3527 - val_recall_2: 0.8278 - val_precision_2: 0.6657 - lr: 1.0000e-04
# Epoch 11/50
# 70/70 [==============================] - ETA: 0s - loss: 0.3482 - dice_coef: 0.6801 - iou: 0.5179 - recall_2: 0.9142 - precision_2: 0.8747
# Epoch 11: val_loss did not improve from 0.57492
# 70/70 [==============================] - 51s 729ms/step - loss: 0.3482 - dice_coef: 0.6801 - iou: 0.5179 - recall_2: 0.9142 - precision_2: 0.8747 - val_loss: 0.6989 - val_dice_coef: 0.3596 - val_iou: 0.2289 - val_recall_2: 0.4709 - val_precision_2: 0.7065 - lr: 1.0000e-04
# Epoch 12/50
# 70/70 [==============================] - ETA: 0s - loss: 0.3210 - dice_coef: 0.7059 - iou: 0.5485 - recall_2: 0.9113 - precision_2: 0.8819
# Epoch 12: val_loss improved from 0.57492 to 0.55538, saving model to files/model3.h5
# 70/70 [==============================] - 54s 774ms/step - loss: 0.3210 - dice_coef: 0.7059 - iou: 0.5485 - recall_2: 0.9113 - precision_2: 0.8819 - val_loss: 0.5554 - val_dice_coef: 0.5351 - val_iou: 0.3918 - val_recall_2: 0.8706 - val_precision_2: 0.5862 - lr: 1.0000e-04
# Epoch 13/50
# 70/70 [==============================] - ETA: 0s - loss: 0.2849 - dice_coef: 0.7387 - iou: 0.5885 - recall_2: 0.9211 - precision_2: 0.8992
# Epoch 13: val_loss did not improve from 0.55538
# 70/70 [==============================] - 51s 728ms/step - loss: 0.2849 - dice_coef: 0.7387 - iou: 0.5885 - recall_2: 0.9211 - precision_2: 0.8992 - val_loss: 0.7928 - val_dice_coef: 0.4252 - val_iou: 0.2918 - val_recall_2: 0.8918 - val_precision_2: 0.3152 - lr: 1.0000e-04
# Epoch 14/50
# 70/70 [==============================] - ETA: 0s - loss: 0.2672 - dice_coef: 0.7559 - iou: 0.6106 - recall_2: 0.9184 - precision_2: 0.8914
# Epoch 14: val_loss improved from 0.55538 to 0.53983, saving model to files/model3.h5
# 70/70 [==============================] - 54s 779ms/step - loss: 0.2672 - dice_coef: 0.7559 - iou: 0.6106 - recall_2: 0.9184 - precision_2: 0.8914 - val_loss: 0.5398 - val_dice_coef: 0.5705 - val_iou: 0.4338 - val_recall_2: 0.9024 - val_precision_2: 0.5730 - lr: 1.0000e-04
# Epoch 15/50
# 70/70 [==============================] - ETA: 0s - loss: 0.2576 - dice_coef: 0.7657 - iou: 0.6243 - recall_2: 0.9030 - precision_2: 0.8907
# Epoch 15: val_loss did not improve from 0.53983
# 70/70 [==============================] - 51s 729ms/step - loss: 0.2576 - dice_coef: 0.7657 - iou: 0.6243 - recall_2: 0.9030 - precision_2: 0.8907 - val_loss: 1.5265 - val_dice_coef: 0.2951 - val_iou: 0.1969 - val_recall_2: 0.9165 - val_precision_2: 0.1310 - lr: 1.0000e-04
# Epoch 16/50
# 70/70 [==============================] - ETA: 0s - loss: 0.2345 - dice_coef: 0.7862 - iou: 0.6504 - recall_2: 0.9087 - precision_2: 0.9036
# Epoch 16: val_loss improved from 0.53983 to 0.45458, saving model to files/model3.h5
# 70/70 [==============================] - 54s 774ms/step - loss: 0.2345 - dice_coef: 0.7862 - iou: 0.6504 - recall_2: 0.9087 - precision_2: 0.9036 - val_loss: 0.4546 - val_dice_coef: 0.5972 - val_iou: 0.4545 - val_recall_2: 0.7466 - val_precision_2: 0.7252 - lr: 1.0000e-04
# Epoch 17/50
# 70/70 [==============================] - ETA: 0s - loss: 0.2260 - dice_coef: 0.7950 - iou: 0.6633 - recall_2: 0.9070 - precision_2: 0.8936
# Epoch 17: val_loss did not improve from 0.45458
# 70/70 [==============================] - 51s 728ms/step - loss: 0.2260 - dice_coef: 0.7950 - iou: 0.6633 - recall_2: 0.9070 - precision_2: 0.8936 - val_loss: 0.7802 - val_dice_coef: 0.4322 - val_iou: 0.3077 - val_recall_2: 0.9240 - val_precision_2: 0.2473 - lr: 1.0000e-04
# Epoch 18/50
# 70/70 [==============================] - ETA: 0s - loss: 0.2036 - dice_coef: 0.8149 - iou: 0.6904 - recall_2: 0.9188 - precision_2: 0.9038
# Epoch 18: val_loss did not improve from 0.45458
# 70/70 [==============================] - 51s 729ms/step - loss: 0.2036 - dice_coef: 0.8149 - iou: 0.6904 - recall_2: 0.9188 - precision_2: 0.9038 - val_loss: 0.5920 - val_dice_coef: 0.4676 - val_iou: 0.3220 - val_recall_2: 0.5005 - val_precision_2: 0.6962 - lr: 1.0000e-04
# Epoch 19/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1805 - dice_coef: 0.8357 - iou: 0.7200 - recall_2: 0.9142 - precision_2: 0.9256
# Epoch 19: val_loss did not improve from 0.45458
# 70/70 [==============================] - 51s 729ms/step - loss: 0.1805 - dice_coef: 0.8357 - iou: 0.7200 - recall_2: 0.9142 - precision_2: 0.9256 - val_loss: 0.4831 - val_dice_coef: 0.5872 - val_iou: 0.4546 - val_recall_2: 0.7598 - val_precision_2: 0.5931 - lr: 1.0000e-04
# Epoch 20/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1582 - dice_coef: 0.8552 - iou: 0.7486 - recall_2: 0.9276 - precision_2: 0.9381
# Epoch 20: val_loss improved from 0.45458 to 0.42411, saving model to files/model3.h5
# 70/70 [==============================] - 54s 778ms/step - loss: 0.1582 - dice_coef: 0.8552 - iou: 0.7486 - recall_2: 0.9276 - precision_2: 0.9381 - val_loss: 0.4241 - val_dice_coef: 0.6373 - val_iou: 0.5115 - val_recall_2: 0.7653 - val_precision_2: 0.7161 - lr: 1.0000e-04
# Epoch 21/50
# 70/70 [==============================] - ETA: 0s - loss: 0.2263 - dice_coef: 0.8019 - iou: 0.6817 - recall_2: 0.8760 - precision_2: 0.8593
# Epoch 21: val_loss did not improve from 0.42411
# 70/70 [==============================] - 51s 729ms/step - loss: 0.2263 - dice_coef: 0.8019 - iou: 0.6817 - recall_2: 0.8760 - precision_2: 0.8593 - val_loss: 1.3038 - val_dice_coef: 0.3498 - val_iou: 0.2381 - val_recall_2: 0.9036 - val_precision_2: 0.1400 - lr: 1.0000e-04
# Epoch 22/50
# 70/70 [==============================] - ETA: 0s - loss: 0.2135 - dice_coef: 0.8107 - iou: 0.6874 - recall_2: 0.8716 - precision_2: 0.8724
# Epoch 22: val_loss did not improve from 0.42411
# 70/70 [==============================] - 51s 728ms/step - loss: 0.2135 - dice_coef: 0.8107 - iou: 0.6874 - recall_2: 0.8716 - precision_2: 0.8724 - val_loss: 1.1023 - val_dice_coef: 0.4008 - val_iou: 0.2782 - val_recall_2: 0.9677 - val_precision_2: 0.1978 - lr: 1.0000e-04
# Epoch 23/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1832 - dice_coef: 0.8376 - iou: 0.7259 - recall_2: 0.8915 - precision_2: 0.8959
# Epoch 23: val_loss improved from 0.42411 to 0.40088, saving model to files/model3.h5
# 70/70 [==============================] - 54s 773ms/step - loss: 0.1832 - dice_coef: 0.8376 - iou: 0.7259 - recall_2: 0.8915 - precision_2: 0.8959 - val_loss: 0.4009 - val_dice_coef: 0.6643 - val_iou: 0.5447 - val_recall_2: 0.8234 - val_precision_2: 0.7071 - lr: 1.0000e-04
# Epoch 24/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1411 - dice_coef: 0.8727 - iou: 0.7761 - recall_2: 0.9220 - precision_2: 0.9338
# Epoch 24: val_loss did not improve from 0.40088
# 70/70 [==============================] - 51s 729ms/step - loss: 0.1411 - dice_coef: 0.8727 - iou: 0.7761 - recall_2: 0.9220 - precision_2: 0.9338 - val_loss: 0.5166 - val_dice_coef: 0.5368 - val_iou: 0.4049 - val_recall_2: 0.5519 - val_precision_2: 0.7404 - lr: 1.0000e-04
# Epoch 25/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1360 - dice_coef: 0.8777 - iou: 0.7838 - recall_2: 0.9228 - precision_2: 0.9321
# Epoch 25: val_loss did not improve from 0.40088
# 70/70 [==============================] - 51s 729ms/step - loss: 0.1360 - dice_coef: 0.8777 - iou: 0.7838 - recall_2: 0.9228 - precision_2: 0.9321 - val_loss: 0.5180 - val_dice_coef: 0.5378 - val_iou: 0.4104 - val_recall_2: 0.5897 - val_precision_2: 0.6941 - lr: 1.0000e-04
# Epoch 26/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1180 - dice_coef: 0.8931 - iou: 0.8080 - recall_2: 0.9319 - precision_2: 0.9450
# Epoch 26: val_loss did not improve from 0.40088
# 70/70 [==============================] - 51s 729ms/step - loss: 0.1180 - dice_coef: 0.8931 - iou: 0.8080 - recall_2: 0.9319 - precision_2: 0.9450 - val_loss: 0.5707 - val_dice_coef: 0.4879 - val_iou: 0.3655 - val_recall_2: 0.4786 - val_precision_2: 0.7652 - lr: 1.0000e-04
# Epoch 27/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1197 - dice_coef: 0.8922 - iou: 0.8070 - recall_2: 0.9248 - precision_2: 0.9466
# Epoch 27: val_loss did not improve from 0.40088
# 70/70 [==============================] - 51s 729ms/step - loss: 0.1197 - dice_coef: 0.8922 - iou: 0.8070 - recall_2: 0.9248 - precision_2: 0.9466 - val_loss: 0.4485 - val_dice_coef: 0.6094 - val_iou: 0.4864 - val_recall_2: 0.6794 - val_precision_2: 0.6904 - lr: 1.0000e-04
# Epoch 28/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1057 - dice_coef: 0.9044 - iou: 0.8263 - recall_2: 0.9330 - precision_2: 0.9558
# Epoch 28: val_loss did not improve from 0.40088
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 70/70 [==============================] - 51s 728ms/step - loss: 0.1057 - dice_coef: 0.9044 - iou: 0.8263 - recall_2: 0.9330 - precision_2: 0.9558 - val_loss: 0.4845 - val_dice_coef: 0.5701 - val_iou: 0.4325 - val_recall_2: 0.5653 - val_precision_2: 0.7404 - lr: 1.0000e-04
# Epoch 29/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0930 - dice_coef: 0.9155 - iou: 0.8447 - recall_2: 0.9407 - precision_2: 0.9655
# Epoch 29: val_loss did not improve from 0.40088
# 70/70 [==============================] - 51s 729ms/step - loss: 0.0930 - dice_coef: 0.9155 - iou: 0.8447 - recall_2: 0.9407 - precision_2: 0.9655 - val_loss: 0.5055 - val_dice_coef: 0.5519 - val_iou: 0.4128 - val_recall_2: 0.5361 - val_precision_2: 0.7357 - lr: 1.0000e-05
# Epoch 30/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0891 - dice_coef: 0.9187 - iou: 0.8501 - recall_2: 0.9422 - precision_2: 0.9704
# Epoch 30: val_loss did not improve from 0.40088
# 70/70 [==============================] - 51s 729ms/step - loss: 0.0891 - dice_coef: 0.9187 - iou: 0.8501 - recall_2: 0.9422 - precision_2: 0.9704 - val_loss: 0.4958 - val_dice_coef: 0.5618 - val_iou: 0.4228 - val_recall_2: 0.5505 - val_precision_2: 0.7360 - lr: 1.0000e-05
# Epoch 31/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0869 - dice_coef: 0.9206 - iou: 0.8534 - recall_2: 0.9445 - precision_2: 0.9719
# Epoch 31: val_loss did not improve from 0.40088
# 70/70 [==============================] - 51s 729ms/step - loss: 0.0869 - dice_coef: 0.9206 - iou: 0.8534 - recall_2: 0.9445 - precision_2: 0.9719 - val_loss: 0.4862 - val_dice_coef: 0.5717 - val_iou: 0.4337 - val_recall_2: 0.5648 - val_precision_2: 0.7352 - lr: 1.0000e-05
# Epoch 32/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0854 - dice_coef: 0.9220 - iou: 0.8558 - recall_2: 0.9456 - precision_2: 0.9729
# Epoch 32: val_loss did not improve from 0.40088
# 70/70 [==============================] - 51s 729ms/step - loss: 0.0854 - dice_coef: 0.9220 - iou: 0.8558 - recall_2: 0.9456 - precision_2: 0.9729 - val_loss: 0.4805 - val_dice_coef: 0.5778 - val_iou: 0.4404 - val_recall_2: 0.5735 - val_precision_2: 0.7335 - lr: 1.0000e-05
# Epoch 33/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0840 - dice_coef: 0.9232 - iou: 0.8578 - recall_2: 0.9464 - precision_2: 0.9737
# Epoch 33: val_loss did not improve from 0.40088
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1e-06.
# 70/70 [==============================] - 51s 729ms/step - loss: 0.0840 - dice_coef: 0.9232 - iou: 0.8578 - recall_2: 0.9464 - precision_2: 0.9737 - val_loss: 0.4778 - val_dice_coef: 0.5810 - val_iou: 0.4439 - val_recall_2: 0.5785 - val_precision_2: 0.7330 - lr: 1.0000e-05

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 1
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model4.h5")
csv_path = os.path.join("files", "data4.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model4 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 1024], strides=[1, 1, 2, 2])

model4.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model4.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 140 - 140
# Valid: 20 - 20
# Epoch 1/50
# 140/140 [==============================] - ETA: 0s - loss: 0.9936 - dice_coef: 0.2049 - iou: 0.1170 - recall_3: 0.7416 - precision_3: 0.4103
# Epoch 1: val_loss improved from inf to 5.20954, saving model to files/model4.h5
# 140/140 [==============================] - 155s 1s/step - loss: 0.9936 - dice_coef: 0.2049 - iou: 0.1170 - recall_3: 0.7416 - precision_3: 0.4103 - val_loss: 5.2095 - val_dice_coef: 0.0299 - val_iou: 0.0152 - val_recall_3: 1.0000 - val_precision_3: 0.0156 - lr: 1.0000e-04
# Epoch 2/50
# 140/140 [==============================] - ETA: 0s - loss: 0.7761 - dice_coef: 0.3300 - iou: 0.2009 - recall_3: 0.8368 - precision_3: 0.6418
# Epoch 2: val_loss improved from 5.20954 to 1.12374, saving model to files/model4.h5
# 140/140 [==============================] - 144s 1s/step - loss: 0.7761 - dice_coef: 0.3300 - iou: 0.2009 - recall_3: 0.8368 - precision_3: 0.6418 - val_loss: 1.1237 - val_dice_coef: 0.0217 - val_iou: 0.0110 - val_recall_3: 3.6993e-05 - val_precision_3: 4.0415e-04 - lr: 1.0000e-04
# Epoch 3/50
# 140/140 [==============================] - ETA: 0s - loss: 0.6752 - dice_coef: 0.4112 - iou: 0.2643 - recall_3: 0.8445 - precision_3: 0.6745
# Epoch 3: val_loss improved from 1.12374 to 1.06236, saving model to files/model4.h5
# 140/140 [==============================] - 144s 1s/step - loss: 0.6752 - dice_coef: 0.4112 - iou: 0.2643 - recall_3: 0.8445 - precision_3: 0.6745 - val_loss: 1.0624 - val_dice_coef: 0.0267 - val_iou: 0.0135 - val_recall_3: 0.0049 - val_precision_3: 1.0000 - lr: 1.0000e-04
# Epoch 4/50
# 140/140 [==============================] - ETA: 0s - loss: 0.5631 - dice_coef: 0.4985 - iou: 0.3389 - recall_3: 0.8605 - precision_3: 0.7441
# Epoch 4: val_loss did not improve from 1.06236
# 140/140 [==============================] - 142s 1s/step - loss: 0.5631 - dice_coef: 0.4985 - iou: 0.3389 - recall_3: 0.8605 - precision_3: 0.7441 - val_loss: 1.2568 - val_dice_coef: 0.1317 - val_iou: 0.0761 - val_recall_3: 0.3184 - val_precision_3: 0.0949 - lr: 1.0000e-04
# Epoch 5/50
# 140/140 [==============================] - ETA: 0s - loss: 0.4743 - dice_coef: 0.5734 - iou: 0.4117 - recall_3: 0.8561 - precision_3: 0.7841
# Epoch 5: val_loss improved from 1.06236 to 0.90276, saving model to files/model4.h5
# 140/140 [==============================] - 144s 1s/step - loss: 0.4743 - dice_coef: 0.5734 - iou: 0.4117 - recall_3: 0.8561 - precision_3: 0.7841 - val_loss: 0.9028 - val_dice_coef: 0.3079 - val_iou: 0.1958 - val_recall_3: 0.5449 - val_precision_3: 0.2323 - lr: 1.0000e-04
# Epoch 6/50
# 140/140 [==============================] - ETA: 0s - loss: 0.3878 - dice_coef: 0.6481 - iou: 0.4896 - recall_3: 0.8722 - precision_3: 0.8350
# Epoch 6: val_loss did not improve from 0.90276
# 140/140 [==============================] - 141s 1s/step - loss: 0.3878 - dice_coef: 0.6481 - iou: 0.4896 - recall_3: 0.8722 - precision_3: 0.8350 - val_loss: 1.0452 - val_dice_coef: 0.3546 - val_iou: 0.2361 - val_recall_3: 0.6313 - val_precision_3: 0.1729 - lr: 1.0000e-04
# Epoch 7/50
# 140/140 [==============================] - ETA: 0s - loss: 0.3425 - dice_coef: 0.6901 - iou: 0.5388 - recall_3: 0.8582 - precision_3: 0.8452
# Epoch 7: val_loss improved from 0.90276 to 0.82216, saving model to files/model4.h5
# 140/140 [==============================] - 144s 1s/step - loss: 0.3425 - dice_coef: 0.6901 - iou: 0.5388 - recall_3: 0.8582 - precision_3: 0.8452 - val_loss: 0.8222 - val_dice_coef: 0.3603 - val_iou: 0.2513 - val_recall_3: 0.5094 - val_precision_3: 0.2330 - lr: 1.0000e-04
# Epoch 8/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2965 - dice_coef: 0.7329 - iou: 0.5925 - recall_3: 0.8734 - precision_3: 0.8485
# Epoch 8: val_loss did not improve from 0.82216
# 140/140 [==============================] - 141s 1s/step - loss: 0.2965 - dice_coef: 0.7329 - iou: 0.5925 - recall_3: 0.8734 - precision_3: 0.8485 - val_loss: 1.5583 - val_dice_coef: 0.3062 - val_iou: 0.2071 - val_recall_3: 0.7453 - val_precision_3: 0.1018 - lr: 1.0000e-04
# Epoch 9/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2510 - dice_coef: 0.7734 - iou: 0.6440 - recall_3: 0.8832 - precision_3: 0.8805
# Epoch 9: val_loss did not improve from 0.82216
# 140/140 [==============================] - 141s 1s/step - loss: 0.2510 - dice_coef: 0.7734 - iou: 0.6440 - recall_3: 0.8832 - precision_3: 0.8805 - val_loss: 0.8708 - val_dice_coef: 0.2866 - val_iou: 0.1958 - val_recall_3: 0.3641 - val_precision_3: 0.2103 - lr: 1.0000e-04
# Epoch 10/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2163 - dice_coef: 0.8051 - iou: 0.6876 - recall_3: 0.8888 - precision_3: 0.8997
# Epoch 10: val_loss improved from 0.82216 to 0.74765, saving model to files/model4.h5
# 140/140 [==============================] - 144s 1s/step - loss: 0.2163 - dice_coef: 0.8051 - iou: 0.6876 - recall_3: 0.8888 - precision_3: 0.8997 - val_loss: 0.7477 - val_dice_coef: 0.4329 - val_iou: 0.3253 - val_recall_3: 0.5679 - val_precision_3: 0.2484 - lr: 1.0000e-04
# Epoch 11/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2098 - dice_coef: 0.8130 - iou: 0.7004 - recall_3: 0.8825 - precision_3: 0.8856
# Epoch 11: val_loss did not improve from 0.74765
# 140/140 [==============================] - 142s 1s/step - loss: 0.2098 - dice_coef: 0.8130 - iou: 0.7004 - recall_3: 0.8825 - precision_3: 0.8856 - val_loss: 0.8869 - val_dice_coef: 0.4060 - val_iou: 0.2940 - val_recall_3: 0.5085 - val_precision_3: 0.1935 - lr: 1.0000e-04
# Epoch 12/50
# 140/140 [==============================] - ETA: 0s - loss: 0.3027 - dice_coef: 0.7460 - iou: 0.6225 - recall_3: 0.8023 - precision_3: 0.8148
# Epoch 12: val_loss did not improve from 0.74765
# 140/140 [==============================] - 141s 1s/step - loss: 0.3027 - dice_coef: 0.7460 - iou: 0.6225 - recall_3: 0.8023 - precision_3: 0.8148 - val_loss: 2.8021 - val_dice_coef: 0.2585 - val_iou: 0.1771 - val_recall_3: 0.8030 - val_precision_3: 0.0732 - lr: 1.0000e-04
# Epoch 13/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2305 - dice_coef: 0.8079 - iou: 0.6990 - recall_3: 0.8407 - precision_3: 0.8570
# Epoch 13: val_loss did not improve from 0.74765
# 140/140 [==============================] - 141s 1s/step - loss: 0.2305 - dice_coef: 0.8079 - iou: 0.6990 - recall_3: 0.8407 - precision_3: 0.8570 - val_loss: 1.7462 - val_dice_coef: 0.3074 - val_iou: 0.2181 - val_recall_3: 0.6661 - val_precision_3: 0.1014 - lr: 1.0000e-04
# Epoch 14/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2105 - dice_coef: 0.8220 - iou: 0.7209 - recall_3: 0.8458 - precision_3: 0.8747
# Epoch 14: val_loss did not improve from 0.74765
# 140/140 [==============================] - 141s 1s/step - loss: 0.2105 - dice_coef: 0.8220 - iou: 0.7209 - recall_3: 0.8458 - precision_3: 0.8747 - val_loss: 0.9445 - val_dice_coef: 0.4289 - val_iou: 0.3182 - val_recall_3: 0.6636 - val_precision_3: 0.2107 - lr: 1.0000e-04
# Epoch 15/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1714 - dice_coef: 0.8523 - iou: 0.7589 - recall_3: 0.8749 - precision_3: 0.9039
# Epoch 15: val_loss did not improve from 0.74765
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 140/140 [==============================] - 141s 1s/step - loss: 0.1714 - dice_coef: 0.8523 - iou: 0.7589 - recall_3: 0.8749 - precision_3: 0.9039 - val_loss: 1.2278 - val_dice_coef: 0.2323 - val_iou: 0.1686 - val_recall_3: 0.3698 - val_precision_3: 0.1221 - lr: 1.0000e-04
# Epoch 16/50
#  99/140 [====================>.........] - ETA: 39s - loss: 0.1446 - dice_coef: 0.8743 - iou: 0.7884 - recall_3: 0.8737 - precision_3: 0.9333

# %% [markdown]
# ### Evaluating the Model:

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import pandas as pd
import cv2
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import accuracy_score, f1_score, jaccard_score, precision_score, recall_score
from tensorflow.keras.models import load_model

# %%
H = 512
W = 512

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.float32)
    return ori_x, x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.int32)
    return ori_x, x

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.png")))
    y = sorted(glob(os.path.join(path, "mask", "*.png")))
    return x, y

def save_results(ori_x, ori_y, y_pred, save_image_path):
    line = np.ones((H, 10, 3)) * 255

    ori_y = np.expand_dims(ori_y, axis=-1)
    ori_y = np.concatenate([ori_y, ori_y, ori_y], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1) * 255

    cat_images = np.concatenate([ori_x, line, ori_y, line, y_pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model1.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score1 = [s[1:] for s in SCORE]
score1 = np.mean(score1, axis=0)
print(f"Accuracy: {score1[0]:0.5f}")
print(f"F1: {score1[1]:0.5f}")
print(f"Jaccard: {score1[2]:0.5f}")
print(f"Recall: {score1[3]:0.5f}")
print(f"Precision: {score1[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score1.csv")
# Out:
# 100%|██████████| 20/20 [00:48<00:00,  2.42s/it]
# Accuracy: 0.99275
# F1: 0.76432
# Jaccard: 0.66817
# Recall: 0.91758
# Precision: 0.74463

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model2.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score2 = [s[1:] for s in SCORE]
score2 = np.mean(score2, axis=0)
print(f"Accuracy: {score2[0]:0.5f}")
print(f"F1: {score2[1]:0.5f}")
print(f"Jaccard: {score2[2]:0.5f}")
print(f"Recall: {score2[3]:0.5f}")
print(f"Precision: {score2[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score2.csv")
# Out:
#  10%|█         | 2/20 [00:01<00:09,  1.84it/s]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 100%|██████████| 20/20 [00:07<00:00,  2.76it/s]
# Accuracy: 0.99272
# F1: 0.72981
# Jaccard: 0.64111
# Recall: 0.87093
# Precision: 0.71588

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model3.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score3 = [s[1:] for s in SCORE]
score3 = np.mean(score3, axis=0)
print(f"Accuracy: {score3[0]:0.5f}")
print(f"F1: {score3[1]:0.5f}")
print(f"Jaccard: {score3[2]:0.5f}")
print(f"Recall: {score3[3]:0.5f}")
print(f"Precision: {score3[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score3.csv")
# Out:
#  10%|█         | 2/20 [00:03<00:25,  1.44s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 100%|██████████| 20/20 [00:10<00:00,  1.98it/s]
# Accuracy: 0.99210
# F1: 0.72926
# Jaccard: 0.64654
# Recall: 0.87385
# Precision: 0.71431

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model4.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score4 = [s[1:] for s in SCORE]
score4 = np.mean(score4, axis=0)
print(f"Accuracy: {score4[0]:0.5f}")
print(f"F1: {score4[1]:0.5f}")
print(f"Jaccard: {score4[2]:0.5f}")
print(f"Recall: {score4[3]:0.5f}")
print(f"Precision: {score4[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score4.csv")
# Out:
#  10%|█         | 2/20 [00:05<00:42,  2.37s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  20%|██        | 4/20 [00:06<00:17,  1.11s/it]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#  25%|██▌       | 5/20 [00:07<00:13,  1.12it/s]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 100%|██████████| 20/20 [00:14<00:00,  1.38it/s]
# Accuracy: 0.96712
# F1: 0.48057
# Jaccard: 0.38716
# Recall: 0.65704
# Precision: 0.57422

# %%
import matplotlib.pyplot as plt

z_dim = [16, 32, 64, 128]
final_score = [score1[1], score2[1], score3[1], score4[1]]

plt.plot(z_dim, final_score)  
plt.show()
