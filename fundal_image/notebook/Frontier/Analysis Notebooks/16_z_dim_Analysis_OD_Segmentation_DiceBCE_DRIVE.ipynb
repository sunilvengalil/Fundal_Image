# %% [markdown]
# ### Import the required libraries and modules:

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
import numpy as np

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# %cd /content/gdrive/MyDrive/Blood_Vessel_Results/ALL_BEST_RESULTS/DRIVE_OD_4
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/Blood_Vessel_Results/ALL_BEST_RESULTS/DRIVE_OD_4

# %% [markdown]
# ### Unzip the data:

# %%
# !unzip new_data.zip

# %% [markdown]
# ### Construct the Model:

# %%
def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(inputs, num_filters, strides=2):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D(strides)(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters, strides=2):
    x = Conv2DTranspose(num_filters, (2, 2), strides=strides, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape, num_filters=[64, 128, 256, 512, 1024], strides=[2, 2, 2, 2]):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, num_filters[0], strides=strides[0])
    s2, p2 = encoder_block(p1, num_filters[1], strides=strides[1])
    s3, p3 = encoder_block(p2, num_filters[2], strides=strides[2])
    s4, p4 = encoder_block(p3, num_filters[3], strides=strides[3])

    b1 = conv_block(p4, num_filters[4])

    d1 = decoder_block(b1, s4, num_filters[3], strides=strides[3])
    d2 = decoder_block(d1, s3, num_filters[2], strides=strides[2])
    d3 = decoder_block(d2, s2, num_filters[1], strides=strides[1])
    d4 = decoder_block(d3, s1, num_filters[0], strides=strides[0])

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="UNET")
    return model

input_shape = (512, 512, 3)
model = build_unet(input_shape)
model.summary()
# Out:
# Model: "UNET"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 512, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 512, 512, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 512, 512, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 512, 512, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 12  0          ['activation_3[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 25  295168      ['max_pooling2d_1[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_4[0][0]']
#  rmalization)                   6)
#
#  activation_4 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_4[0][0]']
#                                 6)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 25  590080      ['activation_4[0][0]']
#                                 6)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_5[0][0]']
#  rmalization)                   6)
#
#  activation_5 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_5[0][0]']
#                                 6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 512)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 512)  2097664    ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 64, 64, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 25  524544     ['activation_11[0][0]']
#  spose)                         6)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 51  0           ['conv2d_transpose_1[0][0]',
#                                 2)                                'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_12 (BatchN  (None, 128, 128, 25  1024       ['conv2d_12[0][0]']
#  ormalization)                  6)
#
#  activation_12 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_12[0][0]']
#                                 6)
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 25  590080      ['activation_12[0][0]']
#                                 6)
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 25  1024       ['conv2d_13[0][0]']
#  ormalization)                  6)
#
#  activation_13 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_13[0][0]']
#                                 6)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 12  131200     ['activation_13[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 256, 256, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  activation_14 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_15 (BatchN  (None, 256, 256, 12  512        ['conv2d_15[0][0]']
#  ormalization)                  8)
#
#  activation_15 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_15[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 64  32832      ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 512, 512, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 512, 512, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 512, 512, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 512, 512, 1)  65          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %% [markdown]
# ### Adding the Metrics:

# %%
def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def DiceBCELoss(y_true, y_pred):

    inputs = tf.keras.layers.Flatten()(y_true)
    targets = tf.keras.layers.Flatten()(y_pred)

    intersection = tf.reduce_sum(inputs * targets)
    dice_loss = 1 - (2.*intersection + smooth)/(tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)
    BCE = tf.keras.losses.BinaryCrossentropy()
    Dice_BCE = BCE(inputs, targets) + dice_loss

    return Dice_BCE

# %% [markdown]
# ### Training the Model:

# %%
H = 512
W = 512

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.png")))
    y = sorted(glob(os.path.join(path, "mask", "*.png")))
    return x, y

def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)
    return x, y

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)              ## (512, 512, 1)
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y, batch_size=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(4)
    return dataset

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 4
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model1.h5")
csv_path = os.path.join("files", "data1.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model1 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 384], strides=[2, 2, 2, 4])

model1.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model1.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 140 - 140
# Valid: 20 - 20
# Epoch 1/50
# 35/35 [==============================] - ETA: 0s - loss: 1.2788 - dice_coef: 0.0932 - iou: 0.0492 - recall: 0.5982 - precision: 0.1547
# Epoch 1: val_loss improved from inf to 1.65221, saving model to files/model1.h5
# 35/35 [==============================] - 68s 1s/step - loss: 1.2788 - dice_coef: 0.0932 - iou: 0.0492 - recall: 0.5982 - precision: 0.1547 - val_loss: 1.6522 - val_dice_coef: 0.0284 - val_iou: 0.0144 - val_recall: 0.0227 - val_precision: 0.0012 - lr: 1.0000e-04
# Epoch 2/50
# 35/35 [==============================] - ETA: 0s - loss: 0.9734 - dice_coef: 0.1957 - iou: 0.1090 - recall: 0.7571 - precision: 0.6548
# Epoch 2: val_loss improved from 1.65221 to 1.64152, saving model to files/model1.h5
# 35/35 [==============================] - 17s 493ms/step - loss: 0.9734 - dice_coef: 0.1957 - iou: 0.1090 - recall: 0.7571 - precision: 0.6548 - val_loss: 1.6415 - val_dice_coef: 0.0316 - val_iou: 0.0161 - val_recall: 0.8857 - val_precision: 0.0342 - lr: 1.0000e-04
# Epoch 3/50
# 35/35 [==============================] - ETA: 0s - loss: 0.8630 - dice_coef: 0.2588 - iou: 0.1491 - recall: 0.8211 - precision: 0.7558
# Epoch 3: val_loss improved from 1.64152 to 1.33574, saving model to files/model1.h5
# 35/35 [==============================] - 17s 492ms/step - loss: 0.8630 - dice_coef: 0.2588 - iou: 0.1491 - recall: 0.8211 - precision: 0.7558 - val_loss: 1.3357 - val_dice_coef: 0.0288 - val_iou: 0.0146 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 4/50
# 35/35 [==============================] - ETA: 0s - loss: 0.7913 - dice_coef: 0.3073 - iou: 0.1821 - recall: 0.8754 - precision: 0.8074
# Epoch 4: val_loss improved from 1.33574 to 1.21688, saving model to files/model1.h5
# 35/35 [==============================] - 17s 493ms/step - loss: 0.7913 - dice_coef: 0.3073 - iou: 0.1821 - recall: 0.8754 - precision: 0.8074 - val_loss: 1.2169 - val_dice_coef: 0.0313 - val_iou: 0.0159 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 5/50
# 35/35 [==============================] - ETA: 0s - loss: 0.7594 - dice_coef: 0.3316 - iou: 0.1994 - recall: 0.8720 - precision: 0.7856
# Epoch 5: val_loss improved from 1.21688 to 1.15634, saving model to files/model1.h5
# 35/35 [==============================] - 17s 496ms/step - loss: 0.7594 - dice_coef: 0.3316 - iou: 0.1994 - recall: 0.8720 - precision: 0.7856 - val_loss: 1.1563 - val_dice_coef: 0.0325 - val_iou: 0.0165 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 6/50
# 35/35 [==============================] - ETA: 0s - loss: 0.7162 - dice_coef: 0.3630 - iou: 0.2223 - recall: 0.8881 - precision: 0.8205
# Epoch 6: val_loss improved from 1.15634 to 1.12445, saving model to files/model1.h5
# 35/35 [==============================] - 17s 497ms/step - loss: 0.7162 - dice_coef: 0.3630 - iou: 0.2223 - recall: 0.8881 - precision: 0.8205 - val_loss: 1.1245 - val_dice_coef: 0.0323 - val_iou: 0.0164 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 7/50
# 35/35 [==============================] - ETA: 0s - loss: 0.6767 - dice_coef: 0.3930 - iou: 0.2452 - recall: 0.9053 - precision: 0.8469
# Epoch 7: val_loss improved from 1.12445 to 1.09503, saving model to files/model1.h5
# 35/35 [==============================] - 17s 496ms/step - loss: 0.6767 - dice_coef: 0.3930 - iou: 0.2452 - recall: 0.9053 - precision: 0.8469 - val_loss: 1.0950 - val_dice_coef: 0.0308 - val_iou: 0.0157 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 8/50
# 35/35 [==============================] - ETA: 0s - loss: 0.6440 - dice_coef: 0.4193 - iou: 0.2659 - recall: 0.9141 - precision: 0.8489
# Epoch 8: val_loss improved from 1.09503 to 1.08134, saving model to files/model1.h5
# 35/35 [==============================] - 18s 511ms/step - loss: 0.6440 - dice_coef: 0.4193 - iou: 0.2659 - recall: 0.9141 - precision: 0.8489 - val_loss: 1.0813 - val_dice_coef: 0.0288 - val_iou: 0.0146 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 
# 35/35 [==============================] - 17s 495ms/step - loss: 0.0974 - dice_coef: 0.9080 - iou: 0.8317 - recall: 0.9646 - precision: 0.9905 - val_loss: 0.3433 - val_dice_coef: 0.7167 - val_iou: 0.5644 - val_recall: 0.8471 - val_precision: 0.7335 - lr: 1.0000e-05
# Epoch 50/50
# 35/35 [==============================] - ETA: 0s - loss: 0.0963 - dice_coef: 0.9090 - iou: 0.8334 - recall: 0.9652 - precision: 0.9911
# Epoch 50: val_loss improved from 0.34330 to 0.34289, saving model to files/model1.h5
# 35/35 [==============================] - 17s 495ms/step - loss: 0.0963 - dice_coef: 0.9090 - iou: 0.8334 - recall: 0.9652 - precision: 0.9911 - val_loss: 0.3429 - val_dice_coef: 0.7171 - val_iou: 0.5648 - val_recall: 0.8456 - val_precision: 0.7344 - lr: 1.0000e-05

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 4
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model2.h5")
csv_path = os.path.join("files", "data2.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model2 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 512], strides=[2, 2, 2, 4])

model2.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model2.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 140 - 140
# Valid: 20 - 20
# Epoch 1/50
# 35/35 [==============================] - ETA: 0s - loss: 1.2792 - dice_coef: 0.0926 - iou: 0.0489 - recall_1: 0.5933 - precision_1: 0.1538
# Epoch 1: val_loss improved from inf to 1.65284, saving model to files/model2.h5
# 35/35 [==============================] - 19s 484ms/step - loss: 1.2792 - dice_coef: 0.0926 - iou: 0.0489 - recall_1: 0.5933 - precision_1: 0.1538 - val_loss: 1.6528 - val_dice_coef: 0.0284 - val_iou: 0.0144 - val_recall_1: 0.0240 - val_precision_1: 0.0012 - lr: 1.0000e-04
# Epoch 2/50
# 35/35 [==============================] - ETA: 0s - loss: 0.9668 - dice_coef: 0.1996 - iou: 0.1113 - recall_1: 0.7750 - precision_1: 0.6675
# Epoch 2: val_loss did not improve from 1.65284
# 35/35 [==============================] - 16s 445ms/step - loss: 0.9668 - dice_coef: 0.1996 - iou: 0.1113 - recall_1: 0.7750 - precision_1: 0.6675 - val_loss: 1.7281 - val_dice_coef: 0.0318 - val_iou: 0.0162 - val_recall_1: 0.9990 - val_precision_1: 0.0184 - lr: 1.0000e-04
# Epoch 3/50
# 35/35 [==============================] - ETA: 0s - loss: 0.8575 - dice_coef: 0.2640 - iou: 0.1526 - recall_1: 0.8378 - precision_1: 0.7634
# Epoch 3: val_loss improved from 1.65284 to 1.34023, saving model to files/model2.h5
# 35/35 [==============================] - 18s 502ms/step - loss: 0.8575 - dice_coef: 0.2640 - iou: 0.1526 - recall_1: 0.8378 - precision_1: 0.7634 - val_loss: 1.3402 - val_dice_coef: 0.0291 - val_iou: 0.0148 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 4/50
# 35/35 [==============================] - ETA: 0s - loss: 0.7931 - dice_coef: 0.3065 - iou: 0.1816 - recall_1: 0.8701 - precision_1: 0.7989
# Epoch 4: val_loss improved from 1.34023 to 1.21532, saving model to files/model2.h5
# 35/35 [==============================] - 17s 493ms/step - loss: 0.7931 - dice_coef: 0.3065 - iou: 0.1816 - recall_1: 0.8701 - precision_1: 0.7989 - val_loss: 1.2153 - val_dice_coef: 0.0315 - val_iou: 0.0160 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 5/50
# 35/35 [==============================] - ETA: 0s - loss: 0.7507 - dice_coef: 0.3396 - iou: 0.2053 - recall_1: 0.8921 - precision_1: 0.8092
# Epoch 5: val_loss improved from 1.21532 to 1.14446, saving model to files/model2.h5
# 35/35 [==============================] - 17s 494ms/step - loss: 0.7507 - dice_coef: 0.3396 - iou: 0.2053 - recall_1: 0.8921 - precision_1: 0.8092 - val_loss: 1.1445 - val_dice_coef: 0.0340 - val_iou: 0.0173 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 6/50
# 35/35 [==============================] - ETA: 0s - loss: 0.7194 - dice_coef: 0.3606 - iou: 0.2206 - recall_1: 0.8830 - precision_1: 0.8139
# Epoch 6: val_loss improved from 1.14446 to 1.11206, saving model to files/model2.h5
# 35/35 [==============================] - 18s 499ms/step - loss: 0.7194 - dice_coef: 0.3606 - iou: 0.2206 - recall_1: 0.8830 - precision_1: 0.8139 - val_loss: 1.1121 - val_dice_coef: 0.0402 - val_iou: 0.0205 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 7/50
# 35/35 [==============================] - ETA: 0s - loss: 0.6748 - dice_coef: 0.3930 - iou: 0.2451 - recall_1: 0.9043 - precision_1: 0.8565
# Epoch 7: val_loss improved from 1.11206 to 1.09335, saving model to files/model2.h5
# 35/35 [==============================] - 16s 446ms/step - loss: 0.3589 - dice_coef: 0.6649 - iou: 0.4994 - recall_1: 0.9518 - precision_1: 0.9416 - val_loss: 0.6312 - val_dice_coef: 0.4704 - val_iou: 0.3119 - val_recall_1: 0.8774 - val_precision_1: 0.5781 - lr: 1.0000e-04
# Epoch 19/50
# 35/35 [==============================] - ETA: 0s - loss: 0.3509 - dice_coef: 0.6733 - iou: 0.5085 - recall_1: 0.9412 - precision_1: 0.9294
# Epoch 19: val_loss did not improve from 0.61237
# 35/35 [==============================] - 16s 446ms/step - loss: 0.3509 - dice_coef: 0.6733 - iou: 0.5085 - recall_1: 0.9412 - precision_1: 0.9294 - val_loss: 0.6141 - val_dice_coef: 0.4909 - val_iou: 0.3286 - val_recall_1: 0.9210 - val_precision_1: 0.5706 - lr: 1.0000e-04
# Epoch 20/50
# 35/35 [==============================] - ETA: 0s - loss: 0.3432 - dice_coef: 0.6814 - iou: 0.5179 - recall_1: 0.9267 - precision_1: 0.9227
# Epoch 20: val_loss improved from 0.61237 to 0.56062, saving model to files/model2.h5
# 35/35 [==============================] - 18s 503ms/step - loss: 0.3432 - dice_coef: 0.6814 - iou: 0.5179 - recall_1: 0.9267 - precision_1: 0.9227 - val_loss: 0.5606 - val_dice_coef: 0.5222 - val_iou: 0.3560 - val_recall_1: 0.8645 - val_precision_1: 0.6686 - lr: 1.0000e-04
# Epoch 21/50
# 35/35 [==============================] - ETA: 0s - loss: 0.3126 - dice_coef: 0.7081 - iou: 0.5492 - recall_1: 0.9376 - precision_1: 0.9449
# Epoch 21: val_loss did not improve from 0.56062
# 35/35 [==============================] - 16s 445ms/step - loss: 0.3126 - dice_coef: 0.7081 - iou: 0.5492 - recall_1: 0.9376 - precision_1: 0.9449 - val_loss: 0.6291 - val_dice_coef: 0.5083 - val_iou: 0.3472 - val_recall_1: 0.9459 - val_precision_1: 0.5331 - lr: 1.0000e-04
# Epoch 22/50
# 35/35 [==============================] - ETA: 0s - loss: 0.2916 - dice_coef: 0.7277 - iou: 0.5729 - recall_1: 0.9460 - precision_1: 0.9433
# Epoch 22: val_loss did not improve from 0.56062
# 35/35 [==============================] - 16s 445ms/step - loss: 0.2916 - dice_coef: 0.7277 - iou: 0.5729 - recall_1: 0.9460 - precision_1: 0.9433 - val_loss: 0.5827 - val_dice_coef: 0.5132 - val_iou: 0.3467 - val_recall_1: 0.8213 - val_precision_1: 0.6245 - lr: 1.0000e-04
# Epoch 23/50
# 35/35 [==============================] - ETA: 0s - loss: 0.2740 - dice_coef: 0.7436 - iou: 0.5928 - recall_1: 0.9464 - precision_1: 0.9499
# Epoch 23: val_loss improved from 0.56062 to 0.50909, saving model to files/model2.h5
# 35/35 [==============================] - 18s 506ms/step - loss: 0.2740 - dice_coef: 0.7436 - iou: 0.5928 - recall_1: 0.9464 - precision_1: 0.9499 - val_loss: 0.5091 - val_dice_coef: 0.5441 - val_iou: 0.3776 - val_recall_1: 0.7750 - val_precision_1: 0.7660 - lr: 1.0000e-04
# Epoch 24/50
# 35/35 [==============================] - ETA: 0s - loss: 0.2599 - dice_coef: 0.7571 - iou: 0.6098 - recall_1: 0.9426 - precision_1: 0.9534
# Epoch 24: val_loss improved from 0.50909 to 0.50652, saving model to files/model2.h5
# 35/35 [==============================] - 18s 498ms/step - loss: 0.2599 - dice_coef: 0.7571 - iou: 0.6098 - recall_1: 0.9426 - precision_1: 0.9534 - val_loss: 0.5065 - val_dice_coef: 0.5701 - val_iou: 0.4014 - val_recall_1: 0.8393 - val_precision_1: 0.6925 - lr: 1.0000e-04
# Epoch 25/50
# 35/35 [==============================] - ETA: 0s - loss: 0.2396 - dice_coef: 0.7757 - iou: 0.6346 - recall_1: 0.9541 - precision_1: 0.9594
# Epoch 25: val_loss improved from 0.50652 to 0.48196, saving model to files/model2.h5
# 35/35 [==============================] - 17s 495ms/step - loss: 0.2396 - dice_coef: 0.7757 - iou: 0.6346 - recall_1: 0.9541 - precision_1: 0.9594 - val_loss: 0.4820 - val_dice_coef: 0.5876 - val_iou: 0.4205 - val_recall_1: 0.8380 - val_precision_1: 0.7044 - lr: 1.0000e-04
# Epoch 26/50
# 35/35 [==============================] - ETA: 0s - loss: 0.2263 - dice_coef: 0.7877 - iou: 0.6509 - recall_1: 0.9543 - precision_1: 0.9621
# Epoch 26: val_loss improved from 0.48196 to 0.46281, saving model to files/model2.h5
# 35/35 [==============================] - 18s 501ms/step - loss: 0.2263 - dice_coef: 0.7877 - iou: 0.6509 - recall_1: 0.9543 - precision_1: 0.9621 - val_loss: 0.4628 - val_dice_coef: 0.6050 - val_iou: 0.4410 - val_recall_1: 0.8490 - val_precision_1: 0.7057 - lr: 1.0000e-04
# Epoch 27/50
# 35/35 [==============================] - ETA: 0s - loss: 0.2190 - dice_coef: 0.7950 - iou: 0.6607 - recall_1: 0.9515 - precision_1: 0.9575
# Epoch 27: val_loss improved from 0.46281 to 0.45534, saving model to files/model2.h5
# 35/35 [==============================] - 17s 495ms/step - loss: 0.2190 - dice_coef: 0.7950 - iou: 0.6607 - recall_1: 0.9515 - precision_1: 0.9575 - val_loss: 0.4553 - val_dice_coef: 0.6018 - val_iou: 0.4345 - val_recall_1: 0.7894 - val_precision_1: 0.7323 - lr: 1.0000e-04
# Epoch 28/50
# 35/35 [==============================] - ETA: 0s - loss: 0.2175 - dice_coef: 0.7976 - iou: 0.6643 - recall_1: 0.9415 - precision_1: 0.9505
# Epoch 28: val_loss did not improve from 0.45534
# 35/35 [==============================] - 16s 446ms/step - loss: 0.2175 - dice_coef: 0.7976 - iou: 0.6643 - recall_1: 0.9415 - precision_1: 0.9505 - val_loss: 0.4623 - val_dice_coef: 0.6139 - val_iou: 0.4480 - val_recall_1: 0.8378 - val_precision_1: 0.6812 - lr: 1.0000e-04
# Epoch 29/50
# 35/35 [==============================] - ETA: 0s - loss: 0.2042 - dice_coef: 0.8095 - iou: 0.6807 - recall_1: 0.9457 - precision_1: 0.9544
# Epoch 29: val_loss improved from 0.45534 to 0.42852, saving model to files/model2.h5
# Epoch 41/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1072 - dice_coef: 0.8994 - iou: 0.8175 - recall_1: 0.9605 - precision_1: 0.9841
# Epoch 41: val_loss did not improve from 0.35918
# 35/35 [==============================] - 16s 446ms/step - loss: 0.1072 - dice_coef: 0.8994 - iou: 0.8175 - recall_1: 0.9605 - precision_1: 0.9841 - val_loss: 0.3694 - val_dice_coef: 0.6914 - val_iou: 0.5344 - val_recall_1: 0.7923 - val_precision_1: 0.7400 - lr: 1.0000e-04
# Epoch 42/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1040 - dice_coef: 0.9027 - iou: 0.8229 - recall_1: 0.9621 - precision_1: 0.9824
# Epoch 42: val_loss did not improve from 0.35918
# 35/35 [==============================] - 16s 446ms/step - loss: 0.1040 - dice_coef: 0.9027 - iou: 0.8229 - recall_1: 0.9621 - precision_1: 0.9824 - val_loss: 0.3763 - val_dice_coef: 0.6842 - val_iou: 0.5271 - val_recall_1: 0.7859 - val_precision_1: 0.7329 - lr: 1.0000e-04
# Epoch 43/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1036 - dice_coef: 0.9034 - iou: 0.8241 - recall_1: 0.9572 - precision_1: 0.9807
# Epoch 43: val_loss did not improve from 0.35918
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 35/35 [==============================] - 16s 446ms/step - loss: 0.1036 - dice_coef: 0.9034 - iou: 0.8241 - recall_1: 0.9572 - precision_1: 0.9807 - val_loss: 0.3817 - val_dice_coef: 0.6700 - val_iou: 0.5112 - val_recall_1: 0.6952 - val_precision_1: 0.7833 - lr: 1.0000e-04
# Epoch 44/50
# 35/35 [==============================] - ETA: 0s - loss: 0.0988 - dice_coef: 0.9076 - iou: 0.8312 - recall_1: 0.9584 - precision_1: 0.9853
# Epoch 44: val_loss improved from 0.35918 to 0.34550, saving model to files/model2.h5
# 35/35 [==============================] - 18s 502ms/step - loss: 0.0988 - dice_coef: 0.9076 - iou: 0.8312 - recall_1: 0.9584 - precision_1: 0.9853 - val_loss: 0.3455 - val_dice_coef: 0.7161 - val_iou: 0.5637 - val_recall_1: 0.8433 - val_precision_1: 0.7269 - lr: 1.0000e-05
# Epoch 45/50
# 35/35 [==============================] - ETA: 0s - loss: 0.0913 - dice_coef: 0.9139 - iou: 0.8418 - recall_1: 0.9659 - precision_1: 0.9890
# Epoch 45: val_loss did not improve from 0.34550
# 35/35 [==============================] - 16s 446ms/step - loss: 0.0913 - dice_coef: 0.9139 - iou: 0.8418 - recall_1: 0.9659 - precision_1: 0.9890 - val_loss: 0.3480 - val_dice_coef: 0.7151 - val_iou: 0.5631 - val_recall_1: 0.8455 - val_precision_1: 0.7242 - lr: 1.0000e-05
# Epoch 46/50
# 35/35 [==============================] - ETA: 0s - loss: 0.0895 - dice_coef: 0.9155 - iou: 0.8444 - recall_1: 0.9663 - precision_1: 0.9908
# Epoch 46: val_loss did not improve from 0.34550
# 35/35 [==============================] - 16s 446ms/step - loss: 0.0895 - dice_coef: 0.9155 - iou: 0.8444 - recall_1: 0.9663 - precision_1: 0.9908 - val_loss: 0.3494 - val_dice_coef: 0.7142 - val_iou: 0.5623 - val_recall_1: 0.8454 - val_precision_1: 0.7228 - lr: 1.0000e-05
# Epoch 47/50
# 35/35 [==============================] - ETA: 0s - loss: 0.0881 - dice_coef: 0.9167 - iou: 0.8465 - recall_1: 0.9672 - precision_1: 0.9918
# Epoch 47: val_loss did not improve from 0.34550
# 35/35 [==============================] - 16s 446ms/step - loss: 0.0881 - dice_coef: 0.9167 - iou: 0.8465 - recall_1: 0.9672 - precision_1: 0.9918 - val_loss: 0.3493 - val_dice_coef: 0.7141 - val_iou: 0.5622 - val_recall_1: 0.8441 - val_precision_1: 0.7237 - lr: 1.0000e-05
# Epoch 48/50
# 35/35 [==============================] - ETA: 0s - loss: 0.0869 - dice_coef: 0.9177 - iou: 0.8482 - recall_1: 0.9676 - precision_1: 0.9926
# Epoch 48: val_loss did not improve from 0.34550
# 35/35 [==============================] - 16s 446ms/step - loss: 0.0869 - dice_coef: 0.9177 - iou: 0.8482 - recall_1: 0.9676 - precision_1: 0.9926 - val_loss: 0.3491 - val_dice_coef: 0.7142 - val_iou: 0.5623 - val_recall_1: 0.8434 - val_precision_1: 0.7244 - lr: 1.0000e-05
# Epoch 49/50
# 35/35 [==============================] - ETA: 0s - loss: 0.0860 - dice_coef: 0.9186 - iou: 0.8498 - recall_1: 0.9680 - precision_1: 0.9932
# Epoch 49: val_loss did not improve from 0.34550
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1e-06.
# 35/35 [==============================] - 16s 446ms/step - loss: 0.0860 - dice_coef: 0.9186 - iou: 0.8498 - recall_1: 0.9680 - precision_1: 0.9932 - val_loss: 0.3486 - val_dice_coef: 0.7145 - val_iou: 0.5626 - val_recall_1: 0.8427 - val_precision_1: 0.7250 - lr: 1.0000e-05
# Epoch 50/50
# 35/35 [==============================] - ETA: 0s - loss: 0.0847 - dice_coef: 0.9197 - iou: 0.8516 - recall_1: 0.9698 - precision_1: 0.9937
# Epoch 50: val_loss did not improve from 0.34550
# 35/35 [==============================] - 16s 446ms/step - loss: 0.0847 - dice_coef: 0.9197 - iou: 0.8516 - recall_1: 0.9698 - precision_1: 0.9937 - val_loss: 0.3488 - val_dice_coef: 0.7145 - val_iou: 0.5627 - val_recall_1: 0.8430 - val_precision_1: 0.7246 - lr: 1.0000e-06

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 4
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model3.h5")
csv_path = os.path.join("files", "data3.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model3 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 768], strides=[2, 2, 2, 4])

model3.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model3.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 140 - 140
# Valid: 20 - 20
# Epoch 1/50
# 35/35 [==============================] - ETA: 0s - loss: 1.2776 - dice_coef: 0.0933 - iou: 0.0492 - recall_2: 0.5988 - precision_2: 0.1551
# Epoch 1: val_loss improved from inf to 1.65216, saving model to files/model3.h5
# 35/35 [==============================] - 20s 493ms/step - loss: 1.2776 - dice_coef: 0.0933 - iou: 0.0492 - recall_2: 0.5988 - precision_2: 0.1551 - val_loss: 1.6522 - val_dice_coef: 0.0284 - val_iou: 0.0144 - val_recall_2: 0.0231 - val_precision_2: 0.0012 - lr: 1.0000e-04
# Epoch 2/50
# 35/35 [==============================] - ETA: 0s - loss: 0.9707 - dice_coef: 0.1976 - iou: 0.1101 - recall_2: 0.7678 - precision_2: 0.6526
# Epoch 2: val_loss improved from 1.65216 to 1.52345, saving model to files/model3.h5
# 35/35 [==============================] - 18s 521ms/step - loss: 0.9707 - dice_coef: 0.1976 - iou: 0.1101 - recall_2: 0.7678 - precision_2: 0.6526 - val_loss: 1.5234 - val_dice_coef: 0.0284 - val_iou: 0.0144 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 3/50
# 35/35 [==============================] - ETA: 0s - loss: 0.8681 - dice_coef: 0.2589 - iou: 0.1492 - recall_2: 0.8292 - precision_2: 0.7249
# Epoch 3: val_loss improved from 1.52345 to 1.34143, saving model to files/model3.h5
# 35/35 [==============================] - 18s 516ms/step - loss: 0.8681 - dice_coef: 0.2589 - iou: 0.1492 - recall_2: 0.8292 - precision_2: 0.7249 - val_loss: 1.3414 - val_dice_coef: 0.0290 - val_iou: 0.0147 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 4/50
# 35/35 [==============================] - ETA: 0s - loss: 0.7987 - dice_coef: 0.3024 - iou: 0.1786 - recall_2: 0.8662 - precision_2: 0.7852
# Epoch 4: val_loss improved from 1.34143 to 1.21953, saving model to files/model3.h5
# 35/35 [==============================] - 18s 513ms/step - loss: 0.7987 - dice_coef: 0.3024 - iou: 0.1786 - recall_2: 0.8662 - precision_2: 0.7852 - val_loss: 1.2195 - val_dice_coef: 0.0309 - val_iou: 0.0157 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 5/50
# 35/35 [==============================] - ETA: 0s - loss: 0.7535 - dice_coef: 0.3358 - iou: 0.2023 - recall_2: 0.8841 - precision_2: 0.8022
# Epoch 5: val_loss improved from 1.21953 to 1.15069, saving model to files/model3.h5
# 35/35 [==============================] - 18s 513ms/step - loss: 0.7535 - dice_coef: 0.3358 - iou: 0.2023 - recall_2: 0.8841 - precision_2: 0.8022 - val_loss: 1.1507 - val_dice_coef: 0.0335 - val_iou: 0.0171 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 6/50
# 35/35 [==============================] - ETA: 0s - loss: 0.7196 - dice_coef: 0.3604 - iou: 0.2203 - recall_2: 0.8842 - precision_2: 0.8156
# Epoch 6: val_loss improved from 1.15069 to 1.11069, saving model to files/model3.h5
# 35/35 [==============================] - 18s 514ms/step - loss: 0.7196 - dice_coef: 0.3604 - iou: 0.2203 - recall_2: 0.8842 - precision_2: 0.8156 - val_loss: 1.1107 - val_dice_coef: 0.0334 - val_iou: 0.0170 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 7/50
# 35/35 [==============================] - ETA: 0s - loss: 0.6777 - dice_coef: 0.3921 - iou: 0.2445 - recall_2: 0.9047 - precision_2: 0.8484
# Epoch 7: val_loss improved from 1.11069 to 1.09370, saving model to files/model3.h5
# 35/35 [==============================] - 18s 516ms/step - loss: 0.6777 - dice_coef: 0.3921 - iou: 0.2445 - recall_2: 0.9047 - precision_2: 0.8484 - val_loss: 1.0937 - val_dice_coef: 0.0320 - val_iou: 0.0163 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 8/50
# 35/35 [==============================] - ETA: 0s - loss: 0.6352 - dice_coef: 0.4252 - iou: 0.2706 - recall_2: 0.9263 - precision_2: 0.8715
# Epoch 8: val_loss improved from 1.09370 to 1.07650, saving model to files/model3.h5
# 35/35 [==============================] - 18s 514ms/step - loss: 0.6352 - dice_coef: 0.4252 - iou: 0.2706 - recall_2: 0.9263 - precision_2: 0.8715 - val_loss: 1.0765 - val_dice_coef: 0.0300 - val_iou: 0.0152 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 9/50
# 35/35 [==============================] - ETA: 0s - loss: 0.5995 - dice_coef: 0.4547 - iou: 0.2950 - recall_2: 0.9392 - precision_2: 0.8853
# Epoch 9: val_loss improved from 1.07650 to 1.06951, saving model to files/model3.h5
# 35/35 [==============================] - 18s 521ms/step - loss: 0.5995 - dice_coef: 0.4547 - iou: 0.2950 - recall_2: 0.9392 - precision_2: 0.8853 - val_loss: 1.0695 - val_dice_coef: 0.0292 - val_iou: 0.0148 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 10/50
# 35/35 [==============================] - ETA: 0s - loss: 0.5675 - dice_coef: 0.4810 - iou: 0.3175 - recall_2: 0.9390 - precision_2: 0.8943
# Epoch 10: val_loss improved from 1.06951 to 1.06744, saving model to files/model3.h5
# 35/35 [==============================] - 18s 509ms/step - loss: 0.5675 - dice_coef: 0.4810 - iou: 0.3175 - recall_2: 0.9390 - precision_2: 0.8943 - val_loss: 1.0674 - val_dice_coef: 0.0268 - val_iou: 0.0136 - val_recall_2: 6.1655e-05 - val_precision_2: 1.0000 - lr: 1.0000e-04
# Epoch 11/50
# 35/35 [==============================] - ETA: 0s - loss: 0.5347 - dice_coef: 0.5084 - iou: 0.3420 - recall_2: 0.9458 - precision_2: 0.9049
# Epoch 11: val_loss improved from 1.06744 to 1.03582, saving model to files/model3.h5
# 35/35 [==============================] - 18s 523ms/step - loss: 0.5347 - dice_coef: 0.5084 - iou: 0.3420 - recall_2: 0.9458 - precision_2: 0.9049 - val_loss: 1.0358 - val_dice_coef: 0.0535 - val_iou: 0.0275 - val_recall_2: 0.0635 - val_precision_2: 0.9959 - lr: 1.0000e-04
# Epoch 12/50
# 35/35 [==============================] - ETA: 0s - loss: 0.5034 - dice_coef: 0.5355 - iou: 0.3669 - recall_2: 0.9513 - precision_2: 0.9132
# Epoch 12: val_loss improved from 1.03582 to 0.98140, saving model to files/model3.h5
# 35/35 [==============================] - 18s 510ms/step - loss: 0.5034 - dice_coef: 0.5355 - iou: 0.3669 - recall_2: 0.9513 - precision_2: 0.9132 - val_loss: 0.9814 - val_dice_coef: 0.0986 - val_iou: 0.0523 - val_recall_2: 0.1509 - val_precision_2: 0.9944 - lr: 1.0000e-04
# Epoch 13/50
# 35/35 [==============================] - ETA: 0s - loss: 0.4823 - dice_coef: 0.5545 - iou: 0.3848 - recall_2: 0.9418 - precision_2: 0.9118
# Epoch 13: val_loss improved from 0.98140 to 0.80727, saving model to files/model3.h5
# 35/35 [==============================] - 18s 518ms/step - loss: 0.4823 - dice_coef: 0.5545 - iou: 0.3848 - recall_2: 0.9418 - precision_2: 0.9118 - val_loss: 0.8073 - val_dice_coef: 0.2698 - val_iou: 0.1563 - val_recall_2: 0.5134 - val_precision_2: 0.7012 - lr: 1.0000e-04
# Epoch 14/50
# 35/35 [==============================] - ETA: 0s - loss: 0.4643 - dice_coef: 0.5714 - iou: 0.4012 - recall_2: 0.9365 - precision_2: 0.8996
# Epoch 14: val_loss improved from 0.80727 to 0.73464, saving model to files/model3.h5
# 35/35 [==============================] - 18s 525ms/step - loss: 0.4643 - dice_coef: 0.5714 - iou: 0.4012 - recall_2: 0.9365 - precision_2: 0.8996 - val_loss: 0.7346 - val_dice_coef: 0.3418 - val_iou: 0.2082 - val_recall_2: 0.6725 - val_precision_2: 0.7071 - lr: 1.0000e-04
# Epoch 15/50
# 35/35 [==============================] - ETA: 0s - loss: 0.4402 - dice_coef: 0.5926 - iou: 0.4220 - recall_2: 0.9347 - precision_2: 0.9056
# Epoch 15: val_loss improved from 0.73464 to 0.67096, saving model to files/model3.h5
# 35/35 [==============================] - 18s 521ms/step - loss: 0.4402 - dice_coef: 0.5926 - iou: 0.4220 - recall_2: 0.9347 - precision_2: 0.9056 - val_loss: 0.6710 - val_dice_coef: 0.4200 - val_iou: 0.2684 - val_recall_2: 0.8837 - val_precision_2: 0.6785 - lr: 1.0000e-04
# Epoch 16/50
# 35/35 [==============================] - ETA: 0s - loss: 0.4078 - dice_coef: 0.6213 - iou: 0.4520 - recall_2: 0.9471 - precision_2: 0.9222
# Epoch 16: val_loss improved from 0.67096 to 0.62258, saving model to files/model3.h5
# 35/35 [==============================] - 18s 524ms/step - loss: 0.4078 - dice_coef: 0.6213 - iou: 0.4520 - recall_2: 0.9471 - precision_2: 0.9222 - val_loss: 0.6226 - val_dice_coef: 0.4587 - val_iou: 0.3011 - val_recall_2: 0.8955 - val_precision_2: 0.6879 - lr: 1.0000e-04
# Epoch 17/50
# 35/35 [==============================] - ETA: 0s - loss: 0.3785 - dice_coef: 0.6470 - iou: 0.4797 - recall_2: 0.9501 - precision_2: 0.9373
# Epoch 17: val_loss improved from 0.62258 to 0.60215, saving model to files/model3.h5
# 35/35 [==============================] - 18s 514ms/step - loss: 0.3785 - dice_coef: 0.6470 - iou: 0.4797 - recall_2: 0.9501 - precision_2: 0.9373 - val_loss: 0.6022 - val_dice_coef: 0.4752 - val_iou: 0.3144 - val_recall_2: 0.8614 - val_precision_2: 0.7032 - lr: 1.0000e-04
# Epoch 18/50
# 35/35 [==============================] - ETA: 0s - loss: 0.3509 - dice_coef: 0.6715 - iou: 0.5068 - recall_2: 0.9578 - precision_2: 0.9471
# Epoch 18: val_loss improved from 0.60215 to 0.57217, saving model to files/model3.h5
# 35/35 [==============================] - 18s 516ms/step - loss: 0.3509 - dice_coef: 0.6715 - iou: 0.5068 - recall_2: 0.9578 - precision_2: 0.9471 - val_loss: 0.5722 - val_dice_coef: 0.5089 - val_iou: 0.3454 - val_recall_2: 0.8885 - val_precision_2: 0.6992 - lr: 1.0000e-04
# Epoch 19/50
# 35/35 [==============================] - ETA: 0s - loss: 0.3322 - dice_coef: 0.6890 - iou: 0.5268 - recall_2: 0.9544 - precision_2: 0.9489
# Epoch 19: val_loss improved from 0.57217 to 0.54812, saving model to files/model3.h5
# 35/35 [==============================] - 18s 515ms/step - loss: 0.3322 - dice_coef: 0.6890 - iou: 0.5268 - recall_2: 0.9544 - precision_2: 0.9489 - val_loss: 0.5481 - val_dice_coef: 0.5321 - val_iou: 0.3654 - val_recall_2: 0.8886 - val_precision_2: 0.6953 - lr: 1.0000e-04
# Epoch 20/50
# 35/35 [==============================] - ETA: 0s - loss: 0.3158 - dice_coef: 0.7045 - iou: 0.5452 - recall_2: 0.9543 - precision_2: 0.9460
# Epoch 20: val_loss improved from 0.54812 to 0.52655, saving model to files/model3.h5
# 35/35 [==============================] - 18s 523ms/step - loss: 0.3158 - dice_coef: 0.7045 - iou: 0.5452 - recall_2: 0.9543 - precision_2: 0.9460 - val_loss: 0.5265 - val_dice_coef: 0.5437 - val_iou: 0.3778 - val_recall_2: 0.8615 - val_precision_2: 0.7233 - lr: 1.0000e-04
# Epoch 21/50
# 35/35 [==============================] - ETA: 0s - loss: 0.2956 - dice_coef: 0.7227 - iou: 0.5670 - recall_2: 0.9556 - precision_2: 0.9532
# Epoch 21: val_loss improved from 0.52655 to 0.51804, saving model to files/model3.h5
# 35/35 [==============================] - 18s 516ms/step - loss: 0.2956 - dice_coef: 0.7227 - iou: 0.5670 - recall_2: 0.9556 - precision_2: 0.9532 - val_loss: 0.5180 - val_dice_coef: 0.5577 - val_iou: 0.3912 - val_recall_2: 0.8783 - val_precision_2: 0.6916 - lr: 1.0000e-04
# Epoch 22/50
# 35/35 [==============================] - ETA: 0s - loss: 0.2852 - dice_coef: 0.7332 - iou: 0.5801 - recall_2: 0.9500 - precision_2: 0.9479
# Epoch 22: val_loss improved from 0.51804 to 0.49877, saving model to files/model3.h5
# 35/35 [==============================] - 18s 519ms/step - loss: 0.2852 - dice_coef: 0.7332 - iou: 0.5801 - recall_2: 0.9500 - precision_2: 0.9479 - val_loss: 0.4988 - val_dice_coef: 0.5674 - val_iou: 0.3997 - val_recall_2: 0.8471 - val_precision_2: 0.7012 - lr: 1.0000e-04
# Epoch 23/50
# 35/35 [==============================] - ETA: 0s - loss: 0.2683 - dice_coef: 0.7486 - iou: 0.5992 - recall_2: 0.9527 - precision_2: 0.9513
# Epoch 23: val_loss improved from 0.49877 to 0.45937, saving model to files/model3.h5
# 35/35 [==============================] - 18s 510ms/step - loss: 0.2683 - dice_coef: 0.7486 - iou: 0.5992 - recall_2: 0.9527 - precision_2: 0.9513 - val_loss: 0.4594 - val_dice_coef: 0.6023 - val_iou: 0.4355 - val_recall_2: 0.8832 - val_precision_2: 0.7370 - lr: 1.0000e-04
# Epoch 24/50
# 35/35 [==============================] - ETA: 0s - loss: 0.2491 - dice_coef: 0.7660 - iou: 0.6218 - recall_2: 0.9570 - precision_2: 0.9605
# Epoch 24: val_loss did not improve from 0.45937
# 35/35 [==============================] - 16s 451ms/step - loss: 0.2491 - dice_coef: 0.7660 - iou: 0.6218 - recall_2: 0.9570 - precision_2: 0.9605 - val_loss: 0.4765 - val_dice_coef: 0.5912 - val_iou: 0.4231 - val_recall_2: 0.8439 - val_precision_2: 0.7098 - lr: 1.0000e-04
# Epoch 25/50
# 35/35 [==============================] - ETA: 0s - loss: 0.2352 - dice_coef: 0.7791 - iou: 0.6392 - recall_2: 0.9585 - precision_2: 0.9614
# Epoch 25: val_loss improved from 0.45937 to 0.45157, saving model to files/model3.h5
# 35/35 [==============================] - 19s 530ms/step - loss: 0.2352 - dice_coef: 0.7791 - iou: 0.6392 - recall_2: 0.9585 - precision_2: 0.9614 - val_loss: 0.4516 - val_dice_coef: 0.6092 - val_iou: 0.4416 - val_recall_2: 0.8277 - val_precision_2: 0.7410 - lr: 1.0000e-04
# Epoch 26/50
# 35/35 [==============================] - ETA: 0s - loss: 0.2252 - dice_coef: 0.7887 - iou: 0.6522 - recall_2: 0.9534 - precision_2: 0.9626
# Epoch 26: val_loss did not improve from 0.45157
# 35/35 [==============================] - 16s 450ms/step - loss: 0.2252 - dice_coef: 0.7887 - iou: 0.6522 - recall_2: 0.9534 - precision_2: 0.9626 - val_loss: 0.4576 - val_dice_coef: 0.6122 - val_iou: 0.4465 - val_recall_2: 0.8476 - val_precision_2: 0.7103 - lr: 1.0000e-04
# Epoch 27/50
# 35/35 [==============================] - ETA: 0s - loss: 0.2156 - dice_coef: 0.7979 - iou: 0.6647 - recall_2: 0.9516 - precision_2: 0.9623
# Epoch 27: val_loss improved from 0.45157 to 0.44938, saving model to files/model3.h5
# 35/35 [==============================] - 18s 528ms/step - loss: 0.2156 - dice_coef: 0.7979 - iou: 0.6647 - recall_2: 0.9516 - precision_2: 0.9623 - val_loss: 0.4494 - val_dice_coef: 0.6183 - val_iou: 0.4512 - val_recall_2: 0.8393 - val_precision_2: 0.7064 - lr: 1.0000e-04
# Epoch 28/50
# 35/35 [==============================] - ETA: 0s - loss: 0.2032 - dice_coef: 0.8094 - iou: 0.6808 - recall_2: 0.9570 - precision_2: 0.9618
# Epoch 28: val_loss improved from 0.44938 to 0.44431, saving model to files/model3.h5
# 35/35 [==============================] - 18s 517ms/step - loss: 0.2032 - dice_coef: 0.8094 - iou: 0.6808 - recall_2: 0.9570 - precision_2: 0.9618 - val_loss: 0.4443 - val_dice_coef: 0.6286 - val_iou: 0.4642 - val_recall_2: 0.8546 - val_precision_2: 0.7026 - lr: 1.0000e-04
# Epoch 29/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1956 - dice_coef: 0.8168 - iou: 0.6911 - recall_2: 0.9517 - precision_2: 0.9628
# Epoch 29: val_loss improved from 0.44431 to 0.43948, saving model to files/model3.h5
# 35/35 [==============================] - 18s 518ms/step - loss: 0.1956 - dice_coef: 0.8168 - iou: 0.6911 - recall_2: 0.9517 - precision_2: 0.9628 - val_loss: 0.4395 - val_dice_coef: 0.6273 - val_iou: 0.4653 - val_recall_2: 0.8218 - val_precision_2: 0.7141 - lr: 1.0000e-04
# Epoch 30/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1918 - dice_coef: 0.8210 - iou: 0.6972 - recall_2: 0.9466 - precision_2: 0.9607
# Epoch 30: val_loss improved from 0.43948 to 0.41398, saving model to files/model3.h5
# 35/35 [==============================] - 18s 517ms/step - loss: 0.1918 - dice_coef: 0.8210 - iou: 0.6972 - recall_2: 0.9466 - precision_2: 0.9607 - val_loss: 0.4140 - val_dice_coef: 0.6559 - val_iou: 0.4933 - val_recall_2: 0.8651 - val_precision_2: 0.7058 - lr: 1.0000e-04
# Epoch 31/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1776 - dice_coef: 0.8338 - iou: 0.7157 - recall_2: 0.9525 - precision_2: 0.9653
# Epoch 31: val_loss improved from 0.41398 to 0.40820, saving model to files/model3.h5
# 35/35 [==============================] - 18s 520ms/step - loss: 0.1776 - dice_coef: 0.8338 - iou: 0.7157 - recall_2: 0.9525 - precision_2: 0.9653 - val_loss: 0.4082 - val_dice_coef: 0.6609 - val_iou: 0.4995 - val_recall_2: 0.8593 - val_precision_2: 0.7065 - lr: 1.0000e-04
# Epoch 32/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1636 - dice_coef: 0.8462 - iou: 0.7341 - recall_2: 0.9576 - precision_2: 0.9724
# Epoch 32: val_loss improved from 0.40820 to 0.40312, saving model to files/model3.h5
# 35/35 [==============================] - 18s 512ms/step - loss: 0.1636 - dice_coef: 0.8462 - iou: 0.7341 - recall_2: 0.9576 - precision_2: 0.9724 - val_loss: 0.4031 - val_dice_coef: 0.6677 - val_iou: 0.5107 - val_recall_2: 0.8788 - val_precision_2: 0.7014 - lr: 1.0000e-04
# Epoch 33/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1531 - dice_coef: 0.8559 - iou: 0.7488 - recall_2: 0.9616 - precision_2: 0.9762
# Epoch 33: val_loss improved from 0.40312 to 0.39867, saving model to files/model3.h5
# 35/35 [==============================] - 18s 514ms/step - loss: 0.1531 - dice_coef: 0.8559 - iou: 0.7488 - recall_2: 0.9616 - precision_2: 0.9762 - val_loss: 0.3987 - val_dice_coef: 0.6743 - val_iou: 0.5146 - val_recall_2: 0.8711 - val_precision_2: 0.7095 - lr: 1.0000e-04
# Epoch 34/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1488 - dice_coef: 0.8603 - iou: 0.7554 - recall_2: 0.9547 - precision_2: 0.9777
# Epoch 34: val_loss did not improve from 0.39867
# 35/35 [==============================] - 16s 451ms/step - loss: 0.1488 - dice_coef: 0.8603 - iou: 0.7554 - recall_2: 0.9547 - precision_2: 0.9777 - val_loss: 0.4039 - val_dice_coef: 0.6678 - val_iou: 0.5094 - val_recall_2: 0.8574 - val_precision_2: 0.6974 - lr: 1.0000e-04
# Epoch 35/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1407 - dice_coef: 0.8679 - iou: 0.7672 - recall_2: 0.9570 - precision_2: 0.9786
# Epoch 35: val_loss improved from 0.39867 to 0.37680, saving model to files/model3.h5
# 35/35 [==============================] - 18s 522ms/step - loss: 0.1407 - dice_coef: 0.8679 - iou: 0.7672 - recall_2: 0.9570 - precision_2: 0.9786 - val_loss: 0.3768 - val_dice_coef: 0.6917 - val_iou: 0.5343 - val_recall_2: 0.8766 - val_precision_2: 0.7139 - lr: 1.0000e-04
# Epoch 36/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1343 - dice_coef: 0.8739 - iou: 0.7765 - recall_2: 0.9582 - precision_2: 0.9782
# Epoch 36: val_loss did not improve from 0.37680
# 35/35 [==============================] - 16s 451ms/step - loss: 0.1343 - dice_coef: 0.8739 - iou: 0.7765 - recall_2: 0.9582 - precision_2: 0.9782 - val_loss: 0.4009 - val_dice_coef: 0.6677 - val_iou: 0.5096 - val_recall_2: 0.8309 - val_precision_2: 0.7059 - lr: 1.0000e-04
# Epoch 37/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1295 - dice_coef: 0.8786 - iou: 0.7839 - recall_2: 0.9593 - precision_2: 0.9767
# Epoch 37: val_loss improved from 0.37680 to 0.34916, saving model to files/model3.h5
# 35/35 [==============================] - 18s 527ms/step - loss: 0.1295 - dice_coef: 0.8786 - iou: 0.7839 - recall_2: 0.9593 - precision_2: 0.9767 - val_loss: 0.3492 - val_dice_coef: 0.7136 - val_iou: 0.5621 - val_recall_2: 0.8899 - val_precision_2: 0.7284 - lr: 1.0000e-04
# Epoch 38/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1222 - dice_coef: 0.8853 - iou: 0.7947 - recall_2: 0.9605 - precision_2: 0.9805
# Epoch 38: val_loss improved from 0.34916 to 0.34765, saving model to files/model3.h5
# 35/35 [==============================] - 17s 479ms/step - loss: 0.1222 - dice_coef: 0.8853 - iou: 0.7947 - recall_2: 0.9605 - precision_2: 0.9805 - val_loss: 0.3476 - val_dice_coef: 0.7073 - val_iou: 0.5517 - val_recall_2: 0.8253 - val_precision_2: 0.7592 - lr: 1.0000e-04
# Epoch 39/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1160 - dice_coef: 0.8911 - iou: 0.8039 - recall_2: 0.9597 - precision_2: 0.9822
# Epoch 39: val_loss did not improve from 0.34765
# 35/35 [==============================] - 16s 451ms/step - loss: 0.1160 - dice_coef: 0.8911 - iou: 0.8039 - recall_2: 0.9597 - precision_2: 0.9822 - val_loss: 0.3676 - val_dice_coef: 0.6836 - val_iou: 0.5267 - val_recall_2: 0.7474 - val_precision_2: 0.7838 - lr: 1.0000e-04
# Epoch 40/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1161 - dice_coef: 0.8917 - iou: 0.8050 - recall_2: 0.9597 - precision_2: 0.9770
# Epoch 40: val_loss improved from 0.34765 to 0.33965, saving model to files/model3.h5
# 35/35 [==============================] - 18s 528ms/step - loss: 0.1161 - dice_coef: 0.8917 - iou: 0.8050 - recall_2: 0.9597 - precision_2: 0.9770 - val_loss: 0.3396 - val_dice_coef: 0.7081 - val_iou: 0.5524 - val_recall_2: 0.7711 - val_precision_2: 0.7976 - lr: 1.0000e-04
# Epoch 41/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1138 - dice_coef: 0.8939 - iou: 0.8086 - recall_2: 0.9580 - precision_2: 0.9758
# Epoch 41: val_loss did not improve from 0.33965
# 35/35 [==============================] - 16s 451ms/step - loss: 0.1138 - dice_coef: 0.8939 - iou: 0.8086 - recall_2: 0.9580 - precision_2: 0.9758 - val_loss: 0.3510 - val_dice_coef: 0.7160 - val_iou: 0.5630 - val_recall_2: 0.8492 - val_precision_2: 0.7275 - lr: 1.0000e-04
# Epoch 42/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1143 - dice_coef: 0.8939 - iou: 0.8085 - recall_2: 0.9497 - precision_2: 0.9757
# Epoch 42: val_loss did not improve from 0.33965
# 35/35 [==============================] - 16s 451ms/step - loss: 0.1143 - dice_coef: 0.8939 - iou: 0.8085 - recall_2: 0.9497 - precision_2: 0.9757 - val_loss: 0.3474 - val_dice_coef: 0.7141 - val_iou: 0.5606 - val_recall_2: 0.8410 - val_precision_2: 0.7302 - lr: 1.0000e-04
# Epoch 43/50
# 35/35 [==============================] - ETA: 0s - loss: 0.1067 - dice_coef: 0.9007 - iou: 0.8197 - recall_2: 0.9570 - precision_2: 0.9763
# Epoch 43: val_loss did not improve from 0.33965
# 35/35 [==============================] - 16s 451ms/step - loss: 0.1067 - dice_coef: 0.9007 - iou: 0.8197 - recall_2: 0.9570 - precision_2: 0.9763 - val_loss: 0.3429 - val_dice_coef: 0.7194 - val_iou: 0.5664 - val_recall_2: 0.8187 - val_precision_2: 0.7470 - lr: 1.0000e-04
# Epoch 44/50
# 35/35 [==============================] - ETA: 0s - loss: 0.0992 - dice_coef: 0.9074 - iou: 0.8308 - recall_2: 0.9586 - precision_2: 0.9813
# Epoch 44: val_loss did not improve from 0.33965
# 35/35 [==============================] - 16s 451ms/step - loss: 0.0992 - dice_coef: 0.9074 - iou: 0.8308 - recall_2: 0.9586 - precision_2: 0.9813 - val_loss: 0.3518 - val_dice_coef: 0.7063 - val_iou: 0.5515 - val_recall_2: 0.7857 - val_precision_2: 0.7497 - lr: 1.0000e-04
# Epoch 45/50
# 35/35 [==============================] - ETA: 0s - loss: 0.0929 - dice_coef: 0.9130 - iou: 0.8401 - recall_2: 0.9613 - precision_2: 0.9843
# Epoch 45: val_loss improved from 0.33965 to 0.33952, saving model to files/model3.h5
# 35/35 [==============================] - 18s 523ms/step - loss: 0.0929 - dice_coef: 0.9130 - iou: 0.8401 - recall_2: 0.9613 - precision_2: 0.9843 - val_loss: 0.3395 - val_dice_coef: 0.7202 - val_iou: 0.5673 - val_recall_2: 0.8216 - val_precision_2: 0.7429 - lr: 1.0000e-04
# Epoch 46/50
# 35/35 [==============================] - ETA: 0s - loss: 0.0887 - dice_coef: 0.9169 - iou: 0.8468 - recall_2: 0.9625 - precision_2: 0.9857
# Epoch 46: val_loss improved from 0.33952 to 0.32176, saving model to files/model3.h5
# 35/35 [==============================] - 18s 520ms/step - loss: 0.0887 - dice_coef: 0.9169 - iou: 0.8468 - recall_2: 0.9625 - precision_2: 0.9857 - val_loss: 0.3218 - val_dice_coef: 0.7341 - val_iou: 0.5842 - val_recall_2: 0.8339 - val_precision_2: 0.7543 - lr: 1.0000e-04
# Epoch 47/50
# 35/35 [==============================] - ETA: 0s - loss: 0.0850 - dice_coef: 0.9203 - iou: 0.8527 - recall_2: 0.9646 - precision_2: 0.9864
# Epoch 47: val_loss did not improve from 0.32176
# 35/35 [==============================] - 16s 450ms/step - loss: 0.0850 - dice_coef: 0.9203 - iou: 0.8527 - recall_2: 0.9646 - precision_2: 0.9864 - val_loss: 0.3281 - val_dice_coef: 0.7329 - val_iou: 0.5833 - val_recall_2: 0.8335 - val_precision_2: 0.7497 - lr: 1.0000e-04
# Epoch 48/50
# 35/35 [==============================] - ETA: 0s - loss: 0.0821 - dice_coef: 0.9232 - iou: 0.8575 - recall_2: 0.9627 - precision_2: 0.9870
# Epoch 48: val_loss did not improve from 0.32176
# 35/35 [==============================] - 16s 451ms/step - loss: 0.0821 - dice_coef: 0.9232 - iou: 0.8575 - recall_2: 0.9627 - precision_2: 0.9870 - val_loss: 0.3347 - val_dice_coef: 0.7314 - val_iou: 0.5838 - val_recall_2: 0.8573 - val_precision_2: 0.7237 - lr: 1.0000e-04
# Epoch 49/50
# 35/35 [==============================] - ETA: 0s - loss: 0.0803 - dice_coef: 0.9249 - iou: 0.8606 - recall_2: 0.9605 - precision_2: 0.9874
# Epoch 49: val_loss did not improve from 0.32176
# 35/35 [==============================] - 16s 451ms/step - loss: 0.0803 - dice_coef: 0.9249 - iou: 0.8606 - recall_2: 0.9605 - precision_2: 0.9874 - val_loss: 0.3339 - val_dice_coef: 0.7332 - val_iou: 0.5866 - val_recall_2: 0.8627 - val_precision_2: 0.7190 - lr: 1.0000e-04
# Epoch 50/50
# 35/35 [==============================] - ETA: 0s - loss: 0.0767 - dice_coef: 0.9282 - iou: 0.8663 - recall_2: 0.9622 - precision_2: 0.9883
# Epoch 50: val_loss did not improve from 0.32176
# 35/35 [==============================] - 16s 451ms/step - loss: 0.0767 - dice_coef: 0.9282 - iou: 0.8663 - recall_2: 0.9622 - precision_2: 0.9883 - val_loss: 0.3271 - val_dice_coef: 0.7339 - val_iou: 0.5849 - val_recall_2: 0.8260 - val_precision_2: 0.7469 - lr: 1.0000e-04

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 2
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model4.h5")
csv_path = os.path.join("files", "data4.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model4 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 1024], strides=[2, 2, 2, 4])

model4.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model4.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 140 - 140
# Valid: 20 - 20
# Epoch 1/50
# 70/70 [==============================] - ETA: 0s - loss: 1.1593 - dice_coef: 0.1320 - iou: 0.0717 - recall_3: 0.6491 - precision_3: 0.2455
# Epoch 1: val_loss improved from inf to 1.67885, saving model to files/model4.h5
# 70/70 [==============================] - 24s 270ms/step - loss: 1.1593 - dice_coef: 0.1320 - iou: 0.0717 - recall_3: 0.6491 - precision_3: 0.2455 - val_loss: 1.6789 - val_dice_coef: 0.0315 - val_iou: 0.0160 - val_recall_3: 0.9085 - val_precision_3: 0.0239 - lr: 1.0000e-04
# Epoch 2/50
# 70/70 [==============================] - ETA: 0s - loss: 0.9021 - dice_coef: 0.2401 - iou: 0.1374 - recall_3: 0.7638 - precision_3: 0.6250
# Epoch 2: val_loss improved from 1.67885 to 1.21740, saving model to files/model4.h5
# 70/70 [==============================] - 21s 305ms/step - loss: 0.9021 - dice_coef: 0.2401 - iou: 0.1374 - recall_3: 0.7638 - precision_3: 0.6250 - val_loss: 1.2174 - val_dice_coef: 0.0313 - val_iou: 0.0159 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00 - lr: 1.0000e-04
# Epoch 3/50
# 70/70 [==============================] - ETA: 0s - loss: 0.7879 - dice_coef: 0.3118 - iou: 0.1860 - recall_3: 0.8201 - precision_3: 0.7436
# Epoch 3: val_loss improved from 1.21740 to 1.11647, saving model to files/model4.h5
# 70/70 [==============================] - 20s 285ms/step - loss: 0.7879 - dice_coef: 0.3118 - iou: 0.1860 - recall_3: 0.8201 - precision_3: 0.7436 - val_loss: 1.1165 - val_dice_coef: 0.0317 - val_iou: 0.0161 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00 - lr: 1.0000e-04
# Epoch 4/50
# 70/70 [==============================] - ETA: 0s - loss: 0.7014 - dice_coef: 0.3758 - iou: 0.2327 - recall_3: 0.8638 - precision_3: 0.7938
# Epoch 4: val_loss improved from 1.11647 to 1.08076, saving model to files/model4.h5
# 70/70 [==============================] - 21s 284ms/step - loss: 0.7014 - dice_coef: 0.3758 - iou: 0.2327 - recall_3: 0.8638 - precision_3: 0.7938 - val_loss: 1.0808 - val_dice_coef: 0.0292 - val_iou: 0.0148 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00 - lr: 1.0000e-04
# Epoch 5/50
# 70/70 [==============================] - ETA: 0s - loss: 0.6338 - dice_coef: 0.4306 - iou: 0.2759 - recall_3: 0.8865 - precision_3: 0.8141
# Epoch 5: val_loss improved from 1.08076 to 1.06093, saving model to files/model4.h5
# 70/70 [==============================] - 20s 283ms/step - loss: 0.6338 - dice_coef: 0.4306 - iou: 0.2759 - recall_3: 0.8865 - precision_3: 0.8141 - val_loss: 1.0609 - val_dice_coef: 0.0285 - val_iou: 0.0145 - val_recall_3: 6.2888e-04 - val_precision_3: 1.0000 - lr: 1.0000e-04
# Epoch 6/50
# 70/70 [==============================] - ETA: 0s - loss: 0.5687 - dice_coef: 0.4831 - iou: 0.3203 - recall_3: 0.8983 - precision_3: 0.8422
# Epoch 6: val_loss did not improve from 1.06093
# 70/70 [==============================] - 17s 247ms/step - loss: 0.5687 - dice_coef: 0.4831 - iou: 0.3203 - recall_3: 0.8983 - precision_3: 0.8422 - val_loss: 1.0625 - val_dice_coef: 0.0227 - val_iou: 0.0115 - val_recall_3: 1.2331e-04 - val_precision_3: 1.0000 - lr: 1.0000e-04
# Epoch 7/50
# 70/70 [==============================] - ETA: 0s - loss: 0.5077 - dice_coef: 0.5346 - iou: 0.3666 - recall_3: 0.9105 - precision_3: 0.8701
# Epoch 7: val_loss improved from 1.06093 to 0.98906, saving model to files/model4.h5
# 70/70 [==============================] - 20s 290ms/step - loss: 0.5077 - dice_coef: 0.5346 - iou: 0.3666 - recall_3: 0.9105 - precision_3: 0.8701 - val_loss: 0.9891 - val_dice_coef: 0.0850 - val_iou: 0.0456 - val_recall_3: 0.1051 - val_precision_3: 0.9981 - lr: 1.0000e-04
# Epoch 8/50
# 70/70 [==============================] - ETA: 0s - loss: 0.4562 - dice_coef: 0.5805 - iou: 0.4110 - recall_3: 0.9193 - precision_3: 0.8833
# Epoch 8: val_loss improved from 0.98906 to 0.76987, saving model to files/model4.h5
# 70/70 [==============================] - 20s 284ms/step - loss: 0.4562 - dice_coef: 0.5805 - iou: 0.4110 - recall_3: 0.9193 - precision_3: 0.8833 - val_loss: 0.7699 - val_dice_coef: 0.2875 - val_iou: 0.1754 - val_recall_3: 0.4482 - val_precision_3: 0.7930 - lr: 1.0000e-04
# Epoch 9/50
# 70/70 [==============================] - ETA: 0s - loss: 0.4305 - dice_coef: 0.6064 - iou: 0.4377 - recall_3: 0.9060 - precision_3: 0.8637
# Epoch 9: val_loss improved from 0.76987 to 0.71757, saving model to files/model4.h5
# 70/70 [==============================] - 20s 285ms/step - loss: 0.4305 - dice_coef: 0.6064 - iou: 0.4377 - recall_3: 0.9060 - precision_3: 0.8637 - val_loss: 0.7176 - val_dice_coef: 0.3402 - val_iou: 0.2146 - val_recall_3: 0.5040 - val_precision_3: 0.7901 - lr: 1.0000e-04
# Epoch 10/50
# 70/70 [==============================] - ETA: 0s - loss: 0.3788 - dice_coef: 0.6505 - iou: 0.4845 - recall_3: 0.9133 - precision_3: 0.8910
# Epoch 10: val_loss improved from 0.71757 to 0.59037, saving model to files/model4.h5
# 70/70 [==============================] - 20s 291ms/step - loss: 0.3788 - dice_coef: 0.6505 - iou: 0.4845 - recall_3: 0.9133 - precision_3: 0.8910 - val_loss: 0.5904 - val_dice_coef: 0.4692 - val_iou: 0.3216 - val_recall_3: 0.7446 - val_precision_3: 0.7262 - lr: 1.0000e-04
# Epoch 11/50
# 70/70 [==============================] - ETA: 0s - loss: 0.3369 - dice_coef: 0.6875 - iou: 0.5262 - recall_3: 0.9153 - precision_3: 0.9117
# Epoch 11: val_loss improved from 0.59037 to 0.52183, saving model to files/model4.h5
# 70/70 [==============================] - 20s 282ms/step - loss: 0.3369 - dice_coef: 0.6875 - iou: 0.5262 - recall_3: 0.9153 - precision_3: 0.9117 - val_loss: 0.5218 - val_dice_coef: 0.5466 - val_iou: 0.3983 - val_recall_3: 0.8548 - val_precision_3: 0.6923 - lr: 1.0000e-04
# Epoch 12/50
# 70/70 [==============================] - ETA: 0s - loss: 0.3010 - dice_coef: 0.7207 - iou: 0.5657 - recall_3: 0.9253 - precision_3: 0.9183
# Epoch 12: val_loss improved from 0.52183 to 0.51834, saving model to files/model4.h5
# 70/70 [==============================] - 21s 294ms/step - loss: 0.3010 - dice_coef: 0.7207 - iou: 0.5657 - recall_3: 0.9253 - precision_3: 0.9183 - val_loss: 0.5183 - val_dice_coef: 0.5366 - val_iou: 0.3920 - val_recall_3: 0.7510 - val_precision_3: 0.7335 - lr: 1.0000e-04
# Epoch 13/50
# 70/70 [==============================] - ETA: 0s - loss: 0.2633 - dice_coef: 0.7546 - iou: 0.6081 - recall_3: 0.9309 - precision_3: 0.9396
# Epoch 13: val_loss improved from 0.51834 to 0.51368, saving model to files/model4.h5
# 70/70 [==============================] - 20s 288ms/step - loss: 0.2633 - dice_coef: 0.7546 - iou: 0.6081 - recall_3: 0.9309 - precision_3: 0.9396 - val_loss: 0.5137 - val_dice_coef: 0.5381 - val_iou: 0.3909 - val_recall_3: 0.6818 - val_precision_3: 0.7484 - lr: 1.0000e-04
# Epoch 14/50
# 70/70 [==============================] - ETA: 0s - loss: 0.2465 - dice_coef: 0.7710 - iou: 0.6297 - recall_3: 0.9284 - precision_3: 0.9294
# Epoch 14: val_loss did not improve from 0.51368
# 70/70 [==============================] - 17s 247ms/step - loss: 0.2465 - dice_coef: 0.7710 - iou: 0.6297 - recall_3: 0.9284 - precision_3: 0.9294 - val_loss: 0.6204 - val_dice_coef: 0.4317 - val_iou: 0.2930 - val_recall_3: 0.4604 - val_precision_3: 0.8063 - lr: 1.0000e-04
# Epoch 15/50
# 70/70 [==============================] - ETA: 0s - loss: 0.2280 - dice_coef: 0.7892 - iou: 0.6543 - recall_3: 0.9203 - precision_3: 0.9326
# Epoch 15: val_loss improved from 0.51368 to 0.49190, saving model to files/model4.h5
# 70/70 [==============================] - 20s 287ms/step - loss: 0.2280 - dice_coef: 0.7892 - iou: 0.6543 - recall_3: 0.9203 - precision_3: 0.9326 - val_loss: 0.4919 - val_dice_coef: 0.5801 - val_iou: 0.4414 - val_recall_3: 0.8164 - val_precision_3: 0.6500 - lr: 1.0000e-04
# Epoch 16/50
# 70/70 [==============================] - ETA: 0s - loss: 0.2049 - dice_coef: 0.8101 - iou: 0.6827 - recall_3: 0.9320 - precision_3: 0.9388
# Epoch 16: val_loss improved from 0.49190 to 0.48054, saving model to files/model4.h5
# 70/70 [==============================] - 21s 296ms/step - loss: 0.2049 - dice_coef: 0.8101 - iou: 0.6827 - recall_3: 0.9320 - precision_3: 0.9388 - val_loss: 0.4805 - val_dice_coef: 0.5724 - val_iou: 0.4289 - val_recall_3: 0.6775 - val_precision_3: 0.7616 - lr: 1.0000e-04
# Epoch 17/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1954 - dice_coef: 0.8200 - iou: 0.6971 - recall_3: 0.9247 - precision_3: 0.9370
# Epoch 17: val_loss improved from 0.48054 to 0.43375, saving model to files/model4.h5
# 70/70 [==============================] - 20s 284ms/step - loss: 0.1954 - dice_coef: 0.8200 - iou: 0.6971 - recall_3: 0.9247 - precision_3: 0.9370 - val_loss: 0.4338 - val_dice_coef: 0.6399 - val_iou: 0.5093 - val_recall_3: 0.8493 - val_precision_3: 0.6820 - lr: 1.0000e-04
# Epoch 18/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1686 - dice_coef: 0.8435 - iou: 0.7305 - recall_3: 0.9345 - precision_3: 0.9531
# Epoch 18: val_loss did not improve from 0.43375
# 70/70 [==============================] - 17s 247ms/step - loss: 0.1686 - dice_coef: 0.8435 - iou: 0.7305 - recall_3: 0.9345 - precision_3: 0.9531 - val_loss: 0.5435 - val_dice_coef: 0.5193 - val_iou: 0.3807 - val_recall_3: 0.5569 - val_precision_3: 0.7327 - lr: 1.0000e-04
# Epoch 19/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1604 - dice_coef: 0.8520 - iou: 0.7438 - recall_3: 0.9317 - precision_3: 0.9511
# Epoch 19: val_loss improved from 0.43375 to 0.39077, saving model to files/model4.h5
# 70/70 [==============================] - 20s 289ms/step - loss: 0.1604 - dice_coef: 0.8520 - iou: 0.7438 - recall_3: 0.9317 - precision_3: 0.9511 - val_loss: 0.3908 - val_dice_coef: 0.6652 - val_iou: 0.5400 - val_recall_3: 0.8218 - val_precision_3: 0.7405 - lr: 1.0000e-04
# Epoch 20/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1400 - dice_coef: 0.8700 - iou: 0.7710 - recall_3: 0.9401 - precision_3: 0.9634
# Epoch 20: val_loss did not improve from 0.39077
# 70/70 [==============================] - 17s 247ms/step - loss: 0.1400 - dice_coef: 0.8700 - iou: 0.7710 - recall_3: 0.9401 - precision_3: 0.9634 - val_loss: 0.4306 - val_dice_coef: 0.6273 - val_iou: 0.4971 - val_recall_3: 0.7205 - val_precision_3: 0.7380 - lr: 1.0000e-04
# Epoch 21/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1295 - dice_coef: 0.8800 - iou: 0.7868 - recall_3: 0.9425 - precision_3: 0.9654
# Epoch 21: val_loss improved from 0.39077 to 0.38954, saving model to files/model4.h5
# 70/70 [==============================] - 20s 288ms/step - loss: 0.1295 - dice_coef: 0.8800 - iou: 0.7868 - recall_3: 0.9425 - precision_3: 0.9654 - val_loss: 0.3895 - val_dice_coef: 0.6734 - val_iou: 0.5532 - val_recall_3: 0.8319 - val_precision_3: 0.7150 - lr: 1.0000e-04
# Epoch 22/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1224 - dice_coef: 0.8867 - iou: 0.7975 - recall_3: 0.9424 - precision_3: 0.9645
# Epoch 22: val_loss improved from 0.38954 to 0.38659, saving model to files/model4.h5
# 70/70 [==============================] - 20s 285ms/step - loss: 0.1224 - dice_coef: 0.8867 - iou: 0.7975 - recall_3: 0.9424 - precision_3: 0.9645 - val_loss: 0.3866 - val_dice_coef: 0.6652 - val_iou: 0.5414 - val_recall_3: 0.7675 - val_precision_3: 0.7516 - lr: 1.0000e-04
# Epoch 23/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1107 - dice_coef: 0.8975 - iou: 0.8147 - recall_3: 0.9448 - precision_3: 0.9709
# Epoch 23: val_loss improved from 0.38659 to 0.36349, saving model to files/model4.h5
# 70/70 [==============================] - 20s 290ms/step - loss: 0.1107 - dice_coef: 0.8975 - iou: 0.8147 - recall_3: 0.9448 - precision_3: 0.9709 - val_loss: 0.3635 - val_dice_coef: 0.6953 - val_iou: 0.5833 - val_recall_3: 0.8361 - val_precision_3: 0.7305 - lr: 1.0000e-04
# Epoch 24/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1056 - dice_coef: 0.9028 - iou: 0.8237 - recall_3: 0.9453 - precision_3: 0.9697
# Epoch 24: val_loss did not improve from 0.36349
# 70/70 [==============================] - 17s 247ms/step - loss: 0.1056 - dice_coef: 0.9028 - iou: 0.8237 - recall_3: 0.9453 - precision_3: 0.9697 - val_loss: 0.4084 - val_dice_coef: 0.6421 - val_iou: 0.5154 - val_recall_3: 0.6905 - val_precision_3: 0.7675 - lr: 1.0000e-04
# Epoch 25/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1107 - dice_coef: 0.8989 - iou: 0.8173 - recall_3: 0.9396 - precision_3: 0.9588
# Epoch 25: val_loss did not improve from 0.36349
# 70/70 [==============================] - 17s 247ms/step - loss: 0.1107 - dice_coef: 0.8989 - iou: 0.8173 - recall_3: 0.9396 - precision_3: 0.9588 - val_loss: 0.4682 - val_dice_coef: 0.5820 - val_iou: 0.4449 - val_recall_3: 0.5762 - val_precision_3: 0.7921 - lr: 1.0000e-04
# Epoch 26/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1335 - dice_coef: 0.8815 - iou: 0.7913 - recall_3: 0.9073 - precision_3: 0.9416
# Epoch 26: val_loss did not improve from 0.36349
# 70/70 [==============================] - 17s 247ms/step - loss: 0.1335 - dice_coef: 0.8815 - iou: 0.7913 - recall_3: 0.9073 - precision_3: 0.9416 - val_loss: 0.4471 - val_dice_coef: 0.6442 - val_iou: 0.5226 - val_recall_3: 0.8373 - val_precision_3: 0.5849 - lr: 1.0000e-04
# Epoch 27/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1143 - dice_coef: 0.8973 - iou: 0.8153 - recall_3: 0.9203 - precision_3: 0.9552
# Epoch 27: val_loss did not improve from 0.36349
# 70/70 [==============================] - 17s 247ms/step - loss: 0.1143 - dice_coef: 0.8973 - iou: 0.8153 - recall_3: 0.9203 - precision_3: 0.9552 - val_loss: 0.4482 - val_dice_coef: 0.6088 - val_iou: 0.4792 - val_recall_3: 0.6285 - val_precision_3: 0.7687 - lr: 1.0000e-04
# Epoch 28/50
# 70/70 [==============================] - ETA: 0s - loss: 0.1020 - dice_coef: 0.9078 - iou: 0.8321 - recall_3: 0.9289 - precision_3: 0.9622
# Epoch 28: val_loss improved from 0.36349 to 0.35031, saving model to files/model4.h5
# 70/70 [==============================] - 20s 290ms/step - loss: 0.1020 - dice_coef: 0.9078 - iou: 0.8321 - recall_3: 0.9289 - precision_3: 0.9622 - val_loss: 0.3503 - val_dice_coef: 0.7010 - val_iou: 0.5761 - val_recall_3: 0.7759 - val_precision_3: 0.7441 - lr: 1.0000e-04
# Epoch 29/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0871 - dice_coef: 0.9207 - iou: 0.8536 - recall_3: 0.9406 - precision_3: 0.9714
# Epoch 29: val_loss improved from 0.35031 to 0.33978, saving model to files/model4.h5
# 70/70 [==============================] - 20s 291ms/step - loss: 0.0871 - dice_coef: 0.9207 - iou: 0.8536 - recall_3: 0.9406 - precision_3: 0.9714 - val_loss: 0.3398 - val_dice_coef: 0.7128 - val_iou: 0.6058 - val_recall_3: 0.8202 - val_precision_3: 0.7495 - lr: 1.0000e-04
# Epoch 30/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0786 - dice_coef: 0.9281 - iou: 0.8663 - recall_3: 0.9457 - precision_3: 0.9761
# Epoch 30: val_loss did not improve from 0.33978
# 70/70 [==============================] - 18s 249ms/step - loss: 0.0786 - dice_coef: 0.9281 - iou: 0.8663 - recall_3: 0.9457 - precision_3: 0.9761 - val_loss: 0.3425 - val_dice_coef: 0.7117 - val_iou: 0.6023 - val_recall_3: 0.8098 - val_precision_3: 0.7513 - lr: 1.0000e-04
# Epoch 31/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0750 - dice_coef: 0.9315 - iou: 0.8722 - recall_3: 0.9496 - precision_3: 0.9759
# Epoch 31: val_loss did not improve from 0.33978
# 70/70 [==============================] - 17s 249ms/step - loss: 0.0750 - dice_coef: 0.9315 - iou: 0.8722 - recall_3: 0.9496 - precision_3: 0.9759 - val_loss: 0.3515 - val_dice_coef: 0.7030 - val_iou: 0.5903 - val_recall_3: 0.7859 - val_precision_3: 0.7456 - lr: 1.0000e-04
# Epoch 32/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0709 - dice_coef: 0.9353 - iou: 0.8788 - recall_3: 0.9497 - precision_3: 0.9780
# Epoch 32: val_loss did not improve from 0.33978
# 70/70 [==============================] - 17s 249ms/step - loss: 0.0709 - dice_coef: 0.9353 - iou: 0.8788 - recall_3: 0.9497 - precision_3: 0.9780 - val_loss: 0.3738 - val_dice_coef: 0.6826 - val_iou: 0.5647 - val_recall_3: 0.7296 - val_precision_3: 0.7613 - lr: 1.0000e-04
# Epoch 33/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0633 - dice_coef: 0.9420 - iou: 0.8906 - recall_3: 0.9549 - precision_3: 0.9823
# Epoch 33: val_loss did not improve from 0.33978
# 70/70 [==============================] - 17s 248ms/step - loss: 0.0633 - dice_coef: 0.9420 - iou: 0.8906 - recall_3: 0.9549 - precision_3: 0.9823 - val_loss: 0.3569 - val_dice_coef: 0.6984 - val_iou: 0.5820 - val_recall_3: 0.7547 - val_precision_3: 0.7623 - lr: 1.0000e-04
# Epoch 34/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0619 - dice_coef: 0.9434 - iou: 0.8931 - recall_3: 0.9554 - precision_3: 0.9802
# Epoch 34: val_loss did not improve from 0.33978
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 70/70 [==============================] - 17s 248ms/step - loss: 0.0619 - dice_coef: 0.9434 - iou: 0.8931 - recall_3: 0.9554 - precision_3: 0.9802 - val_loss: 0.3516 - val_dice_coef: 0.7056 - val_iou: 0.5955 - val_recall_3: 0.7762 - val_precision_3: 0.7548 - lr: 1.0000e-04
# Epoch 35/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0595 - dice_coef: 0.9456 - iou: 0.8970 - recall_3: 0.9538 - precision_3: 0.9845
# Epoch 35: val_loss did not improve from 0.33978
# 70/70 [==============================] - 17s 249ms/step - loss: 0.0595 - dice_coef: 0.9456 - iou: 0.8970 - recall_3: 0.9538 - precision_3: 0.9845 - val_loss: 0.3582 - val_dice_coef: 0.6969 - val_iou: 0.5840 - val_recall_3: 0.7528 - val_precision_3: 0.7607 - lr: 1.0000e-05
# Epoch 36/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0546 - dice_coef: 0.9497 - iou: 0.9044 - recall_3: 0.9581 - precision_3: 0.9878
# Epoch 36: val_loss did not improve from 0.33978
# 70/70 [==============================] - 17s 248ms/step - loss: 0.0546 - dice_coef: 0.9497 - iou: 0.9044 - recall_3: 0.9581 - precision_3: 0.9878 - val_loss: 0.3579 - val_dice_coef: 0.6967 - val_iou: 0.5833 - val_recall_3: 0.7496 - val_precision_3: 0.7634 - lr: 1.0000e-05
# Epoch 37/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0530 - dice_coef: 0.9511 - iou: 0.9069 - recall_3: 0.9592 - precision_3: 0.9889
# Epoch 37: val_loss did not improve from 0.33978
# 70/70 [==============================] - 17s 249ms/step - loss: 0.0530 - dice_coef: 0.9511 - iou: 0.9069 - recall_3: 0.9592 - precision_3: 0.9889 - val_loss: 0.3581 - val_dice_coef: 0.6966 - val_iou: 0.5829 - val_recall_3: 0.7480 - val_precision_3: 0.7637 - lr: 1.0000e-05
# Epoch 38/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0518 - dice_coef: 0.9522 - iou: 0.9088 - recall_3: 0.9600 - precision_3: 0.9896
# Epoch 38: val_loss did not improve from 0.33978
# 70/70 [==============================] - 17s 249ms/step - loss: 0.0518 - dice_coef: 0.9522 - iou: 0.9088 - recall_3: 0.9600 - precision_3: 0.9896 - val_loss: 0.3587 - val_dice_coef: 0.6963 - val_iou: 0.5824 - val_recall_3: 0.7468 - val_precision_3: 0.7639 - lr: 1.0000e-05
# Epoch 39/50
# 70/70 [==============================] - ETA: 0s - loss: 0.0508 - dice_coef: 0.9531 - iou: 0.9105 - recall_3: 0.9607 - precision_3: 0.9902
# Epoch 39: val_loss did not improve from 0.33978
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1e-06.
# 70/70 [==============================] - 17s 249ms/step - loss: 0.0508 - dice_coef: 0.9531 - iou: 0.9105 - recall_3: 0.9607 - precision_3: 0.9902 - val_loss: 0.3594 - val_dice_coef: 0.6959 - val_iou: 0.5818 - val_recall_3: 0.7459 - val_precision_3: 0.7641 - lr: 1.0000e-05

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 1
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model5.h5")
csv_path = os.path.join("files", "data5.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model5 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 1280], strides=[2, 2, 2, 4])

model5.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model5.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 140 - 140
# Valid: 20 - 20
# Epoch 1/50
# 140/140 [==============================] - ETA: 0s - loss: 1.0295 - dice_coef: 0.1957 - iou: 0.1114 - recall_4: 0.7568 - precision_4: 0.3656
# Epoch 1: val_loss improved from inf to 1.21234, saving model to files/model5.h5
# 140/140 [==============================] - 28s 167ms/step - loss: 1.0295 - dice_coef: 0.1957 - iou: 0.1114 - recall_4: 0.7568 - precision_4: 0.3656 - val_loss: 1.2123 - val_dice_coef: 0.0295 - val_iou: 0.0150 - val_recall_4: 0.0000e+00 - val_precision_4: 0.0000e+00 - lr: 1.0000e-04
# Epoch 2/50
# 140/140 [==============================] - ETA: 0s - loss: 0.7740 - dice_coef: 0.3330 - iou: 0.2033 - recall_4: 0.8340 - precision_4: 0.6958
# Epoch 2: val_loss did not improve from 1.21234
# 140/140 [==============================] - 21s 152ms/step - loss: 0.7740 - dice_coef: 0.3330 - iou: 0.2033 - recall_4: 0.8340 - precision_4: 0.6958 - val_loss: 3.6612 - val_dice_coef: 0.0209 - val_iou: 0.0106 - val_recall_4: 0.2952 - val_precision_4: 0.0119 - lr: 1.0000e-04
# Epoch 3/50
# 140/140 [==============================] - ETA: 0s - loss: 0.6354 - dice_coef: 0.4328 - iou: 0.2802 - recall_4: 0.8761 - precision_4: 0.7926
# Epoch 3: val_loss improved from 1.21234 to 1.05739, saving model to files/model5.h5
# Epoch 9/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2268 - dice_coef: 0.7946 - iou: 0.6719 - recall_4: 0.8994 - precision_4: 0.9107
# Epoch 9: val_loss did not improve from 0.76122
# 140/140 [==============================] - 21s 152ms/step - loss: 0.2268 - dice_coef: 0.7946 - iou: 0.6719 - recall_4: 0.8994 - precision_4: 0.9107 - val_loss: 1.0772 - val_dice_coef: 0.3804 - val_iou: 0.2765 - val_recall_4: 0.5619 - val_precision_4: 0.1548 - lr: 1.0000e-04
# Epoch 10/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2012 - dice_coef: 0.8185 - iou: 0.7055 - recall_4: 0.8984 - precision_4: 0.9204
# Epoch 10: val_loss improved from 0.76122 to 0.73163, saving model to files/model5.h5
# 140/140 [==============================] - 25s 177ms/step - loss: 0.2012 - dice_coef: 0.8185 - iou: 0.7055 - recall_4: 0.8984 - precision_4: 0.9204 - val_loss: 0.7316 - val_dice_coef: 0.4525 - val_iou: 0.3371 - val_recall_4: 0.5900 - val_precision_4: 0.2938 - lr: 1.0000e-04
# Epoch 11/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1805 - dice_coef: 0.8379 - iou: 0.7341 - recall_4: 0.9014 - precision_4: 0.9279
# Epoch 11: val_loss did not improve from 0.73163
# 140/140 [==============================] - 22s 152ms/step - loss: 0.1805 - dice_coef: 0.8379 - iou: 0.7341 - recall_4: 0.9014 - precision_4: 0.9279 - val_loss: 1.1142 - val_dice_coef: 0.4579 - val_iou: 0.3439 - val_recall_4: 0.6225 - val_precision_4: 0.1705 - lr: 1.0000e-04
# Epoch 12/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1731 - dice_coef: 0.8455 - iou: 0.7458 - recall_4: 0.9000 - precision_4: 0.9200
# Epoch 12: val_loss improved from 0.73163 to 0.71701, saving model to files/model5.h5
# 140/140 [==============================] - 25s 179ms/step - loss: 0.1731 - dice_coef: 0.8455 - iou: 0.7458 - recall_4: 0.9000 - precision_4: 0.9200 - val_loss: 0.7170 - val_dice_coef: 0.4176 - val_iou: 0.3092 - val_recall_4: 0.4922 - val_precision_4: 0.3831 - lr: 1.0000e-04
# Epoch 13/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1578 - dice_coef: 0.8598 - iou: 0.7667 - recall_4: 0.8965 - precision_4: 0.9307
# Epoch 13: val_loss did not improve from 0.71701
# 140/140 [==============================] - 22s 152ms/step - loss: 0.1578 - dice_coef: 0.8598 - iou: 0.7667 - recall_4: 0.8965 - precision_4: 0.9307 - val_loss: 0.8517 - val_dice_coef: 0.5176 - val_iou: 0.4023 - val_recall_4: 0.7387 - val_precision_4: 0.2551 - lr: 1.0000e-04
# Epoch 14/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1615 - dice_coef: 0.8585 - iou: 0.7679 - recall_4: 0.8918 - precision_4: 0.9127
# Epoch 14: val_loss did not improve from 0.71701
# Epoch 20: val_loss did not improve from 0.70340
# 140/140 [==============================] - 22s 152ms/step - loss: 0.0859 - dice_coef: 0.9240 - iou: 0.8671 - recall_4: 0.9247 - precision_4: 0.9668 - val_loss: 0.8030 - val_dice_coef: 0.3587 - val_iou: 0.2702 - val_recall_4: 0.4109 - val_precision_4: 0.2892 - lr: 1.0000e-04
# Epoch 21/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1058 - dice_coef: 0.9077 - iou: 0.8421 - recall_4: 0.9134 - precision_4: 0.9428
# Epoch 21: val_loss did not improve from 0.70340
# 140/140 [==============================] - 21s 152ms/step - loss: 0.1058 - dice_coef: 0.9077 - iou: 0.8421 - recall_4: 0.9134 - precision_4: 0.9428 - val_loss: 0.9277 - val_dice_coef: 0.3994 - val_iou: 0.2979 - val_recall_4: 0.5111 - val_precision_4: 0.1710 - lr: 1.0000e-04
# Epoch 22/50
# 140/140 [==============================] - ETA: 0s - loss: 0.0970 - dice_coef: 0.9160 - iou: 0.8553 - recall_4: 0.9105 - precision_4: 0.9519
# Epoch 22: val_loss improved from 0.70340 to 0.55454, saving model to files/model5.h5
# 140/140 [==============================] - 25s 179ms/step - loss: 0.0970 - dice_coef: 0.9160 - iou: 0.8553 - recall_4: 0.9105 - precision_4: 0.9519 - val_loss: 0.5545 - val_dice_coef: 0.5428 - val_iou: 0.4155 - val_recall_4: 0.5978 - val_precision_4: 0.5003 - lr: 1.0000e-04
# Epoch 23/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1011 - dice_coef: 0.9117 - iou: 0.8486 - recall_4: 0.9095 - precision_4: 0.9506
# Epoch 23: val_loss did not improve from 0.55454
# 140/140 [==============================] - 22s 152ms/step - loss: 0.1011 - dice_coef: 0.9117 - iou: 0.8486 - recall_4: 0.9095 - precision_4: 0.9506 - val_loss: 0.8971 - val_dice_coef: 0.1990 - val_iou: 0.1418 - val_recall_4: 0.1816 - val_precision_4: 0.5218 - lr: 1.0000e-04
# Epoch 24/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1087 - dice_coef: 0.9068 - iou: 0.8454 - recall_4: 0.9056 - precision_4: 0.9365
# Epoch 24: val_loss did not improve from 0.55454
# 140/140 [==============================] - 21s 152ms/step - loss: 0.1087 - dice_coef: 0.9068 - iou: 0.8454 - recall_4: 0.9056 - precision_4: 0.9365 - val_loss: 0.7466 - val_dice_coef: 0.5488 - val_iou: 0.4364 - val_recall_4: 0.7015 - val_precision_4: 0.2633 - lr: 1.0000e-04
# Epoch 25/50
# 140/140 [==============================] - ETA: 0s - loss: 0.0833 - dice_coef: 0.9272 - iou: 0.8732 - recall_4: 0.9191 - precision_4: 0.9624
# Epoch 25: val_loss did not improve from 0.55454
# 140/140 [==============================] - 21s 152ms/step - loss: 0.0833 - dice_coef: 0.9272 - iou: 0.8732 - recall_4: 0.9191 - precision_4: 0.9624 - val_loss: 0.9221 - val_dice_coef: 0.2604 - val_iou: 0.1895 - val_recall_4: 0.2982 - val_precision_4: 0.2038 - lr: 1.0000e-04
# Epoch 26/50
# 140/140 [==============================] - ETA: 0s - loss: 0.0704 - dice_coef: 0.9382 - iou: 0.8915 - recall_4: 0.9320 - precision_4: 0.9691
# Epoch 26: val_loss did not improve from 0.55454
# 140/140 [==============================] - 21s 152ms/step - loss: 0.0704 - dice_coef: 0.9382 - iou: 0.8915 - recall_4: 0.9320 - precision_4: 0.9691 - val_loss: 0.9060 - val_dice_coef: 0.3938 - val_iou: 0.3033 - val_recall_4: 0.4690 - val_precision_4: 0.1909 - lr: 1.0000e-04
# Epoch 27/50
# 140/140 [==============================] - ETA: 0s - loss: 0.0693 - dice_coef: 0.9390 - iou: 0.8926 - recall_4: 0.9348 - precision_4: 0.9703
# Epoch 27: val_loss did not improve from 0.55454
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 140/140 [==============================] - 21s 152ms/step - loss: 0.0693 - dice_coef: 0.9390 - iou: 0.8926 - recall_4: 0.9348 - precision_4: 0.9703 - val_loss: 0.6500 - val_dice_coef: 0.4318 - val_iou: 0.3230 - val_recall_4: 0.4100 - val_precision_4: 0.5897 - lr: 1.0000e-04
# Epoch 28/50
# 140/140 [==============================] - ETA: 0s - loss: 0.0608 - dice_coef: 0.9462 - iou: 0.9053 - recall_4: 0.9392 - precision_4: 0.9766
# Epoch 28: val_loss did not improve from 0.55454
# 140/140 [==============================] - 21s 152ms/step - loss: 0.0608 - dice_coef: 0.9462 - iou: 0.9053 - recall_4: 0.9392 - precision_4: 0.9766 - val_loss: 0.7346 - val_dice_coef: 0.3603 - val_iou: 0.2658 - val_recall_4: 0.3575 - val_precision_4: 0.4400 - lr: 1.0000e-05
# Epoch 29/50
# 140/140 [==============================] - ETA: 0s - loss: 0.0562 - dice_coef: 0.9499 - iou: 0.9117 - recall_4: 0.9457 - precision_4: 0.9796
# Epoch 29: val_loss did not improve from 0.55454
# 140/140 [==============================] - 21s 152ms/step - loss: 0.0562 - dice_coef: 0.9499 - iou: 0.9117 - recall_4: 0.9457 - precision_4: 0.9796 - val_loss: 0.7542 - val_dice_coef: 0.3485 - val_iou: 0.2558 - val_recall_4: 0.3494 - val_precision_4: 0.3904 - lr: 1.0000e-05
# Epoch 30/50
# 140/140 [==============================] - ETA: 0s - loss: 0.0542 - dice_coef: 0.9516 - iou: 0.9146 - recall_4: 0.9490 - precision_4: 0.9806
# Epoch 30: val_loss did not improve from 0.55454
# 140/140 [==============================] - 21s 152ms/step - loss: 0.0542 - dice_coef: 0.9516 - iou: 0.9146 - recall_4: 0.9490 - precision_4: 0.9806 - val_loss: 0.7689 - val_dice_coef: 0.3456 - val_iou: 0.2542 - val_recall_4: 0.3529 - val_precision_4: 0.3435 - lr: 1.0000e-05
# Epoch 31/50
# 140/140 [==============================] - ETA: 0s - loss: 0.0527 - dice_coef: 0.9528 - iou: 0.9167 - recall_4: 0.9509 - precision_4: 0.9814
# Epoch 31: val_loss did not improve from 0.55454
# 140/140 [==============================] - 21s 152ms/step - loss: 0.0527 - dice_coef: 0.9528 - iou: 0.9167 - recall_4: 0.9509 - precision_4: 0.9814 - val_loss: 0.7782 - val_dice_coef: 0.3464 - val_iou: 0.2560 - val_recall_4: 0.3570 - val_precision_4: 0.3171 - lr: 1.0000e-05
# Epoch 32/50
# 140/140 [==============================] - ETA: 0s - loss: 0.0515 - dice_coef: 0.9538 - iou: 0.9185 - recall_4: 0.9521 - precision_4: 0.9821
# Epoch 32: val_loss did not improve from 0.55454
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1e-06.
# 140/140 [==============================] - 21s 152ms/step - loss: 0.0515 - dice_coef: 0.9538 - iou: 0.9185 - recall_4: 0.9521 - precision_4: 0.9821 - val_loss: 0.7791 - val_dice_coef: 0.3485 - val_iou: 0.2582 - val_recall_4: 0.3588 - val_precision_4: 0.3145 - lr: 1.0000e-05

# %% [markdown]
# ### Evaluating the Model:

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import pandas as pd
import cv2
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import accuracy_score, f1_score, jaccard_score, precision_score, recall_score
from tensorflow.keras.models import load_model

# %%
H = 512
W = 512

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.float32)
    return ori_x, x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.int32)
    return ori_x, x

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.png")))
    y = sorted(glob(os.path.join(path, "mask", "*.png")))
    return x, y

def save_results(ori_x, ori_y, y_pred, save_image_path):
    line = np.ones((H, 10, 3)) * 255

    ori_y = np.expand_dims(ori_y, axis=-1)
    ori_y = np.concatenate([ori_y, ori_y, ori_y], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1) * 255

    cat_images = np.concatenate([ori_x, line, ori_y, line, y_pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model1.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score1 = [s[1:] for s in SCORE]
score1 = np.mean(score1, axis=0)
print(f"Accuracy: {score1[0]:0.5f}")
print(f"F1: {score1[1]:0.5f}")
print(f"Jaccard: {score1[2]:0.5f}")
print(f"Recall: {score1[3]:0.5f}")
print(f"Precision: {score1[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score1.csv")
# Out:
# 100%|██████████| 20/20 [00:07<00:00,  2.78it/s]
# Accuracy: 0.99290
# F1: 0.75503
# Jaccard: 0.66379
# Recall: 0.89217
# Precision: 0.76498

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model2.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score2 = [s[1:] for s in SCORE]
score2 = np.mean(score2, axis=0)
print(f"Accuracy: {score2[0]:0.5f}")
print(f"F1: {score2[1]:0.5f}")
print(f"Jaccard: {score2[2]:0.5f}")
print(f"Recall: {score2[3]:0.5f}")
print(f"Precision: {score2[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score2.csv")
# Out:
# 100%|██████████| 20/20 [00:07<00:00,  2.77it/s]
# Accuracy: 0.99261
# F1: 0.74699
# Jaccard: 0.65220
# Recall: 0.88966
# Precision: 0.75831

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model3.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score3 = [s[1:] for s in SCORE]
score3 = np.mean(score3, axis=0)
print(f"Accuracy: {score3[0]:0.5f}")
print(f"F1: {score3[1]:0.5f}")
print(f"Jaccard: {score3[2]:0.5f}")
print(f"Recall: {score3[3]:0.5f}")
print(f"Precision: {score3[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score3.csv")
# Out:
# 100%|██████████| 20/20 [00:07<00:00,  2.75it/s]
# Accuracy: 0.99333
# F1: 0.75853
# Jaccard: 0.66680
# Recall: 0.88490
# Precision: 0.77451

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model4.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score4 = [s[1:] for s in SCORE]
score4 = np.mean(score4, axis=0)
print(f"Accuracy: {score4[0]:0.5f}")
print(f"F1: {score4[1]:0.5f}")
print(f"Jaccard: {score4[2]:0.5f}")
print(f"Recall: {score4[3]:0.5f}")
print(f"Precision: {score4[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score4.csv")
# Out:
#  10%|█         | 2/20 [00:01<00:08,  2.10it/s]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 100%|██████████| 20/20 [00:07<00:00,  2.73it/s]
# Accuracy: 0.99317
# F1: 0.74091
# Jaccard: 0.65629
# Recall: 0.87109
# Precision: 0.72691

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model5.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score5 = [s[1:] for s in SCORE]
score5 = np.mean(score5, axis=0)
print(f"Accuracy: {score5[0]:0.5f}")
print(f"F1: {score5[1]:0.5f}")
print(f"Jaccard: {score5[2]:0.5f}")
print(f"Recall: {score5[3]:0.5f}")
print(f"Precision: {score5[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score5.csv")
# Out:
# 100%|██████████| 20/20 [00:07<00:00,  2.70it/s]
# Accuracy: 0.98487
# F1: 0.55748
# Jaccard: 0.43309
# Recall: 0.67562
# Precision: 0.70732

# %%
import matplotlib.pyplot as plt

z_dim = 64
channels = [384, 512, 768, 1024, 1280]
final_score = [score1[1], score2[1], score3[1], score4[1], score5[1]]

plt.plot(channels, final_score)  
plt.show()
