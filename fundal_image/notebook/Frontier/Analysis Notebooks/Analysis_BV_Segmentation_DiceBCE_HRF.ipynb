# %% [markdown]
# ### Import the required libraries and modules:

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
import numpy as np

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# %cd /content/gdrive/MyDrive/Blood_Vessel_Results/ALL_BEST_RESULTS/HRF_BV_FULL
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/Blood_Vessel_Results/ALL_BEST_RESULTS/HRF_BV_FULL

# %% [markdown]
# ### Unzip the data:

# %%
# !unzip new_data_512.zip

# %% [markdown]
# ### Construct the Model:

# %%
def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(inputs, num_filters, strides=2):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D(strides)(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters, strides=2):
    x = Conv2DTranspose(num_filters, (2, 2), strides=strides, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape, num_filters=[64, 128, 256, 512, 1024], strides=[2, 2, 2, 2]):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, num_filters[0], strides=strides[0])
    s2, p2 = encoder_block(p1, num_filters[1], strides=strides[1])
    s3, p3 = encoder_block(p2, num_filters[2], strides=strides[2])
    s4, p4 = encoder_block(p3, num_filters[3], strides=strides[3])

    b1 = conv_block(p4, num_filters[4])

    d1 = decoder_block(b1, s4, num_filters[3], strides=strides[3])
    d2 = decoder_block(d1, s3, num_filters[2], strides=strides[2])
    d3 = decoder_block(d2, s2, num_filters[1], strides=strides[1])
    d4 = decoder_block(d3, s1, num_filters[0], strides=strides[0])

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="UNET")
    return model

input_shape = (512, 512, 3)
model = build_unet(input_shape)
model.summary()
# Out:
# Model: "UNET"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 512, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 512, 512, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 512, 512, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 512, 512, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 12  0          ['activation_3[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 25  295168      ['max_pooling2d_1[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_4[0][0]']
#  rmalization)                   6)
#
#  activation_4 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_4[0][0]']
#                                 6)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 25  590080      ['activation_4[0][0]']
#                                 6)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_5[0][0]']
#  rmalization)                   6)
#
#  activation_5 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_5[0][0]']
#                                 6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 512)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 512)  2097664    ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 64, 64, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 25  524544     ['activation_11[0][0]']
#  spose)                         6)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 51  0           ['conv2d_transpose_1[0][0]',
#                                 2)                                'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_12 (BatchN  (None, 128, 128, 25  1024       ['conv2d_12[0][0]']
#  ormalization)                  6)
#
#  activation_12 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_12[0][0]']
#                                 6)
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 25  590080      ['activation_12[0][0]']
#                                 6)
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 25  1024       ['conv2d_13[0][0]']
#  ormalization)                  6)
#
#  activation_13 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_13[0][0]']
#                                 6)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 12  131200     ['activation_13[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 256, 256, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  activation_14 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_15 (BatchN  (None, 256, 256, 12  512        ['conv2d_15[0][0]']
#  ormalization)                  8)
#
#  activation_15 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_15[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 64  32832      ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 512, 512, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 512, 512, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 512, 512, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 512, 512, 1)  65          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %% [markdown]
# ### Adding the Metrics:

# %%
def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def DiceBCELoss(y_true, y_pred):

    inputs = tf.keras.layers.Flatten()(y_true)
    targets = tf.keras.layers.Flatten()(y_pred)

    intersection = tf.reduce_sum(inputs * targets)
    dice_loss = 1 - (2.*intersection + smooth)/(tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)
    BCE = tf.keras.losses.BinaryCrossentropy()
    Dice_BCE = BCE(inputs, targets) + dice_loss

    return Dice_BCE

# %% [markdown]
# ### Training the Model:

# %%
H = 512
W = 512

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.png")))
    y = sorted(glob(os.path.join(path, "mask", "*.png")))
    return x, y

def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)
    return x, y

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)              ## (512, 512, 1)
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y, batch_size=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(4)
    return dataset

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 8
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model1.h5")
csv_path = os.path.join("files", "data1.csv")

""" Dataset """
dataset_path = "new_data_512"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model1 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 1024], strides=[2, 2, 2, 4])

model1.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model1.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 252 - 252
# Valid: 9 - 9
# Epoch 1/50
# 32/32 [==============================] - ETA: 0s - loss: 1.1684 - dice_coef: 0.2474 - iou: 0.1422 - recall: 0.5987 - precision: 0.3560
# Epoch 1: val_loss improved from inf to 1.53464, saving model to files/model1.h5
# 32/32 [==============================] - 210s 5s/step - loss: 1.1684 - dice_coef: 0.2474 - iou: 0.1422 - recall: 0.5987 - precision: 0.3560 - val_loss: 1.5346 - val_dice_coef: 0.1319 - val_iou: 0.0706 - val_recall: 0.0019 - val_precision: 0.0150 - lr: 1.0000e-04
# Epoch 2/50
# 32/32 [==============================] - ETA: 0s - loss: 0.8434 - dice_coef: 0.3902 - iou: 0.2429 - recall: 0.6341 - precision: 0.6775
# Epoch 2: val_loss improved from 1.53464 to 1.43529, saving model to files/model1.h5
# 32/32 [==============================] - 68s 2s/step - loss: 0.8434 - dice_coef: 0.3902 - iou: 0.2429 - recall: 0.6341 - precision: 0.6775 - val_loss: 1.4353 - val_dice_coef: 0.1309 - val_iou: 0.0701 - val_recall: 3.2084e-04 - val_precision: 0.0167 - lr: 1.0000e-04
# Epoch 3/50
# 32/32 [==============================] - ETA: 0s - loss: 0.7419 - dice_coef: 0.4527 - iou: 0.2929 - recall: 0.6573 - precision: 0.7241
# Epoch 3: val_loss did not improve from 1.43529
# 32/32 [==============================] - 63s 2s/step - loss: 0.7419 - dice_coef: 0.4527 - iou: 0.2929 - recall: 0.6573 - precision: 0.7241 - val_loss: 1.5622 - val_dice_coef: 0.1378 - val_iou: 0.0740 - val_recall: 0.5983 - val_precision: 0.1014 - lr: 1.0000e-04
# Epoch 4/50
# 32/32 [==============================] - ETA: 0s - loss: 0.6838 - dice_coef: 0.4895 - iou: 0.3243 - recall: 0.6704 - precision: 0.7512
# Epoch 4: val_loss improved from 1.43529 to 1.20773, saving model to files/model1.h5
# 32/32 [==============================] - 66s 2s/step - loss: 0.6838 - dice_coef: 0.4895 - iou: 0.3243 - recall: 0.6704 - precision: 0.7512 - val_loss: 1.2077 - val_dice_coef: 0.1135 - val_iou: 0.0601 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 5/50
# 32/32 [==============================] - ETA: 0s - loss: 0.6528 - dice_coef: 0.5119 - iou: 0.3444 - recall: 0.6812 - precision: 0.7630
# Epoch 5: val_loss improved from 1.20773 to 1.17588, saving model to files/model1.h5
# 32/32 [==============================] - 66s 2s/step - loss: 0.6528 - dice_coef: 0.5119 - iou: 0.3444 - recall: 0.6812 - precision: 0.7630 - val_loss: 1.1759 - val_dice_coef: 0.1065 - val_iou: 0.0562 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 6/50
# 32/32 [==============================] - ETA: 0s - loss: 0.6320 - dice_coef: 0.5275 - iou: 0.3585 - recall: 0.6828 - precision: 0.7736
# Epoch 6: val_loss improved from 1.17588 to 1.16326, saving model to files/model1.h5
# 32/32 [==============================] - 66s 2s/step - loss: 0.6320 - dice_coef: 0.5275 - iou: 0.3585 - recall: 0.6828 - precision: 0.7736 - val_loss: 1.1633 - val_dice_coef: 0.1039 - val_iou: 0.0548 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 7/50
# 32/32 [==============================] - ETA: 0s - loss: 0.5975 - dice_coef: 0.5501 - iou: 0.3797 - recall: 0.6887 - precision: 0.7912
# Epoch 7: val_loss improved from 1.16326 to 1.15827, saving model to files/model1.h5
# 32/32 [==============================] - 66s 2s/step - loss: 0.5975 - dice_coef: 0.5501 - iou: 0.3797 - recall: 0.6887 - precision: 0.7912 - val_loss: 1.1583 - val_dice_coef: 0.0973 - val_iou: 0.0511 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 8/50
# 32/32 [==============================] - ETA: 0s - loss: 0.5761 - dice_coef: 0.5662 - iou: 0.3951 - recall: 0.6942 - precision: 0.7996
# Epoch 8: val_loss did not improve from 1.15827
# 32/32 [==============================] - 62s 2s/step - loss: 0.5761 - dice_coef: 0.5662 - iou: 0.3951 - recall: 0.6942 - precision: 0.7996 - val_loss: 1.1601 - val_dice_coef: 0.0905 - val_iou: 0.0474 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 
# Epoch 50/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2510 - dice_coef: 0.8170 - iou: 0.6907 - recall: 0.7945 - precision: 0.9377
# Epoch 50: val_loss did not improve from 0.38202
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1e-06.
# 32/32 [==============================] - 63s 2s/step - loss: 0.2510 - dice_coef: 0.8170 - iou: 0.6907 - recall: 0.7945 - precision: 0.9377 - val_loss: 0.3847 - val_dice_coef: 0.7484 - val_iou: 0.5985 - val_recall: 0.7112 - val_precision: 0.8468 - lr: 1.0000e-05

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 8
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model2.h5")
csv_path = os.path.join("files", "data2.csv")

""" Dataset """
dataset_path = "new_data_512"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model2 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 1024], strides=[2, 2, 2, 2])

model2.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model2.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 252 - 252
# Valid: 9 - 9
# Epoch 1/50
# 32/32 [==============================] - ETA: 0s - loss: 1.1690 - dice_coef: 0.2472 - iou: 0.1421 - recall_1: 0.5992 - precision_1: 0.3557
# Epoch 1: val_loss improved from inf to 1.53561, saving model to files/model2.h5
# 32/32 [==============================] - 75s 2s/step - loss: 1.1690 - dice_coef: 0.2472 - iou: 0.1421 - recall_1: 0.5992 - precision_1: 0.3557 - val_loss: 1.5356 - val_dice_coef: 0.1320 - val_iou: 0.0706 - val_recall_1: 0.0019 - val_precision_1: 0.0146 - lr: 1.0000e-04
# Epoch 2/50
# 32/32 [==============================] - ETA: 0s - loss: 0.8458 - dice_coef: 0.3892 - iou: 0.2421 - recall_1: 0.6343 - precision_1: 0.6751
# Epoch 2: val_loss improved from 1.53561 to 1.43081, saving model to files/model2.h5
# 32/32 [==============================] - 70s 2s/step - loss: 0.8458 - dice_coef: 0.3892 - iou: 0.2421 - recall_1: 0.6343 - precision_1: 0.6751 - val_loss: 1.4308 - val_dice_coef: 0.1308 - val_iou: 0.0700 - val_recall_1: 2.0237e-04 - val_precision_1: 0.0122 - lr: 1.0000e-04
# Epoch 3/50
# 32/32 [==============================] - ETA: 0s - loss: 0.7402 - dice_coef: 0.4530 - iou: 0.2932 - recall_1: 0.6591 - precision_1: 0.7233
# Epoch 3: val_loss improved from 1.43081 to 1.30906, saving model to files/model2.h5
# 32/32 [==============================] - 71s 2s/step - loss: 0.7402 - dice_coef: 0.4530 - iou: 0.2932 - recall_1: 0.6591 - precision_1: 0.7233 - val_loss: 1.3091 - val_dice_coef: 0.1262 - val_iou: 0.0673 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 4/50
# 32/32 [==============================] - ETA: 0s - loss: 0.6798 - dice_coef: 0.4919 - iou: 0.3265 - recall_1: 0.6729 - precision_1: 0.7539
# Epoch 4: val_loss improved from 1.30906 to 1.20317, saving model to files/model2.h5
# 32/32 [==============================] - 71s 2s/step - loss: 0.6798 - dice_coef: 0.4919 - iou: 0.3265 - recall_1: 0.6729 - precision_1: 0.7539 - val_loss: 1.2032 - val_dice_coef: 0.1124 - val_iou: 0.0596 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 5/50
# 32/32 [==============================] - ETA: 0s - loss: 0.6442 - dice_coef: 0.5170 - iou: 0.3489 - recall_1: 0.6843 - precision_1: 0.7688
# Epoch 5: val_loss improved from 1.20317 to 1.17598, saving model to files/model2.h5
# 32/32 [==============================] - 69s 2s/step - loss: 0.6442 - dice_coef: 0.5170 - iou: 0.3489 - recall_1: 0.6843 - precision_1: 0.7688 - val_loss: 1.1760 - val_dice_coef: 0.1008 - val_iou: 0.0531 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 6/50
# 32/32 [==============================] - ETA: 0s - loss: 0.6127 - dice_coef: 0.5383 - iou: 0.3686 - recall_1: 0.6895 - precision_1: 0.7850
# Epoch 6: val_loss improved from 1.17598 to 1.17143, saving model to files/model2.h5
# 32/32 [==============================] - 69s 2s/step - loss: 0.6127 - dice_coef: 0.5383 - iou: 0.3686 - recall_1: 0.6895 - precision_1: 0.7850 - val_loss: 1.1714 - val_dice_coef: 0.0910 - val_iou: 0.0476 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 7/50
# 32/32 [==============================] - ETA: 0s - loss: 0.5906 - dice_coef: 0.5550 - iou: 0.3844 - recall_1: 0.6944 - precision_1: 0.7926
# Epoch 7: val_loss improved from 1.17143 to 1.17019, saving model to files/model2.h5
# Epoch 24/50
# 32/32 [==============================] - ETA: 0s - loss: 0.4015 - dice_coef: 0.7032 - iou: 0.5425 - recall_1: 0.7302 - precision_1: 0.8579
# Epoch 24: val_loss improved from 0.45283 to 0.44014, saving model to files/model2.h5
# 32/32 [==============================] - 70s 2s/step - loss: 0.4015 - dice_coef: 0.7032 - iou: 0.5425 - recall_1: 0.7302 - precision_1: 0.8579 - val_loss: 0.4401 - val_dice_coef: 0.6764 - val_iou: 0.5112 - val_recall_1: 0.6960 - val_precision_1: 0.8441 - lr: 1.0000e-04
# Epoch 25/50
# 32/32 [==============================] - ETA: 0s - loss: 0.3944 - dice_coef: 0.7089 - iou: 0.5493 - recall_1: 0.7325 - precision_1: 0.8604
# Epoch 25: val_loss improved from 0.44014 to 0.43241, saving model to files/model2.h5
# 32/32 [==============================] - 70s 2s/step - loss: 0.3944 - dice_coef: 0.7089 - iou: 0.5493 - recall_1: 0.7325 - precision_1: 0.8604 - val_loss: 0.4324 - val_dice_coef: 0.6857 - val_iou: 0.5219 - val_recall_1: 0.7015 - val_precision_1: 0.8416 - lr: 1.0000e-04
# Epoch 26/50
# 32/32 [==============================] - ETA: 0s - loss: 0.3881 - dice_coef: 0.7140 - iou: 0.5555 - recall_1: 0.7342 - precision_1: 0.8626
# Epoch 26: val_loss improved from 0.43241 to 0.42812, saving model to files/model2.h5
# 32/32 [==============================] - 71s 2s/step - loss: 0.3881 - dice_coef: 0.7140 - iou: 0.5555 - recall_1: 0.7342 - precision_1: 0.8626 - val_loss: 0.4281 - val_dice_coef: 0.6882 - val_iou: 0.5248 - val_recall_1: 0.6991 - val_precision_1: 0.8441 - lr: 1.0000e-04
# Epoch 27/50
# 32/32 [==============================] - ETA: 0s - loss: 0.3827 - dice_coef: 0.7185 - iou: 0.5609 - recall_1: 0.7358 - precision_1: 0.8644
# Epoch 27: val_loss improved from 0.42812 to 0.41790, saving model to files/model2.h5
# 32/32 [==============================] - 71s 2s/step - loss: 0.3827 - dice_coef: 0.7185 - iou: 0.5609 - recall_1: 0.7358 - precision_1: 0.8644 - val_loss: 0.4179 - val_dice_coef: 0.6978 - val_iou: 0.5361 - val_recall_1: 0.6982 - val_precision_1: 0.8524 - lr: 1.0000e-04
# Epoch 28/50
# 32/32 [==============================] - ETA: 0s - loss: 0.3771 - dice_coef: 0.7231 - iou: 0.5665 - recall_1: 0.7373 - precision_1: 0.8665
# Epoch 28: val_loss improved from 0.41790 to 0.41657, saving model to files/model2.h5
# 32/32 [==============================] - 70s 2s/step - loss: 0.3771 - dice_coef: 0.7231 - iou: 0.5665 - recall_1: 0.7373 - precision_1: 0.8665 - val_loss: 0.4166 - val_dice_coef: 0.6992 - val_iou: 0.5377 - val_recall_1: 0.7018 - val_precision_1: 0.8471 - lr: 1.0000e-04
# Epoch 29/50
# 32/32 [==============================] - ETA: 0s - loss: 0.3718 - dice_coef: 0.7274 - iou: 0.5718 - recall_1: 0.7390 - precision_1: 0.8684
# Epoch 46: val_loss did not improve from 0.37649
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1e-06.
# 32/32 [==============================] - 66s 2s/step - loss: 0.2994 - dice_coef: 0.7823 - iou: 0.6426 - recall_1: 0.7684 - precision_1: 0.9067 - val_loss: 0.3794 - val_dice_coef: 0.7463 - val_iou: 0.5959 - val_recall_1: 0.7205 - val_precision_1: 0.8457 - lr: 1.0000e-05
# Epoch 47/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2973 - dice_coef: 0.7837 - iou: 0.6446 - recall_1: 0.7715 - precision_1: 0.9071
# Epoch 47: val_loss did not improve from 0.37649
# 32/32 [==============================] - 66s 2s/step - loss: 0.2973 - dice_coef: 0.7837 - iou: 0.6446 - recall_1: 0.7715 - precision_1: 0.9071 - val_loss: 0.3806 - val_dice_coef: 0.7461 - val_iou: 0.5956 - val_recall_1: 0.7217 - val_precision_1: 0.8436 - lr: 1.0000e-06
# Epoch 48/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2968 - dice_coef: 0.7840 - iou: 0.6449 - recall_1: 0.7699 - precision_1: 0.9088
# Epoch 48: val_loss did not improve from 0.37649
# 32/32 [==============================] - 66s 2s/step - loss: 0.2968 - dice_coef: 0.7840 - iou: 0.6449 - recall_1: 0.7699 - precision_1: 0.9088 - val_loss: 0.3812 - val_dice_coef: 0.7456 - val_iou: 0.5950 - val_recall_1: 0.7211 - val_precision_1: 0.8435 - lr: 1.0000e-06
# Epoch 49/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2965 - dice_coef: 0.7841 - iou: 0.6451 - recall_1: 0.7700 - precision_1: 0.9090
# Epoch 49: val_loss did not improve from 0.37649
# 32/32 [==============================] - 66s 2s/step - loss: 0.2965 - dice_coef: 0.7841 - iou: 0.6451 - recall_1: 0.7700 - precision_1: 0.9090 - val_loss: 0.3818 - val_dice_coef: 0.7454 - val_iou: 0.5947 - val_recall_1: 0.7209 - val_precision_1: 0.8431 - lr: 1.0000e-06
# Epoch 50/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2963 - dice_coef: 0.7843 - iou: 0.6454 - recall_1: 0.7702 - precision_1: 0.9091
# Epoch 50: val_loss did not improve from 0.37649
# 32/32 [==============================] - 66s 2s/step - loss: 0.2963 - dice_coef: 0.7843 - iou: 0.6454 - recall_1: 0.7702 - precision_1: 0.9091 - val_loss: 0.3822 - val_dice_coef: 0.7452 - val_iou: 0.5944 - val_recall_1: 0.7209 - val_precision_1: 0.8427 - lr: 1.0000e-06

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 2
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model3.h5")
csv_path = os.path.join("files", "data3.csv")

""" Dataset """
dataset_path = "new_data_512"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model3 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 1024], strides=[1, 2, 2, 2])

model3.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model3.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 252 - 252
# Valid: 9 - 9
# Epoch 1/50
# 126/126 [==============================] - ETA: 0s - loss: 0.8230 - dice_coef: 0.4124 - iou: 0.2643 - recall_2: 0.6439 - precision_2: 0.6129
# Epoch 1: val_loss improved from inf to 1.19091, saving model to files/model3.h5
# 126/126 [==============================] - 254s 2s/step - loss: 0.8230 - dice_coef: 0.4124 - iou: 0.2643 - recall_2: 0.6439 - precision_2: 0.6129 - val_loss: 1.1909 - val_dice_coef: 0.0994 - val_iou: 0.0523 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 2/50
# 126/126 [==============================] - ETA: 0s - loss: 0.5947 - dice_coef: 0.5528 - iou: 0.3833 - recall_2: 0.6989 - precision_2: 0.7918
# Epoch 2: val_loss did not improve from 1.19091
# 126/126 [==============================] - 211s 2s/step - loss: 0.5947 - dice_coef: 0.5528 - iou: 0.3833 - recall_2: 0.6989 - precision_2: 0.7918 - val_loss: 1.1994 - val_dice_coef: 0.0669 - val_iou: 0.0346 - val_recall_2: 1.7276e-04 - val_precision_2: 0.9211 - lr: 1.0000e-04
# Epoch 3/50
# 126/126 [==============================] - ETA: 0s - loss: 0.5166 - dice_coef: 0.6113 - iou: 0.4414 - recall_2: 0.7237 - precision_2: 0.8188
# Epoch 3: val_loss improved from 1.19091 to 0.91558, saving model to files/model3.h5
# 126/126 [==============================] - 214s 2s/step - loss: 0.5166 - dice_coef: 0.6113 - iou: 0.4414 - recall_2: 0.7237 - precision_2: 0.8188 - val_loss: 0.9156 - val_dice_coef: 0.2826 - val_iou: 0.1649 - val_recall_2: 0.1860 - val_precision_2: 0.7537 - lr: 1.0000e-04
# Epoch 4/50
# 126/126 [==============================] - ETA: 0s - loss: 0.4636 - dice_coef: 0.6525 - iou: 0.4854 - recall_2: 0.7375 - precision_2: 0.8349
# Epoch 4: val_loss improved from 0.91558 to 0.54959, saving model to files/model3.h5
# 126/126 [==============================] - 216s 2s/step - loss: 0.4636 - dice_coef: 0.6525 - iou: 0.4854 - recall_2: 0.7375 - precision_2: 0.8349 - val_loss: 0.5496 - val_dice_coef: 0.5718 - val_iou: 0.4007 - val_recall_2: 0.5415 - val_precision_2: 0.9012 - lr: 1.0000e-04
# Epoch 5/50
# 126/126 [==============================] - ETA: 0s - loss: 0.4273 - dice_coef: 0.6816 - iou: 0.5182 - recall_2: 0.7443 - precision_2: 0.8446
# Epoch 5: val_loss improved from 0.54959 to 0.43712, saving model to files/model3.h5
# 126/126 [==============================] - 216s 2s/step - loss: 0.4273 - dice_coef: 0.6816 - iou: 0.5182 - recall_2: 0.7443 - precision_2: 0.8446 - val_loss: 0.4371 - val_dice_coef: 0.6670 - val_iou: 0.5010 - val_recall_2: 0.6772 - val_precision_2: 0.8761 - lr: 1.0000e-04
# Epoch 6/50
# 126/126 [==============================] - ETA: 0s - loss: 0.4013 - dice_coef: 0.7030 - iou: 0.5431 - recall_2: 0.7478 - precision_2: 0.8510
# Epoch 6: val_loss improved from 0.43712 to 0.40195, saving model to files/model3.h5
# 126/126 [==============================] - 217s 2s/step - loss: 0.4013 - dice_coef: 0.7030 - iou: 0.5431 - recall_2: 0.7478 - precision_2: 0.8510 - val_loss: 0.4019 - val_dice_coef: 0.7017 - val_iou: 0.5413 - val_recall_2: 0.7429 - val_precision_2: 0.8457 - lr: 1.0000e-04
# Epoch 7/50
# 126/126 [==============================] - ETA: 0s - loss: 0.3904 - dice_coef: 0.7135 - iou: 0.5557 - recall_2: 0.7435 - precision_2: 0.8509
# Epoch 7: val_loss improved from 0.40195 to 0.39312, saving model to files/model3.h5
# 126/126 [==============================] - 216s 2s/step - loss: 0.3904 - dice_coef: 0.7135 - iou: 0.5557 - recall_2: 0.7435 - precision_2: 0.8509 - val_loss: 0.3931 - val_dice_coef: 0.7115 - val_iou: 0.5531 - val_recall_2: 0.7571 - val_precision_2: 0.8314 - lr: 1.0000e-04
# Epoch 8/50
# 126/126 [==============================] - ETA: 0s - loss: 0.3688 - dice_coef: 0.7306 - iou: 0.5767 - recall_2: 0.7505 - precision_2: 0.8581
# Epoch 8: val_loss improved from 0.39312 to 0.37403, saving model to files/model3.h5
# 126/126 [==============================] - 216s 2s/step - loss: 0.3688 - dice_coef: 0.7306 - iou: 0.5767 - recall_2: 0.7505 - precision_2: 0.8581 - val_loss: 0.3740 - val_dice_coef: 0.7259 - val_iou: 0.5707 - val_recall_2: 0.7441 - val_precision_2: 0.8511 - lr: 1.0000e-04
# Epoch 9/50
# 126/126 [==============================] - ETA: 0s - loss: 0.3552 - dice_coef: 0.7420 - iou: 0.5909 - recall_2: 0.7533 - precision_2: 0.8621
# Epoch 9: val_loss improved from 0.37403 to 0.36856, saving model to files/model3.h5
# Epoch 15: val_loss did not improve from 0.34640
# 126/126 [==============================] - 213s 2s/step - loss: 0.3005 - dice_coef: 0.7872 - iou: 0.6500 - recall_2: 0.7703 - precision_2: 0.8861 - val_loss: 0.3481 - val_dice_coef: 0.7607 - val_iou: 0.6150 - val_recall_2: 0.7679 - val_precision_2: 0.8302 - lr: 1.0000e-04
# Epoch 16/50
# 126/126 [==============================] - ETA: 0s - loss: 0.2914 - dice_coef: 0.7943 - iou: 0.6596 - recall_2: 0.7740 - precision_2: 0.8912
# Epoch 16: val_loss did not improve from 0.34640
# 126/126 [==============================] - 213s 2s/step - loss: 0.2914 - dice_coef: 0.7943 - iou: 0.6596 - recall_2: 0.7740 - precision_2: 0.8912 - val_loss: 0.3502 - val_dice_coef: 0.7587 - val_iou: 0.6122 - val_recall_2: 0.7540 - val_precision_2: 0.8368 - lr: 1.0000e-04
# Epoch 17/50
# 126/126 [==============================] - ETA: 0s - loss: 0.2830 - dice_coef: 0.8009 - iou: 0.6687 - recall_2: 0.7772 - precision_2: 0.8964
# Epoch 17: val_loss did not improve from 0.34640
# 126/126 [==============================] - 213s 2s/step - loss: 0.2830 - dice_coef: 0.8009 - iou: 0.6687 - recall_2: 0.7772 - precision_2: 0.8964 - val_loss: 0.3505 - val_dice_coef: 0.7601 - val_iou: 0.6139 - val_recall_2: 0.7443 - val_precision_2: 0.8403 - lr: 1.0000e-04
# Epoch 18/50
# 126/126 [==============================] - ETA: 0s - loss: 0.2783 - dice_coef: 0.8046 - iou: 0.6739 - recall_2: 0.7787 - precision_2: 0.8986
# Epoch 18: val_loss did not improve from 0.34640
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 126/126 [==============================] - 213s 2s/step - loss: 0.2783 - dice_coef: 0.8046 - iou: 0.6739 - recall_2: 0.7787 - precision_2: 0.8986 - val_loss: 0.3537 - val_dice_coef: 0.7620 - val_iou: 0.6165 - val_recall_2: 0.7639 - val_precision_2: 0.8228 - lr: 1.0000e-04
# Epoch 19/50
# 126/126 [==============================] - ETA: 0s - loss: 0.2601 - dice_coef: 0.8170 - iou: 0.6913 - recall_2: 0.7903 - precision_2: 0.9079
# Epoch 19: val_loss improved from 0.34640 to 0.34189, saving model to files/model3.h5
# 126/126 [==============================] - 218s 2s/step - loss: 0.2601 - dice_coef: 0.8170 - iou: 0.6913 - recall_2: 0.7903 - precision_2: 0.9079 - val_loss: 0.3419 - val_dice_coef: 0.7686 - val_iou: 0.6249 - val_recall_2: 0.7427 - val_precision_2: 0.8500 - lr: 1.0000e-05
# Epoch 20/50
# 126/126 [==============================] - ETA: 0s - loss: 0.2477 - dice_coef: 0.8258 - iou: 0.7039 - recall_2: 0.7943 - precision_2: 0.9186
# Epoch 20: val_loss did not improve from 0.34189
# 126/126 [==============================] - 213s 2s/step - loss: 0.2477 - dice_coef: 0.8258 - iou: 0.7039 - recall_2: 0.7943 - precision_2: 0.9186 - val_loss: 0.3449 - val_dice_coef: 0.7675 - val_iou: 0.6234 - val_recall_2: 0.7386 - val_precision_2: 0.8507 - lr: 1.0000e-05
# Epoch 21/50
# 126/126 [==============================] - ETA: 0s - loss: 0.2404 - dice_coef: 0.8311 - iou: 0.7116 - recall_2: 0.7977 - precision_2: 0.9244
# Epoch 21: val_loss did not improve from 0.34189
# 126/126 [==============================] - 213s 2s/step - loss: 0.2404 - dice_coef: 0.8311 - iou: 0.7116 - recall_2: 0.7977 - precision_2: 0.9244 - val_loss: 0.3475 - val_dice_coef: 0.7667 - val_iou: 0.6224 - val_recall_2: 0.7357 - val_precision_2: 0.8506 - lr: 1.0000e-05
# Epoch 22/50
# 126/126 [==============================] - ETA: 0s - loss: 0.2343 - dice_coef: 0.8357 - iou: 0.7183 - recall_2: 0.8006 - precision_2: 0.9293
# Epoch 22: val_loss did not improve from 0.34189
# 126/126 [==============================] - 213s 2s/step - loss: 0.2343 - dice_coef: 0.8357 - iou: 0.7183 - recall_2: 0.8006 - precision_2: 0.9293 - val_loss: 0.3500 - val_dice_coef: 0.7661 - val_iou: 0.6216 - val_recall_2: 0.7334 - val_precision_2: 0.8502 - lr: 1.0000e-05
# Epoch 23/50
# 126/126 [==============================] - ETA: 0s - loss: 0.2286 - dice_coef: 0.8399 - iou: 0.7246 - recall_2: 0.8031 - precision_2: 0.9337
# Epoch 23: val_loss did not improve from 0.34189
# 126/126 [==============================] - 213s 2s/step - loss: 0.2286 - dice_coef: 0.8399 - iou: 0.7246 - recall_2: 0.8031 - precision_2: 0.9337 - val_loss: 0.3524 - val_dice_coef: 0.7656 - val_iou: 0.6209 - val_recall_2: 0.7315 - val_precision_2: 0.8495 - lr: 1.0000e-05
# Epoch 24/50
# 126/126 [==============================] - ETA: 0s - loss: 0.2233 - dice_coef: 0.8439 - iou: 0.7305 - recall_2: 0.8055 - precision_2: 0.9378
# Epoch 24: val_loss did not improve from 0.34189
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1e-06.
# 126/126 [==============================] - 213s 2s/step - loss: 0.2233 - dice_coef: 0.8439 - iou: 0.7305 - recall_2: 0.8055 - precision_2: 0.9378 - val_loss: 0.3548 - val_dice_coef: 0.7653 - val_iou: 0.6205 - val_recall_2: 0.7303 - val_precision_2: 0.8492 - lr: 1.0000e-05
# Epoch 25/50
# 126/126 [==============================] - ETA: 0s - loss: 0.2200 - dice_coef: 0.8461 - iou: 0.7339 - recall_2: 0.8064 - precision_2: 0.9396
# Epoch 25: val_loss did not improve from 0.34189
# 126/126 [==============================] - 213s 2s/step - loss: 0.2200 - dice_coef: 0.8461 - iou: 0.7339 - recall_2: 0.8064 - precision_2: 0.9396 - val_loss: 0.3532 - val_dice_coef: 0.7655 - val_iou: 0.6207 - val_recall_2: 0.7254 - val_precision_2: 0.8536 - lr: 1.0000e-06
# Epoch 26/50
# 126/126 [==============================] - ETA: 0s - loss: 0.2185 - dice_coef: 0.8472 - iou: 0.7355 - recall_2: 0.8071 - precision_2: 0.9408
# Epoch 26: val_loss did not improve from 0.34189
# 126/126 [==============================] - 213s 2s/step - loss: 0.2185 - dice_coef: 0.8472 - iou: 0.7355 - recall_2: 0.8071 - precision_2: 0.9408 - val_loss: 0.3538 - val_dice_coef: 0.7653 - val_iou: 0.6204 - val_recall_2: 0.7246 - val_precision_2: 0.8536 - lr: 1.0000e-06
# Epoch 27/50
# 126/126 [==============================] - ETA: 0s - loss: 0.2177 - dice_coef: 0.8478 - iou: 0.7363 - recall_2: 0.8075 - precision_2: 0.9414
# Epoch 27: val_loss did not improve from 0.34189
# 126/126 [==============================] - 213s 2s/step - loss: 0.2177 - dice_coef: 0.8478 - iou: 0.7363 - recall_2: 0.8075 - precision_2: 0.9414 - val_loss: 0.3543 - val_dice_coef: 0.7652 - val_iou: 0.6203 - val_recall_2: 0.7244 - val_precision_2: 0.8534 - lr: 1.0000e-06
# Epoch 28/50
# 126/126 [==============================] - ETA: 0s - loss: 0.2170 - dice_coef: 0.8483 - iou: 0.7371 - recall_2: 0.8079 - precision_2: 0.9419
# Epoch 28: val_loss did not improve from 0.34189
# 126/126 [==============================] - 213s 2s/step - loss: 0.2170 - dice_coef: 0.8483 - iou: 0.7371 - recall_2: 0.8079 - precision_2: 0.9419 - val_loss: 0.3547 - val_dice_coef: 0.7651 - val_iou: 0.6202 - val_recall_2: 0.7243 - val_precision_2: 0.8531 - lr: 1.0000e-06
# Epoch 29/50
# 126/126 [==============================] - ETA: 0s - loss: 0.2164 - dice_coef: 0.8487 - iou: 0.7378 - recall_2: 0.8082 - precision_2: 0.9424
# Epoch 29: val_loss did not improve from 0.34189
# 126/126 [==============================] - 213s 2s/step - loss: 0.2164 - dice_coef: 0.8487 - iou: 0.7378 - recall_2: 0.8082 - precision_2: 0.9424 - val_loss: 0.3550 - val_dice_coef: 0.7651 - val_iou: 0.6201 - val_recall_2: 0.7241 - val_precision_2: 0.8530 - lr: 1.0000e-06

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 1
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model4.h5")
csv_path = os.path.join("files", "data4.csv")

""" Dataset """
dataset_path = "new_data_512"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model4 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 1024], strides=[1, 1, 2, 2])

model4.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model4.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 252 - 252
# Valid: 9 - 9
# Epoch 1/50
# 252/252 [==============================] - ETA: 0s - loss: 0.7050 - dice_coef: 0.4875 - iou: 0.3285 - recall_3: 0.6873 - precision_3: 0.6992
# Epoch 1: val_loss improved from inf to 1.21602, saving model to files/model4.h5
# 252/252 [==============================] - 623s 2s/step - loss: 0.7050 - dice_coef: 0.4875 - iou: 0.3285 - recall_3: 0.6873 - precision_3: 0.6992 - val_loss: 1.2160 - val_dice_coef: 0.0586 - val_iou: 0.0302 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00 - lr: 1.0000e-04
# Epoch 2/50
# 252/252 [==============================] - ETA: 0s - loss: 0.4934 - dice_coef: 0.6300 - iou: 0.4624 - recall_3: 0.7375 - precision_3: 0.8246
# Epoch 2: val_loss improved from 1.21602 to 0.60357, saving model to files/model4.h5
# 252/252 [==============================] - 581s 2s/step - loss: 0.4934 - dice_coef: 0.6300 - iou: 0.4624 - recall_3: 0.7375 - precision_3: 0.8246 - val_loss: 0.6036 - val_dice_coef: 0.5295 - val_iou: 0.3625 - val_recall_3: 0.4834 - val_precision_3: 0.9252 - lr: 1.0000e-04
# Epoch 3/50
# 252/252 [==============================] - ETA: 0s - loss: 0.4203 - dice_coef: 0.6878 - iou: 0.5263 - recall_3: 0.7478 - precision_3: 0.8444
# Epoch 3: val_loss improved from 0.60357 to 0.43462, saving model to files/model4.h5
# 252/252 [==============================] - 583s 2s/step - loss: 0.4203 - dice_coef: 0.6878 - iou: 0.5263 - recall_3: 0.7478 - precision_3: 0.8444 - val_loss: 0.4346 - val_dice_coef: 0.6731 - val_iou: 0.5094 - val_recall_3: 0.7305 - val_precision_3: 0.8347 - lr: 1.0000e-04
# Epoch 4/50
# 252/252 [==============================] - ETA: 0s - loss: 0.3797 - dice_coef: 0.7212 - iou: 0.5661 - recall_3: 0.7515 - precision_3: 0.8549
# Epoch 4: val_loss improved from 0.43462 to 0.40986, saving model to files/model4.h5
# 252/252 [==============================] - 583s 2s/step - loss: 0.3797 - dice_coef: 0.7212 - iou: 0.5661 - recall_3: 0.7515 - precision_3: 0.8549 - val_loss: 0.4099 - val_dice_coef: 0.6973 - val_iou: 0.5372 - val_recall_3: 0.7478 - val_precision_3: 0.8211 - lr: 1.0000e-04
# Epoch 5/50
# 252/252 [==============================] - ETA: 0s - loss: 0.3537 - dice_coef: 0.7430 - iou: 0.5931 - recall_3: 0.7550 - precision_3: 0.8623
# Epoch 5: val_loss did not improve from 0.40986
# 252/252 [==============================] - 580s 2s/step - loss: 0.3537 - dice_coef: 0.7430 - iou: 0.5931 - recall_3: 0.7550 - precision_3: 0.8623 - val_loss: 0.4115 - val_dice_coef: 0.7032 - val_iou: 0.5434 - val_recall_3: 0.7559 - val_precision_3: 0.7823 - lr: 1.0000e-04
# Epoch 6/50
# 252/252 [==============================] - ETA: 0s - loss: 0.3373 - dice_coef: 0.7570 - iou: 0.6111 - recall_3: 0.7570 - precision_3: 0.8673
# Epoch 6: val_loss improved from 0.40986 to 0.38129, saving model to files/model4.h5
# 252/252 [==============================] - 583s 2s/step - loss: 0.3373 - dice_coef: 0.7570 - iou: 0.6111 - recall_3: 0.7570 - precision_3: 0.8673 - val_loss: 0.3813 - val_dice_coef: 0.7231 - val_iou: 0.5682 - val_recall_3: 0.7432 - val_precision_3: 0.8318 - lr: 1.0000e-04
# Epoch 7/50
# 252/252 [==============================] - ETA: 0s - loss: 0.3273 - dice_coef: 0.7659 - iou: 0.6227 - recall_3: 0.7583 - precision_3: 0.8701
# Epoch 7: val_loss improved from 0.38129 to 0.38057, saving model to files/model4.h5
# 252/252 [==============================] - 583s 2s/step - loss: 0.3273 - dice_coef: 0.7659 - iou: 0.6227 - recall_3: 0.7583 - precision_3: 0.8701 - val_loss: 0.3806 - val_dice_coef: 0.7282 - val_iou: 0.5737 - val_recall_3: 0.7630 - val_precision_3: 0.8035 - lr: 1.0000e-04
# Epoch 8/50
# 252/252 [==============================] - ETA: 0s - loss: 0.3207 - dice_coef: 0.7719 - iou: 0.6306 - recall_3: 0.7591 - precision_3: 0.8718
# Epoch 8: val_loss improved from 0.38057 to 0.37288, saving model to files/model4.h5
# 252/252 [==============================] - 583s 2s/step - loss: 0.3207 - dice_coef: 0.7719 - iou: 0.6306 - recall_3: 0.7591 - precision_3: 0.8718 - val_loss: 0.3729 - val_dice_coef: 0.7339 - val_iou: 0.5815 - val_recall_3: 0.7521 - val_precision_3: 0.8123 - lr: 1.0000e-04
# Epoch 9/50
# 252/252 [==============================] - ETA: 0s - loss: 0.3120 - dice_coef: 0.7790 - iou: 0.6400 - recall_3: 0.7621 - precision_3: 0.8756
# Epoch 9: val_loss improved from 0.37288 to 0.36008, saving model to files/model4.h5
# 252/252 [==============================] - 584s 2s/step - loss: 0.3120 - dice_coef: 0.7790 - iou: 0.6400 - recall_3: 0.7621 - precision_3: 0.8756 - val_loss: 0.3601 - val_dice_coef: 0.7453 - val_iou: 0.5959 - val_recall_3: 0.7517 - val_precision_3: 0.8261 - lr: 1.0000e-04
# Epoch 10/50
# 252/252 [==============================] - ETA: 0s - loss: 0.3028 - dice_coef: 0.7862 - iou: 0.6496 - recall_3: 0.7668 - precision_3: 0.8802
# Epoch 10: val_loss improved from 0.36008 to 0.35602, saving model to files/model4.h5
# 252/252 [==============================] - 584s 2s/step - loss: 0.3028 - dice_coef: 0.7862 - iou: 0.6496 - recall_3: 0.7668 - precision_3: 0.8802 - val_loss: 0.3560 - val_dice_coef: 0.7502 - val_iou: 0.6022 - val_recall_3: 0.7585 - val_precision_3: 0.8252 - lr: 1.0000e-04
# Epoch 11/50
# 252/252 [==============================] - ETA: 0s - loss: 0.2976 - dice_coef: 0.7906 - iou: 0.6557 - recall_3: 0.7690 - precision_3: 0.8829
# Epoch 11: val_loss did not improve from 0.35602
# 252/252 [==============================] - 579s 2s/step - loss: 0.2976 - dice_coef: 0.7906 - iou: 0.6557 - recall_3: 0.7690 - precision_3: 0.8829 - val_loss: 0.3790 - val_dice_coef: 0.7369 - val_iou: 0.5857 - val_recall_3: 0.7405 - val_precision_3: 0.8233 - lr: 1.0000e-04
# Epoch 12/50
# 252/252 [==============================] - ETA: 0s - loss: 0.2905 - dice_coef: 0.7961 - iou: 0.6632 - recall_3: 0.7728 - precision_3: 0.8871
# Epoch 12: val_loss did not improve from 0.35602
# 252/252 [==============================] - 580s 2s/step - loss: 0.2905 - dice_coef: 0.7961 - iou: 0.6632 - recall_3: 0.7728 - precision_3: 0.8871 - val_loss: 0.3564 - val_dice_coef: 0.7510 - val_iou: 0.6031 - val_recall_3: 0.7572 - val_precision_3: 0.8292 - lr: 1.0000e-04
# Epoch 13/50
# 252/252 [==============================] - ETA: 0s - loss: 0.2810 - dice_coef: 0.8034 - iou: 0.6733 - recall_3: 0.7780 - precision_3: 0.8932
# Epoch 13: val_loss did not improve from 0.35602
# 252/252 [==============================] - 580s 2s/step - loss: 0.2810 - dice_coef: 0.8034 - iou: 0.6733 - recall_3: 0.7780 - precision_3: 0.8932 - val_loss: 0.3684 - val_dice_coef: 0.7468 - val_iou: 0.5978 - val_recall_3: 0.7489 - val_precision_3: 0.8229 - lr: 1.0000e-04
# Epoch 14/50
# 252/252 [==============================] - ETA: 0s - loss: 0.2753 - dice_coef: 0.8080 - iou: 0.6797 - recall_3: 0.7807 - precision_3: 0.8966
# Epoch 14: val_loss did not improve from 0.35602
# 252/252 [==============================] - 581s 2s/step - loss: 0.2753 - dice_coef: 0.8080 - iou: 0.6797 - recall_3: 0.7807 - precision_3: 0.8966 - val_loss: 0.3713 - val_dice_coef: 0.7445 - val_iou: 0.5949 - val_recall_3: 0.7319 - val_precision_3: 0.8314 - lr: 1.0000e-04
# Epoch 15/50
# 252/252 [==============================] - ETA: 0s - loss: 0.2670 - dice_coef: 0.8142 - iou: 0.6883 - recall_3: 0.7843 - precision_3: 0.9021
# Epoch 15: val_loss did not improve from 0.35602
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 252/252 [==============================] - 581s 2s/step - loss: 0.2670 - dice_coef: 0.8142 - iou: 0.6883 - recall_3: 0.7843 - precision_3: 0.9021 - val_loss: 0.3585 - val_dice_coef: 0.7552 - val_iou: 0.6082 - val_recall_3: 0.7235 - val_precision_3: 0.8496 - lr: 1.0000e-04
# Epoch 16/50
# 252/252 [==============================] - ETA: 0s - loss: 0.2528 - dice_coef: 0.8232 - iou: 0.7012 - recall_3: 0.7913 - precision_3: 0.9102
# Epoch 16: val_loss did not improve from 0.35602
# 252/252 [==============================] - 581s 2s/step - loss: 0.2528 - dice_coef: 0.8232 - iou: 0.7012 - recall_3: 0.7913 - precision_3: 0.9102 - val_loss: 0.3601 - val_dice_coef: 0.7533 - val_iou: 0.6057 - val_recall_3: 0.7299 - val_precision_3: 0.8370 - lr: 1.0000e-05
# Epoch 17/50
# 252/252 [==============================] - ETA: 0s - loss: 0.2418 - dice_coef: 0.8312 - iou: 0.7128 - recall_3: 0.7964 - precision_3: 0.9186
# Epoch 17: val_loss did not improve from 0.35602
# 252/252 [==============================] - 579s 2s/step - loss: 0.2418 - dice_coef: 0.8312 - iou: 0.7128 - recall_3: 0.7964 - precision_3: 0.9186 - val_loss: 0.3613 - val_dice_coef: 0.7541 - val_iou: 0.6069 - val_recall_3: 0.7254 - val_precision_3: 0.8403 - lr: 1.0000e-05
# Epoch 18/50
# 252/252 [==============================] - ETA: 0s - loss: 0.2348 - dice_coef: 0.8365 - iou: 0.7205 - recall_3: 0.7998 - precision_3: 0.9241
# Epoch 18: val_loss did not improve from 0.35602
# 252/252 [==============================] - 579s 2s/step - loss: 0.2348 - dice_coef: 0.8365 - iou: 0.7205 - recall_3: 0.7998 - precision_3: 0.9241 - val_loss: 0.3651 - val_dice_coef: 0.7532 - val_iou: 0.6059 - val_recall_3: 0.7218 - val_precision_3: 0.8404 - lr: 1.0000e-05
# Epoch 19/50
# 252/252 [==============================] - ETA: 0s - loss: 0.2286 - dice_coef: 0.8412 - iou: 0.7274 - recall_3: 0.8027 - precision_3: 0.9290
# Epoch 19: val_loss did not improve from 0.35602
# 252/252 [==============================] - 581s 2s/step - loss: 0.2286 - dice_coef: 0.8412 - iou: 0.7274 - recall_3: 0.8027 - precision_3: 0.9290 - val_loss: 0.3712 - val_dice_coef: 0.7510 - val_iou: 0.6030 - val_recall_3: 0.7188 - val_precision_3: 0.8374 - lr: 1.0000e-05
# Epoch 20/50
# 252/252 [==============================] - ETA: 0s - loss: 0.2227 - dice_coef: 0.8457 - iou: 0.7341 - recall_3: 0.8053 - precision_3: 0.9334
# Epoch 20: val_loss did not improve from 0.35602
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1e-06.
# 252/252 [==============================] - 582s 2s/step - loss: 0.2227 - dice_coef: 0.8457 - iou: 0.7341 - recall_3: 0.8053 - precision_3: 0.9334 - val_loss: 0.3766 - val_dice_coef: 0.7492 - val_iou: 0.6007 - val_recall_3: 0.7157 - val_precision_3: 0.8349 - lr: 1.0000e-05

# %% [markdown]
# ### Evaluating the Model:

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import pandas as pd
import cv2
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import accuracy_score, f1_score, jaccard_score, precision_score, recall_score
from tensorflow.keras.models import load_model

# %%
H = 512
W = 512

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.float32)
    return ori_x, x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.int32)
    return ori_x, x

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.png")))
    y = sorted(glob(os.path.join(path, "mask", "*.png")))
    return x, y

def save_results(ori_x, ori_y, y_pred, save_image_path):
    line = np.ones((H, 10, 3)) * 255

    ori_y = np.expand_dims(ori_y, axis=-1)
    ori_y = np.concatenate([ori_y, ori_y, ori_y], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1) * 255

    cat_images = np.concatenate([ori_x, line, ori_y, line, y_pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model1.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data_512", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score1 = [s[1:] for s in SCORE]
score1 = np.mean(score1, axis=0)
print(f"Accuracy: {score1[0]:0.5f}")
print(f"F1: {score1[1]:0.5f}")
print(f"Jaccard: {score1[2]:0.5f}")
print(f"Recall: {score1[3]:0.5f}")
print(f"Precision: {score1[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score1.csv")
# Out:
# 100%|██████████| 9/9 [00:33<00:00,  3.77s/it]
# Accuracy: 0.96704
# F1: 0.75874
# Jaccard: 0.61291
# Recall: 0.81938
# Precision: 0.71078

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model2.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data_512", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score2 = [s[1:] for s in SCORE]
score2 = np.mean(score2, axis=0)
print(f"Accuracy: {score2[0]:0.5f}")
print(f"F1: {score2[1]:0.5f}")
print(f"Jaccard: {score2[2]:0.5f}")
print(f"Recall: {score2[3]:0.5f}")
print(f"Precision: {score2[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score2.csv")
# Out:
# 100%|██████████| 9/9 [00:04<00:00,  1.99it/s]
# Accuracy: 0.96806
# F1: 0.76410
# Jaccard: 0.62008
# Recall: 0.81789
# Precision: 0.72142

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model3.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data_512", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score3 = [s[1:] for s in SCORE]
score3 = np.mean(score3, axis=0)
print(f"Accuracy: {score3[0]:0.5f}")
print(f"F1: {score3[1]:0.5f}")
print(f"Jaccard: {score3[2]:0.5f}")
print(f"Recall: {score3[3]:0.5f}")
print(f"Precision: {score3[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score3.csv")
# Out:
# 100%|██████████| 9/9 [00:12<00:00,  1.40s/it]
# Accuracy: 0.96870
# F1: 0.77222
# Jaccard: 0.63084
# Recall: 0.83847
# Precision: 0.72039

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model4.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data_512", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score4 = [s[1:] for s in SCORE]
score4 = np.mean(score4, axis=0)
print(f"Accuracy: {score4[0]:0.5f}")
print(f"F1: {score4[1]:0.5f}")
print(f"Jaccard: {score4[2]:0.5f}")
print(f"Recall: {score4[3]:0.5f}")
print(f"Precision: {score4[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score4.csv")
# Out:
# 100%|██████████| 9/9 [00:25<00:00,  2.84s/it]
# Accuracy: 0.96559
# F1: 0.75637
# Jaccard: 0.61059
# Recall: 0.84418
# Precision: 0.68915

# %%
import matplotlib.pyplot as plt

z_dim = [16, 32, 64, 128]
final_score = [score1[1], score2[1], score3[1], score4[1]]

plt.plot(z_dim, final_score)  
plt.xlabel("Feature Map Dimension")
plt.ylabel("F1-score")
plt.show()

# %%
print(score1)
# Out:
# [0.96704017 0.75874217 0.61291443 0.81938243 0.71078095]

# %%
print(score2)
# Out:
# [0.96806251 0.76410065 0.62007984 0.81788729 0.72142278]

# %%
print(score3)
# Out:
# [0.96870253 0.77222427 0.63083778 0.83847251 0.72038558]

# %%
print(score4)
# Out:
# [0.96559397 0.75636814 0.61059166 0.84417777 0.68914743]
