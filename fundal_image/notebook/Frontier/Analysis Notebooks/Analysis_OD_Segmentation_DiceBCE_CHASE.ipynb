# %% [markdown]
# ### Import the required libraries and modules:

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
import numpy as np

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# %cd /content/gdrive/MyDrive/Blood_Vessel_Results/ALL_BEST_RESULTS/CHASE_OD_3
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/Blood_Vessel_Results/ALL_BEST_RESULTS/CHASE_OD_3

# %% [markdown]
# ### Unzip the data:

# %%
# !unzip new_data.zip

# %% [markdown]
# ### Construct the Model:

# %%
def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(inputs, num_filters, strides=2):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D(strides)(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters, strides=2):
    x = Conv2DTranspose(num_filters, (2, 2), strides=strides, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape, num_filters=[64, 128, 256, 512, 1024], strides=[2, 2, 2, 2]):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, num_filters[0], strides=strides[0])
    s2, p2 = encoder_block(p1, num_filters[1], strides=strides[1])
    s3, p3 = encoder_block(p2, num_filters[2], strides=strides[2])
    s4, p4 = encoder_block(p3, num_filters[3], strides=strides[3])

    b1 = conv_block(p4, num_filters[4])

    d1 = decoder_block(b1, s4, num_filters[3], strides=strides[3])
    d2 = decoder_block(d1, s3, num_filters[2], strides=strides[2])
    d3 = decoder_block(d2, s2, num_filters[1], strides=strides[1])
    d4 = decoder_block(d3, s1, num_filters[0], strides=strides[0])

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="UNET")
    return model

input_shape = (512, 512, 3)
model = build_unet(input_shape)
model.summary()
# Out:
# Model: "UNET"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 512, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 512, 512, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 512, 512, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 512, 512, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 12  0          ['activation_3[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 25  295168      ['max_pooling2d_1[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_4[0][0]']
#  rmalization)                   6)
#
#  activation_4 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_4[0][0]']
#                                 6)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 25  590080      ['activation_4[0][0]']
#                                 6)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_5[0][0]']
#  rmalization)                   6)
#
#  activation_5 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_5[0][0]']
#                                 6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 512)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 512)  2097664    ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 64, 64, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 25  524544     ['activation_11[0][0]']
#  spose)                         6)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 51  0           ['conv2d_transpose_1[0][0]',
#                                 2)                                'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_12 (BatchN  (None, 128, 128, 25  1024       ['conv2d_12[0][0]']
#  ormalization)                  6)
#
#  activation_12 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_12[0][0]']
#                                 6)
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 25  590080      ['activation_12[0][0]']
#                                 6)
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 25  1024       ['conv2d_13[0][0]']
#  ormalization)                  6)
#
#  activation_13 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_13[0][0]']
#                                 6)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 12  131200     ['activation_13[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 256, 256, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  activation_14 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_15 (BatchN  (None, 256, 256, 12  512        ['conv2d_15[0][0]']
#  ormalization)                  8)
#
#  activation_15 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_15[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 64  32832      ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 512, 512, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 512, 512, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 512, 512, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 512, 512, 1)  65          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %% [markdown]
# ### Adding the Metrics:

# %%
def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def DiceBCELoss(y_true, y_pred):

    inputs = tf.keras.layers.Flatten()(y_true)
    targets = tf.keras.layers.Flatten()(y_pred)

    intersection = tf.reduce_sum(inputs * targets)
    dice_loss = 1 - (2.*intersection + smooth)/(tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)
    BCE = tf.keras.losses.BinaryCrossentropy()
    Dice_BCE = BCE(inputs, targets) + dice_loss

    return Dice_BCE

# %% [markdown]
# ### Training the Model:

# %%
H = 512
W = 512

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.png")))
    y = sorted(glob(os.path.join(path, "mask", "*.png")))
    return x, y

def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)
    return x, y

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)              ## (512, 512, 1)
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y, batch_size=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(4)
    return dataset

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 8
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model1.h5")
csv_path = os.path.join("files", "data1.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model1 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 1024], strides=[2, 2, 2, 4])

model1.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model1.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 161 - 161
# Valid: 5 - 5
# Epoch 1/50
# 21/21 [==============================] - ETA: 0s - loss: 1.3746 - dice_coef: 0.0504 - iou: 0.0259 - recall: 0.7324 - precision: 0.0778
# Epoch 1: val_loss improved from inf to 1.66867, saving model to files/model1.h5
# 21/21 [==============================] - 88s 3s/step - loss: 1.3746 - dice_coef: 0.0504 - iou: 0.0259 - recall: 0.7324 - precision: 0.0778 - val_loss: 1.6687 - val_dice_coef: 0.0274 - val_iou: 0.0139 - val_recall: 0.0839 - val_precision: 0.0024 - lr: 1.0000e-04
# Epoch 2/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0964 - dice_coef: 0.1022 - iou: 0.0539 - recall: 0.7783 - precision: 0.4834
# Epoch 2: val_loss improved from 1.66867 to 1.63121, saving model to files/model1.h5
# 21/21 [==============================] - 20s 966ms/step - loss: 1.0964 - dice_coef: 0.1022 - iou: 0.0539 - recall: 0.7783 - precision: 0.4834 - val_loss: 1.6312 - val_dice_coef: 0.0272 - val_iou: 0.0138 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 
# 21/21 [==============================] - 18s 828ms/step - loss: 0.2684 - dice_coef: 0.7379 - iou: 0.5853 - recall: 0.9747 - precision: 0.9741 - val_loss: 0.4039 - val_dice_coef: 0.6237 - val_iou: 0.4532 - val_recall: 0.6694 - val_precision: 0.9786 - lr: 1.0000e-06

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 8
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model2.h5")
csv_path = os.path.join("files", "data2.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model2 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 1024], strides=[2, 2, 2, 2])

model2.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model2.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 161 - 161
# Valid: 5 - 5
# Epoch 1/50
# 21/21 [==============================] - ETA: 0s - loss: 1.3735 - dice_coef: 0.0510 - iou: 0.0262 - recall_1: 0.7383 - precision_1: 0.0786
# Epoch 1: val_loss improved from inf to 1.66860, saving model to files/model2.h5
# 21/21 [==============================] - 25s 989ms/step - loss: 1.3735 - dice_coef: 0.0510 - iou: 0.0262 - recall_1: 0.7383 - precision_1: 0.0786 - val_loss: 1.6686 - val_dice_coef: 0.0274 - val_iou: 0.0139 - val_recall_1: 0.0836 - val_precision_1: 0.0024 - lr: 1.0000e-04
# Epoch 2/50
# 21/21 [==============================] - ETA: 0s - loss: 1.0948 - dice_coef: 0.1022 - iou: 0.0539 - recall_1: 0.7744 - precision_1: 0.4907
# Epoch 2: val_loss improved from 1.66860 to 1.65604, saving model to files/model2.h5
# 21/21 [==============================] - 21s 1s/step - loss: 1.0948 - dice_coef: 0.1022 - iou: 0.0539 - recall_1: 0.7744 - precision_1: 0.4907 - val_loss: 1.6560 - val_dice_coef: 0.0275 - val_iou: 0.0140 - val_recall_1: 0.2962 - val_precision_1: 0.0133 - lr: 1.0000e-04
# Epoch 3/50
# Epoch 47/50
# 21/21 [==============================] - ETA: 0s - loss: 0.2785 - dice_coef: 0.7282 - iou: 0.5732 - recall_1: 0.9730 - precision_1: 0.9749
# Epoch 47: val_loss did not improve from 0.48081
# 21/21 [==============================] - 18s 868ms/step - loss: 0.2785 - dice_coef: 0.7282 - iou: 0.5732 - recall_1: 0.9730 - precision_1: 0.9749 - val_loss: 0.5116 - val_dice_coef: 0.5252 - val_iou: 0.3562 - val_recall_1: 0.5476 - val_precision_1: 0.9239 - lr: 1.0000e-05
# Epoch 48/50
# 21/21 [==============================] - ETA: 0s - loss: 0.2762 - dice_coef: 0.7303 - iou: 0.5759 - recall_1: 0.9740 - precision_1: 0.9770
# Epoch 48: val_loss did not improve from 0.48081
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1e-06.
# 21/21 [==============================] - 18s 868ms/step - loss: 0.2762 - dice_coef: 0.7303 - iou: 0.5759 - recall_1: 0.9740 - precision_1: 0.9770 - val_loss: 0.5174 - val_dice_coef: 0.5200 - val_iou: 0.3513 - val_recall_1: 0.5357 - val_precision_1: 0.9311 - lr: 1.0000e-05
# Epoch 49/50
# 21/21 [==============================] - ETA: 0s - loss: 0.2741 - dice_coef: 0.7323 - iou: 0.5783 - recall_1: 0.9783 - precision_1: 0.9774
# Epoch 49: val_loss did not improve from 0.48081
# 21/21 [==============================] - 18s 868ms/step - loss: 0.2741 - dice_coef: 0.7323 - iou: 0.5783 - recall_1: 0.9783 - precision_1: 0.9774 - val_loss: 0.5187 - val_dice_coef: 0.5189 - val_iou: 0.3504 - val_recall_1: 0.5326 - val_precision_1: 0.9341 - lr: 1.0000e-06
# Epoch 50/50
# 21/21 [==============================] - ETA: 0s - loss: 0.2738 - dice_coef: 0.7325 - iou: 0.5786 - recall_1: 0.9770 - precision_1: 0.9790
# Epoch 50: val_loss did not improve from 0.48081
# 21/21 [==============================] - 18s 868ms/step - loss: 0.2738 - dice_coef: 0.7325 - iou: 0.5786 - recall_1: 0.9770 - precision_1: 0.9790 - val_loss: 0.5202 - val_dice_coef: 0.5177 - val_iou: 0.3493 - val_recall_1: 0.5294 - val_precision_1: 0.9360 - lr: 1.0000e-06

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 2
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model3.h5")
csv_path = os.path.join("files", "data3.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model3 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 1024], strides=[1, 2, 2, 2])

model3.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model3.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 161 - 161
# Valid: 5 - 5
# Epoch 1/50
# 81/81 [==============================] - ETA: 0s - loss: 1.1316 - dice_coef: 0.1003 - iou: 0.0532 - recall_2: 0.7583 - precision_2: 0.2028
# Epoch 1: val_loss improved from inf to 3.18809, saving model to files/model3.h5
# 81/81 [==============================] - 73s 774ms/step - loss: 1.1316 - dice_coef: 0.1003 - iou: 0.0532 - recall_2: 0.7583 - precision_2: 0.2028 - val_loss: 3.1881 - val_dice_coef: 0.0268 - val_iou: 0.0136 - val_recall_2: 1.0000 - val_precision_2: 0.0150 - lr: 1.0000e-04
# Epoch 2/50
# 81/81 [==============================] - ETA: 0s - loss: 0.9426 - dice_coef: 0.1710 - iou: 0.0939 - recall_2: 0.8322 - precision_2: 0.4725
# Epoch 2: val_loss improved from 3.18809 to 1.14218, saving model to files/model3.h5
# 81/81 [==============================] - 60s 740ms/step - loss: 0.9426 - dice_coef: 0.1710 - iou: 0.0939 - recall_2: 0.8322 - precision_2: 0.4725 - val_loss: 1.1422 - val_dice_coef: 0.0287 - val_iou: 0.0146 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 3/50
# 81/81 [==============================] - ETA: 0s - loss: 0.8840 - dice_coef: 0.2096 - iou: 0.1176 - recall_2: 0.8483 - precision_2: 0.5179
# Epoch 3: val_loss improved from 1.14218 to 1.09245, saving model to files/model3.h5
# 81/81 [==============================] - 61s 740ms/step - loss: 0.8840 - dice_coef: 0.2096 - iou: 0.1176 - recall_2: 0.8483 - precision_2: 0.5179 - val_loss: 1.0924 - val_dice_coef: 0.0249 - val_iou: 0.0126 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 4/50
# 81/81 [==============================] - ETA: 0s - loss: 0.8246 - dice_coef: 0.2509 - iou: 0.1440 - recall_2: 0.8630 - precision_2: 0.5454
# Epoch 4: val_loss improved from 1.09245 to 1.07576, saving model to files/model3.h5
# 81/81 [==============================] - 60s 741ms/step - loss: 0.8246 - dice_coef: 0.2509 - iou: 0.1440 - recall_2: 0.8630 - precision_2: 0.5454 - val_loss: 1.0758 - val_dice_coef: 0.0239 - val_iou: 0.0121 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 5/50
# 81/81 [==============================] - ETA: 0s - loss: 0.7730 - dice_coef: 0.2937 - iou: 0.1730 - recall_2: 0.8725 - precision_2: 0.5839
# Epoch 5: val_loss improved from 1.07576 to 1.06445, saving model to files/model3.h5
# 81/81 [==============================] - 60s 742ms/step - loss: 0.7730 - dice_coef: 0.2937 - iou: 0.1730 - recall_2: 0.8725 - precision_2: 0.5839 - val_loss: 1.0645 - val_dice_coef: 0.0223 - val_iou: 0.0113 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 6/50
# 81/81 [==============================] - ETA: 0s - loss: 0.7112 - dice_coef: 0.3420 - iou: 0.2072 - recall_2: 0.8765 - precision_2: 0.6245
# Epoch 6: val_loss improved from 1.06445 to 1.04814, saving model to files/model3.h5
# 81/81 [==============================] - 60s 740ms/step - loss: 0.7112 - dice_coef: 0.3420 - iou: 0.2072 - recall_2: 0.8765 - precision_2: 0.6245 - val_loss: 1.0481 - val_dice_coef: 0.0289 - val_iou: 0.0147 - val_recall_2: 0.0049 - val_precision_2: 1.0000 - lr: 1.0000e-04
# Epoch 7/50
# 81/81 [==============================] - ETA: 0s - loss: 0.6561 - dice_coef: 0.3892 - iou: 0.2428 - recall_2: 0.8759 - precision_2: 0.6542
# Epoch 7: val_loss improved from 1.04814 to 0.81408, saving model to files/model3.h5
# 81/81 [==============================] - 61s 749ms/step - loss: 0.6561 - dice_coef: 0.3892 - iou: 0.2428 - recall_2: 0.8759 - precision_2: 0.6542 - val_loss: 0.8141 - val_dice_coef: 0.2065 - val_iou: 0.1202 - val_recall_2: 0.3733 - val_precision_2: 0.9763 - lr: 1.0000e-04
# Epoch 8/50
# 81/81 [==============================] - ETA: 0s - loss: 0.6024 - dice_coef: 0.4365 - iou: 0.2807 - recall_2: 0.8677 - precision_2: 0.6803
# Epoch 8: val_loss improved from 0.81408 to 0.60259, saving model to files/model3.h5
# 81/81 [==============================] - 61s 752ms/step - loss: 0.6024 - dice_coef: 0.4365 - iou: 0.2807 - recall_2: 0.8677 - precision_2: 0.6803 - val_loss: 0.6026 - val_dice_coef: 0.4242 - val_iou: 0.2708 - val_recall_2: 0.6872 - val_precision_2: 0.8105 - lr: 1.0000e-04
# Epoch 9/50
# 81/81 [==============================] - ETA: 0s - loss: 0.5523 - dice_coef: 0.4835 - iou: 0.3206 - recall_2: 0.8763 - precision_2: 0.6955
# Epoch 9: val_loss did not improve from 0.60259
# 81/81 [==============================] - 57s 701ms/step - loss: 0.5523 - dice_coef: 0.4835 - iou: 0.3206 - recall_2: 0.8763 - precision_2: 0.6955 - val_loss: 0.6695 - val_dice_coef: 0.4312 - val_iou: 0.2785 - val_recall_2: 0.8772 - val_precision_2: 0.3732 - lr: 1.0000e-04
# Epoch 10/50
# 81/81 [==============================] - ETA: 0s - loss: 0.5061 - dice_coef: 0.5253 - iou: 0.3580 - recall_2: 0.8573 - precision_2: 0.7207
# Epoch 10: val_loss did not improve from 0.60259
# 81/81 [==============================] - 57s 701ms/step - loss: 0.5061 - dice_coef: 0.5253 - iou: 0.3580 - recall_2: 0.8573 - precision_2: 0.7207 - val_loss: 0.7830 - val_dice_coef: 0.3502 - val_iou: 0.2218 - val_recall_2: 0.7296 - val_precision_2: 0.2121 - lr: 1.0000e-04
# Epoch 11/50
# 81/81 [==============================] - ETA: 0s - loss: 0.4574 - dice_coef: 0.5709 - iou: 0.4013 - recall_2: 0.8592 - precision_2: 0.7422
# Epoch 11: val_loss improved from 0.60259 to 0.53593, saving model to files/model3.h5
# 81/81 [==============================] - 60s 741ms/step - loss: 0.4574 - dice_coef: 0.5709 - iou: 0.4013 - recall_2: 0.8592 - precision_2: 0.7422 - val_loss: 0.5359 - val_dice_coef: 0.5101 - val_iou: 0.3512 - val_recall_2: 0.7970 - val_precision_2: 0.4971 - lr: 1.0000e-04
# Epoch 12/50
# 81/81 [==============================] - ETA: 0s - loss: 0.4121 - dice_coef: 0.6125 - iou: 0.4434 - recall_2: 0.8579 - precision_2: 0.7720
# Epoch 12: val_loss did not improve from 0.53593
# 81/81 [==============================] - 57s 701ms/step - loss: 0.4121 - dice_coef: 0.6125 - iou: 0.4434 - recall_2: 0.8579 - precision_2: 0.7720 - val_loss: 0.7004 - val_dice_coef: 0.3033 - val_iou: 0.2027 - val_recall_2: 0.4663 - val_precision_2: 0.4880 - lr: 1.0000e-04
# Epoch 13/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3811 - dice_coef: 0.6424 - iou: 0.4753 - recall_2: 0.8564 - precision_2: 0.7704
# Epoch 13: val_loss did not improve from 0.53593
# 81/81 [==============================] - 57s 701ms/step - loss: 0.3811 - dice_coef: 0.6424 - iou: 0.4753 - recall_2: 0.8564 - precision_2: 0.7704 - val_loss: 0.5988 - val_dice_coef: 0.4191 - val_iou: 0.2808 - val_recall_2: 0.4201 - val_precision_2: 0.9561 - lr: 1.0000e-04
# Epoch 14/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3527 - dice_coef: 0.6695 - iou: 0.5053 - recall_2: 0.8555 - precision_2: 0.7795
# Epoch 14: val_loss did not improve from 0.53593
# 81/81 [==============================] - 57s 701ms/step - loss: 0.3527 - dice_coef: 0.6695 - iou: 0.5053 - recall_2: 0.8555 - precision_2: 0.7795 - val_loss: 1.0076 - val_dice_coef: 0.0543 - val_iou: 0.0283 - val_recall_2: 0.0228 - val_precision_2: 1.0000 - lr: 1.0000e-04
# Epoch 15/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3253 - dice_coef: 0.6956 - iou: 0.5357 - recall_2: 0.8500 - precision_2: 0.8037
# Epoch 15: val_loss did not improve from 0.53593
# 81/81 [==============================] - 57s 701ms/step - loss: 0.3253 - dice_coef: 0.6956 - iou: 0.5357 - recall_2: 0.8500 - precision_2: 0.8037 - val_loss: 0.7836 - val_dice_coef: 0.2336 - val_iou: 0.1413 - val_recall_2: 0.2102 - val_precision_2: 0.9874 - lr: 1.0000e-04
# Epoch 16/50
# 81/81 [==============================] - ETA: 0s - loss: 0.2998 - dice_coef: 0.7200 - iou: 0.5647 - recall_2: 0.8506 - precision_2: 0.8151
# Epoch 16: val_loss improved from 0.53593 to 0.41462, saving model to files/model3.h5
# 81/81 [==============================] - 60s 740ms/step - loss: 0.2998 - dice_coef: 0.7200 - iou: 0.5647 - recall_2: 0.8506 - precision_2: 0.8151 - val_loss: 0.4146 - val_dice_coef: 0.5724 - val_iou: 0.4184 - val_recall_2: 0.5705 - val_precision_2: 0.9444 - lr: 1.0000e-04
# Epoch 17/50
# 81/81 [==============================] - ETA: 0s - loss: 0.2671 - dice_coef: 0.7503 - iou: 0.6022 - recall_2: 0.8578 - precision_2: 0.8418
# Epoch 17: val_loss did not improve from 0.41462
# 81/81 [==============================] - 57s 701ms/step - loss: 0.2671 - dice_coef: 0.7503 - iou: 0.6022 - recall_2: 0.8578 - precision_2: 0.8418 - val_loss: 0.5311 - val_dice_coef: 0.4966 - val_iou: 0.3325 - val_recall_2: 0.3989 - val_precision_2: 0.9955 - lr: 1.0000e-04
# Epoch 18/50
# 81/81 [==============================] - ETA: 0s - loss: 0.2397 - dice_coef: 0.7759 - iou: 0.6356 - recall_2: 0.8680 - precision_2: 0.8598
# Epoch 18: val_loss did not improve from 0.41462
# 81/81 [==============================] - 57s 701ms/step - loss: 0.2397 - dice_coef: 0.7759 - iou: 0.6356 - recall_2: 0.8680 - precision_2: 0.8598 - val_loss: 1.0313 - val_dice_coef: 0.0432 - val_iou: 0.0228 - val_recall_2: 0.0279 - val_precision_2: 1.0000 - lr: 1.0000e-04
# Epoch 19/50
# 81/81 [==============================] - ETA: 0s - loss: 0.2185 - dice_coef: 0.7961 - iou: 0.6628 - recall_2: 0.8771 - precision_2: 0.8695
# Epoch 19: val_loss did not improve from 0.41462
# 81/81 [==============================] - 57s 701ms/step - loss: 0.2185 - dice_coef: 0.7961 - iou: 0.6628 - recall_2: 0.8771 - precision_2: 0.8695 - val_loss: 0.5030 - val_dice_coef: 0.5165 - val_iou: 0.3535 - val_recall_2: 0.4129 - val_precision_2: 0.9996 - lr: 1.0000e-04
# Epoch 20/50
# 81/81 [==============================] - ETA: 0s - loss: 0.2128 - dice_coef: 0.8013 - iou: 0.6699 - recall_2: 0.8669 - precision_2: 0.8713
# Epoch 20: val_loss did not improve from 0.41462
# 81/81 [==============================] - 57s 701ms/step - loss: 0.2128 - dice_coef: 0.8013 - iou: 0.6699 - recall_2: 0.8669 - precision_2: 0.8713 - val_loss: 0.7807 - val_dice_coef: 0.2721 - val_iou: 0.1628 - val_recall_2: 0.1909 - val_precision_2: 1.0000 - lr: 1.0000e-04
# Epoch 21/50
# 81/81 [==============================] - ETA: 0s - loss: 0.2023 - dice_coef: 0.8122 - iou: 0.6853 - recall_2: 0.8726 - precision_2: 0.8729
# Epoch 21: val_loss did not improve from 0.41462
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 81/81 [==============================] - 57s 701ms/step - loss: 0.2023 - dice_coef: 0.8122 - iou: 0.6853 - recall_2: 0.8726 - precision_2: 0.8729 - val_loss: 0.5075 - val_dice_coef: 0.4851 - val_iou: 0.3403 - val_recall_2: 0.4092 - val_precision_2: 1.0000 - lr: 1.0000e-04
# Epoch 22/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1741 - dice_coef: 0.8374 - iou: 0.7216 - recall_2: 0.8795 - precision_2: 0.9109
# Epoch 22: val_loss improved from 0.41462 to 0.39437, saving model to files/model3.h5
# 81/81 [==============================] - 60s 741ms/step - loss: 0.1741 - dice_coef: 0.8374 - iou: 0.7216 - recall_2: 0.8795 - precision_2: 0.9109 - val_loss: 0.3944 - val_dice_coef: 0.6094 - val_iou: 0.4484 - val_recall_2: 0.5173 - val_precision_2: 0.9959 - lr: 1.0000e-05
# Epoch 23/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1582 - dice_coef: 0.8515 - iou: 0.7426 - recall_2: 0.8989 - precision_2: 0.9209
# Epoch 23: val_loss improved from 0.39437 to 0.38476, saving model to files/model3.h5
# 81/81 [==============================] - 62s 751ms/step - loss: 0.1582 - dice_coef: 0.8515 - iou: 0.7426 - recall_2: 0.8989 - precision_2: 0.9209 - val_loss: 0.3848 - val_dice_coef: 0.6201 - val_iou: 0.4586 - val_recall_2: 0.5502 - val_precision_2: 0.9259 - lr: 1.0000e-05
# Epoch 24/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1516 - dice_coef: 0.8576 - iou: 0.7517 - recall_2: 0.9037 - precision_2: 0.9274
# Epoch 24: val_loss did not improve from 0.38476
# 81/81 [==============================] - 57s 701ms/step - loss: 0.1516 - dice_coef: 0.8576 - iou: 0.7517 - recall_2: 0.9037 - precision_2: 0.9274 - val_loss: 0.3863 - val_dice_coef: 0.6207 - val_iou: 0.4587 - val_recall_2: 0.5644 - val_precision_2: 0.8853 - lr: 1.0000e-05
# Epoch 25/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1463 - dice_coef: 0.8624 - iou: 0.7591 - recall_2: 0.9074 - precision_2: 0.9325
# Epoch 25: val_loss did not improve from 0.38476
# 81/81 [==============================] - 57s 701ms/step - loss: 0.1463 - dice_coef: 0.8624 - iou: 0.7591 - recall_2: 0.9074 - precision_2: 0.9325 - val_loss: 0.3877 - val_dice_coef: 0.6206 - val_iou: 0.4585 - val_recall_2: 0.5729 - val_precision_2: 0.8656 - lr: 1.0000e-05
# Epoch 26/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1417 - dice_coef: 0.8667 - iou: 0.7656 - recall_2: 0.9108 - precision_2: 0.9366
# Epoch 26: val_loss did not improve from 0.38476
# 81/81 [==============================] - 57s 701ms/step - loss: 0.1417 - dice_coef: 0.8667 - iou: 0.7656 - recall_2: 0.9108 - precision_2: 0.9366 - val_loss: 0.3890 - val_dice_coef: 0.6203 - val_iou: 0.4582 - val_recall_2: 0.5783 - val_precision_2: 0.8494 - lr: 1.0000e-05
# Epoch 27/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1375 - dice_coef: 0.8706 - iou: 0.7717 - recall_2: 0.9137 - precision_2: 0.9401
# Epoch 27: val_loss did not improve from 0.38476
# 81/81 [==============================] - 57s 701ms/step - loss: 0.1375 - dice_coef: 0.8706 - iou: 0.7717 - recall_2: 0.9137 - precision_2: 0.9401 - val_loss: 0.3895 - val_dice_coef: 0.6200 - val_iou: 0.4582 - val_recall_2: 0.5820 - val_precision_2: 0.8425 - lr: 1.0000e-05
# Epoch 28/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1334 - dice_coef: 0.8743 - iou: 0.7776 - recall_2: 0.9166 - precision_2: 0.9433
# Epoch 28: val_loss did not improve from 0.38476
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1e-06.
# 81/81 [==============================] - 57s 701ms/step - loss: 0.1334 - dice_coef: 0.8743 - iou: 0.7776 - recall_2: 0.9166 - precision_2: 0.9433 - val_loss: 0.3930 - val_dice_coef: 0.6171 - val_iou: 0.4555 - val_recall_2: 0.5830 - val_precision_2: 0.8255 - lr: 1.0000e-05
# Epoch 29/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1288 - dice_coef: 0.8785 - iou: 0.7841 - recall_2: 0.9190 - precision_2: 0.9483
# Epoch 29: val_loss did not improve from 0.38476
# 81/81 [==============================] - 57s 701ms/step - loss: 0.1288 - dice_coef: 0.8785 - iou: 0.7841 - recall_2: 0.9190 - precision_2: 0.9483 - val_loss: 0.3965 - val_dice_coef: 0.6194 - val_iou: 0.4576 - val_recall_2: 0.6059 - val_precision_2: 0.7657 - lr: 1.0000e-06
# Epoch 30/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1280 - dice_coef: 0.8792 - iou: 0.7853 - recall_2: 0.9213 - precision_2: 0.9477
# Epoch 30: val_loss did not improve from 0.38476
# 81/81 [==============================] - 57s 702ms/step - loss: 0.1280 - dice_coef: 0.8792 - iou: 0.7853 - recall_2: 0.9213 - precision_2: 0.9477 - val_loss: 0.4019 - val_dice_coef: 0.6173 - val_iou: 0.4557 - val_recall_2: 0.6136 - val_precision_2: 0.7398 - lr: 1.0000e-06
# Epoch 31/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1275 - dice_coef: 0.8797 - iou: 0.7861 - recall_2: 0.9223 - precision_2: 0.9476
# Epoch 31: val_loss did not improve from 0.38476
# 81/81 [==============================] - 57s 701ms/step - loss: 0.1275 - dice_coef: 0.8797 - iou: 0.7861 - recall_2: 0.9223 - precision_2: 0.9476 - val_loss: 0.4055 - val_dice_coef: 0.6154 - val_iou: 0.4539 - val_recall_2: 0.6160 - val_precision_2: 0.7260 - lr: 1.0000e-06
# Epoch 32/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1269 - dice_coef: 0.8802 - iou: 0.7869 - recall_2: 0.9229 - precision_2: 0.9480
# Epoch 32: val_loss did not improve from 0.38476
# 81/81 [==============================] - 57s 701ms/step - loss: 0.1269 - dice_coef: 0.8802 - iou: 0.7869 - recall_2: 0.9229 - precision_2: 0.9480 - val_loss: 0.4079 - val_dice_coef: 0.6139 - val_iou: 0.4524 - val_recall_2: 0.6168 - val_precision_2: 0.7193 - lr: 1.0000e-06
# Epoch 33/50
# 81/81 [==============================] - ETA: 0s - loss: 0.1264 - dice_coef: 0.8806 - iou: 0.7876 - recall_2: 0.9233 - precision_2: 0.9483
# Epoch 33: val_loss did not improve from 0.38476
# 81/81 [==============================] - 57s 701ms/step - loss: 0.1264 - dice_coef: 0.8806 - iou: 0.7876 - recall_2: 0.9233 - precision_2: 0.9483 - val_loss: 0.4097 - val_dice_coef: 0.6127 - val_iou: 0.4513 - val_recall_2: 0.6170 - val_precision_2: 0.7151 - lr: 1.0000e-06

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 1
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model4.h5")
csv_path = os.path.join("files", "data4.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model4 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 1024], strides=[1, 1, 2, 2])

model4.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model4.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 161 - 161
# Valid: 5 - 5
# Epoch 1/50
# 161/161 [==============================] - ETA: 0s - loss: 1.0512 - dice_coef: 0.1299 - iou: 0.0704 - recall_3: 0.7735 - precision_3: 0.2882
# Epoch 1: val_loss improved from inf to 1.12886, saving model to files/model4.h5
# 161/161 [==============================] - 169s 981ms/step - loss: 1.0512 - dice_coef: 0.1299 - iou: 0.0704 - recall_3: 0.7735 - precision_3: 0.2882 - val_loss: 1.1289 - val_dice_coef: 0.0284 - val_iou: 0.0144 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00 - lr: 1.0000e-04
# Epoch 2/50
# 161/161 [==============================] - ETA: 0s - loss: 0.8728 - dice_coef: 0.2205 - iou: 0.1250 - recall_3: 0.8428 - precision_3: 0.4920
# Epoch 2: val_loss improved from 1.12886 to 1.07915, saving model to files/model4.h5
# 161/161 [==============================] - 159s 989ms/step - loss: 0.8728 - dice_coef: 0.2205 - iou: 0.1250 - recall_3: 0.8428 - precision_3: 0.4920 - val_loss: 1.0792 - val_dice_coef: 0.0268 - val_iou: 0.0136 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00 - lr: 1.0000e-04
# Epoch 3/50
# 161/161 [==============================] - ETA: 0s - loss: 0.7571 - dice_coef: 0.3052 - iou: 0.1819 - recall_3: 0.8516 - precision_3: 0.5831
# Epoch 3: val_loss improved from 1.07915 to 1.07693, saving model to files/model4.h5
# 161/161 [==============================] - 159s 988ms/step - loss: 0.7571 - dice_coef: 0.3052 - iou: 0.1819 - recall_3: 0.8516 - precision_3: 0.5831 - val_loss: 1.0769 - val_dice_coef: 0.0155 - val_iou: 0.0078 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00 - lr: 1.0000e-04
# Epoch 4/50
# 161/161 [==============================] - ETA: 0s - loss: 0.6850 - dice_coef: 0.3727 - iou: 0.2314 - recall_3: 0.8333 - precision_3: 0.5871
# Epoch 4: val_loss improved from 1.07693 to 1.01859, saving model to files/model4.h5
# 161/161 [==============================] - 160s 990ms/step - loss: 0.6850 - dice_coef: 0.3727 - iou: 0.2314 - recall_3: 0.8333 - precision_3: 0.5871 - val_loss: 1.0186 - val_dice_coef: 0.0802 - val_iou: 0.0431 - val_recall_3: 0.2047 - val_precision_3: 0.1429 - lr: 1.0000e-04
# Epoch 5/50
# 161/161 [==============================] - ETA: 0s - loss: 0.5905 - dice_coef: 0.4512 - iou: 0.2942 - recall_3: 0.8121 - precision_3: 0.6345
# Epoch 5: val_loss did not improve from 1.01859
# 161/161 [==============================] - 156s 967ms/step - loss: 0.5905 - dice_coef: 0.4512 - iou: 0.2942 - recall_3: 0.8121 - precision_3: 0.6345 - val_loss: 2.6631 - val_dice_coef: 0.1197 - val_iou: 0.0645 - val_recall_3: 0.9927 - val_precision_3: 0.0595 - lr: 1.0000e-04
# Epoch 6/50
# 161/161 [==============================] - ETA: 0s - loss: 0.5005 - dice_coef: 0.5333 - iou: 0.3670 - recall_3: 0.8030 - precision_3: 0.6875
# Epoch 6: val_loss improved from 1.01859 to 0.88811, saving model to files/model4.h5
# 161/161 [==============================] - 159s 988ms/step - loss: 0.5005 - dice_coef: 0.5333 - iou: 0.3670 - recall_3: 0.8030 - precision_3: 0.6875 - val_loss: 0.8881 - val_dice_coef: 0.2083 - val_iou: 0.1221 - val_recall_3: 0.4682 - val_precision_3: 0.2065 - lr: 1.0000e-04
# Epoch 7/50
# 161/161 [==============================] - ETA: 0s - loss: 0.4243 - dice_coef: 0.6035 - iou: 0.4360 - recall_3: 0.7948 - precision_3: 0.7323
# Epoch 7: val_loss improved from 0.88811 to 0.71820, saving model to files/model4.h5
# 161/161 [==============================] - 160s 990ms/step - loss: 0.4243 - dice_coef: 0.6035 - iou: 0.4360 - recall_3: 0.7948 - precision_3: 0.7323 - val_loss: 0.7182 - val_dice_coef: 0.3390 - val_iou: 0.2141 - val_recall_3: 0.3209 - val_precision_3: 0.7525 - lr: 1.0000e-04
# Epoch 8/50
# 161/161 [==============================] - ETA: 0s - loss: 0.3601 - dice_coef: 0.6633 - iou: 0.5000 - recall_3: 0.7995 - precision_3: 0.7707
# Epoch 8: val_loss did not improve from 0.71820
# 161/161 [==============================] - 156s 966ms/step - loss: 0.3601 - dice_coef: 0.6633 - iou: 0.5000 - recall_3: 0.7995 - precision_3: 0.7707 - val_loss: 0.8138 - val_dice_coef: 0.2619 - val_iou: 0.1552 - val_recall_3: 0.2453 - val_precision_3: 0.4356 - lr: 1.0000e-04
# Epoch 9/50
# 161/161 [==============================] - ETA: 0s - loss: 0.3254 - dice_coef: 0.6968 - iou: 0.5388 - recall_3: 0.7855 - precision_3: 0.7914
# Epoch 9: val_loss did not improve from 0.71820
# 161/161 [==============================] - 156s 967ms/step - loss: 0.3254 - dice_coef: 0.6968 - iou: 0.5388 - recall_3: 0.7855 - precision_3: 0.7914 - val_loss: 0.7629 - val_dice_coef: 0.3049 - val_iou: 0.2118 - val_recall_3: 0.2514 - val_precision_3: 0.8189 - lr: 1.0000e-04
# Epoch 10/50
# 161/161 [==============================] - ETA: 0s - loss: 0.2863 - dice_coef: 0.7341 - iou: 0.5839 - recall_3: 0.8023 - precision_3: 0.8101
# Epoch 10: val_loss did not improve from 0.71820
# 161/161 [==============================] - 156s 966ms/step - loss: 0.2863 - dice_coef: 0.7341 - iou: 0.5839 - recall_3: 0.8023 - precision_3: 0.8101 - val_loss: 0.9829 - val_dice_coef: 0.3389 - val_iou: 0.2245 - val_recall_3: 0.5820 - val_precision_3: 0.1215 - lr: 1.0000e-04
# Epoch 11/50
# 161/161 [==============================] - ETA: 0s - loss: 0.2586 - dice_coef: 0.7602 - iou: 0.6172 - recall_3: 0.8025 - precision_3: 0.8310
# Epoch 11: val_loss did not improve from 0.71820
# 161/161 [==============================] - 156s 966ms/step - loss: 0.2586 - dice_coef: 0.7602 - iou: 0.6172 - recall_3: 0.8025 - precision_3: 0.8310 - val_loss: 1.2171 - val_dice_coef: 0.2315 - val_iou: 0.1351 - val_recall_3: 0.4817 - val_precision_3: 0.0896 - lr: 1.0000e-04
# Epoch 12/50
# 161/161 [==============================] - ETA: 0s - loss: 0.2480 - dice_coef: 0.7713 - iou: 0.6324 - recall_3: 0.7999 - precision_3: 0.8301
# Epoch 12: val_loss did not improve from 0.71820
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 161/161 [==============================] - 156s 966ms/step - loss: 0.2480 - dice_coef: 0.7713 - iou: 0.6324 - recall_3: 0.7999 - precision_3: 0.8301 - val_loss: 0.8220 - val_dice_coef: 0.4259 - val_iou: 0.2843 - val_recall_3: 0.6396 - val_precision_3: 0.2138 - lr: 1.0000e-04
# Epoch 13/50
# 161/161 [==============================] - ETA: 0s - loss: 0.2109 - dice_coef: 0.8047 - iou: 0.6768 - recall_3: 0.8297 - precision_3: 0.8558
# Epoch 13: val_loss did not improve from 0.71820
# 161/161 [==============================] - 156s 966ms/step - loss: 0.2109 - dice_coef: 0.8047 - iou: 0.6768 - recall_3: 0.8297 - precision_3: 0.8558 - val_loss: 1.0307 - val_dice_coef: 0.1959 - val_iou: 0.1103 - val_recall_3: 0.4169 - val_precision_3: 0.1155 - lr: 1.0000e-05
# Epoch 14/50
# 161/161 [==============================] - ETA: 0s - loss: 0.1900 - dice_coef: 0.8234 - iou: 0.7029 - recall_3: 0.8376 - precision_3: 0.8873
# Epoch 14: val_loss did not improve from 0.71820
# 161/161 [==============================] - 156s 966ms/step - loss: 0.1900 - dice_coef: 0.8234 - iou: 0.7029 - recall_3: 0.8376 - precision_3: 0.8873 - val_loss: 0.9333 - val_dice_coef: 0.2183 - val_iou: 0.1247 - val_recall_3: 0.3939 - val_precision_3: 0.1707 - lr: 1.0000e-05
# Epoch 15/50
# 161/161 [==============================] - ETA: 0s - loss: 0.1807 - dice_coef: 0.8319 - iou: 0.7152 - recall_3: 0.8461 - precision_3: 0.8957
# Epoch 15: val_loss did not improve from 0.71820
# 161/161 [==============================] - 156s 966ms/step - loss: 0.1807 - dice_coef: 0.8319 - iou: 0.7152 - recall_3: 0.8461 - precision_3: 0.8957 - val_loss: 1.0283 - val_dice_coef: 0.1950 - val_iou: 0.1111 - val_recall_3: 0.4094 - val_precision_3: 0.1263 - lr: 1.0000e-05
# Epoch 16/50
# 161/161 [==============================] - ETA: 0s - loss: 0.1729 - dice_coef: 0.8392 - iou: 0.7258 - recall_3: 0.8535 - precision_3: 0.9026
# Epoch 16: val_loss did not improve from 0.71820
# 161/161 [==============================] - 156s 967ms/step - loss: 0.1729 - dice_coef: 0.8392 - iou: 0.7258 - recall_3: 0.8535 - precision_3: 0.9026 - val_loss: 1.2111 - val_dice_coef: 0.1818 - val_iou: 0.1049 - val_recall_3: 0.4372 - val_precision_3: 0.0953 - lr: 1.0000e-05
# Epoch 17/50
# 161/161 [==============================] - ETA: 0s - loss: 0.1656 - dice_coef: 0.8459 - iou: 0.7357 - recall_3: 0.8598 - precision_3: 0.9086
# Epoch 17: val_loss did not improve from 0.71820
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1e-06.
# 161/161 [==============================] - 156s 966ms/step - loss: 0.1656 - dice_coef: 0.8459 - iou: 0.7357 - recall_3: 0.8598 - precision_3: 0.9086 - val_loss: 1.3057 - val_dice_coef: 0.1772 - val_iou: 0.1027 - val_recall_3: 0.4415 - val_precision_3: 0.0886 - lr: 1.0000e-05

# %% [markdown]
# ### Evaluating the Model:

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import pandas as pd
import cv2
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import accuracy_score, f1_score, jaccard_score, precision_score, recall_score
from tensorflow.keras.models import load_model

# %%
H = 512
W = 512

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.float32)
    return ori_x, x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.int32)
    return ori_x, x

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.png")))
    y = sorted(glob(os.path.join(path, "mask", "*.png")))
    return x, y

def save_results(ori_x, ori_y, y_pred, save_image_path):
    line = np.ones((H, 10, 3)) * 255

    ori_y = np.expand_dims(ori_y, axis=-1)
    ori_y = np.concatenate([ori_y, ori_y, ori_y], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1) * 255

    cat_images = np.concatenate([ori_x, line, ori_y, line, y_pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model1.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score1 = [s[1:] for s in SCORE]
score1 = np.mean(score1, axis=0)
print(f"Accuracy: {score1[0]:0.5f}")
print(f"F1: {score1[1]:0.5f}")
print(f"Jaccard: {score1[2]:0.5f}")
print(f"Recall: {score1[3]:0.5f}")
print(f"Precision: {score1[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score1.csv")
# Out:
# 100%|██████████| 5/5 [00:02<00:00,  2.07it/s]
# Accuracy: 0.99551
# F1: 0.83195
# Jaccard: 0.71991
# Recall: 0.78533
# Precision: 0.89764

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model2.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score2 = [s[1:] for s in SCORE]
score2 = np.mean(score2, axis=0)
print(f"Accuracy: {score2[0]:0.5f}")
print(f"F1: {score2[1]:0.5f}")
print(f"Jaccard: {score2[2]:0.5f}")
print(f"Recall: {score2[3]:0.5f}")
print(f"Precision: {score2[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score2.csv")
# Out:
# 100%|██████████| 5/5 [00:02<00:00,  2.38it/s]
# Accuracy: 0.99372
# F1: 0.73712
# Jaccard: 0.59028
# Recall: 0.64782
# Precision: 0.89797

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model3.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score3 = [s[1:] for s in SCORE]
score3 = np.mean(score3, axis=0)
print(f"Accuracy: {score3[0]:0.5f}")
print(f"F1: {score3[1]:0.5f}")
print(f"Jaccard: {score3[2]:0.5f}")
print(f"Recall: {score3[3]:0.5f}")
print(f"Precision: {score3[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score3.csv")
# Out:
# 100%|██████████| 5/5 [00:02<00:00,  2.02it/s]
# Accuracy: 0.99334
# F1: 0.69430
# Jaccard: 0.54665
# Recall: 0.58059
# Precision: 0.92291

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model4.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score4 = [s[1:] for s in SCORE]
score4 = np.mean(score4, axis=0)
print(f"Accuracy: {score4[0]:0.5f}")
print(f"F1: {score4[1]:0.5f}")
print(f"Jaccard: {score4[2]:0.5f}")
print(f"Recall: {score4[3]:0.5f}")
print(f"Precision: {score4[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score4.csv")
# Out:
# 100%|██████████| 5/5 [00:03<00:00,  1.43it/s]
# Accuracy: 0.98902
# F1: 0.42398
# Jaccard: 0.28523
# Recall: 0.34853
# Precision: 0.85216

# %%
import matplotlib.pyplot as plt

z_dim = [16, 32, 64, 128]
final_score = [score1[1], score2[1], score3[1], score4[1]]

plt.plot(z_dim, final_score)  
plt.xlabel("Latent Dimension Representation")
plt.ylabel("F1-Score")
plt.show()
