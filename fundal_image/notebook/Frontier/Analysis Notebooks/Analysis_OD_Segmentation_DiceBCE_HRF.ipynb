# %% [markdown]
# ### Import the required libraries and modules:

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
import numpy as np

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# %cd /content/gdrive/MyDrive/Blood_Vessel_Results/ALL_BEST_RESULTS/HRF_OD_3
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/Blood_Vessel_Results/ALL_BEST_RESULTS/HRF_OD_3

# %% [markdown]
# ### Unzip the data:

# %%
# !unzip new_data.zip

# %% [markdown]
# ### Construct the Model:

# %%
def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(inputs, num_filters, strides=2):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D(strides)(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters, strides=2):
    x = Conv2DTranspose(num_filters, (2, 2), strides=strides, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape, num_filters=[64, 128, 256, 512, 1024], strides=[2, 2, 2, 2]):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, num_filters[0], strides=strides[0])
    s2, p2 = encoder_block(p1, num_filters[1], strides=strides[1])
    s3, p3 = encoder_block(p2, num_filters[2], strides=strides[2])
    s4, p4 = encoder_block(p3, num_filters[3], strides=strides[3])

    b1 = conv_block(p4, num_filters[4])

    d1 = decoder_block(b1, s4, num_filters[3], strides=strides[3])
    d2 = decoder_block(d1, s3, num_filters[2], strides=strides[2])
    d3 = decoder_block(d2, s2, num_filters[1], strides=strides[1])
    d4 = decoder_block(d3, s1, num_filters[0], strides=strides[0])

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="UNET")
    return model

input_shape = (512, 512, 3)
model = build_unet(input_shape)
model.summary()
# Out:
# Model: "UNET"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 512, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 512, 512, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 512, 512, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 512, 512, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 12  0          ['activation_3[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 25  295168      ['max_pooling2d_1[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_4[0][0]']
#  rmalization)                   6)
#
#  activation_4 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_4[0][0]']
#                                 6)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 25  590080      ['activation_4[0][0]']
#                                 6)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_5[0][0]']
#  rmalization)                   6)
#
#  activation_5 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_5[0][0]']
#                                 6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 512)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 512)  2097664    ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 64, 64, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 25  524544     ['activation_11[0][0]']
#  spose)                         6)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 51  0           ['conv2d_transpose_1[0][0]',
#                                 2)                                'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_12 (BatchN  (None, 128, 128, 25  1024       ['conv2d_12[0][0]']
#  ormalization)                  6)
#
#  activation_12 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_12[0][0]']
#                                 6)
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 25  590080      ['activation_12[0][0]']
#                                 6)
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 25  1024       ['conv2d_13[0][0]']
#  ormalization)                  6)
#
#  activation_13 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_13[0][0]']
#                                 6)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 12  131200     ['activation_13[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 256, 256, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  activation_14 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_15 (BatchN  (None, 256, 256, 12  512        ['conv2d_15[0][0]']
#  ormalization)                  8)
#
#  activation_15 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_15[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 64  32832      ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 512, 512, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 512, 512, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 512, 512, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 512, 512, 1)  65          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %% [markdown]
# ### Adding the Metrics:

# %%
def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def DiceBCELoss(y_true, y_pred):

    inputs = tf.keras.layers.Flatten()(y_true)
    targets = tf.keras.layers.Flatten()(y_pred)

    intersection = tf.reduce_sum(inputs * targets)
    dice_loss = 1 - (2.*intersection + smooth)/(tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)
    BCE = tf.keras.losses.BinaryCrossentropy()
    Dice_BCE = BCE(inputs, targets) + dice_loss

    return Dice_BCE

# %% [markdown]
# ### Training the Model:

# %%
H = 512
W = 512

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.png")))
    y = sorted(glob(os.path.join(path, "mask", "*.png")))
    return x, y

def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)
    return x, y

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)              ## (512, 512, 1)
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y, batch_size=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(4)
    return dataset

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 8
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model1.h5")
csv_path = os.path.join("files", "data1.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model1 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 1024], strides=[2, 2, 2, 4])

model1.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model1.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 252 - 252
# Valid: 9 - 9
# Epoch 1/50
# 32/32 [==============================] - ETA: 0s - loss: 1.2649 - dice_coef: 0.0893 - iou: 0.0472 - recall: 0.7557 - precision: 0.1477
# Epoch 1: val_loss improved from inf to 1.64950, saving model to files/model1.h5
# 32/32 [==============================] - 225s 6s/step - loss: 1.2649 - dice_coef: 0.0893 - iou: 0.0472 - recall: 0.7557 - precision: 0.1477 - val_loss: 1.6495 - val_dice_coef: 0.0218 - val_iou: 0.0110 - val_recall: 2.5629e-04 - val_precision: 4.4373e-05 - lr: 1.0000e-04
# Epoch 2/50
# 32/32 [==============================] - ETA: 0s - loss: 0.9333 - dice_coef: 0.1961 - iou: 0.1091 - recall: 0.8757 - precision: 0.7811
# Epoch 2: val_loss improved from 1.64950 to 1.58775, saving model to files/model1.h5
# 32/32 [==============================] - 65s 2s/step - loss: 0.9333 - dice_coef: 0.1961 - iou: 0.1091 - recall: 0.8757 - precision: 0.7811 - val_loss: 1.5877 - val_dice_coef: 0.0226 - val_iou: 0.0114 - val_recall: 0.0444 - val_precision: 0.0087 - lr: 1.0000e-04
# Epoch 3/50
# 32/32 [==============================] - ETA: 0s - loss: 0.8422 - dice_coef: 0.2512 - iou: 0.1439 - recall: 0.9039 - precision: 0.8354
# Epoch 3: val_loss did not improve from 1.58775
# 32/32 [==============================] - 61s 2s/step - loss: 0.8422 - dice_coef: 0.2512 - iou: 0.1439 - recall: 0.9039 - precision: 0.8354 - val_loss: 3.3124 - val_dice_coef: 0.0265 - val_iou: 0.0134 - val_recall: 1.0000 - val_precision: 0.0136 - lr: 1.0000e-04
# Epoch 4/50
# 32/32 [==============================] - ETA: 0s - loss: 0.7993 - dice_coef: 0.2811 - iou: 0.1637 - recall: 0.9114 - precision: 0.8552
# Epoch 4: val_loss improved from 1.58775 to 1.20511, saving model to files/model1.h5
# 32/32 [==============================] - 64s 2s/step - loss: 0.7993 - dice_coef: 0.2811 - iou: 0.1637 - recall: 0.9114 - precision: 0.8552 - val_loss: 1.2051 - val_dice_coef: 0.0246 - val_iou: 0.0124 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 5/50
# 32/32 [==============================] - ETA: 0s - loss: 0.7691 - dice_coef: 0.3037 - iou: 0.1793 - recall: 0.9155 - precision: 0.8601
# Epoch 5: val_loss improved from 1.20511 to 1.13749, saving model to files/model1.h5
# 32/32 [==============================] - 66s 2s/step - loss: 0.7691 - dice_coef: 0.3037 - iou: 0.1793 - recall: 0.9155 - precision: 0.8601 - val_loss: 1.1375 - val_dice_coef: 0.0242 - val_iou: 0.0123 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 6/50
# 32/32 [==============================] - ETA: 0s - loss: 0.7369 - dice_coef: 0.3284 - iou: 0.1968 - recall: 0.9332 - precision: 0.8809
# Epoch 6: val_loss improved from 1.13749 to 1.10264, saving model to files/model1.h5
# 32/32 [==============================] - 65s 2s/step - loss: 0.7369 - dice_coef: 0.3284 - iou: 0.1968 - recall: 0.9332 - precision: 0.8809 - val_loss: 1.1026 - val_dice_coef: 0.0233 - val_iou: 0.0118 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 7/50
# 32/32 [==============================] - ETA: 0s - loss: 0.7064 - dice_coef: 0.3521 - iou: 0.2140 - recall: 0.9471 - precision: 0.8955
# Epoch 7: val_loss improved from 1.10264 to 1.08407, saving model to files/model1.h5
# 32/32 [==============================] - 66s 2s/step - loss: 0.7064 - dice_coef: 0.3521 - iou: 0.2140 - recall: 0.9471 - precision: 0.8955 - val_loss: 1.0841 - val_dice_coef: 0.0221 - val_iou: 0.0112 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 8/50
# 32/32 [==============================] - ETA: 0s - loss: 0.6800 - dice_coef: 0.3734 - iou: 0.2300 - recall: 0.9540 - precision: 0.9020
# Epoch 8: val_loss improved from 1.08407 to 1.07206, saving model to files/model1.h5
# 32/32 [==============================] - 65s 2s/step - loss: 0.6800 - dice_coef: 0.3734 - iou: 0.2300 - recall: 0.9540 - precision: 0.9020 - val_loss: 1.0721 - val_dice_coef: 0.0214 - val_iou: 0.0108 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 9/50
# 32/32 [==============================] - ETA: 0s - loss: 0.6548 - dice_coef: 0.3941 - iou: 0.2459 - recall: 0.9576 - precision: 0.9069
# Epoch 9: val_loss improved from 1.07206 to 1.06236, saving model to files/model1.h5
# 32/32 [==============================] - 64s 2s/step - loss: 0.6548 - dice_coef: 0.3941 - iou: 0.2459 - recall: 0.9576 - precision: 0.9069 - val_loss: 1.0624 - val_dice_coef: 0.0213 - val_iou: 0.0108 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 10/50
# 32/32 [==============================] - ETA: 0s - loss: 0.6335 - dice_coef: 0.4128 - iou: 0.2607 - recall: 0.9570 - precision: 0.9010
# Epoch 10: val_loss improved from 1.06236 to 1.02592, saving model to files/model1.h5
# 32/32 [==============================] - 65s 2s/step - loss: 0.6335 - dice_coef: 0.4128 - iou: 0.2607 - recall: 0.9570 - precision: 0.9010 - val_loss: 1.0259 - val_dice_coef: 0.0818 - val_iou: 0.0431 - val_recall: 0.0741 - val_precision: 1.0000 - lr: 1.0000e-04
# Epoch 11/50
# 32/32 [==============================] - ETA: 0s - loss: 0.6070 - dice_coef: 0.4352 - iou: 0.2788 - recall: 0.9611 - precision: 0.9113
# Epoch 11: val_loss improved from 1.02592 to 1.02355, saving model to files/model1.h5
# 32/32 [==============================] - 65s 2s/step - loss: 0.6070 - dice_coef: 0.4352 - iou: 0.2788 - recall: 0.9611 - precision: 0.9113 - val_loss: 1.0236 - val_dice_coef: 0.1018 - val_iou: 0.0551 - val_recall: 0.0647 - val_precision: 1.0000 - lr: 1.0000e-04
# Epoch 12/50
# 32/32 [==============================] - ETA: 0s - loss: 0.5824 - dice_coef: 0.4564 - iou: 0.2964 - recall: 0.9632 - precision: 0.9146
# Epoch 12: val_loss improved from 1.02355 to 0.85065, saving model to files/model1.h5
# 32/32 [==============================] - 64s 2s/step - loss: 0.5824 - dice_coef: 0.4564 - iou: 0.2964 - recall: 0.9632 - precision: 0.9146 - val_loss: 0.8507 - val_dice_coef: 0.2524 - val_iou: 0.1459 - val_recall: 0.4301 - val_precision: 0.8142 - lr: 1.0000e-04
# Epoch 13/50
# 32/32 [==============================] - ETA: 0s - loss: 0.5560 - dice_coef: 0.4793 - iou: 0.3160 - recall: 0.9669 - precision: 0.9256
# Epoch 13: val_loss improved from 0.85065 to 0.73838, saving model to files/model1.h5
# 32/32 [==============================] - 64s 2s/step - loss: 0.5560 - dice_coef: 0.4793 - iou: 0.3160 - recall: 0.9669 - precision: 0.9256 - val_loss: 0.7384 - val_dice_coef: 0.3450 - val_iou: 0.2095 - val_recall: 0.6858 - val_precision: 0.8755 - lr: 1.0000e-04
# Epoch 14/50
# 32/32 [==============================] - ETA: 0s - loss: 0.5334 - dice_coef: 0.4996 - iou: 0.3339 - recall: 0.9663 - precision: 0.9248
# Epoch 14: val_loss did not improve from 0.73838
# 32/32 [==============================] - 61s 2s/step - loss: 0.5334 - dice_coef: 0.4996 - iou: 0.3339 - recall: 0.9663 - precision: 0.9248 - val_loss: 0.7739 - val_dice_coef: 0.2812 - val_iou: 0.1636 - val_recall: 0.5211 - val_precision: 0.8903 - lr: 1.0000e-04
# Epoch 38/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2556 - dice_coef: 0.7552 - iou: 0.6074 - recall: 0.9739 - precision: 0.9768
# Epoch 38: val_loss improved from 0.36262 to 0.36152, saving model to files/model1.h5
# 32/32 [==============================] - 64s 2s/step - loss: 0.2556 - dice_coef: 0.7552 - iou: 0.6074 - recall: 0.9739 - precision: 0.9768 - val_loss: 0.3615 - val_dice_coef: 0.6799 - val_iou: 0.5155 - val_recall: 0.9511 - val_precision: 0.8502 - lr: 1.0000e-05
# Epoch 39/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2537 - dice_coef: 0.7571 - iou: 0.6097 - recall: 0.9744 - precision: 0.9776
# Epoch 39: val_loss improved from 0.36152 to 0.36039, saving model to files/model1.h5
# 32/32 [==============================] - 64s 2s/step - loss: 0.2537 - dice_coef: 0.7571 - iou: 0.6097 - recall: 0.9744 - precision: 0.9776 - val_loss: 0.3604 - val_dice_coef: 0.6813 - val_iou: 0.5171 - val_recall: 0.9505 - val_precision: 0.8503 - lr: 1.0000e-05
# Epoch 40/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2517 - dice_coef: 0.7589 - iou: 0.6121 - recall: 0.9748 - precision: 0.9784
# Epoch 40: val_loss improved from 0.36039 to 0.35923, saving model to files/model1.h5
# 32/32 [==============================] - 64s 2s/step - loss: 0.2517 - dice_coef: 0.7589 - iou: 0.6121 - recall: 0.9748 - precision: 0.9784 - val_loss: 0.3592 - val_dice_coef: 0.6826 - val_iou: 0.5187 - val_recall: 0.9500 - val_precision: 0.8503 - lr: 1.0000e-05
# Epoch 41/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2498 - dice_coef: 0.7607 - iou: 0.6144 - recall: 0.9752 - precision: 0.9791
# Epoch 41: val_loss improved from 0.35923 to 0.35804, saving model to files/model1.h5
# 32/32 [==============================] - 64s 2s/step - loss: 0.2498 - dice_coef: 0.7607 - iou: 0.6144 - recall: 0.9752 - precision: 0.9791 - val_loss: 0.3580 - val_dice_coef: 0.6840 - val_iou: 0.5202 - val_recall: 0.9492 - val_precision: 0.8501 - lr: 1.0000e-05
# Epoch 42/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2479 - dice_coef: 0.7624 - iou: 0.6168 - recall: 0.9756 - precision: 0.9799
# Epoch 42: val_loss improved from 0.35804 to 0.35686, saving model to files/model1.h5
# 32/32 [==============================] - 64s 2s/step - loss: 0.2479 - dice_coef: 0.7624 - iou: 0.6168 - recall: 0.9756 - precision: 0.9799 - val_loss: 0.3569 - val_dice_coef: 0.6854 - val_iou: 0.5219 - val_recall: 0.9486 - val_precision: 0.8499 - lr: 1.0000e-05
# Epoch 43/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2460 - dice_coef: 0.7642 - iou: 0.6191 - recall: 0.9759 - precision: 0.9805
# Epoch 43: val_loss improved from 0.35686 to 0.35574, saving model to files/model1.h5
# Epoch 49: val_loss improved from 0.34962 to 0.34840, saving model to files/model1.h5
# 32/32 [==============================] - 64s 2s/step - loss: 0.2352 - dice_coef: 0.7743 - iou: 0.6324 - recall: 0.9776 - precision: 0.9841 - val_loss: 0.3484 - val_dice_coef: 0.6954 - val_iou: 0.5337 - val_recall: 0.9437 - val_precision: 0.8508 - lr: 1.0000e-05
# Epoch 50/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2334 - dice_coef: 0.7760 - iou: 0.6346 - recall: 0.9779 - precision: 0.9846
# Epoch 50: val_loss improved from 0.34840 to 0.34706, saving model to files/model1.h5
# 32/32 [==============================] - 64s 2s/step - loss: 0.2334 - dice_coef: 0.7760 - iou: 0.6346 - recall: 0.9779 - precision: 0.9846 - val_loss: 0.3471 - val_dice_coef: 0.6969 - val_iou: 0.5355 - val_recall: 0.9434 - val_precision: 0.8510 - lr: 1.0000e-05

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 8
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model2.h5")
csv_path = os.path.join("files", "data2.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model2 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 1024], strides=[2, 2, 2, 2])

model2.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model2.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 252 - 252
# Valid: 9 - 9
# Epoch 1/50
# 32/32 [==============================] - ETA: 0s - loss: 1.2638 - dice_coef: 0.0897 - iou: 0.0474 - recall_1: 0.7640 - precision_1: 0.1491
# Epoch 1: val_loss improved from inf to 1.65690, saving model to files/model2.h5
# 32/32 [==============================] - 76s 2s/step - loss: 1.2638 - dice_coef: 0.0897 - iou: 0.0474 - recall_1: 0.7640 - precision_1: 0.1491 - val_loss: 1.6569 - val_dice_coef: 0.0218 - val_iou: 0.0110 - val_recall_1: 0.0020 - val_precision_1: 1.3299e-04 - lr: 1.0000e-04
# Epoch 2/50
# 32/32 [==============================] - ETA: 0s - loss: 0.9329 - dice_coef: 0.1959 - iou: 0.1089 - recall_1: 0.8743 - precision_1: 0.7849
# Epoch 2: val_loss did not improve from 1.65690
# 32/32 [==============================] - 68s 2s/step - loss: 0.9329 - dice_coef: 0.1959 - iou: 0.1089 - recall_1: 0.8743 - precision_1: 0.7849 - val_loss: 1.9067 - val_dice_coef: 0.0282 - val_iou: 0.0143 - val_recall_1: 1.0000 - val_precision_1: 0.0158 - lr: 1.0000e-04
# Epoch 3/50
# 32/32 [==============================] - ETA: 0s - loss: 0.8463 - dice_coef: 0.2485 - iou: 0.1421 - recall_1: 0.8944 - precision_1: 0.8279
# Epoch 3: val_loss did not improve from 1.65690
# 32/32 [==============================] - 68s 2s/step - loss: 0.8463 - dice_coef: 0.2485 - iou: 0.1421 - recall_1: 0.8944 - precision_1: 0.8279 - val_loss: 4.0206 - val_dice_coef: 0.0252 - val_iou: 0.0128 - val_recall_1: 1.0000 - val_precision_1: 0.0130 - lr: 1.0000e-04
# Epoch 4/50
# 32/32 [==============================] - ETA: 0s - loss: 0.7992 - dice_coef: 0.2814 - iou: 0.1640 - recall_1: 0.9141 - precision_1: 0.8501
# Epoch 4: val_loss improved from 1.65690 to 1.20621, saving model to files/model2.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.7992 - dice_coef: 0.2814 - iou: 0.1640 - recall_1: 0.9141 - precision_1: 0.8501 - val_loss: 1.2062 - val_dice_coef: 0.0244 - val_iou: 0.0124 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 5/50
# 32/32 [==============================] - ETA: 0s - loss: 0.7715 - dice_coef: 0.3019 - iou: 0.1780 - recall_1: 0.9115 - precision_1: 0.8497
# Epoch 5: val_loss did not improve from 1.20621
# 32/32 [==============================] - 64s 2s/step - loss: 0.7715 - dice_coef: 0.3019 - iou: 0.1780 - recall_1: 0.9115 - precision_1: 0.8497 - val_loss: 1.2236 - val_dice_coef: 0.0373 - val_iou: 0.0190 - val_recall_1: 0.2700 - val_precision_1: 0.1109 - lr: 1.0000e-04
# Epoch 6/50
# 32/32 [==============================] - ETA: 0s - loss: 0.7400 - dice_coef: 0.3256 - iou: 0.1947 - recall_1: 0.9242 - precision_1: 0.8780
# Epoch 6: val_loss improved from 1.20621 to 1.10202, saving model to files/model2.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.7400 - dice_coef: 0.3256 - iou: 0.1947 - recall_1: 0.9242 - precision_1: 0.8780 - val_loss: 1.1020 - val_dice_coef: 0.0230 - val_iou: 0.0116 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 7/50
# 32/32 [==============================] - ETA: 0s - loss: 0.7138 - dice_coef: 0.3464 - iou: 0.2098 - recall_1: 0.9318 - precision_1: 0.8808
# Epoch 7: val_loss improved from 1.10202 to 1.08367, saving model to files/model2.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.7138 - dice_coef: 0.3464 - iou: 0.2098 - recall_1: 0.9318 - precision_1: 0.8808 - val_loss: 1.0837 - val_dice_coef: 0.0225 - val_iou: 0.0114 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 8/50
# 32/32 [==============================] - ETA: 0s - loss: 0.6878 - dice_coef: 0.3672 - iou: 0.2253 - recall_1: 0.9371 - precision_1: 0.8918
# Epoch 8: val_loss improved from 1.08367 to 1.07012, saving model to files/model2.h5
# 32/32 [==============================] - 68s 2s/step - loss: 0.6878 - dice_coef: 0.3672 - iou: 0.2253 - recall_1: 0.9371 - precision_1: 0.8918 - val_loss: 1.0701 - val_dice_coef: 0.0209 - val_iou: 0.0106 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 9/50
# 32/32 [==============================] - ETA: 0s - loss: 0.6621 - dice_coef: 0.3886 - iou: 0.2416 - recall_1: 0.9451 - precision_1: 0.8940
# Epoch 9: val_loss improved from 1.07012 to 1.06675, saving model to files/model2.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.6621 - dice_coef: 0.3886 - iou: 0.2416 - recall_1: 0.9451 - precision_1: 0.8940 - val_loss: 1.0667 - val_dice_coef: 0.0190 - val_iou: 0.0096 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 10/50
# 32/32 [==============================] - ETA: 0s - loss: 0.6387 - dice_coef: 0.4080 - iou: 0.2567 - recall_1: 0.9438 - precision_1: 0.9019
# Epoch 10: val_loss improved from 1.06675 to 1.01384, saving model to files/model2.h5
# 32/32 [==============================] - 68s 2s/step - loss: 0.6387 - dice_coef: 0.4080 - iou: 0.2567 - recall_1: 0.9438 - precision_1: 0.9019 - val_loss: 1.0138 - val_dice_coef: 0.1155 - val_iou: 0.0628 - val_recall_1: 0.1056 - val_precision_1: 1.0000 - lr: 1.0000e-04
# Epoch 11/50
# 32/32 [==============================] - ETA: 0s - loss: 0.6186 - dice_coef: 0.4259 - iou: 0.2710 - recall_1: 0.9417 - precision_1: 0.8927
# Epoch 11: val_loss improved from 1.01384 to 0.94747, saving model to files/model2.h5
# 32/32 [==============================] - 68s 2s/step - loss: 0.6186 - dice_coef: 0.4259 - iou: 0.2710 - recall_1: 0.9417 - precision_1: 0.8927 - val_loss: 0.9475 - val_dice_coef: 0.1825 - val_iou: 0.1025 - val_recall_1: 0.2755 - val_precision_1: 0.9721 - lr: 1.0000e-04
# Epoch 12/50
# 32/32 [==============================] - ETA: 0s - loss: 0.5928 - dice_coef: 0.4477 - iou: 0.2889 - recall_1: 0.9431 - precision_1: 0.9055
# Epoch 12: val_loss improved from 0.94747 to 0.90067, saving model to files/model2.h5
# 32/32 [==============================] - 68s 2s/step - loss: 0.5928 - dice_coef: 0.4477 - iou: 0.2889 - recall_1: 0.9431 - precision_1: 0.9055 - val_loss: 0.9007 - val_dice_coef: 0.2505 - val_iou: 0.1485 - val_recall_1: 0.3171 - val_precision_1: 0.9291 - lr: 1.0000e-04
# Epoch 24/50
# 32/32 [==============================] - ETA: 0s - loss: 0.3350 - dice_coef: 0.6825 - iou: 0.5188 - recall_1: 0.9546 - precision_1: 0.9402
# Epoch 24: val_loss improved from 0.53011 to 0.42784, saving model to files/model2.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.3350 - dice_coef: 0.6825 - iou: 0.5188 - recall_1: 0.9546 - precision_1: 0.9402 - val_loss: 0.4278 - val_dice_coef: 0.5812 - val_iou: 0.4100 - val_recall_1: 0.9684 - val_precision_1: 0.8280 - lr: 1.0000e-04
# Epoch 25/50
# 32/32 [==============================] - ETA: 0s - loss: 0.3168 - dice_coef: 0.6994 - iou: 0.5385 - recall_1: 0.9544 - precision_1: 0.9479
# Epoch 25: val_loss improved from 0.42784 to 0.41057, saving model to files/model2.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.3168 - dice_coef: 0.6994 - iou: 0.5385 - recall_1: 0.9544 - precision_1: 0.9479 - val_loss: 0.4106 - val_dice_coef: 0.6368 - val_iou: 0.4675 - val_recall_1: 0.9763 - val_precision_1: 0.7900 - lr: 1.0000e-04
# Epoch 26/50
# 32/32 [==============================] - ETA: 0s - loss: 0.3000 - dice_coef: 0.7151 - iou: 0.5571 - recall_1: 0.9523 - precision_1: 0.9533
# Epoch 26: val_loss improved from 0.41057 to 0.38897, saving model to files/model2.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.3000 - dice_coef: 0.7151 - iou: 0.5571 - recall_1: 0.9523 - precision_1: 0.9533 - val_loss: 0.3890 - val_dice_coef: 0.6493 - val_iou: 0.4809 - val_recall_1: 0.9664 - val_precision_1: 0.8243 - lr: 1.0000e-04
# Epoch 27/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2795 - dice_coef: 0.7338 - iou: 0.5802 - recall_1: 0.9590 - precision_1: 0.9607
# Epoch 27: val_loss improved from 0.38897 to 0.36504, saving model to files/model2.h5
# 32/32 [==============================] - 68s 2s/step - loss: 0.2795 - dice_coef: 0.7338 - iou: 0.5802 - recall_1: 0.9590 - precision_1: 0.9607 - val_loss: 0.3650 - val_dice_coef: 0.6679 - val_iou: 0.5016 - val_recall_1: 0.9586 - val_precision_1: 0.8424 - lr: 1.0000e-04
# Epoch 28/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2628 - dice_coef: 0.7495 - iou: 0.6000 - recall_1: 0.9617 - precision_1: 0.9646
# Epoch 28: val_loss improved from 0.36504 to 0.36046, saving model to files/model2.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.2628 - dice_coef: 0.7495 - iou: 0.6000 - recall_1: 0.9617 - precision_1: 0.9646 - val_loss: 0.3605 - val_dice_coef: 0.6747 - val_iou: 0.5094 - val_recall_1: 0.9091 - val_precision_1: 0.8727 - lr: 1.0000e-04
# Epoch 29/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2502 - dice_coef: 0.7617 - iou: 0.6157 - recall_1: 0.9616 - precision_1: 0.9643
# Epoch 29: val_loss improved from 0.36046 to 0.33367, saving model to files/model2.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.2502 - dice_coef: 0.7617 - iou: 0.6157 - recall_1: 0.9616 - precision_1: 0.9643 - val_loss: 0.3337 - val_dice_coef: 0.6919 - val_iou: 0.5290 - val_recall_1: 0.9136 - val_precision_1: 0.8942 - lr: 1.0000e-04
# Epoch 30/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2354 - dice_coef: 0.7754 - iou: 0.6339 - recall_1: 0.9639 - precision_1: 0.9680
# Epoch 30: val_loss improved from 0.33367 to 0.31000, saving model to files/model2.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.2354 - dice_coef: 0.7754 - iou: 0.6339 - recall_1: 0.9639 - precision_1: 0.9680 - val_loss: 0.3100 - val_dice_coef: 0.7175 - val_iou: 0.5596 - val_recall_1: 0.9497 - val_precision_1: 0.8899 - lr: 1.0000e-04
# Epoch 31/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2232 - dice_coef: 0.7870 - iou: 0.6495 - recall_1: 0.9645 - precision_1: 0.9690
# Epoch 31: val_loss improved from 0.31000 to 0.30453, saving model to files/model2.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.2232 - dice_coef: 0.7870 - iou: 0.6495 - recall_1: 0.9645 - precision_1: 0.9690 - val_loss: 0.3045 - val_dice_coef: 0.7203 - val_iou: 0.5630 - val_recall_1: 0.9301 - val_precision_1: 0.8843 - lr: 1.0000e-04
# Epoch 32/50
# 32/32 [==============================] - ETA: 0s - loss: 0.2102 - dice_coef: 0.7993 - iou: 0.6663 - recall_1: 0.9680 - precision_1: 0.9709
# Epoch 32: val_loss improved from 0.30453 to 0.30367, saving model to files/model2.h5
# 32/32 [==============================] - 68s 2s/step - loss: 0.2102 - dice_coef: 0.7993 - iou: 0.6663 - recall_1: 0.9680 - precision_1: 0.9709 - val_loss: 0.3037 - val_dice_coef: 0.7268 - val_iou: 0.5711 - val_recall_1: 0.9196 - val_precision_1: 0.8890 - lr: 1.0000e-04
# Epoch 33/50
# 32/32 [==============================] - ETA: 0s - loss: 0.1992 - dice_coef: 0.8097 - iou: 0.6808 - recall_1: 0.9673 - precision_1: 0.9736
# Epoch 33: val_loss improved from 0.30367 to 0.28724, saving model to files/model2.h5
# 32/32 [==============================] - 68s 2s/step - loss: 0.1992 - dice_coef: 0.8097 - iou: 0.6808 - recall_1: 0.9673 - precision_1: 0.9736 - val_loss: 0.2872 - val_dice_coef: 0.7495 - val_iou: 0.5998 - val_recall_1: 0.9575 - val_precision_1: 0.8595 - lr: 1.0000e-04
# Epoch 34/50
# 32/32 [==============================] - ETA: 0s - loss: 0.1920 - dice_coef: 0.8167 - iou: 0.6908 - recall_1: 0.9633 - precision_1: 0.9735
# Epoch 34: val_loss improved from 0.28724 to 0.27691, saving model to files/model2.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.1920 - dice_coef: 0.8167 - iou: 0.6908 - recall_1: 0.9633 - precision_1: 0.9735 - val_loss: 0.2769 - val_dice_coef: 0.7600 - val_iou: 0.6134 - val_recall_1: 0.9639 - val_precision_1: 0.8551 - lr: 1.0000e-04
# 32/32 [==============================] - 67s 2s/step - loss: 0.1470 - dice_coef: 0.8600 - iou: 0.7547 - recall_1: 0.9627 - precision_1: 0.9769 - val_loss: 0.2364 - val_dice_coef: 0.7948 - val_iou: 0.6599 - val_recall_1: 0.9522 - val_precision_1: 0.8748 - lr: 1.0000e-04
# Epoch 41/50
# 32/32 [==============================] - ETA: 0s - loss: 0.1369 - dice_coef: 0.8693 - iou: 0.7690 - recall_1: 0.9660 - precision_1: 0.9821
# Epoch 41: val_loss improved from 0.23641 to 0.22536, saving model to files/model2.h5
# 32/32 [==============================] - 68s 2s/step - loss: 0.1369 - dice_coef: 0.8693 - iou: 0.7690 - recall_1: 0.9660 - precision_1: 0.9821 - val_loss: 0.2254 - val_dice_coef: 0.8070 - val_iou: 0.6769 - val_recall_1: 0.9465 - val_precision_1: 0.8802 - lr: 1.0000e-04
# Epoch 42/50
# 32/32 [==============================] - ETA: 0s - loss: 0.1320 - dice_coef: 0.8742 - iou: 0.7767 - recall_1: 0.9657 - precision_1: 0.9811
# Epoch 42: val_loss improved from 0.22536 to 0.21879, saving model to files/model2.h5
# 32/32 [==============================] - 68s 2s/step - loss: 0.1320 - dice_coef: 0.8742 - iou: 0.7767 - recall_1: 0.9657 - precision_1: 0.9811 - val_loss: 0.2188 - val_dice_coef: 0.8120 - val_iou: 0.6840 - val_recall_1: 0.9163 - val_precision_1: 0.9029 - lr: 1.0000e-04
# Epoch 43/50
# 32/32 [==============================] - ETA: 0s - loss: 0.1331 - dice_coef: 0.8737 - iou: 0.7760 - recall_1: 0.9605 - precision_1: 0.9744
# Epoch 43: val_loss improved from 0.21879 to 0.20633, saving model to files/model2.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.1331 - dice_coef: 0.8737 - iou: 0.7760 - recall_1: 0.9605 - precision_1: 0.9744 - val_loss: 0.2063 - val_dice_coef: 0.8251 - val_iou: 0.7028 - val_recall_1: 0.9634 - val_precision_1: 0.8783 - lr: 1.0000e-04
# Epoch 44/50
# 32/32 [==============================] - ETA: 0s - loss: 0.1273 - dice_coef: 0.8790 - iou: 0.7844 - recall_1: 0.9640 - precision_1: 0.9738
# Epoch 44: val_loss improved from 0.20633 to 0.20444, saving model to files/model2.h5
# 32/32 [==============================] - 68s 2s/step - loss: 0.1273 - dice_coef: 0.8790 - iou: 0.7844 - recall_1: 0.9640 - precision_1: 0.9738 - val_loss: 0.2044 - val_dice_coef: 0.8199 - val_iou: 0.6950 - val_recall_1: 0.9353 - val_precision_1: 0.8956 - lr: 1.0000e-04
# Epoch 45/50
# 32/32 [==============================] - ETA: 0s - loss: 0.1202 - dice_coef: 0.8856 - iou: 0.7950 - recall_1: 0.9664 - precision_1: 0.9762
# Epoch 45: val_loss did not improve from 0.20444
# 32/32 [==============================] - 63s 2s/step - loss: 0.1202 - dice_coef: 0.8856 - iou: 0.7950 - recall_1: 0.9664 - precision_1: 0.9762 - val_loss: 0.2164 - val_dice_coef: 0.8124 - val_iou: 0.6842 - val_recall_1: 0.9289 - val_precision_1: 0.8706 - lr: 1.0000e-04
# Epoch 46/50
# 32/32 [==============================] - ETA: 0s - loss: 0.1196 - dice_coef: 0.8868 - iou: 0.7968 - recall_1: 0.9624 - precision_1: 0.9732
# Epoch 46: val_loss did not improve from 0.20444
# 32/32 [==============================] - 63s 2s/step - loss: 0.1196 - dice_coef: 0.8868 - iou: 0.7968 - recall_1: 0.9624 - precision_1: 0.9732 - val_loss: 0.2098 - val_dice_coef: 0.8301 - val_iou: 0.7104 - val_recall_1: 0.9530 - val_precision_1: 0.8498 - lr: 1.0000e-04
# Epoch 47/50
# 32/32 [==============================] - ETA: 0s - loss: 0.1164 - dice_coef: 0.8897 - iou: 0.8016 - recall_1: 0.9603 - precision_1: 0.9746
# Epoch 47: val_loss improved from 0.20444 to 0.19236, saving model to files/model2.h5
# 32/32 [==============================] - 68s 2s/step - loss: 0.1164 - dice_coef: 0.8897 - iou: 0.8016 - recall_1: 0.9603 - precision_1: 0.9746 - val_loss: 0.1924 - val_dice_coef: 0.8444 - val_iou: 0.7316 - val_recall_1: 0.9694 - val_precision_1: 0.8657 - lr: 1.0000e-04
# Epoch 48/50
# 32/32 [==============================] - ETA: 0s - loss: 0.1086 - dice_coef: 0.8969 - iou: 0.8133 - recall_1: 0.9667 - precision_1: 0.9768
# Epoch 48: val_loss improved from 0.19236 to 0.18946, saving model to files/model2.h5
# 32/32 [==============================] - 67s 2s/step - loss: 0.1086 - dice_coef: 0.8969 - iou: 0.8133 - recall_1: 0.9667 - precision_1: 0.9768 - val_loss: 0.1895 - val_dice_coef: 0.8478 - val_iou: 0.7368 - val_recall_1: 0.9608 - val_precision_1: 0.8788 - lr: 1.0000e-04
# Epoch 49/50
# 32/32 [==============================] - ETA: 0s - loss: 0.1003 - dice_coef: 0.9044 - iou: 0.8256 - recall_1: 0.9688 - precision_1: 0.9831
# Epoch 49: val_loss did not improve from 0.18946
# 32/32 [==============================] - 63s 2s/step - loss: 0.1003 - dice_coef: 0.9044 - iou: 0.8256 - recall_1: 0.9688 - precision_1: 0.9831 - val_loss: 0.1934 - val_dice_coef: 0.8389 - val_iou: 0.7230 - val_recall_1: 0.9439 - val_precision_1: 0.8731 - lr: 1.0000e-04
# Epoch 50/50
# 32/32 [==============================] - ETA: 0s - loss: 0.0961 - dice_coef: 0.9083 - iou: 0.8322 - recall_1: 0.9692 - precision_1: 0.9838
# Epoch 50: val_loss did not improve from 0.18946
# 32/32 [==============================] - 63s 2s/step - loss: 0.0961 - dice_coef: 0.9083 - iou: 0.8322 - recall_1: 0.9692 - precision_1: 0.9838 - val_loss: 0.1904 - val_dice_coef: 0.8472 - val_iou: 0.7357 - val_recall_1: 0.9511 - val_precision_1: 0.8661 - lr: 1.0000e-04

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 2
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model3.h5")
csv_path = os.path.join("files", "data3.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model3 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 1024], strides=[1, 2, 2, 2])

model3.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model3.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 252 - 252
# Valid: 9 - 9
# Epoch 1/50
# 126/126 [==============================] - ETA: 0s - loss: 0.9800 - dice_coef: 0.1852 - iou: 0.1040 - recall_2: 0.7930 - precision_2: 0.4035
# Epoch 1: val_loss improved from inf to 1.25208, saving model to files/model3.h5
# 126/126 [==============================] - 244s 2s/step - loss: 0.9800 - dice_coef: 0.1852 - iou: 0.1040 - recall_2: 0.7930 - precision_2: 0.4035 - val_loss: 1.2521 - val_dice_coef: 0.0325 - val_iou: 0.0165 - val_recall_2: 0.1342 - val_precision_2: 0.8994 - lr: 1.0000e-04
# Epoch 2/50
# 126/126 [==============================] - ETA: 0s - loss: 0.7666 - dice_coef: 0.3061 - iou: 0.1819 - recall_2: 0.8828 - precision_2: 0.7693
# Epoch 2: val_loss improved from 1.25208 to 1.08373, saving model to files/model3.h5
# 126/126 [==============================] - 206s 2s/step - loss: 0.7666 - dice_coef: 0.3061 - iou: 0.1819 - recall_2: 0.8828 - precision_2: 0.7693 - val_loss: 1.0837 - val_dice_coef: 0.0201 - val_iou: 0.0102 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 3/50
# 126/126 [==============================] - ETA: 0s - loss: 0.6654 - dice_coef: 0.3879 - iou: 0.2422 - recall_2: 0.8952 - precision_2: 0.8197
# Epoch 3: val_loss improved from 1.08373 to 1.04103, saving model to files/model3.h5
# 126/126 [==============================] - 205s 2s/step - loss: 0.6654 - dice_coef: 0.3879 - iou: 0.2422 - recall_2: 0.8952 - precision_2: 0.8197 - val_loss: 1.0410 - val_dice_coef: 0.0415 - val_iou: 0.0214 - val_recall_2: 0.0492 - val_precision_2: 1.0000 - lr: 1.0000e-04
# Epoch 4/50
# 126/126 [==============================] - ETA: 0s - loss: 0.5739 - dice_coef: 0.4665 - iou: 0.3062 - recall_2: 0.8997 - precision_2: 0.8466
# Epoch 4: val_loss improved from 1.04103 to 0.80866, saving model to files/model3.h5
# 126/126 [==============================] - 205s 2s/step - loss: 0.5739 - dice_coef: 0.4665 - iou: 0.3062 - recall_2: 0.8997 - precision_2: 0.8466 - val_loss: 0.8087 - val_dice_coef: 0.2473 - val_iou: 0.1422 - val_recall_2: 0.4425 - val_precision_2: 0.9441 - lr: 1.0000e-04
# Epoch 5/50
# 126/126 [==============================] - ETA: 0s - loss: 0.4909 - dice_coef: 0.5416 - iou: 0.3740 - recall_2: 0.8959 - precision_2: 0.8663
# Epoch 5: val_loss improved from 0.80866 to 0.53746, saving model to files/model3.h5
# 126/126 [==============================] - 206s 2s/step - loss: 0.4909 - dice_coef: 0.5416 - iou: 0.3740 - recall_2: 0.8959 - precision_2: 0.8663 - val_loss: 0.5375 - val_dice_coef: 0.4952 - val_iou: 0.3311 - val_recall_2: 0.9148 - val_precision_2: 0.8117 - lr: 1.0000e-04
# Epoch 6/50
# 126/126 [==============================] - ETA: 0s - loss: 0.4155 - dice_coef: 0.6111 - iou: 0.4427 - recall_2: 0.8930 - precision_2: 0.8820
# Epoch 6: val_loss improved from 0.53746 to 0.45580, saving model to files/model3.h5
# 126/126 [==============================] - 205s 2s/step - loss: 0.4155 - dice_coef: 0.6111 - iou: 0.4427 - recall_2: 0.8930 - precision_2: 0.8820 - val_loss: 0.4558 - val_dice_coef: 0.5742 - val_iou: 0.4043 - val_recall_2: 0.8895 - val_precision_2: 0.8315 - lr: 1.0000e-04
# Epoch 7/50
# 126/126 [==============================] - ETA: 0s - loss: 0.3634 - dice_coef: 0.6619 - iou: 0.4982 - recall_2: 0.8788 - precision_2: 0.8798
# Epoch 7: val_loss did not improve from 0.45580
# 126/126 [==============================] - 202s 2s/step - loss: 0.3634 - dice_coef: 0.6619 - iou: 0.4982 - recall_2: 0.8788 - precision_2: 0.8798 - val_loss: 5.1655 - val_dice_coef: 0.0576 - val_iou: 0.0298 - val_recall_2: 0.9376 - val_precision_2: 0.0284 - lr: 1.0000e-04
# Epoch 8/50
# 126/126 [==============================] - ETA: 0s - loss: 0.3074 - dice_coef: 0.7138 - iou: 0.5589 - recall_2: 0.8815 - precision_2: 0.8980
# Epoch 8: val_loss improved from 0.45580 to 0.41592, saving model to files/model3.h5
# 126/126 [==============================] - 205s 2s/step - loss: 0.3074 - dice_coef: 0.7138 - iou: 0.5589 - recall_2: 0.8815 - precision_2: 0.8980 - val_loss: 0.4159 - val_dice_coef: 0.6297 - val_iou: 0.4617 - val_recall_2: 0.9471 - val_precision_2: 0.6646 - lr: 1.0000e-04
# Epoch 9/50
# 126/126 [==============================] - ETA: 0s - loss: 0.2672 - dice_coef: 0.7519 - iou: 0.6067 - recall_2: 0.8827 - precision_2: 0.9037
# Epoch 9: val_loss improved from 0.41592 to 0.30479, saving model to files/model3.h5
# 126/126 [==============================] - 205s 2s/step - loss: 0.2672 - dice_coef: 0.7519 - iou: 0.6067 - recall_2: 0.8827 - precision_2: 0.9037 - val_loss: 0.3048 - val_dice_coef: 0.7218 - val_iou: 0.5673 - val_recall_2: 0.9346 - val_precision_2: 0.8098 - lr: 1.0000e-04
# Epoch 10/50
# 126/126 [==============================] - ETA: 0s - loss: 0.2261 - dice_coef: 0.7905 - iou: 0.6580 - recall_2: 0.8877 - precision_2: 0.9211
# Epoch 10: val_loss improved from 0.30479 to 0.29798, saving model to files/model3.h5
# 126/126 [==============================] - 206s 2s/step - loss: 0.2261 - dice_coef: 0.7905 - iou: 0.6580 - recall_2: 0.8877 - precision_2: 0.9211 - val_loss: 0.2980 - val_dice_coef: 0.7275 - val_iou: 0.5756 - val_recall_2: 0.8508 - val_precision_2: 0.8492 - lr: 1.0000e-04
# Epoch 11/50
# 126/126 [==============================] - ETA: 0s - loss: 0.1945 - dice_coef: 0.8201 - iou: 0.6991 - recall_2: 0.8974 - precision_2: 0.9301
# Epoch 11: val_loss did not improve from 0.29798
# 126/126 [==============================] - 200s 2s/step - loss: 0.1945 - dice_coef: 0.8201 - iou: 0.6991 - recall_2: 0.8974 - precision_2: 0.9301 - val_loss: 0.3008 - val_dice_coef: 0.7280 - val_iou: 0.5810 - val_recall_2: 0.8106 - val_precision_2: 0.8647 - lr: 1.0000e-04
# Epoch 12/50
# 126/126 [==============================] - ETA: 0s - loss: 0.1807 - dice_coef: 0.8340 - iou: 0.7199 - recall_2: 0.8917 - precision_2: 0.9277
# Epoch 12: val_loss improved from 0.29798 to 0.23140, saving model to files/model3.h5
# 126/126 [==============================] - 199s 2s/step - loss: 0.1807 - dice_coef: 0.8340 - iou: 0.7199 - recall_2: 0.8917 - precision_2: 0.9277 - val_loss: 0.2314 - val_dice_coef: 0.7899 - val_iou: 0.6550 - val_recall_2: 0.9005 - val_precision_2: 0.8663 - lr: 1.0000e-04
# Epoch 13/50
# 126/126 [==============================] - ETA: 0s - loss: 0.1637 - dice_coef: 0.8500 - iou: 0.7432 - recall_2: 0.8950 - precision_2: 0.9313
# Epoch 13: val_loss did not improve from 0.23140
# 126/126 [==============================] - 194s 2s/step - loss: 0.1637 - dice_coef: 0.8500 - iou: 0.7432 - recall_2: 0.8950 - precision_2: 0.9313 - val_loss: 0.2730 - val_dice_coef: 0.7719 - val_iou: 0.6358 - val_recall_2: 0.9097 - val_precision_2: 0.7303 - lr: 1.0000e-04
# Epoch 14/50
# 126/126 [==============================] - ETA: 0s - loss: 0.1488 - dice_coef: 0.8643 - iou: 0.7654 - recall_2: 0.8981 - precision_2: 0.9367
# Epoch 14: val_loss did not improve from 0.23140
# 126/126 [==============================] - 194s 2s/step - loss: 0.1488 - dice_coef: 0.8643 - iou: 0.7654 - recall_2: 0.8981 - precision_2: 0.9367 - val_loss: 0.2428 - val_dice_coef: 0.7829 - val_iou: 0.6476 - val_recall_2: 0.7975 - val_precision_2: 0.8810 - lr: 1.0000e-04
# Epoch 15/50
# 126/126 [==============================] - ETA: 0s - loss: 0.1403 - dice_coef: 0.8725 - iou: 0.7782 - recall_2: 0.8979 - precision_2: 0.9370
# Epoch 15: val_loss did not improve from 0.23140
# 126/126 [==============================] - 194s 2s/step - loss: 0.1403 - dice_coef: 0.8725 - iou: 0.7782 - recall_2: 0.8979 - precision_2: 0.9370 - val_loss: 0.2470 - val_dice_coef: 0.7792 - val_iou: 0.6421 - val_recall_2: 0.8436 - val_precision_2: 0.8195 - lr: 1.0000e-04
# Epoch 16/50
# 126/126 [==============================] - ETA: 0s - loss: 0.1453 - dice_coef: 0.8692 - iou: 0.7750 - recall_2: 0.8818 - precision_2: 0.9331
# Epoch 16: val_loss did not improve from 0.23140
# 126/126 [==============================] - 194s 2s/step - loss: 0.1453 - dice_coef: 0.8692 - iou: 0.7750 - recall_2: 0.8818 - precision_2: 0.9331 - val_loss: 1.9124 - val_dice_coef: 0.1989 - val_iou: 0.1225 - val_recall_2: 0.9847 - val_precision_2: 0.0704 - lr: 1.0000e-04
# Epoch 17/50
# 126/126 [==============================] - ETA: 0s - loss: 0.1332 - dice_coef: 0.8805 - iou: 0.7917 - recall_2: 0.8846 - precision_2: 0.9391
# Epoch 17: val_loss did not improve from 0.23140
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 126/126 [==============================] - 194s 2s/step - loss: 0.1332 - dice_coef: 0.8805 - iou: 0.7917 - recall_2: 0.8846 - precision_2: 0.9391 - val_loss: 0.2436 - val_dice_coef: 0.7870 - val_iou: 0.6589 - val_recall_2: 0.8501 - val_precision_2: 0.8023 - lr: 1.0000e-04
# Epoch 18/50
# 126/126 [==============================] - ETA: 0s - loss: 0.1167 - dice_coef: 0.8947 - iou: 0.8138 - recall_2: 0.9040 - precision_2: 0.9471
# Epoch 18: val_loss did not improve from 0.23140
# 126/126 [==============================] - 194s 2s/step - loss: 0.1167 - dice_coef: 0.8947 - iou: 0.8138 - recall_2: 0.9040 - precision_2: 0.9471 - val_loss: 0.2407 - val_dice_coef: 0.7919 - val_iou: 0.6693 - val_recall_2: 0.8657 - val_precision_2: 0.7861 - lr: 1.0000e-05
# Epoch 19/50
# 126/126 [==============================] - ETA: 0s - loss: 0.1094 - dice_coef: 0.9010 - iou: 0.8238 - recall_2: 0.9091 - precision_2: 0.9548
# Epoch 19: val_loss did not improve from 0.23140
# 126/126 [==============================] - 194s 2s/step - loss: 0.1094 - dice_coef: 0.9010 - iou: 0.8238 - recall_2: 0.9091 - precision_2: 0.9548 - val_loss: 0.2336 - val_dice_coef: 0.7961 - val_iou: 0.6740 - val_recall_2: 0.8605 - val_precision_2: 0.8023 - lr: 1.0000e-05
# Epoch 20/50
# 126/126 [==============================] - ETA: 0s - loss: 0.1063 - dice_coef: 0.9037 - iou: 0.8281 - recall_2: 0.9108 - precision_2: 0.9578
# Epoch 20: val_loss improved from 0.23140 to 0.22348, saving model to files/model3.h5
# 126/126 [==============================] - 199s 2s/step - loss: 0.1063 - dice_coef: 0.9037 - iou: 0.8281 - recall_2: 0.9108 - precision_2: 0.9578 - val_loss: 0.2235 - val_dice_coef: 0.8036 - val_iou: 0.6840 - val_recall_2: 0.8566 - val_precision_2: 0.8295 - lr: 1.0000e-05
# Epoch 21/50
# 126/126 [==============================] - ETA: 0s - loss: 0.1038 - dice_coef: 0.9059 - iou: 0.8315 - recall_2: 0.9124 - precision_2: 0.9599
# Epoch 21: val_loss improved from 0.22348 to 0.21860, saving model to files/model3.h5
# 126/126 [==============================] - 199s 2s/step - loss: 0.1038 - dice_coef: 0.9059 - iou: 0.8315 - recall_2: 0.9124 - precision_2: 0.9599 - val_loss: 0.2186 - val_dice_coef: 0.8084 - val_iou: 0.6909 - val_recall_2: 0.8598 - val_precision_2: 0.8379 - lr: 1.0000e-05
# Epoch 22/50
# 126/126 [==============================] - ETA: 0s - loss: 0.1017 - dice_coef: 0.9078 - iou: 0.8345 - recall_2: 0.9139 - precision_2: 0.9614
# Epoch 22: val_loss improved from 0.21860 to 0.21472, saving model to files/model3.h5
# 126/126 [==============================] - 197s 2s/step - loss: 0.1017 - dice_coef: 0.9078 - iou: 0.8345 - recall_2: 0.9139 - precision_2: 0.9614 - val_loss: 0.2147 - val_dice_coef: 0.8118 - val_iou: 0.6956 - val_recall_2: 0.8609 - val_precision_2: 0.8451 - lr: 1.0000e-05
# Epoch 23/50
# 126/126 [==============================] - ETA: 0s - loss: 0.0995 - dice_coef: 0.9098 - iou: 0.8376 - recall_2: 0.9157 - precision_2: 0.9627
# Epoch 23: val_loss improved from 0.21472 to 0.21365, saving model to files/model3.h5
# 126/126 [==============================] - 197s 2s/step - loss: 0.0995 - dice_coef: 0.9098 - iou: 0.8376 - recall_2: 0.9157 - precision_2: 0.9627 - val_loss: 0.2136 - val_dice_coef: 0.8125 - val_iou: 0.6965 - val_recall_2: 0.8610 - val_precision_2: 0.8463 - lr: 1.0000e-05
# Epoch 24/50
# 126/126 [==============================] - ETA: 0s - loss: 0.0973 - dice_coef: 0.9116 - iou: 0.8407 - recall_2: 0.9181 - precision_2: 0.9638
# Epoch 24: val_loss improved from 0.21365 to 0.21358, saving model to files/model3.h5
# 126/126 [==============================] - 197s 2s/step - loss: 0.0973 - dice_coef: 0.9116 - iou: 0.8407 - recall_2: 0.9181 - precision_2: 0.9638 - val_loss: 0.2136 - val_dice_coef: 0.8137 - val_iou: 0.6982 - val_recall_2: 0.8655 - val_precision_2: 0.8392 - lr: 1.0000e-05
# Epoch 25/50
# 126/126 [==============================] - ETA: 0s - loss: 0.0951 - dice_coef: 0.9136 - iou: 0.8438 - recall_2: 0.9199 - precision_2: 0.9652
# Epoch 25: val_loss improved from 0.21358 to 0.21311, saving model to files/model3.h5
# 126/126 [==============================] - 197s 2s/step - loss: 0.0951 - dice_coef: 0.9136 - iou: 0.8438 - recall_2: 0.9199 - precision_2: 0.9652 - val_loss: 0.2131 - val_dice_coef: 0.8144 - val_iou: 0.6994 - val_recall_2: 0.8661 - val_precision_2: 0.8378 - lr: 1.0000e-05
# Epoch 26/50
# 126/126 [==============================] - ETA: 0s - loss: 0.0932 - dice_coef: 0.9153 - iou: 0.8466 - recall_2: 0.9215 - precision_2: 0.9661
# Epoch 26: val_loss improved from 0.21311 to 0.21283, saving model to files/model3.h5
# 126/126 [==============================] - 197s 2s/step - loss: 0.0932 - dice_coef: 0.9153 - iou: 0.8466 - recall_2: 0.9215 - precision_2: 0.9661 - val_loss: 0.2128 - val_dice_coef: 0.8149 - val_iou: 0.7001 - val_recall_2: 0.8654 - val_precision_2: 0.8378 - lr: 1.0000e-05
# Epoch 27/50
# 126/126 [==============================] - ETA: 0s - loss: 0.0913 - dice_coef: 0.9170 - iou: 0.8494 - recall_2: 0.9231 - precision_2: 0.9670
# Epoch 27: val_loss improved from 0.21283 to 0.21075, saving model to files/model3.h5
# 126/126 [==============================] - 197s 2s/step - loss: 0.0913 - dice_coef: 0.9170 - iou: 0.8494 - recall_2: 0.9231 - precision_2: 0.9670 - val_loss: 0.2107 - val_dice_coef: 0.8170 - val_iou: 0.7032 - val_recall_2: 0.8657 - val_precision_2: 0.8398 - lr: 1.0000e-05
# Epoch 28/50
# 126/126 [==============================] - ETA: 0s - loss: 0.0893 - dice_coef: 0.9187 - iou: 0.8523 - recall_2: 0.9250 - precision_2: 0.9678
# Epoch 28: val_loss improved from 0.21075 to 0.20801, saving model to files/model3.h5
# 126/126 [==============================] - 197s 2s/step - loss: 0.0893 - dice_coef: 0.9187 - iou: 0.8523 - recall_2: 0.9250 - precision_2: 0.9678 - val_loss: 0.2080 - val_dice_coef: 0.8196 - val_iou: 0.7066 - val_recall_2: 0.8667 - val_precision_2: 0.8431 - lr: 1.0000e-05
# Epoch 29/50
# 126/126 [==============================] - ETA: 0s - loss: 0.0871 - dice_coef: 0.9207 - iou: 0.8554 - recall_2: 0.9275 - precision_2: 0.9686
# Epoch 29: val_loss improved from 0.20801 to 0.20425, saving model to files/model3.h5
# 126/126 [==============================] - 197s 2s/step - loss: 0.0871 - dice_coef: 0.9207 - iou: 0.8554 - recall_2: 0.9275 - precision_2: 0.9686 - val_loss: 0.2043 - val_dice_coef: 0.8223 - val_iou: 0.7099 - val_recall_2: 0.8660 - val_precision_2: 0.8493 - lr: 1.0000e-05
# Epoch 30/50
# 126/126 [==============================] - ETA: 0s - loss: 0.0851 - dice_coef: 0.9224 - iou: 0.8584 - recall_2: 0.9302 - precision_2: 0.9690
# Epoch 30: val_loss improved from 0.20425 to 0.20386, saving model to files/model3.h5
# 126/126 [==============================] - 197s 2s/step - loss: 0.0851 - dice_coef: 0.9224 - iou: 0.8584 - recall_2: 0.9302 - precision_2: 0.9690 - val_loss: 0.2039 - val_dice_coef: 0.8228 - val_iou: 0.7110 - val_recall_2: 0.8628 - val_precision_2: 0.8538 - lr: 1.0000e-05
# Epoch 31/50
# 126/126 [==============================] - ETA: 0s - loss: 0.0830 - dice_coef: 0.9243 - iou: 0.8614 - recall_2: 0.9323 - precision_2: 0.9700
# Epoch 31: val_loss improved from 0.20386 to 0.20201, saving model to files/model3.h5
# 126/126 [==============================] - 197s 2s/step - loss: 0.0830 - dice_coef: 0.9243 - iou: 0.8614 - recall_2: 0.9323 - precision_2: 0.9700 - val_loss: 0.2020 - val_dice_coef: 0.8234 - val_iou: 0.7126 - val_recall_2: 0.8566 - val_precision_2: 0.8661 - lr: 1.0000e-05
# Epoch 32/50
# 126/126 [==============================] - ETA: 0s - loss: 0.0805 - dice_coef: 0.9264 - iou: 0.8651 - recall_2: 0.9353 - precision_2: 0.9711
# Epoch 32: val_loss did not improve from 0.20201
# 126/126 [==============================] - 194s 2s/step - loss: 0.0805 - dice_coef: 0.9264 - iou: 0.8651 - recall_2: 0.9353 - precision_2: 0.9711 - val_loss: 0.2053 - val_dice_coef: 0.8205 - val_iou: 0.7081 - val_recall_2: 0.8588 - val_precision_2: 0.8593 - lr: 1.0000e-05
# Epoch 33/50
# 126/126 [==============================] - ETA: 0s - loss: 0.0783 - dice_coef: 0.9284 - iou: 0.8683 - recall_2: 0.9374 - precision_2: 0.9719
# Epoch 33: val_loss did not improve from 0.20201
# 126/126 [==============================] - 194s 2s/step - loss: 0.0783 - dice_coef: 0.9284 - iou: 0.8683 - recall_2: 0.9374 - precision_2: 0.9719 - val_loss: 0.2070 - val_dice_coef: 0.8192 - val_iou: 0.7061 - val_recall_2: 0.8598 - val_precision_2: 0.8543 - lr: 1.0000e-05
# Epoch 34/50
# 126/126 [==============================] - ETA: 0s - loss: 0.0764 - dice_coef: 0.9301 - iou: 0.8713 - recall_2: 0.9391 - precision_2: 0.9728
# Epoch 34: val_loss did not improve from 0.20201
# 126/126 [==============================] - 194s 2s/step - loss: 0.0764 - dice_coef: 0.9301 - iou: 0.8713 - recall_2: 0.9391 - precision_2: 0.9728 - val_loss: 0.2059 - val_dice_coef: 0.8203 - val_iou: 0.7079 - val_recall_2: 0.8592 - val_precision_2: 0.8563 - lr: 1.0000e-05
# Epoch 35/50
# 126/126 [==============================] - ETA: 0s - loss: 0.0744 - dice_coef: 0.9319 - iou: 0.8744 - recall_2: 0.9408 - precision_2: 0.9738
# Epoch 35: val_loss did not improve from 0.20201
# 126/126 [==============================] - 194s 2s/step - loss: 0.0744 - dice_coef: 0.9319 - iou: 0.8744 - recall_2: 0.9408 - precision_2: 0.9738 - val_loss: 0.2063 - val_dice_coef: 0.8201 - val_iou: 0.7074 - val_recall_2: 0.8591 - val_precision_2: 0.8551 - lr: 1.0000e-05
# Epoch 36/50
# 126/126 [==============================] - ETA: 0s - loss: 0.0725 - dice_coef: 0.9336 - iou: 0.8774 - recall_2: 0.9421 - precision_2: 0.9748
# Epoch 36: val_loss did not improve from 0.20201
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1e-06.
# 126/126 [==============================] - 194s 2s/step - loss: 0.0725 - dice_coef: 0.9336 - iou: 0.8774 - recall_2: 0.9421 - precision_2: 0.9748 - val_loss: 0.2033 - val_dice_coef: 0.8227 - val_iou: 0.7114 - val_recall_2: 0.8599 - val_precision_2: 0.8588 - lr: 1.0000e-05
# Epoch 37/50
# 126/126 [==============================] - ETA: 0s - loss: 0.0707 - dice_coef: 0.9351 - iou: 0.8798 - recall_2: 0.9439 - precision_2: 0.9757
# Epoch 37: val_loss did not improve from 0.20201
# 126/126 [==============================] - 194s 2s/step - loss: 0.0707 - dice_coef: 0.9351 - iou: 0.8798 - recall_2: 0.9439 - precision_2: 0.9757 - val_loss: 0.2071 - val_dice_coef: 0.8206 - val_iou: 0.7083 - val_recall_2: 0.8646 - val_precision_2: 0.8470 - lr: 1.0000e-06
# Epoch 38/50
# 126/126 [==============================] - ETA: 0s - loss: 0.0700 - dice_coef: 0.9357 - iou: 0.8809 - recall_2: 0.9447 - precision_2: 0.9762
# Epoch 38: val_loss did not improve from 0.20201
# 126/126 [==============================] - 194s 2s/step - loss: 0.0700 - dice_coef: 0.9357 - iou: 0.8809 - recall_2: 0.9447 - precision_2: 0.9762 - val_loss: 0.2084 - val_dice_coef: 0.8197 - val_iou: 0.7070 - val_recall_2: 0.8654 - val_precision_2: 0.8435 - lr: 1.0000e-06
# Epoch 39/50
# 126/126 [==============================] - ETA: 0s - loss: 0.0696 - dice_coef: 0.9361 - iou: 0.8815 - recall_2: 0.9449 - precision_2: 0.9766
# Epoch 39: val_loss did not improve from 0.20201
# 126/126 [==============================] - 194s 2s/step - loss: 0.0696 - dice_coef: 0.9361 - iou: 0.8815 - recall_2: 0.9449 - precision_2: 0.9766 - val_loss: 0.2085 - val_dice_coef: 0.8196 - val_iou: 0.7069 - val_recall_2: 0.8656 - val_precision_2: 0.8435 - lr: 1.0000e-06
# Epoch 40/50
# 126/126 [==============================] - ETA: 0s - loss: 0.0693 - dice_coef: 0.9364 - iou: 0.8820 - recall_2: 0.9451 - precision_2: 0.9769
# Epoch 40: val_loss did not improve from 0.20201
# 126/126 [==============================] - 194s 2s/step - loss: 0.0693 - dice_coef: 0.9364 - iou: 0.8820 - recall_2: 0.9451 - precision_2: 0.9769 - val_loss: 0.2083 - val_dice_coef: 0.8198 - val_iou: 0.7071 - val_recall_2: 0.8656 - val_precision_2: 0.8436 - lr: 1.0000e-06
# Epoch 41/50
# 126/126 [==============================] - ETA: 0s - loss: 0.0690 - dice_coef: 0.9367 - iou: 0.8825 - recall_2: 0.9453 - precision_2: 0.9771
# Epoch 41: val_loss did not improve from 0.20201
# 126/126 [==============================] - 194s 2s/step - loss: 0.0690 - dice_coef: 0.9367 - iou: 0.8825 - recall_2: 0.9453 - precision_2: 0.9771 - val_loss: 0.2082 - val_dice_coef: 0.8199 - val_iou: 0.7073 - val_recall_2: 0.8656 - val_precision_2: 0.8439 - lr: 1.0000e-06

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 1
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model4.h5")
csv_path = os.path.join("files", "data4.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model4 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 1024], strides=[1, 1, 2, 2])

model4.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model4.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 252 - 252
# Valid: 9 - 9
# Epoch 1/50
# 252/252 [==============================] - ETA: 0s - loss: 0.8811 - dice_coef: 0.2398 - iou: 0.1395 - recall: 0.8390 - precision: 0.5453
# Epoch 1: val_loss improved from inf to 1.19428, saving model to files/model4.h5
# 252/252 [==============================] - 561s 2s/step - loss: 0.8811 - dice_coef: 0.2398 - iou: 0.1395 - recall: 0.8390 - precision: 0.5453 - val_loss: 1.1943 - val_dice_coef: 0.0117 - val_iou: 0.0059 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 2/50
# 252/252 [==============================] - ETA: 0s - loss: 0.6284 - dice_coef: 0.4189 - iou: 0.2688 - recall: 0.8925 - precision: 0.8366
# Epoch 2: val_loss did not improve from 1.19428
# 252/252 [==============================] - 503s 2s/step - loss: 0.6284 - dice_coef: 0.4189 - iou: 0.2688 - recall: 0.8925 - precision: 0.8366 - val_loss: 1.3687 - val_dice_coef: 0.0699 - val_iou: 0.0367 - val_recall: 0.7829 - val_precision: 0.0508 - lr: 1.0000e-04
# Epoch 3/50
# 252/252 [==============================] - ETA: 0s - loss: 0.4635 - dice_coef: 0.5669 - iou: 0.4014 - recall: 0.8883 - precision: 0.8705
# Epoch 3: val_loss improved from 1.19428 to 0.82583, saving model to files/model4.h5
# 252/252 [==============================] - 507s 2s/step - loss: 0.4635 - dice_coef: 0.5669 - iou: 0.4014 - recall: 0.8883 - precision: 0.8705 - val_loss: 0.8258 - val_dice_coef: 0.3770 - val_iou: 0.2496 - val_recall: 0.8782 - val_precision: 0.2267 - lr: 1.0000e-04
# Epoch 4/50
# 252/252 [==============================] - ETA: 0s - loss: 0.3447 - dice_coef: 0.6785 - iou: 0.5206 - recall: 0.8822 - precision: 0.8818
# Epoch 4: val_loss did not improve from 0.82583
# 252/252 [==============================] - 504s 2s/step - loss: 0.3447 - dice_coef: 0.6785 - iou: 0.5206 - recall: 0.8822 - precision: 0.8818 - val_loss: 2.4122 - val_dice_coef: 0.2401 - val_iou: 0.1546 - val_recall: 0.9398 - val_precision: 0.0635 - lr: 1.0000e-04
# Epoch 5/50
# 252/252 [==============================] - ETA: 0s - loss: 0.2574 - dice_coef: 0.7616 - iou: 0.6238 - recall: 0.8828 - precision: 0.9045
# Epoch 5: val_loss improved from 0.82583 to 0.45226, saving model to files/model4.h5
# 252/252 [==============================] - 506s 2s/step - loss: 0.2574 - dice_coef: 0.7616 - iou: 0.6238 - recall: 0.8828 - precision: 0.9045 - val_loss: 0.4523 - val_dice_coef: 0.5838 - val_iou: 0.4368 - val_recall: 0.7734 - val_precision: 0.6612 - lr: 1.0000e-04
# Epoch 6/50
# 252/252 [==============================] - ETA: 0s - loss: 0.2018 - dice_coef: 0.8146 - iou: 0.6964 - recall: 0.8885 - precision: 0.9165
# Epoch 6: val_loss did not improve from 0.45226
# 252/252 [==============================] - 504s 2s/step - loss: 0.2018 - dice_coef: 0.8146 - iou: 0.6964 - recall: 0.8885 - precision: 0.9165 - val_loss: 0.6470 - val_dice_coef: 0.5028 - val_iou: 0.3707 - val_recall: 0.8921 - val_precision: 0.3125 - lr: 1.0000e-04
# Epoch 7/50
# 252/252 [==============================] - ETA: 0s - loss: 0.1716 - dice_coef: 0.8441 - iou: 0.7402 - recall: 0.8828 - precision: 0.9237
# Epoch 7: val_loss did not improve from 0.45226
# 252/252 [==============================] - 503s 2s/step - loss: 0.1716 - dice_coef: 0.8441 - iou: 0.7402 - recall: 0.8828 - precision: 0.9237 - val_loss: 0.6939 - val_dice_coef: 0.5454 - val_iou: 0.4131 - val_recall: 0.8659 - val_precision: 0.1954 - lr: 1.0000e-04
# Epoch 8/50
# 252/252 [==============================] - ETA: 0s - loss: 0.1486 - dice_coef: 0.8658 - iou: 0.7737 - recall: 0.8895 - precision: 0.9273
# Epoch 8: val_loss did not improve from 0.45226
# 252/252 [==============================] - 503s 2s/step - loss: 0.1486 - dice_coef: 0.8658 - iou: 0.7737 - recall: 0.8895 - precision: 0.9273 - val_loss: 0.8940 - val_dice_coef: 0.5080 - val_iou: 0.3867 - val_recall: 0.8819 - val_precision: 0.1503 - lr: 1.0000e-04
# Epoch 9/50
# 252/252 [==============================] - ETA: 0s - loss: 0.1419 - dice_coef: 0.8731 - iou: 0.7863 - recall: 0.8855 - precision: 0.9263
# Epoch 9: val_loss did not improve from 0.45226
# 252/252 [==============================] - 503s 2s/step - loss: 0.1419 - dice_coef: 0.8731 - iou: 0.7863 - recall: 0.8855 - precision: 0.9263 - val_loss: 4.1086 - val_dice_coef: 0.0999 - val_iou: 0.0536 - val_recall: 0.9817 - val_precision: 0.0412 - lr: 1.0000e-04
# Epoch 10/50
# 252/252 [==============================] - ETA: 0s - loss: 0.1325 - dice_coef: 0.8832 - iou: 0.8024 - recall: 0.8872 - precision: 0.9272
# Epoch 10: val_loss did not improve from 0.45226
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.999999747378752e
# Epoch 17/50
# 252/252 [==============================] - ETA: 0s - loss: 0.0857 - dice_coef: 0.9231 - iou: 0.8632 - recall: 0.9213 - precision: 0.9615
# Epoch 17: val_loss did not improve from 0.41407
# 252/252 [==============================] - 503s 2s/step - loss: 0.0857 - dice_coef: 0.9231 - iou: 0.8632 - recall: 0.9213 - precision: 0.9615 - val_loss: 0.4294 - val_dice_coef: 0.6327 - val_iou: 0.5035 - val_recall: 0.7614 - val_precision: 0.5166 - lr: 1.0000e-06
# Epoch 18/50
# 252/252 [==============================] - ETA: 0s - loss: 0.0841 - dice_coef: 0.9244 - iou: 0.8651 - recall: 0.9225 - precision: 0.9624
# Epoch 18: val_loss did not improve from 0.41407
# 252/252 [==============================] - 503s 2s/step - loss: 0.0841 - dice_coef: 0.9244 - iou: 0.8651 - recall: 0.9225 - precision: 0.9624 - val_loss: 0.4519 - val_dice_coef: 0.6120 - val_iou: 0.4805 - val_recall: 0.7517 - val_precision: 0.5002 - lr: 1.0000e-06
# Epoch 19/50
# 252/252 [==============================] - ETA: 0s - loss: 0.0834 - dice_coef: 0.9251 - iou: 0.8661 - recall: 0.9233 - precision: 0.9628
# Epoch 19: val_loss did not improve from 0.41407
# 252/252 [==============================] - 503s 2s/step - loss: 0.0834 - dice_coef: 0.9251 - iou: 0.8661 - recall: 0.9233 - precision: 0.9628 - val_loss: 0.4700 - val_dice_coef: 0.5984 - val_iou: 0.4670 - val_recall: 0.7525 - val_precision: 0.4745 - lr: 1.0000e-06
# Epoch 20/50
# 252/252 [==============================] - ETA: 0s - loss: 0.0828 - dice_coef: 0.9255 - iou: 0.8668 - recall: 0.9239 - precision: 0.9629
# Epoch 20: val_loss did not improve from 0.41407
# 252/252 [==============================] - 503s 2s/step - loss: 0.0828 - dice_coef: 0.9255 - iou: 0.8668 - recall: 0.9239 - precision: 0.9629 - val_loss: 0.4811 - val_dice_coef: 0.5909 - val_iou: 0.4604 - val_recall: 0.7542 - val_precision: 0.4567 - lr: 1.0000e-06
# Epoch 21/50
# 252/252 [==============================] - ETA: 0s - loss: 0.0823 - dice_coef: 0.9260 - iou: 0.8675 - recall: 0.9244 - precision: 0.9631
# Epoch 21: val_loss did not improve from 0.41407
# 252/252 [==============================] - 503s 2s/step - loss: 0.0823 - dice_coef: 0.9260 - iou: 0.8675 - recall: 0.9244 - precision: 0.9631 - val_loss: 0.4880 - val_dice_coef: 0.5864 - val_iou: 0.4566 - val_recall: 0.7546 - val_precision: 0.4468 - lr: 1.0000e-06

# %% [markdown]
# ### Evaluating the Model:

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import pandas as pd
import cv2
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import accuracy_score, f1_score, jaccard_score, precision_score, recall_score
from tensorflow.keras.models import load_model

# %%
H = 512
W = 512

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.float32)
    return ori_x, x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.int32)
    return ori_x, x

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.png")))
    y = sorted(glob(os.path.join(path, "mask", "*.png")))
    return x, y

def save_results(ori_x, ori_y, y_pred, save_image_path):
    line = np.ones((H, 10, 3)) * 255

    ori_y = np.expand_dims(ori_y, axis=-1)
    ori_y = np.concatenate([ori_y, ori_y, ori_y], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1) * 255

    cat_images = np.concatenate([ori_x, line, ori_y, line, y_pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model1.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score1 = [s[1:] for s in SCORE]
score1 = np.mean(score1, axis=0)
print(f"Accuracy: {score1[0]:0.5f}")
print(f"F1: {score1[1]:0.5f}")
print(f"Jaccard: {score1[2]:0.5f}")
print(f"Recall: {score1[3]:0.5f}")
print(f"Precision: {score1[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score1.csv")
# Out:
# 100%|██████████| 9/9 [00:07<00:00,  1.27it/s]
# Accuracy: 0.99723
# F1: 0.87887
# Jaccard: 0.78805
# Recall: 0.94731
# Precision: 0.83841

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model2.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score2 = [s[1:] for s in SCORE]
score2 = np.mean(score2, axis=0)
print(f"Accuracy: {score2[0]:0.5f}")
print(f"F1: {score2[1]:0.5f}")
print(f"Jaccard: {score2[2]:0.5f}")
print(f"Recall: {score2[3]:0.5f}")
print(f"Precision: {score2[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score2.csv")
# Out:
# 100%|██████████| 9/9 [00:04<00:00,  2.04it/s]
# Accuracy: 0.99778
# F1: 0.90579
# Jaccard: 0.83042
# Recall: 0.97170
# Precision: 0.85132

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model3.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score3 = [s[1:] for s in SCORE]
score3 = np.mean(score3, axis=0)
print(f"Accuracy: {score3[0]:0.5f}")
print(f"F1: {score3[1]:0.5f}")
print(f"Jaccard: {score3[2]:0.5f}")
print(f"Recall: {score3[3]:0.5f}")
print(f"Precision: {score3[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score3.csv")
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 100%|██████████| 9/9 [00:10<00:00,  1.18s/it]
# Accuracy: 0.99675
# F1: 0.79778
# Jaccard: 0.72882
# Recall: 0.84631
# Precision: 0.76704

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model4.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score4 = [s[1:] for s in SCORE]
score4 = np.mean(score4, axis=0)
print(f"Accuracy: {score4[0]:0.5f}")
print(f"F1: {score4[1]:0.5f}")
print(f"Jaccard: {score4[2]:0.5f}")
print(f"Recall: {score4[3]:0.5f}")
print(f"Precision: {score4[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score4.csv")
# Out:
# 100%|██████████| 9/9 [00:09<00:00,  1.01s/it]
# Accuracy: 0.99090
# F1: 0.65307
# Jaccard: 0.53760
# Recall: 0.71539
# Precision: 0.77787

# %%
import matplotlib.pyplot as plt

z_dim = [16, 32, 64, 128]
final_score = [score1[1], score2[1], score3[1], score4[1]]

plt.plot(z_dim, final_score)  
plt.xlabel("Latent Dimension Representation")
plt.ylabel("F1-Score")
plt.show()
