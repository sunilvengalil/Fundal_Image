# %% [markdown]
# ### Import the required libraries and modules:

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
import numpy as np

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# %cd /content/gdrive/MyDrive/Blood_Vessel_Results/ALL_BEST_RESULTS/CHASE_OD_4
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/Blood_Vessel_Results/ALL_BEST_RESULTS/CHASE_OD_4

# %% [markdown]
# ### Unzip the data:

# %%
# !unzip new_data.zip

# %% [markdown]
# ### Construct the Model:

# %%
def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(inputs, num_filters, strides=2):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D(strides)(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters, strides=2):
    x = Conv2DTranspose(num_filters, (2, 2), strides=strides, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape, num_filters=[64, 128, 256, 512, 1024], strides=[2, 2, 2, 2]):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, num_filters[0], strides=strides[0])
    s2, p2 = encoder_block(p1, num_filters[1], strides=strides[1])
    s3, p3 = encoder_block(p2, num_filters[2], strides=strides[2])
    s4, p4 = encoder_block(p3, num_filters[3], strides=strides[3])

    b1 = conv_block(p4, num_filters[4])

    d1 = decoder_block(b1, s4, num_filters[3], strides=strides[3])
    d2 = decoder_block(d1, s3, num_filters[2], strides=strides[2])
    d3 = decoder_block(d2, s2, num_filters[1], strides=strides[1])
    d4 = decoder_block(d3, s1, num_filters[0], strides=strides[0])

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="UNET")
    return model

input_shape = (512, 512, 3)
model = build_unet(input_shape)
model.summary()
# Out:
# Model: "UNET"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 512, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 512, 512, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 512, 512, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 512, 512, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 12  0          ['activation_3[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 25  295168      ['max_pooling2d_1[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_4[0][0]']
#  rmalization)                   6)
#
#  activation_4 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_4[0][0]']
#                                 6)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 25  590080      ['activation_4[0][0]']
#                                 6)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_5[0][0]']
#  rmalization)                   6)
#
#  activation_5 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_5[0][0]']
#                                 6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 512)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 512)  2097664    ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 64, 64, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 25  524544     ['activation_11[0][0]']
#  spose)                         6)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 51  0           ['conv2d_transpose_1[0][0]',
#                                 2)                                'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_12 (BatchN  (None, 128, 128, 25  1024       ['conv2d_12[0][0]']
#  ormalization)                  6)
#
#  activation_12 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_12[0][0]']
#                                 6)
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 25  590080      ['activation_12[0][0]']
#                                 6)
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 25  1024       ['conv2d_13[0][0]']
#  ormalization)                  6)
#
#  activation_13 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_13[0][0]']
#                                 6)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 12  131200     ['activation_13[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 256, 256, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  activation_14 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_15 (BatchN  (None, 256, 256, 12  512        ['conv2d_15[0][0]']
#  ormalization)                  8)
#
#  activation_15 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_15[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 64  32832      ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 512, 512, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 512, 512, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 512, 512, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 512, 512, 1)  65          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %% [markdown]
# ### Adding the Metrics:

# %%
def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def DiceBCELoss(y_true, y_pred):

    inputs = tf.keras.layers.Flatten()(y_true)
    targets = tf.keras.layers.Flatten()(y_pred)

    intersection = tf.reduce_sum(inputs * targets)
    dice_loss = 1 - (2.*intersection + smooth)/(tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)
    BCE = tf.keras.losses.BinaryCrossentropy()
    Dice_BCE = BCE(inputs, targets) + dice_loss

    return Dice_BCE

# %% [markdown]
# ### Training the Model:

# %%
H = 512
W = 512

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.png")))
    y = sorted(glob(os.path.join(path, "mask", "*.png")))
    return x, y

def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)
    return x, y

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)              ## (512, 512, 1)
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y, batch_size=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(4)
    return dataset

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 4
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model1.h5")
csv_path = os.path.join("files", "data1.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model1 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 384], strides=[2, 2, 2, 4])

model1.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model1.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 161 - 161
# Valid: 5 - 5
# Epoch 1/50
# 41/41 [==============================] - ETA: 0s - loss: 1.2581 - dice_coef: 0.0711 - iou: 0.0371 - recall: 0.7565 - precision: 0.1250
# Epoch 1: val_loss improved from inf to 1.66017, saving model to files/model1.h5
# 41/41 [==============================] - 84s 2s/step - loss: 1.2581 - dice_coef: 0.0711 - iou: 0.0371 - recall: 0.7565 - precision: 0.1250 - val_loss: 1.6602 - val_dice_coef: 0.0281 - val_iou: 0.0142 - val_recall: 0.2304 - val_precision: 0.0091 - lr: 1.0000e-04
# Epoch 2/50
# 41/41 [==============================] - ETA: 0s - loss: 0.9904 - dice_coef: 0.1468 - iou: 0.0793 - recall: 0.8348 - precision: 0.5567
# Epoch 2: val_loss did not improve from 1.66017
# 41/41 [==============================] - 17s 420ms/step - loss: 0.9904 - dice_coef: 0.1468 - iou: 0.0793 - recall: 0.8348 - precision: 0.5567 - val_loss: 2.6403 - val_dice_coef: 0.0321 - val_iou: 0.0163 - val_recall: 1.0000 - val_precision: 0.0157 - lr: 1.0000e-04
# Epoch 3/50
# 41/41 [==============================] - ETA: 0s - loss: 0.1249 - dice_coef: 0.8797 - iou: 0.7855 - recall: 0.9534 - precision: 0.9715
# Epoch 39: val_loss did not improve from 0.29519
# 41/41 [==============================] - 17s 425ms/step - loss: 0.1249 - dice_coef: 0.8797 - iou: 0.7855 - recall: 0.9534 - precision: 0.9715 - val_loss: 0.3151 - val_dice_coef: 0.7560 - val_iou: 0.6123 - val_recall: 0.6464 - val_precision: 0.9579 - lr: 1.0000e-05
# Epoch 40/50
# 41/41 [==============================] - ETA: 0s - loss: 0.1212 - dice_coef: 0.8831 - iou: 0.7909 - recall: 0.9566 - precision: 0.9747
# Epoch 40: val_loss did not improve from 0.29519
# 41/41 [==============================] - 17s 424ms/step - loss: 0.1212 - dice_coef: 0.8831 - iou: 0.7909 - recall: 0.9566 - precision: 0.9747 - val_loss: 0.3159 - val_dice_coef: 0.7546 - val_iou: 0.6103 - val_recall: 0.6398 - val_precision: 0.9709 - lr: 1.0000e-05
# Epoch 41/50
# 41/41 [==============================] - ETA: 0s - loss: 0.1183 - dice_coef: 0.8858 - iou: 0.7953 - recall: 0.9588 - precision: 0.9773
# Epoch 41: val_loss did not improve from 0.29519
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1e-06.
# 41/41 [==============================] - 17s 424ms/step - loss: 0.1183 - dice_coef: 0.8858 - iou: 0.7953 - recall: 0.9588 - precision: 0.9773 - val_loss: 0.3182 - val_dice_coef: 0.7524 - val_iou: 0.6074 - val_recall: 0.6335 - val_precision: 0.9747 - lr: 1.0000e-05

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 4
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model2.h5")
csv_path = os.path.join("files", "data2.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model2 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 512], strides=[2, 2, 2, 4])

model2.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model2.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 161 - 161
# Valid: 5 - 5
# Epoch 1/50
# 41/41 [==============================] - ETA: 0s - loss: 1.2570 - dice_coef: 0.0716 - iou: 0.0373 - recall_1: 0.7623 - precision_1: 0.1253
# Epoch 1: val_loss improved from inf to 1.66273, saving model to files/model2.h5
# 41/41 [==============================] - 22s 477ms/step - loss: 1.2570 - dice_coef: 0.0716 - iou: 0.0373 - recall_1: 0.7623 - precision_1: 0.1253 - val_loss: 1.6627 - val_dice_coef: 0.0281 - val_iou: 0.0143 - val_recall_1: 0.2550 - val_precision_1: 0.0091 - lr: 1.0000e-04
# Epoch 2/50
# 41/41 [==============================] - ETA: 0s - loss: 0.9919 - dice_coef: 0.1463 - iou: 0.0791 - recall_1: 0.8415 - precision_1: 0.5467
# Epoch 2: val_loss improved from 1.66273 to 1.44948, saving model to files/model2.h5
# 41/41 [==============================] - 20s 494ms/step - loss: 0.9919 - dice_coef: 0.1463 - iou: 0.0791 - recall_1: 0.8415 - precision_1: 0.5467 - val_loss: 1.4495 - val_dice_coef: 0.0288 - val_iou: 0.0146 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 3/50
# 41/41 [==============================] - ETA: 0s - loss: 0.9282 - dice_coef: 0.1835 - iou: 0.1012 - recall_1: 0.8907 - precision_1: 0.6017
# Epoch 3: val_loss improved from 1.44948 to 1.29565, saving model to files/model2.h5
# 41/41 [==============================] - 21s 504ms/step - loss: 0.9282 - dice_coef: 0.1835 - iou: 0.1012 - recall_1: 0.8907 - precision_1: 0.6017 - val_loss: 1.2956 - val_dice_coef: 0.0281 - val_iou: 0.0143 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 4/50
# 41/41 [==============================] - ETA: 0s - loss: 0.8803 - dice_coef: 0.2108 - iou: 0.1180 - recall_1: 0.9143 - precision_1: 0.6312
# Epoch 4: val_loss improved from 1.29565 to 1.19554, saving model to files/model2.h5
# 41/41 [==============================] - 21s 502ms/step - loss: 0.8803 - dice_coef: 0.2108 - iou: 0.1180 - recall_1: 0.9143 - precision_1: 0.6312 - val_loss: 1.1955 - val_dice_coef: 0.0273 - val_iou: 0.0139 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 5/50
# 41/41 [==============================] - ETA: 0s - loss: 0.8451 - dice_coef: 0.2351 - iou: 0.1334 - recall_1: 0.9222 - precision_1: 0.6537
# Epoch 5: val_loss improved from 1.19554 to 1.13917, saving model to files/model2.h5
# 41/41 [==============================] - 20s 489ms/step - loss: 0.8451 - dice_coef: 0.2351 - iou: 0.1334 - recall_1: 0.9222 - precision_1: 0.6537 - val_loss: 1.1392 - val_dice_coef: 0.0279 - val_iou: 0.0142 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 6/50
# 41/41 [==============================] - 18s 426ms/step - loss: 0.1315 - dice_coef: 0.8729 - iou: 0.7747 - recall_1: 0.9588 - precision_1: 0.9730 - val_loss: 0.3226 - val_dice_coef: 0.7423 - val_iou: 0.5935 - val_recall_1: 0.6311 - val_precision_1: 0.9903 - lr: 1.0000e-05

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 4
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model3.h5")
csv_path = os.path.join("files", "data3.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model3 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 768], strides=[2, 2, 2, 4])

model3.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model3.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 161 - 161
# Valid: 5 - 5
# Epoch 1/50
# 41/41 [==============================] - ETA: 0s - loss: 1.2573 - dice_coef: 0.0716 - iou: 0.0373 - recall_2: 0.7597 - precision_2: 0.1255
# Epoch 1: val_loss improved from inf to 1.65902, saving model to files/model3.h5
# 41/41 [==============================] - 22s 470ms/step - loss: 1.2573 - dice_coef: 0.0716 - iou: 0.0373 - recall_2: 0.7597 - precision_2: 0.1255 - val_loss: 1.6590 - val_dice_coef: 0.0281 - val_iou: 0.0143 - val_recall_2: 0.2214 - val_precision_2: 0.0092 - lr: 1.0000e-04
# Epoch 2/50
# 41/41 [==============================] - ETA: 0s - loss: 0.9909 - dice_coef: 0.1473 - iou: 0.0796 - recall_2: 0.8371 - precision_2: 0.5544
# Epoch 2: val_loss did not improve from 1.65902
# 41/41 [==============================] - 18s 430ms/step - loss: 0.9909 - dice_coef: 0.1473 - iou: 0.0796 - recall_2: 0.8371 - precision_2: 0.5544 - val_loss: 2.2410 - val_dice_coef: 0.0310 - val_iou: 0.0158 - val_recall_2: 1.0000 - val_precision_2: 0.0159 - lr: 1.0000e-04
# Epoch 3/50
# 41/41 [==============================] - ETA: 0s - loss: 0.9324 - dice_coef: 0.1823 - iou: 0.1005 - recall_2: 0.8858 - precision_2: 0.5632
# Epoch 3: val_loss improved from 1.65902 to 1.29673, saving model to files/model3.h5
# 41/41 [==============================] - 21s 514ms/step - loss: 0.9324 - dice_coef: 0.1823 - iou: 0.1005 - recall_2: 0.8858 - precision_2: 0.5632 - val_loss: 1.2967 - val_dice_coef: 0.0276 - val_iou: 0.0140 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 4/50
# 41/41 [==============================] - ETA: 0s - loss: 0.8902 - dice_coef: 0.2060 - iou: 0.1150 - recall_2: 0.8950 - precision_2: 0.6205
# Epoch 4: val_loss improved from 1.29673 to 1.18866, saving model to files/model3.h5
# 41/41 [==============================] - 21s 504ms/step - loss: 0.8902 - dice_coef: 0.2060 - iou: 0.1150 - recall_2: 0.8950 - precision_2: 0.6205 - val_loss: 1.1887 - val_dice_coef: 0.0274 - val_iou: 0.0139 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 5/50
# 41/41 [==============================] - ETA: 0s - loss: 0.8468 - dice_coef: 0.2346 - iou: 0.1331 - recall_2: 0.9191 - precision_2: 0.6573
# Epoch 5: val_loss improved from 1.18866 to 1.12258, saving model to files/model3.h5
# 41/41 [==============================] - 21s 514ms/step - loss: 0.8468 - dice_coef: 0.2346 - iou: 0.1331 - recall_2: 0.9191 - precision_2: 0.6573 - val_loss: 1.1226 - val_dice_coef: 0.0276 - val_iou: 0.0140 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 6/50
# 41/41 [==============================] - ETA: 0s - loss: 0.8108 - dice_coef: 0.2600 - iou: 0.1498 - recall_2: 0.9248 - precision_2: 0.6854
# Epoch 6: val_loss improved from 1.12258 to 1.08789, saving model to files/model3.h5
# 41/41 [==============================] - 21s 509ms/step - loss: 0.8108 - dice_coef: 0.2600 - iou: 0.1498 - recall_2: 0.9248 - precision_2: 0.6854 - val_loss: 1.0879 - val_dice_coef: 0.0274 - val_iou: 0.0139 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 7/50
# 41/41 [==============================] - ETA: 0s - loss: 0.7779 - dice_coef: 0.2858 - iou: 0.1671 - recall_2: 0.9349 - precision_2: 0.6870
# Epoch 7: val_loss improved from 1.08789 to 1.07355, saving model to files/model3.h5
# 41/41 [==============================] - 21s 507ms/step - loss: 0.7779 - dice_coef: 0.2858 - iou: 0.1671 - recall_2: 0.9349 - precision_2: 0.6870 - val_loss: 1.0735 - val_dice_coef: 0.0279 - val_iou: 0.0142 - val_recall_2: 0.0000e+00 - val_precision_2: 0.0000e+00 - lr: 1.0000e-04
# Epoch 8/50
# 41/41 [==============================] - ETA: 0s - loss: 0.7376 - dice_coef: 0.3166 - iou: 0.1885 - recall_2: 0.9440 - precision_2: 0.7412
# Epoch 14/50
# 41/41 [==============================] - ETA: 0s - loss: 0.5454 - dice_coef: 0.4832 - iou: 0.3195 - recall_2: 0.9443 - precision_2: 0.8235
# Epoch 14: val_loss improved from 0.80207 to 0.72986, saving model to files/model3.h5
# 41/41 [==============================] - 21s 510ms/step - loss: 0.5454 - dice_coef: 0.4832 - iou: 0.3195 - recall_2: 0.9443 - precision_2: 0.8235 - val_loss: 0.7299 - val_dice_coef: 0.3529 - val_iou: 0.2158 - val_recall_2: 0.4625 - val_precision_2: 0.9732 - lr: 1.0000e-04
# Epoch 15/50
# 41/41 [==============================] - ETA: 0s - loss: 0.5163 - dice_coef: 0.5100 - iou: 0.3432 - recall_2: 0.9404 - precision_2: 0.8296
# Epoch 15: val_loss improved from 0.72986 to 0.70690, saving model to files/model3.h5
# 41/41 [==============================] - 22s 516ms/step - loss: 0.5163 - dice_coef: 0.5100 - iou: 0.3432 - recall_2: 0.9404 - precision_2: 0.8296 - val_loss: 0.7069 - val_dice_coef: 0.3177 - val_iou: 0.1895 - val_recall_2: 0.4681 - val_precision_2: 0.8956 - lr: 1.0000e-04
# Epoch 16/50
# 41/41 [==============================] - ETA: 0s - loss: 0.4828 - dice_coef: 0.5402 - iou: 0.3711 - recall_2: 0.9422 - precision_2: 0.8510
# Epoch 16: val_loss improved from 0.70690 to 0.65416, saving model to files/model3.h5
# 41/41 [==============================] - 21s 514ms/step - loss: 0.4828 - dice_coef: 0.5402 - iou: 0.3711 - recall_2: 0.9422 - precision_2: 0.8510 - val_loss: 0.6542 - val_dice_coef: 0.3793 - val_iou: 0.2343 - val_recall_2: 0.5322 - val_precision_2: 0.8250 - lr: 1.0000e-04
# Epoch 17/50
# 41/41 [==============================] - ETA: 0s - loss: 0.4526 - dice_coef: 0.5681 - iou: 0.3978 - recall_2: 0.9403 - precision_2: 0.8632
# Epoch 17: val_loss improved from 0.65416 to 0.59085, saving model to files/model3.h5
# 41/41 [==============================] - 21s 504ms/step - loss: 0.4526 - dice_coef: 0.5681 - iou: 0.3978 - recall_2: 0.9403 - precision_2: 0.8632 - val_loss: 0.5909 - val_dice_coef: 0.4457 - val_iou: 0.2870 - val_recall_2: 0.6013 - val_precision_2: 0.8307 - lr: 1.0000e-04
# Epoch 18/50
# 41/41 [==============================] - ETA: 0s - loss: 0.4347 - dice_coef: 0.5859 - iou: 0.4152 - recall_2: 0.9291 - precision_2: 0.8521
# Epoch 18: val_loss improved from 0.59085 to 0.51880, saving model to files/model3.h5
# 41/41 [==============================] - 21s 511ms/step - loss: 0.4347 - dice_coef: 0.5859 - iou: 0.4152 - recall_2: 0.9291 - precision_2: 0.8521 - val_loss: 0.5188 - val_dice_coef: 0.5229 - val_iou: 0.3541 - val_recall_2: 0.6590 - val_precision_2: 0.8661 - lr: 1.0000e-04
# Epoch 19/50
# 41/41 [==============================] - ETA: 0s - loss: 0.4134 - dice_coef: 0.6064 - iou: 0.4359 - recall_2: 0.9241 - precision_2: 0.8508
# Epoch 19: val_loss did not improve from 0.51880
# 41/41 [==============================] - 18s 429ms/step - loss: 0.4134 - dice_coef: 0.6064 - iou: 0.4359 - recall_2: 0.9241 - precision_2: 0.8508 - val_loss: 0.5561 - val_dice_coef: 0.5574 - val_iou: 0.3929 - val_recall_2: 0.7550 - val_precision_2: 0.5499 - lr: 1.0000e-04
# Epoch 20/50
# 41/41 [==============================] - ETA: 0s - loss: 0.3881 - dice_coef: 0.6297 - iou: 0.4604 - recall_2: 0.9238 - precision_2: 0.8588
# Epoch 20: val_loss improved from 0.51880 to 0.46295, saving model to files/model3.h5
# 41/41 [==============================] - 22s 543ms/step - loss: 0.3881 - dice_coef: 0.6297 - iou: 0.4604 - recall_2: 0.9238 - precision_2: 0.8588 - val_loss: 0.4630 - val_dice_coef: 0.6067 - val_iou: 0.4367 - val_recall_2: 0.7580 - val_precision_2: 0.7784 - lr: 1.0000e-04
# Epoch 21/50
# 41/41 [==============================] - ETA: 0s - loss: 0.3541 - dice_coef: 0.6613 - iou: 0.4949 - recall_2: 0.9331 - precision_2: 0.8872
# Epoch 21: val_loss improved from 0.46295 to 0.45708, saving model to files/model3.h5
# 41/41 [==============================] - 23s 559ms/step - loss: 0.3541 - dice_coef: 0.6613 - iou: 0.4949 - recall_2: 0.9331 - precision_2: 0.8872 - val_loss: 0.4571 - val_dice_coef: 0.6205 - val_iou: 0.4537 - val_recall_2: 0.6666 - val_precision_2: 0.9079 - lr: 1.0000e-04
# Epoch 22/50
# 41/41 [==============================] - ETA: 0s - loss: 0.3358 - dice_coef: 0.6793 - iou: 0.5151 - recall_2: 0.9286 - precision_2: 0.8862
# Epoch 22: val_loss improved from 0.45708 to 0.43420, saving model to files/model3.h5
# 41/41 [==============================] - 22s 528ms/step - loss: 0.3358 - dice_coef: 0.6793 - iou: 0.5151 - recall_2: 0.9286 - precision_2: 0.8862 - val_loss: 0.4342 - val_dice_coef: 0.6414 - val_iou: 0.4765 - val_recall_2: 0.6484 - val_precision_2: 0.9301 - lr: 1.0000e-04
# Epoch 23/50
# 41/41 [==============================] - ETA: 0s - loss: 0.3176 - dice_coef: 0.6950 - iou: 0.5337 - recall_2: 0.9258 - precision_2: 0.8887
# Epoch 23: val_loss improved from 0.43420 to 0.42547, saving model to files/model3.h5
# 41/41 [==============================] - 21s 508ms/step - loss: 0.3176 - dice_coef: 0.6950 - iou: 0.5337 - recall_2: 0.9258 - precision_2: 0.8887 - val_loss: 0.4255 - val_dice_coef: 0.6342 - val_iou: 0.4650 - val_recall_2: 0.7427 - val_precision_2: 0.7560 - lr: 1.0000e-04
# Epoch 24/50
# 41/41 [==============================] - ETA: 0s - loss: 0.2958 - dice_coef: 0.7170 - iou: 0.5597 - recall_2: 0.9333 - precision_2: 0.8933
# Epoch 24: val_loss did not improve from 0.42547
# 41/41 [==============================] - 18s 430ms/step - loss: 0.2958 - dice_coef: 0.7170 - iou: 0.5597 - recall_2: 0.9333 - precision_2: 0.8933 - val_loss: 0.4540 - val_dice_coef: 0.5952 - val_iou: 0.4239 - val_recall_2: 0.6420 - val_precision_2: 0.7981 - lr: 1.0000e-04
# Epoch 25/50
# 41/41 [==============================] - ETA: 0s - loss: 0.2801 - dice_coef: 0.7321 - iou: 0.5783 - recall_2: 0.9276 - precision_2: 0.9012
# Epoch 25: val_loss did not improve from 0.42547
# 41/41 [==============================] - 18s 431ms/step - loss: 0.2801 - dice_coef: 0.7321 - iou: 0.5783 - recall_2: 0.9276 - precision_2: 0.9012 - val_loss: 0.4858 - val_dice_coef: 0.6115 - val_iou: 0.4475 - val_recall_2: 0.5548 - val_precision_2: 0.8986 - lr: 1.0000e-04
# Epoch 26/50
# 41/41 [==============================] - ETA: 0s - loss: 0.2583 - dice_coef: 0.7527 - iou: 0.6041 - recall_2: 0.9314 - precision_2: 0.9146
# Epoch 26: val_loss improved from 0.42547 to 0.41532, saving model to files/model3.h5
# 41/41 [==============================] - 21s 522ms/step - loss: 0.2583 - dice_coef: 0.7527 - iou: 0.6041 - recall_2: 0.9314 - precision_2: 0.9146 - val_loss: 0.4153 - val_dice_coef: 0.6625 - val_iou: 0.4989 - val_recall_2: 0.6587 - val_precision_2: 0.8371 - lr: 1.0000e-04
# Epoch 27/50
# 41/41 [==============================] - ETA: 0s - loss: 0.2524 - dice_coef: 0.7592 - iou: 0.6127 - recall_2: 0.9240 - precision_2: 0.9067
# Epoch 27: val_loss improved from 0.41532 to 0.37606, saving model to files/model3.h5
# 41/41 [==============================] - 21s 508ms/step - loss: 0.2524 - dice_coef: 0.7592 - iou: 0.6127 - recall_2: 0.9240 - precision_2: 0.9067 - val_loss: 0.3761 - val_dice_coef: 0.6811 - val_iou: 0.5180 - val_recall_2: 0.6794 - val_precision_2: 0.8653 - lr: 1.0000e-04
# Epoch 28/50
# 41/41 [==============================] - ETA: 0s - loss: 0.2516 - dice_coef: 0.7611 - iou: 0.6152 - recall_2: 0.9142 - precision_2: 0.8935
# Epoch 28: val_loss did not improve from 0.37606
# 41/41 [==============================] - 18s 430ms/step - loss: 0.2516 - dice_coef: 0.7611 - iou: 0.6152 - recall_2: 0.9142 - precision_2: 0.8935 - val_loss: 0.4031 - val_dice_coef: 0.6882 - val_iou: 0.5325 - val_recall_2: 0.6357 - val_precision_2: 0.8553 - lr: 1.0000e-04
# Epoch 29/50
# 41/41 [==============================] - ETA: 0s - loss: 0.2365 - dice_coef: 0.7748 - iou: 0.6333 - recall_2: 0.9213 - precision_2: 0.8971
# Epoch 29: val_loss did not improve from 0.37606
# 41/41 [==============================] - 18s 429ms/step - loss: 0.2365 - dice_coef: 0.7748 - iou: 0.6333 - recall_2: 0.9213 - precision_2: 0.8971 - val_loss: 0.3780 - val_dice_coef: 0.7098 - val_iou: 0.5588 - val_recall_2: 0.6329 - val_precision_2: 0.9508 - lr: 1.0000e-04
# Epoch 30/50
# 41/41 [==============================] - ETA: 0s - loss: 0.2231 - dice_coef: 0.7878 - iou: 0.6506 - recall_2: 0.9198 - precision_2: 0.9059
# Epoch 30: val_loss improved from 0.37606 to 0.29705, saving model to files/model3.h5
# 41/41 [==============================] - 22s 536ms/step - loss: 0.2231 - dice_coef: 0.7878 - iou: 0.6506 - recall_2: 0.9198 - precision_2: 0.9059 - val_loss: 0.2971 - val_dice_coef: 0.7695 - val_iou: 0.6307 - val_recall_2: 0.7706 - val_precision_2: 0.8861 - lr: 1.0000e-04
# Epoch 31/50
# 41/41 [==============================] - ETA: 0s - loss: 0.2064 - dice_coef: 0.8027 - iou: 0.6710 - recall_2: 0.9248 - precision_2: 0.9180
# Epoch 31: val_loss improved from 0.29705 to 0.28745, saving model to files/model3.h5
# 41/41 [==============================] - 21s 513ms/step - loss: 0.2064 - dice_coef: 0.8027 - iou: 0.6710 - recall_2: 0.9248 - precision_2: 0.9180 - val_loss: 0.2875 - val_dice_coef: 0.7805 - val_iou: 0.6457 - val_recall_2: 0.7882 - val_precision_2: 0.8601 - lr: 1.0000e-04
# Epoch 32/50
# 41/41 [==============================] - ETA: 0s - loss: 0.1845 - dice_coef: 0.8229 - iou: 0.6996 - recall_2: 0.9380 - precision_2: 0.9316
# Epoch 32: val_loss did not improve from 0.28745
# 41/41 [==============================] - 18s 429ms/step - loss: 0.1845 - dice_coef: 0.8229 - iou: 0.6996 - recall_2: 0.9380 - precision_2: 0.9316 - val_loss: 0.3500 - val_dice_coef: 0.7200 - val_iou: 0.5664 - val_recall_2: 0.6316 - val_precision_2: 0.9453 - lr: 1.0000e-04
# Epoch 33/50
# 41/41 [==============================] - ETA: 0s - loss: 0.1722 - dice_coef: 0.8350 - iou: 0.7171 - recall_2: 0.9386 - precision_2: 0.9390
# Epoch 33: val_loss did not improve from 0.28745
# 41/41 [==============================] - 18s 430ms/step - loss: 0.1722 - dice_coef: 0.8350 - iou: 0.7171 - recall_2: 0.9386 - precision_2: 0.9390 - val_loss: 0.3346 - val_dice_coef: 0.7663 - val_iou: 0.6357 - val_recall_2: 0.6821 - val_precision_2: 0.9006 - lr: 1.0000e-04
# Epoch 34/50
# 41/41 [==============================] - ETA: 0s - loss: 0.1578 - dice_coef: 0.8485 - iou: 0.7372 - recall_2: 0.9449 - precision_2: 0.9498
# Epoch 34: val_loss did not improve from 0.28745
# 41/41 [==============================] - 18s 430ms/step - loss: 0.1578 - dice_coef: 0.8485 - iou: 0.7372 - recall_2: 0.9449 - precision_2: 0.9498 - val_loss: 0.3460 - val_dice_coef: 0.7441 - val_iou: 0.5999 - val_recall_2: 0.7081 - val_precision_2: 0.8068 - lr: 1.0000e-04
# Epoch 35/50
# 41/41 [==============================] - ETA: 0s - loss: 0.1526 - dice_coef: 0.8539 - iou: 0.7454 - recall_2: 0.9407 - precision_2: 0.9504
# Epoch 35: val_loss did not improve from 0.28745
# 41/41 [==============================] - 18s 430ms/step - loss: 0.1526 - dice_coef: 0.8539 - iou: 0.7454 - recall_2: 0.9407 - precision_2: 0.9504 - val_loss: 0.3249 - val_dice_coef: 0.7555 - val_iou: 0.6144 - val_recall_2: 0.6429 - val_precision_2: 0.9716 - lr: 1.0000e-04
# Epoch 36/50
# 41/41 [==============================] - ETA: 0s - loss: 0.1428 - dice_coef: 0.8634 - iou: 0.7599 - recall_2: 0.9435 - precision_2: 0.9553
# Epoch 36: val_loss did not improve from 0.28745
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 41/41 [==============================] - 18s 429ms/step - loss: 0.1428 - dice_coef: 0.8634 - iou: 0.7599 - recall_2: 0.9435 - precision_2: 0.9553 - val_loss: 0.3606 - val_dice_coef: 0.7273 - val_iou: 0.5792 - val_recall_2: 0.5878 - val_precision_2: 0.9815 - lr: 1.0000e-04
# Epoch 37/50
# 41/41 [==============================] - ETA: 0s - loss: 0.1403 - dice_coef: 0.8659 - iou: 0.7638 - recall_2: 0.9472 - precision_2: 0.9500
# Epoch 37: val_loss did not improve from 0.28745
# 41/41 [==============================] - 18s 430ms/step - loss: 0.1403 - dice_coef: 0.8659 - iou: 0.7638 - recall_2: 0.9472 - precision_2: 0.9500 - val_loss: 0.3572 - val_dice_coef: 0.7291 - val_iou: 0.5811 - val_recall_2: 0.5842 - val_precision_2: 0.9971 - lr: 1.0000e-05
# Epoch 38/50
# 41/41 [==============================] - ETA: 0s - loss: 0.1325 - dice_coef: 0.8728 - iou: 0.7745 - recall_2: 0.9495 - precision_2: 0.9625
# Epoch 38: val_loss did not improve from 0.28745
# 41/41 [==============================] - 18s 430ms/step - loss: 0.1325 - dice_coef: 0.8728 - iou: 0.7745 - recall_2: 0.9495 - precision_2: 0.9625 - val_loss: 0.3517 - val_dice_coef: 0.7357 - val_iou: 0.5898 - val_recall_2: 0.5983 - val_precision_2: 0.9701 - lr: 1.0000e-05
# Epoch 39/50
# 41/41 [==============================] - ETA: 0s - loss: 0.1275 - dice_coef: 0.8773 - iou: 0.7817 - recall_2: 0.9524 - precision_2: 0.9682
# Epoch 39: val_loss did not improve from 0.28745
# 41/41 [==============================] - 18s 430ms/step - loss: 0.1275 - dice_coef: 0.8773 - iou: 0.7817 - recall_2: 0.9524 - precision_2: 0.9682 - val_loss: 0.3496 - val_dice_coef: 0.7374 - val_iou: 0.5919 - val_recall_2: 0.6043 - val_precision_2: 0.9561 - lr: 1.0000e-05
# Epoch 40/50
# 41/41 [==============================] - ETA: 0s - loss: 0.1240 - dice_coef: 0.8806 - iou: 0.7869 - recall_2: 0.9549 - precision_2: 0.9715
# Epoch 40: val_loss did not improve from 0.28745
# 41/41 [==============================] - 18s 430ms/step - loss: 0.1240 - dice_coef: 0.8806 - iou: 0.7869 - recall_2: 0.9549 - precision_2: 0.9715 - val_loss: 0.3484 - val_dice_coef: 0.7372 - val_iou: 0.5912 - val_recall_2: 0.6061 - val_precision_2: 0.9516 - lr: 1.0000e-05
# Epoch 41/50
# 41/41 [==============================] - ETA: 0s - loss: 0.1212 - dice_coef: 0.8832 - iou: 0.7910 - recall_2: 0.9567 - precision_2: 0.9742
# Epoch 41: val_loss did not improve from 0.28745
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1e-06.
# 41/41 [==============================] - 18s 430ms/step - loss: 0.1212 - dice_coef: 0.8832 - iou: 0.7910 - recall_2: 0.9567 - precision_2: 0.9742 - val_loss: 0.3483 - val_dice_coef: 0.7362 - val_iou: 0.5896 - val_recall_2: 0.6064 - val_precision_2: 0.9508 - lr: 1.0000e-05

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 2
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model4.h5")
csv_path = os.path.join("files", "data4.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model4 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 1024], strides=[2, 2, 2, 4])

model4.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model4.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 161 - 161
# Valid: 5 - 5
# Epoch 1/50
# 81/81 [==============================] - ETA: 0s - loss: 1.1720 - dice_coef: 0.0926 - iou: 0.0490 - recall_3: 0.7468 - precision_3: 0.1756
# Epoch 1: val_loss improved from inf to 1.60512, saving model to files/model4.h5
# 81/81 [==============================] - 26s 263ms/step - loss: 1.1720 - dice_coef: 0.0926 - iou: 0.0490 - recall_3: 0.7468 - precision_3: 0.1756 - val_loss: 1.6051 - val_dice_coef: 0.0236 - val_iou: 0.0119 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00 - lr: 1.0000e-04
# Epoch 2/50
# 81/81 [==============================] - ETA: 0s - loss: 0.9455 - dice_coef: 0.1773 - iou: 0.0977 - recall_3: 0.8664 - precision_3: 0.5128
# Epoch 2: val_loss did not improve from 1.60512
# 81/81 [==============================] - 20s 241ms/step - loss: 0.9455 - dice_coef: 0.1773 - iou: 0.0977 - recall_3: 0.8664 - precision_3: 0.5128 - val_loss: 2.4305 - val_dice_coef: 0.0240 - val_iou: 0.0122 - val_recall_3: 0.6144 - val_precision_3: 0.0110 - lr: 1.0000e-04
# Epoch 3/50
# 81/81 [==============================] - ETA: 0s - loss: 0.8623 - dice_coef: 0.2231 - iou: 0.1260 - recall_3: 0.8785 - precision_3: 0.5861
# Epoch 3: val_loss improved from 1.60512 to 1.09807, saving model to files/model4.h5
# 81/81 [==============================] - 25s 305ms/step - loss: 0.8623 - dice_coef: 0.2231 - iou: 0.1260 - recall_3: 0.8785 - precision_3: 0.5861 - val_loss: 1.0981 - val_dice_coef: 0.0274 - val_iou: 0.0139 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00 - lr: 1.0000e-04
# Epoch 4/50
# 81/81 [==============================] - ETA: 0s - loss: 0.7918 - dice_coef: 0.2747 - iou: 0.1599 - recall_3: 0.8989 - precision_3: 0.6360
# Epoch 4: val_loss improved from 1.09807 to 1.07151, saving model to files/model4.h5
# 81/81 [==============================] - 23s 288ms/step - loss: 0.7918 - dice_coef: 0.2747 - iou: 0.1599 - recall_3: 0.8989 - precision_3: 0.6360 - val_loss: 1.0715 - val_dice_coef: 0.0250 - val_iou: 0.0126 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00 - lr: 1.0000e-04
# Epoch 5/50
# 81/81 [==============================] - ETA: 0s - loss: 0.7327 - dice_coef: 0.3226 - iou: 0.1933 - recall_3: 0.9031 - precision_3: 0.6593
# Epoch 5: val_loss improved from 1.07151 to 1.06272, saving model to files/model4.h5
# 81/81 [==============================] - 24s 288ms/step - loss: 0.7327 - dice_coef: 0.3226 - iou: 0.1933 - recall_3: 0.9031 - precision_3: 0.6593 - val_loss: 1.0627 - val_dice_coef: 0.0228 - val_iou: 0.0115 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00 - lr: 1.0000e-04
# Epoch 6/50
# 81/81 [==============================] - ETA: 0s - loss: 0.6727 - dice_coef: 0.3741 - iou: 0.2312 - recall_3: 0.9080 - precision_3: 0.6959
# Epoch 6: val_loss improved from 1.06272 to 1.03188, saving model to files/model4.h5
# 81/81 [==============================] - 24s 301ms/step - loss: 0.6727 - dice_coef: 0.3741 - iou: 0.2312 - recall_3: 0.9080 - precision_3: 0.6959 - val_loss: 1.0319 - val_dice_coef: 0.0412 - val_iou: 0.0210 - val_recall_3: 0.0342 - val_precision_3: 1.0000 - lr: 1.0000e-04
# Epoch 7/50
# 81/81 [==============================] - ETA: 0s - loss: 0.6184 - dice_coef: 0.4222 - iou: 0.2688 - recall_3: 0.9026 - precision_3: 0.7113
# Epoch 7: val_loss improved from 1.03188 to 0.61298, saving model to files/model4.h5
# 81/81 [==============================] - 23s 284ms/step - loss: 0.6184 - dice_coef: 0.4222 - iou: 0.2688 - recall_3: 0.9026 - precision_3: 0.7113 - val_loss: 0.6130 - val_dice_coef: 0.4207 - val_iou: 0.2665 - val_recall_3: 0.7028 - val_precision_3: 0.9466 - lr: 1.0000e-04
# Epoch 8/50
# 81/81 [==============================] - ETA: 0s - loss: 0.5662 - dice_coef: 0.4688 - iou: 0.3076 - recall_3: 0.8972 - precision_3: 0.7256
# Epoch 8: val_loss did not improve from 0.61298
# Epoch 14: val_loss improved from 0.49225 to 0.48873, saving model to files/model4.h5
# 81/81 [==============================] - 23s 284ms/step - loss: 0.3140 - dice_coef: 0.7001 - iou: 0.5402 - recall_3: 0.9133 - precision_3: 0.8753 - val_loss: 0.4887 - val_dice_coef: 0.5693 - val_iou: 0.4167 - val_recall_3: 0.5748 - val_precision_3: 0.9655 - lr: 1.0000e-05
# Epoch 15/50
# 81/81 [==============================] - ETA: 0s - loss: 0.3049 - dice_coef: 0.7086 - iou: 0.5503 - recall_3: 0.9180 - precision_3: 0.8857
# Epoch 15: val_loss improved from 0.48873 to 0.47447, saving model to files/model4.h5
# 81/81 [==============================] - 23s 287ms/step - loss: 0.3049 - dice_coef: 0.7086 - iou: 0.5503 - recall_3: 0.9180 - precision_3: 0.8857 - val_loss: 0.4745 - val_dice_coef: 0.5804 - val_iou: 0.4250 - val_recall_3: 0.5821 - val_precision_3: 0.9674 - lr: 1.0000e-05
# Epoch 16/50
# 81/81 [==============================] - ETA: 0s - loss: 0.2972 - dice_coef: 0.7158 - iou: 0.5590 - recall_3: 0.9208 - precision_3: 0.8937
# Epoch 16: val_loss improved from 0.47447 to 0.46652, saving model to files/model4.h5
# 81/81 [==============================] - 23s 286ms/step - loss: 0.2972 - dice_coef: 0.7158 - iou: 0.5590 - recall_3: 0.9208 - precision_3: 0.8937 - val_loss: 0.4665 - val_dice_coef: 0.5871 - val_iou: 0.4311 - val_recall_3: 0.5877 - val_precision_3: 0.9672 - lr: 1.0000e-05
# Epoch 17/50
# 81/81 [==============================] - ETA: 0s - loss: 0.2900 - dice_coef: 0.7225 - iou: 0.5672 - recall_3: 0.9231 - precision_3: 0.9008
# Epoch 17: val_loss improved from 0.46652 to 0.46330, saving model to files/model4.h5
# 81/81 [==============================] - 23s 286ms/step - loss: 0.2900 - dice_coef: 0.7225 - iou: 0.5672 - recall_3: 0.9231 - precision_3: 0.9008 - val_loss: 0.4633 - val_dice_coef: 0.5898 - val_iou: 0.4337 - val_recall_3: 0.5878 - val_precision_3: 0.9663 - lr: 1.0000e-05
# Epoch 18/50
# 81/81 [==============================] - ETA: 0s - loss: 0.2830 - dice_coef: 0.7289 - iou: 0.5751 - recall_3: 0.9255 - precision_3: 0.9072
# Epoch 18: val_loss did not improve from 0.46330
# 81/81 [==============================] - 20s 241ms/step - loss: 0.2830 - dice_coef: 0.7289 - iou: 0.5751 - recall_3: 0.9255 - precision_3: 0.9072 - val_loss: 0.4658 - val_dice_coef: 0.5883 - val_iou: 0.4333 - val_recall_3: 0.5842 - val_precision_3: 0.9657 - lr: 1.0000e-05
# Epoch 19/50
# 81/81 [==============================] - ETA: 0s - loss: 0.2763 - dice_coef: 0.7352 - iou: 0.5829 - recall_3: 0.9279 - precision_3: 0.9131
# Epoch 19: val_loss did not improve from 0.46330
# 81/81 [==============================] - 20s 241ms/step - loss: 0.2763 - dice_coef: 0.7352 - iou: 0.5829 - recall_3: 0.9279 - precision_3: 0.9131 - val_loss: 0.4694 - val_dice_coef: 0.5861 - val_iou: 0.4327 - val_recall_3: 0.5796 - val_precision_3: 0.9651 - lr: 1.0000e-05
# Epoch 20/50
# 81/81 [==============================] - ETA: 0s - loss: 0.2698 - dice_coef: 0.7413 - iou: 0.5905 - recall_3: 0.9301 - precision_3: 0.9187
# Epoch 20: val_loss did not improve from 0.46330
# 81/81 [==============================] - 20s 241ms/step - loss: 0.2698 - dice_coef: 0.7413 - iou: 0.5905 - recall_3: 0.9301 - precision_3: 0.9187 - val_loss: 0.4758 - val_dice_coef: 0.5818 - val_iou: 0.4304 - val_recall_3: 0.5732 - val_precision_3: 0.9646 - lr: 1.0000e-05
# Epoch 21/50
# 81/81 [==============================] - ETA: 0s - loss: 0.2634 - dice_coef: 0.7473 - iou: 0.5981 - recall_3: 0.9321 - precision_3: 0.9241
# Epoch 21: val_loss did not improve from 0.46330
# 81/81 [==============================] - 20s 241ms/step - loss: 0.2634 - dice_coef: 0.7473 - iou: 0.5981 - recall_3: 0.9321 - precision_3: 0.9241 - val_loss: 0.4842 - val_dice_coef: 0.5761 - val_iou: 0.4274 - val_recall_3: 0.5647 - val_precision_3: 0.9635 - lr: 1.0000e-05
# Epoch 22/50
# 81/81 [==============================] - ETA: 0s - loss: 0.2570 - dice_coef: 0.7532 - iou: 0.6056 - recall_3: 0.9340 - precision_3: 0.9292
# Epoch 22: val_loss did not improve from 0.46330
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1e-06.
# 81/81 [==============================] - 20s 241ms/step - loss: 0.2570 - dice_coef: 0.7532 - iou: 0.6056 - recall_3: 0.9340 - precision_3: 0.9292 - val_loss: 0.4904 - val_dice_coef: 0.5722 - val_iou: 0.4260 - val_recall_3: 0.5592 - val_precision_3: 0.9624 - lr: 1.0000e-05
# Epoch 23/50
# 81/81 [==============================] - ETA: 0s - loss: 0.2523 - dice_coef: 0.7575 - iou: 0.6112 - recall_3: 0.9392 - precision_3: 0.9299
# Epoch 23: val_loss did not improve from 0.46330
# 81/81 [==============================] - 20s 241ms/step - loss: 0.2523 - dice_coef: 0.7575 - iou: 0.6112 - recall_3: 0.9392 - precision_3: 0.9299 - val_loss: 0.4650 - val_dice_coef: 0.5907 - val_iou: 0.4398 - val_recall_3: 0.5771 - val_precision_3: 0.9749 - lr: 1.0000e-06
# Epoch 24/50
# 81/81 [==============================] - ETA: 0s - loss: 0.2501 - dice_coef: 0.7594 - iou: 0.6136 - recall_3: 0.9377 - precision_3: 0.9362
# Epoch 24: val_loss did not improve from 0.46330
# 81/81 [==============================] - 20s 241ms/step - loss: 0.2501 - dice_coef: 0.7594 - iou: 0.6136 - recall_3: 0.9377 - precision_3: 0.9362 - val_loss: 0.4639 - val_dice_coef: 0.5913 - val_iou: 0.4402 - val_recall_3: 0.5784 - val_precision_3: 0.9753 - lr: 1.0000e-06
# Epoch 25/50
# 81/81 [==============================] - ETA: 0s - loss: 0.2492 - dice_coef: 0.7603 - iou: 0.6147 - recall_3: 0.9382 - precision_3: 0.9372
# Epoch 25: val_loss did not improve from 0.46330
# 81/81 [==============================] - 20s 241ms/step - loss: 0.2492 - dice_coef: 0.7603 - iou: 0.6147 - recall_3: 0.9382 - precision_3: 0.9372 - val_loss: 0.4654 - val_dice_coef: 0.5901 - val_iou: 0.4395 - val_recall_3: 0.5770 - val_precision_3: 0.9751 - lr: 1.0000e-06
# Epoch 26/50
# 81/81 [==============================] - ETA: 0s - loss: 0.2484 - dice_coef: 0.7610 - iou: 0.6157 - recall_3: 0.9387 - precision_3: 0.9380
# Epoch 26: val_loss did not improve from 0.46330
# 81/81 [==============================] - 20s 241ms/step - loss: 0.2484 - dice_coef: 0.7610 - iou: 0.6157 - recall_3: 0.9387 - precision_3: 0.9380 - val_loss: 0.4670 - val_dice_coef: 0.5891 - val_iou: 0.4388 - val_recall_3: 0.5757 - val_precision_3: 0.9753 - lr: 1.0000e-06
# Epoch 27/50
# 81/81 [==============================] - ETA: 0s - loss: 0.2476 - dice_coef: 0.7617 - iou: 0.6166 - recall_3: 0.9390 - precision_3: 0.9388
# Epoch 27: val_loss did not improve from 0.46330
# 81/81 [==============================] - 20s 241ms/step - loss: 0.2476 - dice_coef: 0.7617 - iou: 0.6166 - recall_3: 0.9390 - precision_3: 0.9388 - val_loss: 0.4683 - val_dice_coef: 0.5881 - val_iou: 0.4383 - val_recall_3: 0.5744 - val_precision_3: 0.9753 - lr: 1.0000e-06

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 1
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model5.h5")
csv_path = os.path.join("files", "data5.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model5 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 1280], strides=[2, 2, 2, 4])

model5.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model5.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 161 - 161
# Valid: 5 - 5
# Epoch 1/50
# 161/161 [==============================] - ETA: 0s - loss: 1.0736 - dice_coef: 0.1278 - iou: 0.0691 - recall_4: 0.8109 - precision_4: 0.2648
# Epoch 1: val_loss improved from inf to 1.20199, saving model to files/model5.h5
# 161/161 [==============================] - 30s 168ms/step - loss: 1.0736 - dice_coef: 0.1278 - iou: 0.0691 - recall_4: 0.8109 - precision_4: 0.2648 - val_loss: 1.2020 - val_dice_coef: 0.0262 - val_iou: 0.0133 - val_recall_4: 0.0000e+00 - val_precision_4: 0.0000e+00 - lr: 1.0000e-04
# Epoch 2/50
# 161/161 [==============================] - ETA: 0s - loss: 0.8432 - dice_coef: 0.2378 - iou: 0.1358 - recall_4: 0.8801 - precision_4: 0.5915
# Epoch 2: val_loss improved from 1.20199 to 1.07578, saving model to files/model5.h5
# 161/161 [==============================] - 28s 175ms/step - loss: 0.8432 - dice_coef: 0.2378 - iou: 0.1358 - recall_4: 0.8801 - precision_4: 0.5915 - val_loss: 1.0758 - val_dice_coef: 0.0246 - val_iou: 0.0125 - val_recall_4: 0.0000e+00 - val_precision_4: 0.0000e+00 - lr: 1.0000e-04
# Epoch 3/50
# 161/161 [==============================] - ETA: 0s - loss: 0.7176 - dice_coef: 0.3346 - iou: 0.2023 - recall_4: 0.8792 - precision_4: 0.6678
# Epoch 3: val_loss improved from 1.07578 to 1.05719, saving model to files/model5.h5
# 161/161 [==============================] - 28s 176ms/step - loss: 0.7176 - dice_coef: 0.3346 - iou: 0.2023 - recall_4: 0.8792 - precision_4: 0.6678 - val_loss: 1.0572 - val_dice_coef: 0.0205 - val_iou: 0.0104 - val_recall_4: 0.0000e+00 - val_precision_4: 0.0000e+00 - lr: 1.0000e-04
# Epoch 4/50
# 161/161 [==============================] - ETA: 0s - loss: 0.6144 - dice_coef: 0.4251 - iou: 0.2721 - recall_4: 0.8660 - precision_4: 0.6990
# Epoch 4: val_loss improved from 1.05719 to 0.68774, saving model to files/model5.h5
# 161/161 [==============================] - 28s 175ms/step - loss: 0.6144 - dice_coef: 0.4251 - iou: 0.2721 - recall_4: 0.8660 - precision_4: 0.6990 - val_loss: 0.6877 - val_dice_coef: 0.3566 - val_iou: 0.2226 - val_recall_4: 0.4924 - val_precision_4: 0.8899 - lr: 1.0000e-04
# Epoch 5/50
# 161/161 [==============================] - ETA: 0s - loss: 0.5085 - dice_coef: 0.5209 - iou: 0.3547 - recall_4: 0.8626 - precision_4: 0.7496
# Epoch 5: val_loss improved from 0.68774 to 0.63181, saving model to files/model5.h5
# 161/161 [==============================] - 29s 180ms/step - loss: 0.5085 - dice_coef: 0.5209 - iou: 0.3547 - recall_4: 0.8626 - precision_4: 0.7496 - val_loss: 0.6318 - val_dice_coef: 0.4157 - val_iou: 0.2799 - val_recall_4: 0.5391 - val_precision_4: 0.8233 - lr: 1.0000e-04
# Epoch 6/50
# 161/161 [==============================] - ETA: 0s - loss: 0.4198 - dice_coef: 0.6037 - iou: 0.4355 - recall_4: 0.8573 - precision_4: 0.7862
# Epoch 6: val_loss improved from 0.63181 to 0.44130, saving model to files/model5.h5
# 161/161 [==============================] - 28s 176ms/step - loss: 0.4198 - dice_coef: 0.6037 - iou: 0.4355 - recall_4: 0.8573 - precision_4: 0.7862 - val_loss: 0.4413 - val_dice_coef: 0.6136 - val_iou: 0.4516 - val_recall_4: 0.7764 - val_precision_4: 0.7263 - lr: 1.0000e-04
# Epoch 7/50
# 161/161 [==============================] - ETA: 0s - loss: 0.3577 - dice_coef: 0.6631 - iou: 0.4996 - recall_4: 0.8465 - precision_4: 0.8091
# Epoch 7: val_loss improved from 0.44130 to 0.33820, saving model to files/model5.h5
# 161/161 [==============================] - 31s 187ms/step - loss: 0.3577 - dice_coef: 0.6631 - iou: 0.4996 - recall_4: 0.8465 - precision_4: 0.8091 - val_loss: 0.3382 - val_dice_coef: 0.6856 - val_iou: 0.5288 - val_recall_4: 0.7370 - val_precision_4: 0.9162 - lr: 1.0000e-04
# Epoch 8/50
# 161/161 [==============================] - ETA: 0s - loss: 0.3037 - dice_coef: 0.7149 - iou: 0.5600 - recall_4: 0.8475 - precision_4: 0.8286
# Epoch 8: val_loss improved from 0.33820 to 0.31883, saving model to files/model5.h5
# 161/161 [==============================] - 29s 177ms/step - loss: 0.3037 - dice_coef: 0.7149 - iou: 0.5600 - recall_4: 0.8475 - precision_4: 0.8286 - val_loss: 0.3188 - val_dice_coef: 0.7072 - val_iou: 0.5552 - val_recall_4: 0.6901 - val_precision_4: 0.9126 - lr: 1.0000e-04
# Epoch 9/50
# 161/161 [==============================] - ETA: 0s - loss: 0.2585 - dice_coef: 0.7577 - iou: 0.6130 - recall_4: 0.8532 - precision_4: 0.8529
# Epoch 9: val_loss did not improve from 0.31883
# 161/161 [==============================] - 25s 148ms/step - loss: 0.2585 - dice_coef: 0.7577 - iou: 0.6130 - recall_4: 0.8532 - precision_4: 0.8529 - val_loss: 0.7930 - val_dice_coef: 0.2749 - val_iou: 0.1882 - val_recall_4: 0.1902 - val_precision_4: 1.0000 - lr: 1.0000e-04
# Epoch 10/50
# 161/161 [==============================] - ETA: 0s - loss: 0.2298 - dice_coef: 0.7855 - iou: 0.6503 - recall_4: 0.8551 - precision_4: 0.8620
# Epoch 10: val_loss did not improve from 0.31883
# 161/161 [==============================] - 24s 148ms/step - loss: 0.2298 - dice_coef: 0.7855 - iou: 0.6503 - recall_4: 0.8551 - precision_4: 0.8620 - val_loss: 0.8988 - val_dice_coef: 0.1803 - val_iou: 0.1243 - val_recall_4: 0.1075 - val_precision_4: 1.0000 - lr: 1.0000e-04
# Epoch 11/50
# 161/161 [==============================] - ETA: 0s - loss: 0.2070 - dice_coef: 0.8070 - iou: 0.6797 - recall_4: 0.8522 - precision_4: 0.8753
# Epoch 11: val_loss did not improve from 0.31883
# 161/161 [==============================] - 24s 148ms/step - loss: 0.2070 - dice_coef: 0.8070 - iou: 0.6797 - recall_4: 0.8522 - precision_4: 0.8753 - val_loss: 0.5136 - val_dice_coef: 0.5330 - val_iou: 0.3957 - val_recall_4: 0.4570 - val_precision_4: 0.9161 - lr: 1.0000e-04
# Epoch 18/50
# 161/161 [==============================] - ETA: 0s - loss: 0.1189 - dice_coef: 0.8887 - iou: 0.8019 - recall_4: 0.9087 - precision_4: 0.9386
# Epoch 18: val_loss did not improve from 0.31883
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1e-06.
# 161/161 [==============================] - 24s 148ms/step - loss: 0.1189 - dice_coef: 0.8887 - iou: 0.8019 - recall_4: 0.9087 - precision_4: 0.9386 - val_loss: 0.4985 - val_dice_coef: 0.5559 - val_iou: 0.3879 - val_recall_4: 0.4106 - val_precision_4: 0.9521 - lr: 1.0000e-05

# %% [markdown]
# ### Evaluating the Model:

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import pandas as pd
import cv2
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import accuracy_score, f1_score, jaccard_score, precision_score, recall_score
from tensorflow.keras.models import load_model

# %%
H = 512
W = 512

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.float32)
    return ori_x, x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.int32)
    return ori_x, x

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.png")))
    y = sorted(glob(os.path.join(path, "mask", "*.png")))
    return x, y

def save_results(ori_x, ori_y, y_pred, save_image_path):
    line = np.ones((H, 10, 3)) * 255

    ori_y = np.expand_dims(ori_y, axis=-1)
    ori_y = np.concatenate([ori_y, ori_y, ori_y], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1) * 255

    cat_images = np.concatenate([ori_x, line, ori_y, line, y_pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model1.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score1 = [s[1:] for s in SCORE]
score1 = np.mean(score1, axis=0)
print(f"Accuracy: {score1[0]:0.5f}")
print(f"F1: {score1[1]:0.5f}")
print(f"Jaccard: {score1[2]:0.5f}")
print(f"Recall: {score1[3]:0.5f}")
print(f"Precision: {score1[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score1.csv")
# Out:
# 100%|██████████| 5/5 [00:02<00:00,  2.48it/s]
# Accuracy: 0.99590
# F1: 0.83253
# Jaccard: 0.72036
# Recall: 0.74131
# Precision: 0.96661

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model2.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score2 = [s[1:] for s in SCORE]
score2 = np.mean(score2, axis=0)
print(f"Accuracy: {score2[0]:0.5f}")
print(f"F1: {score2[1]:0.5f}")
print(f"Jaccard: {score2[2]:0.5f}")
print(f"Recall: {score2[3]:0.5f}")
print(f"Precision: {score2[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score2.csv")
# Out:
# 100%|██████████| 5/5 [00:01<00:00,  2.51it/s]
# Accuracy: 0.99568
# F1: 0.84358
# Jaccard: 0.73830
# Recall: 0.85539
# Precision: 0.85295

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model3.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score3 = [s[1:] for s in SCORE]
score3 = np.mean(score3, axis=0)
print(f"Accuracy: {score3[0]:0.5f}")
print(f"F1: {score3[1]:0.5f}")
print(f"Jaccard: {score3[2]:0.5f}")
print(f"Recall: {score3[3]:0.5f}")
print(f"Precision: {score3[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score3.csv")
# Out:
# 100%|██████████| 5/5 [00:01<00:00,  2.53it/s]
# Accuracy: 0.99526
# F1: 0.82330
# Jaccard: 0.71393
# Recall: 0.82334
# Precision: 0.83737

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model4.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score4 = [s[1:] for s in SCORE]
score4 = np.mean(score4, axis=0)
print(f"Accuracy: {score4[0]:0.5f}")
print(f"F1: {score4[1]:0.5f}")
print(f"Jaccard: {score4[2]:0.5f}")
print(f"Recall: {score4[3]:0.5f}")
print(f"Precision: {score4[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score4.csv")
# Out:
# 100%|██████████| 5/5 [00:01<00:00,  2.53it/s]
# Accuracy: 0.99415
# F1: 0.69896
# Jaccard: 0.56911
# Recall: 0.59008
# Precision: 0.96996

# %%
""" Save the results in this folder """
# create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model5.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score5 = [s[1:] for s in SCORE]
score5 = np.mean(score5, axis=0)
print(f"Accuracy: {score5[0]:0.5f}")
print(f"F1: {score5[1]:0.5f}")
print(f"Jaccard: {score5[2]:0.5f}")
print(f"Recall: {score5[3]:0.5f}")
print(f"Precision: {score5[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score5.csv")
# Out:
# 100%|██████████| 5/5 [00:02<00:00,  2.49it/s]
# Accuracy: 0.99498
# F1: 0.79181
# Jaccard: 0.66760
# Recall: 0.72844
# Precision: 0.92148

# %%
import matplotlib.pyplot as plt

z_dim = 64
channels = [384, 512, 768, 1024, 1280]
final_score = [score1[1], score2[1], score3[1], score4[1], score5[1]]

plt.plot(channels, final_score)  
plt.xlabel("Bottleneck Channels")
plt.ylabel("F1-Score")
plt.show()
