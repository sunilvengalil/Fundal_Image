# %% [markdown]
# ### Import the required libraries and modules:

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
import numpy as np

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# %cd /content/gdrive/MyDrive/Blood_Vessel_Results/ALL_BEST_RESULTS/BV_OD_HRF
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/Blood_Vessel_Results/ALL_BEST_RESULTS/BV_OD_HRF

# %% [markdown]
# ### Unzip the data:

# %%
# !unzip new_data.zip

# %% [markdown]
# ### Construct the Model:

# %%
def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(inputs, num_filters, strides=2):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D(strides)(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters, strides=2):
    x = Conv2DTranspose(num_filters, (2, 2), strides=strides, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape, num_filters=[64, 128, 256, 512, 1024], strides=[2, 2, 2, 2]):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, num_filters[0], strides=strides[0])
    s2, p2 = encoder_block(p1, num_filters[1], strides=strides[1])
    s3, p3 = encoder_block(p2, num_filters[2], strides=strides[2])
    s4, p4 = encoder_block(p3, num_filters[3], strides=strides[3])

    b1 = conv_block(p4, num_filters[4])

    d1 = decoder_block(b1, s4, num_filters[3], strides=strides[3])
    d2 = decoder_block(d1, s3, num_filters[2], strides=strides[2])
    d3 = decoder_block(d2, s2, num_filters[1], strides=strides[1])
    d4 = decoder_block(d3, s1, num_filters[0], strides=strides[0])

    outputs = Conv2D(2, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="UNET")
    return model

input_shape = (512, 512, 3)
model = build_unet(input_shape)
model.summary()
# Out:
# Model: "UNET"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 512, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 512, 512, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 512, 512, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 512, 512, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 256, 256, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 12  0          ['activation_3[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 25  295168      ['max_pooling2d_1[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_4[0][0]']
#  rmalization)                   6)
#
#  activation_4 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_4[0][0]']
#                                 6)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 25  590080      ['activation_4[0][0]']
#                                 6)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_5[0][0]']
#  rmalization)                   6)
#
#  activation_5 (Activation)      (None, 128, 128, 25  0           ['batch_normalization_5[0][0]']
#                                 6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 512)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 32, 32, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 512)  2097664    ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 64, 64, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 64, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 25  524544     ['activation_11[0][0]']
#  spose)                         6)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 51  0           ['conv2d_transpose_1[0][0]',
#                                 2)                                'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_12 (BatchN  (None, 128, 128, 25  1024       ['conv2d_12[0][0]']
#  ormalization)                  6)
#
#  activation_12 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_12[0][0]']
#                                 6)
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 25  590080      ['activation_12[0][0]']
#                                 6)
#
#  batch_normalization_13 (BatchN  (None, 128, 128, 25  1024       ['conv2d_13[0][0]']
#  ormalization)                  6)
#
#  activation_13 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_13[0][0]']
#                                 6)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 12  131200     ['activation_13[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 256, 256, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  activation_14 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_15 (BatchN  (None, 256, 256, 12  512        ['conv2d_15[0][0]']
#  ormalization)                  8)
#
#  activation_15 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_15[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 64  32832      ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 512, 512, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 512, 512, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 512, 512, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 512, 512, 2)  130         ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31,055,362
# Trainable params: 31,043,586
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %% [markdown]
# ### Adding the Metrics:

# %%
def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def DiceBCELoss(y_true, y_pred):

    inputs = tf.keras.layers.Flatten()(y_true)
    targets = tf.keras.layers.Flatten()(y_pred)

    intersection = tf.reduce_sum(inputs * targets)
    dice_loss = 1 - (2.*intersection + smooth)/(tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)
    BCE = tf.keras.losses.BinaryCrossentropy()
    Dice_BCE = BCE(inputs, targets) + dice_loss

    return Dice_BCE

# %% [markdown]
# ### Training the Model:

# %%
W = 512
H = 512

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.png")))
    y = sorted(glob(os.path.join(path, "mask", "*.png")))
    return x, y

def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)
    return x, y

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)  ## (512, 512, 3)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    x = x[:,:,0:2] # Discard the last channel 

    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 2])
    return x, y

def tf_dataset(X, Y, batch_size=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(4)
    return dataset

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 2
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model_1024.h5")
csv_path = os.path.join("files", "data_1024.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model_1024 = build_unet((H, W, 3), num_filters=[64, 128, 256, 512, 1024], strides=[1, 2, 2, 2])

model_1024.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model_1024.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 40 - 40
# Valid: 5 - 5
# Epoch 1/50
# 20/20 [==============================] - ETA: 0s - loss: 1.2857 - dice_coef: 0.1826 - iou: 0.1008 - recall: 0.7284 - precision: 0.2463
# Epoch 1: val_loss improved from inf to 1.56253, saving model to files/model_1024.h5
# 20/20 [==============================] - 107s 3s/step - loss: 1.2857 - dice_coef: 0.1826 - iou: 0.1008 - recall: 0.7284 - precision: 0.2463 - val_loss: 1.5625 - val_dice_coef: 0.0906 - val_iou: 0.0475 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 2/50
# 20/20 [==============================] - ETA: 0s - loss: 1.0180 - dice_coef: 0.2665 - iou: 0.1539 - recall: 0.7328 - precision: 0.6266
# Epoch 2: val_loss improved from 1.56253 to 1.48610, saving model to files/model_1024.h5
# 20/20 [==============================] - 34s 2s/step - loss: 1.0180 - dice_coef: 0.2665 - iou: 0.1539 - recall: 0.7328 - precision: 0.6266 - val_loss: 1.4861 - val_dice_coef: 0.0885 - val_iou: 0.0463 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 3/50
# 20/20 [==============================] - ETA: 0s - loss: 0.9315 - dice_coef: 0.3086 - iou: 0.1825 - recall: 0.7704 - precision: 0.6843
# Epoch 3: val_loss improved from 1.48610 to 1.41084, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.9315 - dice_coef: 0.3086 - iou: 0.1825 - recall: 0.7704 - precision: 0.6843 - val_loss: 1.4108 - val_dice_coef: 0.0863 - val_iou: 0.0451 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 4/50
# 20/20 [==============================] - ETA: 0s - loss: 0.8861 - dice_coef: 0.3325 - iou: 0.1995 - recall: 0.7926 - precision: 0.7165
# Epoch 4: val_loss improved from 1.41084 to 1.35698, saving model to files/model_1024.h5
# 20/20 [==============================] - 36s 2s/step - loss: 0.8861 - dice_coef: 0.3325 - iou: 0.1995 - recall: 0.7926 - precision: 0.7165 - val_loss: 1.3570 - val_dice_coef: 0.0844 - val_iou: 0.0441 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 5/50
# 20/20 [==============================] - ETA: 0s - loss: 0.8524 - dice_coef: 0.3515 - iou: 0.2133 - recall: 0.8071 - precision: 0.7396
# Epoch 5: val_loss improved from 1.35698 to 1.31201, saving model to files/model_1024.h5
# 20/20 [==============================] - 36s 2s/step - loss: 0.8524 - dice_coef: 0.3515 - iou: 0.2133 - recall: 0.8071 - precision: 0.7396 - val_loss: 1.3120 - val_dice_coef: 0.0848 - val_iou: 0.0443 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 6/50
# 20/20 [==============================] - ETA: 0s - loss: 0.8251 - dice_coef: 0.3671 - iou: 0.2249 - recall: 0.8142 - precision: 0.7582
# Epoch 6: val_loss improved from 1.31201 to 1.26973, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.8251 - dice_coef: 0.3671 - iou: 0.2249 - recall: 0.8142 - precision: 0.7582 - val_loss: 1.2697 - val_dice_coef: 0.0862 - val_iou: 0.0450 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 7/50
# 20/20 [==============================] - ETA: 0s - loss: 0.8012 - dice_coef: 0.3812 - iou: 0.2355 - recall: 0.8205 - precision: 0.7727
# Epoch 7: val_loss improved from 1.26973 to 1.22507, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.8012 - dice_coef: 0.3812 - iou: 0.2355 - recall: 0.8205 - precision: 0.7727 - val_loss: 1.2251 - val_dice_coef: 0.0864 - val_iou: 0.0452 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 8/50
# 20/20 [==============================] - ETA: 0s - loss: 0.7791 - dice_coef: 0.3949 - iou: 0.2461 - recall: 0.8273 - precision: 0.7819
# Epoch 8: val_loss improved from 1.22507 to 1.19346, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.7791 - dice_coef: 0.3949 - iou: 0.2461 - recall: 0.8273 - precision: 0.7819 - val_loss: 1.1935 - val_dice_coef: 0.0854 - val_iou: 0.0446 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 9/50
# 20/20 [==============================] - ETA: 0s - loss: 0.7585 - dice_coef: 0.4077 - iou: 0.2561 - recall: 0.8315 - precision: 0.7925
# Epoch 9: val_loss improved from 1.19346 to 1.17533, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.7585 - dice_coef: 0.4077 - iou: 0.2561 - recall: 0.8315 - precision: 0.7925 - val_loss: 1.1753 - val_dice_coef: 0.0832 - val_iou: 0.0434 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 10/50
# 20/20 [==============================] - ETA: 0s - loss: 0.7398 - dice_coef: 0.4196 - iou: 0.2656 - recall: 0.8346 - precision: 0.8009
# Epoch 10: val_loss improved from 1.17533 to 1.16113, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.7398 - dice_coef: 0.4196 - iou: 0.2656 - recall: 0.8346 - precision: 0.8009 - val_loss: 1.1611 - val_dice_coef: 0.0815 - val_iou: 0.0425 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 11/50
# 20/20 [==============================] - ETA: 0s - loss: 0.7219 - dice_coef: 0.4309 - iou: 0.2747 - recall: 0.8363 - precision: 0.8078
# Epoch 11: val_loss improved from 1.16113 to 1.14749, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.7219 - dice_coef: 0.4309 - iou: 0.2747 - recall: 0.8363 - precision: 0.8078 - val_loss: 1.1475 - val_dice_coef: 0.0800 - val_iou: 0.0417 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 12/50
# 20/20 [==============================] - ETA: 0s - loss: 0.7026 - dice_coef: 0.4436 - iou: 0.2851 - recall: 0.8415 - precision: 0.8167
# Epoch 12: val_loss improved from 1.14749 to 1.14110, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.7026 - dice_coef: 0.4436 - iou: 0.2851 - recall: 0.8415 - precision: 0.8167 - val_loss: 1.1411 - val_dice_coef: 0.0794 - val_iou: 0.0413 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 13/50
# 20/20 [==============================] - ETA: 0s - loss: 0.6854 - dice_coef: 0.4554 - iou: 0.2949 - recall: 0.8448 - precision: 0.8211
# Epoch 13: val_loss improved from 1.14110 to 1.13718, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.6854 - dice_coef: 0.4554 - iou: 0.2949 - recall: 0.8448 - precision: 0.8211 - val_loss: 1.1372 - val_dice_coef: 0.0767 - val_iou: 0.0399 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 14/50
# 20/20 [==============================] - ETA: 0s - loss: 0.6667 - dice_coef: 0.4677 - iou: 0.3054 - recall: 0.8482 - precision: 0.8304
# Epoch 14: val_loss improved from 1.13718 to 1.13406, saving model to files/model_1024.h5
# 20/20 [==============================] - 38s 2s/step - loss: 0.6667 - dice_coef: 0.4677 - iou: 0.3054 - recall: 0.8482 - precision: 0.8304 - val_loss: 1.1341 - val_dice_coef: 0.0746 - val_iou: 0.0388 - val_recall: 1.2905e-04 - val_precision: 0.8261 - lr: 1.0000e-04
# Epoch 15/50
# 20/20 [==============================] - ETA: 0s - loss: 0.6484 - dice_coef: 0.4802 - iou: 0.3160 - recall: 0.8521 - precision: 0.8380
# Epoch 15: val_loss improved from 1.13406 to 1.13006, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.6484 - dice_coef: 0.4802 - iou: 0.3160 - recall: 0.8521 - precision: 0.8380 - val_loss: 1.1301 - val_dice_coef: 0.0741 - val_iou: 0.0385 - val_recall: 4.7546e-04 - val_precision: 0.4930 - lr: 1.0000e-04
# Epoch 16/50
# 20/20 [==============================] - ETA: 0s - loss: 0.6321 - dice_coef: 0.4914 - iou: 0.3259 - recall: 0.8536 - precision: 0.8431
# Epoch 16: val_loss improved from 1.13006 to 1.12602, saving model to files/model_1024.h5
# 20/20 [==============================] - 39s 2s/step - loss: 0.6321 - dice_coef: 0.4914 - iou: 0.3259 - recall: 0.8536 - precision: 0.8431 - val_loss: 1.1260 - val_dice_coef: 0.0750 - val_iou: 0.0390 - val_recall: 0.0016 - val_precision: 0.2679 - lr: 1.0000e-04
# Epoch 17/50
# 20/20 [==============================] - ETA: 0s - loss: 0.6154 - dice_coef: 0.5031 - iou: 0.3362 - recall: 0.8554 - precision: 0.8501
# Epoch 17: val_loss improved from 1.12602 to 1.11387, saving model to files/model_1024.h5
# 20/20 [==============================] - 38s 2s/step - loss: 0.6154 - dice_coef: 0.5031 - iou: 0.3362 - recall: 0.8554 - precision: 0.8501 - val_loss: 1.1139 - val_dice_coef: 0.0808 - val_iou: 0.0421 - val_recall: 0.0054 - val_precision: 0.4608 - lr: 1.0000e-04
# Epoch 18/50
# 20/20 [==============================] - ETA: 0s - loss: 0.5984 - dice_coef: 0.5153 - iou: 0.3472 - recall: 0.8603 - precision: 0.8550
# Epoch 18: val_loss improved from 1.11387 to 1.09594, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.5984 - dice_coef: 0.5153 - iou: 0.3472 - recall: 0.8603 - precision: 0.8550 - val_loss: 1.0959 - val_dice_coef: 0.0925 - val_iou: 0.0486 - val_recall: 0.0241 - val_precision: 0.4230 - lr: 1.0000e-04
# Epoch 19/50
# 20/20 [==============================] - ETA: 0s - loss: 0.5812 - dice_coef: 0.5276 - iou: 0.3584 - recall: 0.8633 - precision: 0.8625
# Epoch 19: val_loss improved from 1.09594 to 1.07249, saving model to files/model_1024.h5
# 20/20 [==============================] - 38s 2s/step - loss: 0.5812 - dice_coef: 0.5276 - iou: 0.3584 - recall: 0.8633 - precision: 0.8625 - val_loss: 1.0725 - val_dice_coef: 0.1056 - val_iou: 0.0560 - val_recall: 0.0436 - val_precision: 0.6290 - lr: 1.0000e-04
# Epoch 20/50
# 20/20 [==============================] - ETA: 0s - loss: 0.5655 - dice_coef: 0.5392 - iou: 0.3692 - recall: 0.8662 - precision: 0.8664
# Epoch 20: val_loss improved from 1.07249 to 1.02210, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.5655 - dice_coef: 0.5392 - iou: 0.3692 - recall: 0.8662 - precision: 0.8664 - val_loss: 1.0221 - val_dice_coef: 0.1403 - val_iou: 0.0760 - val_recall: 0.0976 - val_precision: 0.8018 - lr: 1.0000e-04
# Epoch 21/50
# 20/20 [==============================] - ETA: 0s - loss: 0.5497 - dice_coef: 0.5509 - iou: 0.3803 - recall: 0.8690 - precision: 0.8713
# Epoch 21: val_loss improved from 1.02210 to 0.97351, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.5497 - dice_coef: 0.5509 - iou: 0.3803 - recall: 0.8690 - precision: 0.8713 - val_loss: 0.9735 - val_dice_coef: 0.1755 - val_iou: 0.0971 - val_recall: 0.1511 - val_precision: 0.8587 - lr: 1.0000e-04
# Epoch 22/50
# 20/20 [==============================] - ETA: 0s - loss: 0.5352 - dice_coef: 0.5617 - iou: 0.3906 - recall: 0.8686 - precision: 0.8767
# Epoch 22: val_loss improved from 0.97351 to 0.87585, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.5352 - dice_coef: 0.5617 - iou: 0.3906 - recall: 0.8686 - precision: 0.8767 - val_loss: 0.8758 - val_dice_coef: 0.2543 - val_iou: 0.1471 - val_recall: 0.2890 - val_precision: 0.8689 - lr: 1.0000e-04
# Epoch 23/50
# 20/20 [==============================] - ETA: 0s - loss: 0.5189 - dice_coef: 0.5739 - iou: 0.4026 - recall: 0.8735 - precision: 0.8826
# Epoch 23: val_loss improved from 0.87585 to 0.80036, saving model to files/model_1024.h5
# 20/20 [==============================] - 38s 2s/step - loss: 0.5189 - dice_coef: 0.5739 - iou: 0.4026 - recall: 0.8735 - precision: 0.8826 - val_loss: 0.8004 - val_dice_coef: 0.3179 - val_iou: 0.1904 - val_recall: 0.4036 - val_precision: 0.9108 - lr: 1.0000e-04
# Epoch 24/50
# 20/20 [==============================] - ETA: 0s - loss: 0.5032 - dice_coef: 0.5858 - iou: 0.4144 - recall: 0.8765 - precision: 0.8884
# Epoch 24: val_loss improved from 0.80036 to 0.77172, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.5032 - dice_coef: 0.5858 - iou: 0.4144 - recall: 0.8765 - precision: 0.8884 - val_loss: 0.7717 - val_dice_coef: 0.3374 - val_iou: 0.2050 - val_recall: 0.4183 - val_precision: 0.9570 - lr: 1.0000e-04
# Epoch 25/50
# 20/20 [==============================] - ETA: 0s - loss: 0.4906 - dice_coef: 0.5958 - iou: 0.4244 - recall: 0.8763 - precision: 0.8909
# Epoch 25: val_loss improved from 0.77172 to 0.71091, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.4906 - dice_coef: 0.5958 - iou: 0.4244 - recall: 0.8763 - precision: 0.8909 - val_loss: 0.7109 - val_dice_coef: 0.3880 - val_iou: 0.2427 - val_recall: 0.4856 - val_precision: 0.9654 - lr: 1.0000e-04
# Epoch 26/50
# 20/20 [==============================] - ETA: 0s - loss: 0.4781 - dice_coef: 0.6054 - iou: 0.4342 - recall: 0.8752 - precision: 0.8936
# Epoch 26: val_loss improved from 0.71091 to 0.65684, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.4781 - dice_coef: 0.6054 - iou: 0.4342 - recall: 0.8752 - precision: 0.8936 - val_loss: 0.6568 - val_dice_coef: 0.4371 - val_iou: 0.2813 - val_recall: 0.5814 - val_precision: 0.9243 - lr: 1.0000e-04
# Epoch 27/50
# 20/20 [==============================] - ETA: 0s - loss: 0.4657 - dice_coef: 0.6152 - iou: 0.4444 - recall: 0.8761 - precision: 0.8960
# Epoch 27: val_loss improved from 0.65684 to 0.61525, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.4657 - dice_coef: 0.6152 - iou: 0.4444 - recall: 0.8761 - precision: 0.8960 - val_loss: 0.6153 - val_dice_coef: 0.4729 - val_iou: 0.3111 - val_recall: 0.6294 - val_precision: 0.9248 - lr: 1.0000e-04
# Epoch 28/50
# 20/20 [==============================] - ETA: 0s - loss: 0.4496 - dice_coef: 0.6275 - iou: 0.4573 - recall: 0.8815 - precision: 0.9025
# Epoch 28: val_loss improved from 0.61525 to 0.59093, saving model to files/model_1024.h5
# 20/20 [==============================] - 38s 2s/step - loss: 0.4496 - dice_coef: 0.6275 - iou: 0.4573 - recall: 0.8815 - precision: 0.9025 - val_loss: 0.5909 - val_dice_coef: 0.4935 - val_iou: 0.3289 - val_recall: 0.6504 - val_precision: 0.9268 - lr: 1.0000e-04
# Epoch 29/50
# 20/20 [==============================] - ETA: 0s - loss: 0.4328 - dice_coef: 0.6402 - iou: 0.4709 - recall: 0.8864 - precision: 0.9110
# Epoch 29: val_loss improved from 0.59093 to 0.55165, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.4328 - dice_coef: 0.6402 - iou: 0.4709 - recall: 0.8864 - precision: 0.9110 - val_loss: 0.5517 - val_dice_coef: 0.5282 - val_iou: 0.3601 - val_recall: 0.7089 - val_precision: 0.9076 - lr: 1.0000e-04
# Epoch 30/50
# 20/20 [==============================] - ETA: 0s - loss: 0.4219 - dice_coef: 0.6490 - iou: 0.4805 - recall: 0.8857 - precision: 0.9133
# Epoch 30: val_loss improved from 0.55165 to 0.53042, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.4219 - dice_coef: 0.6490 - iou: 0.4805 - recall: 0.8857 - precision: 0.9133 - val_loss: 0.5304 - val_dice_coef: 0.5417 - val_iou: 0.3729 - val_recall: 0.7163 - val_precision: 0.9277 - lr: 1.0000e-04
# Epoch 31/50
# 20/20 [==============================] - ETA: 0s - loss: 0.4101 - dice_coef: 0.6583 - iou: 0.4908 - recall: 0.8868 - precision: 0.9166
# Epoch 31: val_loss did not improve from 0.53042
# 20/20 [==============================] - 34s 2s/step - loss: 0.4101 - dice_coef: 0.6583 - iou: 0.4908 - recall: 0.8868 - precision: 0.9166 - val_loss: 0.5404 - val_dice_coef: 0.5339 - val_iou: 0.3661 - val_recall: 0.6919 - val_precision: 0.9156 - lr: 1.0000e-04
# Epoch 32/50
# 20/20 [==============================] - ETA: 0s - loss: 0.3981 - dice_coef: 0.6679 - iou: 0.5015 - recall: 0.8878 - precision: 0.9198
# Epoch 32: val_loss improved from 0.53042 to 0.51189, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.3981 - dice_coef: 0.6679 - iou: 0.5015 - recall: 0.8878 - precision: 0.9198 - val_loss: 0.5119 - val_dice_coef: 0.5623 - val_iou: 0.3924 - val_recall: 0.7358 - val_precision: 0.9076 - lr: 1.0000e-04
# Epoch 33/50
# 20/20 [==============================] - ETA: 0s - loss: 0.3838 - dice_coef: 0.6790 - iou: 0.5141 - recall: 0.8912 - precision: 0.9257
# Epoch 33: val_loss improved from 0.51189 to 0.50095, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.3838 - dice_coef: 0.6790 - iou: 0.5141 - recall: 0.8912 - precision: 0.9257 - val_loss: 0.5010 - val_dice_coef: 0.5728 - val_iou: 0.4025 - val_recall: 0.7503 - val_precision: 0.9041 - lr: 1.0000e-04
# Epoch 34/50
# 20/20 [==============================] - ETA: 0s - loss: 0.3709 - dice_coef: 0.6893 - iou: 0.5260 - recall: 0.8935 - precision: 0.9311
# Epoch 34: val_loss improved from 0.50095 to 0.48782, saving model to files/model_1024.h5
# 20/20 [==============================] - 38s 2s/step - loss: 0.3709 - dice_coef: 0.6893 - iou: 0.5260 - recall: 0.8935 - precision: 0.9311 - val_loss: 0.4878 - val_dice_coef: 0.5895 - val_iou: 0.4187 - val_recall: 0.7900 - val_precision: 0.8761 - lr: 1.0000e-04
# Epoch 35/50
# 20/20 [==============================] - ETA: 0s - loss: 0.3614 - dice_coef: 0.6970 - iou: 0.5351 - recall: 0.8916 - precision: 0.9339
# Epoch 35: val_loss improved from 0.48782 to 0.47436, saving model to files/model_1024.h5
# 20/20 [==============================] - 38s 2s/step - loss: 0.3614 - dice_coef: 0.6970 - iou: 0.5351 - recall: 0.8916 - precision: 0.9339 - val_loss: 0.4744 - val_dice_coef: 0.5995 - val_iou: 0.4289 - val_recall: 0.7883 - val_precision: 0.8797 - lr: 1.0000e-04
# Epoch 36/50
# 20/20 [==============================] - ETA: 0s - loss: 0.3510 - dice_coef: 0.7056 - iou: 0.5452 - recall: 0.8927 - precision: 0.9356
# Epoch 36: val_loss improved from 0.47436 to 0.47120, saving model to files/model_1024.h5
# 20/20 [==============================] - 38s 2s/step - loss: 0.3510 - dice_coef: 0.7056 - iou: 0.5452 - recall: 0.8927 - precision: 0.9356 - val_loss: 0.4712 - val_dice_coef: 0.5978 - val_iou: 0.4275 - val_recall: 0.7669 - val_precision: 0.8990 - lr: 1.0000e-04
# Epoch 37/50
# 20/20 [==============================] - ETA: 0s - loss: 0.3373 - dice_coef: 0.7163 - iou: 0.5582 - recall: 0.8965 - precision: 0.9425
# Epoch 37: val_loss improved from 0.47120 to 0.46600, saving model to files/model_1024.h5
# 20/20 [==============================] - 38s 2s/step - loss: 0.3373 - dice_coef: 0.7163 - iou: 0.5582 - recall: 0.8965 - precision: 0.9425 - val_loss: 0.4660 - val_dice_coef: 0.6046 - val_iou: 0.4343 - val_recall: 0.7851 - val_precision: 0.8843 - lr: 1.0000e-04
# Epoch 38/50
# 20/20 [==============================] - ETA: 0s - loss: 0.3280 - dice_coef: 0.7240 - iou: 0.5676 - recall: 0.8953 - precision: 0.9445
# Epoch 38: val_loss improved from 0.46600 to 0.46224, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.3280 - dice_coef: 0.7240 - iou: 0.5676 - recall: 0.8953 - precision: 0.9445 - val_loss: 0.4622 - val_dice_coef: 0.6123 - val_iou: 0.4420 - val_recall: 0.7936 - val_precision: 0.8708 - lr: 1.0000e-04
# Epoch 39/50
# 20/20 [==============================] - ETA: 0s - loss: 0.3212 - dice_coef: 0.7301 - iou: 0.5750 - recall: 0.8941 - precision: 0.9432
# Epoch 39: val_loss improved from 0.46224 to 0.45348, saving model to files/model_1024.h5
# 20/20 [==============================] - 38s 2s/step - loss: 0.3212 - dice_coef: 0.7301 - iou: 0.5750 - recall: 0.8941 - precision: 0.9432 - val_loss: 0.4535 - val_dice_coef: 0.6202 - val_iou: 0.4505 - val_recall: 0.8055 - val_precision: 0.8630 - lr: 1.0000e-04
# Epoch 40/50
# 20/20 [==============================] - ETA: 0s - loss: 0.3112 - dice_coef: 0.7381 - iou: 0.5851 - recall: 0.8946 - precision: 0.9470
# Epoch 40: val_loss improved from 0.45348 to 0.44402, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.3112 - dice_coef: 0.7381 - iou: 0.5851 - recall: 0.8946 - precision: 0.9470 - val_loss: 0.4440 - val_dice_coef: 0.6265 - val_iou: 0.4571 - val_recall: 0.7990 - val_precision: 0.8668 - lr: 1.0000e-04
# Epoch 41/50
# 20/20 [==============================] - ETA: 0s - loss: 0.3036 - dice_coef: 0.7447 - iou: 0.5935 - recall: 0.8955 - precision: 0.9469
# Epoch 41: val_loss improved from 0.44402 to 0.44288, saving model to files/model_1024.h5
# 20/20 [==============================] - 39s 2s/step - loss: 0.3036 - dice_coef: 0.7447 - iou: 0.5935 - recall: 0.8955 - precision: 0.9469 - val_loss: 0.4429 - val_dice_coef: 0.6319 - val_iou: 0.4627 - val_recall: 0.7994 - val_precision: 0.8523 - lr: 1.0000e-04
# Epoch 42/50
# 20/20 [==============================] - ETA: 0s - loss: 0.2976 - dice_coef: 0.7499 - iou: 0.6000 - recall: 0.8926 - precision: 0.9477
# Epoch 42: val_loss did not improve from 0.44288
# 20/20 [==============================] - 34s 2s/step - loss: 0.2976 - dice_coef: 0.7499 - iou: 0.6000 - recall: 0.8926 - precision: 0.9477 - val_loss: 0.4472 - val_dice_coef: 0.6328 - val_iou: 0.4635 - val_recall: 0.8127 - val_precision: 0.8397 - lr: 1.0000e-04
# Epoch 43/50
# 20/20 [==============================] - ETA: 0s - loss: 0.2880 - dice_coef: 0.7579 - iou: 0.6103 - recall: 0.8938 - precision: 0.9511
# Epoch 43: val_loss improved from 0.44288 to 0.43535, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.2880 - dice_coef: 0.7579 - iou: 0.6103 - recall: 0.8938 - precision: 0.9511 - val_loss: 0.4354 - val_dice_coef: 0.6400 - val_iou: 0.4713 - val_recall: 0.8088 - val_precision: 0.8553 - lr: 1.0000e-04
# Epoch 44/50
# 20/20 [==============================] - ETA: 0s - loss: 0.2755 - dice_coef: 0.7678 - iou: 0.6232 - recall: 0.8985 - precision: 0.9566
# Epoch 44: val_loss improved from 0.43535 to 0.43041, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.2755 - dice_coef: 0.7678 - iou: 0.6232 - recall: 0.8985 - precision: 0.9566 - val_loss: 0.4304 - val_dice_coef: 0.6438 - val_iou: 0.4753 - val_recall: 0.7919 - val_precision: 0.8599 - lr: 1.0000e-04
# Epoch 45/50
# 20/20 [==============================] - ETA: 0s - loss: 0.2643 - dice_coef: 0.7765 - iou: 0.6348 - recall: 0.8987 - precision: 0.9638
# Epoch 45: val_loss improved from 0.43041 to 0.42561, saving model to files/model_1024.h5
# 20/20 [==============================] - 38s 2s/step - loss: 0.2643 - dice_coef: 0.7765 - iou: 0.6348 - recall: 0.8987 - precision: 0.9638 - val_loss: 0.4256 - val_dice_coef: 0.6511 - val_iou: 0.4831 - val_recall: 0.8147 - val_precision: 0.8399 - lr: 1.0000e-04
# Epoch 46/50
# 20/20 [==============================] - ETA: 0s - loss: 0.2579 - dice_coef: 0.7821 - iou: 0.6423 - recall: 0.8983 - precision: 0.9645
# Epoch 46: val_loss improved from 0.42561 to 0.39888, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.2579 - dice_coef: 0.7821 - iou: 0.6423 - recall: 0.8983 - precision: 0.9645 - val_loss: 0.3989 - val_dice_coef: 0.6726 - val_iou: 0.5073 - val_recall: 0.8212 - val_precision: 0.8532 - lr: 1.0000e-04
# Epoch 47/50
# 20/20 [==============================] - ETA: 0s - loss: 0.2529 - dice_coef: 0.7865 - iou: 0.6483 - recall: 0.8976 - precision: 0.9635
# Epoch 47: val_loss did not improve from 0.39888
# 20/20 [==============================] - 34s 2s/step - loss: 0.2529 - dice_coef: 0.7865 - iou: 0.6483 - recall: 0.8976 - precision: 0.9635 - val_loss: 0.4023 - val_dice_coef: 0.6635 - val_iou: 0.4974 - val_recall: 0.7843 - val_precision: 0.8825 - lr: 1.0000e-04
# Epoch 48/50
# 20/20 [==============================] - ETA: 0s - loss: 0.2467 - dice_coef: 0.7919 - iou: 0.6557 - recall: 0.8980 - precision: 0.9637
# Epoch 48: val_loss improved from 0.39888 to 0.39614, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.2467 - dice_coef: 0.7919 - iou: 0.6557 - recall: 0.8980 - precision: 0.9637 - val_loss: 0.3961 - val_dice_coef: 0.6721 - val_iou: 0.5071 - val_recall: 0.8055 - val_precision: 0.8706 - lr: 1.0000e-04
# Epoch 49/50
# 20/20 [==============================] - ETA: 0s - loss: 0.2382 - dice_coef: 0.7989 - iou: 0.6652 - recall: 0.8988 - precision: 0.9671
# Epoch 49: val_loss improved from 0.39614 to 0.38755, saving model to files/model_1024.h5
# 20/20 [==============================] - 38s 2s/step - loss: 0.2382 - dice_coef: 0.7989 - iou: 0.6652 - recall: 0.8988 - precision: 0.9671 - val_loss: 0.3876 - val_dice_coef: 0.6824 - val_iou: 0.5186 - val_recall: 0.8204 - val_precision: 0.8591 - lr: 1.0000e-04
# Epoch 50/50
# 20/20 [==============================] - ETA: 0s - loss: 0.2290 - dice_coef: 0.8061 - iou: 0.6753 - recall: 0.8976 - precision: 0.9726
# Epoch 50: val_loss improved from 0.38755 to 0.36944, saving model to files/model_1024.h5
# 20/20 [==============================] - 37s 2s/step - loss: 0.2290 - dice_coef: 0.8061 - iou: 0.6753 - recall: 0.8976 - precision: 0.9726 - val_loss: 0.3694 - val_dice_coef: 0.6947 - val_iou: 0.5329 - val_recall: 0.8139 - val_precision: 0.8764 - lr: 1.0000e-04

# %% [markdown]
# ### Evaluate The Model:

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import pandas as pd
import cv2
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import accuracy_score, f1_score, jaccard_score, precision_score, recall_score, auc
# from metrics import dice_loss, dice_coef, iou
# from utils import get_filenames_sorted

# %%
H = 512
W = 512

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.float32)
    return ori_x, x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.float32)
    x = x[:,:,0:2] # Discard the last channel 
    return ori_x, x

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.png")))
    y = sorted(glob(os.path.join(path, "mask", "*.png")))
    return x, y

def save_results(ori_x, ori_y, y_pred, save_image_path, channel):
    line = np.ones((y_pred.shape[0], 10, 3)) * 255

    pred_image = np.zeros((y_pred.shape[0], y_pred.shape[1], 3))
    _y_pred = y_pred[:, :, channel]
    _ori_y = ori_y[:, :, channel]
    pred_image[:, :, 0] = ((_y_pred > 0.5) & (_ori_y <= 128)) * 255
    pred_image[:, :, 1] = ((_y_pred > 0.5) & (_ori_y  > 128)) * 255
    pred_image[:, :, 2] = ((_ori_y  > 128) & (_y_pred <= 0.5 )) * 255

    print(" saving result", save_image_path)
    cv2.imwrite(save_image_path, pred_image)

# %%
from copy import deepcopy

data_dir = "new_data"
od_channel, bv_channel = 0, 1

model_dir = "files"
threshold = 0.1

od_result_dir = f"files_demo_od_{threshold}_1024"
bv_result_dir = f"files_demo_bv_{threshold}_1024"

create_dir(od_result_dir)
create_dir(bv_result_dir)

""" Load the model """
model_file_name = f"{model_dir}/model_1024.h5"
print(model_file_name)
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef, 'dice_coef_OD': dice_coef_OD, 'dice_coef_MA': dice_coef_MA, 'dice_loss': dice_loss}):
model = tf.keras.models.load_model(model_file_name, compile = False)

""" Load the dataset """
# dataset_path = os.path.join(data_dir, "test")
# test_x, test_y = get_filenames_sorted(data_dir + "/test/image/", data_dir + "/test/mask/" )

dataset_path = os.path.join("new_data", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE_BV, SCORE_OD = [], []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.rsplit("/", 1)[1].rsplit(".", 1)[0]
    print(name)

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred_prob = deepcopy(y_pred)
    y_pred = y_pred > threshold
    y_pred = y_pred.astype(np.float32)

    print(np.max(ori_y), np.max(y))

    """ Saving the images """
    save_image_path_od = f"{od_result_dir}/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path_od, od_channel)

    save_image_path_bv = f"{bv_result_dir}/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path_bv, bv_channel)


#     """ Calculate the od metrics """
    bv_pred = y_pred[:, :, bv_channel].flatten()
    bv_pred_prob = y_pred_prob[:, :, bv_channel].flatten()
    bv_gt = y[:, :, bv_channel].flatten()
    acc_value = accuracy_score(bv_gt > threshold, bv_pred>threshold)
    f1_value = f1_score(bv_gt > threshold, bv_pred>threshold, labels=[0, 1], average="binary")
    jac_value = jaccard_score(bv_gt > threshold, bv_pred>threshold, labels=[0, 1], average="binary")
    recall_value = recall_score(bv_gt > threshold, bv_pred>threshold, labels=[0, 1], average="binary")
    recall_computed = np.sum((bv_gt > threshold) & (bv_pred > threshold)) / np.sum(bv_gt > threshold)
    precision_value = precision_score(bv_gt > threshold, bv_pred>threshold, labels=[0, 1], average="binary")
    auc_score = auc(bv_gt > threshold, bv_pred_prob)
    SCORE_BV.append([name, acc_value, f1_value, jac_value, recall_value, precision_value, recall_computed, auc_score])

#     """ Calculate the ma metrics """
    bv_pred = y_pred[:, :, od_channel].flatten()
    bv_pred_prob = y_pred_prob[:, :, bv_channel].flatten()
    bv_gt = y[:, :, od_channel].flatten()
    acc_value = accuracy_score(bv_gt > threshold, bv_pred>threshold)
    f1_value = f1_score(bv_gt > threshold, bv_pred>threshold, labels=[0, 1], average="binary")
    jac_value = jaccard_score(bv_gt > threshold, bv_pred>threshold, labels=[0, 1], average="binary")
    recall_value = recall_score(bv_gt > threshold, bv_pred>threshold, labels=[0, 1], average="binary")
    recall_computed = np.sum((bv_gt > threshold) & (bv_pred > threshold)) / np.sum(bv_gt > threshold)
    precision_value = precision_score(bv_gt > threshold, bv_pred>threshold, labels=[0, 1], average="binary")
    auc_score = auc(bv_gt > threshold, bv_pred_prob)
    SCORE_OD.append([name, acc_value, f1_value, jac_value, recall_value, precision_value, recall_computed, auc_score])
    
print("\n")
for SCORE in [SCORE_OD, SCORE_BV]:
    if SCORE == SCORE_OD:
        print("****** OD ******Metrics")
    else:
        print("****** BV ******Metrics")
    score = [s[1:] for s in SCORE]
    score = np.mean(score, axis=0)
    print(f"Threshold:", threshold)
    print(f"Accuracy: {score[0]:0.5f}")
    print(f"F1: {score[1]:0.5f} (dice score)")
    print(f"Jaccard: {score[2]:0.5f}")
    print(f"Recall: {score[3]:0.5f}")
    print(f"Precision: {score[4]:0.5f}")
    print(f"AUC: {score[5]:0.5f}")

    # """ Saving """
    if SCORE == SCORE_OD:
        df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision", "Recall Computed", "AUC"])
        df.to_csv(f"{od_result_dir}/score.csv")
    else:
        df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision", "Recall Computed", "AUC"])
        df.to_csv(f"{bv_result_dir}/score.csv")
    print("\n")
# Out:
# files/model_1024.h5
#   0%|          | 0/5 [00:00<?, ?it/s]
# 11_h
# 255 1.0
#  saving result files_demo_od_0.1_1024/11_h.png
#  saving result files_demo_bv_0.1_1024/11_h.png
#  20%|██        | 1/5 [00:01<00:06,  1.57s/it]
# 12_h
# 255 1.0
#  saving result files_demo_od_0.1_1024/12_h.png
#  saving result files_demo_bv_0.1_1024/12_h.png
#  40%|████      | 2/5 [00:02<00:03,  1.19s/it]
# 13_h
# 255 1.0
#  saving result files_demo_od_0.1_1024/13_h.png
#  saving result files_demo_bv_0.1_1024/13_h.png
#  60%|██████    | 3/5 [00:03<00:02,  1.08s/it]
# 14_h
# 255 1.0
#  saving result files_demo_od_0.1_1024/14_h.png
#  saving result files_demo_bv_0.1_1024/14_h.png
#  80%|████████  | 4/5 [00:04<00:01,  1.03s/it]
# 15_h
# 255 1.0
#  saving result files_demo_od_0.1_1024/15_h.png
#  saving result files_demo_bv_0.1_1024/15_h.png
# 100%|██████████| 5/5 [00:05<00:00,  1.06s/it]
# ****** OD ******Metrics
# Threshold: 0.1
# Accuracy: 0.99746
# F1: 0.88449 (dice score)
# Jaccard: 0.79520
# Recall: 0.82989
# Precision: 0.95567
# AUC: 0.82989
#
#
# ****** BV ******Metrics
# Threshold: 0.1
# Accuracy: 0.96082
# F1: 0.81662 (dice score)
# Jaccard: 0.69042
# Recall: 0.89703
# Precision: 0.75117
# AUC: 0.89703

# %%
import pandas as pd

df = pd.read_csv("files/data_1024.csv")
df.head()
# Out:
#    epoch  dice_coef       iou      loss      lr  precision    recall  \
# 0      0   0.182591  0.100831  1.285691  0.0001   0.246307  0.728415
# 1      1   0.266508  0.153896  1.017996  0.0001   0.626594  0.732754
# 2      2   0.308573  0.182500  0.931473  0.0001   0.684305  0.770445
# 3      3   0.332538  0.199492  0.886075  0.0001   0.716459  0.792554
# 4      4   0.351526  0.213307  0.852412  0.0001   0.739553  0.807123
#
#    val_dice_coef   val_iou  val_loss  val_precision  val_recall
# 0       0.090629  0.047481  1.562526            0.0         0.0
# 1       0.088485  0.046306  1.486098            0.0         0.0
# 2       0.086337  0.045130  1.410844            0.0         0.0
# 3       0.084365  0.044053  1.356981            0.0         0.0
# 4       0.084824  0.044303  1.312012            0.0         0.0

# %%
import matplotlib.pyplot as plt

plt.plot(df["epoch"], df["dice_coef"].values)
plt.plot(df["epoch"], df["val_dice_coef"].values)
plt.legend(["train", "val"])
plt.xlabel("Epochs")
plt.ylabel("Dice Score")
plt.show()

# %%
plt.plot(df["epoch"], df["loss"].values)
plt.plot(df["epoch"], df["val_loss"].values)
plt.legend(["train", "val"])
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()
