# %% [markdown]
# ### Import the required libraries and modules:

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
import numpy as np

# %% [markdown]
# ### Unzip the data:

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# %cd /content/gdrive/MyDrive/1_All_Computations/BV_EX
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/1_All_Computations/BV_EX

# %%
# !unzip new_data.zip
# Out:
# Archive:  new_data.zip
#    creating: new_data/
#    creating: new_data/test/
#    creating: new_data/test/image/
#   inflating: new_data/test/image/IDRiD_55.jpg
#   inflating: new_data/test/image/IDRiD_56.jpg
#   inflating: new_data/test/image/IDRiD_57.jpg
#   inflating: new_data/test/image/IDRiD_58.jpg
#   inflating: new_data/test/image/IDRiD_59.jpg
#   inflating: new_data/test/image/IDRiD_60.jpg
#   inflating: new_data/test/image/IDRiD_61.jpg
#   inflating: new_data/test/image/IDRiD_62.jpg
#   inflating: new_data/test/image/IDRiD_63.jpg
#   inflating: new_data/test/image/IDRiD_64.jpg
#   inflating: new_data/test/image/IDRiD_65.jpg
#   inflating: new_data/test/image/IDRiD_66.jpg
#   inflating: new_data/test/image/IDRiD_67.jpg
#   inflating: new_data/test/image/IDRiD_68.jpg
#   inflating: new_data/test/image/IDRiD_69.jpg
#   inflating: new_data/test/image/IDRiD_70.jpg
#   inflating: new_data/test/image/IDRiD_71.jpg
#   inflating: new_data/test/image/IDRiD_72.jpg
#   inflating: new_data/test/image/IDRiD_73.jpg
#   inflating: new_data/test/image/IDRiD_74.jpg
#   inflating: new_data/test/image/IDRiD_75.jpg
#   inflating: new_data/test/image/IDRiD_76.jpg
#   inflating: new_data/test/image/IDRiD_77.jpg
#   inflating: new_data/test/image/IDRiD_78.jpg
#   inflating: new_data/test/image/IDRiD_79.jpg
#   inflating: new_data/test/image/IDRiD_80.jpg
#   inflating: new_data/test/image/IDRiD_81.jpg
#    creating: new_data/test/mask/
#   inflating: new_data/test/mask/IDRiD_55.jpg
#   inflating: new_data/test/mask/IDRiD_56.jpg
#   inflating: new_data/test/mask/IDRiD_57.jpg
#   inflating: new_data/test/mask/IDRiD_58.jpg
#   inflating: new_data/test/mask/IDRiD_59.jpg
#   inflating: new_data/test/mask/IDRiD_60.jpg
#   inflating: new_data/test/mask/IDRiD_61.jpg
#   inflating: new_data/test/mask/IDRiD_62.jpg
#   inflating: new_data/test/mask/IDRiD_63.jpg
#   inflating: new_data/test/mask/IDRiD_64.jpg
#   inflating: new_data/test/mask/IDRiD_65.jpg
#   inflating: new_data/test/mask/IDRiD_66.jpg
#   inflating: new_data/test/mask/IDRiD_67.jpg
#   inflating: new_data/test/mask/IDRiD_68.jpg
#   inflating: new_data/test/mask/IDRiD_69.jpg
#   inflating: new_data/test/mask/IDRiD_70.jpg
#   inflating: new_data/test/mask/IDRiD_71.jpg
#   inflating: new_data/test/mask/IDRiD_72.jpg
#   inflating: new_data/test/mask/IDRiD_73.jpg
#   inflating: new_data/test/mask/IDRiD_74.jpg
#   inflating: new_data/test/mask/IDRiD_75.jpg
#   inflating: new_data/test/mask/IDRiD_76.jpg
#   inflating: new_data/test/mask/IDRiD_77.jpg
#   inflating: new_data/test/mask/IDRiD_78.jpg
#   inflating: new_data/test/mask/IDRiD_79.jpg
#   inflating: new_data/test/mask/IDRiD_80.jpg
#   inflating: new_data/test/mask/IDRiD_81.jpg
#    creating: new_data/train/
#    creating: new_data/train/image/
#   inflating: new_data/train/image/IDRiD_01_0.jpg
#   inflating: new_data/train/image/IDRiD_01_1.jpg
#   inflating: new_data/train/image/IDRiD_01_2.jpg
#   inflating: new_data/train/image/IDRiD_01_3.jpg
#   inflating: new_data/train/image/IDRiD_01_4.jpg
#   inflating: new_data/train/image/IDRiD_01_5.jpg
#   inflating: new_data/train/image/IDRiD_02_0.jpg
#   inflating: new_data/train/image/IDRiD_02_1.jpg
#   inflating: new_data/train/image/IDRiD_02_2.jpg
#   inflating: new_data/train/image/IDRiD_02_3.jpg
#   inflating: new_data/train/image/IDRiD_02_4.jpg
#   inflating: new_data/train/image/IDRiD_02_5.jpg
#   inflating: new_data/train/image/IDRiD_03_0.jpg
#   inflating: new_data/train/image/IDRiD_03_1.jpg
#   inflating: new_data/train/image/IDRiD_03_2.jpg
#   inflating: new_data/train/image/IDRiD_03_3.jpg
#   inflating: new_data/train/image/IDRiD_03_4.jpg
#   inflating: new_data/train/image/IDRiD_03_5.jpg
#   inflating: new_data/train/image/IDRiD_04_0.jpg
#   inflating: new_data/train/image/IDRiD_04_1.jpg
#   inflating: new_data/train/image/IDRiD_04_2.jpg
#   inflating: new_data/train/image/IDRiD_04_3.jpg
#   inflating: new_data/train/image/IDRiD_04_4.jpg
#   inflating: new_data/train/image/IDRiD_04_5.jpg
#   inflating: new_data/train/image/IDRiD_05_0.jpg
#   inflating: new_data/train/image/IDRiD_05_1.jpg
#   inflating: new_data/train/image/IDRiD_05_2.jpg
#   inflating: new_data/train/image/IDRiD_05_3.jpg
#   inflating: new_data/train/image/IDRiD_05_4.jpg
#   inflating: new_data/train/image/IDRiD_05_5.jpg
#   inflating: new_data/train/image/IDRiD_06_0.jpg
#   inflating: new_data/train/image/IDRiD_06_1.jpg
#   inflating: new_data/train/image/IDRiD_06_2.jpg
#   inflating: new_data/train/image/IDRiD_06_3.jpg
#   inflating: new_data/train/image/IDRiD_06_4.jpg
#   inflating: new_data/train/image/IDRiD_06_5.jpg
#   inflating: new_data/train/image/IDRiD_07_0.jpg
#   inflating: new_data/train/image/IDRiD_07_1.jpg
#   inflating: new_data/train/image/IDRiD_07_2.jpg
#   inflating: new_data/train/image/IDRiD_07_3.jpg
#   inflating: new_data/train/image/IDRiD_07_4.jpg
#   inflating: new_data/train/image/IDRiD_07_5.jpg
#   inflating: new_data/train/image/IDRiD_08_0.jpg
#   inflating: new_data/train/image/IDRiD_08_1.jpg
#   inflating: new_data/train/image/IDRiD_08_2.jpg
#   inflating: new_data/train/image/IDRiD_08_3.jpg
#   inflating: new_data/train/image/IDRiD_08_4.jpg
#   inflating: new_data/train/image/IDRiD_08_5.jpg
#   inflating: new_data/train/image/IDRiD_09_0.jpg
#   inflating: new_data/train/image/IDRiD_09_1.jpg
#   inflating: new_data/train/image/IDRiD_09_2.jpg
#   inflating: new_data/train/image/IDRiD_09_3.jpg
#   inflating: new_data/train/image/IDRiD_09_4.jpg
#   inflating: new_data/train/image/IDRiD_09_5.jpg
#   inflating: new_data/train/image/IDRiD_10_0.jpg
#   inflating: new_data/train/image/IDRiD_10_1.jpg
#   inflating: new_data/train/image/IDRiD_10_2.jpg
#   inflating: new_data/train/image/IDRiD_10_3.jpg
#   inflating: new_data/train/image/IDRiD_10_4.jpg
#   inflating: new_data/train/image/IDRiD_10_5.jpg
#   inflating: new_data/train/image/IDRiD_11_0.jpg
#   inflating: new_data/train/image/IDRiD_11_1.jpg
#   inflating: new_data/train/image/IDRiD_11_2.jpg
#   inflating: new_data/train/image/IDRiD_11_3.jpg
#   inflating: new_data/train/image/IDRiD_11_4.jpg
#   inflating: new_data/train/image/IDRiD_11_5.jpg
#   inflating: new_data/train/image/IDRiD_12_0.jpg
#   inflating: new_data/train/image/IDRiD_12_1.jpg
#   inflating: new_data/train/image/IDRiD_12_2.jpg
#   inflating: new_data/train/image/IDRiD_12_3.jpg
#   inflating: new_data/train/image/IDRiD_12_4.jpg
#   inflating: new_data/train/image/IDRiD_12_5.jpg
#   inflating: new_data/train/image/IDRiD_13_0.jpg
#   inflating: new_data/train/image/IDRiD_13_1.jpg
#   inflating: new_data/train/image/IDRiD_13_2.jpg
#   inflating: new_data/train/image/IDRiD_13_3.jpg
#   inflating: new_data/train/image/IDRiD_13_4.jpg
#   inflating: new_data/train/image/IDRiD_13_5.jpg
#   inflating: new_data/train/image/IDRiD_14_0.jpg
#   inflating: new_data/train/image/IDRiD_14_1.jpg
#   inflating: new_data/train/image/IDRiD_14_2.jpg
#   inflating: new_data/train/image/IDRiD_14_3.jpg
#   inflating: new_data/train/image/IDRiD_14_4.jpg
#   inflating: new_data/train/image/IDRiD_14_5.jpg
#   inflating: new_data/train/image/IDRiD_15_0.jpg
#   inflating: new_data/train/image/IDRiD_15_1.jpg
#   inflating: new_data/train/image/IDRiD_15_2.jpg
#   inflating: new_data/train/image/IDRiD_15_3.jpg
#   inflating: new_data/train/image/IDRiD_15_4.jpg
#   inflating: new_data/train/image/IDRiD_15_5.jpg
#   inflating: new_data/train/image/IDRiD_16_0.jpg
#   inflating: new_data/train/image/IDRiD_16_1.jpg
#   inflating: new_data/train/image/IDRiD_16_2.jpg
#   inflating: new_data/train/image/IDRiD_16_3.jpg
#   inflating: new_data/train/image/IDRiD_16_4.jpg
#   inflating: new_data/train/image/IDRiD_16_5.jpg
#   inflating: new_data/train/image/IDRiD_17_0.jpg
#   inflating: new_data/train/image/IDRiD_17_1.jpg
#   inflating: new_data/train/image/IDRiD_17_2.jpg
#   inflating: new_data/train/image/IDRiD_17_3.jpg
#   inflating: new_data/train/image/IDRiD_17_4.jpg
#   inflating: new_data/train/image/IDRiD_17_5.jpg
#   inflating: new_data/train/image/IDRiD_18_0.jpg
#   inflating: new_data/train/image/IDRiD_18_1.jpg
#   inflating: new_data/train/image/IDRiD_18_2.jpg
#   inflating: new_data/train/image/IDRiD_18_3.jpg
#   inflating: new_data/train/image/IDRiD_18_4.jpg
#   inflating: new_data/train/image/IDRiD_18_5.jpg
#   inflating: new_data/train/image/IDRiD_19_0.jpg
#   inflating: new_data/train/image/IDRiD_19_1.jpg
#   inflating: new_data/train/image/IDRiD_19_2.jpg
#   inflating: new_data/train/image/IDRiD_19_3.jpg
#   inflating: new_data/train/image/IDRiD_19_4.jpg
#   inflating: new_data/train/image/IDRiD_19_5.jpg
#   inflating: new_data/train/image/IDRiD_20_0.jpg
#   inflating: new_data/train/image/IDRiD_20_1.jpg
#   inflating: new_data/train/image/IDRiD_20_2.jpg
#   inflating: new_data/train/image/IDRiD_20_3.jpg
#   inflating: new_data/train/image/IDRiD_20_4.jpg
#   inflating: new_data/train/image/IDRiD_20_5.jpg
#   inflating: new_data/train/image/IDRiD_21_0.jpg
#   inflating: new_data/train/image/IDRiD_21_1.jpg
#   inflating: new_data/train/image/IDRiD_21_2.jpg
#   inflating: new_data/train/image/IDRiD_21_3.jpg
#   inflating: new_data/train/image/IDRiD_21_4.jpg
#   inflating: new_data/train/image/IDRiD_21_5.jpg
#   inflating: new_data/train/image/IDRiD_22_0.jpg
#   inflating: new_data/train/image/IDRiD_22_1.jpg
#   inflating: new_data/train/image/IDRiD_22_2.jpg
#   inflating: new_data/train/image/IDRiD_22_3.jpg
#   inflating: new_data/train/image/IDRiD_22_4.jpg
#   inflating: new_data/train/image/IDRiD_22_5.jpg
#   inflating: new_data/train/image/IDRiD_23_0.jpg
#   inflating: new_data/train/image/IDRiD_23_1.jpg
#   inflating: new_data/train/image/IDRiD_23_2.jpg
#   inflating: new_data/train/image/IDRiD_23_3.jpg
#   inflating: new_data/train/image/IDRiD_23_4.jpg
#   inflating: new_data/train/image/IDRiD_23_5.jpg
#   inflating: new_data/train/image/IDRiD_24_0.jpg
#   inflating: new_data/train/image/IDRiD_24_1.jpg
#   inflating: new_data/train/image/IDRiD_24_2.jpg
#   inflating: new_data/train/image/IDRiD_24_3.jpg
#   inflating: new_data/train/image/IDRiD_24_4.jpg
#   inflating: new_data/train/image/IDRiD_24_5.jpg
#   inflating: new_data/train/image/IDRiD_25_0.jpg
#   inflating: new_data/train/image/IDRiD_25_1.jpg
#   inflating: new_data/train/image/IDRiD_25_2.jpg
#   inflating: new_data/train/image/IDRiD_25_3.jpg
#   inflating: new_data/train/image/IDRiD_25_4.jpg
#   inflating: new_data/train/image/IDRiD_25_5.jpg
#   inflating: new_data/train/image/IDRiD_26_0.jpg
#   inflating: new_data/train/image/IDRiD_26_1.jpg
#   inflating: new_data/train/image/IDRiD_26_2.jpg
#   inflating: new_data/train/image/IDRiD_26_3.jpg
#   inflating: new_data/train/image/IDRiD_26_4.jpg
#   inflating: new_data/train/image/IDRiD_26_5.jpg
#   inflating: new_data/train/image/IDRiD_27_0.jpg
#   inflating: new_data/train/image/IDRiD_27_1.jpg
#   inflating: new_data/train/image/IDRiD_27_2.jpg
#   inflating: new_data/train/image/IDRiD_27_3.jpg
#   inflating: new_data/train/image/IDRiD_27_4.jpg
#   inflating: new_data/train/image/IDRiD_27_5.jpg
#   inflating: new_data/train/image/IDRiD_28_0.jpg
#   inflating: new_data/train/image/IDRiD_28_1.jpg
#   inflating: new_data/train/image/IDRiD_28_2.jpg
#   inflating: new_data/train/image/IDRiD_28_3.jpg
#   inflating: new_data/train/image/IDRiD_28_4.jpg
#   inflating: new_data/train/image/IDRiD_28_5.jpg
#   inflating: new_data/train/image/IDRiD_29_0.jpg
#   inflating: new_data/train/image/IDRiD_29_1.jpg
#   inflating: new_data/train/image/IDRiD_29_2.jpg
#   inflating: new_data/train/image/IDRiD_29_3.jpg
#   inflating: new_data/train/image/IDRiD_29_4.jpg
#   inflating: new_data/train/image/IDRiD_29_5.jpg
#   inflating: new_data/train/image/IDRiD_30_0.jpg
#   inflating: new_data/train/image/IDRiD_30_1.jpg
#   inflating: new_data/train/image/IDRiD_30_2.jpg
#   inflating: new_data/train/image/IDRiD_30_3.jpg
#   inflating: new_data/train/image/IDRiD_30_4.jpg
#   inflating: new_data/train/image/IDRiD_30_5.jpg
#   inflating: new_data/train/image/IDRiD_31_0.jpg
#   inflating: new_data/train/image/IDRiD_31_1.jpg
#   inflating: new_data/train/image/IDRiD_31_2.jpg
#   inflating: new_data/train/image/IDRiD_31_3.jpg
#   inflating: new_data/train/image/IDRiD_31_4.jpg
#   inflating: new_data/train/image/IDRiD_31_5.jpg
#   inflating: new_data/train/image/IDRiD_32_0.jpg
#   inflating: new_data/train/image/IDRiD_32_1.jpg
#   inflating: new_data/train/image/IDRiD_32_2.jpg
#   inflating: new_data/train/image/IDRiD_32_3.jpg
#   inflating: new_data/train/image/IDRiD_32_4.jpg
#   inflating: new_data/train/image/IDRiD_32_5.jpg
#   inflating: new_data/train/image/IDRiD_33_0.jpg
#   inflating: new_data/train/image/IDRiD_33_1.jpg
#   inflating: new_data/train/image/IDRiD_33_2.jpg
#   inflating: new_data/train/image/IDRiD_33_3.jpg
#   inflating: new_data/train/image/IDRiD_33_4.jpg
#   inflating: new_data/train/image/IDRiD_33_5.jpg
#   inflating: new_data/train/image/IDRiD_34_0.jpg
#   inflating: new_data/train/image/IDRiD_34_1.jpg
#   inflating: new_data/train/image/IDRiD_34_2.jpg
#   inflating: new_data/train/image/IDRiD_34_3.jpg
#   inflating: new_data/train/image/IDRiD_34_4.jpg
#   inflating: new_data/train/image/IDRiD_34_5.jpg
#   inflating: new_data/train/image/IDRiD_35_0.jpg
#   inflating: new_data/train/image/IDRiD_35_1.jpg
#   inflating: new_data/train/image/IDRiD_35_2.jpg
#   inflating: new_data/train/image/IDRiD_35_3.jpg
#   inflating: new_data/train/image/IDRiD_35_4.jpg
#   inflating: new_data/train/image/IDRiD_35_5.jpg
#   inflating: new_data/train/image/IDRiD_36_0.jpg
#   inflating: new_data/train/image/IDRiD_36_1.jpg
#   inflating: new_data/train/image/IDRiD_36_2.jpg
#   inflating: new_data/train/image/IDRiD_36_3.jpg
#   inflating: new_data/train/image/IDRiD_36_4.jpg
#   inflating: new_data/train/image/IDRiD_36_5.jpg
#   inflating: new_data/train/image/IDRiD_37_0.jpg
#   inflating: new_data/train/image/IDRiD_37_1.jpg
#   inflating: new_data/train/image/IDRiD_37_2.jpg
#   inflating: new_data/train/image/IDRiD_37_3.jpg
#   inflating: new_data/train/image/IDRiD_37_4.jpg
#   inflating: new_data/train/image/IDRiD_37_5.jpg
#   inflating: new_data/train/image/IDRiD_38_0.jpg
#   inflating: new_data/train/image/IDRiD_38_1.jpg
#   inflating: new_data/train/image/IDRiD_38_2.jpg
#   inflating: new_data/train/image/IDRiD_38_3.jpg
#   inflating: new_data/train/image/IDRiD_38_4.jpg
#   inflating: new_data/train/image/IDRiD_38_5.jpg
#   inflating: new_data/train/image/IDRiD_39_0.jpg
#   inflating: new_data/train/image/IDRiD_39_1.jpg
#   inflating: new_data/train/image/IDRiD_39_2.jpg
#   inflating: new_data/train/image/IDRiD_39_3.jpg
#   inflating: new_data/train/image/IDRiD_39_4.jpg
#   inflating: new_data/train/image/IDRiD_39_5.jpg
#   inflating: new_data/train/image/IDRiD_40_0.jpg
#   inflating: new_data/train/image/IDRiD_40_1.jpg
#   inflating: new_data/train/image/IDRiD_40_2.jpg
#   inflating: new_data/train/image/IDRiD_40_3.jpg
#   inflating: new_data/train/image/IDRiD_40_4.jpg
#   inflating: new_data/train/image/IDRiD_40_5.jpg
#   inflating: new_data/train/image/IDRiD_41_0.jpg
#   inflating: new_data/train/image/IDRiD_41_1.jpg
#   inflating: new_data/train/image/IDRiD_41_2.jpg
#   inflating: new_data/train/image/IDRiD_41_3.jpg
#   inflating: new_data/train/image/IDRiD_41_4.jpg
#   inflating: new_data/train/image/IDRiD_41_5.jpg
#   inflating: new_data/train/image/IDRiD_42_0.jpg
#   inflating: new_data/train/image/IDRiD_42_1.jpg
#   inflating: new_data/train/image/IDRiD_42_2.jpg
#   inflating: new_data/train/image/IDRiD_42_3.jpg
#   inflating: new_data/train/image/IDRiD_42_4.jpg
#   inflating: new_data/train/image/IDRiD_42_5.jpg
#   inflating: new_data/train/image/IDRiD_44_0.jpg
#   inflating: new_data/train/image/IDRiD_44_1.jpg
#   inflating: new_data/train/image/IDRiD_44_2.jpg
#   inflating: new_data/train/image/IDRiD_44_3.jpg
#   inflating: new_data/train/image/IDRiD_44_4.jpg
#   inflating: new_data/train/image/IDRiD_44_5.jpg
#   inflating: new_data/train/image/IDRiD_45_0.jpg
#   inflating: new_data/train/image/IDRiD_45_1.jpg
#   inflating: new_data/train/image/IDRiD_45_2.jpg
#   inflating: new_data/train/image/IDRiD_45_3.jpg
#   inflating: new_data/train/image/IDRiD_45_4.jpg
#   inflating: new_data/train/image/IDRiD_45_5.jpg
#   inflating: new_data/train/image/IDRiD_46_0.jpg
#   inflating: new_data/train/image/IDRiD_46_1.jpg
#   inflating: new_data/train/image/IDRiD_46_2.jpg
#   inflating: new_data/train/image/IDRiD_46_3.jpg
#   inflating: new_data/train/image/IDRiD_46_4.jpg
#   inflating: new_data/train/image/IDRiD_46_5.jpg
#   inflating: new_data/train/image/IDRiD_47_0.jpg
#   inflating: new_data/train/image/IDRiD_47_1.jpg
#   inflating: new_data/train/image/IDRiD_47_2.jpg
#   inflating: new_data/train/image/IDRiD_47_3.jpg
#   inflating: new_data/train/image/IDRiD_47_4.jpg
#   inflating: new_data/train/image/IDRiD_47_5.jpg
#   inflating: new_data/train/image/IDRiD_48_0.jpg
#   inflating: new_data/train/image/IDRiD_48_1.jpg
#   inflating: new_data/train/image/IDRiD_48_2.jpg
#   inflating: new_data/train/image/IDRiD_48_3.jpg
#   inflating: new_data/train/image/IDRiD_48_4.jpg
#   inflating: new_data/train/image/IDRiD_48_5.jpg
#   inflating: new_data/train/image/IDRiD_49_0.jpg
#   inflating: new_data/train/image/IDRiD_49_1.jpg
#   inflating: new_data/train/image/IDRiD_49_2.jpg
#   inflating: new_data/train/image/IDRiD_49_3.jpg
#   inflating: new_data/train/image/IDRiD_49_4.jpg
#   inflating: new_data/train/image/IDRiD_49_5.jpg
#   inflating: new_data/train/image/IDRiD_50_0.jpg
#   inflating: new_data/train/image/IDRiD_50_1.jpg
#   inflating: new_data/train/image/IDRiD_50_2.jpg
#   inflating: new_data/train/image/IDRiD_50_3.jpg
#   inflating: new_data/train/image/IDRiD_50_4.jpg
#   inflating: new_data/train/image/IDRiD_50_5.jpg
#   inflating: new_data/train/image/IDRiD_51_0.jpg
#   inflating: new_data/train/image/IDRiD_51_1.jpg
#   inflating: new_data/train/image/IDRiD_51_2.jpg
#   inflating: new_data/train/image/IDRiD_51_3.jpg
#   inflating: new_data/train/image/IDRiD_51_4.jpg
#   inflating: new_data/train/image/IDRiD_51_5.jpg
#   inflating: new_data/train/image/IDRiD_52_0.jpg
#   inflating: new_data/train/image/IDRiD_52_1.jpg
#   inflating: new_data/train/image/IDRiD_52_2.jpg
#   inflating: new_data/train/image/IDRiD_52_3.jpg
#   inflating: new_data/train/image/IDRiD_52_4.jpg
#   inflating: new_data/train/image/IDRiD_52_5.jpg
#   inflating: new_data/train/image/IDRiD_53_0.jpg
#   inflating: new_data/train/image/IDRiD_53_1.jpg
#   inflating: new_data/train/image/IDRiD_53_2.jpg
#   inflating: new_data/train/image/IDRiD_53_3.jpg
#   inflating: new_data/train/image/IDRiD_53_4.jpg
#   inflating: new_data/train/image/IDRiD_53_5.jpg
#   inflating: new_data/train/image/IDRiD_54_0.jpg
#   inflating: new_data/train/image/IDRiD_54_1.jpg
#   inflating: new_data/train/image/IDRiD_54_2.jpg
#   inflating: new_data/train/image/IDRiD_54_3.jpg
#   inflating: new_data/train/image/IDRiD_54_4.jpg
#   inflating: new_data/train/image/IDRiD_54_5.jpg
#    creating: new_data/train/mask/
#   inflating: new_data/train/mask/IDRiD_01_0.jpg
#   inflating: new_data/train/mask/IDRiD_01_1.jpg
#   inflating: new_data/train/mask/IDRiD_01_2.jpg
#   inflating: new_data/train/mask/IDRiD_01_3.jpg
#   inflating: new_data/train/mask/IDRiD_01_4.jpg
#   inflating: new_data/train/mask/IDRiD_01_5.jpg
#   inflating: new_data/train/mask/IDRiD_02_0.jpg
#   inflating: new_data/train/mask/IDRiD_02_1.jpg
#   inflating: new_data/train/mask/IDRiD_02_2.jpg
#   inflating: new_data/train/mask/IDRiD_02_3.jpg
#   inflating: new_data/train/mask/IDRiD_02_4.jpg
#   inflating: new_data/train/mask/IDRiD_02_5.jpg
#   inflating: new_data/train/mask/IDRiD_03_0.jpg
#   inflating: new_data/train/mask/IDRiD_03_1.jpg
#   inflating: new_data/train/mask/IDRiD_03_2.jpg
#   inflating: new_data/train/mask/IDRiD_03_3.jpg
#   inflating: new_data/train/mask/IDRiD_03_4.jpg
#   inflating: new_data/train/mask/IDRiD_03_5.jpg
#   inflating: new_data/train/mask/IDRiD_04_0.jpg
#   inflating: new_data/train/mask/IDRiD_04_1.jpg
#   inflating: new_data/train/mask/IDRiD_04_2.jpg
#   inflating: new_data/train/mask/IDRiD_04_3.jpg
#   inflating: new_data/train/mask/IDRiD_04_4.jpg
#   inflating: new_data/train/mask/IDRiD_04_5.jpg
#   inflating: new_data/train/mask/IDRiD_05_0.jpg
#   inflating: new_data/train/mask/IDRiD_05_1.jpg
#   inflating: new_data/train/mask/IDRiD_05_2.jpg
#   inflating: new_data/train/mask/IDRiD_05_3.jpg
#   inflating: new_data/train/mask/IDRiD_05_4.jpg
#   inflating: new_data/train/mask/IDRiD_05_5.jpg
#   inflating: new_data/train/mask/IDRiD_06_0.jpg
#   inflating: new_data/train/mask/IDRiD_06_1.jpg
#   inflating: new_data/train/mask/IDRiD_06_2.jpg
#   inflating: new_data/train/mask/IDRiD_06_3.jpg
#   inflating: new_data/train/mask/IDRiD_06_4.jpg
#   inflating: new_data/train/mask/IDRiD_06_5.jpg
#   inflating: new_data/train/mask/IDRiD_07_0.jpg
#   inflating: new_data/train/mask/IDRiD_07_1.jpg
#   inflating: new_data/train/mask/IDRiD_07_2.jpg
#   inflating: new_data/train/mask/IDRiD_07_3.jpg
#   inflating: new_data/train/mask/IDRiD_07_4.jpg
#   inflating: new_data/train/mask/IDRiD_07_5.jpg
#   inflating: new_data/train/mask/IDRiD_08_0.jpg
#   inflating: new_data/train/mask/IDRiD_08_1.jpg
#   inflating: new_data/train/mask/IDRiD_08_2.jpg
#   inflating: new_data/train/mask/IDRiD_08_3.jpg
#   inflating: new_data/train/mask/IDRiD_08_4.jpg
#   inflating: new_data/train/mask/IDRiD_08_5.jpg
#   inflating: new_data/train/mask/IDRiD_09_0.jpg
#   inflating: new_data/train/mask/IDRiD_09_1.jpg
#   inflating: new_data/train/mask/IDRiD_09_2.jpg
#   inflating: new_data/train/mask/IDRiD_09_3.jpg
#   inflating: new_data/train/mask/IDRiD_09_4.jpg
#   inflating: new_data/train/mask/IDRiD_09_5.jpg
#   inflating: new_data/train/mask/IDRiD_10_0.jpg
#   inflating: new_data/train/mask/IDRiD_10_1.jpg
#   inflating: new_data/train/mask/IDRiD_10_2.jpg
#   inflating: new_data/train/mask/IDRiD_10_3.jpg
#   inflating: new_data/train/mask/IDRiD_10_4.jpg
#   inflating: new_data/train/mask/IDRiD_10_5.jpg
#   inflating: new_data/train/mask/IDRiD_11_0.jpg
#   inflating: new_data/train/mask/IDRiD_11_1.jpg
#   inflating: new_data/train/mask/IDRiD_11_2.jpg
#   inflating: new_data/train/mask/IDRiD_11_3.jpg
#   inflating: new_data/train/mask/IDRiD_11_4.jpg
#   inflating: new_data/train/mask/IDRiD_11_5.jpg
#   inflating: new_data/train/mask/IDRiD_12_0.jpg
#   inflating: new_data/train/mask/IDRiD_12_1.jpg
#   inflating: new_data/train/mask/IDRiD_12_2.jpg
#   inflating: new_data/train/mask/IDRiD_12_3.jpg
#   inflating: new_data/train/mask/IDRiD_12_4.jpg
#   inflating: new_data/train/mask/IDRiD_12_5.jpg
#   inflating: new_data/train/mask/IDRiD_13_0.jpg
#   inflating: new_data/train/mask/IDRiD_13_1.jpg
#   inflating: new_data/train/mask/IDRiD_13_2.jpg
#   inflating: new_data/train/mask/IDRiD_13_3.jpg
#   inflating: new_data/train/mask/IDRiD_13_4.jpg
#   inflating: new_data/train/mask/IDRiD_13_5.jpg
#   inflating: new_data/train/mask/IDRiD_14_0.jpg
#   inflating: new_data/train/mask/IDRiD_14_1.jpg
#   inflating: new_data/train/mask/IDRiD_14_2.jpg
#   inflating: new_data/train/mask/IDRiD_14_3.jpg
#   inflating: new_data/train/mask/IDRiD_14_4.jpg
#   inflating: new_data/train/mask/IDRiD_14_5.jpg
#   inflating: new_data/train/mask/IDRiD_15_0.jpg
#   inflating: new_data/train/mask/IDRiD_15_1.jpg
#   inflating: new_data/train/mask/IDRiD_15_2.jpg
#   inflating: new_data/train/mask/IDRiD_15_3.jpg
#   inflating: new_data/train/mask/IDRiD_15_4.jpg
#   inflating: new_data/train/mask/IDRiD_15_5.jpg
#   inflating: new_data/train/mask/IDRiD_16_0.jpg
#   inflating: new_data/train/mask/IDRiD_16_1.jpg
#   inflating: new_data/train/mask/IDRiD_16_2.jpg
#   inflating: new_data/train/mask/IDRiD_16_3.jpg
#   inflating: new_data/train/mask/IDRiD_16_4.jpg
#   inflating: new_data/train/mask/IDRiD_16_5.jpg
#   inflating: new_data/train/mask/IDRiD_17_0.jpg
#   inflating: new_data/train/mask/IDRiD_17_1.jpg
#   inflating: new_data/train/mask/IDRiD_17_2.jpg
#   inflating: new_data/train/mask/IDRiD_17_3.jpg
#   inflating: new_data/train/mask/IDRiD_17_4.jpg
#   inflating: new_data/train/mask/IDRiD_17_5.jpg
#   inflating: new_data/train/mask/IDRiD_18_0.jpg
#   inflating: new_data/train/mask/IDRiD_18_1.jpg
#   inflating: new_data/train/mask/IDRiD_18_2.jpg
#   inflating: new_data/train/mask/IDRiD_18_3.jpg
#   inflating: new_data/train/mask/IDRiD_18_4.jpg
#   inflating: new_data/train/mask/IDRiD_18_5.jpg
#   inflating: new_data/train/mask/IDRiD_19_0.jpg
#   inflating: new_data/train/mask/IDRiD_19_1.jpg
#   inflating: new_data/train/mask/IDRiD_19_2.jpg
#   inflating: new_data/train/mask/IDRiD_19_3.jpg
#   inflating: new_data/train/mask/IDRiD_19_4.jpg
#   inflating: new_data/train/mask/IDRiD_19_5.jpg
#   inflating: new_data/train/mask/IDRiD_20_0.jpg
#   inflating: new_data/train/mask/IDRiD_20_1.jpg
#   inflating: new_data/train/mask/IDRiD_20_2.jpg
#   inflating: new_data/train/mask/IDRiD_20_3.jpg
#   inflating: new_data/train/mask/IDRiD_20_4.jpg
#   inflating: new_data/train/mask/IDRiD_20_5.jpg
#   inflating: new_data/train/mask/IDRiD_21_0.jpg
#   inflating: new_data/train/mask/IDRiD_21_1.jpg
#   inflating: new_data/train/mask/IDRiD_21_2.jpg
#   inflating: new_data/train/mask/IDRiD_21_3.jpg
#   inflating: new_data/train/mask/IDRiD_21_4.jpg
#   inflating: new_data/train/mask/IDRiD_21_5.jpg
#   inflating: new_data/train/mask/IDRiD_22_0.jpg
#   inflating: new_data/train/mask/IDRiD_22_1.jpg
#   inflating: new_data/train/mask/IDRiD_22_2.jpg
#   inflating: new_data/train/mask/IDRiD_22_3.jpg
#   inflating: new_data/train/mask/IDRiD_22_4.jpg
#   inflating: new_data/train/mask/IDRiD_22_5.jpg
#   inflating: new_data/train/mask/IDRiD_23_0.jpg
#   inflating: new_data/train/mask/IDRiD_23_1.jpg
#   inflating: new_data/train/mask/IDRiD_23_2.jpg
#   inflating: new_data/train/mask/IDRiD_23_3.jpg
#   inflating: new_data/train/mask/IDRiD_23_4.jpg
#   inflating: new_data/train/mask/IDRiD_23_5.jpg
#   inflating: new_data/train/mask/IDRiD_24_0.jpg
#   inflating: new_data/train/mask/IDRiD_24_1.jpg
#   inflating: new_data/train/mask/IDRiD_24_2.jpg
#   inflating: new_data/train/mask/IDRiD_24_3.jpg
#   inflating: new_data/train/mask/IDRiD_24_4.jpg
#   inflating: new_data/train/mask/IDRiD_24_5.jpg
#   inflating: new_data/train/mask/IDRiD_25_0.jpg
#   inflating: new_data/train/mask/IDRiD_25_1.jpg
#   inflating: new_data/train/mask/IDRiD_25_2.jpg
#   inflating: new_data/train/mask/IDRiD_25_3.jpg
#   inflating: new_data/train/mask/IDRiD_25_4.jpg
#   inflating: new_data/train/mask/IDRiD_25_5.jpg
#   inflating: new_data/train/mask/IDRiD_26_0.jpg
#   inflating: new_data/train/mask/IDRiD_26_1.jpg
#   inflating: new_data/train/mask/IDRiD_26_2.jpg
#   inflating: new_data/train/mask/IDRiD_26_3.jpg
#   inflating: new_data/train/mask/IDRiD_26_4.jpg
#   inflating: new_data/train/mask/IDRiD_26_5.jpg
#   inflating: new_data/train/mask/IDRiD_27_0.jpg
#   inflating: new_data/train/mask/IDRiD_27_1.jpg
#   inflating: new_data/train/mask/IDRiD_27_2.jpg
#   inflating: new_data/train/mask/IDRiD_27_3.jpg
#   inflating: new_data/train/mask/IDRiD_27_4.jpg
#   inflating: new_data/train/mask/IDRiD_27_5.jpg
#   inflating: new_data/train/mask/IDRiD_28_0.jpg
#   inflating: new_data/train/mask/IDRiD_28_1.jpg
#   inflating: new_data/train/mask/IDRiD_28_2.jpg
#   inflating: new_data/train/mask/IDRiD_28_3.jpg
#   inflating: new_data/train/mask/IDRiD_28_4.jpg
#   inflating: new_data/train/mask/IDRiD_28_5.jpg
#   inflating: new_data/train/mask/IDRiD_29_0.jpg
#   inflating: new_data/train/mask/IDRiD_29_1.jpg
#   inflating: new_data/train/mask/IDRiD_29_2.jpg
#   inflating: new_data/train/mask/IDRiD_29_3.jpg
#   inflating: new_data/train/mask/IDRiD_29_4.jpg
#   inflating: new_data/train/mask/IDRiD_29_5.jpg
#   inflating: new_data/train/mask/IDRiD_30_0.jpg
#   inflating: new_data/train/mask/IDRiD_30_1.jpg
#   inflating: new_data/train/mask/IDRiD_30_2.jpg
#   inflating: new_data/train/mask/IDRiD_30_3.jpg
#   inflating: new_data/train/mask/IDRiD_30_4.jpg
#   inflating: new_data/train/mask/IDRiD_30_5.jpg
#   inflating: new_data/train/mask/IDRiD_31_0.jpg
#   inflating: new_data/train/mask/IDRiD_31_1.jpg
#   inflating: new_data/train/mask/IDRiD_31_2.jpg
#   inflating: new_data/train/mask/IDRiD_31_3.jpg
#   inflating: new_data/train/mask/IDRiD_31_4.jpg
#   inflating: new_data/train/mask/IDRiD_31_5.jpg
#   inflating: new_data/train/mask/IDRiD_32_0.jpg
#   inflating: new_data/train/mask/IDRiD_32_1.jpg
#   inflating: new_data/train/mask/IDRiD_32_2.jpg
#   inflating: new_data/train/mask/IDRiD_32_3.jpg
#   inflating: new_data/train/mask/IDRiD_32_4.jpg
#   inflating: new_data/train/mask/IDRiD_32_5.jpg
#   inflating: new_data/train/mask/IDRiD_33_0.jpg
#   inflating: new_data/train/mask/IDRiD_33_1.jpg
#   inflating: new_data/train/mask/IDRiD_33_2.jpg
#   inflating: new_data/train/mask/IDRiD_33_3.jpg
#   inflating: new_data/train/mask/IDRiD_33_4.jpg
#   inflating: new_data/train/mask/IDRiD_33_5.jpg
#   inflating: new_data/train/mask/IDRiD_34_0.jpg
#   inflating: new_data/train/mask/IDRiD_34_1.jpg
#   inflating: new_data/train/mask/IDRiD_34_2.jpg
#   inflating: new_data/train/mask/IDRiD_34_3.jpg
#   inflating: new_data/train/mask/IDRiD_34_4.jpg
#   inflating: new_data/train/mask/IDRiD_34_5.jpg
#   inflating: new_data/train/mask/IDRiD_35_0.jpg
#   inflating: new_data/train/mask/IDRiD_35_1.jpg
#   inflating: new_data/train/mask/IDRiD_35_2.jpg
#   inflating: new_data/train/mask/IDRiD_35_3.jpg
#   inflating: new_data/train/mask/IDRiD_35_4.jpg
#   inflating: new_data/train/mask/IDRiD_35_5.jpg
#   inflating: new_data/train/mask/IDRiD_36_0.jpg
#   inflating: new_data/train/mask/IDRiD_36_1.jpg
#   inflating: new_data/train/mask/IDRiD_36_2.jpg
#   inflating: new_data/train/mask/IDRiD_36_3.jpg
#   inflating: new_data/train/mask/IDRiD_36_4.jpg
#   inflating: new_data/train/mask/IDRiD_36_5.jpg
#   inflating: new_data/train/mask/IDRiD_37_0.jpg
#   inflating: new_data/train/mask/IDRiD_37_1.jpg
#   inflating: new_data/train/mask/IDRiD_37_2.jpg
#   inflating: new_data/train/mask/IDRiD_37_3.jpg
#   inflating: new_data/train/mask/IDRiD_37_4.jpg
#   inflating: new_data/train/mask/IDRiD_37_5.jpg
#   inflating: new_data/train/mask/IDRiD_38_0.jpg
#   inflating: new_data/train/mask/IDRiD_38_1.jpg
#   inflating: new_data/train/mask/IDRiD_38_2.jpg
#   inflating: new_data/train/mask/IDRiD_38_3.jpg
#   inflating: new_data/train/mask/IDRiD_38_4.jpg
#   inflating: new_data/train/mask/IDRiD_38_5.jpg
#   inflating: new_data/train/mask/IDRiD_39_0.jpg
#   inflating: new_data/train/mask/IDRiD_39_1.jpg
#   inflating: new_data/train/mask/IDRiD_39_2.jpg
#   inflating: new_data/train/mask/IDRiD_39_3.jpg
#   inflating: new_data/train/mask/IDRiD_39_4.jpg
#   inflating: new_data/train/mask/IDRiD_39_5.jpg
#   inflating: new_data/train/mask/IDRiD_40_0.jpg
#   inflating: new_data/train/mask/IDRiD_40_1.jpg
#   inflating: new_data/train/mask/IDRiD_40_2.jpg
#   inflating: new_data/train/mask/IDRiD_40_3.jpg
#   inflating: new_data/train/mask/IDRiD_40_4.jpg
#   inflating: new_data/train/mask/IDRiD_40_5.jpg
#   inflating: new_data/train/mask/IDRiD_41_0.jpg
#   inflating: new_data/train/mask/IDRiD_41_1.jpg
#   inflating: new_data/train/mask/IDRiD_41_2.jpg
#   inflating: new_data/train/mask/IDRiD_41_3.jpg
#   inflating: new_data/train/mask/IDRiD_41_4.jpg
#   inflating: new_data/train/mask/IDRiD_41_5.jpg
#   inflating: new_data/train/mask/IDRiD_42_0.jpg
#   inflating: new_data/train/mask/IDRiD_42_1.jpg
#   inflating: new_data/train/mask/IDRiD_42_2.jpg
#   inflating: new_data/train/mask/IDRiD_42_3.jpg
#   inflating: new_data/train/mask/IDRiD_42_4.jpg
#   inflating: new_data/train/mask/IDRiD_42_5.jpg
#   inflating: new_data/train/mask/IDRiD_44_0.jpg
#   inflating: new_data/train/mask/IDRiD_44_1.jpg
#   inflating: new_data/train/mask/IDRiD_44_2.jpg
#   inflating: new_data/train/mask/IDRiD_44_3.jpg
#   inflating: new_data/train/mask/IDRiD_44_4.jpg
#   inflating: new_data/train/mask/IDRiD_44_5.jpg
#   inflating: new_data/train/mask/IDRiD_45_0.jpg
#   inflating: new_data/train/mask/IDRiD_45_1.jpg
#   inflating: new_data/train/mask/IDRiD_45_2.jpg
#   inflating: new_data/train/mask/IDRiD_45_3.jpg
#   inflating: new_data/train/mask/IDRiD_45_4.jpg
#   inflating: new_data/train/mask/IDRiD_45_5.jpg
#   inflating: new_data/train/mask/IDRiD_46_0.jpg
#   inflating: new_data/train/mask/IDRiD_46_1.jpg
#   inflating: new_data/train/mask/IDRiD_46_2.jpg
#   inflating: new_data/train/mask/IDRiD_46_3.jpg
#   inflating: new_data/train/mask/IDRiD_46_4.jpg
#   inflating: new_data/train/mask/IDRiD_46_5.jpg
#   inflating: new_data/train/mask/IDRiD_47_0.jpg
#   inflating: new_data/train/mask/IDRiD_47_1.jpg
#   inflating: new_data/train/mask/IDRiD_47_2.jpg
#   inflating: new_data/train/mask/IDRiD_47_3.jpg
#   inflating: new_data/train/mask/IDRiD_47_4.jpg
#   inflating: new_data/train/mask/IDRiD_47_5.jpg
#   inflating: new_data/train/mask/IDRiD_48_0.jpg
#   inflating: new_data/train/mask/IDRiD_48_1.jpg
#   inflating: new_data/train/mask/IDRiD_48_2.jpg
#   inflating: new_data/train/mask/IDRiD_48_3.jpg
#   inflating: new_data/train/mask/IDRiD_48_4.jpg
#   inflating: new_data/train/mask/IDRiD_48_5.jpg
#   inflating: new_data/train/mask/IDRiD_49_0.jpg
#   inflating: new_data/train/mask/IDRiD_49_1.jpg
#   inflating: new_data/train/mask/IDRiD_49_2.jpg
#   inflating: new_data/train/mask/IDRiD_49_3.jpg
#   inflating: new_data/train/mask/IDRiD_49_4.jpg
#   inflating: new_data/train/mask/IDRiD_49_5.jpg
#   inflating: new_data/train/mask/IDRiD_50_0.jpg
#   inflating: new_data/train/mask/IDRiD_50_1.jpg
#   inflating: new_data/train/mask/IDRiD_50_2.jpg
#   inflating: new_data/train/mask/IDRiD_50_3.jpg
#   inflating: new_data/train/mask/IDRiD_50_4.jpg
#   inflating: new_data/train/mask/IDRiD_50_5.jpg
#   inflating: new_data/train/mask/IDRiD_51_0.jpg
#   inflating: new_data/train/mask/IDRiD_51_1.jpg
#   inflating: new_data/train/mask/IDRiD_51_2.jpg
#   inflating: new_data/train/mask/IDRiD_51_3.jpg
#   inflating: new_data/train/mask/IDRiD_51_4.jpg
#   inflating: new_data/train/mask/IDRiD_51_5.jpg
#   inflating: new_data/train/mask/IDRiD_52_0.jpg
#   inflating: new_data/train/mask/IDRiD_52_1.jpg
#   inflating: new_data/train/mask/IDRiD_52_2.jpg
#   inflating: new_data/train/mask/IDRiD_52_3.jpg
#   inflating: new_data/train/mask/IDRiD_52_4.jpg
#   inflating: new_data/train/mask/IDRiD_52_5.jpg
#   inflating: new_data/train/mask/IDRiD_53_0.jpg
#   inflating: new_data/train/mask/IDRiD_53_1.jpg
#   inflating: new_data/train/mask/IDRiD_53_2.jpg
#   inflating: new_data/train/mask/IDRiD_53_3.jpg
#   inflating: new_data/train/mask/IDRiD_53_4.jpg
#   inflating: new_data/train/mask/IDRiD_53_5.jpg
#   inflating: new_data/train/mask/IDRiD_54_0.jpg
#   inflating: new_data/train/mask/IDRiD_54_1.jpg
#   inflating: new_data/train/mask/IDRiD_54_2.jpg
#   inflating: new_data/train/mask/IDRiD_54_3.jpg
#   inflating: new_data/train/mask/IDRiD_54_4.jpg
#   inflating: new_data/train/mask/IDRiD_54_5.jpg

# %% [markdown]
# ### Construct the Model:

# %%
def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    b1 = conv_block(p4, 1024)

    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    outputs = Conv2D(2, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="UNET")
    return model

input_shape = (512, 768, 3)
model = build_unet(input_shape)
model.summary()
# Out:
# Model: "UNET"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 768, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 768, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 768, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 512, 768, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 768, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 512, 768, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 512, 768, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 384, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 384, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 256, 384, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 256, 384, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 256, 384, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 256, 384, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 256, 384, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 192, 12  0          ['activation_3[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 128, 192, 25  295168      ['max_pooling2d_1[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 192, 25  1024       ['conv2d_4[0][0]']
#  rmalization)                   6)
#
#  activation_4 (Activation)      (None, 128, 192, 25  0           ['batch_normalization_4[0][0]']
#                                 6)
#
#  conv2d_5 (Conv2D)              (None, 128, 192, 25  590080      ['activation_4[0][0]']
#                                 6)
#
#  batch_normalization_5 (BatchNo  (None, 128, 192, 25  1024       ['conv2d_5[0][0]']
#  rmalization)                   6)
#
#  activation_5 (Activation)      (None, 128, 192, 25  0           ['batch_normalization_5[0][0]']
#                                 6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 96, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 96, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 96, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 96, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 96, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 96, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 64, 96, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 48, 512)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 48, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 32, 48, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 32, 48, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 32, 48, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 32, 48, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 32, 48, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 96, 512)  2097664    ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 64, 96, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 96, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 96, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 96, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 96, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 96, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 96, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 192, 25  524544     ['activation_11[0][0]']
#  spose)                         6)
#
#  concatenate_1 (Concatenate)    (None, 128, 192, 51  0           ['conv2d_transpose_1[0][0]',
#                                 2)                                'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 192, 25  1179904     ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_12 (BatchN  (None, 128, 192, 25  1024       ['conv2d_12[0][0]']
#  ormalization)                  6)
#
#  activation_12 (Activation)     (None, 128, 192, 25  0           ['batch_normalization_12[0][0]']
#                                 6)
#
#  conv2d_13 (Conv2D)             (None, 128, 192, 25  590080      ['activation_12[0][0]']
#                                 6)
#
#  batch_normalization_13 (BatchN  (None, 128, 192, 25  1024       ['conv2d_13[0][0]']
#  ormalization)                  6)
#
#  activation_13 (Activation)     (None, 128, 192, 25  0           ['batch_normalization_13[0][0]']
#                                 6)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 384, 12  131200     ['activation_13[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 256, 384, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 256, 384, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 256, 384, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  activation_14 (Activation)     (None, 256, 384, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 256, 384, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_15 (BatchN  (None, 256, 384, 12  512        ['conv2d_15[0][0]']
#  ormalization)                  8)
#
#  activation_15 (Activation)     (None, 256, 384, 12  0           ['batch_normalization_15[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 768, 64  32832      ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 512, 768, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 512, 768, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 512, 768, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 512, 768, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 512, 768, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 512, 768, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 512, 768, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 512, 768, 2)  130         ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31,055,362
# Trainable params: 31,043,586
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %% [markdown]
# ### Adding the Metrics:

# %%
def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %% [markdown]
# ### Training the Model:

# %%
W = 768
H = 512

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.jpg")))
    y = sorted(glob(os.path.join(path, "mask", "*.jpg")))
    return x, y

def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)
    return x, y

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)  ## (512, 512, 3)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    x = x[:,:,0:2] # Discard the last channel 

    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 2])
    return x, y

def tf_dataset(X, Y, batch_size=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(4)
    return dataset

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 2
lr = 1e-4
num_epochs = 30
model_path = os.path.join("files", "model.h5")
csv_path = os.path.join("files", "data.csv")

""" Dataset """
dataset_path = "new_data"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model = build_unet((H, W, 3))
# model.compile(loss=tf.keras.losses.BinaryCrossentropy(), optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])
model.compile(loss=dice_loss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])
# model.summary()

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 318 - 318
# Valid: 27 - 27
# Epoch 1/30
# 159/159 [==============================] - ETA: 0s - loss: 0.8267 - dice_coef: 0.1733 - iou: 0.0957 - recall: 0.4328 - precision: 0.4174
# Epoch 00001: val_loss improved from inf to 0.93834, saving model to files/model.h5
# 159/159 [==============================] - 451s 3s/step - loss: 0.8267 - dice_coef: 0.1733 - iou: 0.0957 - recall: 0.4328 - precision: 0.4174 - val_loss: 0.9383 - val_dice_coef: 0.0621 - val_iou: 0.0321 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - lr: 1.0000e-04
# Epoch 2/30
# 159/159 [==============================] - ETA: 0s - loss: 0.7318 - dice_coef: 0.2682 - iou: 0.1564 - recall: 0.2874 - precision: 0.6938
# Epoch 00002: val_loss improved from 0.93834 to 0.83427, saving model to files/model.h5
# 159/159 [==============================] - 411s 3s/step - loss: 0.7318 - dice_coef: 0.2682 - iou: 0.1564 - recall: 0.2874 - precision: 0.6938 - val_loss: 0.8343 - val_dice_coef: 0.1656 - val_iou: 0.0905 - val_recall: 0.0630 - val_precision: 0.5602 - lr: 1.0000e-04
# Epoch 3/30
# 159/159 [==============================] - ETA: 0s - loss: 0.6594 - dice_coef: 0.3406 - iou: 0.2082 - recall: 0.2423 - precision: 0.7793
# Epoch 00003: val_loss improved from 0.83427 to 0.64119, saving model to files/model.h5
# 159/159 [==============================] - 411s 3s/step - loss: 0.6594 - dice_coef: 0.3406 - iou: 0.2082 - recall: 0.2423 - precision: 0.7793 - val_loss: 0.6412 - val_dice_coef: 0.3586 - val_iou: 0.2189 - val_recall: 0.2088 - val_precision: 0.7553 - lr: 1.0000e-04
# Epoch 4/30
# 159/159 [==============================] - ETA: 0s - loss: 0.5970 - dice_coef: 0.4030 - iou: 0.2572 - recall: 0.2155 - precision: 0.8111
# Epoch 00004: val_loss improved from 0.64119 to 0.51798, saving model to files/model.h5
# 159/159 [==============================] - 411s 3s/step - loss: 0.5970 - dice_coef: 0.4030 - iou: 0.2572 - recall: 0.2155 - precision: 0.8111 - val_loss: 0.5180 - val_dice_coef: 0.4811 - val_iou: 0.3174 - val_recall: 0.2320 - val_precision: 0.9356 - lr: 1.0000e-04
# Epoch 5/30
# 159/159 [==============================] - ETA: 0s - loss: 0.5435 - dice_coef: 0.4565 - iou: 0.3026 - recall: 0.1984 - precision: 0.8328
# Epoch 00005: val_loss improved from 0.51798 to 0.45544, saving model to files/model.h5
# 159/159 [==============================] - 411s 3s/step - loss: 0.5435 - dice_coef: 0.4565 - iou: 0.3026 - recall: 0.1984 - precision: 0.8328 - val_loss: 0.4554 - val_dice_coef: 0.5432 - val_iou: 0.3738 - val_recall: 0.2300 - val_precision: 0.9387 - lr: 1.0000e-04
# Epoch 6/30
# 159/159 [==============================] - ETA: 0s - loss: 0.5047 - dice_coef: 0.4953 - iou: 0.3382 - recall: 0.1868 - precision: 0.8398
# Epoch 00006: val_loss improved from 0.45544 to 0.41888, saving model to files/model.h5
# 159/159 [==============================] - 412s 3s/step - loss: 0.5047 - dice_coef: 0.4953 - iou: 0.3382 - recall: 0.1868 - precision: 0.8398 - val_loss: 0.4189 - val_dice_coef: 0.5795 - val_iou: 0.4089 - val_recall: 0.2088 - val_precision: 0.9510 - lr: 1.0000e-04
# Epoch 7/30
# 159/159 [==============================] - ETA: 0s - loss: 0.4728 - dice_coef: 0.5272 - iou: 0.3687 - recall: 0.1798 - precision: 0.8520
# Epoch 00007: val_loss improved from 0.41888 to 0.37899, saving model to files/model.h5
# 159/159 [==============================] - 411s 3s/step - loss: 0.4728 - dice_coef: 0.5272 - iou: 0.3687 - recall: 0.1798 - precision: 0.8520 - val_loss: 0.3790 - val_dice_coef: 0.6202 - val_iou: 0.4503 - val_recall: 0.1864 - val_precision: 0.9636 - lr: 1.0000e-04
# Epoch 8/30
# 159/159 [==============================] - ETA: 0s - loss: 0.4544 - dice_coef: 0.5456 - iou: 0.3871 - recall: 0.1755 - precision: 0.8562
# Epoch 00008: val_loss did not improve from 0.37899
# 159/159 [==============================] - 407s 3s/step - loss: 0.4544 - dice_coef: 0.5456 - iou: 0.3871 - recall: 0.1755 - precision: 0.8562 - val_loss: 0.3792 - val_dice_coef: 0.6187 - val_iou: 0.4496 - val_recall: 0.1546 - val_precision: 0.9853 - lr: 1.0000e-04
# Epoch 9/30
# 159/159 [==============================] - ETA: 0s - loss: 0.4390 - dice_coef: 0.5610 - iou: 0.4028 - recall: 0.1720 - precision: 0.8645
# Epoch 00009: val_loss improved from 0.37899 to 0.33518, saving model to files/model.h5
# 159/159 [==============================] - 411s 3s/step - loss: 0.4390 - dice_coef: 0.5610 - iou: 0.4028 - recall: 0.1720 - precision: 0.8645 - val_loss: 0.3352 - val_dice_coef: 0.6649 - val_iou: 0.4986 - val_recall: 0.1754 - val_precision: 0.9858 - lr: 1.0000e-04
# Epoch 10/30
# 159/159 [==============================] - ETA: 0s - loss: 0.4247 - dice_coef: 0.5753 - iou: 0.4177 - recall: 0.1707 - precision: 0.8682
# Epoch 00010: val_loss improved from 0.33518 to 0.33232, saving model to files/model.h5
# 159/159 [==============================] - 411s 3s/step - loss: 0.4247 - dice_coef: 0.5753 - iou: 0.4177 - recall: 0.1707 - precision: 0.8682 - val_loss: 0.3323 - val_dice_coef: 0.6678 - val_iou: 0.5021 - val_recall: 0.1636 - val_precision: 0.9877 - lr: 1.0000e-04
# Epoch 11/30
# 159/159 [==============================] - ETA: 0s - loss: 0.4148 - dice_coef: 0.5852 - iou: 0.4280 - recall: 0.1695 - precision: 0.8726
# Epoch 00011: val_loss improved from 0.33232 to 0.32452, saving model to files/model.h5
# 159/159 [==============================] - 411s 3s/step - loss: 0.4148 - dice_coef: 0.5852 - iou: 0.4280 - recall: 0.1695 - precision: 0.8726 - val_loss: 0.3245 - val_dice_coef: 0.6751 - val_iou: 0.5103 - val_recall: 0.1578 - val_precision: 0.9893 - lr: 1.0000e-04
# Epoch 12/30
# 159/159 [==============================] - ETA: 0s - loss: 0.4072 - dice_coef: 0.5928 - iou: 0.4359 - recall: 0.1685 - precision: 0.8762
# Epoch 00012: val_loss improved from 0.32452 to 0.31492, saving model to files/model.h5
# 159/159 [==============================] - 403s 3s/step - loss: 0.4072 - dice_coef: 0.5928 - iou: 0.4359 - recall: 0.1685 - precision: 0.8762 - val_loss: 0.3149 - val_dice_coef: 0.6849 - val_iou: 0.5215 - val_recall: 0.1601 - val_precision: 0.9839 - lr: 1.0000e-04
# Epoch 13/30
# 159/159 [==============================] - ETA: 0s - loss: 0.4014 - dice_coef: 0.5986 - iou: 0.4419 - recall: 0.1677 - precision: 0.8806
# Epoch 00013: val_loss improved from 0.31492 to 0.31461, saving model to files/model.h5
# 159/159 [==============================] - 412s 3s/step - loss: 0.4014 - dice_coef: 0.5986 - iou: 0.4419 - recall: 0.1677 - precision: 0.8806 - val_loss: 0.3146 - val_dice_coef: 0.6848 - val_iou: 0.5215 - val_recall: 0.1615 - val_precision: 0.9833 - lr: 1.0000e-04
# Epoch 14/30
# 159/159 [==============================] - ETA: 0s - loss: 0.3960 - dice_coef: 0.6040 - iou: 0.4475 - recall: 0.1669 - precision: 0.8850
# Epoch 00014: val_loss did not improve from 0.31461
# 159/159 [==============================] - 407s 3s/step - loss: 0.3960 - dice_coef: 0.6040 - iou: 0.4475 - recall: 0.1669 - precision: 0.8850 - val_loss: 0.3174 - val_dice_coef: 0.6813 - val_iou: 0.5179 - val_recall: 0.1548 - val_precision: 0.9904 - lr: 1.0000e-04
# Epoch 15/30
# 159/159 [==============================] - ETA: 0s - loss: 0.3929 - dice_coef: 0.6071 - iou: 0.4507 - recall: 0.1668 - precision: 0.8869
# Epoch 00015: val_loss improved from 0.31461 to 0.30544, saving model to files/model.h5
# 159/159 [==============================] - 412s 3s/step - loss: 0.3929 - dice_coef: 0.6071 - iou: 0.4507 - recall: 0.1668 - precision: 0.8869 - val_loss: 0.3054 - val_dice_coef: 0.6940 - val_iou: 0.5319 - val_recall: 0.1629 - val_precision: 0.9860 - lr: 1.0000e-04
# Epoch 16/30
# 159/159 [==============================] - ETA: 0s - loss: 0.3881 - dice_coef: 0.6119 - iou: 0.4555 - recall: 0.1664 - precision: 0.8924
# Epoch 00016: val_loss did not improve from 0.30544
# 159/159 [==============================] - 399s 3s/step - loss: 0.3881 - dice_coef: 0.6119 - iou: 0.4555 - recall: 0.1664 - precision: 0.8924 - val_loss: 0.3229 - val_dice_coef: 0.6740 - val_iou: 0.5100 - val_recall: 0.1482 - val_precision: 0.9895 - lr: 1.0000e-04
# Epoch 17/30
# 159/159 [==============================] - ETA: 0s - loss: 0.3867 - dice_coef: 0.6133 - iou: 0.4570 - recall: 0.1660 - precision: 0.8914
# Epoch 00017: val_loss did not improve from 0.30544
# 159/159 [==============================] - 407s 3s/step - loss: 0.3867 - dice_coef: 0.6133 - iou: 0.4570 - recall: 0.1660 - precision: 0.8914 - val_loss: 0.3269 - val_dice_coef: 0.6712 - val_iou: 0.5068 - val_recall: 0.1426 - val_precision: 0.9921 - lr: 1.0000e-04
# Epoch 18/30
# 159/159 [==============================] - ETA: 0s - loss: 0.3783 - dice_coef: 0.6217 - iou: 0.4653 - recall: 0.1663 - precision: 0.9022
# Epoch 00018: val_loss did not improve from 0.30544
# 159/159 [==============================] - 407s 3s/step - loss: 0.3783 - dice_coef: 0.6217 - iou: 0.4653 - recall: 0.1663 - precision: 0.9022 - val_loss: 0.3082 - val_dice_coef: 0.6912 - val_iou: 0.5289 - val_recall: 0.1574 - val_precision: 0.9841 - lr: 1.0000e-04
# Epoch 19/30
# 159/159 [==============================] - ETA: 0s - loss: 0.3748 - dice_coef: 0.6252 - iou: 0.4687 - recall: 0.1662 - precision: 0.9074
# Epoch 00019: val_loss did not improve from 0.30544
# 159/159 [==============================] - 408s 3s/step - loss: 0.3748 - dice_coef: 0.6252 - iou: 0.4687 - recall: 0.1662 - precision: 0.9074 - val_loss: 0.3098 - val_dice_coef: 0.6895 - val_iou: 0.5270 - val_recall: 0.1559 - val_precision: 0.9863 - lr: 1.0000e-04
# Epoch 20/30
# 159/159 [==============================] - ETA: 0s - loss: 0.3717 - dice_coef: 0.6283 - iou: 0.4717 - recall: 0.1663 - precision: 0.9109
# Epoch 00020: val_loss did not improve from 0.30544
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 159/159 [==============================] - 402s 3s/step - loss: 0.3717 - dice_coef: 0.6283 - iou: 0.4717 - recall: 0.1663 - precision: 0.9109 - val_loss: 0.3059 - val_dice_coef: 0.6925 - val_iou: 0.5306 - val_recall: 0.1625 - val_precision: 0.9843 - lr: 1.0000e-04
# Epoch 21/30
# 159/159 [==============================] - ETA: 0s - loss: 0.3684 - dice_coef: 0.6316 - iou: 0.4749 - recall: 0.1660 - precision: 0.9128
# Epoch 00021: val_loss did not improve from 0.30544
# 159/159 [==============================] - 410s 3s/step - loss: 0.3684 - dice_coef: 0.6316 - iou: 0.4749 - recall: 0.1660 - precision: 0.9128 - val_loss: 0.3091 - val_dice_coef: 0.6882 - val_iou: 0.5258 - val_recall: 0.1529 - val_precision: 0.9915 - lr: 1.0000e-05
# Epoch 22/30
# 159/159 [==============================] - ETA: 0s - loss: 0.3607 - dice_coef: 0.6393 - iou: 0.4824 - recall: 0.1667 - precision: 0.9255
# Epoch 00022: val_loss did not improve from 0.30544
# 159/159 [==============================] - 402s 3s/step - loss: 0.3607 - dice_coef: 0.6393 - iou: 0.4824 - recall: 0.1667 - precision: 0.9255 - val_loss: 0.3115 - val_dice_coef: 0.6857 - val_iou: 0.5231 - val_recall: 0.1529 - val_precision: 0.9909 - lr: 1.0000e-05
# Epoch 23/30
# 159/159 [==============================] - ETA: 0s - loss: 0.3567 - dice_coef: 0.6433 - iou: 0.4864 - recall: 0.1670 - precision: 0.9314
# Epoch 00023: val_loss did not improve from 0.30544
# 159/159 [==============================] - 410s 3s/step - loss: 0.3567 - dice_coef: 0.6433 - iou: 0.4864 - recall: 0.1670 - precision: 0.9314 - val_loss: 0.3134 - val_dice_coef: 0.6837 - val_iou: 0.5209 - val_recall: 0.1547 - val_precision: 0.9895 - lr: 1.0000e-05
# Epoch 24/30
# 159/159 [==============================] - ETA: 0s - loss: 0.3535 - dice_coef: 0.6465 - iou: 0.4895 - recall: 0.1671 - precision: 0.9365
# Epoch 00024: val_loss did not improve from 0.30544
# 159/159 [==============================] - 410s 3s/step - loss: 0.3535 - dice_coef: 0.6465 - iou: 0.4895 - recall: 0.1671 - precision: 0.9365 - val_loss: 0.3200 - val_dice_coef: 0.6765 - val_iou: 0.5130 - val_recall: 0.1513 - val_precision: 0.9893 - lr: 1.0000e-05
# Epoch 25/30
# 159/159 [==============================] - ETA: 0s - loss: 0.3507 - dice_coef: 0.6493 - iou: 0.4923 - recall: 0.1674 - precision: 0.9403
# Epoch 00025: val_loss did not improve from 0.30544
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1e-06.
# 159/159 [==============================] - 410s 3s/step - loss: 0.3507 - dice_coef: 0.6493 - iou: 0.4923 - recall: 0.1674 - precision: 0.9403 - val_loss: 0.3221 - val_dice_coef: 0.6742 - val_iou: 0.5106 - val_recall: 0.1515 - val_precision: 0.9885 - lr: 1.0000e-05

# %% [markdown]
# ### Evaluate The Metrics:

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import pandas as pd
import cv2
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import accuracy_score, f1_score, jaccard_score, precision_score, recall_score
from metrics import dice_loss, dice_coef, iou
from utils import get_filenames_sorted

# %%
H = 512
W = 768

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.float32)
    return ori_x, x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.float32)
    x = x[:,:,0:2] # Discard the last channel 
    return ori_x, x

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.jpg")))
    y = sorted(glob(os.path.join(path, "mask", "*.jpg")))
    return x, y

def save_results(ori_x, ori_y, y_pred, save_image_path, channel):
    line = np.ones((y_pred.shape[0], 10, 3)) * 255

    pred_image = np.zeros((y_pred.shape[0], y_pred.shape[1], 3))
    _y_pred = y_pred[:, :, channel]
    _ori_y = ori_y[:, :, channel]
    pred_image[:, :, 0] = ((_y_pred > 0.5) & (_ori_y <= 128)) * 255
    pred_image[:, :, 1] = ((_y_pred > 0.5) & (_ori_y  > 128)) * 255
    pred_image[:, :, 2] = ((_ori_y  > 128) & (_y_pred <= 0.5 )) * 255

    print(" saving result", save_image_path)
    cv2.imwrite(save_image_path, pred_image)

# %%
    data_dir = "new_data"
    od_channel, bv_channel = 0, 1

    od_result_dir = "files_demo_bv"
    bv_result_dir = "files_demo_ex"

    create_dir(od_result_dir)
    create_dir(bv_result_dir)

    model_dir = "files"

    """ Load the model """
    model_file_name = f"{model_dir}/model.h5"
    print(model_file_name)
    with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef, 'dice_loss': dice_loss}):
        model = tf.keras.models.load_model(model_file_name)

    """ Load the dataset """
    # dataset_path = os.path.join(data_dir, "test")
    test_x, test_y = get_filenames_sorted(data_dir + "/test/image/", data_dir + "/test/mask/" )

    """ Make the prediction and calculate the metrics values """
    SCORE_BV, SCORE_OD = [], []
    for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
        """ Extracting name """
        name = x.rsplit("/", 1)[1].rsplit(".", 1)[0]
        print(name)

        """ Read the image and mask """
        ori_x, x = read_image(x)
        ori_y, y = read_mask(y)

        """ Prediction """
        y_pred = model.predict(np.expand_dims(x, axis=0))[0]
        y_pred = y_pred > 0.5
        y_pred = y_pred.astype(np.float32)

        print(np.max(ori_y), np.max(y))

        """ Saving the images """
        save_image_path_od = f"{od_result_dir}/{name}.png"
        save_results(ori_x, ori_y, y_pred, save_image_path_od, od_channel)

        save_image_path_bv = f"{bv_result_dir}/{name}.png"
        save_results(ori_x, ori_y, y_pred, save_image_path_bv, bv_channel)


    #     """ Calculate the od metrics """
        bv_pred = y_pred[:, :, bv_channel].flatten()
        bv_gt = y[:, :, bv_channel].flatten()
        acc_value = accuracy_score(bv_gt > 0.5, bv_pred>0.5)
        f1_value = f1_score(bv_gt > 0.5, bv_pred>0.5, labels=[0, 1], average="binary")
        jac_value = jaccard_score(bv_gt > 0.5, bv_pred>0.5, labels=[0, 1], average="binary")
        recall_value = recall_score(bv_gt > 0.5, bv_pred>0.5, labels=[0, 1], average="binary")
        recall_computed = np.sum((bv_gt > 0.5) & (bv_pred > 0.5)) / np.sum(bv_gt > 0.5)
        precision_value = precision_score(bv_gt > 0.5, bv_pred>0.5, labels=[0, 1], average="binary")
        SCORE_BV.append([name, acc_value, f1_value, jac_value, recall_value, precision_value, recall_computed])

    #     """ Calculate the he metrics """
        bv_pred = y_pred[:, :, od_channel].flatten()
        bv_gt = y[:, :, od_channel].flatten()
        acc_value = accuracy_score(bv_gt > 0.5, bv_pred>0.5)
        f1_value = f1_score(bv_gt > 0.5, bv_pred>0.5, labels=[0, 1], average="binary")
        jac_value = jaccard_score(bv_gt > 0.5, bv_pred>0.5, labels=[0, 1], average="binary")
        recall_value = recall_score(bv_gt > 0.5, bv_pred>0.5, labels=[0, 1], average="binary")
        recall_computed = np.sum((bv_gt > 0.5) & (bv_pred > 0.5)) / np.sum(bv_gt > 0.5)
        precision_value = precision_score(bv_gt > 0.5, bv_pred>0.5, labels=[0, 1], average="binary")
        SCORE_OD.append([name, acc_value, f1_value, jac_value, recall_value, precision_value, recall_computed])
        
    print("\n")
    for SCORE in [SCORE_OD, SCORE_BV]:
        if SCORE == SCORE_OD:
            print("****** OD Metrics")
        else:
            print("****** HE Metrics")
        score = [s[1:] for s in SCORE]
        score = np.mean(score, axis=0)
        print(f"Accuracy: {score[0]:0.5f}")
        print(f"F1: {score[1]:0.5f} (dice score)")
        print(f"AUC: {score[1]:0.5f} (Auc score)")
        print(f"Jaccard: {score[2]:0.5f}")
        print(f"Recall: {score[3]:0.5f}")
        print(f"Precision: {score[4]:0.5f}")

        # """ Saving """
        if SCORE == SCORE_OD:
            df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision", "Recall Computed"])
            df.to_csv(f"{od_result_dir}/score.csv")
        else:
            df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision", "Recall Computed"])
            df.to_csv(f"{bv_result_dir}/score.csv")
        print("\n")
# Out:
# files/model.h5
#   0%|          | 0/27 [00:00<?, ?it/s]
# IDRiD_55
# 255 1.0
#  saving result files_demo_bv/IDRiD_55.png
#  saving result files_demo_ex/IDRiD_55.png
#   4%|▎         | 1/27 [00:01<00:49,  1.89s/it]
# IDRiD_56
# 255 1.0
#  saving result files_demo_bv/IDRiD_56.png
#  saving result files_demo_ex/IDRiD_56.png
#   7%|▋         | 2/27 [00:03<00:39,  1.58s/it]
# IDRiD_57
# 255 1.0
#  saving result files_demo_bv/IDRiD_57.png
#  saving result files_demo_ex/IDRiD_57.png
#  11%|█         | 3/27 [00:04<00:35,  1.49s/it]
# IDRiD_58
# 255 1.0
#  saving result files_demo_bv/IDRiD_58.png
#  saving result files_demo_ex/IDRiD_58.png
#  15%|█▍        | 4/27 [00:05<00:32,  1.42s/it]
# IDRiD_59
# 255 1.0
#  saving result files_demo_bv/IDRiD_59.png
#  saving result files_demo_ex/IDRiD_59.png
#  19%|█▊        | 5/27 [00:07<00:30,  1.39s/it]
# IDRiD_60
# 255 1.0
#  saving result files_demo_bv/IDRiD_60.png
#  saving result files_demo_ex/IDRiD_60.png
#  22%|██▏       | 6/27 [00:08<00:28,  1.37s/it]
# IDRiD_61
# 255 1.0
#  saving result files_demo_bv/IDRiD_61.png
#  saving result files_demo_ex/IDRiD_61.png
#  26%|██▌       | 7/27 [00:09<00:27,  1.35s/it]
# IDRiD_62
# 255 1.0
#  saving result files_demo_bv/IDRiD_62.png
#  saving result files_demo_ex/IDRiD_62.png
#  30%|██▉       | 8/27 [00:11<00:26,  1.42s/it]
# IDRiD_63
# 255 1.0
#  saving result files_demo_bv/IDRiD_63.png
#  saving result files_demo_ex/IDRiD_63.png
#  33%|███▎      | 9/27 [00:12<00:25,  1.39s/it]
# IDRiD_64
# 255 1.0
#  saving result files_demo_bv/IDRiD_64.png
#  saving result files_demo_ex/IDRiD_64.png
#  37%|███▋      | 10/27 [00:14<00:23,  1.37s/it]
# IDRiD_65
# 255 1.0
#  saving result files_demo_bv/IDRiD_65.png
#  saving result files_demo_ex/IDRiD_65.png
#  41%|████      | 11/27 [00:15<00:21,  1.36s/it]
# IDRiD_66
# 255 1.0
#  saving result files_demo_bv/IDRiD_66.png
#  saving result files_demo_ex/IDRiD_66.png
#  44%|████▍     | 12/27 [00:16<00:20,  1.37s/it]
# IDRiD_67
# 255 1.0
#  saving result files_demo_bv/IDRiD_67.png
#  saving result files_demo_ex/IDRiD_67.png
#  48%|████▊     | 13/27 [00:18<00:19,  1.37s/it]
# IDRiD_68
# 255 1.0
#  saving result files_demo_bv/IDRiD_68.png
#  saving result files_demo_ex/IDRiD_68.png
#  52%|█████▏    | 14/27 [00:19<00:17,  1.35s/it]
# IDRiD_69
# 255 1.0
#  saving result files_demo_bv/IDRiD_69.png
#  saving result files_demo_ex/IDRiD_69.png
#  56%|█████▌    | 15/27 [00:21<00:16,  1.39s/it]
# IDRiD_70
# 255 1.0
#  saving result files_demo_bv/IDRiD_70.png
#  saving result files_demo_ex/IDRiD_70.png
#  59%|█████▉    | 16/27 [00:22<00:15,  1.37s/it]
# IDRiD_71
# 255 1.0
#  saving result files_demo_bv/IDRiD_71.png
#  saving result files_demo_ex/IDRiD_71.png
#  63%|██████▎   | 17/27 [00:23<00:13,  1.37s/it]
# IDRiD_72
# 255 1.0
#  saving result files_demo_bv/IDRiD_72.png
#  saving result files_demo_ex/IDRiD_72.png
#  67%|██████▋   | 18/27 [00:25<00:12,  1.36s/it]
# IDRiD_73
# 255 1.0
#  saving result files_demo_bv/IDRiD_73.png
#  saving result files_demo_ex/IDRiD_73.png
#  70%|███████   | 19/27 [00:26<00:10,  1.36s/it]
# IDRiD_74
# 255 1.0
#  saving result files_demo_bv/IDRiD_74.png
#  saving result files_demo_ex/IDRiD_74.png
#  74%|███████▍  | 20/27 [00:27<00:09,  1.36s/it]
# IDRiD_75
# 255 1.0
#  saving result files_demo_bv/IDRiD_75.png
#  saving result files_demo_ex/IDRiD_75.png
#  78%|███████▊  | 21/27 [00:29<00:08,  1.36s/it]
# IDRiD_76
# 255 1.0
#  saving result files_demo_bv/IDRiD_76.png
#  saving result files_demo_ex/IDRiD_76.png
#  81%|████████▏ | 22/27 [00:30<00:06,  1.36s/it]
# IDRiD_77
# 255 1.0
#  saving result files_demo_bv/IDRiD_77.png
#  saving result files_demo_ex/IDRiD_77.png
#  85%|████████▌ | 23/27 [00:31<00:05,  1.35s/it]
# IDRiD_78
# 255 1.0
#  saving result files_demo_bv/IDRiD_78.png
#  saving result files_demo_ex/IDRiD_78.png
#  89%|████████▉ | 24/27 [00:33<00:04,  1.36s/it]
# IDRiD_79
# 255 1.0
#  saving result files_demo_bv/IDRiD_79.png
#  saving result files_demo_ex/IDRiD_79.png
#  93%|█████████▎| 25/27 [00:34<00:02,  1.41s/it]
# IDRiD_80
# 255 1.0
#  saving result files_demo_bv/IDRiD_80.png
#  saving result files_demo_ex/IDRiD_80.png
#  96%|█████████▋| 26/27 [00:36<00:01,  1.39s/it]
# IDRiD_81
# 255 1.0
#  saving result files_demo_bv/IDRiD_81.png
#  saving result files_demo_ex/IDRiD_81.png
# 100%|██████████| 27/27 [00:37<00:00,  1.39s/it]
# ****** OD Metrics
# Accuracy: 0.98131
# F1: 0.82823 (dice score)
# AUC: 0.82823 (Auc score)
# Jaccard: 0.70758
# Recall: 0.83345
# Precision: 0.83012
#
#
# ****** HE Metrics
# Accuracy: 0.99450
# F1: 0.61372 (dice score)
# AUC: 0.61372 (Auc score)
# Jaccard: 0.46328
# Recall: 0.59151
# Precision: 0.67426
