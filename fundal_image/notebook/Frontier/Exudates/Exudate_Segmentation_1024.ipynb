# %% [markdown]
# ### Import the required libraries and modules:

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
import numpy as np

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# %cd /content/gdrive/MyDrive/1_All_Computations/Exudate_Segmentation_1024
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/1_All_Computations/Exudate_Segmentation_1024

# %% [markdown]
# ### Unzip the data:

# %%
# !unzip new_data_1024.zip
# Out:
# Archive:  new_data_1024.zip
#    creating: new_data_1024/
#    creating: new_data_1024/test/
#    creating: new_data_1024/test/image/
#   inflating: new_data_1024/test/image/IDRiD_55.png
#   inflating: new_data_1024/test/image/IDRiD_56.png
#   inflating: new_data_1024/test/image/IDRiD_57.png
#   inflating: new_data_1024/test/image/IDRiD_58.png
#   inflating: new_data_1024/test/image/IDRiD_59.png
#   inflating: new_data_1024/test/image/IDRiD_60.png
#   inflating: new_data_1024/test/image/IDRiD_61.png
#   inflating: new_data_1024/test/image/IDRiD_62.png
#   inflating: new_data_1024/test/image/IDRiD_63.png
#   inflating: new_data_1024/test/image/IDRiD_64.png
#   inflating: new_data_1024/test/image/IDRiD_65.png
#   inflating: new_data_1024/test/image/IDRiD_66.png
#   inflating: new_data_1024/test/image/IDRiD_67.png
#   inflating: new_data_1024/test/image/IDRiD_68.png
#   inflating: new_data_1024/test/image/IDRiD_69.png
#   inflating: new_data_1024/test/image/IDRiD_70.png
#   inflating: new_data_1024/test/image/IDRiD_71.png
#   inflating: new_data_1024/test/image/IDRiD_72.png
#   inflating: new_data_1024/test/image/IDRiD_73.png
#   inflating: new_data_1024/test/image/IDRiD_74.png
#   inflating: new_data_1024/test/image/IDRiD_75.png
#   inflating: new_data_1024/test/image/IDRiD_76.png
#   inflating: new_data_1024/test/image/IDRiD_77.png
#   inflating: new_data_1024/test/image/IDRiD_78.png
#   inflating: new_data_1024/test/image/IDRiD_79.png
#   inflating: new_data_1024/test/image/IDRiD_80.png
#   inflating: new_data_1024/test/image/IDRiD_81.png
#    creating: new_data_1024/test/mask/
#   inflating: new_data_1024/test/mask/IDRiD_55.png
#   inflating: new_data_1024/test/mask/IDRiD_56.png
#   inflating: new_data_1024/test/mask/IDRiD_57.png
#   inflating: new_data_1024/test/mask/IDRiD_58.png
#   inflating: new_data_1024/test/mask/IDRiD_59.png
#   inflating: new_data_1024/test/mask/IDRiD_60.png
#   inflating: new_data_1024/test/mask/IDRiD_61.png
#   inflating: new_data_1024/test/mask/IDRiD_62.png
#   inflating: new_data_1024/test/mask/IDRiD_63.png
#   inflating: new_data_1024/test/mask/IDRiD_64.png
#   inflating: new_data_1024/test/mask/IDRiD_65.png
#   inflating: new_data_1024/test/mask/IDRiD_66.png
#   inflating: new_data_1024/test/mask/IDRiD_67.png
#   inflating: new_data_1024/test/mask/IDRiD_68.png
#   inflating: new_data_1024/test/mask/IDRiD_69.png
#   inflating: new_data_1024/test/mask/IDRiD_70.png
#   inflating: new_data_1024/test/mask/IDRiD_71.png
#   inflating: new_data_1024/test/mask/IDRiD_72.png
#   inflating: new_data_1024/test/mask/IDRiD_73.png
#   inflating: new_data_1024/test/mask/IDRiD_74.png
#   inflating: new_data_1024/test/mask/IDRiD_75.png
#   inflating: new_data_1024/test/mask/IDRiD_76.png
#   inflating: new_data_1024/test/mask/IDRiD_77.png
#   inflating: new_data_1024/test/mask/IDRiD_78.png
#   inflating: new_data_1024/test/mask/IDRiD_79.png
#   inflating: new_data_1024/test/mask/IDRiD_80.png
#   inflating: new_data_1024/test/mask/IDRiD_81.png
#    creating: new_data_1024/train/
#    creating: new_data_1024/train/image/
#   inflating: new_data_1024/train/image/IDRiD_01_0.png
#   inflating: new_data_1024/train/image/IDRiD_01_1.png
#   inflating: new_data_1024/train/image/IDRiD_01_2.png
#   inflating: new_data_1024/train/image/IDRiD_01_3.png
#   inflating: new_data_1024/train/image/IDRiD_01_4.png
#   inflating: new_data_1024/train/image/IDRiD_01_5.png
#   inflating: new_data_1024/train/image/IDRiD_02_0.png
#   inflating: new_data_1024/train/image/IDRiD_02_1.png
#   inflating: new_data_1024/train/image/IDRiD_02_2.png
#   inflating: new_data_1024/train/image/IDRiD_02_3.png
#   inflating: new_data_1024/train/image/IDRiD_02_4.png
#   inflating: new_data_1024/train/image/IDRiD_02_5.png
#   inflating: new_data_1024/train/image/IDRiD_03_0.png
#   inflating: new_data_1024/train/image/IDRiD_03_1.png
#   inflating: new_data_1024/train/image/IDRiD_03_2.png
#   inflating: new_data_1024/train/image/IDRiD_03_3.png
#   inflating: new_data_1024/train/image/IDRiD_03_4.png
#   inflating: new_data_1024/train/image/IDRiD_03_5.png
#   inflating: new_data_1024/train/image/IDRiD_04_0.png
#   inflating: new_data_1024/train/image/IDRiD_04_1.png
#   inflating: new_data_1024/train/image/IDRiD_04_2.png
#   inflating: new_data_1024/train/image/IDRiD_04_3.png
#   inflating: new_data_1024/train/image/IDRiD_04_4.png
#   inflating: new_data_1024/train/image/IDRiD_04_5.png
#   inflating: new_data_1024/train/image/IDRiD_05_0.png
#   inflating: new_data_1024/train/image/IDRiD_05_1.png
#   inflating: new_data_1024/train/image/IDRiD_05_2.png
#   inflating: new_data_1024/train/image/IDRiD_05_3.png
#   inflating: new_data_1024/train/image/IDRiD_05_4.png
#   inflating: new_data_1024/train/image/IDRiD_05_5.png
#   inflating: new_data_1024/train/image/IDRiD_06_0.png
#   inflating: new_data_1024/train/image/IDRiD_06_1.png
#   inflating: new_data_1024/train/image/IDRiD_06_2.png
#   inflating: new_data_1024/train/image/IDRiD_06_3.png
#   inflating: new_data_1024/train/image/IDRiD_06_4.png
#   inflating: new_data_1024/train/image/IDRiD_06_5.png
#   inflating: new_data_1024/train/image/IDRiD_07_0.png
#   inflating: new_data_1024/train/image/IDRiD_07_1.png
#   inflating: new_data_1024/train/image/IDRiD_07_2.png
#   inflating: new_data_1024/train/image/IDRiD_07_3.png
#   inflating: new_data_1024/train/image/IDRiD_07_4.png
#   inflating: new_data_1024/train/image/IDRiD_07_5.png
#   inflating: new_data_1024/train/image/IDRiD_08_0.png
#   inflating: new_data_1024/train/image/IDRiD_08_1.png
#   inflating: new_data_1024/train/image/IDRiD_08_2.png
#   inflating: new_data_1024/train/image/IDRiD_08_3.png
#   inflating: new_data_1024/train/image/IDRiD_08_4.png
#   inflating: new_data_1024/train/image/IDRiD_08_5.png
#   inflating: new_data_1024/train/image/IDRiD_09_0.png
#   inflating: new_data_1024/train/image/IDRiD_09_1.png
#   inflating: new_data_1024/train/image/IDRiD_09_2.png
#   inflating: new_data_1024/train/image/IDRiD_09_3.png
#   inflating: new_data_1024/train/image/IDRiD_09_4.png
#   inflating: new_data_1024/train/image/IDRiD_09_5.png
#   inflating: new_data_1024/train/image/IDRiD_10_0.png
#   inflating: new_data_1024/train/image/IDRiD_10_1.png
#   inflating: new_data_1024/train/image/IDRiD_10_2.png
#   inflating: new_data_1024/train/image/IDRiD_10_3.png
#   inflating: new_data_1024/train/image/IDRiD_10_4.png
#   inflating: new_data_1024/train/image/IDRiD_10_5.png
#   inflating: new_data_1024/train/image/IDRiD_11_0.png
#   inflating: new_data_1024/train/image/IDRiD_11_1.png
#   inflating: new_data_1024/train/image/IDRiD_11_2.png
#   inflating: new_data_1024/train/image/IDRiD_11_3.png
#   inflating: new_data_1024/train/image/IDRiD_11_4.png
#   inflating: new_data_1024/train/image/IDRiD_11_5.png
#   inflating: new_data_1024/train/image/IDRiD_12_0.png
#   inflating: new_data_1024/train/image/IDRiD_12_1.png
#   inflating: new_data_1024/train/image/IDRiD_12_2.png
#   inflating: new_data_1024/train/image/IDRiD_12_3.png
#   inflating: new_data_1024/train/image/IDRiD_12_4.png
#   inflating: new_data_1024/train/image/IDRiD_12_5.png
#   inflating: new_data_1024/train/image/IDRiD_13_0.png
#   inflating: new_data_1024/train/image/IDRiD_13_1.png
#   inflating: new_data_1024/train/image/IDRiD_13_2.png
#   inflating: new_data_1024/train/image/IDRiD_13_3.png
#   inflating: new_data_1024/train/image/IDRiD_13_4.png
#   inflating: new_data_1024/train/image/IDRiD_13_5.png
#   inflating: new_data_1024/train/image/IDRiD_14_0.png
#   inflating: new_data_1024/train/image/IDRiD_14_1.png
#   inflating: new_data_1024/train/image/IDRiD_14_2.png
#   inflating: new_data_1024/train/image/IDRiD_14_3.png
#   inflating: new_data_1024/train/image/IDRiD_14_4.png
#   inflating: new_data_1024/train/image/IDRiD_14_5.png
#   inflating: new_data_1024/train/image/IDRiD_15_0.png
#   inflating: new_data_1024/train/image/IDRiD_15_1.png
#   inflating: new_data_1024/train/image/IDRiD_15_2.png
#   inflating: new_data_1024/train/image/IDRiD_15_3.png
#   inflating: new_data_1024/train/image/IDRiD_15_4.png
#   inflating: new_data_1024/train/image/IDRiD_15_5.png
#   inflating: new_data_1024/train/image/IDRiD_16_0.png
#   inflating: new_data_1024/train/image/IDRiD_16_1.png
#   inflating: new_data_1024/train/image/IDRiD_16_2.png
#   inflating: new_data_1024/train/image/IDRiD_16_3.png
#   inflating: new_data_1024/train/image/IDRiD_16_4.png
#   inflating: new_data_1024/train/image/IDRiD_16_5.png
#   inflating: new_data_1024/train/image/IDRiD_17_0.png
#   inflating: new_data_1024/train/image/IDRiD_17_1.png
#   inflating: new_data_1024/train/image/IDRiD_17_2.png
#   inflating: new_data_1024/train/image/IDRiD_17_3.png
#   inflating: new_data_1024/train/image/IDRiD_17_4.png
#   inflating: new_data_1024/train/image/IDRiD_17_5.png
#   inflating: new_data_1024/train/image/IDRiD_18_0.png
#   inflating: new_data_1024/train/image/IDRiD_18_1.png
#   inflating: new_data_1024/train/image/IDRiD_18_2.png
#   inflating: new_data_1024/train/image/IDRiD_18_3.png
#   inflating: new_data_1024/train/image/IDRiD_18_4.png
#   inflating: new_data_1024/train/image/IDRiD_18_5.png
#   inflating: new_data_1024/train/image/IDRiD_19_0.png
#   inflating: new_data_1024/train/image/IDRiD_19_1.png
#   inflating: new_data_1024/train/image/IDRiD_19_2.png
#   inflating: new_data_1024/train/image/IDRiD_19_3.png
#   inflating: new_data_1024/train/image/IDRiD_19_4.png
#   inflating: new_data_1024/train/image/IDRiD_19_5.png
#   inflating: new_data_1024/train/image/IDRiD_20_0.png
#   inflating: new_data_1024/train/image/IDRiD_20_1.png
#   inflating: new_data_1024/train/image/IDRiD_20_2.png
#   inflating: new_data_1024/train/image/IDRiD_20_3.png
#   inflating: new_data_1024/train/image/IDRiD_20_4.png
#   inflating: new_data_1024/train/image/IDRiD_20_5.png
#   inflating: new_data_1024/train/image/IDRiD_21_0.png
#   inflating: new_data_1024/train/image/IDRiD_21_1.png
#   inflating: new_data_1024/train/image/IDRiD_21_2.png
#   inflating: new_data_1024/train/image/IDRiD_21_3.png
#   inflating: new_data_1024/train/image/IDRiD_21_4.png
#   inflating: new_data_1024/train/image/IDRiD_21_5.png
#   inflating: new_data_1024/train/image/IDRiD_22_0.png
#   inflating: new_data_1024/train/image/IDRiD_22_1.png
#   inflating: new_data_1024/train/image/IDRiD_22_2.png
#   inflating: new_data_1024/train/image/IDRiD_22_3.png
#   inflating: new_data_1024/train/image/IDRiD_22_4.png
#   inflating: new_data_1024/train/image/IDRiD_22_5.png
#   inflating: new_data_1024/train/image/IDRiD_23_0.png
#   inflating: new_data_1024/train/image/IDRiD_23_1.png
#   inflating: new_data_1024/train/image/IDRiD_23_2.png
#   inflating: new_data_1024/train/image/IDRiD_23_3.png
#   inflating: new_data_1024/train/image/IDRiD_23_4.png
#   inflating: new_data_1024/train/image/IDRiD_23_5.png
#   inflating: new_data_1024/train/image/IDRiD_24_0.png
#   inflating: new_data_1024/train/image/IDRiD_24_1.png
#   inflating: new_data_1024/train/image/IDRiD_24_2.png
#   inflating: new_data_1024/train/image/IDRiD_24_3.png
#   inflating: new_data_1024/train/image/IDRiD_24_4.png
#   inflating: new_data_1024/train/image/IDRiD_24_5.png
#   inflating: new_data_1024/train/image/IDRiD_25_0.png
#   inflating: new_data_1024/train/image/IDRiD_25_1.png
#   inflating: new_data_1024/train/image/IDRiD_25_2.png
#   inflating: new_data_1024/train/image/IDRiD_25_3.png
#   inflating: new_data_1024/train/image/IDRiD_25_4.png
#   inflating: new_data_1024/train/image/IDRiD_25_5.png
#   inflating: new_data_1024/train/image/IDRiD_26_0.png
#   inflating: new_data_1024/train/image/IDRiD_26_1.png
#   inflating: new_data_1024/train/image/IDRiD_26_2.png
#   inflating: new_data_1024/train/image/IDRiD_26_3.png
#   inflating: new_data_1024/train/image/IDRiD_26_4.png
#   inflating: new_data_1024/train/image/IDRiD_26_5.png
#   inflating: new_data_1024/train/image/IDRiD_27_0.png
#   inflating: new_data_1024/train/image/IDRiD_27_1.png
#   inflating: new_data_1024/train/image/IDRiD_27_2.png
#   inflating: new_data_1024/train/image/IDRiD_27_3.png
#   inflating: new_data_1024/train/image/IDRiD_27_4.png
#   inflating: new_data_1024/train/image/IDRiD_27_5.png
#   inflating: new_data_1024/train/image/IDRiD_28_0.png
#   inflating: new_data_1024/train/image/IDRiD_28_1.png
#   inflating: new_data_1024/train/image/IDRiD_28_2.png
#   inflating: new_data_1024/train/image/IDRiD_28_3.png
#   inflating: new_data_1024/train/image/IDRiD_28_4.png
#   inflating: new_data_1024/train/image/IDRiD_28_5.png
#   inflating: new_data_1024/train/image/IDRiD_29_0.png
#   inflating: new_data_1024/train/image/IDRiD_29_1.png
#   inflating: new_data_1024/train/image/IDRiD_29_2.png
#   inflating: new_data_1024/train/image/IDRiD_29_3.png
#   inflating: new_data_1024/train/image/IDRiD_29_4.png
#   inflating: new_data_1024/train/image/IDRiD_29_5.png
#   inflating: new_data_1024/train/image/IDRiD_30_0.png
#   inflating: new_data_1024/train/image/IDRiD_30_1.png
#   inflating: new_data_1024/train/image/IDRiD_30_2.png
#   inflating: new_data_1024/train/image/IDRiD_30_3.png
#   inflating: new_data_1024/train/image/IDRiD_30_4.png
#   inflating: new_data_1024/train/image/IDRiD_30_5.png
#   inflating: new_data_1024/train/image/IDRiD_31_0.png
#   inflating: new_data_1024/train/image/IDRiD_31_1.png
#   inflating: new_data_1024/train/image/IDRiD_31_2.png
#   inflating: new_data_1024/train/image/IDRiD_31_3.png
#   inflating: new_data_1024/train/image/IDRiD_31_4.png
#   inflating: new_data_1024/train/image/IDRiD_31_5.png
#   inflating: new_data_1024/train/image/IDRiD_32_0.png
#   inflating: new_data_1024/train/image/IDRiD_32_1.png
#   inflating: new_data_1024/train/image/IDRiD_32_2.png
#   inflating: new_data_1024/train/image/IDRiD_32_3.png
#   inflating: new_data_1024/train/image/IDRiD_32_4.png
#   inflating: new_data_1024/train/image/IDRiD_32_5.png
#   inflating: new_data_1024/train/image/IDRiD_33_0.png
#   inflating: new_data_1024/train/image/IDRiD_33_1.png
#   inflating: new_data_1024/train/image/IDRiD_33_2.png
#   inflating: new_data_1024/train/image/IDRiD_33_3.png
#   inflating: new_data_1024/train/image/IDRiD_33_4.png
#   inflating: new_data_1024/train/image/IDRiD_33_5.png
#   inflating: new_data_1024/train/image/IDRiD_34_0.png
#   inflating: new_data_1024/train/image/IDRiD_34_1.png
#   inflating: new_data_1024/train/image/IDRiD_34_2.png
#   inflating: new_data_1024/train/image/IDRiD_34_3.png
#   inflating: new_data_1024/train/image/IDRiD_34_4.png
#   inflating: new_data_1024/train/image/IDRiD_34_5.png
#   inflating: new_data_1024/train/image/IDRiD_35_0.png
#   inflating: new_data_1024/train/image/IDRiD_35_1.png
#   inflating: new_data_1024/train/image/IDRiD_35_2.png
#   inflating: new_data_1024/train/image/IDRiD_35_3.png
#   inflating: new_data_1024/train/image/IDRiD_35_4.png
#   inflating: new_data_1024/train/image/IDRiD_35_5.png
#   inflating: new_data_1024/train/image/IDRiD_36_0.png
#   inflating: new_data_1024/train/image/IDRiD_36_1.png
#   inflating: new_data_1024/train/image/IDRiD_36_2.png
#   inflating: new_data_1024/train/image/IDRiD_36_3.png
#   inflating: new_data_1024/train/image/IDRiD_36_4.png
#   inflating: new_data_1024/train/image/IDRiD_36_5.png
#   inflating: new_data_1024/train/image/IDRiD_37_0.png
#   inflating: new_data_1024/train/image/IDRiD_37_1.png
#   inflating: new_data_1024/train/image/IDRiD_37_2.png
#   inflating: new_data_1024/train/image/IDRiD_37_3.png
#   inflating: new_data_1024/train/image/IDRiD_37_4.png
#   inflating: new_data_1024/train/image/IDRiD_37_5.png
#   inflating: new_data_1024/train/image/IDRiD_38_0.png
#   inflating: new_data_1024/train/image/IDRiD_38_1.png
#   inflating: new_data_1024/train/image/IDRiD_38_2.png
#   inflating: new_data_1024/train/image/IDRiD_38_3.png
#   inflating: new_data_1024/train/image/IDRiD_38_4.png
#   inflating: new_data_1024/train/image/IDRiD_38_5.png
#   inflating: new_data_1024/train/image/IDRiD_39_0.png
#   inflating: new_data_1024/train/image/IDRiD_39_1.png
#   inflating: new_data_1024/train/image/IDRiD_39_2.png
#   inflating: new_data_1024/train/image/IDRiD_39_3.png
#   inflating: new_data_1024/train/image/IDRiD_39_4.png
#   inflating: new_data_1024/train/image/IDRiD_39_5.png
#   inflating: new_data_1024/train/image/IDRiD_40_0.png
#   inflating: new_data_1024/train/image/IDRiD_40_1.png
#   inflating: new_data_1024/train/image/IDRiD_40_2.png
#   inflating: new_data_1024/train/image/IDRiD_40_3.png
#   inflating: new_data_1024/train/image/IDRiD_40_4.png
#   inflating: new_data_1024/train/image/IDRiD_40_5.png
#   inflating: new_data_1024/train/image/IDRiD_41_0.png
#   inflating: new_data_1024/train/image/IDRiD_41_1.png
#   inflating: new_data_1024/train/image/IDRiD_41_2.png
#   inflating: new_data_1024/train/image/IDRiD_41_3.png
#   inflating: new_data_1024/train/image/IDRiD_41_4.png
#   inflating: new_data_1024/train/image/IDRiD_41_5.png
#   inflating: new_data_1024/train/image/IDRiD_42_0.png
#   inflating: new_data_1024/train/image/IDRiD_42_1.png
#   inflating: new_data_1024/train/image/IDRiD_42_2.png
#   inflating: new_data_1024/train/image/IDRiD_42_3.png
#   inflating: new_data_1024/train/image/IDRiD_42_4.png
#   inflating: new_data_1024/train/image/IDRiD_42_5.png
#   inflating: new_data_1024/train/image/IDRiD_43_0.png
#   inflating: new_data_1024/train/image/IDRiD_43_1.png
#   inflating: new_data_1024/train/image/IDRiD_43_2.png
#   inflating: new_data_1024/train/image/IDRiD_43_3.png
#   inflating: new_data_1024/train/image/IDRiD_43_4.png
#   inflating: new_data_1024/train/image/IDRiD_43_5.png
#   inflating: new_data_1024/train/image/IDRiD_44_0.png
#   inflating: new_data_1024/train/image/IDRiD_44_1.png
#   inflating: new_data_1024/train/image/IDRiD_44_2.png
#   inflating: new_data_1024/train/image/IDRiD_44_3.png
#   inflating: new_data_1024/train/image/IDRiD_44_4.png
#   inflating: new_data_1024/train/image/IDRiD_44_5.png
#   inflating: new_data_1024/train/image/IDRiD_45_0.png
#   inflating: new_data_1024/train/image/IDRiD_45_1.png
#   inflating: new_data_1024/train/image/IDRiD_45_2.png
#   inflating: new_data_1024/train/image/IDRiD_45_3.png
#   inflating: new_data_1024/train/image/IDRiD_45_4.png
#   inflating: new_data_1024/train/image/IDRiD_45_5.png
#   inflating: new_data_1024/train/image/IDRiD_46_0.png
#   inflating: new_data_1024/train/image/IDRiD_46_1.png
#   inflating: new_data_1024/train/image/IDRiD_46_2.png
#   inflating: new_data_1024/train/image/IDRiD_46_3.png
#   inflating: new_data_1024/train/image/IDRiD_46_4.png
#   inflating: new_data_1024/train/image/IDRiD_46_5.png
#   inflating: new_data_1024/train/image/IDRiD_47_0.png
#   inflating: new_data_1024/train/image/IDRiD_47_1.png
#   inflating: new_data_1024/train/image/IDRiD_47_2.png
#   inflating: new_data_1024/train/image/IDRiD_47_3.png
#   inflating: new_data_1024/train/image/IDRiD_47_4.png
#   inflating: new_data_1024/train/image/IDRiD_47_5.png
#   inflating: new_data_1024/train/image/IDRiD_48_0.png
#   inflating: new_data_1024/train/image/IDRiD_48_1.png
#   inflating: new_data_1024/train/image/IDRiD_48_2.png
#   inflating: new_data_1024/train/image/IDRiD_48_3.png
#   inflating: new_data_1024/train/image/IDRiD_48_4.png
#   inflating: new_data_1024/train/image/IDRiD_48_5.png
#   inflating: new_data_1024/train/image/IDRiD_49_0.png
#   inflating: new_data_1024/train/image/IDRiD_49_1.png
#   inflating: new_data_1024/train/image/IDRiD_49_2.png
#   inflating: new_data_1024/train/image/IDRiD_49_3.png
#   inflating: new_data_1024/train/image/IDRiD_49_4.png
#   inflating: new_data_1024/train/image/IDRiD_49_5.png
#   inflating: new_data_1024/train/image/IDRiD_50_0.png
#   inflating: new_data_1024/train/image/IDRiD_50_1.png
#   inflating: new_data_1024/train/image/IDRiD_50_2.png
#   inflating: new_data_1024/train/image/IDRiD_50_3.png
#   inflating: new_data_1024/train/image/IDRiD_50_4.png
#   inflating: new_data_1024/train/image/IDRiD_50_5.png
#   inflating: new_data_1024/train/image/IDRiD_51_0.png
#   inflating: new_data_1024/train/image/IDRiD_51_1.png
#   inflating: new_data_1024/train/image/IDRiD_51_2.png
#   inflating: new_data_1024/train/image/IDRiD_51_3.png
#   inflating: new_data_1024/train/image/IDRiD_51_4.png
#   inflating: new_data_1024/train/image/IDRiD_51_5.png
#   inflating: new_data_1024/train/image/IDRiD_52_0.png
#   inflating: new_data_1024/train/image/IDRiD_52_1.png
#   inflating: new_data_1024/train/image/IDRiD_52_2.png
#   inflating: new_data_1024/train/image/IDRiD_52_3.png
#   inflating: new_data_1024/train/image/IDRiD_52_4.png
#   inflating: new_data_1024/train/image/IDRiD_52_5.png
#   inflating: new_data_1024/train/image/IDRiD_53_0.png
#   inflating: new_data_1024/train/image/IDRiD_53_1.png
#   inflating: new_data_1024/train/image/IDRiD_53_2.png
#   inflating: new_data_1024/train/image/IDRiD_53_3.png
#   inflating: new_data_1024/train/image/IDRiD_53_4.png
#   inflating: new_data_1024/train/image/IDRiD_53_5.png
#   inflating: new_data_1024/train/image/IDRiD_54_0.png
#   inflating: new_data_1024/train/image/IDRiD_54_1.png
#   inflating: new_data_1024/train/image/IDRiD_54_2.png
#   inflating: new_data_1024/train/image/IDRiD_54_3.png
#   inflating: new_data_1024/train/image/IDRiD_54_4.png
#   inflating: new_data_1024/train/image/IDRiD_54_5.png
#    creating: new_data_1024/train/mask/
#   inflating: new_data_1024/train/mask/IDRiD_01_0.png
#   inflating: new_data_1024/train/mask/IDRiD_01_1.png
#   inflating: new_data_1024/train/mask/IDRiD_01_2.png
#   inflating: new_data_1024/train/mask/IDRiD_01_3.png
#   inflating: new_data_1024/train/mask/IDRiD_01_4.png
#   inflating: new_data_1024/train/mask/IDRiD_01_5.png
#   inflating: new_data_1024/train/mask/IDRiD_02_0.png
#   inflating: new_data_1024/train/mask/IDRiD_02_1.png
#   inflating: new_data_1024/train/mask/IDRiD_02_2.png
#   inflating: new_data_1024/train/mask/IDRiD_02_3.png
#   inflating: new_data_1024/train/mask/IDRiD_02_4.png
#   inflating: new_data_1024/train/mask/IDRiD_02_5.png
#   inflating: new_data_1024/train/mask/IDRiD_03_0.png
#   inflating: new_data_1024/train/mask/IDRiD_03_1.png
#   inflating: new_data_1024/train/mask/IDRiD_03_2.png
#   inflating: new_data_1024/train/mask/IDRiD_03_3.png
#   inflating: new_data_1024/train/mask/IDRiD_03_4.png
#   inflating: new_data_1024/train/mask/IDRiD_03_5.png
#   inflating: new_data_1024/train/mask/IDRiD_04_0.png
#   inflating: new_data_1024/train/mask/IDRiD_04_1.png
#   inflating: new_data_1024/train/mask/IDRiD_04_2.png
#   inflating: new_data_1024/train/mask/IDRiD_04_3.png
#   inflating: new_data_1024/train/mask/IDRiD_04_4.png
#   inflating: new_data_1024/train/mask/IDRiD_04_5.png
#   inflating: new_data_1024/train/mask/IDRiD_05_0.png
#   inflating: new_data_1024/train/mask/IDRiD_05_1.png
#   inflating: new_data_1024/train/mask/IDRiD_05_2.png
#   inflating: new_data_1024/train/mask/IDRiD_05_3.png
#   inflating: new_data_1024/train/mask/IDRiD_05_4.png
#   inflating: new_data_1024/train/mask/IDRiD_05_5.png
#   inflating: new_data_1024/train/mask/IDRiD_06_0.png
#   inflating: new_data_1024/train/mask/IDRiD_06_1.png
#   inflating: new_data_1024/train/mask/IDRiD_06_2.png
#   inflating: new_data_1024/train/mask/IDRiD_06_3.png
#   inflating: new_data_1024/train/mask/IDRiD_06_4.png
#   inflating: new_data_1024/train/mask/IDRiD_06_5.png
#   inflating: new_data_1024/train/mask/IDRiD_07_0.png
#   inflating: new_data_1024/train/mask/IDRiD_07_1.png
#   inflating: new_data_1024/train/mask/IDRiD_07_2.png
#   inflating: new_data_1024/train/mask/IDRiD_07_3.png
#   inflating: new_data_1024/train/mask/IDRiD_07_4.png
#   inflating: new_data_1024/train/mask/IDRiD_07_5.png
#   inflating: new_data_1024/train/mask/IDRiD_08_0.png
#   inflating: new_data_1024/train/mask/IDRiD_08_1.png
#   inflating: new_data_1024/train/mask/IDRiD_08_2.png
#   inflating: new_data_1024/train/mask/IDRiD_08_3.png
#   inflating: new_data_1024/train/mask/IDRiD_08_4.png
#   inflating: new_data_1024/train/mask/IDRiD_08_5.png
#   inflating: new_data_1024/train/mask/IDRiD_09_0.png
#   inflating: new_data_1024/train/mask/IDRiD_09_1.png
#   inflating: new_data_1024/train/mask/IDRiD_09_2.png
#   inflating: new_data_1024/train/mask/IDRiD_09_3.png
#   inflating: new_data_1024/train/mask/IDRiD_09_4.png
#   inflating: new_data_1024/train/mask/IDRiD_09_5.png
#   inflating: new_data_1024/train/mask/IDRiD_10_0.png
#   inflating: new_data_1024/train/mask/IDRiD_10_1.png
#   inflating: new_data_1024/train/mask/IDRiD_10_2.png
#   inflating: new_data_1024/train/mask/IDRiD_10_3.png
#   inflating: new_data_1024/train/mask/IDRiD_10_4.png
#   inflating: new_data_1024/train/mask/IDRiD_10_5.png
#   inflating: new_data_1024/train/mask/IDRiD_11_0.png
#   inflating: new_data_1024/train/mask/IDRiD_11_1.png
#   inflating: new_data_1024/train/mask/IDRiD_11_2.png
#   inflating: new_data_1024/train/mask/IDRiD_11_3.png
#   inflating: new_data_1024/train/mask/IDRiD_11_4.png
#   inflating: new_data_1024/train/mask/IDRiD_11_5.png
#   inflating: new_data_1024/train/mask/IDRiD_12_0.png
#   inflating: new_data_1024/train/mask/IDRiD_12_1.png
#   inflating: new_data_1024/train/mask/IDRiD_12_2.png
#   inflating: new_data_1024/train/mask/IDRiD_12_3.png
#   inflating: new_data_1024/train/mask/IDRiD_12_4.png
#   inflating: new_data_1024/train/mask/IDRiD_12_5.png
#   inflating: new_data_1024/train/mask/IDRiD_13_0.png
#   inflating: new_data_1024/train/mask/IDRiD_13_1.png
#   inflating: new_data_1024/train/mask/IDRiD_13_2.png
#   inflating: new_data_1024/train/mask/IDRiD_13_3.png
#   inflating: new_data_1024/train/mask/IDRiD_13_4.png
#   inflating: new_data_1024/train/mask/IDRiD_13_5.png
#   inflating: new_data_1024/train/mask/IDRiD_14_0.png
#   inflating: new_data_1024/train/mask/IDRiD_14_1.png
#   inflating: new_data_1024/train/mask/IDRiD_14_2.png
#   inflating: new_data_1024/train/mask/IDRiD_14_3.png
#   inflating: new_data_1024/train/mask/IDRiD_14_4.png
#   inflating: new_data_1024/train/mask/IDRiD_14_5.png
#   inflating: new_data_1024/train/mask/IDRiD_15_0.png
#   inflating: new_data_1024/train/mask/IDRiD_15_1.png
#   inflating: new_data_1024/train/mask/IDRiD_15_2.png
#   inflating: new_data_1024/train/mask/IDRiD_15_3.png
#   inflating: new_data_1024/train/mask/IDRiD_15_4.png
#   inflating: new_data_1024/train/mask/IDRiD_15_5.png
#   inflating: new_data_1024/train/mask/IDRiD_16_0.png
#   inflating: new_data_1024/train/mask/IDRiD_16_1.png
#   inflating: new_data_1024/train/mask/IDRiD_16_2.png
#   inflating: new_data_1024/train/mask/IDRiD_16_3.png
#   inflating: new_data_1024/train/mask/IDRiD_16_4.png
#   inflating: new_data_1024/train/mask/IDRiD_16_5.png
#   inflating: new_data_1024/train/mask/IDRiD_17_0.png
#   inflating: new_data_1024/train/mask/IDRiD_17_1.png
#   inflating: new_data_1024/train/mask/IDRiD_17_2.png
#   inflating: new_data_1024/train/mask/IDRiD_17_3.png
#   inflating: new_data_1024/train/mask/IDRiD_17_4.png
#   inflating: new_data_1024/train/mask/IDRiD_17_5.png
#   inflating: new_data_1024/train/mask/IDRiD_18_0.png
#   inflating: new_data_1024/train/mask/IDRiD_18_1.png
#   inflating: new_data_1024/train/mask/IDRiD_18_2.png
#   inflating: new_data_1024/train/mask/IDRiD_18_3.png
#   inflating: new_data_1024/train/mask/IDRiD_18_4.png
#   inflating: new_data_1024/train/mask/IDRiD_18_5.png
#   inflating: new_data_1024/train/mask/IDRiD_19_0.png
#   inflating: new_data_1024/train/mask/IDRiD_19_1.png
#   inflating: new_data_1024/train/mask/IDRiD_19_2.png
#   inflating: new_data_1024/train/mask/IDRiD_19_3.png
#   inflating: new_data_1024/train/mask/IDRiD_19_4.png
#   inflating: new_data_1024/train/mask/IDRiD_19_5.png
#   inflating: new_data_1024/train/mask/IDRiD_20_0.png
#   inflating: new_data_1024/train/mask/IDRiD_20_1.png
#   inflating: new_data_1024/train/mask/IDRiD_20_2.png
#   inflating: new_data_1024/train/mask/IDRiD_20_3.png
#   inflating: new_data_1024/train/mask/IDRiD_20_4.png
#   inflating: new_data_1024/train/mask/IDRiD_20_5.png
#   inflating: new_data_1024/train/mask/IDRiD_21_0.png
#   inflating: new_data_1024/train/mask/IDRiD_21_1.png
#   inflating: new_data_1024/train/mask/IDRiD_21_2.png
#   inflating: new_data_1024/train/mask/IDRiD_21_3.png
#   inflating: new_data_1024/train/mask/IDRiD_21_4.png
#   inflating: new_data_1024/train/mask/IDRiD_21_5.png
#   inflating: new_data_1024/train/mask/IDRiD_22_0.png
#   inflating: new_data_1024/train/mask/IDRiD_22_1.png
#   inflating: new_data_1024/train/mask/IDRiD_22_2.png
#   inflating: new_data_1024/train/mask/IDRiD_22_3.png
#   inflating: new_data_1024/train/mask/IDRiD_22_4.png
#   inflating: new_data_1024/train/mask/IDRiD_22_5.png
#   inflating: new_data_1024/train/mask/IDRiD_23_0.png
#   inflating: new_data_1024/train/mask/IDRiD_23_1.png
#   inflating: new_data_1024/train/mask/IDRiD_23_2.png
#   inflating: new_data_1024/train/mask/IDRiD_23_3.png
#   inflating: new_data_1024/train/mask/IDRiD_23_4.png
#   inflating: new_data_1024/train/mask/IDRiD_23_5.png
#   inflating: new_data_1024/train/mask/IDRiD_24_0.png
#   inflating: new_data_1024/train/mask/IDRiD_24_1.png
#   inflating: new_data_1024/train/mask/IDRiD_24_2.png
#   inflating: new_data_1024/train/mask/IDRiD_24_3.png
#   inflating: new_data_1024/train/mask/IDRiD_24_4.png
#   inflating: new_data_1024/train/mask/IDRiD_24_5.png
#   inflating: new_data_1024/train/mask/IDRiD_25_0.png
#   inflating: new_data_1024/train/mask/IDRiD_25_1.png
#   inflating: new_data_1024/train/mask/IDRiD_25_2.png
#   inflating: new_data_1024/train/mask/IDRiD_25_3.png
#   inflating: new_data_1024/train/mask/IDRiD_25_4.png
#   inflating: new_data_1024/train/mask/IDRiD_25_5.png
#   inflating: new_data_1024/train/mask/IDRiD_26_0.png
#   inflating: new_data_1024/train/mask/IDRiD_26_1.png
#   inflating: new_data_1024/train/mask/IDRiD_26_2.png
#   inflating: new_data_1024/train/mask/IDRiD_26_3.png
#   inflating: new_data_1024/train/mask/IDRiD_26_4.png
#   inflating: new_data_1024/train/mask/IDRiD_26_5.png
#   inflating: new_data_1024/train/mask/IDRiD_27_0.png
#   inflating: new_data_1024/train/mask/IDRiD_27_1.png
#   inflating: new_data_1024/train/mask/IDRiD_27_2.png
#   inflating: new_data_1024/train/mask/IDRiD_27_3.png
#   inflating: new_data_1024/train/mask/IDRiD_27_4.png
#   inflating: new_data_1024/train/mask/IDRiD_27_5.png
#   inflating: new_data_1024/train/mask/IDRiD_28_0.png
#   inflating: new_data_1024/train/mask/IDRiD_28_1.png
#   inflating: new_data_1024/train/mask/IDRiD_28_2.png
#   inflating: new_data_1024/train/mask/IDRiD_28_3.png
#   inflating: new_data_1024/train/mask/IDRiD_28_4.png
#   inflating: new_data_1024/train/mask/IDRiD_28_5.png
#   inflating: new_data_1024/train/mask/IDRiD_29_0.png
#   inflating: new_data_1024/train/mask/IDRiD_29_1.png
#   inflating: new_data_1024/train/mask/IDRiD_29_2.png
#   inflating: new_data_1024/train/mask/IDRiD_29_3.png
#   inflating: new_data_1024/train/mask/IDRiD_29_4.png
#   inflating: new_data_1024/train/mask/IDRiD_29_5.png
#   inflating: new_data_1024/train/mask/IDRiD_30_0.png
#   inflating: new_data_1024/train/mask/IDRiD_30_1.png
#   inflating: new_data_1024/train/mask/IDRiD_30_2.png
#   inflating: new_data_1024/train/mask/IDRiD_30_3.png
#   inflating: new_data_1024/train/mask/IDRiD_30_4.png
#   inflating: new_data_1024/train/mask/IDRiD_30_5.png
#   inflating: new_data_1024/train/mask/IDRiD_31_0.png
#   inflating: new_data_1024/train/mask/IDRiD_31_1.png
#   inflating: new_data_1024/train/mask/IDRiD_31_2.png
#   inflating: new_data_1024/train/mask/IDRiD_31_3.png
#   inflating: new_data_1024/train/mask/IDRiD_31_4.png
#   inflating: new_data_1024/train/mask/IDRiD_31_5.png
#   inflating: new_data_1024/train/mask/IDRiD_32_0.png
#   inflating: new_data_1024/train/mask/IDRiD_32_1.png
#   inflating: new_data_1024/train/mask/IDRiD_32_2.png
#   inflating: new_data_1024/train/mask/IDRiD_32_3.png
#   inflating: new_data_1024/train/mask/IDRiD_32_4.png
#   inflating: new_data_1024/train/mask/IDRiD_32_5.png
#   inflating: new_data_1024/train/mask/IDRiD_33_0.png
#   inflating: new_data_1024/train/mask/IDRiD_33_1.png
#   inflating: new_data_1024/train/mask/IDRiD_33_2.png
#   inflating: new_data_1024/train/mask/IDRiD_33_3.png
#   inflating: new_data_1024/train/mask/IDRiD_33_4.png
#   inflating: new_data_1024/train/mask/IDRiD_33_5.png
#   inflating: new_data_1024/train/mask/IDRiD_34_0.png
#   inflating: new_data_1024/train/mask/IDRiD_34_1.png
#   inflating: new_data_1024/train/mask/IDRiD_34_2.png
#   inflating: new_data_1024/train/mask/IDRiD_34_3.png
#   inflating: new_data_1024/train/mask/IDRiD_34_4.png
#   inflating: new_data_1024/train/mask/IDRiD_34_5.png
#   inflating: new_data_1024/train/mask/IDRiD_35_0.png
#   inflating: new_data_1024/train/mask/IDRiD_35_1.png
#   inflating: new_data_1024/train/mask/IDRiD_35_2.png
#   inflating: new_data_1024/train/mask/IDRiD_35_3.png
#   inflating: new_data_1024/train/mask/IDRiD_35_4.png
#   inflating: new_data_1024/train/mask/IDRiD_35_5.png
#   inflating: new_data_1024/train/mask/IDRiD_36_0.png
#   inflating: new_data_1024/train/mask/IDRiD_36_1.png
#   inflating: new_data_1024/train/mask/IDRiD_36_2.png
#   inflating: new_data_1024/train/mask/IDRiD_36_3.png
#   inflating: new_data_1024/train/mask/IDRiD_36_4.png
#   inflating: new_data_1024/train/mask/IDRiD_36_5.png
#   inflating: new_data_1024/train/mask/IDRiD_37_0.png
#   inflating: new_data_1024/train/mask/IDRiD_37_1.png
#   inflating: new_data_1024/train/mask/IDRiD_37_2.png
#   inflating: new_data_1024/train/mask/IDRiD_37_3.png
#   inflating: new_data_1024/train/mask/IDRiD_37_4.png
#   inflating: new_data_1024/train/mask/IDRiD_37_5.png
#   inflating: new_data_1024/train/mask/IDRiD_38_0.png
#   inflating: new_data_1024/train/mask/IDRiD_38_1.png
#   inflating: new_data_1024/train/mask/IDRiD_38_2.png
#   inflating: new_data_1024/train/mask/IDRiD_38_3.png
#   inflating: new_data_1024/train/mask/IDRiD_38_4.png
#   inflating: new_data_1024/train/mask/IDRiD_38_5.png
#   inflating: new_data_1024/train/mask/IDRiD_39_0.png
#   inflating: new_data_1024/train/mask/IDRiD_39_1.png
#   inflating: new_data_1024/train/mask/IDRiD_39_2.png
#   inflating: new_data_1024/train/mask/IDRiD_39_3.png
#   inflating: new_data_1024/train/mask/IDRiD_39_4.png
#   inflating: new_data_1024/train/mask/IDRiD_39_5.png
#   inflating: new_data_1024/train/mask/IDRiD_40_0.png
#   inflating: new_data_1024/train/mask/IDRiD_40_1.png
#   inflating: new_data_1024/train/mask/IDRiD_40_2.png
#   inflating: new_data_1024/train/mask/IDRiD_40_3.png
#   inflating: new_data_1024/train/mask/IDRiD_40_4.png
#   inflating: new_data_1024/train/mask/IDRiD_40_5.png
#   inflating: new_data_1024/train/mask/IDRiD_41_0.png
#   inflating: new_data_1024/train/mask/IDRiD_41_1.png
#   inflating: new_data_1024/train/mask/IDRiD_41_2.png
#   inflating: new_data_1024/train/mask/IDRiD_41_3.png
#   inflating: new_data_1024/train/mask/IDRiD_41_4.png
#   inflating: new_data_1024/train/mask/IDRiD_41_5.png
#   inflating: new_data_1024/train/mask/IDRiD_42_0.png
#   inflating: new_data_1024/train/mask/IDRiD_42_1.png
#   inflating: new_data_1024/train/mask/IDRiD_42_2.png
#   inflating: new_data_1024/train/mask/IDRiD_42_3.png
#   inflating: new_data_1024/train/mask/IDRiD_42_4.png
#   inflating: new_data_1024/train/mask/IDRiD_42_5.png
#   inflating: new_data_1024/train/mask/IDRiD_43_0.png
#   inflating: new_data_1024/train/mask/IDRiD_43_1.png
#   inflating: new_data_1024/train/mask/IDRiD_43_2.png
#   inflating: new_data_1024/train/mask/IDRiD_43_3.png
#   inflating: new_data_1024/train/mask/IDRiD_43_4.png
#   inflating: new_data_1024/train/mask/IDRiD_43_5.png
#   inflating: new_data_1024/train/mask/IDRiD_44_0.png
#   inflating: new_data_1024/train/mask/IDRiD_44_1.png
#   inflating: new_data_1024/train/mask/IDRiD_44_2.png
#   inflating: new_data_1024/train/mask/IDRiD_44_3.png
#   inflating: new_data_1024/train/mask/IDRiD_44_4.png
#   inflating: new_data_1024/train/mask/IDRiD_44_5.png
#   inflating: new_data_1024/train/mask/IDRiD_45_0.png
#   inflating: new_data_1024/train/mask/IDRiD_45_1.png
#   inflating: new_data_1024/train/mask/IDRiD_45_2.png
#   inflating: new_data_1024/train/mask/IDRiD_45_3.png
#   inflating: new_data_1024/train/mask/IDRiD_45_4.png
#   inflating: new_data_1024/train/mask/IDRiD_45_5.png
#   inflating: new_data_1024/train/mask/IDRiD_46_0.png
#   inflating: new_data_1024/train/mask/IDRiD_46_1.png
#   inflating: new_data_1024/train/mask/IDRiD_46_2.png
#   inflating: new_data_1024/train/mask/IDRiD_46_3.png
#   inflating: new_data_1024/train/mask/IDRiD_46_4.png
#   inflating: new_data_1024/train/mask/IDRiD_46_5.png
#   inflating: new_data_1024/train/mask/IDRiD_47_0.png
#   inflating: new_data_1024/train/mask/IDRiD_47_1.png
#   inflating: new_data_1024/train/mask/IDRiD_47_2.png
#   inflating: new_data_1024/train/mask/IDRiD_47_3.png
#   inflating: new_data_1024/train/mask/IDRiD_47_4.png
#   inflating: new_data_1024/train/mask/IDRiD_47_5.png
#   inflating: new_data_1024/train/mask/IDRiD_48_0.png
#   inflating: new_data_1024/train/mask/IDRiD_48_1.png
#   inflating: new_data_1024/train/mask/IDRiD_48_2.png
#   inflating: new_data_1024/train/mask/IDRiD_48_3.png
#   inflating: new_data_1024/train/mask/IDRiD_48_4.png
#   inflating: new_data_1024/train/mask/IDRiD_48_5.png
#   inflating: new_data_1024/train/mask/IDRiD_49_0.png
#   inflating: new_data_1024/train/mask/IDRiD_49_1.png
#   inflating: new_data_1024/train/mask/IDRiD_49_2.png
#   inflating: new_data_1024/train/mask/IDRiD_49_3.png
#   inflating: new_data_1024/train/mask/IDRiD_49_4.png
#   inflating: new_data_1024/train/mask/IDRiD_49_5.png
#   inflating: new_data_1024/train/mask/IDRiD_50_0.png
#   inflating: new_data_1024/train/mask/IDRiD_50_1.png
#   inflating: new_data_1024/train/mask/IDRiD_50_2.png
#   inflating: new_data_1024/train/mask/IDRiD_50_3.png
#   inflating: new_data_1024/train/mask/IDRiD_50_4.png
#   inflating: new_data_1024/train/mask/IDRiD_50_5.png
#   inflating: new_data_1024/train/mask/IDRiD_51_0.png
#   inflating: new_data_1024/train/mask/IDRiD_51_1.png
#   inflating: new_data_1024/train/mask/IDRiD_51_2.png
#   inflating: new_data_1024/train/mask/IDRiD_51_3.png
#   inflating: new_data_1024/train/mask/IDRiD_51_4.png
#   inflating: new_data_1024/train/mask/IDRiD_51_5.png
#   inflating: new_data_1024/train/mask/IDRiD_52_0.png
#   inflating: new_data_1024/train/mask/IDRiD_52_1.png
#   inflating: new_data_1024/train/mask/IDRiD_52_2.png
#   inflating: new_data_1024/train/mask/IDRiD_52_3.png
#   inflating: new_data_1024/train/mask/IDRiD_52_4.png
#   inflating: new_data_1024/train/mask/IDRiD_52_5.png
#   inflating: new_data_1024/train/mask/IDRiD_53_0.png
#   inflating: new_data_1024/train/mask/IDRiD_53_1.png
#   inflating: new_data_1024/train/mask/IDRiD_53_2.png
#   inflating: new_data_1024/train/mask/IDRiD_53_3.png
#   inflating: new_data_1024/train/mask/IDRiD_53_4.png
#   inflating: new_data_1024/train/mask/IDRiD_53_5.png
#   inflating: new_data_1024/train/mask/IDRiD_54_0.png
#   inflating: new_data_1024/train/mask/IDRiD_54_1.png
#   inflating: new_data_1024/train/mask/IDRiD_54_2.png
#   inflating: new_data_1024/train/mask/IDRiD_54_3.png
#   inflating: new_data_1024/train/mask/IDRiD_54_4.png
#   inflating: new_data_1024/train/mask/IDRiD_54_5.png

# %% [markdown]
# ### Construct the Model:

# %%
def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    b1 = conv_block(p4, 1024)

    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="UNET")
    return model

input_shape = (512, 768, 3)
model = build_unet(input_shape)
model.summary()
# Out:
# Model: "UNET"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 768, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 768, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 768, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 512, 768, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 768, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 512, 768, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 512, 768, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 384, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 384, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 256, 384, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 256, 384, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 256, 384, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 256, 384, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 256, 384, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 192, 12  0          ['activation_3[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 128, 192, 25  295168      ['max_pooling2d_1[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 192, 25  1024       ['conv2d_4[0][0]']
#  rmalization)                   6)
#
#  activation_4 (Activation)      (None, 128, 192, 25  0           ['batch_normalization_4[0][0]']
#                                 6)
#
#  conv2d_5 (Conv2D)              (None, 128, 192, 25  590080      ['activation_4[0][0]']
#                                 6)
#
#  batch_normalization_5 (BatchNo  (None, 128, 192, 25  1024       ['conv2d_5[0][0]']
#  rmalization)                   6)
#
#  activation_5 (Activation)      (None, 128, 192, 25  0           ['batch_normalization_5[0][0]']
#                                 6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 96, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 96, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 96, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 96, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 96, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 96, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 64, 96, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 48, 512)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 48, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 32, 48, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_8 (Activation)      (None, 32, 48, 1024  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 32, 48, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 32, 48, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 32, 48, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 96, 512)  2097664    ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 64, 96, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 96, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 96, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 96, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 96, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 64, 96, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 64, 96, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 192, 25  524544     ['activation_11[0][0]']
#  spose)                         6)
#
#  concatenate_1 (Concatenate)    (None, 128, 192, 51  0           ['conv2d_transpose_1[0][0]',
#                                 2)                                'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 192, 25  1179904     ['concatenate_1[0][0]']
#                                 6)
#
#  batch_normalization_12 (BatchN  (None, 128, 192, 25  1024       ['conv2d_12[0][0]']
#  ormalization)                  6)
#
#  activation_12 (Activation)     (None, 128, 192, 25  0           ['batch_normalization_12[0][0]']
#                                 6)
#
#  conv2d_13 (Conv2D)             (None, 128, 192, 25  590080      ['activation_12[0][0]']
#                                 6)
#
#  batch_normalization_13 (BatchN  (None, 128, 192, 25  1024       ['conv2d_13[0][0]']
#  ormalization)                  6)
#
#  activation_13 (Activation)     (None, 128, 192, 25  0           ['batch_normalization_13[0][0]']
#                                 6)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 384, 12  131200     ['activation_13[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 256, 384, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 256, 384, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 256, 384, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  activation_14 (Activation)     (None, 256, 384, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 256, 384, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_15 (BatchN  (None, 256, 384, 12  512        ['conv2d_15[0][0]']
#  ormalization)                  8)
#
#  activation_15 (Activation)     (None, 256, 384, 12  0           ['batch_normalization_15[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 768, 64  32832      ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 512, 768, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 512, 768, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 512, 768, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 512, 768, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 512, 768, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 512, 768, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 512, 768, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 512, 768, 1)  65          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %% [markdown]
# ### Adding the Metrics:

# %%
def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def DiceBCELoss(y_true, y_pred):

    inputs = tf.keras.layers.Flatten()(y_true)
    targets = tf.keras.layers.Flatten()(y_pred)

    intersection = tf.reduce_sum(inputs * targets)
    dice_loss = 1 - (2.*intersection + smooth)/(tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)
    BCE = tf.keras.losses.BinaryCrossentropy()
    Dice_BCE = BCE(inputs, targets) + dice_loss

    return Dice_BCE

# %% [markdown]
# ### Training the Model:

# %%
H = 1024
W = 1024

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.png")))
    y = sorted(glob(os.path.join(path, "mask", "*.png")))
    return x, y

def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)
    return x, y

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)              ## (512, 512, 1)
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y, batch_size=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(4)
    return dataset

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

""" Directory to save files """
create_dir("files")

""" Hyperparameters """
batch_size = 2
lr = 1e-4
num_epochs = 50
model_path = os.path.join("files", "model.h5")
csv_path = os.path.join("files", "data.csv")

""" Dataset """
dataset_path = "new_data_1024"
train_path = os.path.join(dataset_path, "train")
valid_path = os.path.join(dataset_path, "test")

train_x, train_y = load_data(train_path)
train_x, train_y = shuffling(train_x, train_y)
valid_x, valid_y = load_data(valid_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Valid: {len(valid_x)} - {len(valid_y)}")

train_dataset = tf_dataset(train_x, train_y, batch_size=batch_size)
valid_dataset = tf_dataset(valid_x, valid_y, batch_size=batch_size)

train_steps = len(train_x)//batch_size
valid_setps = len(valid_x)//batch_size

if len(train_x) % batch_size != 0:
    train_steps += 1
if len(valid_x) % batch_size != 0:
    valid_setps += 1

""" Model """
model = build_unet((H, W, 3))
# model.compile(loss=tf.keras.losses.BinaryCrossentropy(), optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])
# model.compile(loss=dice_loss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])
# model.summary()

model.compile(loss=DiceBCELoss, optimizer=Adam(lr), metrics=[dice_coef, iou, Recall(), Precision()])

callbacks = [
    ModelCheckpoint(model_path, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=5, min_lr=1e-6, verbose=1),
    CSVLogger(csv_path),
    TensorBoard(),
    EarlyStopping(monitor="val_loss", patience=10, restore_best_weights=False)
]

model.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=valid_dataset,
    steps_per_epoch=train_steps,
    validation_steps=valid_setps,
    callbacks=callbacks
)
# Out:
# Train: 324 - 324
# Valid: 27 - 27
# Epoch 1/50
# 162/162 [==============================] - ETA: 0s - loss: 1.1544 - dice_coef: 0.0475 - iou: 0.0250 - recall_1: 0.3369 - precision_1: 0.1358
# Epoch 00001: val_loss improved from inf to 1.20056, saving model to files/model.h5
# 162/162 [==============================] - 175s 1s/step - loss: 1.1544 - dice_coef: 0.0475 - iou: 0.0250 - recall_1: 0.3369 - precision_1: 0.1358 - val_loss: 1.2006 - val_dice_coef: 0.0209 - val_iou: 0.0107 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - lr: 1.0000e-04
# Epoch 2/50
# 162/162 [==============================] - ETA: 0s - loss: 0.9928 - dice_coef: 0.1064 - iou: 0.0587 - recall_1: 0.6009 - precision_1: 0.4097
# Epoch 00002: val_loss improved from 1.20056 to 1.07365, saving model to files/model.h5
# 162/162 [==============================] - 163s 1s/step - loss: 0.9928 - dice_coef: 0.1064 - iou: 0.0587 - recall_1: 0.6009 - precision_1: 0.4097 - val_loss: 1.0736 - val_dice_coef: 0.0269 - val_iou: 0.0137 - val_recall_1: 0.0177 - val_precision_1: 0.5462 - lr: 1.0000e-04
# Epoch 3/50
# 162/162 [==============================] - ETA: 0s - loss: 0.9060 - dice_coef: 0.1616 - iou: 0.0929 - recall_1: 0.6901 - precision_1: 0.4900
# Epoch 00003: val_loss improved from 1.07365 to 0.97356, saving model to files/model.h5
# 162/162 [==============================] - 163s 1s/step - loss: 0.9060 - dice_coef: 0.1616 - iou: 0.0929 - recall_1: 0.6901 - precision_1: 0.4900 - val_loss: 0.9736 - val_dice_coef: 0.0928 - val_iou: 0.0502 - val_recall_1: 0.2044 - val_precision_1: 0.9200 - lr: 1.0000e-04
# Epoch 4/50
# 162/162 [==============================] - ETA: 0s - loss: 0.8348 - dice_coef: 0.2162 - iou: 0.1291 - recall_1: 0.7260 - precision_1: 0.5392
# Epoch 00004: val_loss improved from 0.97356 to 0.89048, saving model to files/model.h5
# 162/162 [==============================] - 163s 1s/step - loss: 0.8348 - dice_coef: 0.2162 - iou: 0.1291 - recall_1: 0.7260 - precision_1: 0.5392 - val_loss: 0.8905 - val_dice_coef: 0.1615 - val_iou: 0.0945 - val_recall_1: 0.3344 - val_precision_1: 0.7696 - lr: 1.0000e-04
# Epoch 5/50
# 162/162 [==============================] - ETA: 0s - loss: 0.7633 - dice_coef: 0.2761 - iou: 0.1713 - recall_1: 0.7286 - precision_1: 0.5913
# Epoch 00005: val_loss improved from 0.89048 to 0.80944, saving model to files/model.h5
# 162/162 [==============================] - 163s 1s/step - loss: 0.7633 - dice_coef: 0.2761 - iou: 0.1713 - recall_1: 0.7286 - precision_1: 0.5913 - val_loss: 0.8094 - val_dice_coef: 0.2425 - val_iou: 0.1481 - val_recall_1: 0.4677 - val_precision_1: 0.6366 - lr: 1.0000e-04
# Epoch 6/50
# 162/162 [==============================] - ETA: 0s - loss: 0.6955 - dice_coef: 0.3358 - iou: 0.2154 - recall_1: 0.7118 - precision_1: 0.6373
# Epoch 00006: val_loss improved from 0.80944 to 0.75865, saving model to files/model.h5
# 162/162 [==============================] - 163s 1s/step - loss: 0.6955 - dice_coef: 0.3358 - iou: 0.2154 - recall_1: 0.7118 - precision_1: 0.6373 - val_loss: 0.7586 - val_dice_coef: 0.2819 - val_iou: 0.1774 - val_recall_1: 0.3695 - val_precision_1: 0.7542 - lr: 1.0000e-04
# Epoch 7/50
# 162/162 [==============================] - ETA: 0s - loss: 0.6257 - dice_coef: 0.4006 - iou: 0.2669 - recall_1: 0.7106 - precision_1: 0.6878
# Epoch 00007: val_loss did not improve from 0.75865
# 162/162 [==============================] - 159s 982ms/step - loss: 0.6257 - dice_coef: 0.4006 - iou: 0.2669 - recall_1: 0.7106 - precision_1: 0.6878 - val_loss: 1.3895 - val_dice_coef: 0.0482 - val_iou: 0.0254 - val_recall_1: 0.3463 - val_precision_1: 0.0335 - lr: 1.0000e-04
# Epoch 8/50
# 162/162 [==============================] - ETA: 0s - loss: 0.5684 - dice_coef: 0.4552 - iou: 0.3122 - recall_1: 0.6926 - precision_1: 0.7176
# Epoch 00008: val_loss improved from 0.75865 to 0.65196, saving model to files/model.h5
# 162/162 [==============================] - 162s 1s/step - loss: 0.5684 - dice_coef: 0.4552 - iou: 0.3122 - recall_1: 0.6926 - precision_1: 0.7176 - val_loss: 0.6520 - val_dice_coef: 0.3881 - val_iou: 0.2572 - val_recall_1: 0.3988 - val_precision_1: 0.7579 - lr: 1.0000e-04
# Epoch 9/50
# 162/162 [==============================] - ETA: 0s - loss: 0.5065 - dice_coef: 0.5147 - iou: 0.3639 - recall_1: 0.6921 - precision_1: 0.7590
# Epoch 00009: val_loss improved from 0.65196 to 0.58017, saving model to files/model.h5
# 162/162 [==============================] - 163s 1s/step - loss: 0.5065 - dice_coef: 0.5147 - iou: 0.3639 - recall_1: 0.6921 - precision_1: 0.7590 - val_loss: 0.5802 - val_dice_coef: 0.4493 - val_iou: 0.3119 - val_recall_1: 0.4236 - val_precision_1: 0.8726 - lr: 1.0000e-04
# Epoch 10/50
# 162/162 [==============================] - ETA: 0s - loss: 0.4699 - dice_coef: 0.5506 - iou: 0.3965 - recall_1: 0.6825 - precision_1: 0.7734
# Epoch 00010: val_loss did not improve from 0.58017
# 162/162 [==============================] - 159s 982ms/step - loss: 0.4699 - dice_coef: 0.5506 - iou: 0.3965 - recall_1: 0.6825 - precision_1: 0.7734 - val_loss: 0.6140 - val_dice_coef: 0.4208 - val_iou: 0.2892 - val_recall_1: 0.3601 - val_precision_1: 0.8975 - lr: 1.0000e-04
# Epoch 11/50
# 162/162 [==============================] - ETA: 0s - loss: 0.4318 - dice_coef: 0.5885 - iou: 0.4323 - recall_1: 0.6785 - precision_1: 0.7882
# Epoch 00011: val_loss improved from 0.58017 to 0.53651, saving model to files/model.h5
# 162/162 [==============================] - 162s 1s/step - loss: 0.4318 - dice_coef: 0.5885 - iou: 0.4323 - recall_1: 0.6785 - precision_1: 0.7882 - val_loss: 0.5365 - val_dice_coef: 0.4959 - val_iou: 0.3532 - val_recall_1: 0.4147 - val_precision_1: 0.8745 - lr: 1.0000e-04
# Epoch 12/50
# 162/162 [==============================] - ETA: 0s - loss: 0.3958 - dice_coef: 0.6235 - iou: 0.4669 - recall_1: 0.6964 - precision_1: 0.8078
# Epoch 00012: val_loss improved from 0.53651 to 0.49938, saving model to files/model.h5
# 162/162 [==============================] - 163s 1s/step - loss: 0.3958 - dice_coef: 0.6235 - iou: 0.4669 - recall_1: 0.6964 - precision_1: 0.8078 - val_loss: 0.4994 - val_dice_coef: 0.5305 - val_iou: 0.3895 - val_recall_1: 0.4169 - val_precision_1: 0.8789 - lr: 1.0000e-04
# Epoch 13/50
# 162/162 [==============================] - ETA: 0s - loss: 0.3918 - dice_coef: 0.6285 - iou: 0.4717 - recall_1: 0.6709 - precision_1: 0.8045
# Epoch 00013: val_loss did not improve from 0.49938
# 162/162 [==============================] - 159s 982ms/step - loss: 0.3918 - dice_coef: 0.6285 - iou: 0.4717 - recall_1: 0.6709 - precision_1: 0.8045 - val_loss: 0.5210 - val_dice_coef: 0.5083 - val_iou: 0.3711 - val_recall_1: 0.3786 - val_precision_1: 0.9052 - lr: 1.0000e-04
# Epoch 14/50
# 162/162 [==============================] - ETA: 0s - loss: 0.3839 - dice_coef: 0.6369 - iou: 0.4800 - recall_1: 0.6665 - precision_1: 0.8041
# Epoch 00014: val_loss improved from 0.49938 to 0.43551, saving model to files/model.h5
# 162/162 [==============================] - 163s 1s/step - loss: 0.3839 - dice_coef: 0.6369 - iou: 0.4800 - recall_1: 0.6665 - precision_1: 0.8041 - val_loss: 0.4355 - val_dice_coef: 0.5998 - val_iou: 0.4405 - val_recall_1: 0.5041 - val_precision_1: 0.8783 - lr: 1.0000e-04
# Epoch 15/50
# 162/162 [==============================] - ETA: 0s - loss: 0.3616 - dice_coef: 0.6584 - iou: 0.5019 - recall_1: 0.6793 - precision_1: 0.8143
# Epoch 00015: val_loss did not improve from 0.43551
# 162/162 [==============================] - 159s 982ms/step - loss: 0.3616 - dice_coef: 0.6584 - iou: 0.5019 - recall_1: 0.6793 - precision_1: 0.8143 - val_loss: 0.5079 - val_dice_coef: 0.5256 - val_iou: 0.3866 - val_recall_1: 0.3841 - val_precision_1: 0.9149 - lr: 1.0000e-04
# Epoch 16/50
# 162/162 [==============================] - ETA: 0s - loss: 0.3297 - dice_coef: 0.6884 - iou: 0.5340 - recall_1: 0.7141 - precision_1: 0.8329
# Epoch 00016: val_loss improved from 0.43551 to 0.42681, saving model to files/model.h5
# 162/162 [==============================] - 163s 1s/step - loss: 0.3297 - dice_coef: 0.6884 - iou: 0.5340 - recall_1: 0.7141 - precision_1: 0.8329 - val_loss: 0.4268 - val_dice_coef: 0.6031 - val_iou: 0.4536 - val_recall_1: 0.4926 - val_precision_1: 0.8731 - lr: 1.0000e-04
# Epoch 17/50
# 162/162 [==============================] - ETA: 0s - loss: 0.3262 - dice_coef: 0.6925 - iou: 0.5381 - recall_1: 0.7096 - precision_1: 0.8303
# Epoch 00017: val_loss did not improve from 0.42681
# 162/162 [==============================] - 159s 982ms/step - loss: 0.3262 - dice_coef: 0.6925 - iou: 0.5381 - recall_1: 0.7096 - precision_1: 0.8303 - val_loss: 0.5007 - val_dice_coef: 0.5310 - val_iou: 0.3954 - val_recall_1: 0.3896 - val_precision_1: 0.9080 - lr: 1.0000e-04
# Epoch 18/50
# 162/162 [==============================] - ETA: 0s - loss: 0.3068 - dice_coef: 0.7108 - iou: 0.5589 - recall_1: 0.7312 - precision_1: 0.8388
# Epoch 00018: val_loss did not improve from 0.42681
# 162/162 [==============================] - 159s 982ms/step - loss: 0.3068 - dice_coef: 0.7108 - iou: 0.5589 - recall_1: 0.7312 - precision_1: 0.8388 - val_loss: 0.4885 - val_dice_coef: 0.5472 - val_iou: 0.4150 - val_recall_1: 0.3975 - val_precision_1: 0.8939 - lr: 1.0000e-04
# Epoch 19/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2984 - dice_coef: 0.7193 - iou: 0.5687 - recall_1: 0.7323 - precision_1: 0.8409
# Epoch 00019: val_loss did not improve from 0.42681
# 162/162 [==============================] - 159s 982ms/step - loss: 0.2984 - dice_coef: 0.7193 - iou: 0.5687 - recall_1: 0.7323 - precision_1: 0.8409 - val_loss: 0.5050 - val_dice_coef: 0.5316 - val_iou: 0.3772 - val_recall_1: 0.4224 - val_precision_1: 0.9128 - lr: 1.0000e-04
# Epoch 20/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2881 - dice_coef: 0.7290 - iou: 0.5796 - recall_1: 0.7426 - precision_1: 0.8486
# Epoch 00020: val_loss did not improve from 0.42681
# 162/162 [==============================] - 159s 983ms/step - loss: 0.2881 - dice_coef: 0.7290 - iou: 0.5796 - recall_1: 0.7426 - precision_1: 0.8486 - val_loss: 0.4738 - val_dice_coef: 0.5632 - val_iou: 0.4193 - val_recall_1: 0.4092 - val_precision_1: 0.9200 - lr: 1.0000e-04
# Epoch 21/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2805 - dice_coef: 0.7364 - iou: 0.5884 - recall_1: 0.7443 - precision_1: 0.8496
# Epoch 00021: val_loss did not improve from 0.42681
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 162/162 [==============================] - 159s 982ms/step - loss: 0.2805 - dice_coef: 0.7364 - iou: 0.5884 - recall_1: 0.7443 - precision_1: 0.8496 - val_loss: 0.4356 - val_dice_coef: 0.5977 - val_iou: 0.4585 - val_recall_1: 0.4487 - val_precision_1: 0.8828 - lr: 1.0000e-04
# Epoch 22/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2657 - dice_coef: 0.7500 - iou: 0.6050 - recall_1: 0.7602 - precision_1: 0.8555
# Epoch 00022: val_loss improved from 0.42681 to 0.38873, saving model to files/model.h5
# 162/162 [==============================] - 163s 1s/step - loss: 0.2657 - dice_coef: 0.7500 - iou: 0.6050 - recall_1: 0.7602 - precision_1: 0.8555 - val_loss: 0.3887 - val_dice_coef: 0.6415 - val_iou: 0.4956 - val_recall_1: 0.5284 - val_precision_1: 0.8453 - lr: 1.0000e-05
# Epoch 23/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2587 - dice_coef: 0.7567 - iou: 0.6128 - recall_1: 0.7618 - precision_1: 0.8599
# Epoch 00023: val_loss improved from 0.38873 to 0.38773, saving model to files/model.h5
# 162/162 [==============================] - 163s 1s/step - loss: 0.2587 - dice_coef: 0.7567 - iou: 0.6128 - recall_1: 0.7618 - precision_1: 0.8599 - val_loss: 0.3877 - val_dice_coef: 0.6428 - val_iou: 0.4966 - val_recall_1: 0.5264 - val_precision_1: 0.8492 - lr: 1.0000e-05
# Epoch 24/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2558 - dice_coef: 0.7594 - iou: 0.6162 - recall_1: 0.7639 - precision_1: 0.8606
# Epoch 00024: val_loss improved from 0.38773 to 0.38369, saving model to files/model.h5
# 162/162 [==============================] - 163s 1s/step - loss: 0.2558 - dice_coef: 0.7594 - iou: 0.6162 - recall_1: 0.7639 - precision_1: 0.8606 - val_loss: 0.3837 - val_dice_coef: 0.6464 - val_iou: 0.4997 - val_recall_1: 0.5308 - val_precision_1: 0.8497 - lr: 1.0000e-05
# Epoch 25/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2536 - dice_coef: 0.7616 - iou: 0.6188 - recall_1: 0.7651 - precision_1: 0.8614
# Epoch 00025: val_loss did not improve from 0.38369
# 162/162 [==============================] - 159s 983ms/step - loss: 0.2536 - dice_coef: 0.7616 - iou: 0.6188 - recall_1: 0.7651 - precision_1: 0.8614 - val_loss: 0.3840 - val_dice_coef: 0.6462 - val_iou: 0.4998 - val_recall_1: 0.5316 - val_precision_1: 0.8506 - lr: 1.0000e-05
# Epoch 26/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2517 - dice_coef: 0.7634 - iou: 0.6210 - recall_1: 0.7659 - precision_1: 0.8620
# Epoch 00026: val_loss improved from 0.38369 to 0.38201, saving model to files/model.h5
# 162/162 [==============================] - 162s 1s/step - loss: 0.2517 - dice_coef: 0.7634 - iou: 0.6210 - recall_1: 0.7659 - precision_1: 0.8620 - val_loss: 0.3820 - val_dice_coef: 0.6479 - val_iou: 0.5014 - val_recall_1: 0.5350 - val_precision_1: 0.8506 - lr: 1.0000e-05
# Epoch 27/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2497 - dice_coef: 0.7654 - iou: 0.6235 - recall_1: 0.7669 - precision_1: 0.8628
# Epoch 00027: val_loss did not improve from 0.38201
# 162/162 [==============================] - 159s 982ms/step - loss: 0.2497 - dice_coef: 0.7654 - iou: 0.6235 - recall_1: 0.7669 - precision_1: 0.8628 - val_loss: 0.3825 - val_dice_coef: 0.6475 - val_iou: 0.5011 - val_recall_1: 0.5349 - val_precision_1: 0.8509 - lr: 1.0000e-05
# Epoch 28/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2480 - dice_coef: 0.7670 - iou: 0.6255 - recall_1: 0.7678 - precision_1: 0.8634
# Epoch 00028: val_loss did not improve from 0.38201
# 162/162 [==============================] - 159s 983ms/step - loss: 0.2480 - dice_coef: 0.7670 - iou: 0.6255 - recall_1: 0.7678 - precision_1: 0.8634 - val_loss: 0.3827 - val_dice_coef: 0.6474 - val_iou: 0.5010 - val_recall_1: 0.5356 - val_precision_1: 0.8505 - lr: 1.0000e-05
# Epoch 29/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2463 - dice_coef: 0.7687 - iou: 0.6276 - recall_1: 0.7685 - precision_1: 0.8642
# Epoch 00029: val_loss did not improve from 0.38201
# 162/162 [==============================] - 159s 982ms/step - loss: 0.2463 - dice_coef: 0.7687 - iou: 0.6276 - recall_1: 0.7685 - precision_1: 0.8642 - val_loss: 0.3828 - val_dice_coef: 0.6474 - val_iou: 0.5010 - val_recall_1: 0.5345 - val_precision_1: 0.8518 - lr: 1.0000e-05
# Epoch 30/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2445 - dice_coef: 0.7704 - iou: 0.6298 - recall_1: 0.7695 - precision_1: 0.8648
# Epoch 00030: val_loss did not improve from 0.38201
# 162/162 [==============================] - 159s 982ms/step - loss: 0.2445 - dice_coef: 0.7704 - iou: 0.6298 - recall_1: 0.7695 - precision_1: 0.8648 - val_loss: 0.3829 - val_dice_coef: 0.6473 - val_iou: 0.5010 - val_recall_1: 0.5340 - val_precision_1: 0.8525 - lr: 1.0000e-05
# Epoch 31/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2428 - dice_coef: 0.7721 - iou: 0.6318 - recall_1: 0.7705 - precision_1: 0.8654
# Epoch 00031: val_loss improved from 0.38201 to 0.38090, saving model to files/model.h5
# 162/162 [==============================] - 163s 1s/step - loss: 0.2428 - dice_coef: 0.7721 - iou: 0.6318 - recall_1: 0.7705 - precision_1: 0.8654 - val_loss: 0.3809 - val_dice_coef: 0.6490 - val_iou: 0.5024 - val_recall_1: 0.5385 - val_precision_1: 0.8512 - lr: 1.0000e-05
# Epoch 32/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2410 - dice_coef: 0.7739 - iou: 0.6341 - recall_1: 0.7711 - precision_1: 0.8663
# Epoch 00032: val_loss did not improve from 0.38090
# 162/162 [==============================] - 160s 983ms/step - loss: 0.2410 - dice_coef: 0.7739 - iou: 0.6341 - recall_1: 0.7711 - precision_1: 0.8663 - val_loss: 0.3818 - val_dice_coef: 0.6484 - val_iou: 0.5021 - val_recall_1: 0.5354 - val_precision_1: 0.8530 - lr: 1.0000e-05
# Epoch 33/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2391 - dice_coef: 0.7757 - iou: 0.6364 - recall_1: 0.7721 - precision_1: 0.8670
# Epoch 00033: val_loss did not improve from 0.38090
# 162/162 [==============================] - 159s 983ms/step - loss: 0.2391 - dice_coef: 0.7757 - iou: 0.6364 - recall_1: 0.7721 - precision_1: 0.8670 - val_loss: 0.3813 - val_dice_coef: 0.6488 - val_iou: 0.5025 - val_recall_1: 0.5351 - val_precision_1: 0.8542 - lr: 1.0000e-05
# Epoch 34/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2373 - dice_coef: 0.7774 - iou: 0.6386 - recall_1: 0.7729 - precision_1: 0.8676
# Epoch 00034: val_loss improved from 0.38090 to 0.37914, saving model to files/model.h5
# 162/162 [==============================] - 163s 1s/step - loss: 0.2373 - dice_coef: 0.7774 - iou: 0.6386 - recall_1: 0.7729 - precision_1: 0.8676 - val_loss: 0.3791 - val_dice_coef: 0.6507 - val_iou: 0.5043 - val_recall_1: 0.5383 - val_precision_1: 0.8543 - lr: 1.0000e-05
# Epoch 35/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2357 - dice_coef: 0.7790 - iou: 0.6406 - recall_1: 0.7736 - precision_1: 0.8685
# Epoch 00035: val_loss did not improve from 0.37914
# 162/162 [==============================] - 160s 983ms/step - loss: 0.2357 - dice_coef: 0.7790 - iou: 0.6406 - recall_1: 0.7736 - precision_1: 0.8685 - val_loss: 0.3830 - val_dice_coef: 0.6475 - val_iou: 0.5012 - val_recall_1: 0.5351 - val_precision_1: 0.8524 - lr: 1.0000e-05
# Epoch 36/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2342 - dice_coef: 0.7804 - iou: 0.6425 - recall_1: 0.7743 - precision_1: 0.8688
# Epoch 00036: val_loss improved from 0.37914 to 0.37844, saving model to files/model.h5
# 162/162 [==============================] - 163s 1s/step - loss: 0.2342 - dice_coef: 0.7804 - iou: 0.6425 - recall_1: 0.7743 - precision_1: 0.8688 - val_loss: 0.3784 - val_dice_coef: 0.6514 - val_iou: 0.5049 - val_recall_1: 0.5367 - val_precision_1: 0.8582 - lr: 1.0000e-05
# Epoch 37/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2322 - dice_coef: 0.7824 - iou: 0.6450 - recall_1: 0.7749 - precision_1: 0.8699
# Epoch 00037: val_loss did not improve from 0.37844
# 162/162 [==============================] - 160s 983ms/step - loss: 0.2322 - dice_coef: 0.7824 - iou: 0.6450 - recall_1: 0.7749 - precision_1: 0.8699 - val_loss: 0.3812 - val_dice_coef: 0.6494 - val_iou: 0.5031 - val_recall_1: 0.5374 - val_precision_1: 0.8520 - lr: 1.0000e-05
# Epoch 38/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2304 - dice_coef: 0.7841 - iou: 0.6473 - recall_1: 0.7757 - precision_1: 0.8707
# Epoch 00038: val_loss did not improve from 0.37844
# 162/162 [==============================] - 159s 983ms/step - loss: 0.2304 - dice_coef: 0.7841 - iou: 0.6473 - recall_1: 0.7757 - precision_1: 0.8707 - val_loss: 0.3809 - val_dice_coef: 0.6497 - val_iou: 0.5033 - val_recall_1: 0.5350 - val_precision_1: 0.8534 - lr: 1.0000e-05
# Epoch 39/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2292 - dice_coef: 0.7852 - iou: 0.6488 - recall_1: 0.7771 - precision_1: 0.8700
# Epoch 00039: val_loss improved from 0.37844 to 0.37642, saving model to files/model.h5
# 162/162 [==============================] - 163s 1s/step - loss: 0.2292 - dice_coef: 0.7852 - iou: 0.6488 - recall_1: 0.7771 - precision_1: 0.8700 - val_loss: 0.3764 - val_dice_coef: 0.6530 - val_iou: 0.5053 - val_recall_1: 0.5458 - val_precision_1: 0.8551 - lr: 1.0000e-05
# Epoch 40/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2302 - dice_coef: 0.7843 - iou: 0.6476 - recall_1: 0.7731 - precision_1: 0.8729
# Epoch 00040: val_loss did not improve from 0.37642
# 162/162 [==============================] - 160s 983ms/step - loss: 0.2302 - dice_coef: 0.7843 - iou: 0.6476 - recall_1: 0.7731 - precision_1: 0.8729 - val_loss: 0.3970 - val_dice_coef: 0.6362 - val_iou: 0.4912 - val_recall_1: 0.5271 - val_precision_1: 0.8475 - lr: 1.0000e-05
# Epoch 41/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2272 - dice_coef: 0.7872 - iou: 0.6514 - recall_1: 0.7772 - precision_1: 0.8714
# Epoch 00041: val_loss improved from 0.37642 to 0.37536, saving model to files/model.h5
# 162/162 [==============================] - 163s 1s/step - loss: 0.2272 - dice_coef: 0.7872 - iou: 0.6514 - recall_1: 0.7772 - precision_1: 0.8714 - val_loss: 0.3754 - val_dice_coef: 0.6540 - val_iou: 0.5072 - val_recall_1: 0.5426 - val_precision_1: 0.8599 - lr: 1.0000e-05
# Epoch 42/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2246 - dice_coef: 0.7897 - iou: 0.6547 - recall_1: 0.7781 - precision_1: 0.8733
# Epoch 00042: val_loss did not improve from 0.37536
# 162/162 [==============================] - 160s 983ms/step - loss: 0.2246 - dice_coef: 0.7897 - iou: 0.6547 - recall_1: 0.7781 - precision_1: 0.8733 - val_loss: 0.3846 - val_dice_coef: 0.6466 - val_iou: 0.5004 - val_recall_1: 0.5308 - val_precision_1: 0.8560 - lr: 1.0000e-05
# Epoch 43/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2227 - dice_coef: 0.7916 - iou: 0.6571 - recall_1: 0.7790 - precision_1: 0.8740
# Epoch 00043: val_loss did not improve from 0.37536
# 162/162 [==============================] - 159s 983ms/step - loss: 0.2227 - dice_coef: 0.7916 - iou: 0.6571 - recall_1: 0.7790 - precision_1: 0.8740 - val_loss: 0.3813 - val_dice_coef: 0.6491 - val_iou: 0.5028 - val_recall_1: 0.5352 - val_precision_1: 0.8583 - lr: 1.0000e-05
# Epoch 44/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2211 - dice_coef: 0.7931 - iou: 0.6592 - recall_1: 0.7798 - precision_1: 0.8746
# Epoch 00044: val_loss did not improve from 0.37536
# 162/162 [==============================] - 159s 983ms/step - loss: 0.2211 - dice_coef: 0.7931 - iou: 0.6592 - recall_1: 0.7798 - precision_1: 0.8746 - val_loss: 0.3762 - val_dice_coef: 0.6534 - val_iou: 0.5068 - val_recall_1: 0.5421 - val_precision_1: 0.8575 - lr: 1.0000e-05
# Epoch 45/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2196 - dice_coef: 0.7945 - iou: 0.6611 - recall_1: 0.7810 - precision_1: 0.8750
# Epoch 00045: val_loss did not improve from 0.37536
# 162/162 [==============================] - 159s 983ms/step - loss: 0.2196 - dice_coef: 0.7945 - iou: 0.6611 - recall_1: 0.7810 - precision_1: 0.8750 - val_loss: 0.3804 - val_dice_coef: 0.6502 - val_iou: 0.5039 - val_recall_1: 0.5386 - val_precision_1: 0.8557 - lr: 1.0000e-05
# Epoch 46/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2186 - dice_coef: 0.7955 - iou: 0.6625 - recall_1: 0.7814 - precision_1: 0.8755
# Epoch 00046: val_loss did not improve from 0.37536
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 1e-06.
# 162/162 [==============================] - 159s 983ms/step - loss: 0.2186 - dice_coef: 0.7955 - iou: 0.6625 - recall_1: 0.7814 - precision_1: 0.8755 - val_loss: 0.3776 - val_dice_coef: 0.6526 - val_iou: 0.5061 - val_recall_1: 0.5444 - val_precision_1: 0.8541 - lr: 1.0000e-05
# Epoch 47/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2170 - dice_coef: 0.7970 - iou: 0.6644 - recall_1: 0.7793 - precision_1: 0.8787
# Epoch 00047: val_loss improved from 0.37536 to 0.37326, saving model to files/model.h5
# 162/162 [==============================] - 163s 1s/step - loss: 0.2170 - dice_coef: 0.7970 - iou: 0.6644 - recall_1: 0.7793 - precision_1: 0.8787 - val_loss: 0.3733 - val_dice_coef: 0.6565 - val_iou: 0.5093 - val_recall_1: 0.5548 - val_precision_1: 0.8462 - lr: 1.0000e-06
# Epoch 48/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2162 - dice_coef: 0.7978 - iou: 0.6655 - recall_1: 0.7814 - precision_1: 0.8776
# Epoch 00048: val_loss did not improve from 0.37326
# 162/162 [==============================] - 160s 984ms/step - loss: 0.2162 - dice_coef: 0.7978 - iou: 0.6655 - recall_1: 0.7814 - precision_1: 0.8776 - val_loss: 0.3744 - val_dice_coef: 0.6554 - val_iou: 0.5083 - val_recall_1: 0.5532 - val_precision_1: 0.8465 - lr: 1.0000e-06
# Epoch 49/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2157 - dice_coef: 0.7982 - iou: 0.6661 - recall_1: 0.7822 - precision_1: 0.8773
# Epoch 00049: val_loss did not improve from 0.37326
# 162/162 [==============================] - 159s 983ms/step - loss: 0.2157 - dice_coef: 0.7982 - iou: 0.6661 - recall_1: 0.7822 - precision_1: 0.8773 - val_loss: 0.3746 - val_dice_coef: 0.6553 - val_iou: 0.5082 - val_recall_1: 0.5531 - val_precision_1: 0.8465 - lr: 1.0000e-06
# Epoch 50/50
# 162/162 [==============================] - ETA: 0s - loss: 0.2154 - dice_coef: 0.7985 - iou: 0.6665 - recall_1: 0.7827 - precision_1: 0.8772
# Epoch 00050: val_loss did not improve from 0.37326
# 162/162 [==============================] - 159s 983ms/step - loss: 0.2154 - dice_coef: 0.7985 - iou: 0.6665 - recall_1: 0.7827 - precision_1: 0.8772 - val_loss: 0.3747 - val_dice_coef: 0.6551 - val_iou: 0.5081 - val_recall_1: 0.5527 - val_precision_1: 0.8466 - lr: 1.0000e-06

# %% [markdown]
# ### Evaluating the Model:

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import pandas as pd
import cv2
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import accuracy_score, f1_score, jaccard_score, precision_score, recall_score
from tensorflow.keras.models import load_model

# %%
H = 1024
W = 1024

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.float32)
    return ori_x, x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (512, 512)
    # x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.int32)
    return ori_x, x

def load_data(path):
    x = sorted(glob(os.path.join(path, "image", "*.png")))
    y = sorted(glob(os.path.join(path, "mask", "*.png")))
    return x, y

def save_results(ori_x, ori_y, y_pred, save_image_path):
    line = np.ones((H, 10, 3)) * 255

    ori_y = np.expand_dims(ori_y, axis=-1)
    ori_y = np.concatenate([ori_y, ori_y, ori_y], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1) * 255

    cat_images = np.concatenate([ori_x, line, ori_y, line, y_pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)

# %%
""" Save the results in this folder """
create_dir("results")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data_1024", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.5
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score = [s[1:] for s in SCORE]
score = np.mean(score, axis=0)
print(f"Accuracy: {score[0]:0.5f}")
print(f"F1: {score[1]:0.5f}")
print(f"Jaccard: {score[2]:0.5f}")
print(f"Recall: {score[3]:0.5f}")
print(f"Precision: {score[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score.csv")
# Out:
# 100%|██████████| 27/27 [00:40<00:00,  1.49s/it]
# Accuracy: 0.99408
# F1: 0.63893
# Jaccard: 0.49298
# Recall: 0.63689
# Precision: 0.71997

# %%
""" Save the results in this folder """
create_dir("results_04")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data_1024", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.4
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results_04/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score = [s[1:] for s in SCORE]
score = np.mean(score, axis=0)
print(f"Accuracy: {score[0]:0.5f}")
print(f"F1: {score[1]:0.5f}")
print(f"Jaccard: {score[2]:0.5f}")
print(f"Recall: {score[3]:0.5f}")
print(f"Precision: {score[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score_04.csv")
# Out:
# 100%|██████████| 27/27 [00:39<00:00,  1.48s/it]
# Accuracy: 0.99404
# F1: 0.63957
# Jaccard: 0.49285
# Recall: 0.64370
# Precision: 0.71200

# %%
""" Save the results in this folder """
create_dir("results_06")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data_1024", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.6
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results_06/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score = [s[1:] for s in SCORE]
score = np.mean(score, axis=0)
print(f"Accuracy: {score[0]:0.5f}")
print(f"F1: {score[1]:0.5f}")
print(f"Jaccard: {score[2]:0.5f}")
print(f"Recall: {score[3]:0.5f}")
print(f"Precision: {score[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score_06.csv")
# Out:
# 100%|██████████| 27/27 [00:39<00:00,  1.48s/it]
# Accuracy: 0.99410
# F1: 0.63822
# Jaccard: 0.49297
# Recall: 0.63026
# Precision: 0.72786

# %%
""" Save the results in this folder """
create_dir("results_03")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data_1024", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.3
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results_03/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score = [s[1:] for s in SCORE]
score = np.mean(score, axis=0)
print(f"Accuracy: {score[0]:0.5f}")
print(f"F1: {score[1]:0.5f}")
print(f"Jaccard: {score[2]:0.5f}")
print(f"Recall: {score[3]:0.5f}")
print(f"Precision: {score[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score_03.csv")
# Out:
# 100%|██████████| 27/27 [00:40<00:00,  1.51s/it]
# Accuracy: 0.99401
# F1: 0.64024
# Jaccard: 0.49272
# Recall: 0.65089
# Precision: 0.70355

# %%
""" Save the results in this folder """
create_dir("results_02")

""" Load the model """
# with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
model = load_model("files/model.h5", compile=False)

""" Load the dataset """
dataset_path = os.path.join("new_data_1024", "test")
test_x, test_y = load_data(dataset_path)

""" Make the prediction and calculate the metrics values """
SCORE = []
for x, y in tqdm(zip(test_x, test_y), total=len(test_x)):
    """ Extracting name """
    name = x.split("/")[-1].split(".")[0]

    """ Read the image and mask """
    ori_x, x = read_image(x)
    ori_y, y = read_mask(y)

    """ Prediction """
    y_pred = model.predict(np.expand_dims(x, axis=0))[0]
    y_pred = y_pred > 0.2
    y_pred = y_pred.astype(np.int32)
    y_pred = np.squeeze(y_pred, axis=-1)

    """ Saving the images """
    save_image_path = f"results_02/{name}.png"
    save_results(ori_x, ori_y, y_pred, save_image_path)

    """ Flatten the array """
    y = y.flatten()
    y_pred = y_pred.flatten()

    """ Calculate the metrics """
    acc_value = accuracy_score(y, y_pred)
    f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
    jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
    recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
    precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
    SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

score = [s[1:] for s in SCORE]
score = np.mean(score, axis=0)
print(f"Accuracy: {score[0]:0.5f}")
print(f"F1: {score[1]:0.5f}")
print(f"Jaccard: {score[2]:0.5f}")
print(f"Recall: {score[3]:0.5f}")
print(f"Precision: {score[4]:0.5f}")

""" Saving """
df = pd.DataFrame(SCORE, columns=["Image", "Acc", "F1", "Jaccard", "Recall", "Precision"])
df.to_csv("files/score_02.csv")
# Out:
# 100%|██████████| 27/27 [00:40<00:00,  1.50s/it]
# Accuracy: 0.99395
# F1: 0.64014
# Jaccard: 0.49159
# Recall: 0.65967
# Precision: 0.69232
